# %% [markdown]
# # multi-omics analysis of *Yarrowia lipolytica* Reactor samples.
#
# This notebook analysis the omic that was obtained from Yarrowia lipolytica grown under variety of oxygen conditions in 2L bioreactors.

# %% [markdown]
# ## Sample Information
# | Sample Label | 	Media | 	Carbon source  | 	Nitrogen condition | 	comments |
# | --- | --- | --- | --- | --- |
# | Ctrl | 	YNB-100gGlucose-C/N100 | 	Glucose | 	C/N 100 | pO2 set to 25% |
# | Osc | 	YNB-100gGlucose-C/N100 | Glucose | 	C/N 100 | pO2 oscillating between ~5-40%	 |
# | Low | 	YNB-100gGlucose-C/N100 | 	Glucose | 	C/N 100 | pO2 set to 5%	 |

# %% [markdown]
# import libraries.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import zscore
from scipy.stats import ttest_ind
from statsmodels.stats.multitest import multipletests
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn3
from matplotlib.lines import Line2D

import re
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


from Bio.KEGG import REST
from Bio.KEGG.KGML import KGML_parser
import io

from scipy.stats import f_oneway
from statsmodels.stats.multitest import multipletests
sns.set_context("talk")
plt.rcParams['pdf.fonttype'] = 42 # when exporting as PDF, font can be edited as font

# %% [markdown]
# ## Create sample mapping for names to conditions/reactors.

# %%
# Data provided
sample_ids_prot_redox = [
    "Biostat2L_29_Oscillation_3.5", "Biostat2L_29_Oscillation_4.5", "Biostat2L_29_Oscillation_5.5",
    "Biostat2L_29_Oscillation_24", "Biostat2L_29_Oscillation_48", "Biostat2L_29_Oscillation_72",
    "Biostat2L_30_Control_3.5", "Biostat2L_30_Control_4.5", "Biostat2L_30_Control_5.5",
    "Biostat2L_30_Control_24", "Biostat2L_30_Control_48", "Biostat2L_30_Control_72",
    "Biostat2L_30_Oscillation_3.5", "Biostat2L_30_Oscillation_4.5", "Biostat2L_30_Oscillation_5.5",
    "Biostat2L_30_Oscillation_24", "Biostat2L_30_Oscillation_48", "Biostat2L_30_Oscillation_72",
    "Biostat2L_31_Control_3.5", "Biostat2L_31_Control_4.5", "Biostat2L_31_Control_5.5",
    "Biostat2L_31_Control_24", "Biostat2L_31_Control_48", "Biostat2L_31_Control_72",
    "Biostat2L_31_Oscillation_3.5", "Biostat2L_31_Oscillation_4.5", "Biostat2L_31_Oscillation_5.5",
    "Biostat2L_31_Oscillation_24", "Biostat2L_31_Oscillation_48", "Biostat2L_31_Oscillation_72",
    "Biostat2L_32_Control_3.5", "Biostat2L_32_Control_4.5", "Biostat2L_32_Control_5.5",
    "Biostat2L_32_Control_24", "Biostat2L_32_Control_48", "Biostat2L_32_Control_72",
    "Biostat2L_32_Low_3.5", "Biostat2L_32_Low_4.5", "Biostat2L_32_Low_5.5",
    "Biostat2L_32_Low_24", "Biostat2L_32_Low_48", "Biostat2L_32_Low_72",
    "Biostat2L_33_Low_3.5", "Biostat2L_33_Low_4.5", "Biostat2L_33_Low_5.5",
    "Biostat2L_33_Low_24", "Biostat2L_33_Low_48", "Biostat2L_33_Low_72",
    "Biostat2L_34_Low_3.5", "Biostat2L_34_Low_4.5", "Biostat2L_34_Low_5.5",
    "Biostat2L_34_Low_24", "Biostat2L_34_Low_48", "Biostat2L_34_Low_72",
]

sample_ids_metabolomics = [
        'PPI_Ylip_Osc_3hr_01',
        'PPI_Ylip_Osc_3hr_08',
        'PPI_Ylip_Osc_3hr_20',
        'PPI_Ylip_Osc_4hr_02',
        'PPI_Ylip_Osc_4hr_10',
        'PPI_Ylip_Osc_4hr_22',
        'PPI_Ylip_Osc_5hr_03',
        'PPI_Ylip_Osc_5hr_12',
        'PPI_Ylip_Osc_5hr_24',
        'PPI_Ylip_Osc_24hr_04',
        'PPI_Ylip_Osc_24hr_14',
        'PPI_Ylip_Osc_24hr_26',
        'PPI_Ylip_Osc_47hr_05',
        'PPI_Ylip_Osc_48hr_16',
        'PPI_Ylip_Osc_48hr_28',
        'PPI_Ylip_Osc_72hr_06',
        'PPI_Ylip_Osc_72hr_18',
        'PPI_Ylip_Osc_72hr_30',
        'PPI_Ylip_Ctrl_3hr_07',
        'PPI_Ylip_Ctrl_3hr_19',
        'PPI_Ylip_Ctrl_3hr_31',
        'PPI_Ylip_Ctrl_4hr_09',
        'PPI_Ylip_Ctrl_4hr_21',
        'PPI_Ylip_Ctrl_4hr_33',
        'PPI_Ylip_Ctrl_5hr_11',
        'PPI_Ylip_Ctrl_5hr_23',
        'PPI_Ylip_Ctrl_5hr_35',
        'PPI_Ylip_Ctrl_24hr_13',
        'PPI_Ylip_Ctrl_24hr_25',
        'PPI_Ylip_Ctrl_24hr_37',
        'PPI_Ylip_Ctrl_48hr_15',
        'PPI_Ylip_Ctrl_48hr_27',
        'PPI_Ylip_Ctrl_48hr_39',
        'PPI_Ylip_Ctrl_72hr_17',
        'PPI_Ylip_Ctrl_72hr_29',
        'PPI_Ylip_Ctrl_72hr_41',
        'PPI_Ylip_Low_3hr_32',
        'PPI_Ylip_Low_3hr_43',
        'PPI_Ylip_Low_3hr_49',
        'PPI_Ylip_Low_4hr_34',
        'PPI_Ylip_Low_4hr_44',
        'PPI_Ylip_Low_4hr_50',
        'PPI_Ylip_Low_5hr_36',
        'PPI_Ylip_Low_5hr_45',
        'PPI_Ylip_Low_5hr_51',
        'PPI_Ylip_Low_24hr_38',
        'PPI_Ylip_Low_24hr_46',
        'PPI_Ylip_Low_24hr_52',
        'PPI_Ylip_Low_48hr_40',
        'PPI_Ylip_Low_48hr_47',
        'PPI_Ylip_Low_48hr_53',
        'PPI_Ylip_Low_72hr_42',
        'PPI_Ylip_Low_72hr_48',
        'PPI_Ylip_Low_72hr_54',

]
lipid_timepoint = [
  3.5, 3.5, 3.5,
  4.5, 4.5, 4.5,
  5.5, 5.5, 5.5,
  24, 24, 24,
  48, 48, 48,
  72, 72, 72,
  3.5, 3.5, 3.5,
  4.5, 4.5, 4.5,
  5.5, 5.5, 5.5,
  24, 24, 24,
  48, 48, 48,
  72, 72, 72,
  3.5, 3.5, 3.5,
  4.5, 4.5, 4.5,
  5.5, 5.5, 5.5,
  24, 24, 24,
  48, 48, 48,
  72, 72, 72
]

sample_ids_lipidomics = [
        'PPI_Ylip_Osc_3hr_01',
        'PPI_Ylip_Osc_3hr_08',
        'PPI_Ylip_Osc_3hr_20',
        'PPI_Ylip_Osc_4hr_02',
        'PPI_Ylip_Osc_4hr_10',
        'PPI_Ylip_Osc_4hr_22',
        'PPI_Ylip_Osc_5hr_03',
        'PPI_Ylip_Osc_5hr_12',
        'PPI_Ylip_Osc_5hr_24',
        'PPI_Ylip_Osc_24hr_04',
        'PPI_Ylip_Osc_24hr_14',
        'PPI_Ylip_Osc_24hr_26',
        'PPI_Ylip_Osc_47hr_05',
        'PPI_Ylip_Osc_48hr_16',
        'PPI_Ylip_Osc_48hr_28',
        'PPI_Ylip_Osc_72hr_06',
        'PPI_Ylip_Osc_72hr_18',
        'PPI_Ylip_Osc_72hr_30',
        'PPI_Ylip_Ctrl_3hr_07',
        'PPI_Ylip_Ctrl_3hr_19',
        'PPI_Ylip_Ctrl_3hr_31',
        'PPI_Ylip_Ctrl_4hr_09',
        'PPI_Ylip_Ctrl_4hr_21',
        'PPI_Ylip_Ctrl_4hr_33',
        'PPI_Ylip_Ctrl_5hr_11',
        'PPI_Ylip_Ctrl_5hr_23',
        'PPI_Ylip_Ctrl_5hr_35',
        'PPI_Ylip_Ctrl_24hr_13',
        'PPI_Ylip_Ctrl_24hr_25',
        'PPI_Ylip_Ctrl_24hr_37',
        'PPI_Ylip_Ctrl_48hr_15',
        'PPI_Ylip_Ctrl_48hr_27',
        'PPI_Ylip_Ctrl_48hr_39',
        'PPI_Ylip_Ctrl_72hr_17',
        'PPI_Ylip_Ctrl_72hr_29',
        'PPI_Ylip_Ctrl_72hr_41',
        'PPI_Ylip_Low_3hr_32',
        'PPI_Ylip_Low_3hr_43',
        'PPI_Ylip_Low_3hr_49',
        'PPI_Ylip_Low_4hr_34',
        'PPI_Ylip_Low_4hr_44',
        'PPI_Ylip_Low_4hr_50',
        'PPI_Ylip_Low_5hr_36',
        'PPI_Ylip_Low_5hr_45',
        'PPI_Ylip_Low_5hr_51',
        'PPI_Ylip_Low_24hr_38',
        'PPI_Ylip_Low_24hr_46',
        'PPI_Ylip_Low_24hr_52',
        'PPI_Ylip_Low_48hr_40',
        'PPI_Ylip_Low_48hr_47',
        'PPI_Ylip_Low_48hr_53',
        'PPI_Ylip_Low_48hr_40',
        'PPI_Ylip_Low_48hr_47',
        'PPI_Ylip_Low_48hr_53',

]

conditions = [
    "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation",
    "Control", "Control", "Control", "Control", "Control", "Control",
    "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation",
    "Control", "Control", "Control", "Control", "Control", "Control",
    "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation",
    "Control", "Control", "Control", "Control", "Control", "Control",
    "Low", "Low", "Low", "Low", "Low", "Low",
    "Low", "Low", "Low", "Low", "Low", "Low",
    "Low", "Low", "Low", "Low", "Low", "Low"
]

timepoints = [
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
]

# Create sample_dict
sample_dict = {
    'prot_redox_ids':sample_ids_prot_redox,
    'lipid_ids':sample_ids_lipidomics,
    'lipid_timepoint': lipid_timepoint,
    'met_ids':sample_ids_metabolomics,
    "sample ID": sample_ids_prot_redox,
    "condition": conditions,
    "timepoint": timepoints,
}

lipid_condition_dict = dict(zip(sample_dict['lipid_ids'], sample_dict['condition']))
lipid_timepoint_dict = dict(zip(sample_dict['lipid_ids'], sample_dict['lipid_timepoint']))
met_condition_dict = dict(zip(sample_dict['met_ids'], sample_dict['condition']))
met_timepoint_dict = dict(zip(sample_dict['met_ids'], sample_dict['lipid_timepoint']))
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict_2 = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))


prot_timepoint_dict = {
    "Biostat2L_29_Oscillation_3.5": "Early",
    "Biostat2L_29_Oscillation_4.5": "Early",
    "Biostat2L_29_Oscillation_5.5": "Early",
    "Biostat2L_29_Oscillation_24": "Late",
    "Biostat2L_29_Oscillation_48": "Late",
    "Biostat2L_29_Oscillation_72": "Late",
    "Biostat2L_30_Control_3.5": "Early",
    "Biostat2L_30_Control_4.5": "Early",
    "Biostat2L_30_Control_5.5": "Early",
    "Biostat2L_30_Control_24": "Late",
    "Biostat2L_30_Control_48": "Late",
    "Biostat2L_30_Control_72": "Late",
    "Biostat2L_30_Oscillation_3.5": "Early",
    "Biostat2L_30_Oscillation_4.5": "Early",
    "Biostat2L_30_Oscillation_5.5": "Early",
    "Biostat2L_30_Oscillation_24": "Late",
    "Biostat2L_30_Oscillation_48": "Late",
    "Biostat2L_30_Oscillation_72": "Late",
    "Biostat2L_31_Control_3.5": "Early",
    "Biostat2L_31_Control_4.5": "Early",
    "Biostat2L_31_Control_5.5": "Early",
    "Biostat2L_31_Control_24": "Late",
    "Biostat2L_31_Control_48": "Late",
    "Biostat2L_31_Control_72": "Late",
    "Biostat2L_31_Oscillation_3.5": "Early",
    "Biostat2L_31_Oscillation_4.5": "Early",
    "Biostat2L_31_Oscillation_5.5": "Early",
    "Biostat2L_31_Oscillation_24": "Late",
    "Biostat2L_31_Oscillation_48": "Late",
    "Biostat2L_31_Oscillation_72": "Late",
    "Biostat2L_32_Control_3.5": "Early",
    "Biostat2L_32_Control_4.5": "Early",
    "Biostat2L_32_Control_5.5": "Early",
    "Biostat2L_32_Control_24": "Late",
    "Biostat2L_32_Control_48": "Late",
    "Biostat2L_32_Control_72": "Late",
    "Biostat2L_32_Low_3.5": "Early",
    "Biostat2L_32_Low_4.5": "Early",
    "Biostat2L_32_Low_5.5": "Early",
    "Biostat2L_32_Low_24": "Late",
    "Biostat2L_32_Low_48": "Late",
    "Biostat2L_32_Low_72": "Late",
    "Biostat2L_33_Low_3.5": "Early",
    "Biostat2L_33_Low_4.5": "Early",
    "Biostat2L_33_Low_5.5": "Early",
    "Biostat2L_33_Low_24": "Late",
    "Biostat2L_33_Low_48": "Late",
    "Biostat2L_33_Low_72": "Late",
    "Biostat2L_34_Low_3.5": "Early",
    "Biostat2L_34_Low_4.5": "Early",
    "Biostat2L_34_Low_5.5": "Early",
    "Biostat2L_34_Low_24": "Late",
    "Biostat2L_34_Low_48": "Late",
    "Biostat2L_34_Low_72": "Late",
}

# %% [markdown]
# ## Definitions.

# %%
def plot_pca(pca_df, explained_variance, hue='Condition', time='Timepoint', title=None):
    # Font style
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']

    # Force condition order and assign colors manually
    condition_order = ['Control', 'Low', 'Oscillation']
    color_palette = {
        'Control': '#9467bd',     # purple
        'Low': '#2ca02c',         # red
        'Oscillation': '#6495ED'  # blue
    }
    pca_df[hue] = pd.Categorical(pca_df[hue], categories=condition_order, ordered=True)

    # Timepoint to marker shape
    marker_styles = {
        24.0: 'v',   # triangle down
        48.0: 's',   # square
        72.0: 'D'    # diamond
    }
    default_marker = 'o'
    pca_df['Marker'] = pca_df[time].map(marker_styles).fillna(default_marker)

    # Create the plot
    plt.figure(figsize=(8, 8))
    ax = sns.scatterplot(
        x='PC1', y='PC2',
        hue=hue,
        hue_order=condition_order,
        style='Marker',
        markers={'o': 'o', 'v': 'v', 's': 's', 'D': 'D'},
        palette=color_palette,
        data=pca_df,
        s=150
    )

    # Label axes
    plt.xlabel(f'PC1 ({explained_variance[0]*100:.2f}% variance)', fontsize=24)
    plt.ylabel(f'PC2 ({explained_variance[1]*100:.2f}% variance)', fontsize=24)

    # Custom shape legend
    shape_legend_elements = [
        Line2D([0], [0], marker='o', color='w', label='< 24 h', markersize=10, markerfacecolor='black'),

        Line2D([0], [0], marker='v', color='w', label='24 h', markersize=10, markerfacecolor='black'),
        Line2D([0], [0], marker='s', color='w', label='48 h', markersize=10, markerfacecolor='black'),
        Line2D([0], [0], marker='D', color='w', label='72 h', markersize=10, markerfacecolor='black'),
    ]

    # Manually control legends to prevent cutoff & missing entries
    handles, labels = ax.get_legend_handles_labels()
    condition_handles = [h for h, l in zip(handles, labels) if l in condition_order]
    condition_labels = condition_order  # preserve order

    # Add condition legend
    first_legend = plt.legend(
        condition_handles, condition_labels,
        title=hue, bbox_to_anchor=(0.95, .75), loc='upper left',
        frameon=False, fontsize=16, title_fontsize=16
    )
    ax.add_artist(first_legend)

    # Add timepoint shape legend
    plt.legend(
        title='Time (h)', 
        handles=shape_legend_elements,
        bbox_to_anchor=(1.0, 0.50), loc='upper left',
        frameon=False, fontsize=16, title_fontsize=16
    )

    # Clean up axes and ticks
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_linewidth(0.5)
    ax.spines['bottom'].set_linewidth(0.5)
    ax.tick_params(axis='both', which='major', width=0.5, labelsize=20)
    plt.xticks(size=16)
    plt.yticks(size=16)

    # Prevent legends from getting cut off
    plt.tight_layout()

    # Save if filename provided
    if title:
        # plt.savefig(title, dpi=600, bbox_inches='tight', facecolor='white')
        plt.savefig(title+".png", dpi=600, bbox_inches="tight", facecolor="white")
        # or
        plt.savefig(title+".tiff", dpi=600, bbox_inches="tight")
        plt.savefig(title+".pdf", bbox_inches="tight" )
        plt.savefig(title+".svg", bbox_inches="tight")
    plt.show()


def global_stats_calc_prot(df, condition_series,protein_labels=None):
    # Prepare DataFrame for ANOVA
    # data = df.drop(columns=['Protein', 'ANOVA_p', 'ANOVA_padj'], errors='ignore').copy()
    # data.index = df['Protein']
    t_data = df.transpose()


    unique_conditions = condition_series.unique()

    # Perform ANOVA for each protein
    anova_results = {}
    for protein in t_data.columns:
        # Group data based on mapped conditions
        group_data = []
        for condition in unique_conditions:
            indices = condition_series[condition_series == condition].index
            group_data.append(t_data.loc[indices, protein].dropna().values)
        # Ensure valid data points are present across all condition groups
        if any(len(group) == 0 for group in group_data):
            print(f"Skipping protein {protein} due to insufficient data in some groups.")
            continue
        
        # Perform ANOVA
        try:
            f_stat, p_value = f_oneway(*group_data)
            anova_results[protein] = p_value
        except Exception as e:
            print(f"Error processing protein {protein}: {e}")
            continue

    # Convert ANOVA results into DataFrame
    anova_df = pd.DataFrame.from_dict(anova_results, orient='index', columns=['ANOVA_p'])
    # return anova_df
    # Adjust p-values using Benjamini-Hochberg
    if len(anova_df > 0):
        anova_df['ANOVA_padj'] = multipletests(anova_df['ANOVA_p'], method='fdr_bh')[1]
    else:
        print('No ANOVA_p values returned')

    # Merge ANOVA results back to the original DataFrame
    if protein_labels is not None:
        anova_df['Protein'] = protein_labels
        df['Protein'] = protein_labels
    else:
        anova_df['Site'] = anova_df.index
        # print(anova_df.index)
    merged_df = df.merge(anova_df, on='Site', how='left')

    return merged_df

def sort_by_significance(df,key_stat='ANOVA_padj'):
    if key_stat not in df.columns:
        raise KeyError("'Key_stat column is missing. Ensure ANOVA has been performed.")
    
    # Sort the DataFrame based on 'ANOVA_p' for significance
    # If you want to use 'ANOVA_padj', you can replace 'ANOVA_p' with 'ANOVA_padj'
    sorted_df = df.sort_values(by=key_stat).copy()

    # Select the top 100 most significant
    top_100_df = sorted_df.head(100)

    return top_100_df

def pca_preprocess(df):
    # Standardize the features
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(df)

    # Perform PCA
    # pca = make_pipeline(StandardScaler(), PCA())

    # pca = PCA()#n_components=2)  # Reduce to 2 components for visualization
    pca = PCA(n_components=2)  # Reduce to 2 components for visualization
    pca_result = pca.fit_transform(df)

    # Capture the explained variance for each component
    explained_variance = pca.explained_variance_ratio_

    # Create a new DataFrame with PCA results
    # pca_df = pd.DataFrame(
    #     pca_result,
    #     columns=[f"PC{i+1}" for i in range(pca_result.shape[1])]
    # )
    pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])
    return pca_df, explained_variance


def get_dynamic_limits(df):
    # Compute the overall minimum and maximum values from the dataset
    x_min = df.min()[0]-1
    x_max = df.max()[0]+1
    
    y_min = 0
    y_max = dataset.max()[2]+1

    return x_min,x_max,y_min,y_max


def volcano_plot(dataset,title=None):
    fig,ax = plt.subplots(1,1,figsize=(7,7))

    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']
    
    x_min,x_max, y_min,y_max = get_dynamic_limits(dataset)

    x_limits = (x_min,x_max)
    y_limits = (0,y_max)
    
    y_cutoff = -np.log10(0.05)
    x_cutoff = 0.37851162325
    sns.scatterplot(data = dataset, 
                    x = 'log2FC', 
                    y = '-logP_adj', 
                    hue='class', 
                    s = 25, alpha = 0.5, palette=['#0571B0','#BABABA','#CA0020'], ax=ax)
    legend_handles, _= ax.get_legend_handles_labels()
    
    legend = ax.legend(legend_handles, ['down-regulated','not significant','up-regulated'], 
              bbox_to_anchor=(1,1), 
              title='')
    
    legend.get_frame().set_edgecolor('none')  # Disable the border

    ax.plot(x_limits,[y_cutoff,y_cutoff],'k--')
    ax.plot([x_cutoff,x_cutoff],y_limits,'k--')
    ax.plot([-x_cutoff,-x_cutoff],y_limits,'k--')
    ax.set_ylabel(r'-Log$_2$(P$_{adj}$)', fontsize=24)
    ax.set_xlabel(r'Log$_2$(FC)', fontsize=24)
    if title:
        fig.savefig(title+'.png')

def log2FC_function(df1,df2):
    # substrates 1 dataframe from the second. 
    mean1 = df1.mean(axis=1)
    mean2 = df2.mean(axis=1)
    return (mean1-mean2)

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# import matplotlib.pyplot as plt
# import seaborn as sns
# import numpy as np
# import pandas as pd

def annotate_top_genes(ax, dataset, num_top=5):
    """
    Annotates the top up-regulated and down-regulated genes on the volcano plot with dynamic text positioning.
    """
    # Sort dataset by log2FC and find top up-regulated and down-regulated genes
    top_up = dataset.nlargest(num_top, 'log2FC')
    top_down = dataset.nsmallest(num_top, 'log2FC')

    # Combine top genes using pd.concat (instead of deprecated append)
    top_genes = pd.concat([top_up, top_down])
    
    for protein_id, row in top_genes.iterrows():
        # Determine text position based on log2FC (right for positive, left for negative)
        if row['log2FC'] > 0:
            xytext = (row['log2FC'] + 0.5, row['-logP_adj'] + 0.5)  # Right-hand side for positive values
        else:
            xytext = (row['log2FC'] - 0.5, row['-logP_adj'] + 0.5)  # Left-hand side for negative values
        
        ax.annotate(
            protein_id, # Annotate with proteinID, which is the index
            xy=(row['log2FC'], row['-logP_adj']), # Point where annotation starts
            xytext=xytext, # Adjust text placement dynamically
            fontsize=10,
            arrowprops=dict(arrowstyle="->", color="black", lw=1.5), # Arrow pointing to the data point
            bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white") # Label background
        )


def volcano_plot_annotate(dataset, title=None):
    """
    Function to plot the volcano plot and annotate the top 5 up-regulated and down-regulated genes with arrows.
    """
    # Extract dynamic plot limits
    x_min, x_max, y_min, y_max = get_dynamic_limits(dataset)
    x_limits = (x_min, x_max)
    y_limits = (0, y_max)

    # Initialize plot
    fig, ax = plt.subplots(1, 1, figsize=(7, 7))
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']

    # Add scatter plot
    sns.scatterplot(data=dataset, 
                    x='log2FC', 
                    y='-logP_adj', 
                    hue='class', 
                    s=25, alpha=0.5, palette=['#0571B0','#BABABA','#CA0020'], ax=ax)
    
    # Add legend
    legend_handles, _ = ax.get_legend_handles_labels()
    legend = ax.legend(legend_handles, ['down-regulated', 'not significant', 'up-regulated'], 
                       bbox_to_anchor=(1, 1), title='')
    legend.get_frame().set_edgecolor('none')  # Disable legend border

    # Draw threshold cutoff lines
    y_cutoff = -np.log10(0.05)
    x_cutoff = 0.37851162325
    ax.plot(x_limits, [y_cutoff, y_cutoff], 'k--')
    ax.plot([x_cutoff, x_cutoff], y_limits, 'k--')
    ax.plot([-x_cutoff, -x_cutoff], y_limits, 'k--')

    # Label axes
    ax.set_ylabel(r'-Log$_2$(P$_{adj}$)', fontsize=24)
    ax.set_xlabel(r'Log$_2$(FC)', fontsize=24)

    # Annotate the top genes
    annotate_top_genes(ax, dataset)

    # Save the plot if a title is provided
    if title:
        fig.savefig(f"{title}.png")

    return fig, ax

# %% [markdown]
# # Read in Annotations.

# %% [markdown]
# Annotations downloaded for FKP355 strain from JGI, June 2025.
#
#
# https://mycocosm.jgi.doe.gov/pages/search-for-genes.jsf?organism=Yarlip1

# %% [markdown]
# ### grab KEGG info.

# %%
KEGGannotate = pd.read_table('../Annotations/Filtered Models ("best")/Functional Annotations/EC annotations and KEGG pathway mappings/YarliW29_1_GeneCatalog_proteins_20190319_KEGG.tab')
# annotate.index = annotate.index.map(str)
KEGGannotate.head()
# Kegg_pathwayDict = dict(zip(annotate.index,annotate.pathway))
# Out:
#    #proteinId     ecNum                                definition  \
# 0           5  4.2.1.24                 Porphobilinogen synthase.
# 1          11   6.1.1.5                  Isoleucine--tRNA ligase.
# 2          11   6.1.1.5                  Isoleucine--tRNA ligase.
# 3          32  3.1.4.46  Glycerophosphodiester phosphodiesterase.
# 4          32  3.1.4.46  Glycerophosphodiester phosphodiesterase.
#
#                                    catalyticActivity cofactors  \
# 0   2 5-aminolevulinate = porphobilinogen + 2 H(2)O.     Zinc.
# 1  ATP + L-isoleucine + tRNA(Ile) = AMP + diphosp...        \N
# 2  ATP + L-isoleucine + tRNA(Ile) = AMP + diphosp...        \N
# 3  A glycerophosphodiester + H(2)O = an alcohol +...        \N
# 4  A glycerophosphodiester + H(2)O = an alcohol +...        \N
#
#                                   associatedDiseases  \
# 0  Susceptibility to lead poisoning; MIM:125270. ...
# 1                                                 \N
# 2                                                 \N
# 3                                                 \N
# 4                                                 \N
#
#                                        pathway  \
# 0         Porphyrin and chlorophyll metabolism
# 1  Valine, leucine and isoleucine biosynthesis
# 2                  Aminoacyl-tRNA biosynthesis
# 3                     Phospholipid degradation
# 4                      Glycerolipid metabolism
#
#                           pathway_class pathway_type
# 0  Metabolism of Cofactors and Vitamins    METABOLIC
# 1                 Amino Acid Metabolism    METABOLIC
# 2                           TRANSLATION   REGULATORY
# 3          Metabolism of Complex Lipids    METABOLIC
# 4          Metabolism of Complex Lipids    METABOLIC

# %%
KEGGannotate.shape
# Out:
# (2516, 9)

# %%
# Group by 'proteinId' and aggregate columns into lists for simpler downstream processing. 
KEGGannotate = KEGGannotate.groupby('#proteinId').agg({
    'definition': list,
    'catalyticActivity': list,
    'pathway': list,
    'pathway_class': list,
    'pathway_type': list,
    'ecNum': list,
    'cofactors': list,
}).reset_index()

# %% [markdown]
# ### grab GO info.

# %%
GOannotate  = pd.read_table('../Annotations/Filtered Models ("best")/Functional Annotations/GO/YarliW29_1_GeneCatalog_proteins_20190319_GO.tab')

GOannotate.head()
# Out:
#    #proteinId  gotermId                             goName  \
# 0           5      3028  porphobilinogen synthase activity
# 1          11       162                 nucleotide binding
# 2          11      3172     aminoacyl-tRNA ligase activity
# 3          11      3736                        ATP binding
# 4          11      3930                          cytoplasm
#
#            gotermType       goAcc
# 0  molecular_function  GO:0004655
# 1  molecular_function  GO:0000166
# 2  molecular_function  GO:0004812
# 3  molecular_function  GO:0005524
# 4  cellular_component  GO:0005737

# %%
# Group by 'proteinId' and aggregate columns into lists for simpler downstream processing. 
GOannotate = GOannotate.groupby('#proteinId').agg({
    'gotermId': list,
    'gotermType': list,
    'goName': list,
    'goAcc': list,
}).reset_index()

# %% [markdown]
# ## Merge annotations.

# %%
merged_annotations = pd.merge(KEGGannotate, GOannotate, on='#proteinId', how='outer')

# Merge the result with df3
# merged_annotations = pd.merge(merged_annotations, KEGGannotate, on='proteinId', how='outer')

# %%
merged_annotations.head()
# Out:
#    #proteinId                                         definition  \
# 0           5                        [Porphobilinogen synthase.]
# 1          11  [Isoleucine--tRNA ligase., Isoleucine--tRNA li...
# 2          12                                                NaN
# 3          13                                                NaN
# 4          14                                                NaN
#
#                                    catalyticActivity  \
# 0  [2 5-aminolevulinate = porphobilinogen + 2 H(2...
# 1  [ATP + L-isoleucine + tRNA(Ile) = AMP + diphos...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              pathway  \
# 0             [Porphyrin and chlorophyll metabolism]
# 1  [Valine, leucine and isoleucine biosynthesis, ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                             pathway_class             pathway_type  \
# 0  [Metabolism of Cofactors and Vitamins]              [METABOLIC]
# 1    [Amino Acid Metabolism, TRANSLATION]  [METABOLIC, REGULATORY]
# 2                                     NaN                      NaN
# 3                                     NaN                      NaN
# 4                                     NaN                      NaN
#
#                 ecNum cofactors  \
# 0          [4.2.1.24]   [Zinc.]
# 1  [6.1.1.5, 6.1.1.5]  [\N, \N]
# 2                 NaN       NaN
# 3                 NaN       NaN
# 4                 NaN       NaN
#
#                                           gotermId  \
# 0                                           [3028]
# 1  [162, 3172, 3736, 3930, 4556, 4561, 3182, 4571]
# 2                                           [3737]
# 3                                     [4604, 5817]
# 4                              [3737, 2378, 24058]
#
#                                           gotermType  \
# 0                               [molecular_function]
# 1  [molecular_function, molecular_function, molec...
# 2                               [molecular_function]
# 3           [biological_process, molecular_function]
# 4  [molecular_function, molecular_function, molec...
#
#                                               goName  \
# 0                [porphobilinogen synthase activity]
# 1  [nucleotide binding, aminoacyl-tRNA ligase act...
# 2                                      [GTP binding]
# 3  [protein amino acid dephosphorylation, protein...
# 4  [GTP binding, GTPase activity, hydrolase activ...
#
#                                                goAcc
# 0                                       [GO:0004655]
# 1  [GO:0000166, GO:0004812, GO:0005524, GO:000573...
# 2                                       [GO:0005525]
# 3                           [GO:0006470, GO:0008138]
# 4               [GO:0005525, GO:0003924, GO:0050800]

# %%
# merged_annotations.to_csv('../Annotations/GO_KEGG_EC_annotations.csv')

# %% [markdown]
# ## grab KOG info.

# %%
kog_annotations = pd.read_table('../Annotations/Filtered Models ("best")/Functional Annotations/YarliW29_1_GeneCatalog_proteins_20190319_KOG.tab')
kog_annotations.rename(columns={'proteinId': '#proteinId'}, inplace=True)

# %%
kog_annotations.head()
# Out:
#    #transcriptId  #proteinId    kogid  \
# 0           6541        5563  KOG0001
# 1           6541        5563  KOG0001
# 2           7831        6853  KOG0004
# 3           8270        7292  KOG0005
# 4           8270        7292  KOG0005
#
#                                     kogdefline  \
# 0        Ubiquitin and ubiquitin-like proteins
# 1        Ubiquitin and ubiquitin-like proteins
# 2  Ubiquitin/40S ribosomal protein S27a fusion
# 3                       Ubiquitin-like protein
# 4                       Ubiquitin-like protein
#
#                                             kogClass  \
# 0  Posttranslational modification, protein turnov...
# 1                  General function prediction only
# 2   Translation, ribosomal structure and biogenesis
# 3  Cell cycle control, cell division, chromosome ...
# 4  Posttranslational modification, protein turnov...
#
#                              kogGroup
# 0    CELLULAR PROCESSES AND SIGNALING
# 1                POORLY CHARACTERIZED
# 2  INFORMATION STORAGE AND PROCESSING
# 3                          METABOLISM
# 4    CELLULAR PROCESSES AND SIGNALING

# %%
# Group by 'proteinId' and aggregate columns into lists for simpler downstream processing. 
kog_annotations = kog_annotations.groupby('#proteinId').agg({
    'kogid': list,
    'kogdefline': list,
    'kogClass': list,
    'kogGroup': list,
}).reset_index()

# %% [markdown]
# ## Merge KOG with KEGG / GO annotations.

# %%
merged_annotations = pd.merge(kog_annotations, merged_annotations, on='#proteinId', how='outer')

# Merge the result with df3
# merged_annotations = pd.merge(merged_annotations, KEGGannotate, on='proteinId', how='outer')

# %%
merged_annotations.head()
# Out:
#    #proteinId      kogid                                         kogdefline  \
# 0           4  [KOG2262]      [Sexual differentiation process protein ISP4]
# 1           5  [KOG0101]  [Molecular chaperones HSP70/HSC70, HSP70 super...
# 2          11  [KOG0434]                        [Isoleucyl-tRNA synthetase]
# 3          12  [KOG1487]       [GTP-binding protein DRG1 (ODN superfamily)]
# 4          13  [KOG1716]                     [Dual specificity phosphatase]
#
#                                             kogClass  \
# 0                  [Signal transduction mechanisms ]
# 1  [Posttranslational modification, protein turno...
# 2  [Translation, ribosomal structure and biogenes...
# 3                  [Signal transduction mechanisms ]
# 4                              [Defense mechanisms ]
#
#                                kogGroup  \
# 0    [CELLULAR PROCESSES AND SIGNALING]
# 1    [CELLULAR PROCESSES AND SIGNALING]
# 2  [INFORMATION STORAGE AND PROCESSING]
# 3    [CELLULAR PROCESSES AND SIGNALING]
# 4    [CELLULAR PROCESSES AND SIGNALING]
#
#                                           definition  \
# 0                                                NaN
# 1                        [Porphobilinogen synthase.]
# 2  [Isoleucine--tRNA ligase., Isoleucine--tRNA li...
# 3                                                NaN
# 4                                                NaN
#
#                                    catalyticActivity  \
# 0                                                NaN
# 1  [2 5-aminolevulinate = porphobilinogen + 2 H(2...
# 2  [ATP + L-isoleucine + tRNA(Ile) = AMP + diphos...
# 3                                                NaN
# 4                                                NaN
#
#                                              pathway  \
# 0                                                NaN
# 1             [Porphyrin and chlorophyll metabolism]
# 2  [Valine, leucine and isoleucine biosynthesis, ...
# 3                                                NaN
# 4                                                NaN
#
#                             pathway_class             pathway_type  \
# 0                                     NaN                      NaN
# 1  [Metabolism of Cofactors and Vitamins]              [METABOLIC]
# 2    [Amino Acid Metabolism, TRANSLATION]  [METABOLIC, REGULATORY]
# 3                                     NaN                      NaN
# 4                                     NaN                      NaN
#
#                 ecNum cofactors  \
# 0                 NaN       NaN
# 1          [4.2.1.24]   [Zinc.]
# 2  [6.1.1.5, 6.1.1.5]  [\N, \N]
# 3                 NaN       NaN
# 4                 NaN       NaN
#
#                                           gotermId  \
# 0                                              NaN
# 1                                           [3028]
# 2  [162, 3172, 3736, 3930, 4556, 4561, 3182, 4571]
# 3                                           [3737]
# 4                                     [4604, 5817]
#
#                                           gotermType  \
# 0                                                NaN
# 1                               [molecular_function]
# 2  [molecular_function, molecular_function, molec...
# 3                               [molecular_function]
# 4           [biological_process, molecular_function]
#
#                                               goName  \
# 0                                                NaN
# 1                [porphobilinogen synthase activity]
# 2  [nucleotide binding, aminoacyl-tRNA ligase act...
# 3                                      [GTP binding]
# 4  [protein amino acid dephosphorylation, protein...
#
#                                                goAcc
# 0                                                NaN
# 1                                       [GO:0004655]
# 2  [GO:0000166, GO:0004812, GO:0005524, GO:000573...
# 3                                       [GO:0005525]
# 4                           [GO:0006470, GO:0008138]

# %% [markdown]
# ## save annotation file.

# %%
# merged_annotations.to_csv('../Annotations/KOG_GO_KEGG_EC_annotations.csv')

# %%
annot_plus_kog = merged_annotations.copy()

# %% [markdown]
# # Read in protein and PTM data.

# %%
# proteomics_data = pd.read_csv('../Data/PPI_yarrowia_REDOX_Global/result/PTM/PPI_yarrowia_protein_abundance.csv')
# with annotations
# proteomics_data = pd.read_csv('../Data/Proteomic_PTMs/redox_global/PPI_yarrowia_protein_abundance_wAnnotations.csv')

phospho_data = pd.read_csv('../Data/Proteomic_PTMs/redox_global/PPI_yarrowia_all_ptms.csv')
# phospho_data = pd.read_csv('../Data/PPI_yarrowia_REDOX_Global/Phospho/PPI_yarrowia/result/PTM/PPI_yarrowia_all_ptms.csv')
# phospho_data = phospho_data[phospho_data['Type']=='Ph']

phopho = phospho_data[sample_ids_prot_redox]

# %%
phospho_data.head()
# Out:
#                                       Peptide                      Site  \
# 0                              R.IEPIC@AQGR.I  jgi|YarliW29_1|1000@C503
# 1                             K.VFIGSC@TNSR.I  jgi|YarliW29_1|1002@C352
# 2                                R.C@ASTSNR.N  jgi|YarliW29_1|1002@C430
# 3                       K.DC@TLATVDHNIPTTTR.K   jgi|YarliW29_1|1002@C55
# 4  K.ASILVVSGDNFGC@GSSR.E; L.VVSGDNFGC@GSSR.E  jgi|YarliW29_1|1002@C614
#
#                UniProt              Protein Residue                        id  \
# 0  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000    C503  jgi|YarliW29_1|1000@C503
# 1  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C352  jgi|YarliW29_1|1002@C352
# 2  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C430  jgi|YarliW29_1|1002@C430
# 3  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002     C55   jgi|YarliW29_1|1002@C55
# 4  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C614  jgi|YarliW29_1|1002@C614
#
#    Total missingness  Oscillation_24 missingness  Oscillation_3.5 missingness  \
# 0                  0                           0                            0
# 1                  0                           0                            0
# 2                 36                           3                            3
# 3                  0                           0                            0
# 4                  0                           0                            0
#
#    Oscillation_4.5 missingness  ...  Oscillation_24/Oscillation_3.5_adj-p  \
# 0                            0  ...                              0.004273
# 1                            0  ...                              0.074259
# 2                            3  ...                                   NaN
# 3                            0  ...                              0.016003
# 4                            0  ...                              0.009960
#
#    Oscillation_48/Oscillation_3.5  Oscillation_48/Oscillation_3.5_pval  \
# 0                        1.760655                             0.000120
# 1                        0.386963                             0.260477
# 2                             NaN                                  NaN
# 3                        1.571801                             0.008855
# 4                        2.879304                             0.000645
#
#    Oscillation_48/Oscillation_3.5_adj-p  Oscillation_72/Oscillation_3.5  \
# 0                              0.001042                        1.937960
# 1                              0.280174                        0.273868
# 2                                   NaN                             NaN
# 3                              0.015009                        1.852336
# 4                              0.002500                        3.240543
#
#    Oscillation_72/Oscillation_3.5_pval  Oscillation_72/Oscillation_3.5_adj-p  \
# 0                             0.000041                              0.000449
# 1                             0.235540                              0.248877
# 2                                  NaN                                   NaN
# 3                             0.000728                              0.002182
# 4                             0.000032                              0.000423
#
#    Type  Experiment  site_number
# 0    Ox         PTM            1
# 1    Ox         PTM            8
# 2    Ox         PTM            8
# 3    Ox         PTM            8
# 4    Ox         PTM            8
#
# [5 rows x 170 columns]

# %%
phospho_data["proteinId"] = phospho_data["Protein"].str.rsplit("|", n=1).str[-1]
phospho_data["#proteinId"] = phospho_data["proteinId"].copy().astype(int)

# %%
phospho_data.head()
# Out:
#                                       Peptide                      Site  \
# 0                              R.IEPIC@AQGR.I  jgi|YarliW29_1|1000@C503
# 1                             K.VFIGSC@TNSR.I  jgi|YarliW29_1|1002@C352
# 2                                R.C@ASTSNR.N  jgi|YarliW29_1|1002@C430
# 3                       K.DC@TLATVDHNIPTTTR.K   jgi|YarliW29_1|1002@C55
# 4  K.ASILVVSGDNFGC@GSSR.E; L.VVSGDNFGC@GSSR.E  jgi|YarliW29_1|1002@C614
#
#                UniProt              Protein Residue                        id  \
# 0  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000    C503  jgi|YarliW29_1|1000@C503
# 1  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C352  jgi|YarliW29_1|1002@C352
# 2  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C430  jgi|YarliW29_1|1002@C430
# 3  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002     C55   jgi|YarliW29_1|1002@C55
# 4  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C614  jgi|YarliW29_1|1002@C614
#
#    Total missingness  Oscillation_24 missingness  Oscillation_3.5 missingness  \
# 0                  0                           0                            0
# 1                  0                           0                            0
# 2                 36                           3                            3
# 3                  0                           0                            0
# 4                  0                           0                            0
#
#    Oscillation_4.5 missingness  ...  Oscillation_48/Oscillation_3.5_pval  \
# 0                            0  ...                             0.000120
# 1                            0  ...                             0.260477
# 2                            3  ...                                  NaN
# 3                            0  ...                             0.008855
# 4                            0  ...                             0.000645
#
#    Oscillation_48/Oscillation_3.5_adj-p  Oscillation_72/Oscillation_3.5  \
# 0                              0.001042                        1.937960
# 1                              0.280174                        0.273868
# 2                                   NaN                             NaN
# 3                              0.015009                        1.852336
# 4                              0.002500                        3.240543
#
#    Oscillation_72/Oscillation_3.5_pval  Oscillation_72/Oscillation_3.5_adj-p  \
# 0                             0.000041                              0.000449
# 1                             0.235540                              0.248877
# 2                                  NaN                                   NaN
# 3                             0.000728                              0.002182
# 4                             0.000032                              0.000423
#
#    Type  Experiment  site_number  proteinId  #proteinId
# 0    Ox         PTM            1       1000        1000
# 1    Ox         PTM            8       1002        1002
# 2    Ox         PTM            8       1002        1002
# 3    Ox         PTM            8       1002        1002
# 4    Ox         PTM            8       1002        1002
#
# [5 rows x 172 columns]

# %%
annotated_phospho = phospho_data.merge(annot_plus_kog, on='#proteinId', how='left')
# annotated_redox.to_csv('../Data/PPI_yarrowia_REDOX_Global/result/PTM/PPI_yarrowia_phospho_wAnnotations_.csv')

# %% [markdown]
# df['YALI1_protID'] = df['proteinId'].map(JGI_Yali1.set_index('JGI_protID')['YALI1_protID'])
# df['YALI0_locus'] = df['YALI1_protID'].map(Yali1_Yali0.set_index('YALI1_Proteins')['YALI0_locus_ID'])
# df['YALI1_protID_converted'] = df['YALI1_protID'].str.replace('g', 'p', regex=False)
# df['YALI2'] = df['YALI1_protID_converted'].map(Yali1_Yali2.set_index('YALI1')['YALI2'])

# %%
annotated_phospho = pd.read_csv( "../Data/Proteomic_PTMs/phospho/PPI_yarrowia_PHOSPHO_wAnnotations.csv")

# %%
# phospho_data = pd.read_csv('../Data/Proteomic_PTMs/phospho/PPI_yarrowia_all_ptms.csv')

# %%
# phospho_data = phospho_data[phospho_data['Type']=='Ph']

# %%
# phos = phospho_data[sample_ids_prot_redox]
# phos.dropna(axis=0, inplace=True)

# %%
phospho = phospho_data[sample_ids_prot_redox]

phospho.dropna(axis=0, inplace=True)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/784544916.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phospho.dropna(axis=0, inplace=True)

# %%
phospho.head()
# Out:
#    Biostat2L_29_Oscillation_3.5  Biostat2L_29_Oscillation_4.5  \
# 0                     16.846811                     16.562889
# 1                     19.436363                     19.469720
# 3                     18.252694                     18.286464
# 4                     15.896053                     15.358501
# 5                     15.450753                     14.430536
#
#    Biostat2L_29_Oscillation_5.5  Biostat2L_29_Oscillation_24  \
# 0                     16.827315                    17.771583
# 1                     19.418304                    19.220965
# 3                     18.422682                    19.363283
# 4                     15.582766                    17.383142
# 5                     14.176803                    17.133909
#
#    Biostat2L_29_Oscillation_48  Biostat2L_29_Oscillation_72  \
# 0                    18.596711                    18.613297
# 1                    19.952574                    19.523283
# 3                    20.099247                    20.247919
# 4                    18.595572                    18.774382
# 5                    18.364913                    18.364627
#
#    Biostat2L_30_Control_3.5  Biostat2L_30_Control_4.5  \
# 0                 16.792441                 16.258855
# 1                 18.877320                 19.745658
# 3                 18.424198                 18.487841
# 4                 15.784976                 15.481521
# 5                 15.162194                 14.713784
#
#    Biostat2L_30_Control_5.5  Biostat2L_30_Control_24  ...  \
# 0                 16.392205                17.457152  ...
# 1                 18.694869                19.717296  ...
# 3                 18.562002                18.874312  ...
# 4                 15.453148                17.278106  ...
# 5                 14.530765                17.177533  ...
#
#    Biostat2L_33_Low_5.5  Biostat2L_33_Low_24  Biostat2L_33_Low_48  \
# 0             16.605363            16.635118            16.142903
# 1             18.014867            18.321864            19.446600
# 3             18.599085            18.679093            18.578693
# 4             15.417675            15.447046            16.150221
# 5             14.516666            15.164010            15.375349
#
#    Biostat2L_33_Low_72  Biostat2L_34_Low_3.5  Biostat2L_34_Low_4.5  \
# 0            16.651285             16.641320             16.532442
# 1            19.953698             19.213165             18.988372
# 3            18.428186             18.354685             18.568332
# 4            16.877026             15.691573             15.082033
# 5            16.649625             15.161328             14.884083
#
#    Biostat2L_34_Low_5.5  Biostat2L_34_Low_24  Biostat2L_34_Low_48  \
# 0             16.538504            16.451691            16.481918
# 1             18.240673            19.104072            19.454477
# 3             18.748328            18.593297            18.424024
# 4             14.969355            15.920855            16.629091
# 5             14.430293            15.278934            15.935781
#
#    Biostat2L_34_Low_72
# 0            16.782876
# 1            20.131243
# 3            18.238569
# 4            17.021753
# 5            16.193239
#
# [5 rows x 54 columns]

# %% [markdown]
# ## PCA plots of phospho proteome.

# %%
features = phospho.T
pca_df, explained_variance = pca_preprocess(features)
features['Condition'] = features.index.map(prot_condition_dict)
# features['Timepoint'] = features.index.map(prot_timepoint_dict)
features['Timepoint'] = features.index.map(prot_timepoint_dict_2)

pca_df['Condition'] = features['Condition'].values
pca_df['Timepoint'] = features['Timepoint'].values


pca_df['Batch']=0
# pca_df[pca_df.index<15]['Batch']=1
# pca_df['Reactor'] = df['Reactor'].values
pca_df.loc[pca_df.index <= 17, 'Batch'] = 1
pca_df.loc[pca_df.index > 17, 'Batch'] = 2
plot_pca(pca_df, explained_variance,title='pca_redox_condition')

# %% [markdown]
# # Differential Expression of Global Prot.

# %% [markdown]
# ## Compare Control late vs early.

# %%
# grab the redox data. 
prot = annotated_phospho[sample_ids_prot_redox]
prot['Protein'] = annotated_phospho['Protein']
prot['ProteinID'] = annotated_phospho['Protein'].copy()
prot.index = annotated_phospho['Site']

# drop oscillations, low. 
prot_control_late_vs_early_combined = prot.drop(prot.columns[prot.columns.str.contains("Oscillation|Low")], axis=1)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/3233933384.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prot['Protein'] = annotated_phospho['Protein']
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/3233933384.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prot['ProteinID'] = annotated_phospho['Protein'].copy()

# %%
prot_control_late_vs_early_combined.columns
# Out:
# Index(['Biostat2L_30_Control_3.5', 'Biostat2L_30_Control_4.5',
#        'Biostat2L_30_Control_5.5', 'Biostat2L_30_Control_24',
#        'Biostat2L_30_Control_48', 'Biostat2L_30_Control_72',
#        'Biostat2L_31_Control_3.5', 'Biostat2L_31_Control_4.5',
#        'Biostat2L_31_Control_5.5', 'Biostat2L_31_Control_24',
#        'Biostat2L_31_Control_48', 'Biostat2L_31_Control_72',
#        'Biostat2L_32_Control_3.5', 'Biostat2L_32_Control_4.5',
#        'Biostat2L_32_Control_5.5', 'Biostat2L_32_Control_24',
#        'Biostat2L_32_Control_48', 'Biostat2L_32_Control_72', 'Protein',
#        'ProteinID'],
#       dtype='object')

# %%
# prot_timepoint_dict initialized in annotation section. 
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))

# %% [markdown]
# ### Prep for p-values.

# %%
# group for mapping in nanova. 
condition_series = pd.Series(prot_control_late_vs_early_combined.columns).map(prot_timepoint_dict)
condition_series.index = prot_control_late_vs_early_combined.columns
condition_series
# Out:
# Biostat2L_30_Control_3.5    Early
# Biostat2L_30_Control_4.5    Early
# Biostat2L_30_Control_5.5    Early
# Biostat2L_30_Control_24      Late
# Biostat2L_30_Control_48      Late
# Biostat2L_30_Control_72      Late
# Biostat2L_31_Control_3.5    Early
# Biostat2L_31_Control_4.5    Early
# Biostat2L_31_Control_5.5    Early
# Biostat2L_31_Control_24      Late
# Biostat2L_31_Control_48      Late
# Biostat2L_31_Control_72      Late
# Biostat2L_32_Control_3.5    Early
# Biostat2L_32_Control_4.5    Early
# Biostat2L_32_Control_5.5    Early
# Biostat2L_32_Control_24      Late
# Biostat2L_32_Control_48      Late
# Biostat2L_32_Control_72      Late
# Protein                       NaN
# ProteinID                     NaN
# dtype: object

# %%
# calculate p-values. 
prot_control_late_vs_early_combined_stats = global_stats_calc_prot(prot_control_late_vs_early_combined,condition_series)
# Out:
# Skipping protein jgi|YarliW29_1|1012@T748 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S1108 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S212 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S225 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S368 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S49 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S559 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1049@T925 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1051@S540 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1051@T191 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1058@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1064@S131 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1077@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1096@T209 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1103@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1115@T247 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1124@S738 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S71 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@T202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1332@S228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@S243 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@T769 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S3768 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S4408 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1380@S273 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1394@S24 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1414@T792 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S578 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S581 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1449@T166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@T83 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@T86 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1516@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1516@S672 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1519@T282 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1524@S94 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1529@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S283 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S331 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S333 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S337 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S350 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S367 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1625@T19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1633@T65 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1648@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S1066 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S393 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1667@S386 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1686@S938 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1686@T946 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S504 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1707@S231 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1724@T250 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1742@S595 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1813@S177 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1817@S427 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1834@S267 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1834@T304 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1864@S49 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1871@S14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1882@S33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1893@S196 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1893@S516 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1897@S577 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1899@S1371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1904@T245 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1914@S263 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1927@S555 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1927@S621 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1930@T166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1969@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1981@T259 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1981@T910 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2062@S655 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2071@S42 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2075@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2089@T482 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|208@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2119@S6 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2130@S364 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2186@T246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2191@S316 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|21@S855 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2200@T460 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2213@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S80 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2250@S14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2263@S203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2270@S40 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@T506 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S217 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S285 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@T261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2322@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2322@T382 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2342@S565 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2348@S62 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S68 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S98 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2355@T200 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2355@Y314 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2358@S501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2364@S112 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2398@S311 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2424@S459 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2465@S105 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2465@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2465@T115 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2478@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2492@T6 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2502@S65 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2502@T127 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2509@T70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2561@S215 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|25@S53 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S20 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S274 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S50 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2620@S157 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@S1170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@S1178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@T1167 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@T837 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|263@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2679@S135 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2817@T491 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2823@S371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2868@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2872@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2888@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2907@Y583 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2916@S440 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2936@S52 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@S210 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2995@S437 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3028@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3038@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3038@T704 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3072@S21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3136@S1280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3136@S825 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3160@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3185@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@S219 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@Y222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3243@S653 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S38 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|324@S1275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3260@S1035 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3260@S845 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3269@T15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@Y294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3304@S130 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3304@T120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3304@T456 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3310@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3457@T327 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3485@Y1084 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3495@T170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3499@T51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|34@S166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S303 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S305 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S308 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3613@S56 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3613@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3647@Y359 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3658@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3667@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3669@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3694@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3723@S347 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3762@S65 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3778@S180 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3868@S224 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3873@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3903@S198 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3944@S654 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3944@S702 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4000@T20 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4054@S184 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|409@S558 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4109@T501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S547 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S551 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@T489 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@T493 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4187@S253 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4199@S147 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4199@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4229@S299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4253@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4271@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4271@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|428@T147 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4301@T18 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4387@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4400@S83 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S860 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S872 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|443@S767 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S149 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4446@T126 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4471@S160 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4480@S1176 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4496@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4508@S510 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4510@S618 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@S174 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@T280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4606@S629 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4609@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4616@S162 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4616@S202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S150 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S250 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4644@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4661@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4668@S529 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|46@S222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4721@T100 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4737@T33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4756@S449 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S1018 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S780 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@S230 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4774@S146 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4776@T140 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4790@S561 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4802@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4809@S421 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4928@S246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4968@T307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4976@S398 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5015@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5052@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5060@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@S479 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T162 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T484 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@S1831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@T1834 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5112@S456 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5112@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5133@S575 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5190@Y266 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5213@S262 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5213@T111 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5232@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|524@S404 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5280@S669 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5296@T27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5298@S431 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5298@S470 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5313@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5319@S271 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5335@Y107 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5341@S38 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5366@T521 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5414@S276 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5449@S23 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5454@S357 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5462@S261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5470@S419 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5489@S476 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5512@S310 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5533@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5539@S17 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T514 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5602@S956 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5612@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|561@S66 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5620@S145 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5670@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5698@S237 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5738@S66 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5741@S628 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5769@S13 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5794@T46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5817@T251 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5877@Y173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5897@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5899@T560 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5913@S1039 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5913@S1047 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5917@T11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5931@T345 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5942@S179 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5972@S71 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5974@S326 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5@S515 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6070@S662 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6074@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6127@T1122 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6130@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6140@S170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6140@T136 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6151@S158 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6151@T69 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6157@S592 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6199@S530 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6240@T173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6283@T831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6291@S414 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6294@S330 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6299@S86 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6322@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6325@S142 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6333@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6351@S267 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S190 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@S294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6382@S292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6402@S301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6403@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@S5 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@T2 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6429@S737 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|642@S41 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6434@S366 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6435@T1244 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6437@S472 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6447@S854 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6454@S275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6460@T10 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6465@S496 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|647@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6523@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6569@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6569@T47 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6588@S335 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6588@S358 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@T117 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6656@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6686@S16 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6686@S51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|668@S169 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6704@S25 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T500 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T514 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6719@S59 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6743@T371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6755@S153 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6756@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6770@S375 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6800@S635 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6825@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6848@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|684@S109 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6859@S67 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6865@T612 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6877@T741 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|688@T46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6907@S433 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@S496 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@T413 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6954@S268 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@S464 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@T165 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7022@T356 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7026@S740 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7086@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7108@S642 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7108@T640 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|711@S1050 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|711@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7128@S113 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7132@S351 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7178@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7198@T593 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7213@T41 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|721@S325 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7255@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7263@T321 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7264@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S846 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T651 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7307@T626 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7363@S75 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7368@S70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7370@S494 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7376@T531 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7380@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7386@T318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7395@S287 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S189 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S193 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7457@S596 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7506@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7531@S207 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7567@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@S70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@S63 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@T144 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7617@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7633@T278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7692@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7696@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7719@S711 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7731@S598 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7735@S132 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7778@S281 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7796@T368 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7864@T203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T424 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7877@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|78@S172 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|791@T45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|828@S278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|868@S383 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|930@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|965@S260 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|971@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|994@S150 due to insufficient data in some groups.
# No ANOVA_p values returned

# %%
prot_control_late_vs_early_combined_stats
# Out:
#                           Site  Biostat2L_30_Control_3.5  \
# 0     jgi|YarliW29_1|1012@T748                 12.673789
# 1    jgi|YarliW29_1|1029@S1108                 14.076738
# 2     jgi|YarliW29_1|1029@S212                 13.069854
# 3     jgi|YarliW29_1|1029@S225                 17.829095
# 4     jgi|YarliW29_1|1029@S368                 16.825546
# ..                         ...                       ...
# 452    jgi|YarliW29_1|868@S383                 10.774548
# 453    jgi|YarliW29_1|930@S188                 14.141160
# 454    jgi|YarliW29_1|965@S260                 14.503131
# 455     jgi|YarliW29_1|971@S12                 14.152041
# 456    jgi|YarliW29_1|994@S150                 15.304376
#
#      Biostat2L_30_Control_4.5  Biostat2L_30_Control_5.5  \
# 0                   12.174665                 12.784090
# 1                   14.560468                 14.123239
# 2                   13.332494                 13.366579
# 3                   18.111247                 18.440744
# 4                   16.932283                 17.511132
# ..                        ...                       ...
# 452                       NaN                 10.308301
# 453                 13.741552                 14.411935
# 454                 14.262400                 14.364013
# 455                 13.508958                 14.011627
# 456                 15.551194                 15.375182
#
#      Biostat2L_30_Control_24  Biostat2L_30_Control_48  \
# 0                  13.787372                14.073101
# 1                  14.986167                15.273361
# 2                  14.699762                14.329749
# 3                  19.030934                19.312877
# 4                  17.105610                17.644165
# ..                       ...                      ...
# 452                      NaN                      NaN
# 453                14.912793                15.620293
# 454                15.165872                15.619454
# 455                14.777946                15.657588
# 456                15.482982                15.926688
#
#      Biostat2L_30_Control_72  Biostat2L_31_Control_3.5  \
# 0                  13.139452                 13.440964
# 1                  15.055229                 14.154478
# 2                  14.208659                 13.769032
# 3                  19.436340                 18.317856
# 4                  17.407525                 17.101510
# ..                       ...                       ...
# 452                      NaN                       NaN
# 453                15.553742                 14.257876
# 454                15.664237                 14.718338
# 455                15.659934                 14.128689
# 456                16.177884                 15.160573
#
#      Biostat2L_31_Control_4.5  Biostat2L_31_Control_5.5  ...  \
# 0                   12.765363                 12.955787  ...
# 1                   14.334222                 14.303263  ...
# 2                   13.599552                 13.408821  ...
# 3                   18.115729                 18.198653  ...
# 4                   17.465836                 17.810798  ...
# ..                        ...                       ...  ...
# 452                       NaN                 10.442978  ...
# 453                 13.993590                 14.163506  ...
# 454                 14.511029                 14.433241  ...
# 455                 14.063924                 13.880465  ...
# 456                 15.250789                 15.102504  ...
#
#      Biostat2L_31_Control_72  Biostat2L_32_Control_3.5  \
# 0                  13.641081                 12.936020
# 1                  15.129808                 13.654126
# 2                  14.519338                 12.506573
# 3                  19.186372                 17.741004
# 4                  17.564225                 16.457102
# ..                       ...                       ...
# 452                      NaN                       NaN
# 453                15.626420                 14.242461
# 454                15.613034                 14.345546
# 455                15.414603                 13.940774
# 456                15.889416                 15.379336
#
#      Biostat2L_32_Control_4.5  Biostat2L_32_Control_5.5  \
# 0                   12.765731                 12.660501
# 1                   14.414255                 14.726615
# 2                   13.314957                 13.328912
# 3                   18.138030                 18.215223
# 4                   17.264963                 17.439530
# ..                        ...                       ...
# 452                 10.989316                       NaN
# 453                 14.525689                 14.186452
# 454                 14.412083                 14.616176
# 455                 14.080348                 13.923460
# 456                 15.505178                 15.384215
#
#      Biostat2L_32_Control_24  Biostat2L_32_Control_48  \
# 0                  13.571825                13.513770
# 1                  14.785028                14.819879
# 2                  13.936396                14.696044
# 3                  18.683641                19.453357
# 4                  16.853587                17.659650
# ..                       ...                      ...
# 452                      NaN                      NaN
# 453                15.133290                15.056103
# 454                15.208554                15.554385
# 455                14.771296                15.062128
# 456                15.420687                15.591771
#
#      Biostat2L_32_Control_72              Protein            ProteinID ANOVA_p
# 0                  13.580512  jgi|YarliW29_1|1012  jgi|YarliW29_1|1012     NaN
# 1                  14.811235  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029     NaN
# 2                  14.338431  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029     NaN
# 3                  19.281014  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029     NaN
# 4                  17.554265  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029     NaN
# ..                       ...                  ...                  ...     ...
# 452                      NaN   jgi|YarliW29_1|868   jgi|YarliW29_1|868     NaN
# 453                15.360002   jgi|YarliW29_1|930   jgi|YarliW29_1|930     NaN
# 454                15.498715   jgi|YarliW29_1|965   jgi|YarliW29_1|965     NaN
# 455                15.564438   jgi|YarliW29_1|971   jgi|YarliW29_1|971     NaN
# 456                15.748870   jgi|YarliW29_1|994   jgi|YarliW29_1|994     NaN
#
# [457 rows x 22 columns]

# %%
# Extract the number between "YarliW29_1|" and "@GLB" using regex
prot_control_late_vs_early_combined_stats["proteinID"] = prot_control_late_vs_early_combined_stats["Site"].str.extract(r"YarliW29_1\|(\d+)@")

# Convert the extracted number to integer (if needed)
prot_control_late_vs_early_combined_stats["proteinID"] = prot_control_late_vs_early_combined_stats["proteinID"].astype(int)

# %%
prot_control_late_vs_early_combined_stats
# Out:
#                           Site  Biostat2L_30_Control_3.5  \
# 0     jgi|YarliW29_1|1012@T748                 12.673789
# 1    jgi|YarliW29_1|1029@S1108                 14.076738
# 2     jgi|YarliW29_1|1029@S212                 13.069854
# 3     jgi|YarliW29_1|1029@S225                 17.829095
# 4     jgi|YarliW29_1|1029@S368                 16.825546
# ..                         ...                       ...
# 452    jgi|YarliW29_1|868@S383                 10.774548
# 453    jgi|YarliW29_1|930@S188                 14.141160
# 454    jgi|YarliW29_1|965@S260                 14.503131
# 455     jgi|YarliW29_1|971@S12                 14.152041
# 456    jgi|YarliW29_1|994@S150                 15.304376
#
#      Biostat2L_30_Control_4.5  Biostat2L_30_Control_5.5  \
# 0                   12.174665                 12.784090
# 1                   14.560468                 14.123239
# 2                   13.332494                 13.366579
# 3                   18.111247                 18.440744
# 4                   16.932283                 17.511132
# ..                        ...                       ...
# 452                       NaN                 10.308301
# 453                 13.741552                 14.411935
# 454                 14.262400                 14.364013
# 455                 13.508958                 14.011627
# 456                 15.551194                 15.375182
#
#      Biostat2L_30_Control_24  Biostat2L_30_Control_48  \
# 0                  13.787372                14.073101
# 1                  14.986167                15.273361
# 2                  14.699762                14.329749
# 3                  19.030934                19.312877
# 4                  17.105610                17.644165
# ..                       ...                      ...
# 452                      NaN                      NaN
# 453                14.912793                15.620293
# 454                15.165872                15.619454
# 455                14.777946                15.657588
# 456                15.482982                15.926688
#
#      Biostat2L_30_Control_72  Biostat2L_31_Control_3.5  \
# 0                  13.139452                 13.440964
# 1                  15.055229                 14.154478
# 2                  14.208659                 13.769032
# 3                  19.436340                 18.317856
# 4                  17.407525                 17.101510
# ..                       ...                       ...
# 452                      NaN                       NaN
# 453                15.553742                 14.257876
# 454                15.664237                 14.718338
# 455                15.659934                 14.128689
# 456                16.177884                 15.160573
#
#      Biostat2L_31_Control_4.5  Biostat2L_31_Control_5.5  ...  \
# 0                   12.765363                 12.955787  ...
# 1                   14.334222                 14.303263  ...
# 2                   13.599552                 13.408821  ...
# 3                   18.115729                 18.198653  ...
# 4                   17.465836                 17.810798  ...
# ..                        ...                       ...  ...
# 452                       NaN                 10.442978  ...
# 453                 13.993590                 14.163506  ...
# 454                 14.511029                 14.433241  ...
# 455                 14.063924                 13.880465  ...
# 456                 15.250789                 15.102504  ...
#
#      Biostat2L_32_Control_3.5  Biostat2L_32_Control_4.5  \
# 0                   12.936020                 12.765731
# 1                   13.654126                 14.414255
# 2                   12.506573                 13.314957
# 3                   17.741004                 18.138030
# 4                   16.457102                 17.264963
# ..                        ...                       ...
# 452                       NaN                 10.989316
# 453                 14.242461                 14.525689
# 454                 14.345546                 14.412083
# 455                 13.940774                 14.080348
# 456                 15.379336                 15.505178
#
#      Biostat2L_32_Control_5.5  Biostat2L_32_Control_24  \
# 0                   12.660501                13.571825
# 1                   14.726615                14.785028
# 2                   13.328912                13.936396
# 3                   18.215223                18.683641
# 4                   17.439530                16.853587
# ..                        ...                      ...
# 452                       NaN                      NaN
# 453                 14.186452                15.133290
# 454                 14.616176                15.208554
# 455                 13.923460                14.771296
# 456                 15.384215                15.420687
#
#      Biostat2L_32_Control_48  Biostat2L_32_Control_72              Protein  \
# 0                  13.513770                13.580512  jgi|YarliW29_1|1012
# 1                  14.819879                14.811235  jgi|YarliW29_1|1029
# 2                  14.696044                14.338431  jgi|YarliW29_1|1029
# 3                  19.453357                19.281014  jgi|YarliW29_1|1029
# 4                  17.659650                17.554265  jgi|YarliW29_1|1029
# ..                       ...                      ...                  ...
# 452                      NaN                      NaN   jgi|YarliW29_1|868
# 453                15.056103                15.360002   jgi|YarliW29_1|930
# 454                15.554385                15.498715   jgi|YarliW29_1|965
# 455                15.062128                15.564438   jgi|YarliW29_1|971
# 456                15.591771                15.748870   jgi|YarliW29_1|994
#
#                ProteinID  ANOVA_p proteinID
# 0    jgi|YarliW29_1|1012      NaN      1012
# 1    jgi|YarliW29_1|1029      NaN      1029
# 2    jgi|YarliW29_1|1029      NaN      1029
# 3    jgi|YarliW29_1|1029      NaN      1029
# 4    jgi|YarliW29_1|1029      NaN      1029
# ..                   ...      ...       ...
# 452   jgi|YarliW29_1|868      NaN       868
# 453   jgi|YarliW29_1|930      NaN       930
# 454   jgi|YarliW29_1|965      NaN       965
# 455   jgi|YarliW29_1|971      NaN       971
# 456   jgi|YarliW29_1|994      NaN       994
#
# [457 rows x 23 columns]

# %%
prot_control_late_vs_early_combined_stats.head()
# Out:
#                         Site  Biostat2L_30_Control_3.5  \
# 0   jgi|YarliW29_1|1012@T748                 12.673789
# 1  jgi|YarliW29_1|1029@S1108                 14.076738
# 2   jgi|YarliW29_1|1029@S212                 13.069854
# 3   jgi|YarliW29_1|1029@S225                 17.829095
# 4   jgi|YarliW29_1|1029@S368                 16.825546
#
#    Biostat2L_30_Control_4.5  Biostat2L_30_Control_5.5  \
# 0                 12.174665                 12.784090
# 1                 14.560468                 14.123239
# 2                 13.332494                 13.366579
# 3                 18.111247                 18.440744
# 4                 16.932283                 17.511132
#
#    Biostat2L_30_Control_24  Biostat2L_30_Control_48  Biostat2L_30_Control_72  \
# 0                13.787372                14.073101                13.139452
# 1                14.986167                15.273361                15.055229
# 2                14.699762                14.329749                14.208659
# 3                19.030934                19.312877                19.436340
# 4                17.105610                17.644165                17.407525
#
#    Biostat2L_31_Control_3.5  Biostat2L_31_Control_4.5  \
# 0                 13.440964                 12.765363
# 1                 14.154478                 14.334222
# 2                 13.769032                 13.599552
# 3                 18.317856                 18.115729
# 4                 17.101510                 17.465836
#
#    Biostat2L_31_Control_5.5  ...  Biostat2L_32_Control_3.5  \
# 0                 12.955787  ...                 12.936020
# 1                 14.303263  ...                 13.654126
# 2                 13.408821  ...                 12.506573
# 3                 18.198653  ...                 17.741004
# 4                 17.810798  ...                 16.457102
#
#    Biostat2L_32_Control_4.5  Biostat2L_32_Control_5.5  \
# 0                 12.765731                 12.660501
# 1                 14.414255                 14.726615
# 2                 13.314957                 13.328912
# 3                 18.138030                 18.215223
# 4                 17.264963                 17.439530
#
#    Biostat2L_32_Control_24  Biostat2L_32_Control_48  Biostat2L_32_Control_72  \
# 0                13.571825                13.513770                13.580512
# 1                14.785028                14.819879                14.811235
# 2                13.936396                14.696044                14.338431
# 3                18.683641                19.453357                19.281014
# 4                16.853587                17.659650                17.554265
#
#                Protein            ProteinID  ANOVA_p proteinID
# 0  jgi|YarliW29_1|1012  jgi|YarliW29_1|1012      NaN      1012
# 1  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029      NaN      1029
# 2  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029      NaN      1029
# 3  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029      NaN      1029
# 4  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029      NaN      1029
#
# [5 rows x 23 columns]

# %% [markdown]
# ### calculate log2FC

# %%
early = prot_control_late_vs_early_combined_stats.loc[:, prot_control_late_vs_early_combined_stats.columns[prot_control_late_vs_early_combined_stats.columns.str.contains("3.5|4.5|5.5")]]
early.head()

# 24 h
# Out:
#    Biostat2L_30_Control_3.5  Biostat2L_30_Control_4.5  \
# 0                 12.673789                 12.174665
# 1                 14.076738                 14.560468
# 2                 13.069854                 13.332494
# 3                 17.829095                 18.111247
# 4                 16.825546                 16.932283
#
#    Biostat2L_30_Control_5.5  Biostat2L_31_Control_3.5  \
# 0                 12.784090                 13.440964
# 1                 14.123239                 14.154478
# 2                 13.366579                 13.769032
# 3                 18.440744                 18.317856
# 4                 17.511132                 17.101510
#
#    Biostat2L_31_Control_4.5  Biostat2L_31_Control_5.5  \
# 0                 12.765363                 12.955787
# 1                 14.334222                 14.303263
# 2                 13.599552                 13.408821
# 3                 18.115729                 18.198653
# 4                 17.465836                 17.810798
#
#    Biostat2L_32_Control_3.5  Biostat2L_32_Control_4.5  \
# 0                 12.936020                 12.765731
# 1                 13.654126                 14.414255
# 2                 12.506573                 13.314957
# 3                 17.741004                 18.138030
# 4                 16.457102                 17.264963
#
#    Biostat2L_32_Control_5.5
# 0                 12.660501
# 1                 14.726615
# 2                 13.328912
# 3                 18.215223
# 4                 17.439530

# %%
late = prot_control_late_vs_early_combined_stats.loc[:, prot_control_late_vs_early_combined_stats.columns[prot_control_late_vs_early_combined_stats.columns.str.contains("24|48|72")]]
late.head()

# 24 h
# Out:
#    Biostat2L_30_Control_24  Biostat2L_30_Control_48  Biostat2L_30_Control_72  \
# 0                13.787372                14.073101                13.139452
# 1                14.986167                15.273361                15.055229
# 2                14.699762                14.329749                14.208659
# 3                19.030934                19.312877                19.436340
# 4                17.105610                17.644165                17.407525
#
#    Biostat2L_31_Control_24  Biostat2L_31_Control_48  Biostat2L_31_Control_72  \
# 0                13.584965                13.975370                13.641081
# 1                14.881975                15.121685                15.129808
# 2                13.898204                14.799473                14.519338
# 3                18.626579                19.306227                19.186372
# 4                17.154443                17.636363                17.564225
#
#    Biostat2L_32_Control_24  Biostat2L_32_Control_48  Biostat2L_32_Control_72
# 0                13.571825                13.513770                13.580512
# 1                14.785028                14.819879                14.811235
# 2                13.936396                14.696044                14.338431
# 3                18.683641                19.453357                19.281014
# 4                16.853587                17.659650                17.554265

# %%
# gives the increase of the first. 
prot_control_late_vs_early_combined_stats['log2FC']=log2FC_function(early,late)

# %%
df_to_merge = pd.DataFrame()
df_to_merge['early/late'] = prot_control_late_vs_early_combined_stats['log2FC']
df_to_merge['Site'] = prot_control_late_vs_early_combined_stats['Site']
# df_to_merge['early/late_ANOVA_padj'] = prot_control_late_vs_early_combined_stats['ANOVA_padj']
df_to_merge['early/late_ANOVA_p'] = prot_control_late_vs_early_combined_stats['ANOVA_p']

# %%
df_to_merge.columns
# Out:
# Index(['early/late', 'Site', 'early/late_ANOVA_p'], dtype='object')

# %%
merged_df = pd.merge(annotated_phospho, df_to_merge, left_on='Site',right_on='Site', how='left')

# %%
merged_df.head(20)
# Out:
#                                        Peptide                       Site  \
# 0                  K.LAEENTSEAIFDTPDT#DEDDAK.S   jgi|YarliW29_1|1012@T748
# 1                                R.SNS#MSAFR.M  jgi|YarliW29_1|1029@S1108
# 2                           R.RGS#MTSTTTNTER.T   jgi|YarliW29_1|1029@S212
# 3        R.THS#LTSTTTTIK.R; R.THS#LTSTTTTIKR.M   jgi|YarliW29_1|1029@S225
# 4            R.TLS#PM*KPALK.M; R.TLS#PMKPALK.M   jgi|YarliW29_1|1029@S368
# 5                         R.ANS#GLSSAAAAAAIR.H    jgi|YarliW29_1|1029@S49
# 6   R.QAAPAPPSQVLSPM*LS#HSESEEDLSMFQDAHEHLGK.S   jgi|YarliW29_1|1029@S559
# 7                       R.HHS#LTSSTSQPNLQQGR.N    jgi|YarliW29_1|1029@S64
# 8                      K.T#PGGAAQHFLDDDDYFSR.G   jgi|YarliW29_1|1049@T925
# 9                          K.LHDVANSPYQSS#PR.T   jgi|YarliW29_1|1051@S540
# 10                        R.SRST#VEADRDALLQR.K   jgi|YarliW29_1|1051@T191
# 11                        R.SQS#PQRPQSGIWDGK.F   jgi|YarliW29_1|1058@S120
# 12                         R.S#FDVPPPPIADDDK.W   jgi|YarliW29_1|1064@S131
# 13                           K.S#PQIEDEHIEER.F    jgi|YarliW29_1|1077@S61
# 14                      A.PADRPT#WGTNVPGSGTR.E   jgi|YarliW29_1|1096@T209
# 15                             R.RLS#EDILNSR.R    jgi|YarliW29_1|1103@S46
# 16                      S.KVT#LVFGQM*NEPPGAR.A   jgi|YarliW29_1|1115@T247
# 17                         E.YS#VEFC@GGTHVGK.T   jgi|YarliW29_1|1124@S738
# 18                  R.GHQSRPS#QSSIDLQPTSSYTR.E    jgi|YarliW29_1|1205@S48
# 19                           R.EGYHDEPSS#PKK.H    jgi|YarliW29_1|1205@S71
#
#                 UniProt              Protein Residue      AScore  \
# 0   jgi|YarliW29_1|1012  jgi|YarliW29_1|1012    T748    43.40600
# 1   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029   S1108    22.21700
# 2   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029    S212    45.54300
# 3   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029    S225    28.74600
# 4   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029    S368  1000.00000
# 5   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029     S49   107.28000
# 6   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029    S559    23.94200
# 7   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029     S64    45.54300
# 8   jgi|YarliW29_1|1049  jgi|YarliW29_1|1049    T925   256.78000
# 9   jgi|YarliW29_1|1051  jgi|YarliW29_1|1051    S540     0.00000
# 10  jgi|YarliW29_1|1051  jgi|YarliW29_1|1051    T191     0.00000
# 11  jgi|YarliW29_1|1058  jgi|YarliW29_1|1058    S120    32.86900
# 12  jgi|YarliW29_1|1064  jgi|YarliW29_1|1064    S131  1000.00000
# 13  jgi|YarliW29_1|1077  jgi|YarliW29_1|1077     S61  1000.00000
# 14  jgi|YarliW29_1|1096  jgi|YarliW29_1|1096    T209    71.26700
# 15  jgi|YarliW29_1|1103  jgi|YarliW29_1|1103     S46    81.29900
# 16  jgi|YarliW29_1|1115  jgi|YarliW29_1|1115    T247  1000.00000
# 17  jgi|YarliW29_1|1124  jgi|YarliW29_1|1124    S738  1000.00000
# 18  jgi|YarliW29_1|1205  jgi|YarliW29_1|1205     S48     0.00002
# 19  jgi|YarliW29_1|1205  jgi|YarliW29_1|1205     S71     0.00000
#
#                            id  Total missingness  Oscillation_24 missingness  \
# 0    jgi|YarliW29_1|1012@T748                 18                           0
# 1   jgi|YarliW29_1|1029@S1108                 18                           0
# 2    jgi|YarliW29_1|1029@S212                 36                           3
# 3    jgi|YarliW29_1|1029@S225                  0                           0
# 4    jgi|YarliW29_1|1029@S368                 18                           3
# 5     jgi|YarliW29_1|1029@S49                  5                           0
# 6    jgi|YarliW29_1|1029@S559                 49                           3
# 7     jgi|YarliW29_1|1029@S64                 37                           3
# 8    jgi|YarliW29_1|1049@T925                  1                           0
# 9    jgi|YarliW29_1|1051@S540                 19                           3
# 10   jgi|YarliW29_1|1051@T191                 18                           0
# 11   jgi|YarliW29_1|1058@S120                 36                           3
# 12   jgi|YarliW29_1|1064@S131                 41                           3
# 13    jgi|YarliW29_1|1077@S61                 18                           0
# 14   jgi|YarliW29_1|1096@T209                 36                           3
# 15    jgi|YarliW29_1|1103@S46                 36                           3
# 16   jgi|YarliW29_1|1115@T247                 36                           3
# 17   jgi|YarliW29_1|1124@S738                 36                           3
# 18    jgi|YarliW29_1|1205@S48                 41                           3
# 19    jgi|YarliW29_1|1205@S71                 36                           3
#
#     Oscillation_3.5 missingness  ...  \
# 0                             0  ...
# 1                             0  ...
# 2                             3  ...
# 3                             0  ...
# 4                             3  ...
# 5                             1  ...
# 6                             3  ...
# 7                             3  ...
# 8                             1  ...
# 9                             3  ...
# 10                            0  ...
# 11                            3  ...
# 12                            3  ...
# 13                            0  ...
# 14                            3  ...
# 15                            3  ...
# 16                            3  ...
# 17                            3  ...
# 18                            3  ...
# 19                            3  ...
#
#                                                goName  \
# 0   Rab GTPase activator activity, intracellular, ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   mannosyl-oligosaccharide glucosidase activity,...
# 9   phosphotransferase activity, alcohol group as ...
# 10  phosphotransferase activity, alcohol group as ...
# 11  cation transport, cation transmembrane transpo...
# 12  catalytic activity, metabolic process, glycoly...
# 13                                            binding
# 14                                                NaN
# 15                                                NaN
# 16  hydrogen ion transmembrane transporter activit...
# 17  alanine-tRNA ligase activity, ATP binding, cyt...
# 18  protein kinase activity, ATP binding, protein ...
# 19  protein kinase activity, ATP binding, protein ...
#
#                                            gotermType  \
# 0   molecular_function, cellular_component, biolog...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8              molecular_function, biological_process
# 9                                  molecular_function
# 10                                 molecular_function
# 11  biological_process, molecular_function, cellul...
# 12             molecular_function, biological_process
# 13                                 molecular_function
# 14                                                NaN
# 15                                                NaN
# 16  molecular_function, cellular_component, biolog...
# 17  molecular_function, cellular_component, biolog...
# 18             molecular_function, biological_process
# 19             molecular_function, biological_process
#
#                                                 goAcc  #transcriptId    kogid  \
# 0                  GO:0005097, GO:0005622, GO:0032313         1990.0  KOG4347
# 1                                                 NaN            NaN      NaN
# 2                                                 NaN            NaN      NaN
# 3                                                 NaN            NaN      NaN
# 4                                                 NaN            NaN      NaN
# 5                                                 NaN            NaN      NaN
# 6                                                 NaN            NaN      NaN
# 7                                                 NaN            NaN      NaN
# 8                  GO:0004573, GO:0009311, GO:0003824         2027.0  KOG2161
# 9      GO:0016773, GO:0004428, GO:0005488, GO:0004430         2029.0  KOG0903
# 10     GO:0016773, GO:0004428, GO:0005488, GO:0004430         2029.0  KOG0903
# 11                 GO:0006812, GO:0008324, GO:0016020            NaN      NaN
# 12     GO:0003824, GO:0008152, GO:0006096, GO:0016868         2042.0  KOG0235
# 13                                         GO:0005488         2055.0  KOG2734
# 14                                                NaN         2074.0  KOG3346
# 15                                                NaN            NaN      NaN
# 16  GO:0015078, GO:0016469, GO:0000166, GO:0017111...         2093.0  KOG1350
# 17  GO:0004813, GO:0005524, GO:0005737, GO:0006412...         2102.0  KOG0188
# 18  GO:0004672, GO:0005524, GO:0006468, GO:0004674...         2183.0  KOG0592
# 19  GO:0004672, GO:0005524, GO:0006468, GO:0004674...         2183.0  KOG0592
#
#                                            kogdefline  \
# 0                       GTPase-activating protein VRP
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                       Glucosidase I
# 9   Phosphatidylinositol 4-kinase, involved in int...
# 10  Phosphatidylinositol 4-kinase, involved in int...
# 11                                                NaN
# 12                            Phosphoglycerate mutase
# 13                  Uncharacterized conserved protein
# 14           Phosphatidylethanolamine binding protein
# 15                                                NaN
# 16               F0F1-type ATP synthase, beta subunit
# 17                             Alanyl-tRNA synthetase
# 18  3-phosphoinositide-dependent protein kinase (P...
# 19  3-phosphoinositide-dependent protein kinase (P...
#
#                                              kogClass  \
# 0                    General function prediction only
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8               Carbohydrate transport and metabolism
# 9   Signal transduction mechanisms, Intracellular ...
# 10  Signal transduction mechanisms, Intracellular ...
# 11                                                NaN
# 12              Carbohydrate transport and metabolism
# 13                                   Function unknown
# 14                   General function prediction only
# 15                                                NaN
# 16                   Energy production and conversion
# 17    Translation, ribosomal structure and biogenesis
# 18                     Signal transduction mechanisms
# 19                     Signal transduction mechanisms
#
#                               kogGroup  early/late  early/late_ANOVA_p
# 0                 POORLY CHARACTERIZED   -0.856726                 NaN
# 1                                  NaN   -0.724107                 NaN
# 2                                  NaN   -1.081031                 NaN
# 3                                  NaN   -1.023307                 NaN
# 4                                  NaN   -0.196793                 NaN
# 5                                  NaN   -0.656691                 NaN
# 6                                  NaN   -0.129958                 NaN
# 7                                  NaN   -1.161774                 NaN
# 8                           METABOLISM   -1.337130                 NaN
# 9     CELLULAR PROCESSES AND SIGNALING   -0.705503                 NaN
# 10    CELLULAR PROCESSES AND SIGNALING    0.163752                 NaN
# 11                                 NaN   -0.260584                 NaN
# 12                          METABOLISM   -0.120233                 NaN
# 13                POORLY CHARACTERIZED   -0.476474                 NaN
# 14                POORLY CHARACTERIZED    0.517389                 NaN
# 15                                 NaN   -0.829052                 NaN
# 16                          METABOLISM   -1.481107                 NaN
# 17  INFORMATION STORAGE AND PROCESSING   -0.452256                 NaN
# 18    CELLULAR PROCESSES AND SIGNALING    2.054248                 NaN
# 19    CELLULAR PROCESSES AND SIGNALING    1.183146                 NaN
#
# [20 rows x 195 columns]

# %%
prot_control_late_vs_early_combined_stats_withAnnote = pd.merge(prot_control_late_vs_early_combined_stats, merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')

# %% [markdown]
# ### optional save.

# %%
# prot_control_late_vs_early_combined_stats_withAnnote.to_csv('early_vs_late.csv')

# %% [markdown]
# ### Volcano plot comparing late vs early.
# all late (increase means increased in low)

# %%
dataset = prot_control_late_vs_early_combined_stats_withAnnote[['log2FC', 'ANOVA_p']].copy()
dataset.index = prot_control_late_vs_early_combined_stats_withAnnote.proteinID

# %%
log2FC_threshold = np.log2(1.3)

# %%
dataset
# Out:
#              log2FC ANOVA_p
# proteinID
# 1012      -0.856726     NaN
# 1029      -0.724107     NaN
# 1029      -1.081031     NaN
# 1029      -1.023307     NaN
# 1029      -0.196793     NaN
# ...             ...     ...
# 868       -0.296738     NaN
# 930       -1.108683     NaN
# 965       -1.021961     NaN
# 971       -1.277760     NaN
# 994       -0.363352     NaN
#
# [457 rows x 2 columns]

# %%
# # subset the log2FC and the P_value for this dataset. 
# dataset.columns = ['log2FC','P_value']

# # obtain the -logP_adj for the dataset. 
# dataset['-logP_adj'] = -np.log10(dataset['P_value'])

# # set a class for up (1) or down (-1) proteins. 
# dataset['class'] = 0
# dataset.loc[(dataset['log2FC']>log2FC_threshold)&(dataset['-logP_adj']>-np.log10(0.05)),'class'] = 1
# dataset.loc[(dataset['log2FC']<-log2FC_threshold)&(dataset['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
# volcano_plot(dataset)

# %% [markdown]
# ## Compare Control vs low.

# %%
prot = annotated_phospho[sample_ids_prot_redox]
prot['Protein'] = annotated_phospho['Site']
prot.index = annotated_phospho['Site']
# drop oscillations.
prot_control_vs_low_late_combined = prot.drop(prot.columns[prot.columns.str.contains("Oscillation")], axis=1)
# prot_control_vs_oscillation_late_combined = prot.drop(prot.columns[prot.columns.str.contains("Low")], axis=1)
prot_control_vs_low_24h = prot.drop(prot.columns[prot.columns.str.contains("Oscillation")], axis=1)


# drop early timepoints. 
prot_control_vs_low_late_combined = prot_control_vs_low_late_combined.drop(prot_control_vs_low_late_combined.columns[
    prot_control_vs_low_late_combined.columns.str.contains("5.5|3.5|4.5")], axis=1)

# prot_control_vs_low_24h = prot_control_vs_low_24h.drop(prot_control_vs_low_24h.columns[
#     prot_control_vs_low_24h.columns.str.contains("5.5|3.5|4.5|48|72")], axis=1)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/3895769385.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prot['Protein'] = annotated_phospho['Site']

# %%
prot_control_vs_low_late_combined.columns
# Out:
# Index(['Biostat2L_30_Control_24', 'Biostat2L_30_Control_48',
#        'Biostat2L_30_Control_72', 'Biostat2L_31_Control_24',
#        'Biostat2L_31_Control_48', 'Biostat2L_31_Control_72',
#        'Biostat2L_32_Control_24', 'Biostat2L_32_Control_48',
#        'Biostat2L_32_Control_72', 'Biostat2L_32_Low_24', 'Biostat2L_32_Low_48',
#        'Biostat2L_32_Low_72', 'Biostat2L_33_Low_24', 'Biostat2L_33_Low_48',
#        'Biostat2L_33_Low_72', 'Biostat2L_34_Low_24', 'Biostat2L_34_Low_48',
#        'Biostat2L_34_Low_72', 'Protein'],
#       dtype='object')

# %%
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))

# %% [markdown]
# ### Prep for p-values.

# %%
# group for mapping in nanova. 
condition_series = pd.Series(prot_control_vs_low_late_combined.columns).map(prot_condition_dict)
condition_series.index = prot_control_vs_low_late_combined.columns
condition_series 

condition_series24h = pd.Series(prot_control_vs_low_24h.columns).map(prot_condition_dict)
condition_series24h.index = prot_control_vs_low_24h.columns
condition_series24h
# Out:
# Biostat2L_30_Control_3.5    Control
# Biostat2L_30_Control_4.5    Control
# Biostat2L_30_Control_5.5    Control
# Biostat2L_30_Control_24     Control
# Biostat2L_30_Control_48     Control
# Biostat2L_30_Control_72     Control
# Biostat2L_31_Control_3.5    Control
# Biostat2L_31_Control_4.5    Control
# Biostat2L_31_Control_5.5    Control
# Biostat2L_31_Control_24     Control
# Biostat2L_31_Control_48     Control
# Biostat2L_31_Control_72     Control
# Biostat2L_32_Control_3.5    Control
# Biostat2L_32_Control_4.5    Control
# Biostat2L_32_Control_5.5    Control
# Biostat2L_32_Control_24     Control
# Biostat2L_32_Control_48     Control
# Biostat2L_32_Control_72     Control
# Biostat2L_32_Low_3.5            Low
# Biostat2L_32_Low_4.5            Low
# Biostat2L_32_Low_5.5            Low
# Biostat2L_32_Low_24             Low
# Biostat2L_32_Low_48             Low
# Biostat2L_32_Low_72             Low
# Biostat2L_33_Low_3.5            Low
# Biostat2L_33_Low_4.5            Low
# Biostat2L_33_Low_5.5            Low
# Biostat2L_33_Low_24             Low
# Biostat2L_33_Low_48             Low
# Biostat2L_33_Low_72             Low
# Biostat2L_34_Low_3.5            Low
# Biostat2L_34_Low_4.5            Low
# Biostat2L_34_Low_5.5            Low
# Biostat2L_34_Low_24             Low
# Biostat2L_34_Low_48             Low
# Biostat2L_34_Low_72             Low
# Protein                         NaN
# dtype: object

# %%
prot.head()
# Out:
#                            Biostat2L_29_Oscillation_3.5  \
# Site
# jgi|YarliW29_1|1012@T748                      12.221481
# jgi|YarliW29_1|1029@S1108                     14.374154
# jgi|YarliW29_1|1029@S212                            NaN
# jgi|YarliW29_1|1029@S225                      18.100242
# jgi|YarliW29_1|1029@S368                            NaN
#
#                            Biostat2L_29_Oscillation_4.5  \
# Site
# jgi|YarliW29_1|1012@T748                      12.249952
# jgi|YarliW29_1|1029@S1108                     14.303978
# jgi|YarliW29_1|1029@S212                            NaN
# jgi|YarliW29_1|1029@S225                      17.731381
# jgi|YarliW29_1|1029@S368                            NaN
#
#                            Biostat2L_29_Oscillation_5.5  \
# Site
# jgi|YarliW29_1|1012@T748                      13.431107
# jgi|YarliW29_1|1029@S1108                     14.345682
# jgi|YarliW29_1|1029@S212                            NaN
# jgi|YarliW29_1|1029@S225                      17.530926
# jgi|YarliW29_1|1029@S368                            NaN
#
#                            Biostat2L_29_Oscillation_24  \
# Site
# jgi|YarliW29_1|1012@T748                     13.921812
# jgi|YarliW29_1|1029@S1108                    14.687903
# jgi|YarliW29_1|1029@S212                           NaN
# jgi|YarliW29_1|1029@S225                     18.450295
# jgi|YarliW29_1|1029@S368                           NaN
#
#                            Biostat2L_29_Oscillation_48  \
# Site
# jgi|YarliW29_1|1012@T748                     14.148031
# jgi|YarliW29_1|1029@S1108                    14.764124
# jgi|YarliW29_1|1029@S212                           NaN
# jgi|YarliW29_1|1029@S225                     19.224261
# jgi|YarliW29_1|1029@S368                           NaN
#
#                            Biostat2L_29_Oscillation_72  \
# Site
# jgi|YarliW29_1|1012@T748                     13.556648
# jgi|YarliW29_1|1029@S1108                    14.143469
# jgi|YarliW29_1|1029@S212                           NaN
# jgi|YarliW29_1|1029@S225                     19.409963
# jgi|YarliW29_1|1029@S368                           NaN
#
#                            Biostat2L_30_Control_3.5  Biostat2L_30_Control_4.5  \
# Site
# jgi|YarliW29_1|1012@T748                  12.673789                 12.174665
# jgi|YarliW29_1|1029@S1108                 14.076738                 14.560468
# jgi|YarliW29_1|1029@S212                  13.069854                 13.332494
# jgi|YarliW29_1|1029@S225                  17.829095                 18.111247
# jgi|YarliW29_1|1029@S368                  16.825546                 16.932283
#
#                            Biostat2L_30_Control_5.5  Biostat2L_30_Control_24  \
# Site
# jgi|YarliW29_1|1012@T748                  12.784090                13.787372
# jgi|YarliW29_1|1029@S1108                 14.123239                14.986167
# jgi|YarliW29_1|1029@S212                  13.366579                14.699762
# jgi|YarliW29_1|1029@S225                  18.440744                19.030934
# jgi|YarliW29_1|1029@S368                  17.511132                17.105610
#
#                            ...  Biostat2L_33_Low_24  Biostat2L_33_Low_48  \
# Site                       ...
# jgi|YarliW29_1|1012@T748   ...                  NaN                  NaN
# jgi|YarliW29_1|1029@S1108  ...                  NaN                  NaN
# jgi|YarliW29_1|1029@S212   ...                  NaN                  NaN
# jgi|YarliW29_1|1029@S225   ...            19.560714            19.514274
# jgi|YarliW29_1|1029@S368   ...            16.512579            16.373739
#
#                            Biostat2L_33_Low_72  Biostat2L_34_Low_3.5  \
# Site
# jgi|YarliW29_1|1012@T748                   NaN                   NaN
# jgi|YarliW29_1|1029@S1108                  NaN                   NaN
# jgi|YarliW29_1|1029@S212                   NaN                   NaN
# jgi|YarliW29_1|1029@S225             19.683966             18.893723
# jgi|YarliW29_1|1029@S368             15.780137             17.111359
#
#                            Biostat2L_34_Low_4.5  Biostat2L_34_Low_5.5  \
# Site
# jgi|YarliW29_1|1012@T748                    NaN                   NaN
# jgi|YarliW29_1|1029@S1108                   NaN                   NaN
# jgi|YarliW29_1|1029@S212                    NaN                   NaN
# jgi|YarliW29_1|1029@S225              18.824457             19.094217
# jgi|YarliW29_1|1029@S368              17.149535             17.474933
#
#                            Biostat2L_34_Low_24  Biostat2L_34_Low_48  \
# Site
# jgi|YarliW29_1|1012@T748                   NaN                  NaN
# jgi|YarliW29_1|1029@S1108                  NaN                  NaN
# jgi|YarliW29_1|1029@S212                   NaN                  NaN
# jgi|YarliW29_1|1029@S225             19.120369            19.430804
# jgi|YarliW29_1|1029@S368             17.059593            16.416683
#
#                            Biostat2L_34_Low_72                    Protein
# Site
# jgi|YarliW29_1|1012@T748                   NaN   jgi|YarliW29_1|1012@T748
# jgi|YarliW29_1|1029@S1108                  NaN  jgi|YarliW29_1|1029@S1108
# jgi|YarliW29_1|1029@S212                   NaN   jgi|YarliW29_1|1029@S212
# jgi|YarliW29_1|1029@S225             19.867831   jgi|YarliW29_1|1029@S225
# jgi|YarliW29_1|1029@S368             16.037147   jgi|YarliW29_1|1029@S368
#
# [5 rows x 55 columns]

# %%
# calculate p-values. 
prot_control_vs_low_late_combined_stats = global_stats_calc_prot(prot_control_vs_low_late_combined,condition_series)
# prot_control_vs_low_24h_stats = global_stats_calc_prot(prot_control_vs_low_24h,condition_series24h)


# prot_control_vs_oscillation_late_combined_stats = global_stats_calc_prot(prot_control_vs_oscillation_late_combined,condition_series_controlvsOsc )
# prot_control_late_vs_control_early_stats = global_stats_calc_prot(prot_control_late_vs_control_early,condition_series_controlLateVsEarly)
# Out:
# Skipping protein jgi|YarliW29_1|1012@T748 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S1108 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S212 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S225 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S368 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S49 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S559 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1049@T925 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1051@S540 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1051@T191 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1058@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1064@S131 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1077@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1096@T209 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1103@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1115@T247 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1124@S738 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S71 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@T202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1332@S228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@S243 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@T769 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S3768 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S4408 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1380@S273 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1394@S24 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1414@T792 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S578 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S581 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1449@T166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@T83 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@T86 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1516@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1516@S672 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1519@T282 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1524@S94 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1529@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S283 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S331 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S333 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S337 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S350 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S367 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1625@T19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1633@T65 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1648@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S1066 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S393 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1667@S386 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1686@S938 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1686@T946 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S504 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1707@S231 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1724@T250 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1742@S595 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1813@S177 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1817@S427 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1834@S267 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1834@T304 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1864@S49 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1871@S14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1882@S33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1893@S196 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1893@S516 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1897@S577 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1899@S1371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1904@T245 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1914@S263 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1927@S555 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1927@S621 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1930@T166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1969@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1981@T259 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1981@T910 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2062@S655 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2071@S42 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2075@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2089@T482 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|208@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2119@S6 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2130@S364 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2186@T246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2191@S316 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|21@S855 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2200@T460 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2213@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S80 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2250@S14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2263@S203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2270@S40 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@T506 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S217 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S285 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@T261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2322@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2322@T382 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2342@S565 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2348@S62 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S68 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S98 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2355@T200 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2355@Y314 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2358@S501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2364@S112 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2398@S311 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2424@S459 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2465@S105 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2465@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2465@T115 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2478@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2492@T6 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2502@S65 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2502@T127 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2509@T70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2561@S215 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|25@S53 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S20 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S274 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S50 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2620@S157 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@S1170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@S1178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@T1167 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@T837 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|263@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2679@S135 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2817@T491 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2823@S371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2868@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2872@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2888@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2907@Y583 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2916@S440 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2936@S52 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@S210 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2995@S437 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3028@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3038@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3038@T704 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3072@S21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3136@S1280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3136@S825 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3160@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3185@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@S219 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@Y222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3243@S653 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S38 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|324@S1275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3260@S1035 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3260@S845 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3269@T15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@Y294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3304@S130 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3304@T120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3304@T456 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3310@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3457@T327 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3485@Y1084 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3495@T170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3499@T51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|34@S166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S303 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S305 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S308 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3613@S56 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3613@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3647@Y359 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3658@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3667@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3669@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3694@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3723@S347 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3762@S65 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3778@S180 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3868@S224 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3873@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3903@S198 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3944@S654 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3944@S702 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4000@T20 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4054@S184 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|409@S558 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4109@T501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S547 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S551 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@T489 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@T493 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4187@S253 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4199@S147 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4199@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4229@S299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4253@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4271@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4271@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|428@T147 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4301@T18 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4387@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4400@S83 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S860 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S872 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|443@S767 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S149 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4446@T126 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4471@S160 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4480@S1176 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4496@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4508@S510 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4510@S618 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@S174 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@T280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4606@S629 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4609@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4616@S162 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4616@S202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S150 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S250 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4644@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4661@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4668@S529 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|46@S222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4721@T100 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4737@T33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4756@S449 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S1018 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S780 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@S230 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4774@S146 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4776@T140 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4790@S561 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4802@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4809@S421 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4928@S246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4968@T307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4976@S398 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5015@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5052@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5060@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@S479 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T162 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T484 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@S1831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@T1834 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5112@S456 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5112@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5133@S575 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5190@Y266 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5213@S262 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5213@T111 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5232@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|524@S404 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5280@S669 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5296@T27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5298@S431 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5298@S470 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5313@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5319@S271 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5335@Y107 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5341@S38 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5366@T521 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5414@S276 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5449@S23 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5454@S357 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5462@S261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5470@S419 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5489@S476 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5512@S310 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5533@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5539@S17 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T514 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5602@S956 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5612@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|561@S66 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5620@S145 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5670@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5698@S237 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5738@S66 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5741@S628 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5769@S13 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5794@T46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5817@T251 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5877@Y173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5897@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5899@T560 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5913@S1039 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5913@S1047 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5917@T11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5931@T345 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5942@S179 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5972@S71 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5974@S326 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5@S515 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6070@S662 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6074@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6127@T1122 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6130@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6140@S170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6140@T136 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6151@S158 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6151@T69 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6157@S592 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6199@S530 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6240@T173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6283@T831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6291@S414 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6294@S330 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6299@S86 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6322@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6325@S142 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6333@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6351@S267 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S190 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@S294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6382@S292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6402@S301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6403@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@S5 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@T2 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6429@S737 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|642@S41 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6434@S366 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6435@T1244 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6437@S472 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6447@S854 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6454@S275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6460@T10 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6465@S496 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|647@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6523@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6569@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6569@T47 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6588@S335 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6588@S358 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@T117 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6656@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6686@S16 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6686@S51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|668@S169 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6704@S25 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T500 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T514 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6719@S59 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6743@T371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6755@S153 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6756@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6770@S375 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6800@S635 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6825@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6848@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|684@S109 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6859@S67 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6865@T612 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6877@T741 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|688@T46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6907@S433 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@S496 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@T413 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6954@S268 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@S464 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@T165 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7022@T356 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7026@S740 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7086@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7108@S642 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7108@T640 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|711@S1050 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|711@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7128@S113 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7132@S351 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7178@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7198@T593 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7213@T41 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|721@S325 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7255@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7263@T321 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7264@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S846 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T651 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7307@T626 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7363@S75 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7368@S70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7370@S494 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7376@T531 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7380@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7386@T318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7395@S287 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S189 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S193 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7457@S596 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7506@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7531@S207 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7567@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@S70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@S63 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@T144 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7617@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7633@T278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7692@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7696@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7719@S711 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7731@S598 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7735@S132 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7778@S281 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7796@T368 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7864@T203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T424 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7877@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|78@S172 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|791@T45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|828@S278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|868@S383 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|930@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|965@S260 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|971@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|994@S150 due to insufficient data in some groups.
# No ANOVA_p values returned

# %%
prot_control_vs_low_late_combined_stats.head()
# Out:
#                         Site  Biostat2L_30_Control_24  \
# 0   jgi|YarliW29_1|1012@T748                13.787372
# 1  jgi|YarliW29_1|1029@S1108                14.986167
# 2   jgi|YarliW29_1|1029@S212                14.699762
# 3   jgi|YarliW29_1|1029@S225                19.030934
# 4   jgi|YarliW29_1|1029@S368                17.105610
#
#    Biostat2L_30_Control_48  Biostat2L_30_Control_72  Biostat2L_31_Control_24  \
# 0                14.073101                13.139452                13.584965
# 1                15.273361                15.055229                14.881975
# 2                14.329749                14.208659                13.898204
# 3                19.312877                19.436340                18.626579
# 4                17.644165                17.407525                17.154443
#
#    Biostat2L_31_Control_48  Biostat2L_31_Control_72  Biostat2L_32_Control_24  \
# 0                13.975370                13.641081                13.571825
# 1                15.121685                15.129808                14.785028
# 2                14.799473                14.519338                13.936396
# 3                19.306227                19.186372                18.683641
# 4                17.636363                17.564225                16.853587
#
#    Biostat2L_32_Control_48  Biostat2L_32_Control_72  ...  Biostat2L_32_Low_48  \
# 0                13.513770                13.580512  ...                  NaN
# 1                14.819879                14.811235  ...                  NaN
# 2                14.696044                14.338431  ...                  NaN
# 3                19.453357                19.281014  ...            19.618330
# 4                17.659650                17.554265  ...            16.329088
#
#    Biostat2L_32_Low_72  Biostat2L_33_Low_24  Biostat2L_33_Low_48  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3            19.928461            19.560714            19.514274
# 4            16.183309            16.512579            16.373739
#
#    Biostat2L_33_Low_72  Biostat2L_34_Low_24  Biostat2L_34_Low_48  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3            19.683966            19.120369            19.430804
# 4            15.780137            17.059593            16.416683
#
#    Biostat2L_34_Low_72                    Protein ANOVA_p
# 0                  NaN   jgi|YarliW29_1|1012@T748     NaN
# 1                  NaN  jgi|YarliW29_1|1029@S1108     NaN
# 2                  NaN   jgi|YarliW29_1|1029@S212     NaN
# 3            19.867831   jgi|YarliW29_1|1029@S225     NaN
# 4            16.037147   jgi|YarliW29_1|1029@S368     NaN
#
# [5 rows x 21 columns]

# %%
# Extract the number between "YarliW29_1|" and "@GLB" using regex
prot_control_vs_low_late_combined_stats["proteinID"] = prot_control_vs_low_late_combined_stats["Site"].str.extract(r"YarliW29_1\|(\d+)@")
# prot_control_vs_low_24h_stats["proteinID"] = prot_control_vs_low_24h_stats["Protein"].str.extract(r"YarliW29_1\|(\d+)@GLB")

# Convert the extracted number to integer (if needed)
prot_control_vs_low_late_combined_stats["proteinID"] = prot_control_vs_low_late_combined_stats["proteinID"].astype(int)
# prot_control_vs_low_24h_stats["proteinID"] = prot_control_vs_low_24h_stats["proteinID"].astype(int)

# %%
prot_control_vs_low_late_combined_stats.head()
# Out:
#                         Site  Biostat2L_30_Control_24  \
# 0   jgi|YarliW29_1|1012@T748                13.787372
# 1  jgi|YarliW29_1|1029@S1108                14.986167
# 2   jgi|YarliW29_1|1029@S212                14.699762
# 3   jgi|YarliW29_1|1029@S225                19.030934
# 4   jgi|YarliW29_1|1029@S368                17.105610
#
#    Biostat2L_30_Control_48  Biostat2L_30_Control_72  Biostat2L_31_Control_24  \
# 0                14.073101                13.139452                13.584965
# 1                15.273361                15.055229                14.881975
# 2                14.329749                14.208659                13.898204
# 3                19.312877                19.436340                18.626579
# 4                17.644165                17.407525                17.154443
#
#    Biostat2L_31_Control_48  Biostat2L_31_Control_72  Biostat2L_32_Control_24  \
# 0                13.975370                13.641081                13.571825
# 1                15.121685                15.129808                14.785028
# 2                14.799473                14.519338                13.936396
# 3                19.306227                19.186372                18.683641
# 4                17.636363                17.564225                16.853587
#
#    Biostat2L_32_Control_48  Biostat2L_32_Control_72  ...  Biostat2L_32_Low_72  \
# 0                13.513770                13.580512  ...                  NaN
# 1                14.819879                14.811235  ...                  NaN
# 2                14.696044                14.338431  ...                  NaN
# 3                19.453357                19.281014  ...            19.928461
# 4                17.659650                17.554265  ...            16.183309
#
#    Biostat2L_33_Low_24  Biostat2L_33_Low_48  Biostat2L_33_Low_72  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3            19.560714            19.514274            19.683966
# 4            16.512579            16.373739            15.780137
#
#    Biostat2L_34_Low_24  Biostat2L_34_Low_48  Biostat2L_34_Low_72  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3            19.120369            19.430804            19.867831
# 4            17.059593            16.416683            16.037147
#
#                      Protein  ANOVA_p proteinID
# 0   jgi|YarliW29_1|1012@T748      NaN      1012
# 1  jgi|YarliW29_1|1029@S1108      NaN      1029
# 2   jgi|YarliW29_1|1029@S212      NaN      1029
# 3   jgi|YarliW29_1|1029@S225      NaN      1029
# 4   jgi|YarliW29_1|1029@S368      NaN      1029
#
# [5 rows x 22 columns]

# %% [markdown]
# ### calculate log2FC

# %%
control = prot_control_vs_low_late_combined_stats.loc[:, prot_control_vs_low_late_combined_stats.columns[prot_control_vs_low_late_combined_stats.columns.str.contains("Control")]]
control.head()

# 24 h
# control24h = prot_control_vs_low_24h_stats.loc[:, prot_control_vs_low_24h_stats.columns[prot_control_vs_low_24h_stats.columns.str.contains("Control")]]
# control24h.head()
# Out:
#    Biostat2L_30_Control_24  Biostat2L_30_Control_48  Biostat2L_30_Control_72  \
# 0                13.787372                14.073101                13.139452
# 1                14.986167                15.273361                15.055229
# 2                14.699762                14.329749                14.208659
# 3                19.030934                19.312877                19.436340
# 4                17.105610                17.644165                17.407525
#
#    Biostat2L_31_Control_24  Biostat2L_31_Control_48  Biostat2L_31_Control_72  \
# 0                13.584965                13.975370                13.641081
# 1                14.881975                15.121685                15.129808
# 2                13.898204                14.799473                14.519338
# 3                18.626579                19.306227                19.186372
# 4                17.154443                17.636363                17.564225
#
#    Biostat2L_32_Control_24  Biostat2L_32_Control_48  Biostat2L_32_Control_72
# 0                13.571825                13.513770                13.580512
# 1                14.785028                14.819879                14.811235
# 2                13.936396                14.696044                14.338431
# 3                18.683641                19.453357                19.281014
# 4                16.853587                17.659650                17.554265

# %%
low = prot_control_vs_low_late_combined_stats.loc[:, prot_control_vs_low_late_combined_stats.columns[
    prot_control_vs_low_late_combined_stats.columns.str.contains("Low")]]
low.head()

# low24h = prot_control_vs_low_24h_stats.loc[:, prot_control_vs_low_24h_stats.columns[
    # prot_control_vs_low_24h_stats.columns.str.contains("Low")]]
# low24h.head()
# Out:
#    Biostat2L_32_Low_24  Biostat2L_32_Low_48  Biostat2L_32_Low_72  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3            19.143275            19.618330            19.928461
# 4            16.613736            16.329088            16.183309
#
#    Biostat2L_33_Low_24  Biostat2L_33_Low_48  Biostat2L_33_Low_72  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3            19.560714            19.514274            19.683966
# 4            16.512579            16.373739            15.780137
#
#    Biostat2L_34_Low_24  Biostat2L_34_Low_48  Biostat2L_34_Low_72
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3            19.120369            19.430804            19.867831
# 4            17.059593            16.416683            16.037147

# %%
# gives the increase of the first. 
prot_control_vs_low_late_combined_stats['log2FC']=log2FC_function(low,control)
# prot_control_vs_low_24h_stats['log2FC']=log2FC_function(low24h,control24h)

# %%
prot_control_vs_low_late_combined_stats['proteinId'] = prot_control_vs_low_late_combined_stats['proteinID']

# %%
df_to_merge = pd.DataFrame()
df_to_merge['low/control_late_combined'] = prot_control_vs_low_late_combined_stats['log2FC']
df_to_merge['Site'] = prot_control_vs_low_late_combined_stats['Site']
# df_to_merge['low/control_late_combined_ANOVA_padj'] = prot_control_vs_low_late_combined_stats['ANOVA_padj']
df_to_merge['low/control_late_combined_ANOVA_p'] = prot_control_vs_low_late_combined_stats['ANOVA_p']

# %%
df_to_merge
# Out:
#      low/control_late_combined                       Site  \
# 0                          NaN   jgi|YarliW29_1|1012@T748
# 1                          NaN  jgi|YarliW29_1|1029@S1108
# 2                          NaN   jgi|YarliW29_1|1029@S212
# 3                     0.394520   jgi|YarliW29_1|1029@S225
# 4                    -1.030425   jgi|YarliW29_1|1029@S368
# ..                         ...                        ...
# 452                        NaN    jgi|YarliW29_1|868@S383
# 453                        NaN    jgi|YarliW29_1|930@S188
# 454                  -0.244271    jgi|YarliW29_1|965@S260
# 455                        NaN     jgi|YarliW29_1|971@S12
# 456                  -0.084112    jgi|YarliW29_1|994@S150
#
#     low/control_late_combined_ANOVA_p
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 452                               NaN
# 453                               NaN
# 454                               NaN
# 455                               NaN
# 456                               NaN
#
# [457 rows x 3 columns]

# %%
merged_df = pd.merge(merged_df, df_to_merge, left_on='Site',right_on='Site', how='left')

# %%
merged_df.head(20)
# Out:
#                                        Peptide                       Site  \
# 0                  K.LAEENTSEAIFDTPDT#DEDDAK.S   jgi|YarliW29_1|1012@T748
# 1                                R.SNS#MSAFR.M  jgi|YarliW29_1|1029@S1108
# 2                           R.RGS#MTSTTTNTER.T   jgi|YarliW29_1|1029@S212
# 3        R.THS#LTSTTTTIK.R; R.THS#LTSTTTTIKR.M   jgi|YarliW29_1|1029@S225
# 4            R.TLS#PM*KPALK.M; R.TLS#PMKPALK.M   jgi|YarliW29_1|1029@S368
# 5                         R.ANS#GLSSAAAAAAIR.H    jgi|YarliW29_1|1029@S49
# 6   R.QAAPAPPSQVLSPM*LS#HSESEEDLSMFQDAHEHLGK.S   jgi|YarliW29_1|1029@S559
# 7                       R.HHS#LTSSTSQPNLQQGR.N    jgi|YarliW29_1|1029@S64
# 8                      K.T#PGGAAQHFLDDDDYFSR.G   jgi|YarliW29_1|1049@T925
# 9                          K.LHDVANSPYQSS#PR.T   jgi|YarliW29_1|1051@S540
# 10                        R.SRST#VEADRDALLQR.K   jgi|YarliW29_1|1051@T191
# 11                        R.SQS#PQRPQSGIWDGK.F   jgi|YarliW29_1|1058@S120
# 12                         R.S#FDVPPPPIADDDK.W   jgi|YarliW29_1|1064@S131
# 13                           K.S#PQIEDEHIEER.F    jgi|YarliW29_1|1077@S61
# 14                      A.PADRPT#WGTNVPGSGTR.E   jgi|YarliW29_1|1096@T209
# 15                             R.RLS#EDILNSR.R    jgi|YarliW29_1|1103@S46
# 16                      S.KVT#LVFGQM*NEPPGAR.A   jgi|YarliW29_1|1115@T247
# 17                         E.YS#VEFC@GGTHVGK.T   jgi|YarliW29_1|1124@S738
# 18                  R.GHQSRPS#QSSIDLQPTSSYTR.E    jgi|YarliW29_1|1205@S48
# 19                           R.EGYHDEPSS#PKK.H    jgi|YarliW29_1|1205@S71
#
#                 UniProt              Protein Residue      AScore  \
# 0   jgi|YarliW29_1|1012  jgi|YarliW29_1|1012    T748    43.40600
# 1   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029   S1108    22.21700
# 2   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029    S212    45.54300
# 3   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029    S225    28.74600
# 4   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029    S368  1000.00000
# 5   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029     S49   107.28000
# 6   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029    S559    23.94200
# 7   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029     S64    45.54300
# 8   jgi|YarliW29_1|1049  jgi|YarliW29_1|1049    T925   256.78000
# 9   jgi|YarliW29_1|1051  jgi|YarliW29_1|1051    S540     0.00000
# 10  jgi|YarliW29_1|1051  jgi|YarliW29_1|1051    T191     0.00000
# 11  jgi|YarliW29_1|1058  jgi|YarliW29_1|1058    S120    32.86900
# 12  jgi|YarliW29_1|1064  jgi|YarliW29_1|1064    S131  1000.00000
# 13  jgi|YarliW29_1|1077  jgi|YarliW29_1|1077     S61  1000.00000
# 14  jgi|YarliW29_1|1096  jgi|YarliW29_1|1096    T209    71.26700
# 15  jgi|YarliW29_1|1103  jgi|YarliW29_1|1103     S46    81.29900
# 16  jgi|YarliW29_1|1115  jgi|YarliW29_1|1115    T247  1000.00000
# 17  jgi|YarliW29_1|1124  jgi|YarliW29_1|1124    S738  1000.00000
# 18  jgi|YarliW29_1|1205  jgi|YarliW29_1|1205     S48     0.00002
# 19  jgi|YarliW29_1|1205  jgi|YarliW29_1|1205     S71     0.00000
#
#                            id  Total missingness  Oscillation_24 missingness  \
# 0    jgi|YarliW29_1|1012@T748                 18                           0
# 1   jgi|YarliW29_1|1029@S1108                 18                           0
# 2    jgi|YarliW29_1|1029@S212                 36                           3
# 3    jgi|YarliW29_1|1029@S225                  0                           0
# 4    jgi|YarliW29_1|1029@S368                 18                           3
# 5     jgi|YarliW29_1|1029@S49                  5                           0
# 6    jgi|YarliW29_1|1029@S559                 49                           3
# 7     jgi|YarliW29_1|1029@S64                 37                           3
# 8    jgi|YarliW29_1|1049@T925                  1                           0
# 9    jgi|YarliW29_1|1051@S540                 19                           3
# 10   jgi|YarliW29_1|1051@T191                 18                           0
# 11   jgi|YarliW29_1|1058@S120                 36                           3
# 12   jgi|YarliW29_1|1064@S131                 41                           3
# 13    jgi|YarliW29_1|1077@S61                 18                           0
# 14   jgi|YarliW29_1|1096@T209                 36                           3
# 15    jgi|YarliW29_1|1103@S46                 36                           3
# 16   jgi|YarliW29_1|1115@T247                 36                           3
# 17   jgi|YarliW29_1|1124@S738                 36                           3
# 18    jgi|YarliW29_1|1205@S48                 41                           3
# 19    jgi|YarliW29_1|1205@S71                 36                           3
#
#     Oscillation_3.5 missingness  ...  \
# 0                             0  ...
# 1                             0  ...
# 2                             3  ...
# 3                             0  ...
# 4                             3  ...
# 5                             1  ...
# 6                             3  ...
# 7                             3  ...
# 8                             1  ...
# 9                             3  ...
# 10                            0  ...
# 11                            3  ...
# 12                            3  ...
# 13                            0  ...
# 14                            3  ...
# 15                            3  ...
# 16                            3  ...
# 17                            3  ...
# 18                            3  ...
# 19                            3  ...
#
#                                                 goAcc  #transcriptId    kogid  \
# 0                  GO:0005097, GO:0005622, GO:0032313         1990.0  KOG4347
# 1                                                 NaN            NaN      NaN
# 2                                                 NaN            NaN      NaN
# 3                                                 NaN            NaN      NaN
# 4                                                 NaN            NaN      NaN
# 5                                                 NaN            NaN      NaN
# 6                                                 NaN            NaN      NaN
# 7                                                 NaN            NaN      NaN
# 8                  GO:0004573, GO:0009311, GO:0003824         2027.0  KOG2161
# 9      GO:0016773, GO:0004428, GO:0005488, GO:0004430         2029.0  KOG0903
# 10     GO:0016773, GO:0004428, GO:0005488, GO:0004430         2029.0  KOG0903
# 11                 GO:0006812, GO:0008324, GO:0016020            NaN      NaN
# 12     GO:0003824, GO:0008152, GO:0006096, GO:0016868         2042.0  KOG0235
# 13                                         GO:0005488         2055.0  KOG2734
# 14                                                NaN         2074.0  KOG3346
# 15                                                NaN            NaN      NaN
# 16  GO:0015078, GO:0016469, GO:0000166, GO:0017111...         2093.0  KOG1350
# 17  GO:0004813, GO:0005524, GO:0005737, GO:0006412...         2102.0  KOG0188
# 18  GO:0004672, GO:0005524, GO:0006468, GO:0004674...         2183.0  KOG0592
# 19  GO:0004672, GO:0005524, GO:0006468, GO:0004674...         2183.0  KOG0592
#
#                                            kogdefline  \
# 0                       GTPase-activating protein VRP
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                       Glucosidase I
# 9   Phosphatidylinositol 4-kinase, involved in int...
# 10  Phosphatidylinositol 4-kinase, involved in int...
# 11                                                NaN
# 12                            Phosphoglycerate mutase
# 13                  Uncharacterized conserved protein
# 14           Phosphatidylethanolamine binding protein
# 15                                                NaN
# 16               F0F1-type ATP synthase, beta subunit
# 17                             Alanyl-tRNA synthetase
# 18  3-phosphoinositide-dependent protein kinase (P...
# 19  3-phosphoinositide-dependent protein kinase (P...
#
#                                              kogClass  \
# 0                    General function prediction only
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8               Carbohydrate transport and metabolism
# 9   Signal transduction mechanisms, Intracellular ...
# 10  Signal transduction mechanisms, Intracellular ...
# 11                                                NaN
# 12              Carbohydrate transport and metabolism
# 13                                   Function unknown
# 14                   General function prediction only
# 15                                                NaN
# 16                   Energy production and conversion
# 17    Translation, ribosomal structure and biogenesis
# 18                     Signal transduction mechanisms
# 19                     Signal transduction mechanisms
#
#                               kogGroup  early/late  early/late_ANOVA_p  \
# 0                 POORLY CHARACTERIZED   -0.856726                 NaN
# 1                                  NaN   -0.724107                 NaN
# 2                                  NaN   -1.081031                 NaN
# 3                                  NaN   -1.023307                 NaN
# 4                                  NaN   -0.196793                 NaN
# 5                                  NaN   -0.656691                 NaN
# 6                                  NaN   -0.129958                 NaN
# 7                                  NaN   -1.161774                 NaN
# 8                           METABOLISM   -1.337130                 NaN
# 9     CELLULAR PROCESSES AND SIGNALING   -0.705503                 NaN
# 10    CELLULAR PROCESSES AND SIGNALING    0.163752                 NaN
# 11                                 NaN   -0.260584                 NaN
# 12                          METABOLISM   -0.120233                 NaN
# 13                POORLY CHARACTERIZED   -0.476474                 NaN
# 14                POORLY CHARACTERIZED    0.517389                 NaN
# 15                                 NaN   -0.829052                 NaN
# 16                          METABOLISM   -1.481107                 NaN
# 17  INFORMATION STORAGE AND PROCESSING   -0.452256                 NaN
# 18    CELLULAR PROCESSES AND SIGNALING    2.054248                 NaN
# 19    CELLULAR PROCESSES AND SIGNALING    1.183146                 NaN
#
#     low/control_late_combined  low/control_late_combined_ANOVA_p
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                    0.394520                                NaN
# 4                   -1.030425                                NaN
# 5                   -0.311865                                NaN
# 6                         NaN                                NaN
# 7                         NaN                                NaN
# 8                   -1.404896                                NaN
# 9                   -1.072325                                NaN
# 10                        NaN                                NaN
# 11                        NaN                                NaN
# 12                        NaN                                NaN
# 13                        NaN                                NaN
# 14                        NaN                                NaN
# 15                        NaN                                NaN
# 16                        NaN                                NaN
# 17                        NaN                                NaN
# 18                        NaN                                NaN
# 19                        NaN                                NaN
#
# [20 rows x 197 columns]

# %%
prot_control_vs_low_late_combined_stats.head()
# Out:
#                         Site  Biostat2L_30_Control_24  \
# 0   jgi|YarliW29_1|1012@T748                13.787372
# 1  jgi|YarliW29_1|1029@S1108                14.986167
# 2   jgi|YarliW29_1|1029@S212                14.699762
# 3   jgi|YarliW29_1|1029@S225                19.030934
# 4   jgi|YarliW29_1|1029@S368                17.105610
#
#    Biostat2L_30_Control_48  Biostat2L_30_Control_72  Biostat2L_31_Control_24  \
# 0                14.073101                13.139452                13.584965
# 1                15.273361                15.055229                14.881975
# 2                14.329749                14.208659                13.898204
# 3                19.312877                19.436340                18.626579
# 4                17.644165                17.407525                17.154443
#
#    Biostat2L_31_Control_48  Biostat2L_31_Control_72  Biostat2L_32_Control_24  \
# 0                13.975370                13.641081                13.571825
# 1                15.121685                15.129808                14.785028
# 2                14.799473                14.519338                13.936396
# 3                19.306227                19.186372                18.683641
# 4                17.636363                17.564225                16.853587
#
#    Biostat2L_32_Control_48  Biostat2L_32_Control_72  ...  Biostat2L_33_Low_48  \
# 0                13.513770                13.580512  ...                  NaN
# 1                14.819879                14.811235  ...                  NaN
# 2                14.696044                14.338431  ...                  NaN
# 3                19.453357                19.281014  ...            19.514274
# 4                17.659650                17.554265  ...            16.373739
#
#    Biostat2L_33_Low_72  Biostat2L_34_Low_24  Biostat2L_34_Low_48  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3            19.683966            19.120369            19.430804
# 4            15.780137            17.059593            16.416683
#
#    Biostat2L_34_Low_72                    Protein  ANOVA_p  proteinID  \
# 0                  NaN   jgi|YarliW29_1|1012@T748      NaN       1012
# 1                  NaN  jgi|YarliW29_1|1029@S1108      NaN       1029
# 2                  NaN   jgi|YarliW29_1|1029@S212      NaN       1029
# 3            19.867831   jgi|YarliW29_1|1029@S225      NaN       1029
# 4            16.037147   jgi|YarliW29_1|1029@S368      NaN       1029
#
#      log2FC proteinId
# 0       NaN      1012
# 1       NaN      1029
# 2       NaN      1029
# 3  0.394520      1029
# 4 -1.030425      1029
#
# [5 rows x 24 columns]

# %%
prot_control_vs_low_late_combined_stats_withAnnote = pd.merge(prot_control_vs_low_late_combined_stats, merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')
# prot_control_vs_low_24h_stats_withAnnote = pd.merge(prot_control_vs_low_24h_stats, merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')

# %%
prot_control_vs_low_late_combined_stats_withAnnote.columns
# Out:
# Index(['Site', 'Biostat2L_30_Control_24', 'Biostat2L_30_Control_48',
#        'Biostat2L_30_Control_72', 'Biostat2L_31_Control_24',
#        'Biostat2L_31_Control_48', 'Biostat2L_31_Control_72',
#        'Biostat2L_32_Control_24', 'Biostat2L_32_Control_48',
#        'Biostat2L_32_Control_72', 'Biostat2L_32_Low_24', 'Biostat2L_32_Low_48',
#        'Biostat2L_32_Low_72', 'Biostat2L_33_Low_24', 'Biostat2L_33_Low_48',
#        'Biostat2L_33_Low_72', 'Biostat2L_34_Low_24', 'Biostat2L_34_Low_48',
#        'Biostat2L_34_Low_72', 'Protein', 'ANOVA_p', 'proteinID', 'log2FC',
#        'proteinId', '#proteinId', 'kogid', 'kogdefline', 'kogClass',
#        'kogGroup', 'definition', 'catalyticActivity', 'pathway',
#        'pathway_class', 'pathway_type', 'ecNum', 'cofactors', 'gotermId',
#        'gotermType', 'goName', 'goAcc'],
#       dtype='object')

# %% [markdown]
# ### optional save.

# %%
# prot_control_vs_low_late_combined_stats_withAnnote.to_csv('control_vs_low_late.csv')
# prot_control_vs_low_24h_stats_withAnnote.to_csv('control_vs_low_24h.csv')

# %% [markdown]
# ### Volcano plot comparing low vs high,
# all late (increase means increased in low)

# %%
dataset = prot_control_vs_low_late_combined_stats_withAnnote[['log2FC', 'ANOVA_p']].copy()
dataset.index = prot_control_vs_low_late_combined_stats_withAnnote.Site

# dataset24h = prot_control_vs_low_24h_stats_withAnnote[['log2FC', 'ANOVA_padj']].copy()

# %%
log2FC_threshold = np.log2(1.3)

# %%
dataset
# Out:
#                              log2FC ANOVA_p
# Site
# jgi|YarliW29_1|1012@T748        NaN     NaN
# jgi|YarliW29_1|1029@S1108       NaN     NaN
# jgi|YarliW29_1|1029@S212        NaN     NaN
# jgi|YarliW29_1|1029@S225   0.394520     NaN
# jgi|YarliW29_1|1029@S368  -1.030425     NaN
# ...                             ...     ...
# jgi|YarliW29_1|868@S383         NaN     NaN
# jgi|YarliW29_1|930@S188         NaN     NaN
# jgi|YarliW29_1|965@S260   -0.244271     NaN
# jgi|YarliW29_1|971@S12          NaN     NaN
# jgi|YarliW29_1|994@S150   -0.084112     NaN
#
# [457 rows x 2 columns]

# %%
# # subset the log2FC and the P_value for this dataset. 
# dataset.columns = ['log2FC','P_value']

# # obtain the -logP_adj for the dataset. 
# dataset['-logP_adj'] = -np.log10(dataset['P_value'])

# # set a class for up (1) or down (-1) proteins. 
# dataset['class'] = 0
# dataset.loc[(dataset['log2FC']>log2FC_threshold)&(dataset['-logP_adj']>-np.log10(0.05)),'class'] = 1
# dataset.loc[(dataset['log2FC']<-log2FC_threshold)&(dataset['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
# # subset the log2FC and the P_value for this dataset. 
# dataset24h.columns = ['log2FC','P_value']

# # obtain the -logP_adj for the dataset. 
# dataset24h['-logP_adj'] = -np.log10(dataset['P_value'])

# # set a class for up (1) or down (-1) proteins. 
# dataset24h['class'] = 0
# dataset24h.loc[(dataset24h['log2FC']>log2FC_threshold)&(dataset24h['-logP_adj']>-np.log10(0.05)),'class'] = 1
# dataset24h.loc[(dataset24h['log2FC']<-log2FC_threshold)&(dataset24h['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
dataset
# Out:
#                              log2FC P_value
# Site
# jgi|YarliW29_1|1012@T748        NaN     NaN
# jgi|YarliW29_1|1029@S1108       NaN     NaN
# jgi|YarliW29_1|1029@S212        NaN     NaN
# jgi|YarliW29_1|1029@S225   0.394520     NaN
# jgi|YarliW29_1|1029@S368  -1.030425     NaN
# ...                             ...     ...
# jgi|YarliW29_1|868@S383         NaN     NaN
# jgi|YarliW29_1|930@S188         NaN     NaN
# jgi|YarliW29_1|965@S260   -0.244271     NaN
# jgi|YarliW29_1|971@S12          NaN     NaN
# jgi|YarliW29_1|994@S150   -0.084112     NaN
#
# [457 rows x 2 columns]

# %%
# volcano_plot(dataset)

# %%
# volcano_plot_annotate(dataset)

# %%
# volcano_plot(dataset24h)

# %% [markdown]
# ### Significant protein slicing.

# %%
prot_control_vs_low_late_combined_stats_withAnnote.columns
# Out:
# Index(['Site', 'Biostat2L_30_Control_24', 'Biostat2L_30_Control_48',
#        'Biostat2L_30_Control_72', 'Biostat2L_31_Control_24',
#        'Biostat2L_31_Control_48', 'Biostat2L_31_Control_72',
#        'Biostat2L_32_Control_24', 'Biostat2L_32_Control_48',
#        'Biostat2L_32_Control_72', 'Biostat2L_32_Low_24', 'Biostat2L_32_Low_48',
#        'Biostat2L_32_Low_72', 'Biostat2L_33_Low_24', 'Biostat2L_33_Low_48',
#        'Biostat2L_33_Low_72', 'Biostat2L_34_Low_24', 'Biostat2L_34_Low_48',
#        'Biostat2L_34_Low_72', 'Protein', 'ANOVA_p', 'proteinID', 'log2FC',
#        'proteinId', '#proteinId', 'kogid', 'kogdefline', 'kogClass',
#        'kogGroup', 'definition', 'catalyticActivity', 'pathway',
#        'pathway_class', 'pathway_type', 'ecNum', 'cofactors', 'gotermId',
#        'gotermType', 'goName', 'goAcc'],
#       dtype='object')

# %%
# sig_control_vs_low_late_combined = prot_control_vs_low_late_combined_stats_withAnnote[prot_control_vs_low_late_combined_stats_withAnnote['ANOVA_padj'] < 0.05]
# sig_control_vs_low_24h = prot_control_vs_low_24h_stats_withAnnote[prot_control_vs_low_24h_stats_withAnnote['ANOVA_padj'] < 0.05]

# %% [markdown]
# ### optional save.

# %%
# sig_control_vs_low_late_combined.to_csv('Sig_control_vs_low_late_combined.csv')
# sig_control_vs_low_24h.to_csv('Sig_control_vs_low_24h.csv')

# %% [markdown]
# ## Compare Control vs Oscillation.

# %%
prot = annotated_phospho[sample_ids_prot_redox]
prot['Protein'] = annotated_phospho['Site']
prot.index = annotated_phospho['Site']
# drop oscillations.
# prot_control_vs_oscillation_24h = prot.drop(prot.columns[prot.columns.str.contains("Low")], axis=1)
prot_control_vs_oscillation_late_combined = prot.drop(prot.columns[prot.columns.str.contains("Low")], axis=1)


# drop early timepoints. 
# prot_control_vs_oscillation_24h = prot_control_vs_oscillation_24h.drop(prot_control_vs_oscillation_24h.columns[
#     prot_control_vs_oscillation_24h.columns.str.contains("5.5|3.5|4.5|48|72")], axis=1)

prot_control_vs_oscillation_late_combined = prot_control_vs_oscillation_late_combined.drop(prot_control_vs_oscillation_late_combined.columns[
    prot_control_vs_oscillation_late_combined.columns.str.contains("5.5|3.5|4.5")], axis=1)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/1265878771.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prot['Protein'] = annotated_phospho['Site']

# %%
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))

# %% [markdown]
# ### Prep for p-values.

# %%
# group for mapping in nanova. 


condition_series_controlvsOscLateCombined = pd.Series(prot_control_vs_oscillation_late_combined.columns).map(prot_condition_dict)
condition_series_controlvsOscLateCombined.index = prot_control_vs_oscillation_late_combined.columns
condition_series_controlvsOscLateCombined 

# condition_series_controlvsOsc24 = pd.Series(prot_control_vs_oscillation_24h.columns).map(prot_condition_dict)
# condition_series_controlvsOsc24.index = prot_control_vs_oscillation_24h.columns
# condition_series_controlvsOsc24
# Out:
# Biostat2L_29_Oscillation_24    Oscillation
# Biostat2L_29_Oscillation_48    Oscillation
# Biostat2L_29_Oscillation_72    Oscillation
# Biostat2L_30_Control_24            Control
# Biostat2L_30_Control_48            Control
# Biostat2L_30_Control_72            Control
# Biostat2L_30_Oscillation_24    Oscillation
# Biostat2L_30_Oscillation_48    Oscillation
# Biostat2L_30_Oscillation_72    Oscillation
# Biostat2L_31_Control_24            Control
# Biostat2L_31_Control_48            Control
# Biostat2L_31_Control_72            Control
# Biostat2L_31_Oscillation_24    Oscillation
# Biostat2L_31_Oscillation_48    Oscillation
# Biostat2L_31_Oscillation_72    Oscillation
# Biostat2L_32_Control_24            Control
# Biostat2L_32_Control_48            Control
# Biostat2L_32_Control_72            Control
# Protein                                NaN
# dtype: object

# %%
# late stats.
prot_control_vs_oscillation_late_combined_stats = global_stats_calc_prot(prot_control_vs_oscillation_late_combined,
                                                                         condition_series_controlvsOscLateCombined )

# 24 h stats. 
# prot_control_vs_oscillation_24h_stats = global_stats_calc_prot(prot_control_vs_oscillation_24h,
                                                                  # condition_series_controlvsOsc24)
# Out:
# Skipping protein jgi|YarliW29_1|1012@T748 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S1108 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S212 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S225 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S368 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S49 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S559 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1049@T925 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1051@S540 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1051@T191 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1058@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1064@S131 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1077@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1096@T209 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1103@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1115@T247 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1124@S738 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S71 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@T202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1332@S228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@S243 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@T769 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S3768 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S4408 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1380@S273 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1394@S24 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1414@T792 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S578 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S581 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1449@T166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@T83 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@T86 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1516@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1516@S672 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1519@T282 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1524@S94 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1529@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S283 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S331 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S333 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S337 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S350 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S367 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1625@T19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1633@T65 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1648@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S1066 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S393 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1667@S386 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1686@S938 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1686@T946 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S504 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1707@S231 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1724@T250 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1742@S595 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1813@S177 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1817@S427 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1834@S267 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1834@T304 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1864@S49 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1871@S14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1882@S33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1893@S196 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1893@S516 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1897@S577 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1899@S1371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1904@T245 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1914@S263 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1927@S555 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1927@S621 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1930@T166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1969@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1981@T259 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1981@T910 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2062@S655 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2071@S42 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2075@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2089@T482 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|208@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2119@S6 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2130@S364 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2186@T246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2191@S316 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|21@S855 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2200@T460 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2213@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S80 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2250@S14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2263@S203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2270@S40 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@T506 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S217 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S285 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@T261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2322@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2322@T382 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2342@S565 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2348@S62 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S68 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S98 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2355@T200 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2355@Y314 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2358@S501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2364@S112 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2398@S311 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2424@S459 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2465@S105 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2465@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2465@T115 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2478@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2492@T6 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2502@S65 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2502@T127 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2509@T70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2561@S215 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|25@S53 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S20 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S274 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S50 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2620@S157 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@S1170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@S1178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@T1167 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@T837 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|263@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2679@S135 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2817@T491 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2823@S371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2868@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2872@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2888@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2907@Y583 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2916@S440 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2936@S52 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@S210 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2995@S437 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3028@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3038@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3038@T704 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3072@S21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3136@S1280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3136@S825 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3160@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3185@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@S219 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@Y222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3243@S653 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S38 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|324@S1275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3260@S1035 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3260@S845 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3269@T15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@Y294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3304@S130 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3304@T120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3304@T456 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3310@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3457@T327 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3485@Y1084 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3495@T170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3499@T51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|34@S166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S303 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S305 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S308 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3613@S56 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3613@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3647@Y359 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3658@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3667@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3669@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3694@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3723@S347 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3762@S65 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3778@S180 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3868@S224 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3873@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3903@S198 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3944@S654 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3944@S702 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4000@T20 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4054@S184 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|409@S558 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4109@T501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S547 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S551 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@T489 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@T493 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4187@S253 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4199@S147 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4199@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4229@S299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4253@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4271@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4271@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|428@T147 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4301@T18 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4387@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4400@S83 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S860 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S872 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|443@S767 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S149 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4446@T126 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4471@S160 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4480@S1176 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4496@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4508@S510 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4510@S618 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@S174 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@T280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4606@S629 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4609@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4616@S162 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4616@S202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S150 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S250 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4644@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4661@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4668@S529 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|46@S222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4721@T100 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4737@T33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4756@S449 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S1018 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S780 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@S230 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4774@S146 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4776@T140 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4790@S561 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4802@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4809@S421 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4928@S246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4968@T307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4976@S398 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5015@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5052@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5060@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@S479 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T162 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T484 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@S1831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@T1834 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5112@S456 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5112@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5133@S575 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5190@Y266 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5213@S262 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5213@T111 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5232@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|524@S404 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5280@S669 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5296@T27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5298@S431 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5298@S470 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5313@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5319@S271 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5335@Y107 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5341@S38 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5366@T521 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5414@S276 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5449@S23 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5454@S357 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5462@S261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5470@S419 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5489@S476 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5512@S310 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5533@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5539@S17 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T514 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5602@S956 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5612@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|561@S66 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5620@S145 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5670@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5698@S237 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5738@S66 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5741@S628 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5769@S13 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5794@T46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5817@T251 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5877@Y173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5897@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5899@T560 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5913@S1039 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5913@S1047 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5917@T11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5931@T345 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5942@S179 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5972@S71 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5974@S326 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5@S515 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6070@S662 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6074@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6127@T1122 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6130@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6140@S170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6140@T136 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6151@S158 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6151@T69 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6157@S592 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6199@S530 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6240@T173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6283@T831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6291@S414 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6294@S330 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6299@S86 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6322@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6325@S142 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6333@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6351@S267 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S190 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@S294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6382@S292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6402@S301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6403@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@S5 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@T2 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6429@S737 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|642@S41 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6434@S366 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6435@T1244 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6437@S472 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6447@S854 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6454@S275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6460@T10 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6465@S496 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|647@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6523@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6569@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6569@T47 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6588@S335 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6588@S358 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@T117 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6656@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6686@S16 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6686@S51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|668@S169 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6704@S25 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T500 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T514 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6719@S59 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6743@T371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6755@S153 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6756@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6770@S375 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6800@S635 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6825@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6848@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|684@S109 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6859@S67 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6865@T612 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6877@T741 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|688@T46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6907@S433 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@S496 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@T413 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6954@S268 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@S464 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@T165 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7022@T356 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7026@S740 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7086@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7108@S642 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7108@T640 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|711@S1050 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|711@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7128@S113 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7132@S351 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7178@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7198@T593 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7213@T41 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|721@S325 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7255@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7263@T321 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7264@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S846 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T651 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7307@T626 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7363@S75 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7368@S70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7370@S494 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7376@T531 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7380@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7386@T318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7395@S287 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S189 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S193 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7457@S596 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7506@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7531@S207 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7567@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@S70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@S63 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@T144 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7617@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7633@T278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7692@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7696@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7719@S711 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7731@S598 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7735@S132 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7778@S281 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7796@T368 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7864@T203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T424 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7877@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|78@S172 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|791@T45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|828@S278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|868@S383 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|930@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|965@S260 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|971@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|994@S150 due to insufficient data in some groups.
# No ANOVA_p values returned

# %%
# Extract the number between "YarliW29_1|" and "@GLB" using regex.
prot_control_vs_oscillation_late_combined_stats["proteinID"] = prot_control_vs_oscillation_late_combined_stats["Site"].str.extract(r"YarliW29_1\|(\d+)@")
# prot_control_vs_oscillation_24h_stats["proteinID"] = prot_control_vs_oscillation_24h_stats["Protein"].str.extract(r"YarliW29_1\|(\d+)@GLB")



# Convert the extracted number to integer (if needed).
prot_control_vs_oscillation_late_combined_stats["proteinID"] = prot_control_vs_oscillation_late_combined_stats["proteinID"].astype(int)
# prot_control_vs_oscillation_24h_stats["proteinID"] = prot_control_vs_oscillation_24h_stats["proteinID"].astype(int)

# %% [markdown]
# ### calculate log2FC

# %%
controlLateCombined = prot_control_vs_oscillation_late_combined_stats.loc[:, prot_control_vs_oscillation_late_combined_stats.columns[prot_control_vs_oscillation_late_combined_stats.columns.str.contains("Control")]]
# control24h = prot_control_vs_oscillation_24h_stats.loc[:, prot_control_vs_oscillation_24h_stats.columns[prot_control_vs_oscillation_24h_stats.columns.str.contains("Control")]]
# control24h.head()

# %%
oscLateCombinedLate = prot_control_vs_oscillation_late_combined_stats.loc[:, prot_control_vs_oscillation_late_combined_stats.columns[
    prot_control_vs_oscillation_late_combined_stats.columns.str.contains("Oscillation")]]

# osc24h = prot_control_vs_oscillation_24h_stats.loc[:, prot_control_vs_oscillation_24h_stats.columns[
    # prot_control_vs_oscillation_24h_stats.columns.str.contains("Oscillation")]]
# osc24h.head()

# %%
oscLateCombinedLate.head()
# Out:
#    Biostat2L_29_Oscillation_24  Biostat2L_29_Oscillation_48  \
# 0                    13.921812                    14.148031
# 1                    14.687903                    14.764124
# 2                          NaN                          NaN
# 3                    18.450295                    19.224261
# 4                          NaN                          NaN
#
#    Biostat2L_29_Oscillation_72  Biostat2L_30_Oscillation_24  \
# 0                    13.556648                    13.728869
# 1                    14.143469                    14.749323
# 2                          NaN                          NaN
# 3                    19.409963                    18.449405
# 4                          NaN                          NaN
#
#    Biostat2L_30_Oscillation_48  Biostat2L_30_Oscillation_72  \
# 0                    13.957324                    14.072943
# 1                    14.903341                    14.317786
# 2                          NaN                          NaN
# 3                    19.105002                    19.042270
# 4                          NaN                          NaN
#
#    Biostat2L_31_Oscillation_24  Biostat2L_31_Oscillation_48  \
# 0                    13.943018                    13.816518
# 1                    15.112586                    15.277582
# 2                          NaN                          NaN
# 3                    18.343261                    19.083977
# 4                          NaN                          NaN
#
#    Biostat2L_31_Oscillation_72
# 0                    14.655760
# 1                    15.195779
# 2                          NaN
# 3                    19.094777
# 4                          NaN

# %%
# gives the increase of the first. 
# prot_control_vs_oscillation_24h_stats['log2FC']=log2FC_function(osc24h, control24h)
prot_control_vs_oscillation_late_combined_stats['log2FC']=log2FC_function(oscLateCombinedLate,controlLateCombined)

# %%
df_to_merge = pd.DataFrame()
df_to_merge['osc/control_late_cominbed'] = prot_control_vs_oscillation_late_combined_stats['log2FC']
df_to_merge['Site'] = prot_control_vs_oscillation_late_combined_stats['Site']
# df_to_merge['osc/control_late_cominbedANOVA_padj'] = prot_control_vs_oscillation_late_combined_stats['ANOVA_padj']
df_to_merge['osc/control_late_cominbedANOVA_p'] = prot_control_vs_oscillation_late_combined_stats['ANOVA_p']

# %%
merged_df = pd.merge(merged_df, df_to_merge, left_on='Site',right_on='Site', how='left')

# %%
merged_df.head(20)
# Out:
#                                        Peptide                       Site  \
# 0                  K.LAEENTSEAIFDTPDT#DEDDAK.S   jgi|YarliW29_1|1012@T748
# 1                                R.SNS#MSAFR.M  jgi|YarliW29_1|1029@S1108
# 2                           R.RGS#MTSTTTNTER.T   jgi|YarliW29_1|1029@S212
# 3        R.THS#LTSTTTTIK.R; R.THS#LTSTTTTIKR.M   jgi|YarliW29_1|1029@S225
# 4            R.TLS#PM*KPALK.M; R.TLS#PMKPALK.M   jgi|YarliW29_1|1029@S368
# 5                         R.ANS#GLSSAAAAAAIR.H    jgi|YarliW29_1|1029@S49
# 6   R.QAAPAPPSQVLSPM*LS#HSESEEDLSMFQDAHEHLGK.S   jgi|YarliW29_1|1029@S559
# 7                       R.HHS#LTSSTSQPNLQQGR.N    jgi|YarliW29_1|1029@S64
# 8                      K.T#PGGAAQHFLDDDDYFSR.G   jgi|YarliW29_1|1049@T925
# 9                          K.LHDVANSPYQSS#PR.T   jgi|YarliW29_1|1051@S540
# 10                        R.SRST#VEADRDALLQR.K   jgi|YarliW29_1|1051@T191
# 11                        R.SQS#PQRPQSGIWDGK.F   jgi|YarliW29_1|1058@S120
# 12                         R.S#FDVPPPPIADDDK.W   jgi|YarliW29_1|1064@S131
# 13                           K.S#PQIEDEHIEER.F    jgi|YarliW29_1|1077@S61
# 14                      A.PADRPT#WGTNVPGSGTR.E   jgi|YarliW29_1|1096@T209
# 15                             R.RLS#EDILNSR.R    jgi|YarliW29_1|1103@S46
# 16                      S.KVT#LVFGQM*NEPPGAR.A   jgi|YarliW29_1|1115@T247
# 17                         E.YS#VEFC@GGTHVGK.T   jgi|YarliW29_1|1124@S738
# 18                  R.GHQSRPS#QSSIDLQPTSSYTR.E    jgi|YarliW29_1|1205@S48
# 19                           R.EGYHDEPSS#PKK.H    jgi|YarliW29_1|1205@S71
#
#                 UniProt              Protein Residue      AScore  \
# 0   jgi|YarliW29_1|1012  jgi|YarliW29_1|1012    T748    43.40600
# 1   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029   S1108    22.21700
# 2   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029    S212    45.54300
# 3   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029    S225    28.74600
# 4   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029    S368  1000.00000
# 5   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029     S49   107.28000
# 6   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029    S559    23.94200
# 7   jgi|YarliW29_1|1029  jgi|YarliW29_1|1029     S64    45.54300
# 8   jgi|YarliW29_1|1049  jgi|YarliW29_1|1049    T925   256.78000
# 9   jgi|YarliW29_1|1051  jgi|YarliW29_1|1051    S540     0.00000
# 10  jgi|YarliW29_1|1051  jgi|YarliW29_1|1051    T191     0.00000
# 11  jgi|YarliW29_1|1058  jgi|YarliW29_1|1058    S120    32.86900
# 12  jgi|YarliW29_1|1064  jgi|YarliW29_1|1064    S131  1000.00000
# 13  jgi|YarliW29_1|1077  jgi|YarliW29_1|1077     S61  1000.00000
# 14  jgi|YarliW29_1|1096  jgi|YarliW29_1|1096    T209    71.26700
# 15  jgi|YarliW29_1|1103  jgi|YarliW29_1|1103     S46    81.29900
# 16  jgi|YarliW29_1|1115  jgi|YarliW29_1|1115    T247  1000.00000
# 17  jgi|YarliW29_1|1124  jgi|YarliW29_1|1124    S738  1000.00000
# 18  jgi|YarliW29_1|1205  jgi|YarliW29_1|1205     S48     0.00002
# 19  jgi|YarliW29_1|1205  jgi|YarliW29_1|1205     S71     0.00000
#
#                            id  Total missingness  Oscillation_24 missingness  \
# 0    jgi|YarliW29_1|1012@T748                 18                           0
# 1   jgi|YarliW29_1|1029@S1108                 18                           0
# 2    jgi|YarliW29_1|1029@S212                 36                           3
# 3    jgi|YarliW29_1|1029@S225                  0                           0
# 4    jgi|YarliW29_1|1029@S368                 18                           3
# 5     jgi|YarliW29_1|1029@S49                  5                           0
# 6    jgi|YarliW29_1|1029@S559                 49                           3
# 7     jgi|YarliW29_1|1029@S64                 37                           3
# 8    jgi|YarliW29_1|1049@T925                  1                           0
# 9    jgi|YarliW29_1|1051@S540                 19                           3
# 10   jgi|YarliW29_1|1051@T191                 18                           0
# 11   jgi|YarliW29_1|1058@S120                 36                           3
# 12   jgi|YarliW29_1|1064@S131                 41                           3
# 13    jgi|YarliW29_1|1077@S61                 18                           0
# 14   jgi|YarliW29_1|1096@T209                 36                           3
# 15    jgi|YarliW29_1|1103@S46                 36                           3
# 16   jgi|YarliW29_1|1115@T247                 36                           3
# 17   jgi|YarliW29_1|1124@S738                 36                           3
# 18    jgi|YarliW29_1|1205@S48                 41                           3
# 19    jgi|YarliW29_1|1205@S71                 36                           3
#
#     Oscillation_3.5 missingness  ...    kogid  \
# 0                             0  ...  KOG4347
# 1                             0  ...      NaN
# 2                             3  ...      NaN
# 3                             0  ...      NaN
# 4                             3  ...      NaN
# 5                             1  ...      NaN
# 6                             3  ...      NaN
# 7                             3  ...      NaN
# 8                             1  ...  KOG2161
# 9                             3  ...  KOG0903
# 10                            0  ...  KOG0903
# 11                            3  ...      NaN
# 12                            3  ...  KOG0235
# 13                            0  ...  KOG2734
# 14                            3  ...  KOG3346
# 15                            3  ...      NaN
# 16                            3  ...  KOG1350
# 17                            3  ...  KOG0188
# 18                            3  ...  KOG0592
# 19                            3  ...  KOG0592
#
#                                            kogdefline  \
# 0                       GTPase-activating protein VRP
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                       Glucosidase I
# 9   Phosphatidylinositol 4-kinase, involved in int...
# 10  Phosphatidylinositol 4-kinase, involved in int...
# 11                                                NaN
# 12                            Phosphoglycerate mutase
# 13                  Uncharacterized conserved protein
# 14           Phosphatidylethanolamine binding protein
# 15                                                NaN
# 16               F0F1-type ATP synthase, beta subunit
# 17                             Alanyl-tRNA synthetase
# 18  3-phosphoinositide-dependent protein kinase (P...
# 19  3-phosphoinositide-dependent protein kinase (P...
#
#                                              kogClass  \
# 0                    General function prediction only
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8               Carbohydrate transport and metabolism
# 9   Signal transduction mechanisms, Intracellular ...
# 10  Signal transduction mechanisms, Intracellular ...
# 11                                                NaN
# 12              Carbohydrate transport and metabolism
# 13                                   Function unknown
# 14                   General function prediction only
# 15                                                NaN
# 16                   Energy production and conversion
# 17    Translation, ribosomal structure and biogenesis
# 18                     Signal transduction mechanisms
# 19                     Signal transduction mechanisms
#
#                               kogGroup  early/late  early/late_ANOVA_p  \
# 0                 POORLY CHARACTERIZED   -0.856726                 NaN
# 1                                  NaN   -0.724107                 NaN
# 2                                  NaN   -1.081031                 NaN
# 3                                  NaN   -1.023307                 NaN
# 4                                  NaN   -0.196793                 NaN
# 5                                  NaN   -0.656691                 NaN
# 6                                  NaN   -0.129958                 NaN
# 7                                  NaN   -1.161774                 NaN
# 8                           METABOLISM   -1.337130                 NaN
# 9     CELLULAR PROCESSES AND SIGNALING   -0.705503                 NaN
# 10    CELLULAR PROCESSES AND SIGNALING    0.163752                 NaN
# 11                                 NaN   -0.260584                 NaN
# 12                          METABOLISM   -0.120233                 NaN
# 13                POORLY CHARACTERIZED   -0.476474                 NaN
# 14                POORLY CHARACTERIZED    0.517389                 NaN
# 15                                 NaN   -0.829052                 NaN
# 16                          METABOLISM   -1.481107                 NaN
# 17  INFORMATION STORAGE AND PROCESSING   -0.452256                 NaN
# 18    CELLULAR PROCESSES AND SIGNALING    2.054248                 NaN
# 19    CELLULAR PROCESSES AND SIGNALING    1.183146                 NaN
#
#     low/control_late_combined  low/control_late_combined_ANOVA_p  \
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                    0.394520                                NaN
# 4                   -1.030425                                NaN
# 5                   -0.311865                                NaN
# 6                         NaN                                NaN
# 7                         NaN                                NaN
# 8                   -1.404896                                NaN
# 9                   -1.072325                                NaN
# 10                        NaN                                NaN
# 11                        NaN                                NaN
# 12                        NaN                                NaN
# 13                        NaN                                NaN
# 14                        NaN                                NaN
# 15                        NaN                                NaN
# 16                        NaN                                NaN
# 17                        NaN                                NaN
# 18                        NaN                                NaN
# 19                        NaN                                NaN
#
#     osc/control_late_cominbed  osc/control_late_cominbedANOVA_p
# 0                    0.325942                               NaN
# 1                   -0.190275                               NaN
# 2                         NaN                               NaN
# 3                   -0.234903                               NaN
# 4                         NaN                               NaN
# 5                   -0.225629                               NaN
# 6                         NaN                               NaN
# 7                         NaN                               NaN
# 8                    0.953048                               NaN
# 9                         NaN                               NaN
# 10                   1.404799                               NaN
# 11                        NaN                               NaN
# 12                        NaN                               NaN
# 13                  -0.034321                               NaN
# 14                        NaN                               NaN
# 15                        NaN                               NaN
# 16                        NaN                               NaN
# 17                        NaN                               NaN
# 18                        NaN                               NaN
# 19                        NaN                               NaN
#
# [20 rows x 199 columns]

# %%
merged_df
# Out:
#                                                Peptide  \
# 0                          K.LAEENTSEAIFDTPDT#DEDDAK.S
# 1                                        R.SNS#MSAFR.M
# 2                                   R.RGS#MTSTTTNTER.T
# 3                R.THS#LTSTTTTIK.R; R.THS#LTSTTTTIKR.M
# 4                    R.TLS#PM*KPALK.M; R.TLS#PMKPALK.M
# ..                                                 ...
# 452                  R.SYTDELQDTQVLEDPAES#DEEEEPVISR.K
# 453                                     R.AAS#PSPVFR.S
# 454                                R.SSS#QSNIASIGFGK.W
# 455                                     K.RS#PEASPEK.R
# 456  K.GLADM*FS#DEEEQPAPVEQR.N; K.GLADMFS#DEEEQPAPV...
#
#                           Site              UniProt              Protein  \
# 0     jgi|YarliW29_1|1012@T748  jgi|YarliW29_1|1012  jgi|YarliW29_1|1012
# 1    jgi|YarliW29_1|1029@S1108  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029
# 2     jgi|YarliW29_1|1029@S212  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029
# 3     jgi|YarliW29_1|1029@S225  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029
# 4     jgi|YarliW29_1|1029@S368  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029
# ..                         ...                  ...                  ...
# 452    jgi|YarliW29_1|868@S383   jgi|YarliW29_1|868   jgi|YarliW29_1|868
# 453    jgi|YarliW29_1|930@S188   jgi|YarliW29_1|930   jgi|YarliW29_1|930
# 454    jgi|YarliW29_1|965@S260   jgi|YarliW29_1|965   jgi|YarliW29_1|965
# 455     jgi|YarliW29_1|971@S12   jgi|YarliW29_1|971   jgi|YarliW29_1|971
# 456    jgi|YarliW29_1|994@S150   jgi|YarliW29_1|994   jgi|YarliW29_1|994
#
#     Residue    AScore                         id  Total missingness  \
# 0      T748    43.406   jgi|YarliW29_1|1012@T748                 18
# 1     S1108    22.217  jgi|YarliW29_1|1029@S1108                 18
# 2      S212    45.543   jgi|YarliW29_1|1029@S212                 36
# 3      S225    28.746   jgi|YarliW29_1|1029@S225                  0
# 4      S368  1000.000   jgi|YarliW29_1|1029@S368                 18
# ..      ...       ...                        ...                ...
# 452    S383   138.590    jgi|YarliW29_1|868@S383                 49
# 453    S188    39.967    jgi|YarliW29_1|930@S188                 36
# 454    S260     0.000    jgi|YarliW29_1|965@S260                 18
# 455     S12    83.653     jgi|YarliW29_1|971@S12                 18
# 456    S150  1000.000    jgi|YarliW29_1|994@S150                  0
#
#      Oscillation_24 missingness  Oscillation_3.5 missingness  ...    kogid  \
# 0                             0                            0  ...  KOG4347
# 1                             0                            0  ...      NaN
# 2                             3                            3  ...      NaN
# 3                             0                            0  ...      NaN
# 4                             3                            3  ...      NaN
# ..                          ...                          ...  ...      ...
# 452                           3                            3  ...  KOG1274
# 453                           3                            3  ...  KOG3780
# 454                           3                            3  ...  KOG0590
# 455                           0                            0  ...  KOG4011
# 456                           0                            0  ...  KOG1856
#
#                                             kogdefline  \
# 0                        GTPase-activating protein VRP
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 452                                WD40 repeat protein
# 453            Thioredoxin binding protein TBP-2/VDUP1
# 454  Checkpoint kinase and related serine/threonine...
# 455  Transcription initiation factor TFIID, subunit...
# 456               Transcription elongation factor SPT6
#
#                                               kogClass  \
# 0                     General function prediction only
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 452                   General function prediction only
# 453                   General function prediction only
# 454  Cell cycle control, cell division, chromosome ...
# 455                                      Transcription
# 456                    RNA processing and modification
#
#                                kogGroup  early/late  early/late_ANOVA_p  \
# 0                  POORLY CHARACTERIZED   -0.856726                 NaN
# 1                                   NaN   -0.724107                 NaN
# 2                                   NaN   -1.081031                 NaN
# 3                                   NaN   -1.023307                 NaN
# 4                                   NaN   -0.196793                 NaN
# ..                                  ...         ...                 ...
# 452                POORLY CHARACTERIZED   -0.296738                 NaN
# 453                POORLY CHARACTERIZED   -1.108683                 NaN
# 454                          METABOLISM   -1.021961                 NaN
# 455  INFORMATION STORAGE AND PROCESSING   -1.277760                 NaN
# 456  INFORMATION STORAGE AND PROCESSING   -0.363352                 NaN
#
#      low/control_late_combined  low/control_late_combined_ANOVA_p  \
# 0                          NaN                                NaN
# 1                          NaN                                NaN
# 2                          NaN                                NaN
# 3                     0.394520                                NaN
# 4                    -1.030425                                NaN
# ..                         ...                                ...
# 452                        NaN                                NaN
# 453                        NaN                                NaN
# 454                  -0.244271                                NaN
# 455                        NaN                                NaN
# 456                  -0.084112                                NaN
#
#      osc/control_late_cominbed  osc/control_late_cominbedANOVA_p
# 0                     0.325942                               NaN
# 1                    -0.190275                               NaN
# 2                          NaN                               NaN
# 3                    -0.234903                               NaN
# 4                          NaN                               NaN
# ..                         ...                               ...
# 452                        NaN                               NaN
# 453                        NaN                               NaN
# 454                        NaN                               NaN
# 455                   0.287181                               NaN
# 456                   0.602162                               NaN
#
# [457 rows x 199 columns]

# %% [markdown]
# ### optional save. This is final file with proteomic details.

# %%
merged_df["proteinId"] = merged_df["Site"].str.extract(r"YarliW29_1\|(\d+)@")
merged_df['proteinID'] = merged_df['proteinId'].copy()
merged_df['#proteinId'] = merged_df['proteinId'].copy()

# %%
# merged_df.to_csv('../Data/PPI_yarrowia_REDOX_Global/result/PPI_yarrowia_redox_wAnnotations_fullLog2FC.csv')

# %%
prot_control_vs_oscillation_late_combined_stats.head()
# Out:
#                         Site  Biostat2L_29_Oscillation_24  \
# 0   jgi|YarliW29_1|1012@T748                    13.921812
# 1  jgi|YarliW29_1|1029@S1108                    14.687903
# 2   jgi|YarliW29_1|1029@S212                          NaN
# 3   jgi|YarliW29_1|1029@S225                    18.450295
# 4   jgi|YarliW29_1|1029@S368                          NaN
#
#    Biostat2L_29_Oscillation_48  Biostat2L_29_Oscillation_72  \
# 0                    14.148031                    13.556648
# 1                    14.764124                    14.143469
# 2                          NaN                          NaN
# 3                    19.224261                    19.409963
# 4                          NaN                          NaN
#
#    Biostat2L_30_Control_24  Biostat2L_30_Control_48  Biostat2L_30_Control_72  \
# 0                13.787372                14.073101                13.139452
# 1                14.986167                15.273361                15.055229
# 2                14.699762                14.329749                14.208659
# 3                19.030934                19.312877                19.436340
# 4                17.105610                17.644165                17.407525
#
#    Biostat2L_30_Oscillation_24  Biostat2L_30_Oscillation_48  \
# 0                    13.728869                    13.957324
# 1                    14.749323                    14.903341
# 2                          NaN                          NaN
# 3                    18.449405                    19.105002
# 4                          NaN                          NaN
#
#    Biostat2L_30_Oscillation_72  ...  Biostat2L_31_Oscillation_24  \
# 0                    14.072943  ...                    13.943018
# 1                    14.317786  ...                    15.112586
# 2                          NaN  ...                          NaN
# 3                    19.042270  ...                    18.343261
# 4                          NaN  ...                          NaN
#
#    Biostat2L_31_Oscillation_48  Biostat2L_31_Oscillation_72  \
# 0                    13.816518                    14.655760
# 1                    15.277582                    15.195779
# 2                          NaN                          NaN
# 3                    19.083977                    19.094777
# 4                          NaN                          NaN
#
#    Biostat2L_32_Control_24  Biostat2L_32_Control_48  Biostat2L_32_Control_72  \
# 0                13.571825                13.513770                13.580512
# 1                14.785028                14.819879                14.811235
# 2                13.936396                14.696044                14.338431
# 3                18.683641                19.453357                19.281014
# 4                16.853587                17.659650                17.554265
#
#                      Protein  ANOVA_p  proteinID    log2FC
# 0   jgi|YarliW29_1|1012@T748      NaN       1012  0.325942
# 1  jgi|YarliW29_1|1029@S1108      NaN       1029 -0.190275
# 2   jgi|YarliW29_1|1029@S212      NaN       1029       NaN
# 3   jgi|YarliW29_1|1029@S225      NaN       1029 -0.234903
# 4   jgi|YarliW29_1|1029@S368      NaN       1029       NaN
#
# [5 rows x 23 columns]

# %%
prot_control_vs_oscillation_late_combined_stats_withAnnote = pd.merge(prot_control_vs_oscillation_late_combined_stats, 
                                                                      merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')
# prot_control_vs_oscillation_24h_stats_withAnnote = pd.merge(prot_control_vs_oscillation_24h_stats, 
                                                                      # merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')

# %%
# prot_control_vs_oscillation_late_combined_stats_withAnnote.to_csv('control_vs_oscillation_late.csv')
# prot_control_vs_oscillation_24h_stats_withAnnote.to_csv('control_vs_oscillation_24h.csv')

# %% [markdown]
# ### Volcano plot comparing low vs high,
# all late (increase means increased in low)

# %%
# dataset_late_combined = prot_control_vs_oscillation_late_combined_stats_withAnnote[['log2FC', 'ANOVA_padj']].copy()
# dataset_24h = prot_control_vs_oscillation_24h_stats_withAnnote[['log2FC', 'ANOVA_padj']].copy()

# %%
log2FC_threshold = np.log2(1.3)

# %%
# # subset the log2FC and the P_value for this dataset. 
# dataset_late_combined.columns = ['log2FC','P_value']

# # obtain the -logP_adj for the dataset. 
# dataset_late_combined['-logP_adj'] = -np.log10(dataset_late_combined['P_value'])

# # set a class for up (1) or down (-1) proteins. 
# dataset_late_combined['class'] = 0
# dataset_late_combined.loc[(dataset_late_combined['log2FC']>log2FC_threshold)&(dataset_late_combined['-logP_adj']>-np.log10(0.05)),'class'] = 1
# dataset_late_combined.loc[(dataset_late_combined['log2FC']<-log2FC_threshold)&(dataset_late_combined['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
# # subset the log2FC and the P_value for this dataset. 
# dataset_24h.columns = ['log2FC','P_value']

# # obtain the -logP_adj for the dataset. 
# dataset_24h['-logP_adj'] = -np.log10(dataset_24h['P_value'])

# # set a class for up (1) or down (-1) proteins. 
# dataset_24h['class'] = 0
# dataset_24h.loc[(dataset_24h['log2FC']>log2FC_threshold)&(dataset_24h['-logP_adj']>-np.log10(0.05)),'class'] = 1
# dataset_24h.loc[(dataset_24h['log2FC']<-log2FC_threshold)&(dataset_24h['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
# volcano_plot(dataset_late_combined)

# %%
# volcano_plot(dataset_24h)

# %% [markdown]
# ## Compare Oscillation vs Low. Start with all late.

# %% [markdown]
# ### prep for p-values.

# %%
prot = annotated_phospho[sample_ids_prot_redox]
prot['Protein'] = annotated_phospho['Site']
prot.index = annotated_phospho['Site']
# drop oscillations.
# prot_control_vs_oscillation_24h = prot.drop(prot.columns[prot.columns.str.contains("Low")], axis=1)
prot_oscillation_vs_low_late_combined = prot.drop(prot.columns[prot.columns.str.contains("Control")], axis=1)


# drop early timepoints. 
prot_oscillation_vs_low_late_combined = prot_oscillation_vs_low_late_combined.drop(prot_oscillation_vs_low_late_combined.columns[
    prot_oscillation_vs_low_late_combined.columns.str.contains("5.5|3.5|4.5")], axis=1)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/3842424781.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prot['Protein'] = annotated_phospho['Site']

# %%
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))

# %%
# group for mapping in annova. 

condition_series_OscvsLowLateCombined = pd.Series(prot_oscillation_vs_low_late_combined.columns).map(prot_condition_dict)
condition_series_OscvsLowLateCombined.index = prot_oscillation_vs_low_late_combined.columns
condition_series_OscvsLowLateCombined
# Out:
# Biostat2L_29_Oscillation_24    Oscillation
# Biostat2L_29_Oscillation_48    Oscillation
# Biostat2L_29_Oscillation_72    Oscillation
# Biostat2L_30_Oscillation_24    Oscillation
# Biostat2L_30_Oscillation_48    Oscillation
# Biostat2L_30_Oscillation_72    Oscillation
# Biostat2L_31_Oscillation_24    Oscillation
# Biostat2L_31_Oscillation_48    Oscillation
# Biostat2L_31_Oscillation_72    Oscillation
# Biostat2L_32_Low_24                    Low
# Biostat2L_32_Low_48                    Low
# Biostat2L_32_Low_72                    Low
# Biostat2L_33_Low_24                    Low
# Biostat2L_33_Low_48                    Low
# Biostat2L_33_Low_72                    Low
# Biostat2L_34_Low_24                    Low
# Biostat2L_34_Low_48                    Low
# Biostat2L_34_Low_72                    Low
# Protein                                NaN
# dtype: object

# %%
# late stats.
prot_OscvsLowLateCombined_stats = global_stats_calc_prot(prot_oscillation_vs_low_late_combined,
                                                                         condition_series_OscvsLowLateCombined)
# Out:
# Skipping protein jgi|YarliW29_1|1012@T748 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S1108 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S212 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S225 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S368 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S49 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S559 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1049@T925 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1051@S540 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1051@T191 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1058@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1064@S131 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1077@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1096@T209 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1103@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1115@T247 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1124@S738 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S71 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@T202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1332@S228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@S243 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@T769 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S3768 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S4408 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1380@S273 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1394@S24 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1414@T792 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S578 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S581 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1449@T166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@T83 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@T86 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1516@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1516@S672 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1519@T282 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1524@S94 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1529@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S283 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S331 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S333 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S337 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S350 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S367 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1625@T19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1633@T65 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1648@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S1066 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S393 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1667@S386 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1686@S938 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1686@T946 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S504 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1707@S231 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1724@T250 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1742@S595 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1813@S177 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1817@S427 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1834@S267 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1834@T304 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1864@S49 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1871@S14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1882@S33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1893@S196 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1893@S516 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1897@S577 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1899@S1371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1904@T245 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1914@S263 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1927@S555 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1927@S621 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1930@T166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1969@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1981@T259 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1981@T910 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2062@S655 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2071@S42 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2075@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2089@T482 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|208@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2119@S6 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2130@S364 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2186@T246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2191@S316 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|21@S855 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2200@T460 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2213@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S80 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2250@S14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2263@S203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2270@S40 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@T506 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S217 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S285 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@T261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2322@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2322@T382 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2342@S565 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2348@S62 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S68 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S98 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2355@T200 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2355@Y314 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2358@S501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2364@S112 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2398@S311 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2424@S459 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2465@S105 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2465@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2465@T115 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2478@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2492@T6 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2502@S65 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2502@T127 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2509@T70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2561@S215 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|25@S53 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S20 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S274 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S50 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2620@S157 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@S1170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@S1178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@T1167 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@T837 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|263@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2679@S135 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2817@T491 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2823@S371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2868@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2872@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2888@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2907@Y583 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2916@S440 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2936@S52 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@S210 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2995@S437 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3028@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3038@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3038@T704 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3072@S21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3136@S1280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3136@S825 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3160@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3185@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@S219 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@Y222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3243@S653 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S38 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|324@S1275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3260@S1035 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3260@S845 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3269@T15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@Y294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3304@S130 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3304@T120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3304@T456 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3310@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3457@T327 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3485@Y1084 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3495@T170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3499@T51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|34@S166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S303 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S305 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S308 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3613@S56 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3613@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3647@Y359 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3658@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3667@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3669@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3694@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3723@S347 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3762@S65 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3778@S180 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3868@S224 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3873@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3903@S198 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3944@S654 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3944@S702 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4000@T20 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4054@S184 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|409@S558 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4109@T501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S547 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S551 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@T489 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@T493 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4187@S253 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4199@S147 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4199@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4229@S299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4253@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4271@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4271@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|428@T147 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4301@T18 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4387@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4400@S83 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S860 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S872 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|443@S767 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S149 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4446@T126 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4471@S160 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4480@S1176 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4496@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4508@S510 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4510@S618 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@S174 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@T280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4606@S629 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4609@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4616@S162 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4616@S202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S150 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S250 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4644@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4661@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4668@S529 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|46@S222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4721@T100 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4737@T33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4756@S449 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S1018 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S780 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@S230 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4774@S146 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4776@T140 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4790@S561 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4802@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4809@S421 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4928@S246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4968@T307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4976@S398 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5015@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5052@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5060@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@S479 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T162 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T484 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@S1831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@T1834 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5112@S456 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5112@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5133@S575 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5190@Y266 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5213@S262 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5213@T111 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5232@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|524@S404 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5280@S669 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5296@T27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5298@S431 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5298@S470 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5313@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5319@S271 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5335@Y107 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5341@S38 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5366@T521 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5414@S276 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5449@S23 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5454@S357 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5462@S261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5470@S419 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5489@S476 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5512@S310 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5533@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5539@S17 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T514 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5602@S956 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5612@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|561@S66 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5620@S145 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5670@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5698@S237 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5738@S66 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5741@S628 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5769@S13 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5794@T46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5817@T251 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5877@Y173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5897@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5899@T560 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5913@S1039 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5913@S1047 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5917@T11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5931@T345 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5942@S179 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5972@S71 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5974@S326 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5@S515 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6070@S662 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6074@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6127@T1122 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6130@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6140@S170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6140@T136 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6151@S158 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6151@T69 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6157@S592 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6199@S530 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6240@T173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6283@T831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6291@S414 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6294@S330 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6299@S86 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6322@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6325@S142 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6333@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6351@S267 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S190 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@S294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6382@S292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6402@S301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6403@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@S5 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@T2 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6429@S737 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|642@S41 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6434@S366 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6435@T1244 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6437@S472 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6447@S854 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6454@S275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6460@T10 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6465@S496 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|647@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6523@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6569@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6569@T47 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6588@S335 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6588@S358 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@T117 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6656@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6686@S16 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6686@S51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|668@S169 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6704@S25 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T500 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T514 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6719@S59 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6743@T371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6755@S153 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6756@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6770@S375 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6800@S635 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6825@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6848@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|684@S109 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6859@S67 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6865@T612 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6877@T741 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|688@T46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6907@S433 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@S496 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@T413 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6954@S268 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@S464 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@T165 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7022@T356 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7026@S740 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7086@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7108@S642 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7108@T640 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|711@S1050 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|711@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7128@S113 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7132@S351 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7178@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7198@T593 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7213@T41 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|721@S325 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7255@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7263@T321 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7264@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S846 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T651 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7307@T626 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7363@S75 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7368@S70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7370@S494 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7376@T531 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7380@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7386@T318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7395@S287 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S189 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S193 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7457@S596 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7506@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7531@S207 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7567@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@S70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@S63 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@T144 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7617@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7633@T278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7692@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7696@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7719@S711 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7731@S598 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7735@S132 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7778@S281 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7796@T368 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7864@T203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T424 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7877@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|78@S172 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|791@T45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|828@S278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|868@S383 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|930@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|965@S260 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|971@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|994@S150 due to insufficient data in some groups.
# No ANOVA_p values returned

# %%
# Extract the number between "YarliW29_1|" and "@GLB" using regex.
prot_OscvsLowLateCombined_stats["proteinID"] = prot_OscvsLowLateCombined_stats["Site"].str.extract(r"YarliW29_1\|(\d+)@")



# Convert the extracted number to integer (if needed).
prot_OscvsLowLateCombined_stats["proteinID"] = prot_OscvsLowLateCombined_stats["proteinID"].astype(int)

# %% [markdown]
# ### calculate log2FC

# %%
oscLateCombinedLate = prot_OscvsLowLateCombined_stats.loc[:, prot_OscvsLowLateCombined_stats.columns[
    prot_OscvsLowLateCombined_stats.columns.str.contains("Oscillation")]]


oscLateCombinedLate.head()
# Out:
#    Biostat2L_29_Oscillation_24  Biostat2L_29_Oscillation_48  \
# 0                    13.921812                    14.148031
# 1                    14.687903                    14.764124
# 2                          NaN                          NaN
# 3                    18.450295                    19.224261
# 4                          NaN                          NaN
#
#    Biostat2L_29_Oscillation_72  Biostat2L_30_Oscillation_24  \
# 0                    13.556648                    13.728869
# 1                    14.143469                    14.749323
# 2                          NaN                          NaN
# 3                    19.409963                    18.449405
# 4                          NaN                          NaN
#
#    Biostat2L_30_Oscillation_48  Biostat2L_30_Oscillation_72  \
# 0                    13.957324                    14.072943
# 1                    14.903341                    14.317786
# 2                          NaN                          NaN
# 3                    19.105002                    19.042270
# 4                          NaN                          NaN
#
#    Biostat2L_31_Oscillation_24  Biostat2L_31_Oscillation_48  \
# 0                    13.943018                    13.816518
# 1                    15.112586                    15.277582
# 2                          NaN                          NaN
# 3                    18.343261                    19.083977
# 4                          NaN                          NaN
#
#    Biostat2L_31_Oscillation_72
# 0                    14.655760
# 1                    15.195779
# 2                          NaN
# 3                    19.094777
# 4                          NaN

# %%
lowLateCombined = prot_OscvsLowLateCombined_stats.loc[:, prot_OscvsLowLateCombined_stats.columns[prot_OscvsLowLateCombined_stats.columns.str.contains("Low")]]
lowLateCombined.head()
# Out:
#    Biostat2L_32_Low_24  Biostat2L_32_Low_48  Biostat2L_32_Low_72  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3            19.143275            19.618330            19.928461
# 4            16.613736            16.329088            16.183309
#
#    Biostat2L_33_Low_24  Biostat2L_33_Low_48  Biostat2L_33_Low_72  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3            19.560714            19.514274            19.683966
# 4            16.512579            16.373739            15.780137
#
#    Biostat2L_34_Low_24  Biostat2L_34_Low_48  Biostat2L_34_Low_72
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3            19.120369            19.430804            19.867831
# 4            17.059593            16.416683            16.037147

# %%
# gives the increase of the first. 
prot_OscvsLowLateCombined_stats['log2FC_Osc_vs_low_Late']=log2FC_function(oscLateCombinedLate, lowLateCombined)

# %%
df_to_merge = pd.DataFrame()
df_to_merge['osc/low_late_cominbed'] = prot_OscvsLowLateCombined_stats['log2FC_Osc_vs_low_Late']
df_to_merge['Site'] = prot_OscvsLowLateCombined_stats['Site']
# df_to_merge['osc/low_late_cominbedANOVA_padj'] = prot_OscvsLowLateCombined_stats['ANOVA_padj']
df_to_merge['osc/low_late_cominbedANOVA_p'] = prot_OscvsLowLateCombined_stats['ANOVA_p']

# %%
merged_df
# Out:
#                                                Peptide  \
# 0                          K.LAEENTSEAIFDTPDT#DEDDAK.S
# 1                                        R.SNS#MSAFR.M
# 2                                   R.RGS#MTSTTTNTER.T
# 3                R.THS#LTSTTTTIK.R; R.THS#LTSTTTTIKR.M
# 4                    R.TLS#PM*KPALK.M; R.TLS#PMKPALK.M
# ..                                                 ...
# 452                  R.SYTDELQDTQVLEDPAES#DEEEEPVISR.K
# 453                                     R.AAS#PSPVFR.S
# 454                                R.SSS#QSNIASIGFGK.W
# 455                                     K.RS#PEASPEK.R
# 456  K.GLADM*FS#DEEEQPAPVEQR.N; K.GLADMFS#DEEEQPAPV...
#
#                           Site              UniProt              Protein  \
# 0     jgi|YarliW29_1|1012@T748  jgi|YarliW29_1|1012  jgi|YarliW29_1|1012
# 1    jgi|YarliW29_1|1029@S1108  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029
# 2     jgi|YarliW29_1|1029@S212  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029
# 3     jgi|YarliW29_1|1029@S225  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029
# 4     jgi|YarliW29_1|1029@S368  jgi|YarliW29_1|1029  jgi|YarliW29_1|1029
# ..                         ...                  ...                  ...
# 452    jgi|YarliW29_1|868@S383   jgi|YarliW29_1|868   jgi|YarliW29_1|868
# 453    jgi|YarliW29_1|930@S188   jgi|YarliW29_1|930   jgi|YarliW29_1|930
# 454    jgi|YarliW29_1|965@S260   jgi|YarliW29_1|965   jgi|YarliW29_1|965
# 455     jgi|YarliW29_1|971@S12   jgi|YarliW29_1|971   jgi|YarliW29_1|971
# 456    jgi|YarliW29_1|994@S150   jgi|YarliW29_1|994   jgi|YarliW29_1|994
#
#     Residue    AScore                         id  Total missingness  \
# 0      T748    43.406   jgi|YarliW29_1|1012@T748                 18
# 1     S1108    22.217  jgi|YarliW29_1|1029@S1108                 18
# 2      S212    45.543   jgi|YarliW29_1|1029@S212                 36
# 3      S225    28.746   jgi|YarliW29_1|1029@S225                  0
# 4      S368  1000.000   jgi|YarliW29_1|1029@S368                 18
# ..      ...       ...                        ...                ...
# 452    S383   138.590    jgi|YarliW29_1|868@S383                 49
# 453    S188    39.967    jgi|YarliW29_1|930@S188                 36
# 454    S260     0.000    jgi|YarliW29_1|965@S260                 18
# 455     S12    83.653     jgi|YarliW29_1|971@S12                 18
# 456    S150  1000.000    jgi|YarliW29_1|994@S150                  0
#
#      Oscillation_24 missingness  Oscillation_3.5 missingness  ...  \
# 0                             0                            0  ...
# 1                             0                            0  ...
# 2                             3                            3  ...
# 3                             0                            0  ...
# 4                             3                            3  ...
# ..                          ...                          ...  ...
# 452                           3                            3  ...
# 453                           3                            3  ...
# 454                           3                            3  ...
# 455                           0                            0  ...
# 456                           0                            0  ...
#
#                                               kogClass  \
# 0                     General function prediction only
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 452                   General function prediction only
# 453                   General function prediction only
# 454  Cell cycle control, cell division, chromosome ...
# 455                                      Transcription
# 456                    RNA processing and modification
#
#                                kogGroup  early/late  early/late_ANOVA_p  \
# 0                  POORLY CHARACTERIZED   -0.856726                 NaN
# 1                                   NaN   -0.724107                 NaN
# 2                                   NaN   -1.081031                 NaN
# 3                                   NaN   -1.023307                 NaN
# 4                                   NaN   -0.196793                 NaN
# ..                                  ...         ...                 ...
# 452                POORLY CHARACTERIZED   -0.296738                 NaN
# 453                POORLY CHARACTERIZED   -1.108683                 NaN
# 454                          METABOLISM   -1.021961                 NaN
# 455  INFORMATION STORAGE AND PROCESSING   -1.277760                 NaN
# 456  INFORMATION STORAGE AND PROCESSING   -0.363352                 NaN
#
#      low/control_late_combined  low/control_late_combined_ANOVA_p  \
# 0                          NaN                                NaN
# 1                          NaN                                NaN
# 2                          NaN                                NaN
# 3                     0.394520                                NaN
# 4                    -1.030425                                NaN
# ..                         ...                                ...
# 452                        NaN                                NaN
# 453                        NaN                                NaN
# 454                  -0.244271                                NaN
# 455                        NaN                                NaN
# 456                  -0.084112                                NaN
#
#      osc/control_late_cominbed  osc/control_late_cominbedANOVA_p  proteinID  \
# 0                     0.325942                               NaN       1012
# 1                    -0.190275                               NaN       1029
# 2                          NaN                               NaN       1029
# 3                    -0.234903                               NaN       1029
# 4                          NaN                               NaN       1029
# ..                         ...                               ...        ...
# 452                        NaN                               NaN        868
# 453                        NaN                               NaN        930
# 454                        NaN                               NaN        965
# 455                   0.287181                               NaN        971
# 456                   0.602162                               NaN        994
#
#      #proteinId
# 0          1012
# 1          1029
# 2          1029
# 3          1029
# 4          1029
# ..          ...
# 452         868
# 453         930
# 454         965
# 455         971
# 456         994
#
# [457 rows x 201 columns]

# %%
prot_control_vs_oscillation_late_combined_stats_withAnnote.columns
# Out:
# Index(['Site', 'Biostat2L_29_Oscillation_24', 'Biostat2L_29_Oscillation_48',
#        'Biostat2L_29_Oscillation_72', 'Biostat2L_30_Control_24',
#        'Biostat2L_30_Control_48', 'Biostat2L_30_Control_72',
#        'Biostat2L_30_Oscillation_24', 'Biostat2L_30_Oscillation_48',
#        'Biostat2L_30_Oscillation_72', 'Biostat2L_31_Control_24',
#        'Biostat2L_31_Control_48', 'Biostat2L_31_Control_72',
#        'Biostat2L_31_Oscillation_24', 'Biostat2L_31_Oscillation_48',
#        'Biostat2L_31_Oscillation_72', 'Biostat2L_32_Control_24',
#        'Biostat2L_32_Control_48', 'Biostat2L_32_Control_72', 'Protein',
#        'ANOVA_p', 'proteinID', 'log2FC', '#proteinId', 'kogid', 'kogdefline',
#        'kogClass', 'kogGroup', 'definition', 'catalyticActivity', 'pathway',
#        'pathway_class', 'pathway_type', 'ecNum', 'cofactors', 'gotermId',
#        'gotermType', 'goName', 'goAcc'],
#       dtype='object')

# %% [markdown]
# # multiple Yarrowia gene annotations. mapping/annotations

# %%
prot_control_late_vs_early_combined_stats_withAnnote['ANOVA_padj']=pd.Series(np.nan)
prot_control_vs_low_late_combined_stats_withAnnote['ANOVA_padj']=pd.Series(np.nan)
prot_control_vs_oscillation_late_combined_stats_withAnnote['ANOVA_padj']=pd.Series(np.nan)

# %%
def combine_dataframes(dataframes, names):
    """
    Combine multiple dataframes to create a single dataframe tracking provenance 
    of `ANOVA_p`, `ANOVA_padj`, `log2FC` while merging overlapping information.
    
    Args:
        dataframes (list of pd.DataFrame): List of DataFrames to combine.
        names (list of str): Names corresponding to each DataFrame for labeling unique columns.
    
    Returns:
        combined_df (pd.DataFrame): Combined DataFrame.
    """
    # List for renaming and merging
    dataframes_processed = []
    
    for df, name in zip(dataframes, names):
        # Select common and unique columns
        common_cols = ['Site', 'proteinID', '#proteinId', 'definition',
                       'catalyticActivity', 'pathway', 'pathway_class', 'pathway_type',
                       'ecNum', 'cofactors', 'gotermId', 'gotermType', 'goName', 'goAcc']
        
        unique_cols = ['ANOVA_p', 'ANOVA_padj', 'log2FC']
        
        # Rename unique columns to track source
        df_renamed = df[common_cols + unique_cols].copy()
        df_renamed.rename(columns={
            'ANOVA_p': f'ANOVA_p_{name}',
            'ANOVA_padj': f'ANOVA_padj_{name}',
            'log2FC': f'log2FC_{name}'
        }, inplace=True)
        
        # Append processed DataFrame to the list
        dataframes_processed.append(df_renamed)
    
    # Merge all processed DataFrames on common columns using outer join
    combined_df = dataframes_processed[0]
    for df in dataframes_processed[1:]:
        combined_df = pd.merge(combined_df, df, on=['Site', 'proteinID', '#proteinId', 'definition',
                                                    'catalyticActivity', 'pathway', 'pathway_class', 'pathway_type',
                                                    'ecNum', 'cofactors', 'gotermId', 'gotermType', 'goName', 'goAcc'],
                               how='outer')
    
    return combined_df

# Example usage

# Create a list of DataFrames (replace these with your actual DataFrames)
dataframes = [
    prot_control_late_vs_early_combined_stats_withAnnote,

    prot_control_vs_low_late_combined_stats_withAnnote,
    prot_control_vs_oscillation_late_combined_stats_withAnnote
]
for df in dataframes:
    for col in ['Site', 'proteinID', '#proteinId', 'definition', 'catalyticActivity', 'pathway', 
                'pathway_class', 'pathway_type', 'ecNum', 'cofactors', 'gotermId', 'gotermType', 'goName', 'goAcc']:
        df[col] = df[col].astype(str)  # Convert key columns to string

# Create corresponding names for data provenance
names = [
    'late_vs_early_combined',
    'control_vs_low_late',
    'oscillation_late_combined'
]

# Combine all DataFrames into one
combined_df = combine_dataframes(dataframes, names)

# Save the result to a file or inspect it
# combined_df.to_csv("combined_dataframe.csv", index=False)

# %%
combined_df['proteinId'] = combined_df['proteinID'].copy()

# %%
combined_df = pd.merge(combined_df, df_to_merge, left_on='Site',right_on='Site', how='left')

# %%
combined_df['#proteinId'] = combined_df['proteinID'].copy()

# %%
gene_dict = {}

# Step Open and Read the FASTA File
with open('../Data/DNA/W29.fasta', 'r') as fasta_file:
    for line in fasta_file:
        # Check for header lines starting with ">"
        if line.startswith(">"):
            # Extract the relevant fields from the header line
            header_parts = line.strip().split('|')  # Split header by '|'
            gene_id = header_parts[2]  # "1000"
            gene_name = header_parts[3]  # "YALI1_B02228p"
            
            # Map "1000" to "YALI1_B02228p" in the dictionary
            gene_dict[gene_id] = gene_name

# %%
gene_dict
# Out:
# {'1000': 'YALI1_B02228p',
#  '1001': 'YALI1_B02283p',
#  '1002': 'YALI1_B02345p',
#  '1003': 'YALI1_B02375p',
#  '1004': 'YALI1_B02415p',
#  '1005': 'YALI1_B02430p',
#  '1006': 'YALI1_B02465p',
#  '1007': 'YALI1_B02472p',
#  '1008': 'YALI1_B02487p',
#  '1009': 'YALI1_B02496p',
#  '100': 'YALI1_A02775p',
#  '1010': 'YALI1_B02506p',
#  '1011': 'YALI1_B02533p',
#  '1012': 'YALI1_B02550p',
#  '1013': 'YALI1_B02604p',
#  '1014': 'YALI1_B02637p',
#  '1015': 'YALI1_B02642p',
#  '1016': 'YALI1_B02672p',
#  '1017': 'YALI1_B02696p',
#  '1018': 'YALI1_B02717p',
#  '1019': 'YALI1_B02733p',
#  '101': 'YALI1_A02813p',
#  '1020': 'YALI1_B02767p',
#  '1021': 'YALI1_B02781p',
#  '1022': 'YALI1_B02806p',
#  '1023': 'YALI1_B02833p',
#  '1024': 'YALI1_B02850p',
#  '1025': 'YALI1_B02874p',
#  '1026': 'YALI1_B02881p',
#  '1027': 'YALI1_B02910p',
#  '1028': 'YALI1_B02931p',
#  '1029': 'YALI1_B02991p',
#  '102': 'YALI1_A02819p',
#  '1030': 'YALI1_B03021p',
#  '1031': 'YALI1_B03041p',
#  '1032': 'YALI1_B03043p',
#  '1033': 'YALI1_B03085p',
#  '1034': 'YALI1_B03120p',
#  '1035': 'YALI1_B03168p',
#  '1036': 'YALI1_B03198p',
#  '1037': 'YALI1_B03225p',
#  '1038': 'YALI1_B03288p',
#  '1039': 'YALI1_B03290p',
#  '103': 'YALI1_A02833p',
#  '1040': 'YALI1_B03299p',
#  '1041': 'YALI1_B03314p',
#  '1042': 'YALI1_B03324p',
#  '1043': 'YALI1_B03335p',
#  '1044': 'YALI1_B03404p',
#  '1045': 'YALI1_B03429p',
#  '1046': 'YALI1_B03516p',
#  '1047': 'YALI1_B03556p',
#  '1048': 'YALI1_B03610p',
#  '1049': 'YALI1_B03644p',
#  '104': 'YALI1_A02875p',
#  '1050': 'YALI1_B03673p',
#  '1051': 'YALI1_B03719p',
#  '1052': 'YALI1_B03761p',
#  '1053': 'YALI1_B03797p',
#  '1054': 'YALI1_B03807p',
#  '1055': 'YALI1_B03832p',
#  '1056': 'YALI1_B03853p',
#  '1057': 'YALI1_B03910p',
#  '1058': 'YALI1_B03963p',
#  '1059': 'YALI1_B03979p',
#  '105': 'YALI1_A02895p',
#  '1060': 'YALI1_B04007p',
#  '1061': 'YALI1_B04032p',
#  '1062': 'YALI1_B04068p',
#  '1063': 'YALI1_B04123p',
#  '1064': 'YALI1_B04138p',
#  '1065': 'YALI1_B04200p',
#  '1066': 'YALI1_B04212p',
#  '1067': 'YALI1_B04228p',
#  '1068': 'YALI1_B04248p',
#  '1069': 'YALI1_B04274p',
#  '106': 'YALI1_A02947p',
#  '1070': 'YALI1_B04309p',
#  '1071': 'YALI1_B04321p',
#  '1072': 'YALI1_B04370p',
#  '1073': 'YALI1_B04391p',
#  '1074': 'YALI1_B04433p',
#  '1075': 'YALI1_B04466p',
#  '1076': 'YALI1_B04470p',
#  '1077': 'YALI1_B04497p',
#  '1078': 'YALI1_B04502p',
#  '1079': 'YALI1_B04523p',
#  '107': 'YALI1_A02974p',
#  '1080': 'YALI1_B04540p',
#  '1081': 'YALI1_B04559p',
#  '1082': 'YALI1_B04577p',
#  '1083': 'YALI1_B04579p',
#  '1084': 'YALI1_B04589p',
#  '1085': 'YALI1_B04637p',
#  '1086': 'YALI1_B04663p',
#  '1087': 'YALI1_B04690p',
#  '1088': 'YALI1_B04703p',
#  '1089': 'YALI1_B04747p',
#  '108': 'YALI1_A02977p',
#  '1090': 'YALI1_B04753p',
#  '1091': 'YALI1_B04759p',
#  '1092': 'YALI1_B04779p',
#  '1093': 'YALI1_B04781p',
#  '1094': 'YALI1_B04803p',
#  '1095': 'YALI1_B04831p',
#  '1096': 'YALI1_B04853p',
#  '1097': 'YALI1_B04873p',
#  '1098': 'YALI1_B04901p',
#  '1099': 'YALI1_B04937p',
#  '109': 'YALI1_A02998p',
#  '10': 'YALI1_A00252p',
#  '1100': 'YALI1_B04947p',
#  '1101': 'YALI1_B04950p',
#  '1102': 'YALI1_B04974p',
#  '1103': 'YALI1_B05005p',
#  '1104': 'YALI1_B05024p',
#  '1105': 'YALI1_B05043p',
#  '1106': 'YALI1_B05072p',
#  '1107': 'YALI1_B05106p',
#  '1108': 'YALI1_B05185p',
#  '1109': 'YALI1_B05226p',
#  '110': 'YALI1_A03017p',
#  '1110': 'YALI1_B05242p',
#  '1111': 'YALI1_B05282p',
#  '1112': 'YALI1_B05295p',
#  '1113': 'YALI1_B05313p',
#  '1114': 'YALI1_B05350p',
#  '1115': 'YALI1_B05364p',
#  '1116': 'YALI1_B05404p',
#  '1117': 'YALI1_B05420p',
#  '1118': 'YALI1_B05438p',
#  '1119': 'YALI1_B05454p',
#  '111': 'YALI1_A03029p',
#  '1120': 'YALI1_B05483p',
#  '1121': 'YALI1_B05497p',
#  '1122': 'YALI1_B05520p',
#  '1123': 'YALI1_B05522p',
#  '1124': 'YALI1_B05571p',
#  '1125': 'YALI1_B05609p',
#  '1126': 'YALI1_B05639p',
#  '1127': 'YALI1_B05646p',
#  '1128': 'YALI1_B05690p',
#  '1129': 'YALI1_B05698p',
#  '112': 'YALI1_A03069p',
#  '1130': 'YALI1_B05711p',
#  '1131': 'YALI1_B05730p',
#  '1132': 'YALI1_B05762p',
#  '1133': 'YALI1_B05782p',
#  '1134': 'YALI1_B05798p',
#  '1135': 'YALI1_B05830p',
#  '1136': 'YALI1_B05832p',
#  '1137': 'YALI1_B05891p',
#  '1138': 'YALI1_B05947p',
#  '1139': 'YALI1_B05954p',
#  '113': 'YALI1_A03081p',
#  '1140': 'YALI1_B05964p',
#  '1141': 'YALI1_B05971p',
#  '1142': 'YALI1_B05984p',
#  '1143': 'YALI1_B05995p',
#  '1144': 'YALI1_B06015p',
#  '1145': 'YALI1_B06028p',
#  '1146': 'YALI1_B06089p',
#  '1147': 'YALI1_B06110p',
#  '1148': 'YALI1_B06134p',
#  '1149': 'YALI1_B06141p',
#  '114': 'YALI1_A03091p',
#  '1150': 'YALI1_B06146p',
#  '1151': 'YALI1_B06207p',
#  '1152': 'YALI1_B06245p',
#  '1153': 'YALI1_B06264p',
#  '1154': 'YALI1_B06315p',
#  '1155': 'YALI1_B06324p',
#  '1156': 'YALI1_B06328p',
#  '1157': 'YALI1_B06340p',
#  '1158': 'YALI1_B06447p',
#  '1159': 'YALI1_B06487p',
#  '115': 'YALI1_A03116p',
#  '1160': 'YALI1_B06489p',
#  '1161': 'YALI1_B06508p',
#  '1162': 'YALI1_B06514p',
#  '1163': 'YALI1_B06537p',
#  '1164': 'YALI1_B06546p',
#  '1165': 'YALI1_B06607p',
#  '1166': 'YALI1_B06613p',
#  '1167': 'YALI1_B06620p',
#  '1168': 'YALI1_B06628p',
#  '1169': 'YALI1_B06635p',
#  '116': 'YALI1_A03137p',
#  '1170': 'YALI1_B06640p',
#  '1171': 'YALI1_B06644p',
#  '1172': 'YALI1_B06704p',
#  '1173': 'YALI1_B06726p',
#  '1174': 'YALI1_B06735p',
#  '1175': 'YALI1_B06745p',
#  '1176': 'YALI1_B06776p',
#  '1177': 'YALI1_B06809p',
#  '1178': 'YALI1_B06839p',
#  '1179': 'YALI1_B06847p',
#  '117': 'YALI1_A03153p',
#  '1180': 'YALI1_B06866p',
#  '1181': 'YALI1_B06885p',
#  '1182': 'YALI1_B06928p',
#  '1183': 'YALI1_B06969p',
#  '1184': 'YALI1_B07043p',
#  '1185': 'YALI1_B07076p',
#  '1186': 'YALI1_B07094p',
#  '1187': 'YALI1_B07134p',
#  '1188': 'YALI1_B07162p',
#  '1189': 'YALI1_B07203p',
#  '118': 'YALI1_A03170p',
#  '1190': 'YALI1_B07210p',
#  '1191': 'YALI1_B07220p',
#  '1192': 'YALI1_B07271p',
#  '1193': 'YALI1_B07284p',
#  '1194': 'YALI1_B07295p',
#  '1195': 'YALI1_B07331p',
#  '1196': 'YALI1_B07366p',
#  '1197': 'YALI1_B07374p',
#  '1198': 'YALI1_B07399p',
#  '1199': 'YALI1_B07413p',
#  '119': 'YALI1_A03183p',
#  '11': 'YALI1_A00309p',
#  '1200': 'YALI1_B07444p',
#  '1201': 'YALI1_B07500p',
#  '1202': 'YALI1_B07538p',
#  '1203': 'YALI1_B07549p',
#  '1204': 'YALI1_B07578p',
#  '1205': 'YALI1_B07598p',
#  '1206': 'YALI1_B07652p',
#  '1207': 'YALI1_B07675p',
#  '1208': 'YALI1_B07696p',
#  '1209': 'YALI1_B07735p',
#  '120': 'YALI1_A03210p',
#  '1210': 'YALI1_B07762p',
#  '1211': 'YALI1_B07769p',
#  '1212': 'YALI1_B07786p',
#  '1213': 'YALI1_B07809p',
#  '1214': 'YALI1_B07843p',
#  '1215': 'YALI1_B07852p',
#  '1216': 'YALI1_B07853p',
#  '1217': 'YALI1_B07864p',
#  '1218': 'YALI1_B07915p',
#  '1219': 'YALI1_B07937p',
#  '121': 'YALI1_A03258p',
#  '1220': 'YALI1_B07957p',
#  '1221': 'YALI1_B07983p',
#  '1222': 'YALI1_B08094p',
#  '1223': 'YALI1_B08102p',
#  '1224': 'YALI1_B08123p',
#  '1225': 'YALI1_B08134p',
#  '1226': 'YALI1_B08156p',
#  '1227': 'YALI1_B08186p',
#  '1228': 'YALI1_B08193p',
#  '1229': 'YALI1_B08207p',
#  '122': 'YALI1_A03278p',
#  '1230': 'YALI1_B08214p',
#  '1231': 'YALI1_B08247p',
#  '1232': 'YALI1_B08263p',
#  '1233': 'YALI1_B08321p',
#  '1234': 'YALI1_B08374p',
#  '1235': 'YALI1_B08401p',
#  '1236': 'YALI1_B08438p',
#  '1237': 'YALI1_B08461p',
#  '1238': 'YALI1_B08493p',
#  '1239': 'YALI1_B08531p',
#  '123': 'YALI1_A03289p',
#  '1240': 'YALI1_B08540p',
#  '1241': 'YALI1_B08575p',
#  '1242': 'YALI1_B08580p',
#  '1243': 'YALI1_B08588p',
#  '1244': 'YALI1_B08616p',
#  '1245': 'YALI1_B08627p',
#  '1246': 'YALI1_B08650p',
#  '1247': 'YALI1_B08699p',
#  '1248': 'YALI1_B08721p',
#  '1249': 'YALI1_B08758p',
#  '124': 'YALI1_A03300p',
#  '1250': 'YALI1_B08783p',
#  '1251': 'YALI1_B08801p',
#  '1252': 'YALI1_B08817p',
#  '1253': 'YALI1_B08831p',
#  '1254': 'YALI1_B08851p',
#  '1255': 'YALI1_B08868p',
#  '1256': 'YALI1_B08885p',
#  '1257': 'YALI1_B08898p',
#  '1258': 'YALI1_B08975p',
#  '1259': 'YALI1_B08978p',
#  '125': 'YALI1_A03322p',
#  '1260': 'YALI1_B09002p',
#  '1261': 'YALI1_B09025p',
#  '1262': 'YALI1_B09044p',
#  '1263': 'YALI1_B09072p',
#  '1264': 'YALI1_B09090p',
#  '1265': 'YALI1_B09117p',
#  '1266': 'YALI1_B09132p',
#  '1267': 'YALI1_B09144p',
#  '1268': 'YALI1_B09161p',
#  '1269': 'YALI1_B09181p',
#  '126': 'YALI1_A03351p',
#  '1270': 'YALI1_B09211p',
#  '1271': 'YALI1_B09258p',
#  '1272': 'YALI1_B09266p',
#  '1273': 'YALI1_B09279p',
#  '1274': 'YALI1_B09299p',
#  '1275': 'YALI1_B09310p',
#  '1276': 'YALI1_B09316p',
#  '1277': 'YALI1_B09320p',
#  '1278': 'YALI1_B09333p',
#  '1279': 'YALI1_B09367p',
#  '127': 'YALI1_A03356p',
#  '1280': 'YALI1_B09426p',
#  '1281': 'YALI1_B09448p',
#  '1282': 'YALI1_B09476p',
#  '1283': 'YALI1_B09497p',
#  '1284': 'YALI1_B09518p',
#  '1285': 'YALI1_B09568p',
#  '1286': 'YALI1_B09580p',
#  '1287': 'YALI1_B09591p',
#  '1288': 'YALI1_B09592p',
#  '1289': 'YALI1_B09708p',
#  '128': 'YALI1_A03396p',
#  '1290': 'YALI1_B09807p',
#  '1291': 'YALI1_B09837p',
#  '1292': 'YALI1_B09871p',
#  '1293': 'YALI1_B09894p',
#  '1294': 'YALI1_B09929p',
#  '1295': 'YALI1_B09931p',
#  '1296': 'YALI1_B09957p',
#  '1297': 'YALI1_B09993p',
#  '1298': 'YALI1_B09994p',
#  '1299': 'YALI1_B10032p',
#  '129': 'YALI1_A03402p',
#  '12': 'YALI1_A00325p',
#  '1300': 'YALI1_B10094p',
#  '1301': 'YALI1_B10119p',
#  '1302': 'YALI1_B10130p',
#  '1303': 'YALI1_B10145p',
#  '1304': 'YALI1_B10170p',
#  '1305': 'YALI1_B10182p',
#  '1306': 'YALI1_B10185p',
#  '1307': 'YALI1_B10231p',
#  '1308': 'YALI1_B10263p',
#  '1309': 'YALI1_B10288p',
#  '130': 'YALI1_A03422p',
#  '1310': 'YALI1_B10359p',
#  '1311': 'YALI1_B10424p',
#  '1312': 'YALI1_B10437p',
#  '1313': 'YALI1_B10449p',
#  '1314': 'YALI1_B10463p',
#  '1315': 'YALI1_B10525p',
#  '1316': 'YALI1_B10552p',
#  '1317': 'YALI1_B10582p',
#  '1318': 'YALI1_B10607p',
#  '1319': 'YALI1_B10635p',
#  '131': 'YALI1_A03442p',
#  '1320': 'YALI1_B10751p',
#  '1321': 'YALI1_B10757p',
#  '1322': 'YALI1_B10762p',
#  '1323': 'YALI1_B10773p',
#  '1324': 'YALI1_B10780p',
#  '1325': 'YALI1_B10782p',
#  '1326': 'YALI1_B10813p',
#  '1327': 'YALI1_B10891p',
#  '1328': 'YALI1_B10933p',
#  '1329': 'YALI1_B10943p',
#  '132': 'YALI1_A03450p',
#  '1330': 'YALI1_B10990p',
#  '1331': 'YALI1_B11034p',
#  '1332': 'YALI1_B11083p',
#  '1333': 'YALI1_B11111p',
#  '1334': 'YALI1_B11120p',
#  '1335': 'YALI1_B11131p',
#  '1336': 'YALI1_B11167p',
#  '1337': 'YALI1_B11183p',
#  '1338': 'YALI1_B11200p',
#  '1339': 'YALI1_B11388p',
#  '133': 'YALI1_A03487p',
#  '1340': 'YALI1_B11398p',
#  '1341': 'YALI1_B11402p',
#  '1342': 'YALI1_B11415p',
#  '1343': 'YALI1_B11448p',
#  '1344': 'YALI1_B11484p',
#  '1345': 'YALI1_B11495p',
#  '1346': 'YALI1_B11519p',
#  '1347': 'YALI1_B11532p',
#  '1348': 'YALI1_B11577p',
#  '1349': 'YALI1_B11588p',
#  '134': 'YALI1_A03507p',
#  '1350': 'YALI1_B11593p',
#  '1351': 'YALI1_B11607p',
#  '1352': 'YALI1_B11625p',
#  '1353': 'YALI1_B11648p',
#  '1354': 'YALI1_B11681p',
#  '1355': 'YALI1_B11715p',
#  '1356': 'YALI1_B11719p',
#  '1357': 'YALI1_B11729p',
#  '1358': 'YALI1_B11759p',
#  '1359': 'YALI1_B11781p',
#  '135': 'YALI1_A03512p',
#  '1360': 'YALI1_B11794p',
#  '1361': 'YALI1_B11853p',
#  '1362': 'YALI1_B11878p',
#  '1363': 'YALI1_B11916p',
#  '1364': 'YALI1_B11934p',
#  '1365': 'YALI1_B11960p',
#  '1366': 'YALI1_B11978p',
#  '1367': 'YALI1_B11983p',
#  '1368': 'YALI1_B12010p',
#  '1369': 'YALI1_B12042p',
#  '136': 'YALI1_A03549p',
#  '1370': 'YALI1_B12057p',
#  '1371': 'YALI1_B12101p',
#  '1372': 'YALI1_B12150p',
#  '1373': 'YALI1_B12154p',
#  '1374': 'YALI1_B12195p',
#  '1375': 'YALI1_B12204p',
#  '1376': 'YALI1_B12243p',
#  '1377': 'YALI1_B12267p',
#  '1378': 'YALI1_B12295p',
#  '1379': 'YALI1_B12313p',
#  '137': 'YALI1_A03567p',
#  '1380': 'YALI1_B12337p',
#  '1381': 'YALI1_B12375p',
#  '1382': 'YALI1_B12384p',
#  '1383': 'YALI1_B12409p',
#  '1384': 'YALI1_B12427p',
#  '1385': 'YALI1_B12443p',
#  '1386': 'YALI1_B12451p',
#  '1387': 'YALI1_B12489p',
#  '1388': 'YALI1_B12529p',
#  '1389': 'YALI1_B12633p',
#  '138': 'YALI1_A03579p',
#  '1390': 'YALI1_B12677p',
#  '1391': 'YALI1_B12691p',
#  '1392': 'YALI1_B12714p',
#  '1393': 'YALI1_B12742p',
#  '1394': 'YALI1_B12781p',
#  '1395': 'YALI1_B12847p',
#  '1396': 'YALI1_B12874p',
#  '1397': 'YALI1_B12917p',
#  '1398': 'YALI1_B12966p',
#  '1399': 'YALI1_B12970p',
#  '139': 'YALI1_A03599p',
#  '13': 'YALI1_A00375p',
#  '1400': 'YALI1_B12993p',
#  '1401': 'YALI1_B13041p',
#  '1402': 'YALI1_B13069p',
#  '1403': 'YALI1_B13112p',
#  '1404': 'YALI1_B13122p',
#  '1405': 'YALI1_B13137p',
#  '1406': 'YALI1_B13150p',
#  '1407': 'YALI1_B13179p',
#  '1408': 'YALI1_B13259p',
#  '1409': 'YALI1_B13290p',
#  '140': 'YALI1_A03624p',
#  '1410': 'YALI1_B13328p',
#  '1411': 'YALI1_B13355p',
#  '1412': 'YALI1_B13401p',
#  '1413': 'YALI1_B13411p',
#  '1414': 'YALI1_B13439p',
#  '1415': 'YALI1_B13483p',
#  '1416': 'YALI1_B13536p',
#  '1417': 'YALI1_B13556p',
#  '1418': 'YALI1_B13586p',
#  '1419': 'YALI1_B13614p',
#  '141': 'YALI1_A03669p',
#  '1420': 'YALI1_B13641p',
#  '1421': 'YALI1_B13662p',
#  '1422': 'YALI1_B13699p',
#  '1423': 'YALI1_B13723p',
#  '1424': 'YALI1_B13737p',
#  '1425': 'YALI1_B13800p',
#  '1426': 'YALI1_B13828p',
#  '1427': 'YALI1_B13886p',
#  '1428': 'YALI1_B13888p',
#  '1429': 'YALI1_B13915p',
#  '142': 'YALI1_A03688p',
#  '1430': 'YALI1_B13917p',
#  '1431': 'YALI1_B13948p',
#  '1432': 'YALI1_B13973p',
#  '1433': 'YALI1_B14013p',
#  '1434': 'YALI1_B14044p',
#  '1435': 'YALI1_B14064p',
#  '1436': 'YALI1_B14121p',
#  '1437': 'YALI1_B14147p',
#  '1438': 'YALI1_B14150p',
#  '1439': 'YALI1_B14187p',
#  '143': 'YALI1_A03721p',
#  '1440': 'YALI1_B14194p',
#  '1441': 'YALI1_B14236p',
#  '1442': 'YALI1_B14238p',
#  '1443': 'YALI1_B14268p',
#  '1444': 'YALI1_B14292p',
#  '1445': 'YALI1_B14308p',
#  '1446': 'YALI1_B14325p',
#  '1447': 'YALI1_B14355p',
#  '1448': 'YALI1_B14382p',
#  '1449': 'YALI1_B14418p',
#  '144': 'YALI1_A03757p',
#  '1450': 'YALI1_B14441p',
#  '1451': 'YALI1_B14492p',
#  '1452': 'YALI1_B14510p',
#  '1453': 'YALI1_B14517p',
#  '1454': 'YALI1_B14544p',
#  '1455': 'YALI1_B14573p',
#  '1456': 'YALI1_B14600p',
#  '1457': 'YALI1_B14615p',
#  '1458': 'YALI1_B14645p',
#  '1459': 'YALI1_B14658p',
#  '145': 'YALI1_A03763p',
#  '1460': 'YALI1_B14680p',
#  '1461': 'YALI1_B14686p',
#  '1462': 'YALI1_B14733p',
#  '1463': 'YALI1_B14752p',
#  '1464': 'YALI1_B14793p',
#  '1465': 'YALI1_B14804p',
#  '1466': 'YALI1_B14826p',
#  '1467': 'YALI1_B14844p',
#  '1468': 'YALI1_B14882p',
#  '1469': 'YALI1_B14924p',
#  '146': 'YALI1_A03803p',
#  '1470': 'YALI1_B14948p',
#  '1471': 'YALI1_B14959p',
#  '1472': 'YALI1_B14978p',
#  '1473': 'YALI1_B14993p',
#  '1474': 'YALI1_B15015p',
#  '1475': 'YALI1_B15036p',
#  '1476': 'YALI1_B15072p',
#  '1477': 'YALI1_B15092p',
#  '1478': 'YALI1_B15109p',
#  '1479': 'YALI1_B15151p',
#  '147': 'YALI1_A03809p',
#  '1480': 'YALI1_B15180p',
#  '1481': 'YALI1_B15192p',
#  '1482': 'YALI1_B15237p',
#  '1483': 'YALI1_B15275p',
#  '1484': 'YALI1_B15301p',
#  '1485': 'YALI1_B15307p',
#  '1486': 'YALI1_B15310p',
#  '1487': 'YALI1_B15346p',
#  '1488': 'YALI1_B15380p',
#  '1489': 'YALI1_B15420p',
#  '148': 'YALI1_A03815p',
#  '1490': 'YALI1_B15440p',
#  '1491': 'YALI1_B15460p',
#  '1492': 'YALI1_B15475p',
#  '1493': 'YALI1_B15482p',
#  '1494': 'YALI1_B15509p',
#  '1495': 'YALI1_B15521p',
#  '1496': 'YALI1_B15560p',
#  '1497': 'YALI1_B15587p',
#  '1498': 'YALI1_B15592p',
#  '1499': 'YALI1_B15624p',
#  '149': 'YALI1_A03837p',
#  '14': 'YALI1_A00406p',
#  '1500': 'YALI1_B15655p',
#  '1501': 'YALI1_B15670p',
#  '1502': 'YALI1_B15692p',
#  '1503': 'YALI1_B15703p',
#  '1504': 'YALI1_B15706p',
#  '1505': 'YALI1_B15733p',
#  '1506': 'YALI1_B15742p',
#  '1507': 'YALI1_B15792p',
#  '1508': 'YALI1_B15852p',
#  '1509': 'YALI1_B15887p',
#  '150': 'YALI1_A03842p',
#  '1510': 'YALI1_B15905p',
#  '1511': 'YALI1_B15928p',
#  '1512': 'YALI1_B15943p',
#  '1513': 'YALI1_B15964p',
#  '1514': 'YALI1_B15988p',
#  '1515': 'YALI1_B15996p',
#  '1516': 'YALI1_B16022p',
#  '1517': 'YALI1_B16068p',
#  '1518': 'YALI1_B16087p',
#  '1519': 'YALI1_B16110p',
#  '151': 'YALI1_A03857p',
#  '1520': 'YALI1_B16158p',
#  '1521': 'YALI1_B16194p',
#  '1522': 'YALI1_B16239p',
#  '1523': 'YALI1_B16255p',
#  '1524': 'YALI1_B16277p',
#  '1525': 'YALI1_B16309p',
#  '1526': 'YALI1_B16318p',
#  '1527': 'YALI1_B16375p',
#  '1528': 'YALI1_B16410p',
#  '1529': 'YALI1_B16419p',
#  '152': 'YALI1_A03883p',
#  '1530': 'YALI1_B16446p',
#  '1531': 'YALI1_B16477p',
#  '1532': 'YALI1_B16504p',
#  '1533': 'YALI1_B16544p',
#  '1534': 'YALI1_B16566p',
#  '1535': 'YALI1_B16572p',
#  '1536': 'YALI1_B16578p',
#  '1537': 'YALI1_B16584p',
#  '1538': 'YALI1_B16645p',
#  '1539': 'YALI1_B16687p',
#  '153': 'YALI1_A03900p',
#  '1540': 'YALI1_B16705p',
#  '1541': 'YALI1_B16735p',
#  '1542': 'YALI1_B16808p',
#  '1543': 'YALI1_B16863p',
#  '1544': 'YALI1_B16922p',
#  '1545': 'YALI1_B16944p',
#  '1546': 'YALI1_B16968p',
#  '1547': 'YALI1_B16996p',
#  '1548': 'YALI1_B17008p',
#  '1549': 'YALI1_B17039p',
#  '154': 'YALI1_A03907p',
#  '1550': 'YALI1_B17050p',
#  '1551': 'YALI1_B17105p',
#  '1552': 'YALI1_B17112p',
#  '1553': 'YALI1_B17132p',
#  '1554': 'YALI1_B17155p',
#  '1555': 'YALI1_B17214p',
#  '1556': 'YALI1_B17261p',
#  '1557': 'YALI1_B17285p',
#  '1558': 'YALI1_B17292p',
#  '1559': 'YALI1_B17299p',
#  '155': 'YALI1_A03937p',
#  '1560': 'YALI1_B17363p',
#  '1561': 'YALI1_B17406p',
#  '1562': 'YALI1_B17441p',
#  '1563': 'YALI1_B17468p',
#  '1564': 'YALI1_B17493p',
#  '1565': 'YALI1_B17518p',
#  '1566': 'YALI1_B17569p',
#  '1567': 'YALI1_B17592p',
#  '1568': 'YALI1_B17660p',
#  '1569': 'YALI1_B17695p',
#  '156': 'YALI1_A03964p',
#  '1570': 'YALI1_B17724p',
#  '1571': 'YALI1_B17773p',
#  '1572': 'YALI1_B17805p',
#  '1573': 'YALI1_B17838p',
#  '1574': 'YALI1_B17853p',
#  '1575': 'YALI1_B17871p',
#  '1576': 'YALI1_B17908p',
#  '1577': 'YALI1_B17927p',
#  '1578': 'YALI1_B17964p',
#  '1579': 'YALI1_B17968p',
#  '157': 'YALI1_A04006p',
#  '1580': 'YALI1_B17990p',
#  '1581': 'YALI1_B17998p',
#  '1582': 'YALI1_B18012p',
#  '1583': 'YALI1_B18069p',
#  '1584': 'YALI1_B18134p',
#  '1585': 'YALI1_B18190p',
#  '1586': 'YALI1_B18205p',
#  '1587': 'YALI1_B18207p',
#  '1588': 'YALI1_B18236p',
#  '1589': 'YALI1_B18260p',
#  '158': 'YALI1_A04022p',
#  '1590': 'YALI1_B18265p',
#  '1591': 'YALI1_B18292p',
#  '1592': 'YALI1_B18311p',
#  '1593': 'YALI1_B18347p',
#  '1594': 'YALI1_B18368p',
#  '1595': 'YALI1_B18375p',
#  '1596': 'YALI1_B18384p',
#  '1597': 'YALI1_B18391p',
#  '1598': 'YALI1_B18451p',
#  '1599': 'YALI1_B18460p',
#  '159': 'YALI1_A04044p',
#  '15': 'YALI1_A00447p',
#  '1600': 'YALI1_B18472p',
#  '1601': 'YALI1_B18499p',
#  '1602': 'YALI1_B18536p',
#  '1603': 'YALI1_B18572p',
#  '1604': 'YALI1_B18607p',
#  '1605': 'YALI1_B18613p',
#  '1606': 'YALI1_B18631p',
#  '1607': 'YALI1_B18645p',
#  '1608': 'YALI1_B18687p',
#  '1609': 'YALI1_B18707p',
#  '160': 'YALI1_A04071p',
#  '1610': 'YALI1_B18727p',
#  '1611': 'YALI1_B18741p',
#  '1612': 'YALI1_B18764p',
#  '1613': 'YALI1_B18798p',
#  '1614': 'YALI1_B18811p',
#  '1615': 'YALI1_B18845p',
#  '1616': 'YALI1_B18854p',
#  '1617': 'YALI1_B18887p',
#  '1618': 'YALI1_B18902p',
#  '1619': 'YALI1_B18921p',
#  '161': 'YALI1_A04109p',
#  '1620': 'YALI1_B18930p',
#  '1621': 'YALI1_B18955p',
#  '1622': 'YALI1_B18971p',
#  '1623': 'YALI1_B18975p',
#  '1624': 'YALI1_B19021p',
#  '1625': 'YALI1_B19044p',
#  '1626': 'YALI1_B19079p',
#  '1627': 'YALI1_B19107p',
#  '1628': 'YALI1_B19120p',
#  '1629': 'YALI1_B19153p',
#  '162': 'YALI1_A04119p',
#  '1630': 'YALI1_B19205p',
#  '1631': 'YALI1_B19217p',
#  '1632': 'YALI1_B19276p',
#  '1633': 'YALI1_B19290p',
#  '1634': 'YALI1_B19323p',
#  '1635': 'YALI1_B19326p',
#  '1636': 'YALI1_B19336p',
#  '1637': 'YALI1_B19348p',
#  '1638': 'YALI1_B19388p',
#  '1639': 'YALI1_B19390p',
#  '163': 'YALI1_A04164p',
#  '1640': 'YALI1_B19429p',
#  '1641': 'YALI1_B19453p',
#  '1642': 'YALI1_B19485p',
#  '1643': 'YALI1_B19490p',
#  '1644': 'YALI1_B19507p',
#  '1645': 'YALI1_B19520p',
#  '1646': 'YALI1_B19567p',
#  '1647': 'YALI1_B19576p',
#  '1648': 'YALI1_B19602p',
#  '1649': 'YALI1_B19668p',
#  '164': 'YALI1_A04178p',
#  '1650': 'YALI1_B19713p',
#  '1651': 'YALI1_B19747p',
#  '1652': 'YALI1_B19774p',
#  '1653': 'YALI1_B19844p',
#  '1654': 'YALI1_B19856p',
#  '1655': 'YALI1_B19877p',
#  '1656': 'YALI1_B19880p',
#  '1657': 'YALI1_B19897p',
#  '1658': 'YALI1_B19932p',
#  '1659': 'YALI1_B19962p',
#  '165': 'YALI1_A04261p',
#  '1660': 'YALI1_B20009p',
#  '1661': 'YALI1_B20043p',
#  '1662': 'YALI1_B20052p',
#  '1663': 'YALI1_B20094p',
#  '1664': 'YALI1_B20108p',
#  '1665': 'YALI1_B20130p',
#  '1666': 'YALI1_B20145p',
#  '1667': 'YALI1_B20153p',
#  '1668': 'YALI1_B20188p',
#  '1669': 'YALI1_B20192p',
#  '166': 'YALI1_A04309p',
#  '1670': 'YALI1_B20205p',
#  '1671': 'YALI1_B20242p',
#  '1672': 'YALI1_B20243p',
#  '1673': 'YALI1_B20276p',
#  '1674': 'YALI1_B20289p',
#  '1675': 'YALI1_B20319p',
#  '1676': 'YALI1_B20337p',
#  '1677': 'YALI1_B20359p',
#  '1678': 'YALI1_B20378p',
#  '1679': 'YALI1_B20399p',
#  '167': 'YALI1_A04332p',
#  '1680': 'YALI1_B20407p',
#  '1681': 'YALI1_B20416p',
#  '1682': 'YALI1_B20462p',
#  '1683': 'YALI1_B20493p',
#  '1684': 'YALI1_B20521p',
#  '1685': 'YALI1_B20527p',
#  '1686': 'YALI1_B20577p',
#  '1687': 'YALI1_B20589p',
#  '1688': 'YALI1_B20634p',
#  '1689': 'YALI1_B20709p',
#  '168': 'YALI1_A04341p',
#  '1690': 'YALI1_B20717p',
#  '1691': 'YALI1_B20730p',
#  '1692': 'YALI1_B20765p',
#  '1693': 'YALI1_B20777p',
#  '1694': 'YALI1_B20802p',
#  '1695': 'YALI1_B20834p',
#  '1696': 'YALI1_B20835p',
#  '1697': 'YALI1_B20870p',
#  '1698': 'YALI1_B20887p',
#  '1699': 'YALI1_B20919p',
#  '169': 'YALI1_A04385p',
#  '16': 'YALI1_A00468p',
#  '1700': 'YALI1_B20935p',
#  '1701': 'YALI1_B20968p',
#  '1702': 'YALI1_B20992p',
#  '1703': 'YALI1_B21004p',
#  '1704': 'YALI1_B21030p',
#  '1705': 'YALI1_B21042p',
#  '1706': 'YALI1_B21043p',
#  '1707': 'YALI1_B21070p',
#  '1708': 'YALI1_B21088p',
#  '1709': 'YALI1_B21104p',
#  '170': 'YALI1_A04415p',
#  '1710': 'YALI1_B21114p',
#  '1711': 'YALI1_B21134p',
#  '1712': 'YALI1_B21155p',
#  '1713': 'YALI1_B21194p',
#  '1714': 'YALI1_B21208p',
#  '1715': 'YALI1_B21250p',
#  '1716': 'YALI1_B21275p',
#  '1717': 'YALI1_B21313p',
#  '1718': 'YALI1_B21323p',
#  '1719': 'YALI1_B21356p',
#  '171': 'YALI1_A04462p',
#  '1720': 'YALI1_B21381p',
#  '1721': 'YALI1_B21423p',
#  '1722': 'YALI1_B21432p',
#  '1723': 'YALI1_B21466p',
#  '1724': 'YALI1_B21493p',
#  '1725': 'YALI1_B21538p',
#  '1726': 'YALI1_B21562p',
#  '1727': 'YALI1_B21594p',
#  '1728': 'YALI1_B21618p',
#  '1729': 'YALI1_B21628p',
#  '172': 'YALI1_A04495p',
#  '1730': 'YALI1_B21675p',
#  '1731': 'YALI1_B21714p',
#  '1732': 'YALI1_B21737p',
#  '1733': 'YALI1_B21774p',
#  '1734': 'YALI1_B21787p',
#  '1735': 'YALI1_B21798p',
#  '1736': 'YALI1_B21816p',
#  '1737': 'YALI1_B21819p',
#  '1738': 'YALI1_B21855p',
#  '1739': 'YALI1_B21885p',
#  '173': 'YALI1_A04533p',
#  '1740': 'YALI1_B21935p',
#  '1741': 'YALI1_B21946p',
#  '1742': 'YALI1_B21966p',
#  '1743': 'YALI1_B22015p',
#  '1744': 'YALI1_B22020p',
#  '1745': 'YALI1_B22055p',
#  '1746': 'YALI1_B22060p',
#  '1747': 'YALI1_B22088p',
#  '1748': 'YALI1_B22109p',
#  '1749': 'YALI1_B22158p',
#  '174': 'YALI1_A04561p',
#  '1750': 'YALI1_B22259p',
#  '1751': 'YALI1_B22266p',
#  '1752': 'YALI1_B22276p',
#  '1753': 'YALI1_B22321p',
#  '1754': 'YALI1_B22351p',
#  '1755': 'YALI1_B22372p',
#  '1756': 'YALI1_B22375p',
#  '1757': 'YALI1_B22391p',
#  '1758': 'YALI1_B22410p',
#  '1759': 'YALI1_B22414p',
#  '175': 'YALI1_A04576p',
#  '1760': 'YALI1_B22452p',
#  '1761': 'YALI1_B22499p',
#  '1762': 'YALI1_B22512p',
#  '1763': 'YALI1_B22533p',
#  '1764': 'YALI1_B22549p',
#  '1765': 'YALI1_B22561p',
#  '1766': 'YALI1_B22598p',
#  '1767': 'YALI1_B22614p',
#  '1768': 'YALI1_B22638p',
#  '1769': 'YALI1_B22645p',
#  '176': 'YALI1_A04620p',
#  '1770': 'YALI1_B22667p',
#  '1771': 'YALI1_B22677p',
#  '1772': 'YALI1_B22697p',
#  '1773': 'YALI1_B22721p',
#  '1774': 'YALI1_B22747p',
#  '1775': 'YALI1_B22793p',
#  '1776': 'YALI1_B22820p',
#  '1777': 'YALI1_B22853p',
#  '1778': 'YALI1_B22883p',
#  '1779': 'YALI1_B22905p',
#  '177': 'YALI1_A04653p',
#  '1780': 'YALI1_B22908p',
#  '1781': 'YALI1_B22938p',
#  '1782': 'YALI1_B23017p',
#  '1783': 'YALI1_B23055p',
#  '1784': 'YALI1_B23061p',
#  '1785': 'YALI1_B23077p',
#  '1786': 'YALI1_B23153p',
#  '1787': 'YALI1_B23176p',
#  '1788': 'YALI1_B23201p',
#  '1789': 'YALI1_B23237p',
#  '178': 'YALI1_A04661p',
#  '1790': 'YALI1_B23300p',
#  '1791': 'YALI1_B23338p',
#  '1792': 'YALI1_B23351p',
#  '1793': 'YALI1_B23373p',
#  '1794': 'YALI1_B23385p',
#  '1795': 'YALI1_B23420p',
#  '1796': 'YALI1_B23440p',
#  '1797': 'YALI1_B23443p',
#  '1798': 'YALI1_B23447p',
#  '1799': 'YALI1_B23467p',
#  '179': 'YALI1_A04676p',
#  '17': 'YALI1_A00504p',
#  '1800': 'YALI1_B23515p',
#  '1801': 'YALI1_B23522p',
#  '1802': 'YALI1_B23554p',
#  '1803': 'YALI1_B23579p',
#  '1804': 'YALI1_B23603p',
#  '1805': 'YALI1_B23609p',
#  '1806': 'YALI1_B23622p',
#  '1807': 'YALI1_B23677p',
#  '1808': 'YALI1_B23708p',
#  '1809': 'YALI1_B23729p',
#  '180': 'YALI1_A04715p',
#  '1810': 'YALI1_B23744p',
#  '1811': 'YALI1_B23771p',
#  '1812': 'YALI1_B23794p',
#  '1813': 'YALI1_B23798p',
#  '1814': 'YALI1_B23834p',
#  '1815': 'YALI1_B23866p',
#  '1816': 'YALI1_B23879p',
#  '1817': 'YALI1_B23933p',
#  '1818': 'YALI1_B23939p',
#  '1819': 'YALI1_B23966p',
#  '181': 'YALI1_A04742p',
#  '1820': 'YALI1_B23981p',
#  '1821': 'YALI1_B24018p',
#  '1822': 'YALI1_B24043p',
#  '1823': 'YALI1_B24051p',
#  '1824': 'YALI1_B24129p',
#  '1825': 'YALI1_B24185p',
#  '1826': 'YALI1_B24214p',
#  '1827': 'YALI1_B24218p',
#  '1828': 'YALI1_B24252p',
#  '1829': 'YALI1_B24264p',
#  '182': 'YALI1_A04781p',
#  '1830': 'YALI1_B24280p',
#  '1831': 'YALI1_B24292p',
#  '1832': 'YALI1_B24335p',
#  '1833': 'YALI1_B24351p',
#  '1834': 'YALI1_B24424p',
#  '1835': 'YALI1_B24446p',
#  '1836': 'YALI1_B24471p',
#  '1837': 'YALI1_B24502p',
#  '1838': 'YALI1_B24564p',
#  '1839': 'YALI1_B24606p',
#  '183': 'YALI1_A04795p',
#  '1840': 'YALI1_B24638p',
#  '1841': 'YALI1_B24654p',
#  '1842': 'YALI1_B24672p',
#  '1843': 'YALI1_B24714p',
#  '1844': 'YALI1_B24758p',
#  '1845': 'YALI1_B24836p',
#  '1846': 'YALI1_B24901p',
#  '1847': 'YALI1_B24936p',
#  '1848': 'YALI1_B24970p',
#  '1849': 'YALI1_B24997p',
#  '184': 'YALI1_A04815p',
#  '1850': 'YALI1_B25004p',
#  '1851': 'YALI1_B25017p',
#  '1852': 'YALI1_B25062p',
#  '1853': 'YALI1_B25077p',
#  '1854': 'YALI1_B25087p',
#  '1855': 'YALI1_B25107p',
#  '1856': 'YALI1_B25136p',
#  '1857': 'YALI1_B25187p',
#  '1858': 'YALI1_B25223p',
#  '1859': 'YALI1_B25258p',
#  '185': 'YALI1_A04817p',
#  '1860': 'YALI1_B25313p',
#  '1861': 'YALI1_B25319p',
#  '1862': 'YALI1_B25322p',
#  '1863': 'YALI1_B25334p',
#  '1864': 'YALI1_B25360p',
#  '1865': 'YALI1_B25387p',
#  '1866': 'YALI1_B25395p',
#  '1867': 'YALI1_B25427p',
#  '1868': 'YALI1_B25484p',
#  '1869': 'YALI1_B25495p',
#  '186': 'YALI1_A04848p',
#  '1870': 'YALI1_B25506p',
#  '1871': 'YALI1_B25553p',
#  '1872': 'YALI1_B25593p',
#  '1873': 'YALI1_B25603p',
#  '1874': 'YALI1_B25676p',
#  '1875': 'YALI1_B25734p',
#  '1876': 'YALI1_B25744p',
#  '1877': 'YALI1_B25762p',
#  '1878': 'YALI1_B25795p',
#  '1879': 'YALI1_B25798p',
#  '187': 'YALI1_A04859p',
#  '1880': 'YALI1_B25833p',
#  '1881': 'YALI1_B25868p',
#  '1882': 'YALI1_B25906p',
#  '1883': 'YALI1_B25952p',
#  '1884': 'YALI1_B25963p',
#  '1885': 'YALI1_B25988p',
#  '1886': 'YALI1_B25997p',
#  '1887': 'YALI1_B26033p',
#  '1888': 'YALI1_B26112p',
#  '1889': 'YALI1_B26153p',
#  '188': 'YALI1_A04864p',
#  '1890': 'YALI1_B26175p',
#  '1891': 'YALI1_B26205p',
#  '1892': 'YALI1_B26235p',
#  '1893': 'YALI1_B26271p',
#  '1894': 'YALI1_B26322p',
#  '1895': 'YALI1_B26350p',
#  '1896': 'YALI1_B26377p',
#  '1897': 'YALI1_B26430p',
#  '1898': 'YALI1_B26451p',
#  '1899': 'YALI1_B26517p',
#  '189': 'YALI1_A04884p',
#  '18': 'YALI1_A00538p',
#  '1900': 'YALI1_B26550p',
#  ...}

# %%
combined_df['YALI1_protID'] = combined_df['proteinID'].map(gene_dict)
combined_df['YALI1_mod'] = combined_df['YALI1_protID'].str.replace('p', 'g', regex=False)

# %%
combined_df.head()
# Out:
#                         Site proteinID #proteinId definition  \
# 0   jgi|YarliW29_1|1012@T748      1012       1012        nan
# 1  jgi|YarliW29_1|1029@S1108      1029       1029        nan
# 2   jgi|YarliW29_1|1029@S212      1029       1029        nan
# 3   jgi|YarliW29_1|1029@S225      1029       1029        nan
# 4   jgi|YarliW29_1|1029@S368      1029       1029        nan
#
#   catalyticActivity pathway pathway_class pathway_type ecNum cofactors  ...  \
# 0               nan     nan           nan          nan   nan       nan  ...
# 1               nan     nan           nan          nan   nan       nan  ...
# 2               nan     nan           nan          nan   nan       nan  ...
# 3               nan     nan           nan          nan   nan       nan  ...
# 4               nan     nan           nan          nan   nan       nan  ...
#
#   ANOVA_padj_control_vs_low_late log2FC_control_vs_low_late  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                   0.394520
# 4                            NaN                  -1.030425
#
#   ANOVA_p_oscillation_late_combined ANOVA_padj_oscillation_late_combined  \
# 0                               NaN                                  NaN
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 4                               NaN                                  NaN
#
#   log2FC_oscillation_late_combined  proteinId  osc/low_late_cominbed  \
# 0                         0.325942       1012                    NaN
# 1                        -0.190275       1029                    NaN
# 2                              NaN       1029                    NaN
# 3                        -0.234903       1029              -0.629424
# 4                              NaN       1029                    NaN
#
#   osc/low_late_cominbedANOVA_p   YALI1_protID      YALI1_mod
# 0                          NaN  YALI1_B02550p  YALI1_B02550g
# 1                          NaN  YALI1_B02991p  YALI1_B02991g
# 2                          NaN  YALI1_B02991p  YALI1_B02991g
# 3                          NaN  YALI1_B02991p  YALI1_B02991g
# 4                          NaN  YALI1_B02991p  YALI1_B02991g
#
# [5 rows x 28 columns]

# %%
# File path to your GFF file
gff_file = "../Data/DNA/genomic_yali1_yali2.gff"

# Initialize mapping dictionary
yali1_to_yali2 = {}

# Regex patterns for locus_tag and old_locus_tag
locus_re = re.compile(r'locus_tag=(YALI1_[A-Z0-9]+g)')
old_locus_re = re.compile(r'old_locus_tag=(YALI2_[A-Z0-9]+g)')

# Parse the GFF
with open(gff_file, 'r') as file:
    for line in file:
        if line.startswith("#"):
            continue
        if "\tgene\t" not in line:
            continue

        locus_match = locus_re.search(line)
        old_locus_match = old_locus_re.search(line)

        if locus_match and old_locus_match:
            yali1 = locus_match.group(1)
            yali2 = old_locus_match.group(1)
            yali1_to_yali2[yali1] = yali2

# Convert to DataFrame for inspection or export
df_map = pd.DataFrame(list(yali1_to_yali2.items()), columns=["YALI1", "YALI2"])

# Optionally save to CSV
df_map.to_csv("yali1_to_yali2_mapping.csv", index=False)

# %%
df_map['YALI1'] = df_map['YALI1'].str.replace('g', 'p', regex=False)
locus_dict_2 = dict(zip(df_map["YALI1"], df_map["YALI2"]))

# %%
df_map
# Out:
#               YALI1          YALI2
# 0     YALI1_A00058p  YALI2_A00002g
# 1     YALI1_A00102p  YALI2_A00003g
# 2     YALI1_A00148p  YALI2_A00004g
# 3     YALI1_A00204p  YALI2_A00005g
# 4     YALI1_A00241p  YALI2_A00692g
# ...             ...            ...
# 6210  YALI1_F39665p  YALI2_E00867g
# 6211  YALI1_F39789p  YALI2_E00868g
# 6212  YALI1_F39844p  YALI2_E00869g
# 6213  YALI1_F39885p  YALI2_E00871g
# 6214  YALI1_F39891p  YALI2_E00870g
#
# [6215 rows x 2 columns]

# %%
combined_df['YALI2'] = combined_df['YALI1_protID'].map(df_map.set_index('YALI1')['YALI2'])

# %%
combined_df.head()
# Out:
#                         Site proteinID #proteinId definition  \
# 0   jgi|YarliW29_1|1012@T748      1012       1012        nan
# 1  jgi|YarliW29_1|1029@S1108      1029       1029        nan
# 2   jgi|YarliW29_1|1029@S212      1029       1029        nan
# 3   jgi|YarliW29_1|1029@S225      1029       1029        nan
# 4   jgi|YarliW29_1|1029@S368      1029       1029        nan
#
#   catalyticActivity pathway pathway_class pathway_type ecNum cofactors  ...  \
# 0               nan     nan           nan          nan   nan       nan  ...
# 1               nan     nan           nan          nan   nan       nan  ...
# 2               nan     nan           nan          nan   nan       nan  ...
# 3               nan     nan           nan          nan   nan       nan  ...
# 4               nan     nan           nan          nan   nan       nan  ...
#
#   log2FC_control_vs_low_late ANOVA_p_oscillation_late_combined  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                   0.394520                               NaN
# 4                  -1.030425                               NaN
#
#   ANOVA_padj_oscillation_late_combined log2FC_oscillation_late_combined  \
# 0                                  NaN                         0.325942
# 1                                  NaN                        -0.190275
# 2                                  NaN                              NaN
# 3                                  NaN                        -0.234903
# 4                                  NaN                              NaN
#
#   proteinId  osc/low_late_cominbed  osc/low_late_cominbedANOVA_p  \
# 0      1012                    NaN                           NaN
# 1      1029                    NaN                           NaN
# 2      1029                    NaN                           NaN
# 3      1029              -0.629424                           NaN
# 4      1029                    NaN                           NaN
#
#     YALI1_protID      YALI1_mod          YALI2
# 0  YALI1_B02550p  YALI1_B02550g  YALI2_B00027g
# 1  YALI1_B02991p  YALI1_B02991g  YALI2_B00615g
# 2  YALI1_B02991p  YALI1_B02991g  YALI2_B00615g
# 3  YALI1_B02991p  YALI1_B02991g  YALI2_B00615g
# 4  YALI1_B02991p  YALI1_B02991g  YALI2_B00615g
#
# [5 rows x 29 columns]

# %%
# JGI_protID_toYali1 = pd.DataFrame(list(gene_dict.items()), columns=['JGI_protID', 'YALI1_protID'])
# # JGI_protID_toYali1.to_csv('JGI_Yali1_protMap.csv')
# JGI_protID_toYali1.head()

# %%
df = pd.read_excel('../Annotations/yali_genes.xlsx')
df.head()
# df = pd.read_excel('../Data/locus_tag_map.xlsx')
# df.head()
# Out:
#   YALI0 locus ID YALI1 Locus ID YALI1 Proteins Gene Type Chromosome  \
# 0            NaN  YALI1_A00014g  YALI1_A00014p      mRNA     YALI1A
# 1            NaN  YALI1_A00019g  YALI1_A00019p      mRNA     YALI1A
# 2            NaN  YALI1_A00032g  YALI1_A00032p      mRNA     YALI1A
# 3   YALI0A00110g  YALI1_A00058g  YALI1_A00058p      mRNA     YALI1A
# 4   YALI0A00132g  YALI1_A00102g  YALI1_A00102p      mRNA     YALI1A
#
#    Start Base  End Base Strand  \
# 0        1230      1648      -
# 1        1806      2173      -
# 2        3285      3920      +
# 3        5913      8531      +
# 4       10299     12134      +
#
#                                           Annotation
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3    weakly similar to uniprot|Q06593 Saccharomyc...
# 4    highly similar to uniprot|P40150 Saccharomyc...

# %%
filtered_df = df.dropna(subset=["YALI0 locus ID"])

locus_dict = dict(zip(filtered_df["YALI1 Proteins"], filtered_df["YALI0 locus ID"]))

# %%
combined_df['YALI0_locus'] = combined_df['YALI1_protID'].map(locus_dict)

# %%
combined_df.head()
# Out:
#                         Site proteinID #proteinId definition  \
# 0   jgi|YarliW29_1|1012@T748      1012       1012        nan
# 1  jgi|YarliW29_1|1029@S1108      1029       1029        nan
# 2   jgi|YarliW29_1|1029@S212      1029       1029        nan
# 3   jgi|YarliW29_1|1029@S225      1029       1029        nan
# 4   jgi|YarliW29_1|1029@S368      1029       1029        nan
#
#   catalyticActivity pathway pathway_class pathway_type ecNum cofactors  ...  \
# 0               nan     nan           nan          nan   nan       nan  ...
# 1               nan     nan           nan          nan   nan       nan  ...
# 2               nan     nan           nan          nan   nan       nan  ...
# 3               nan     nan           nan          nan   nan       nan  ...
# 4               nan     nan           nan          nan   nan       nan  ...
#
#   ANOVA_p_oscillation_late_combined ANOVA_padj_oscillation_late_combined  \
# 0                               NaN                                  NaN
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 4                               NaN                                  NaN
#
#   log2FC_oscillation_late_combined proteinId osc/low_late_cominbed  \
# 0                         0.325942      1012                   NaN
# 1                        -0.190275      1029                   NaN
# 2                              NaN      1029                   NaN
# 3                        -0.234903      1029             -0.629424
# 4                              NaN      1029                   NaN
#
#    osc/low_late_cominbedANOVA_p   YALI1_protID      YALI1_mod          YALI2  \
# 0                           NaN  YALI1_B02550p  YALI1_B02550g  YALI2_B00027g
# 1                           NaN  YALI1_B02991p  YALI1_B02991g  YALI2_B00615g
# 2                           NaN  YALI1_B02991p  YALI1_B02991g  YALI2_B00615g
# 3                           NaN  YALI1_B02991p  YALI1_B02991g  YALI2_B00615g
# 4                           NaN  YALI1_B02991p  YALI1_B02991g  YALI2_B00615g
#
#     YALI0_locus
# 0  YALI0B01628g
# 1  YALI0B02002g
# 2  YALI0B02002g
# 3  YALI0B02002g
# 4  YALI0B02002g
#
# [5 rows x 30 columns]

# %% [markdown]
# ## add rest of proteomic comparisions to timepoint.

# %%
# ============================================================
# CONDITION-TO-CONDITION COMPARISONS AT EACH TIMEPOINT
# Adds log2FC, ANOVA_p, and ANOVA_padj directly to combined_df
# ============================================================

# Build protein dataframe exactly as elsewhere in notebook
prot = annotated_phospho[sample_ids_prot_redox]
prot['Protein'] = annotated_phospho['Site']
prot.index = annotated_phospho['Site']

prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))


STRESS_VS_CTRL_COLS = [
    "Low_3.5/Control_3.5",
    "Low_4.5/Control_4.5",
    "Low_5.5/Control_5.5",
    "Low_24/Control_24",
    "Low_48/Control_48",
    "Low_72/Control_72",

    "Oscillation_3.5/Control_3.5",
    "Oscillation_4.5/Control_4.5",
    "Oscillation_5.5/Control_5.5",
    "Oscillation_24/Control_24",
    "Oscillation_48/Control_48",
    "Oscillation_72/Control_72",
]


for comparison in STRESS_VS_CTRL_COLS:

    first, second = comparison.split("/")

    first_condition, first_timepoint = first.rsplit("_", 1)
    second_condition, second_timepoint = second.rsplit("_", 1)

    # -------------------------------------------------------
    # Keep only the two conditions being compared
    # -------------------------------------------------------
    prot_compare = prot.drop(
        prot.columns[
            ~(prot.columns.str.contains(first_condition) |
              prot.columns.str.contains(second_condition))
        ],
        axis=1
    )

    # -------------------------------------------------------
    # Keep only the requested timepoint
    # -------------------------------------------------------
    prot_compare = prot_compare.drop(
        prot_compare.columns[
            ~prot_compare.columns.str.contains(f"_{first_timepoint}$")
        ],
        axis=1
    )

    # -------------------------------------------------------
    # Group samples by CONDITION for ANOVA
    # -------------------------------------------------------
    condition_series = pd.Series(
        prot_compare.columns
    ).map(prot_condition_dict)

    condition_series.index = prot_compare.columns

    # -------------------------------------------------------
    # Calculate p-values
    # -------------------------------------------------------
    prot_compare_stats = global_stats_calc_prot(
        prot_compare,
        condition_series
    )

    # -------------------------------------------------------
    # Extract protein ID exactly as elsewhere in notebook
    # -------------------------------------------------------
    prot_compare_stats["proteinID"] = (
        prot_compare_stats["Site"]
        .str.extract(r"YarliW29_1\|(\d+)@")
    )

    prot_compare_stats["proteinID"] = (
        prot_compare_stats["proteinID"].astype(int)
    )

    # -------------------------------------------------------
    # Separate first and second condition
    # -------------------------------------------------------
    first_group = prot_compare_stats[
        prot_compare_stats.columns[
            prot_compare_stats.columns.str.contains(
                f"_{first_condition}_{first_timepoint}$"
            )
        ]
    ]

    second_group = prot_compare_stats[
        prot_compare_stats.columns[
            prot_compare_stats.columns.str.contains(
                f"_{second_condition}_{second_timepoint}$"
            )
        ]
    ]

    # gives the increase of the first
    prot_compare_stats['log2FC'] = log2FC_function(
        first_group,
        second_group
    )

    # -------------------------------------------------------
    # Merge exactly like existing notebook
    # -------------------------------------------------------
    df_to_merge2 = pd.DataFrame()

    df_to_merge2[comparison] = prot_compare_stats['log2FC']
    df_to_merge2['Site'] = prot_compare_stats['Site']
    df_to_merge2[f'{comparison}_ANOVA_padj'] = prot_compare_stats['ANOVA_padj']
    df_to_merge2[f'{comparison}_ANOVA_p'] = prot_compare_stats['ANOVA_p']

    # match proteinId dtype before merge
    # df_to_merge2['proteinID'] = df_to_merge['proteinID'].astype(str)
    # combined_df['proteinId'] = combined_df['proteinId'].astype(str)

    combined_df = pd.merge(
        combined_df,
        df_to_merge2,
        left_on='Site',
        right_on='Site',
        how='left'
    )
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/1717727680.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prot['Protein'] = annotated_phospho['Site']
# Skipping protein jgi|YarliW29_1|1012@T748 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S1108 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S212 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S559 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1051@T191 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1058@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1064@S131 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1077@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1096@T209 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1103@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1115@T247 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1124@S738 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S71 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@T202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1332@S228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@S243 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@T769 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S3768 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S4408 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S578 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1519@T282 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1524@S94 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S283 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S331 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1625@T19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1648@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S393 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1667@S386 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1686@T946 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S504 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1707@S231 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1724@T250 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1742@S595 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1813@S177 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1817@S427 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1864@S49 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1882@S33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1893@S196 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1904@T245 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1914@S263 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1927@S621 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1930@T166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2062@S655 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2071@S42 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2075@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|208@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2130@S364 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2186@T246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2191@S316 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|21@S855 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2200@T460 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2213@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S80 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2250@S14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2263@S203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@T506 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S217 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S285 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2322@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2342@S565 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S68 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S98 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2355@Y314 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2364@S112 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2398@S311 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2424@S459 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2478@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2492@T6 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2561@S215 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S50 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2620@S157 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@T1167 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@T837 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|263@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2679@S135 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2817@T491 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2868@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2872@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2888@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2916@S440 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2936@S52 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@S210 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2995@S437 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3028@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3038@T704 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3072@S21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3160@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3185@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@S219 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@Y222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3243@S653 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S38 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|324@S1275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@Y294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3310@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3457@T327 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3499@T51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S303 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S305 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S308 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3647@Y359 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3694@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3723@S347 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3778@S180 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3873@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3903@S198 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3944@S702 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4054@S184 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|409@S558 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4109@T501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4253@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4271@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4301@T18 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4387@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S872 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|443@S767 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S149 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4471@S160 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4496@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@T280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4609@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4616@S202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S150 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4644@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4661@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4668@S529 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|46@S222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4737@T33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4776@T140 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4790@S561 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4802@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4809@S421 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4928@S246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4968@T307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5052@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5060@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T162 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T484 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@S1831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@T1834 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5133@S575 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5232@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|524@S404 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5298@S470 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5366@T521 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5414@S276 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5462@S261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5489@S476 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5512@S310 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5533@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5612@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5670@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5698@S237 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5738@S66 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5741@S628 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5769@S13 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5877@Y173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5897@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5899@T560 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5913@S1039 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5917@T11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5942@S179 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5974@S326 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5@S515 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6070@S662 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6074@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6127@T1122 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6130@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6140@T136 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6151@T69 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6157@S592 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6199@S530 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6240@T173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6294@S330 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6322@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6325@S142 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6333@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S190 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@S294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6382@S292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6402@S301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6403@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6435@T1244 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6447@S854 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6460@T10 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|647@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6523@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6569@T47 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6588@S335 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6686@S16 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|668@S169 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6704@S25 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T500 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T514 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6719@S59 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6743@T371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6756@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|684@S109 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6865@T612 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6877@T741 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@T413 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6954@S268 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@T165 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7022@T356 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7026@S740 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|711@S1050 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7132@S351 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7198@T593 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|721@S325 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7255@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7264@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S846 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T651 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7363@S75 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7376@T531 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7380@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7386@T318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7395@S287 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S189 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S193 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7506@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7531@S207 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7567@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@S70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@S63 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@T144 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7617@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7633@T278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7692@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7719@S711 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7731@S598 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7735@S132 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7778@S281 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7796@T368 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7864@T203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7877@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|828@S278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|868@S383 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|930@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|971@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1012@T748 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S1108 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S212 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S559 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1051@T191 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1058@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1064@S131 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1077@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1096@T209 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1103@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1115@T247 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1124@S738 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S71 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@T202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1332@S228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@S243 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@T769 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S3768 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S4408 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S578 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1519@T282 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1524@S94 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S283 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S331 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1625@T19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1648@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S393 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1667@S386 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1686@T946 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S504 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1707@S231 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1724@T250 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1742@S595 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1813@S177 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1817@S427 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1864@S49 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1882@S33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1893@S196 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1904@T245 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1914@S263 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1927@S621 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1930@T166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2062@S655 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2071@S42 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2075@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|208@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2130@S364 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2186@T246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2191@S316 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|21@S855 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2200@T460 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2213@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S80 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2250@S14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2263@S203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@T506 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S217 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S285 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@T261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2322@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2342@S565 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S68 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S98 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2355@Y314 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2364@S112 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2398@S311 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2424@S459 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2478@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2492@T6 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2561@S215 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S50 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2620@S157 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@T1167 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@T837 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|263@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2679@S135 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2817@T491 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2868@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2872@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2888@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2916@S440 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2936@S52 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@S210 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2995@S437 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3028@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3038@T704 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3072@S21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3160@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3185@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@S219 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@Y222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3243@S653 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S38 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|324@S1275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@Y294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3310@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3457@T327 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3499@T51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S303 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S305 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S308 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3647@Y359 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3694@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3723@S347 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3778@S180 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3873@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3903@S198 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3944@S702 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4054@S184 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|409@S558 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4109@T501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4253@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4271@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4301@T18 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4387@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S872 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|443@S767 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S149 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4471@S160 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4496@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@T280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4609@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4616@S202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S150 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4644@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4661@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4668@S529 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|46@S222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4737@T33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4776@T140 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4790@S561 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4802@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4809@S421 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4928@S246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4968@T307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5052@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5060@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T162 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T484 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@S1831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@T1834 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5133@S575 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5232@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|524@S404 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5298@S470 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5366@T521 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5414@S276 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5462@S261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5489@S476 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5512@S310 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5533@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5612@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5670@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5698@S237 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5738@S66 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5741@S628 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5769@S13 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5877@Y173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5897@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5899@T560 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5913@S1039 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5917@T11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5942@S179 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5974@S326 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5@S515 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6070@S662 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6074@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6127@T1122 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6130@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6140@T136 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6151@T69 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6157@S592 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6199@S530 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6240@T173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6294@S330 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6322@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6325@S142 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6333@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S190 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@S294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6382@S292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6402@S301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6403@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6435@T1244 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6447@S854 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6460@T10 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|647@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6523@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6569@T47 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6588@S335 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6686@S16 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|668@S169 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6704@S25 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T500 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T514 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6719@S59 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6743@T371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6756@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|684@S109 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6865@T612 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6877@T741 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@T413 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6954@S268 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@T165 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7022@T356 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7026@S740 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|711@S1050 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7132@S351 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7198@T593 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|721@S325 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7255@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7264@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S846 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T651 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7363@S75 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7376@T531 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7380@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7386@T318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7395@S287 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S189 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S193 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7506@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7531@S207 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7567@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@S70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@S63 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@T144 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7617@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7633@T278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7692@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7719@S711 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7731@S598 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7735@S132 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7778@S281 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7796@T368 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7864@T203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7877@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|828@S278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|868@S383 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|930@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|971@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1012@T748 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S1108 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S212 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S559 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1051@T191 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1058@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1064@S131 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1077@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1096@T209 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1103@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1115@T247 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1124@S738 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S71 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S102 due to insufficient data in some groups.
# ...
# Skipping protein jgi|YarliW29_1|3038@T704 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3072@S21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3136@S825 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3160@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3185@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@S219 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@Y222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3243@S653 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S38 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|324@S1275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3260@S1035 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3260@S845 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3310@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3457@T327 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3485@Y1084 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3495@T170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3499@T51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S303 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S305 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S308 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3647@Y359 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3658@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3694@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3778@S180 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3868@S224 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3873@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4000@T20 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4054@S184 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|409@S558 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4109@T501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S551 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@T493 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4199@S147 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4199@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4229@S299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4387@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S860 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S872 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|443@S767 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S149 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4471@S160 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4480@S1176 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4508@S510 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@T280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4609@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S150 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4644@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4661@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4668@S529 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4737@T33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4756@S449 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S1018 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S780 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4774@S146 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4776@T140 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4790@S561 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4809@S421 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4928@S246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4968@T307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5052@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5060@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T162 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@S1831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@T1834 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5133@S575 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5190@Y266 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|524@S404 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5298@S470 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5313@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5319@S271 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5366@T521 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5462@S261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5470@S419 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5489@S476 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5533@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5612@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|561@S66 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5620@S145 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5670@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5698@S237 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5741@S628 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5817@T251 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5897@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5899@T560 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5913@S1047 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5917@T11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5942@S179 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5@S515 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6074@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6127@T1122 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6151@T69 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6157@S592 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6199@S530 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6240@T173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6283@T831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6294@S330 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6322@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6325@S142 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6333@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6351@S267 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@S294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6382@S292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6402@S301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6403@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@T2 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6429@S737 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6435@T1244 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6447@S854 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6454@S275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6460@T10 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6465@S496 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|647@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6523@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6569@T47 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6588@S335 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@T117 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|668@S169 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T500 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T514 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6719@S59 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6743@T371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6755@S153 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6756@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6859@S67 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6865@T612 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6877@T741 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@S496 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@T413 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6954@S268 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@S464 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@T165 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7022@T356 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7026@S740 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7086@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|711@S1050 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7132@S351 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7213@T41 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7255@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7264@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T651 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7363@S75 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7376@T531 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7380@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7386@T318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7395@S287 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S189 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S193 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7506@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7531@S207 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7567@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@S70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@S63 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@T144 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7617@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7633@T278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7692@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7696@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7731@S598 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7735@S132 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7778@S281 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7796@T368 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7864@T203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T424 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7877@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|78@S172 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|791@T45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|828@S278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|868@S383 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|930@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|965@S260 due to insufficient data in some groups.

# %%
# Build protein dataframe exactly as elsewhere in notebook
# Build protein dataframe exactly as elsewhere in notebook
prot = annotated_phospho[sample_ids_prot_redox]
prot['Protein'] = annotated_phospho['Site']
prot.index = annotated_phospho['Site']

prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))


WITHIN_COND_COLS = [
    "Control_4.5/Control_3.5",
    "Control_5.5/Control_3.5",
    "Control_24/Control_3.5",
    "Control_48/Control_3.5",
    "Control_72/Control_3.5",
    
    "Low_4.5/Low_3.5",
    "Low_5.5/Low_3.5",
    "Low_24/Low_3.5",
    "Low_48/Low_3.5",
    "Low_72/Low_3.5",
    
    "Oscillation_4.5/Oscillation_3.5",
    "Oscillation_5.5/Oscillation_3.5",
    "Oscillation_24/Oscillation_3.5",
    "Oscillation_48/Oscillation_3.5",
    "Oscillation_72/Oscillation_3.5",
]


for comparison in WITHIN_COND_COLS:

    first, second = comparison.split("/")
    
    condition = first.rsplit("_", 1)[0]
    timepoint = first.rsplit("_", 1)[1]

    # -------------------------------------------------------
    # Keep only the condition being tested
    # -------------------------------------------------------
    prot_compare = prot.drop(
        prot.columns[~prot.columns.str.contains(condition)],
        axis=1
    )

    # -------------------------------------------------------
    # Keep only current timepoint and 3.5 h
    # -------------------------------------------------------
    keep_pattern = f"_{timepoint}$|_3.5$"

    prot_compare = prot_compare.drop(
        prot_compare.columns[
            ~prot_compare.columns.str.contains(keep_pattern)
        ],
        axis=1
    )

    # -------------------------------------------------------
    # Group samples by TIMEPOINT for ANOVA
    # -------------------------------------------------------
    timepoint_series = pd.Series(
        prot_compare.columns
    ).map(prot_timepoint_dict)

    timepoint_series.index = prot_compare.columns

    # -------------------------------------------------------
    # Calculate p-values
    # -------------------------------------------------------
    prot_compare_stats = global_stats_calc_prot(
        prot_compare,
        timepoint_series
    )

    # -------------------------------------------------------
    # Extract protein ID exactly as elsewhere in notebook
    # -------------------------------------------------------
    prot_compare_stats["proteinID"] = (
        prot_compare_stats["Site"]
        .str.extract(r"YarliW29_1\|(\d+)@")
    )

    prot_compare_stats["proteinID"] = (
        prot_compare_stats["proteinID"].astype(int)
    )

    # -------------------------------------------------------
    # Separate later timepoint and 3.5 h
    # -------------------------------------------------------
    later = prot_compare_stats[
        prot_compare_stats.columns[
            prot_compare_stats.columns.str.contains(
                f"_{condition}_{timepoint}$"
            )
        ]
    ]

    baseline = prot_compare_stats[
        prot_compare_stats.columns[
            prot_compare_stats.columns.str.contains(
                f"_{condition}_3.5$"
            )
        ]
    ]

    # gives the increase of the first
    prot_compare_stats['log2FC'] = log2FC_function(
        later,
        baseline
    )

    # -------------------------------------------------------
    # Merge exactly like existing notebook
    # -------------------------------------------------------
    df_to_merge2 = pd.DataFrame()

    df_to_merge2[comparison] = prot_compare_stats['log2FC']
    df_to_merge2['Site'] = prot_compare_stats['Site']
    df_to_merge2[f'{comparison}_ANOVA_padj'] = prot_compare_stats['ANOVA_padj']
    df_to_merge2[f'{comparison}_ANOVA_p'] = prot_compare_stats['ANOVA_p']

    # df_to_merge2['Site'] = df_to_merge2['Site'].astype(str)

    combined_df = pd.merge(
        combined_df,
        df_to_merge2,
        left_on='Site',
        right_on='Site',
        how='left'
    )
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/801847093.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prot['Protein'] = annotated_phospho['Site']
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/2565568102.py:118: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   f_stat, p_value = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/2565568102.py:118: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   f_stat, p_value = f_oneway(*group_data)
# Skipping protein jgi|YarliW29_1|1332@S228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@S243 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2062@S655 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2342@S565 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@S210 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3243@S653 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S559 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1332@S228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2342@S565 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@S210 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3160@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5533@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1332@S228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1394@S24 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1516@S672 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2062@S655 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2191@S316 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2342@S565 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@S210 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3160@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@S294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7778@S281 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S559 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1332@S228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1914@S263 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2186@T246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2342@S565 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@S210 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3243@S653 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3658@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S1018 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@S294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|868@S383 due to insufficient data in some groups.
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/2565568102.py:118: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   f_stat, p_value = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/2565568102.py:118: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   f_stat, p_value = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/2565568102.py:118: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   f_stat, p_value = f_oneway(*group_data)
# Skipping protein jgi|YarliW29_1|1205@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1332@S228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1380@S273 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1394@S24 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1904@T245 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2062@S655 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2186@T246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2191@S316 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2342@S565 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@S210 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@Y222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S1018 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6333@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@S294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6523@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|828@S278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|868@S383 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1012@T748 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S1108 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S212 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S559 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1051@T191 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1058@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1064@S131 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1077@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1096@T209 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1103@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1115@T247 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1124@S738 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S71 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@T202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1332@S228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@S243 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@T769 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S3768 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S4408 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S578 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1519@T282 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1524@S94 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S283 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S331 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1625@T19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1648@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S393 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1667@S386 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1686@T946 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S504 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1707@S231 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1724@T250 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1742@S595 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1813@S177 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1817@S427 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1864@S49 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1882@S33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1893@S196 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1904@T245 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1914@S263 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1927@S621 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1930@T166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2062@S655 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2071@S42 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2075@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|208@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2130@S364 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2186@T246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2191@S316 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|21@S855 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2200@T460 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2213@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S80 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2250@S14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2263@S203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@T506 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S217 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S285 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@T261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2322@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2342@S565 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S68 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S98 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2355@Y314 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2364@S112 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2398@S311 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2424@S459 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2478@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2492@T6 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2561@S215 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S50 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2620@S157 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@T1167 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@T837 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|263@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2679@S135 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2817@T491 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2868@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2872@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2888@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2916@S440 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2936@S52 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@S210 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2995@S437 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3028@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3038@T704 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3072@S21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3160@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3185@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@S219 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@Y222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3243@S653 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S38 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|324@S1275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@Y294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3310@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3457@T327 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3499@T51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S303 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S305 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S308 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3647@Y359 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3694@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3723@S347 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3778@S180 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3873@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3903@S198 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3944@S702 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4054@S184 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|409@S558 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4109@T501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4253@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4271@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4301@T18 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4387@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S872 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|443@S767 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S149 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4471@S160 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4496@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@T280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4609@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4616@S202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S150 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4644@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4661@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4668@S529 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|46@S222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4737@T33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4776@T140 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4790@S561 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4802@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4809@S421 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4928@S246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4968@T307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5052@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5060@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T162 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T484 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@S1831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@T1834 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5133@S575 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5232@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|524@S404 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5298@S470 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5366@T521 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5414@S276 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5462@S261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5489@S476 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5512@S310 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5533@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5612@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5670@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5698@S237 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5738@S66 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5741@S628 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5769@S13 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5877@Y173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5897@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5899@T560 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5913@S1039 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5917@T11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5942@S179 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5974@S326 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5@S515 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6070@S662 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6074@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6127@T1122 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6130@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6140@T136 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6151@T69 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6157@S592 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6199@S530 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6240@T173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6294@S330 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6322@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6325@S142 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6333@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6353@S190 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@S294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6382@S292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6402@S301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6403@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6435@T1244 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6447@S854 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6460@T10 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|647@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6523@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6569@T47 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6588@S335 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6686@S16 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|668@S169 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6704@S25 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T500 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T514 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6719@S59 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6743@T371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6756@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|684@S109 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6865@T612 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6877@T741 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@T413 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6954@S268 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@T165 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7022@T356 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7026@S740 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|711@S1050 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7132@S351 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7198@T593 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|721@S325 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7255@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7264@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7270@S846 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T651 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7363@S75 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7376@T531 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7380@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7386@T318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7395@S287 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S189 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S193 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7506@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7531@S207 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7567@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@S70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@S63 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@T144 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7617@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7633@T278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7692@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7719@S711 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7731@S598 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7735@S132 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7778@S281 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7796@T368 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7864@T203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7877@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|828@S278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|868@S383 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|930@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|971@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1012@T748 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S1108 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S212 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S559 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1029@S64 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1051@T191 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1058@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1064@S131 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1077@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1096@T209 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1103@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1115@T247 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1124@S738 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1205@S71 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|128@T202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1332@S228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@S243 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1335@T769 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S3768 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1338@S4408 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1426@S578 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1456@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1519@T282 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1524@S94 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S283 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1582@S331 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1625@T19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1648@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1649@S393 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1667@S386 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1686@T946 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1687@S504 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1707@S231 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1724@T250 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1742@S595 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1813@S177 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1817@S427 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1864@S49 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1882@S33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1893@S196 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1904@T245 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1914@S263 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1927@S621 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1930@T166 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2062@S655 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2071@S42 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2075@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|208@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2130@S364 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2186@T246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2191@S316 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|21@S855 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2200@T460 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2213@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2223@S80 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2250@S14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2263@S203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2272@T506 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S217 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2302@S285 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2322@S124 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2342@S565 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S68 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2350@S98 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2355@Y314 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2364@S112 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2398@S311 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2424@S459 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2478@S468 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2492@T6 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2561@S215 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S46 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2619@S50 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2620@S157 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2623@T1167 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2632@T837 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|263@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2679@S135 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2817@T491 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2868@S22 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2872@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2888@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2916@S440 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2936@S52 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@S210 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2995@S437 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3028@S102 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3038@T704 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3072@S21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3160@S318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3185@S61 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@S219 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3231@Y222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3243@S653 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S19 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3245@S38 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|324@S1275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3299@Y294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3310@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3457@T327 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3499@T51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S303 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S305 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S308 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3647@Y359 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3694@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3723@S347 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3778@S180 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3873@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3903@S198 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3944@S702 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4054@S184 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|409@S558 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4109@T501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4253@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4271@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4301@T18 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4387@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S872 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|443@S767 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S149 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4471@S160 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4496@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@T280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4609@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4616@S202 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S150 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4644@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4661@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4668@S529 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|46@S222 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4737@T33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4776@T140 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4790@S561 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4802@S101 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4809@S421 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4928@S246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4968@T307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5052@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5060@S120 due to insufficient data in some groups.
# ...
# Skipping protein jgi|YarliW29_1|3299@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3310@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3457@T327 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3485@Y1084 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3495@T170 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3499@T51 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S303 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S305 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@S308 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3580@Y299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3647@Y359 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3658@S178 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3694@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3778@S180 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3868@S224 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3873@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4000@T20 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4054@S184 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|409@S558 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4109@T501 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@S551 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4186@T493 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4199@S147 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4199@S307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4229@S299 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4231@T277 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4387@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S860 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4417@S872 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|443@S767 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4442@S149 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4471@S160 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4480@S1176 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4508@S510 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4594@T280 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4609@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4637@S150 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4644@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4661@T143 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4668@S529 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4737@T33 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4756@S449 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S1018 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4765@S780 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4767@T228 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4774@S146 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4776@T140 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4790@S561 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4809@S421 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S155 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4845@S164 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4928@S246 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4968@T307 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5052@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5060@S120 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5084@T162 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@S1831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5106@T1834 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5133@S575 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@T8 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5190@Y266 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|524@S404 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5298@S470 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5313@S44 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5319@S271 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5366@T521 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5462@S261 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5470@S419 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5489@S476 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5492@T134 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5533@S15 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5588@T490 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5612@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|561@S66 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5620@S145 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5670@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5695@S45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5698@S237 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5741@S628 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5817@T251 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5897@S12 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5899@T560 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5913@S1047 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5917@T11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5942@S179 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5993@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5@S515 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6074@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6127@T1122 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6151@T69 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6157@S592 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6199@S530 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6240@T173 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6283@T831 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6294@S330 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6322@S123 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6323@Y70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6325@S142 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6333@S11 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6351@S267 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@S294 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6377@T301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6382@S292 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6402@S301 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6403@S289 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6406@T2 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6429@S737 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6435@T1244 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6447@S854 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6454@S275 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6460@T10 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6465@S496 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|647@S185 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6523@T288 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6569@T47 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6588@S335 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@S114 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@T117 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|668@S169 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T500 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6705@T514 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6719@S59 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6743@T371 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6755@S153 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6756@S34 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6859@S67 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6865@T612 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6877@T741 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@S496 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6927@T413 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6954@S268 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@S464 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6965@T165 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7022@T356 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7026@S740 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7086@S742 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|711@S1050 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7132@S351 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7213@T41 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7255@S92 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7264@S32 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T21 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7274@T651 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7363@S75 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7376@T531 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7380@S192 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7386@T318 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7395@S287 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S189 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7455@S193 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7506@S27 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7531@S207 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7567@T81 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@S70 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@T238 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@S63 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7612@T144 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7617@S79 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7633@T278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7692@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7696@S48 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7731@S598 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7735@S132 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7778@S281 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7796@T368 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7864@T203 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T422 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T424 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7869@T428 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7877@T14 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|78@S172 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|791@T45 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|828@S278 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|868@S383 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|930@S188 due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|965@S260 due to insufficient data in some groups.
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/2565568102.py:118: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   f_stat, p_value = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_69465/2565568102.py:118: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   f_stat, p_value = f_oneway(*group_data)

# %%
for col in combined_df.columns:
    print(col)
# Out:
# Site
# proteinID
# #proteinId
# definition
# catalyticActivity
# pathway
# pathway_class
# pathway_type
# ecNum
# cofactors
# gotermId
# gotermType
# goName
# goAcc
# ANOVA_p_late_vs_early_combined
# ANOVA_padj_late_vs_early_combined
# log2FC_late_vs_early_combined
# ANOVA_p_control_vs_low_late
# ANOVA_padj_control_vs_low_late
# log2FC_control_vs_low_late
# ANOVA_p_oscillation_late_combined
# ANOVA_padj_oscillation_late_combined
# log2FC_oscillation_late_combined
# proteinId
# osc/low_late_cominbed
# osc/low_late_cominbedANOVA_p
# YALI1_protID
# YALI1_mod
# YALI2
# YALI0_locus
# Low_3.5/Control_3.5
# Low_3.5/Control_3.5_ANOVA_padj
# Low_3.5/Control_3.5_ANOVA_p
# Low_4.5/Control_4.5
# Low_4.5/Control_4.5_ANOVA_padj
# Low_4.5/Control_4.5_ANOVA_p
# Low_5.5/Control_5.5
# Low_5.5/Control_5.5_ANOVA_padj
# Low_5.5/Control_5.5_ANOVA_p
# Low_24/Control_24
# Low_24/Control_24_ANOVA_padj
# Low_24/Control_24_ANOVA_p
# Low_48/Control_48
# Low_48/Control_48_ANOVA_padj
# Low_48/Control_48_ANOVA_p
# Low_72/Control_72
# Low_72/Control_72_ANOVA_padj
# Low_72/Control_72_ANOVA_p
# Oscillation_3.5/Control_3.5
# Oscillation_3.5/Control_3.5_ANOVA_padj
# Oscillation_3.5/Control_3.5_ANOVA_p
# Oscillation_4.5/Control_4.5
# Oscillation_4.5/Control_4.5_ANOVA_padj
# Oscillation_4.5/Control_4.5_ANOVA_p
# Oscillation_5.5/Control_5.5
# Oscillation_5.5/Control_5.5_ANOVA_padj
# Oscillation_5.5/Control_5.5_ANOVA_p
# Oscillation_24/Control_24
# Oscillation_24/Control_24_ANOVA_padj
# Oscillation_24/Control_24_ANOVA_p
# Oscillation_48/Control_48
# Oscillation_48/Control_48_ANOVA_padj
# Oscillation_48/Control_48_ANOVA_p
# Oscillation_72/Control_72
# Oscillation_72/Control_72_ANOVA_padj
# Oscillation_72/Control_72_ANOVA_p
# Control_4.5/Control_3.5
# Control_4.5/Control_3.5_ANOVA_padj
# Control_4.5/Control_3.5_ANOVA_p
# Control_5.5/Control_3.5
# Control_5.5/Control_3.5_ANOVA_padj
# Control_5.5/Control_3.5_ANOVA_p
# Control_24/Control_3.5
# Control_24/Control_3.5_ANOVA_padj
# Control_24/Control_3.5_ANOVA_p
# Control_48/Control_3.5
# Control_48/Control_3.5_ANOVA_padj
# Control_48/Control_3.5_ANOVA_p
# Control_72/Control_3.5
# Control_72/Control_3.5_ANOVA_padj
# Control_72/Control_3.5_ANOVA_p
# Low_4.5/Low_3.5
# Low_4.5/Low_3.5_ANOVA_padj
# Low_4.5/Low_3.5_ANOVA_p
# Low_5.5/Low_3.5
# Low_5.5/Low_3.5_ANOVA_padj
# Low_5.5/Low_3.5_ANOVA_p
# Low_24/Low_3.5
# Low_24/Low_3.5_ANOVA_padj
# Low_24/Low_3.5_ANOVA_p
# Low_48/Low_3.5
# Low_48/Low_3.5_ANOVA_padj
# Low_48/Low_3.5_ANOVA_p
# Low_72/Low_3.5
# Low_72/Low_3.5_ANOVA_padj
# Low_72/Low_3.5_ANOVA_p
# Oscillation_4.5/Oscillation_3.5
# Oscillation_4.5/Oscillation_3.5_ANOVA_padj
# Oscillation_4.5/Oscillation_3.5_ANOVA_p
# Oscillation_5.5/Oscillation_3.5
# Oscillation_5.5/Oscillation_3.5_ANOVA_padj
# Oscillation_5.5/Oscillation_3.5_ANOVA_p
# Oscillation_24/Oscillation_3.5
# Oscillation_24/Oscillation_3.5_ANOVA_padj
# Oscillation_24/Oscillation_3.5_ANOVA_p
# Oscillation_48/Oscillation_3.5
# Oscillation_48/Oscillation_3.5_ANOVA_padj
# Oscillation_48/Oscillation_3.5_ANOVA_p
# Oscillation_72/Oscillation_3.5
# Oscillation_72/Oscillation_3.5_ANOVA_padj
# Oscillation_72/Oscillation_3.5_ANOVA_p

# %% [markdown]
# # Final Proteomic File for processed.

# %%
# combined_df.save_to_csv('processedProteomic.csv')

# %%
# combined_df['YALI1_protID'] = combined_df['proteinId'].map(JGI_protID_toYali1.set_index('JGI_protID')['YALI1_protID'])
# combined_df['YALI0_locus'] = combined_df['YALI1_protID'].map(Yali1_Yali0.set_index('YALI1_Proteins')['YALI0_locus_ID'])
# combined_df['YALI1_protID_converted'] = combined_df['YALI1_protID'].str.replace('g', 'p', regex=False)
# combined_df['YALI2'] = combined_df['YALI1_protID_converted'].map(Yali1_Yali2.set_index('YALI1')['YALI2'])

# %%
Phospho_PATH = '../Data/ProcessedData/Proteomics/PPI_yarrowia_phospho_wAnnotations_fullLog2FC_withOsc.csv'
combined_df.to_csv(Phospho_PATH)

# %%
# merged_df.to_csv('../Data/ProcessedData/Proteomics/PPI_yarrowia_protein_abundance_wAnnotations_wOscLow_fullLog2FC.csv')
