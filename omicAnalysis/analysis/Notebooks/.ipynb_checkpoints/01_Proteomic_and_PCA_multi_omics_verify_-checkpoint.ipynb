# %% [markdown]
# # multi-omics analysis of *Yarrowia lipolytica* Reactor samples.
#
# This notebook analysis the omic that was obtained from Yarrowia lipolytica grown under variety of oxygen conditions in 2L bioreactors.

# %% [markdown]
# ## Sample Information
# | Sample Label | 	Media | 	Carbon source  | 	Nitrogen condition | 	comments |
# | --- | --- | --- | --- | --- |
# | Ctrl | 	YNB-100gGlucose-C/N100 | 	Glucose | 	C/N 100 | pO2 set to 25% |
# | Osc | 	YNB-100gGlucose-C/N100 | Glucose | 	C/N 100 | pO2 oscillating between ~5-40%	 |
# | Low | 	YNB-100gGlucose-C/N100 | 	Glucose | 	C/N 100 | pO2 set to 5%	 |

# %% [markdown]
# import libraries.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import zscore
from scipy.stats import ttest_ind
from statsmodels.stats.multitest import multipletests
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn3
from matplotlib.lines import Line2D

import re
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


from Bio.KEGG import REST
from Bio.KEGG.KGML import KGML_parser
import io

from scipy.stats import f_oneway
from statsmodels.stats.multitest import multipletests
sns.set_context("talk")
plt.rcParams['pdf.fonttype'] = 42 # when exporting as PDF, font can be edited as font

# %% [markdown]
# ## Create sample mapping for names to conditions/reactors.

# %%
# Data provided
sample_ids_prot_redox = [
    "Biostat2L_29_Oscillation_3.5", "Biostat2L_29_Oscillation_4.5", "Biostat2L_29_Oscillation_5.5",
    "Biostat2L_29_Oscillation_24", "Biostat2L_29_Oscillation_48", "Biostat2L_29_Oscillation_72",
    "Biostat2L_30_Control_3.5", "Biostat2L_30_Control_4.5", "Biostat2L_30_Control_5.5",
    "Biostat2L_30_Control_24", "Biostat2L_30_Control_48", "Biostat2L_30_Control_72",
    "Biostat2L_30_Oscillation_3.5", "Biostat2L_30_Oscillation_4.5", "Biostat2L_30_Oscillation_5.5",
    "Biostat2L_30_Oscillation_24", "Biostat2L_30_Oscillation_48", "Biostat2L_30_Oscillation_72",
    "Biostat2L_31_Control_3.5", "Biostat2L_31_Control_4.5", "Biostat2L_31_Control_5.5",
    "Biostat2L_31_Control_24", "Biostat2L_31_Control_48", "Biostat2L_31_Control_72",
    "Biostat2L_31_Oscillation_3.5", "Biostat2L_31_Oscillation_4.5", "Biostat2L_31_Oscillation_5.5",
    "Biostat2L_31_Oscillation_24", "Biostat2L_31_Oscillation_48", "Biostat2L_31_Oscillation_72",
    "Biostat2L_32_Control_3.5", "Biostat2L_32_Control_4.5", "Biostat2L_32_Control_5.5",
    "Biostat2L_32_Control_24", "Biostat2L_32_Control_48", "Biostat2L_32_Control_72",
    "Biostat2L_32_Low_3.5", "Biostat2L_32_Low_4.5", "Biostat2L_32_Low_5.5",
    "Biostat2L_32_Low_24", "Biostat2L_32_Low_48", "Biostat2L_32_Low_72",
    "Biostat2L_33_Low_3.5", "Biostat2L_33_Low_4.5", "Biostat2L_33_Low_5.5",
    "Biostat2L_33_Low_24", "Biostat2L_33_Low_48", "Biostat2L_33_Low_72",
    "Biostat2L_34_Low_3.5", "Biostat2L_34_Low_4.5", "Biostat2L_34_Low_5.5",
    "Biostat2L_34_Low_24", "Biostat2L_34_Low_48", "Biostat2L_34_Low_72",
]

sample_ids_metabolomics = [
        'PPI_Ylip_Osc_3hr_01',
        'PPI_Ylip_Osc_3hr_08',
        'PPI_Ylip_Osc_3hr_20',
        'PPI_Ylip_Osc_4hr_02',
        'PPI_Ylip_Osc_4hr_10',
        'PPI_Ylip_Osc_4hr_22',
        'PPI_Ylip_Osc_5hr_03',
        'PPI_Ylip_Osc_5hr_12',
        'PPI_Ylip_Osc_5hr_24',
        'PPI_Ylip_Osc_24hr_04',
        'PPI_Ylip_Osc_24hr_14',
        'PPI_Ylip_Osc_24hr_26',
        'PPI_Ylip_Osc_47hr_05',
        'PPI_Ylip_Osc_48hr_16',
        'PPI_Ylip_Osc_48hr_28',
        'PPI_Ylip_Osc_72hr_06',
        'PPI_Ylip_Osc_72hr_18',
        'PPI_Ylip_Osc_72hr_30',
        'PPI_Ylip_Ctrl_3hr_07',
        'PPI_Ylip_Ctrl_3hr_19',
        'PPI_Ylip_Ctrl_3hr_31',
        'PPI_Ylip_Ctrl_4hr_09',
        'PPI_Ylip_Ctrl_4hr_21',
        'PPI_Ylip_Ctrl_4hr_33',
        'PPI_Ylip_Ctrl_5hr_11',
        'PPI_Ylip_Ctrl_5hr_23',
        'PPI_Ylip_Ctrl_5hr_35',
        'PPI_Ylip_Ctrl_24hr_13',
        'PPI_Ylip_Ctrl_24hr_25',
        'PPI_Ylip_Ctrl_24hr_37',
        'PPI_Ylip_Ctrl_48hr_15',
        'PPI_Ylip_Ctrl_48hr_27',
        'PPI_Ylip_Ctrl_48hr_39',
        'PPI_Ylip_Ctrl_72hr_17',
        'PPI_Ylip_Ctrl_72hr_29',
        'PPI_Ylip_Ctrl_72hr_41',
        'PPI_Ylip_Low_3hr_32',
        'PPI_Ylip_Low_3hr_43',
        'PPI_Ylip_Low_3hr_49',
        'PPI_Ylip_Low_4hr_34',
        'PPI_Ylip_Low_4hr_44',
        'PPI_Ylip_Low_4hr_50',
        'PPI_Ylip_Low_5hr_36',
        'PPI_Ylip_Low_5hr_45',
        'PPI_Ylip_Low_5hr_51',
        'PPI_Ylip_Low_24hr_38',
        'PPI_Ylip_Low_24hr_46',
        'PPI_Ylip_Low_24hr_52',
        'PPI_Ylip_Low_48hr_40',
        'PPI_Ylip_Low_48hr_47',
        'PPI_Ylip_Low_48hr_53',
        'PPI_Ylip_Low_72hr_42',
        'PPI_Ylip_Low_72hr_48',
        'PPI_Ylip_Low_72hr_54',

]
lipid_timepoint = [
  3.5, 3.5, 3.5,
  4.5, 4.5, 4.5,
  5.5, 5.5, 5.5,
  24, 24, 24,
  48, 48, 48,
  72, 72, 72,
  3.5, 3.5, 3.5,
  4.5, 4.5, 4.5,
  5.5, 5.5, 5.5,
  24, 24, 24,
  48, 48, 48,
  72, 72, 72,
  3.5, 3.5, 3.5,
  4.5, 4.5, 4.5,
  5.5, 5.5, 5.5,
  24, 24, 24,
  48, 48, 48,
  72, 72, 72
]

sample_ids_lipidomics = [
        'PPI_Ylip_Osc_3hr_01',
        'PPI_Ylip_Osc_3hr_08',
        'PPI_Ylip_Osc_3hr_20',
        'PPI_Ylip_Osc_4hr_02',
        'PPI_Ylip_Osc_4hr_10',
        'PPI_Ylip_Osc_4hr_22',
        'PPI_Ylip_Osc_5hr_03',
        'PPI_Ylip_Osc_5hr_12',
        'PPI_Ylip_Osc_5hr_24',
        'PPI_Ylip_Osc_24hr_04',
        'PPI_Ylip_Osc_24hr_14',
        'PPI_Ylip_Osc_24hr_26',
        'PPI_Ylip_Osc_47hr_05',
        'PPI_Ylip_Osc_48hr_16',
        'PPI_Ylip_Osc_48hr_28',
        'PPI_Ylip_Osc_72hr_06',
        'PPI_Ylip_Osc_72hr_18',
        'PPI_Ylip_Osc_72hr_30',
        'PPI_Ylip_Ctrl_3hr_07',
        'PPI_Ylip_Ctrl_3hr_19',
        'PPI_Ylip_Ctrl_3hr_31',
        'PPI_Ylip_Ctrl_4hr_09',
        'PPI_Ylip_Ctrl_4hr_21',
        'PPI_Ylip_Ctrl_4hr_33',
        'PPI_Ylip_Ctrl_5hr_11',
        'PPI_Ylip_Ctrl_5hr_23',
        'PPI_Ylip_Ctrl_5hr_35',
        'PPI_Ylip_Ctrl_24hr_13',
        'PPI_Ylip_Ctrl_24hr_25',
        'PPI_Ylip_Ctrl_24hr_37',
        'PPI_Ylip_Ctrl_48hr_15',
        'PPI_Ylip_Ctrl_48hr_27',
        'PPI_Ylip_Ctrl_48hr_39',
        'PPI_Ylip_Ctrl_72hr_17',
        'PPI_Ylip_Ctrl_72hr_29',
        'PPI_Ylip_Ctrl_72hr_41',
        'PPI_Ylip_Low_3hr_32',
        'PPI_Ylip_Low_3hr_43',
        'PPI_Ylip_Low_3hr_49',
        'PPI_Ylip_Low_4hr_34',
        'PPI_Ylip_Low_4hr_44',
        'PPI_Ylip_Low_4hr_50',
        'PPI_Ylip_Low_5hr_36',
        'PPI_Ylip_Low_5hr_45',
        'PPI_Ylip_Low_5hr_51',
        'PPI_Ylip_Low_24hr_38',
        'PPI_Ylip_Low_24hr_46',
        'PPI_Ylip_Low_24hr_52',
        'PPI_Ylip_Low_48hr_40',
        'PPI_Ylip_Low_48hr_47',
        'PPI_Ylip_Low_48hr_53',
        'PPI_Ylip_Low_48hr_40',
        'PPI_Ylip_Low_48hr_47',
        'PPI_Ylip_Low_48hr_53',

]

conditions = [
    "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation",
    "Control", "Control", "Control", "Control", "Control", "Control",
    "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation",
    "Control", "Control", "Control", "Control", "Control", "Control",
    "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation",
    "Control", "Control", "Control", "Control", "Control", "Control",
    "Low", "Low", "Low", "Low", "Low", "Low",
    "Low", "Low", "Low", "Low", "Low", "Low",
    "Low", "Low", "Low", "Low", "Low", "Low"
]

timepoints = [
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
]

# Create sample_dict
sample_dict = {
    'prot_redox_ids':sample_ids_prot_redox,
    'lipid_ids':sample_ids_lipidomics,
    'lipid_timepoint': lipid_timepoint,
    'met_ids':sample_ids_metabolomics,
    "sample ID": sample_ids_prot_redox,
    "condition": conditions,
    "timepoint": timepoints,
}

lipid_condition_dict = dict(zip(sample_dict['lipid_ids'], sample_dict['condition']))
lipid_timepoint_dict = dict(zip(sample_dict['lipid_ids'], sample_dict['lipid_timepoint']))
met_condition_dict = dict(zip(sample_dict['met_ids'], sample_dict['condition']))
met_timepoint_dict = dict(zip(sample_dict['met_ids'], sample_dict['lipid_timepoint']))
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict_2 = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))


prot_timepoint_dict = {
    "Biostat2L_29_Oscillation_3.5": "Early",
    "Biostat2L_29_Oscillation_4.5": "Early",
    "Biostat2L_29_Oscillation_5.5": "Early",
    "Biostat2L_29_Oscillation_24": "Late",
    "Biostat2L_29_Oscillation_48": "Late",
    "Biostat2L_29_Oscillation_72": "Late",
    "Biostat2L_30_Control_3.5": "Early",
    "Biostat2L_30_Control_4.5": "Early",
    "Biostat2L_30_Control_5.5": "Early",
    "Biostat2L_30_Control_24": "Late",
    "Biostat2L_30_Control_48": "Late",
    "Biostat2L_30_Control_72": "Late",
    "Biostat2L_30_Oscillation_3.5": "Early",
    "Biostat2L_30_Oscillation_4.5": "Early",
    "Biostat2L_30_Oscillation_5.5": "Early",
    "Biostat2L_30_Oscillation_24": "Late",
    "Biostat2L_30_Oscillation_48": "Late",
    "Biostat2L_30_Oscillation_72": "Late",
    "Biostat2L_31_Control_3.5": "Early",
    "Biostat2L_31_Control_4.5": "Early",
    "Biostat2L_31_Control_5.5": "Early",
    "Biostat2L_31_Control_24": "Late",
    "Biostat2L_31_Control_48": "Late",
    "Biostat2L_31_Control_72": "Late",
    "Biostat2L_31_Oscillation_3.5": "Early",
    "Biostat2L_31_Oscillation_4.5": "Early",
    "Biostat2L_31_Oscillation_5.5": "Early",
    "Biostat2L_31_Oscillation_24": "Late",
    "Biostat2L_31_Oscillation_48": "Late",
    "Biostat2L_31_Oscillation_72": "Late",
    "Biostat2L_32_Control_3.5": "Early",
    "Biostat2L_32_Control_4.5": "Early",
    "Biostat2L_32_Control_5.5": "Early",
    "Biostat2L_32_Control_24": "Late",
    "Biostat2L_32_Control_48": "Late",
    "Biostat2L_32_Control_72": "Late",
    "Biostat2L_32_Low_3.5": "Early",
    "Biostat2L_32_Low_4.5": "Early",
    "Biostat2L_32_Low_5.5": "Early",
    "Biostat2L_32_Low_24": "Late",
    "Biostat2L_32_Low_48": "Late",
    "Biostat2L_32_Low_72": "Late",
    "Biostat2L_33_Low_3.5": "Early",
    "Biostat2L_33_Low_4.5": "Early",
    "Biostat2L_33_Low_5.5": "Early",
    "Biostat2L_33_Low_24": "Late",
    "Biostat2L_33_Low_48": "Late",
    "Biostat2L_33_Low_72": "Late",
    "Biostat2L_34_Low_3.5": "Early",
    "Biostat2L_34_Low_4.5": "Early",
    "Biostat2L_34_Low_5.5": "Early",
    "Biostat2L_34_Low_24": "Late",
    "Biostat2L_34_Low_48": "Late",
    "Biostat2L_34_Low_72": "Late",
}

# %% [markdown]
# ## Definitions.

# %%
def plot_pca(pca_df, explained_variance, hue='Condition', time='Timepoint', title=None):
    # Font style
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']

    # Force condition order and assign colors manually
    condition_order = ['Control', 'Low', 'Oscillation']
    color_palette = {
        'Control': '#9467bd',     # purple
        'Low': '#2ca02c',         # red
        'Oscillation': '#6495ED'  # blue
    }
    pca_df[hue] = pd.Categorical(pca_df[hue], categories=condition_order, ordered=True)

    # Timepoint to marker shape
    marker_styles = {
        24.0: 'v',   # triangle down
        48.0: 's',   # square
        72.0: 'D'    # diamond
    }
    default_marker = 'o'
    pca_df['Marker'] = pca_df[time].map(marker_styles).fillna(default_marker)

    # Create the plot
    plt.figure(figsize=(8, 8))
    ax = sns.scatterplot(
        x='PC1', y='PC2',
        hue=hue,
        hue_order=condition_order,
        style='Marker',
        markers={'o': 'o', 'v': 'v', 's': 's', 'D': 'D'},
        palette=color_palette,
        data=pca_df,
        s=150
    )

    # Label axes
    plt.xlabel(f'PC1 ({explained_variance[0]*100:.2f}% variance)', fontsize=24)
    plt.ylabel(f'PC2 ({explained_variance[1]*100:.2f}% variance)', fontsize=24)

    # Custom shape legend
    shape_legend_elements = [
        Line2D([0], [0], marker='o', color='w', label='< 24 h', markersize=10, markerfacecolor='black'),

        Line2D([0], [0], marker='v', color='w', label='24 h', markersize=10, markerfacecolor='black'),
        Line2D([0], [0], marker='s', color='w', label='48 h', markersize=10, markerfacecolor='black'),
        Line2D([0], [0], marker='D', color='w', label='72 h', markersize=10, markerfacecolor='black'),
    ]

    # Manually control legends to prevent cutoff & missing entries
    handles, labels = ax.get_legend_handles_labels()
    condition_handles = [h for h, l in zip(handles, labels) if l in condition_order]
    condition_labels = condition_order  # preserve order

    # Add condition legend
    first_legend = plt.legend(
        condition_handles, condition_labels,
        title=hue, bbox_to_anchor=(0.95, .75), loc='upper left',
        frameon=False, fontsize=16, title_fontsize=16
    )
    ax.add_artist(first_legend)

    # Add timepoint shape legend
    plt.legend(
        title='Time (h)', 
        handles=shape_legend_elements,
        bbox_to_anchor=(1.0, 0.50), loc='upper left',
        frameon=False, fontsize=16, title_fontsize=16
    )

    # Clean up axes and ticks
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_linewidth(0.5)
    ax.spines['bottom'].set_linewidth(0.5)
    ax.tick_params(axis='both', which='major', width=0.5, labelsize=20)
    plt.xticks(size=16)
    plt.yticks(size=16)

    # Prevent legends from getting cut off
    plt.tight_layout()

    # Save if filename provided
    if title:
        # plt.savefig(title, dpi=600, bbox_inches='tight', facecolor='white')
        plt.savefig(title+".png", dpi=600, bbox_inches="tight", facecolor="white")
        # or
        plt.savefig(title+".tiff", dpi=600, bbox_inches="tight")
        plt.savefig(title+".pdf", bbox_inches="tight" )
        plt.savefig(title+".svg", bbox_inches="tight")
    plt.show()


def global_stats_calc_prot(df, condition_series,protein_labels=None):
    # Prepare DataFrame for ANOVA
    # data = df.drop(columns=['Protein', 'ANOVA_p', 'ANOVA_padj'], errors='ignore').copy()
    # data.index = df['Protein']
    t_data = df.transpose()


    unique_conditions = condition_series.unique()

    # Perform ANOVA for each protein
    anova_results = {}
    for protein in t_data.columns:
        
        # Group data based on mapped conditions
        group_data = []
        for condition in unique_conditions:
            indices = condition_series[condition_series == condition].index
            group_data.append(t_data.loc[indices, protein].dropna().values)
        
        # Ensure valid data points are present across all condition groups
        if any(len(group) == 0 for group in group_data):
            print(f"Skipping protein {protein} due to insufficient data in some groups.")
            continue
        
        # Perform ANOVA
        try:
            f_stat, p_value = f_oneway(*group_data)
            anova_results[protein] = p_value
        except Exception as e:
            print(f"Error processing protein {protein}: {e}")
            continue

    # Convert ANOVA results into DataFrame
    anova_df = pd.DataFrame.from_dict(anova_results, orient='index', columns=['ANOVA_p'])

    # Adjust p-values using Benjamini-Hochberg
    anova_df['ANOVA_padj'] = multipletests(anova_df['ANOVA_p'], method='fdr_bh')[1]

    # Merge ANOVA results back to the original DataFrame
    if protein_labels is not None:
        anova_df['Protein'] = protein_labels
        df['Protein'] = protein_labels
    else:
        anova_df['Protein'] = anova_df.index
    merged_df = df.merge(anova_df, on='Protein', how='left')

    return merged_df

def sort_by_significance(df,key_stat='ANOVA_padj'):
    if key_stat not in df.columns:
        raise KeyError("'Key_stat column is missing. Ensure ANOVA has been performed.")
    
    # Sort the DataFrame based on 'ANOVA_p' for significance
    # If you want to use 'ANOVA_padj', you can replace 'ANOVA_p' with 'ANOVA_padj'
    sorted_df = df.sort_values(by=key_stat).copy()

    # Select the top 100 most significant
    top_100_df = sorted_df.head(100)

    return top_100_df

def pca_preprocess(df):
    # Standardize the features
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(df)

    # Perform PCA
    # pca = make_pipeline(StandardScaler(), PCA())

    # pca = PCA()#n_components=2)  # Reduce to 2 components for visualization
    pca = PCA(n_components=2)  # Reduce to 2 components for visualization
    pca_result = pca.fit_transform(df)

    # Capture the explained variance for each component
    explained_variance = pca.explained_variance_ratio_

    # Create a new DataFrame with PCA results
    # pca_df = pd.DataFrame(
    #     pca_result,
    #     columns=[f"PC{i+1}" for i in range(pca_result.shape[1])]
    # )
    pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])
    return pca_df, explained_variance


def get_dynamic_limits(df):
    
    # Compute the overall minimum and maximum values from the dataset
    x_min = df.min()[0]-1
    x_max = df.max()[0]+1
    
    y_min = 0
    y_max = dataset.max()[2]+1

    return x_min,x_max,y_min,y_max


def volcano_plot(dataset,title=None):
    fig,ax = plt.subplots(1,1,figsize=(7,7))

    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']
    
    x_min,x_max, y_min,y_max = get_dynamic_limits(dataset)

    x_limits = (x_min,x_max)
    y_limits = (0,y_max)
    
    y_cutoff = -np.log10(0.05)
    x_cutoff = 0.37851162325
    sns.scatterplot(data = dataset, 
                    x = 'log2FC', 
                    y = '-logP_adj', 
                    hue='class', 
                    s = 25, alpha = 0.5, palette=['#0571B0','#BABABA','#CA0020'], ax=ax)
    legend_handles, _= ax.get_legend_handles_labels()
    
    legend = ax.legend(legend_handles, ['down-regulated','not significant','up-regulated'], 
              bbox_to_anchor=(1,1), 
              title='')
    
    legend.get_frame().set_edgecolor('none')  # Disable the border

    ax.plot(x_limits,[y_cutoff,y_cutoff],'k--')
    ax.plot([x_cutoff,x_cutoff],y_limits,'k--')
    ax.plot([-x_cutoff,-x_cutoff],y_limits,'k--')
    ax.set_ylabel(r'-Log$_2$(P$_{adj}$)', fontsize=24)
    ax.set_xlabel(r'Log$_2$(FC)', fontsize=24)
    if title:
        fig.savefig(title+'.png')

def log2FC_function(df1,df2):
    # substrates 1 dataframe from the second. 
    mean1 = df1.mean(axis=1)
    mean2 = df2.mean(axis=1)
    return (mean1-mean2)



def annotate_top_genes(ax, dataset, num_top=5):
    """
    Annotates the top up-regulated and down-regulated genes on the volcano plot with dynamic text positioning.
    """
    # Sort dataset by log2FC and find top up-regulated and down-regulated genes
    top_up = dataset.nlargest(num_top, 'log2FC')
    top_down = dataset.nsmallest(num_top, 'log2FC')

    # Combine top genes using pd.concat (instead of deprecated append)
    top_genes = pd.concat([top_up, top_down])
    
    for protein_id, row in top_genes.iterrows():
        # Determine text position based on log2FC (right for positive, left for negative)
        if row['log2FC'] > 0:
            xytext = (row['log2FC'] + 0.5, row['-logP_adj'] + 0.5)  # Right-hand side for positive values
        else:
            xytext = (row['log2FC'] - 0.5, row['-logP_adj'] + 0.5)  # Left-hand side for negative values
        
        ax.annotate(
            protein_id, # Annotate with proteinID, which is the index
            xy=(row['log2FC'], row['-logP_adj']), # Point where annotation starts
            xytext=xytext, # Adjust text placement dynamically
            fontsize=10,
            arrowprops=dict(arrowstyle="->", color="black", lw=1.5), # Arrow pointing to the data point
            bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white") # Label background
        )


def volcano_plot_annotate(dataset, title=None):
    """
    Function to plot the volcano plot and annotate the top 5 up-regulated and down-regulated genes with arrows.
    """
    # Extract dynamic plot limits
    x_min, x_max, y_min, y_max = get_dynamic_limits(dataset)
    x_limits = (x_min, x_max)
    y_limits = (0, y_max)

    # Initialize plot
    fig, ax = plt.subplots(1, 1, figsize=(7, 7))
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']

    # Add scatter plot
    sns.scatterplot(data=dataset, 
                    x='log2FC', 
                    y='-logP_adj', 
                    hue='class', 
                    s=25, alpha=0.5, palette=['#0571B0','#BABABA','#CA0020'], ax=ax)
    
    # Add legend
    legend_handles, _ = ax.get_legend_handles_labels()
    legend = ax.legend(legend_handles, ['down-regulated', 'not significant', 'up-regulated'], 
                       bbox_to_anchor=(1, 1), title='')
    legend.get_frame().set_edgecolor('none')  # Disable legend border

    # Draw threshold cutoff lines
    y_cutoff = -np.log10(0.05)
    x_cutoff = 0.37851162325
    ax.plot(x_limits, [y_cutoff, y_cutoff], 'k--')
    ax.plot([x_cutoff, x_cutoff], y_limits, 'k--')
    ax.plot([-x_cutoff, -x_cutoff], y_limits, 'k--')

    # Label axes
    ax.set_ylabel(r'-Log$_2$(P$_{adj}$)', fontsize=24)
    ax.set_xlabel(r'Log$_2$(FC)', fontsize=24)

    # Annotate the top genes
    annotate_top_genes(ax, dataset)

    # Save the plot if a title is provided
    if title:
        fig.savefig(f"{title}.png")

    return fig, ax

# %% [markdown]
# # Read in Annotations.

# %% [markdown]
# Annotations downloaded for FKP355 strain from JGI, June 2025.
#
#
# https://mycocosm.jgi.doe.gov/pages/search-for-genes.jsf?organism=Yarlip1

# %% [markdown]
# ### grab KEGG info.

# %%
KEGGannotate = pd.read_table('../Annotations/Filtered Models ("best")/Functional Annotations/EC annotations and KEGG pathway mappings/YarliW29_1_GeneCatalog_proteins_20190319_KEGG.tab')
# annotate.index = annotate.index.map(str)
KEGGannotate.head()
# Kegg_pathwayDict = dict(zip(annotate.index,annotate.pathway))
# Out:
#    #proteinId     ecNum                                definition  \
# 0           5  4.2.1.24                 Porphobilinogen synthase.
# 1          11   6.1.1.5                  Isoleucine--tRNA ligase.
# 2          11   6.1.1.5                  Isoleucine--tRNA ligase.
# 3          32  3.1.4.46  Glycerophosphodiester phosphodiesterase.
# 4          32  3.1.4.46  Glycerophosphodiester phosphodiesterase.
#
#                                    catalyticActivity cofactors  \
# 0   2 5-aminolevulinate = porphobilinogen + 2 H(2)O.     Zinc.
# 1  ATP + L-isoleucine + tRNA(Ile) = AMP + diphosp...        \N
# 2  ATP + L-isoleucine + tRNA(Ile) = AMP + diphosp...        \N
# 3  A glycerophosphodiester + H(2)O = an alcohol +...        \N
# 4  A glycerophosphodiester + H(2)O = an alcohol +...        \N
#
#                                   associatedDiseases  \
# 0  Susceptibility to lead poisoning; MIM:125270. ...
# 1                                                 \N
# 2                                                 \N
# 3                                                 \N
# 4                                                 \N
#
#                                        pathway  \
# 0         Porphyrin and chlorophyll metabolism
# 1  Valine, leucine and isoleucine biosynthesis
# 2                  Aminoacyl-tRNA biosynthesis
# 3                     Phospholipid degradation
# 4                      Glycerolipid metabolism
#
#                           pathway_class pathway_type
# 0  Metabolism of Cofactors and Vitamins    METABOLIC
# 1                 Amino Acid Metabolism    METABOLIC
# 2                           TRANSLATION   REGULATORY
# 3          Metabolism of Complex Lipids    METABOLIC
# 4          Metabolism of Complex Lipids    METABOLIC

# %%
KEGGannotate.shape
# Out:
# (2516, 9)

# %%
# Group by 'proteinId' and aggregate columns into lists for simpler downstream processing. 
KEGGannotate = KEGGannotate.groupby('#proteinId').agg({
    'definition': list,
    'catalyticActivity': list,
    'pathway': list,
    'pathway_class': list,
    'pathway_type': list,
    'ecNum': list,
    'cofactors': list,
}).reset_index()

# %% [markdown]
# ### grab GO info.

# %%
GOannotate  = pd.read_table('../Annotations/Filtered Models ("best")/Functional Annotations/GO/YarliW29_1_GeneCatalog_proteins_20190319_GO.tab')

GOannotate.head()
# Out:
#    #proteinId  gotermId                             goName  \
# 0           5      3028  porphobilinogen synthase activity
# 1          11       162                 nucleotide binding
# 2          11      3172     aminoacyl-tRNA ligase activity
# 3          11      3736                        ATP binding
# 4          11      3930                          cytoplasm
#
#            gotermType       goAcc
# 0  molecular_function  GO:0004655
# 1  molecular_function  GO:0000166
# 2  molecular_function  GO:0004812
# 3  molecular_function  GO:0005524
# 4  cellular_component  GO:0005737

# %%
# Group by 'proteinId' and aggregate columns into lists for simpler downstream processing. 
GOannotate = GOannotate.groupby('#proteinId').agg({
    'gotermId': list,
    'gotermType': list,
    'goName': list,
    'goAcc': list,
}).reset_index()

# %% [markdown]
# ## Merge annotations.

# %%
merged_annotations = pd.merge(KEGGannotate, GOannotate, on='#proteinId', how='outer')

# Merge the result with df3
# merged_annotations = pd.merge(merged_annotations, KEGGannotate, on='proteinId', how='outer')

# %%
merged_annotations.head()
# Out:
#    #proteinId                                         definition  \
# 0           5                        [Porphobilinogen synthase.]
# 1          11  [Isoleucine--tRNA ligase., Isoleucine--tRNA li...
# 2          12                                                NaN
# 3          13                                                NaN
# 4          14                                                NaN
#
#                                    catalyticActivity  \
# 0  [2 5-aminolevulinate = porphobilinogen + 2 H(2...
# 1  [ATP + L-isoleucine + tRNA(Ile) = AMP + diphos...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              pathway  \
# 0             [Porphyrin and chlorophyll metabolism]
# 1  [Valine, leucine and isoleucine biosynthesis, ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                             pathway_class             pathway_type  \
# 0  [Metabolism of Cofactors and Vitamins]              [METABOLIC]
# 1    [Amino Acid Metabolism, TRANSLATION]  [METABOLIC, REGULATORY]
# 2                                     NaN                      NaN
# 3                                     NaN                      NaN
# 4                                     NaN                      NaN
#
#                 ecNum cofactors  \
# 0          [4.2.1.24]   [Zinc.]
# 1  [6.1.1.5, 6.1.1.5]  [\N, \N]
# 2                 NaN       NaN
# 3                 NaN       NaN
# 4                 NaN       NaN
#
#                                           gotermId  \
# 0                                           [3028]
# 1  [162, 3172, 3736, 3930, 4556, 4561, 3182, 4571]
# 2                                           [3737]
# 3                                     [4604, 5817]
# 4                              [3737, 2378, 24058]
#
#                                           gotermType  \
# 0                               [molecular_function]
# 1  [molecular_function, molecular_function, molec...
# 2                               [molecular_function]
# 3           [biological_process, molecular_function]
# 4  [molecular_function, molecular_function, molec...
#
#                                               goName  \
# 0                [porphobilinogen synthase activity]
# 1  [nucleotide binding, aminoacyl-tRNA ligase act...
# 2                                      [GTP binding]
# 3  [protein amino acid dephosphorylation, protein...
# 4  [GTP binding, GTPase activity, hydrolase activ...
#
#                                                goAcc
# 0                                       [GO:0004655]
# 1  [GO:0000166, GO:0004812, GO:0005524, GO:000573...
# 2                                       [GO:0005525]
# 3                           [GO:0006470, GO:0008138]
# 4               [GO:0005525, GO:0003924, GO:0050800]

# %%
# merged_annotations.to_csv('../Annotations/GO_KEGG_EC_annotations.csv')

# %% [markdown]
# ## grab KOG info.

# %%
kog_annotations = pd.read_table('../Annotations/Filtered Models ("best")/Functional Annotations/YarliW29_1_GeneCatalog_proteins_20190319_KOG.tab')
kog_annotations.rename(columns={'proteinId': '#proteinId'}, inplace=True)

# %%
kog_annotations.head()
# Out:
#    #transcriptId  #proteinId    kogid  \
# 0           6541        5563  KOG0001
# 1           6541        5563  KOG0001
# 2           7831        6853  KOG0004
# 3           8270        7292  KOG0005
# 4           8270        7292  KOG0005
#
#                                     kogdefline  \
# 0        Ubiquitin and ubiquitin-like proteins
# 1        Ubiquitin and ubiquitin-like proteins
# 2  Ubiquitin/40S ribosomal protein S27a fusion
# 3                       Ubiquitin-like protein
# 4                       Ubiquitin-like protein
#
#                                             kogClass  \
# 0  Posttranslational modification, protein turnov...
# 1                  General function prediction only
# 2   Translation, ribosomal structure and biogenesis
# 3  Cell cycle control, cell division, chromosome ...
# 4  Posttranslational modification, protein turnov...
#
#                              kogGroup
# 0    CELLULAR PROCESSES AND SIGNALING
# 1                POORLY CHARACTERIZED
# 2  INFORMATION STORAGE AND PROCESSING
# 3                          METABOLISM
# 4    CELLULAR PROCESSES AND SIGNALING

# %%
# Group by 'proteinId' and aggregate columns into lists for simpler downstream processing. 
kog_annotations = kog_annotations.groupby('#proteinId').agg({
    'kogid': list,
    'kogdefline': list,
    'kogClass': list,
    'kogGroup': list,
}).reset_index()

# %% [markdown]
# ## Merge KOG with KEGG / GO annotations.

# %%
merged_annotations = pd.merge(kog_annotations, merged_annotations, on='#proteinId', how='outer')

# Merge the result with df3
# merged_annotations = pd.merge(merged_annotations, KEGGannotate, on='proteinId', how='outer')

# %%
merged_annotations.head()
# Out:
#    #proteinId      kogid                                         kogdefline  \
# 0           4  [KOG2262]      [Sexual differentiation process protein ISP4]
# 1           5  [KOG0101]  [Molecular chaperones HSP70/HSC70, HSP70 super...
# 2          11  [KOG0434]                        [Isoleucyl-tRNA synthetase]
# 3          12  [KOG1487]       [GTP-binding protein DRG1 (ODN superfamily)]
# 4          13  [KOG1716]                     [Dual specificity phosphatase]
#
#                                             kogClass  \
# 0                  [Signal transduction mechanisms ]
# 1  [Posttranslational modification, protein turno...
# 2  [Translation, ribosomal structure and biogenes...
# 3                  [Signal transduction mechanisms ]
# 4                              [Defense mechanisms ]
#
#                                kogGroup  \
# 0    [CELLULAR PROCESSES AND SIGNALING]
# 1    [CELLULAR PROCESSES AND SIGNALING]
# 2  [INFORMATION STORAGE AND PROCESSING]
# 3    [CELLULAR PROCESSES AND SIGNALING]
# 4    [CELLULAR PROCESSES AND SIGNALING]
#
#                                           definition  \
# 0                                                NaN
# 1                        [Porphobilinogen synthase.]
# 2  [Isoleucine--tRNA ligase., Isoleucine--tRNA li...
# 3                                                NaN
# 4                                                NaN
#
#                                    catalyticActivity  \
# 0                                                NaN
# 1  [2 5-aminolevulinate = porphobilinogen + 2 H(2...
# 2  [ATP + L-isoleucine + tRNA(Ile) = AMP + diphos...
# 3                                                NaN
# 4                                                NaN
#
#                                              pathway  \
# 0                                                NaN
# 1             [Porphyrin and chlorophyll metabolism]
# 2  [Valine, leucine and isoleucine biosynthesis, ...
# 3                                                NaN
# 4                                                NaN
#
#                             pathway_class             pathway_type  \
# 0                                     NaN                      NaN
# 1  [Metabolism of Cofactors and Vitamins]              [METABOLIC]
# 2    [Amino Acid Metabolism, TRANSLATION]  [METABOLIC, REGULATORY]
# 3                                     NaN                      NaN
# 4                                     NaN                      NaN
#
#                 ecNum cofactors  \
# 0                 NaN       NaN
# 1          [4.2.1.24]   [Zinc.]
# 2  [6.1.1.5, 6.1.1.5]  [\N, \N]
# 3                 NaN       NaN
# 4                 NaN       NaN
#
#                                           gotermId  \
# 0                                              NaN
# 1                                           [3028]
# 2  [162, 3172, 3736, 3930, 4556, 4561, 3182, 4571]
# 3                                           [3737]
# 4                                     [4604, 5817]
#
#                                           gotermType  \
# 0                                                NaN
# 1                               [molecular_function]
# 2  [molecular_function, molecular_function, molec...
# 3                               [molecular_function]
# 4           [biological_process, molecular_function]
#
#                                               goName  \
# 0                                                NaN
# 1                [porphobilinogen synthase activity]
# 2  [nucleotide binding, aminoacyl-tRNA ligase act...
# 3                                      [GTP binding]
# 4  [protein amino acid dephosphorylation, protein...
#
#                                                goAcc
# 0                                                NaN
# 1                                       [GO:0004655]
# 2  [GO:0000166, GO:0004812, GO:0005524, GO:000573...
# 3                                       [GO:0005525]
# 4                           [GO:0006470, GO:0008138]

# %% [markdown]
# ## save annotation file.

# %%
# merged_annotations.to_csv('../Annotations/KOG_GO_KEGG_EC_annotations.csv')

# %%
annot_plus_kog = merged_annotations.copy()

# %% [markdown]
# # Read in protein and PTM data.

# %%
# proteomics_data = pd.read_csv('../Data/PPI_yarrowia_REDOX_Global/result/PTM/PPI_yarrowia_protein_abundance.csv')
# with annotations
proteomics_data = pd.read_csv('../Data/Proteomic_PTMs/redox_global/PPI_yarrowia_protein_abundance_wAnnotations.csv')

redox_data = pd.read_csv('../Data/Proteomic_PTMs/redox_global/PPI_yarrowia_all_ptms.csv')
# phospho_data = pd.read_csv('../Data/PPI_yarrowia_REDOX_Global/Phospho/PPI_yarrowia/result/PTM/PPI_yarrowia_all_ptms.csv')
# phospho_data = phospho_data[phospho_data['Type']=='Ph']

redox = redox_data[sample_ids_prot_redox]

# %% [markdown]
# df['YALI1_protID'] = df['proteinId'].map(JGI_Yali1.set_index('JGI_protID')['YALI1_protID'])
# df['YALI0_locus'] = df['YALI1_protID'].map(Yali1_Yali0.set_index('YALI1_Proteins')['YALI0_locus_ID'])
# df['YALI1_protID_converted'] = df['YALI1_protID'].str.replace('g', 'p', regex=False)
# df['YALI2'] = df['YALI1_protID_converted'].map(Yali1_Yali2.set_index('YALI1')['YALI2'])

# %%
phospho_data = pd.read_csv('../Data/Proteomic_PTMs/phospho/PPI_yarrowia_all_ptms.csv')

# %%
phospho_data = phospho_data[phospho_data['Type']=='Ph']

# %%
phos = phospho_data[sample_ids_prot_redox]
phos.dropna(axis=0, inplace=True)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_56072/4208503721.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phos.dropna(axis=0, inplace=True)

# %%
prot = proteomics_data[sample_ids_prot_redox]

redox = redox_data[sample_ids_prot_redox]

prot.dropna(axis=0, inplace=True)
redox.dropna(axis=0, inplace=True)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_56072/1923882063.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prot.dropna(axis=0, inplace=True)
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_56072/1923882063.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   redox.dropna(axis=0, inplace=True)

# %% [markdown]
# ## PCA plots of PTM global proteom.

# %%
# features['Condition'] = features.index.map(condition_dict3)
features = prot.T
pca_df, explained_variance = pca_preprocess(features)
features['Condition'] = features.index.map(prot_condition_dict)
features.head()
pca_df['Condition'] = features['Condition'].values
# pca_df['Timepoint'] = features.index.map(prot_timepoint_dict)
pca_df['Timepoint'] = features.index.map(prot_timepoint_dict_2)


pca_df['Batch']=0
# pca_df[pca_df.index<15]['Batch']=1
# pca_df['Reactor'] = df['Reactor'].values

pca_df.loc[pca_df.index <= 17, 'Batch'] = 1
pca_df.loc[pca_df.index > 17, 'Batch'] = 2
plot_pca(pca_df, explained_variance, title='pca_globalProt_condition')

# %%
features = redox.T
pca_df, explained_variance = pca_preprocess(features)
features['Condition'] = features.index.map(prot_condition_dict)
# features['Timepoint'] = features.index.map(prot_timepoint_dict)
features['Timepoint'] = features.index.map(prot_timepoint_dict_2)

pca_df['Condition'] = features['Condition'].values
pca_df['Timepoint'] = features['Timepoint'].values


pca_df['Batch']=0
# pca_df[pca_df.index<15]['Batch']=1
# pca_df['Reactor'] = df['Reactor'].values
pca_df.loc[pca_df.index <= 17, 'Batch'] = 1
pca_df.loc[pca_df.index > 17, 'Batch'] = 2
plot_pca(pca_df, explained_variance,title='pca_redox_condition')

# %%
features = phos.T
pca_df, explained_variance = pca_preprocess(features)
features['Condition'] = features.index.map(prot_condition_dict)
features['Timepoint'] = features.index.map(prot_timepoint_dict_2)
# features['Timepoint'] = features.index.map(prot_timepoint_dict)

pca_df['Condition'] = features['Condition'].values
pca_df['Timepoint'] = features['Timepoint'].values


pca_df['Batch']=0
# pca_df[pca_df.index<15]['Batch']=1
# pca_df['Reactor'] = df['Reactor'].values
pca_df.loc[pca_df.index <= 17, 'Batch'] = 1
pca_df.loc[pca_df.index > 17, 'Batch'] = 2
plot_pca(pca_df, explained_variance,title='pca_phos_condition')

# %% [markdown]
# # Differential Expression of Global Prot.

# %% [markdown]
# ## Compare Control late vs early.

# %%
prot = proteomics_data[sample_ids_prot_redox]
proteomics_data['Protein'] = proteomics_data['Site']
prot.index = proteomics_data['Protein']
# drop oscillations, low. 
prot_control_late_vs_early_combined = prot.drop(prot.columns[prot.columns.str.contains("Oscillation|Low")], axis=1)

# %%
prot_control_late_vs_early_combined.columns
# Out:
# Index(['Biostat2L_30_Control_3.5', 'Biostat2L_30_Control_4.5',
#        'Biostat2L_30_Control_5.5', 'Biostat2L_30_Control_24',
#        'Biostat2L_30_Control_48', 'Biostat2L_30_Control_72',
#        'Biostat2L_31_Control_3.5', 'Biostat2L_31_Control_4.5',
#        'Biostat2L_31_Control_5.5', 'Biostat2L_31_Control_24',
#        'Biostat2L_31_Control_48', 'Biostat2L_31_Control_72',
#        'Biostat2L_32_Control_3.5', 'Biostat2L_32_Control_4.5',
#        'Biostat2L_32_Control_5.5', 'Biostat2L_32_Control_24',
#        'Biostat2L_32_Control_48', 'Biostat2L_32_Control_72'],
#       dtype='object')

# %%
# prot_timepoint_dict initialized in annotation section. 
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))

# %% [markdown]
# ### Prep for p-values.

# %%
# group for mapping in nanova. 
condition_series = pd.Series(prot_control_late_vs_early_combined.columns).map(prot_timepoint_dict)
condition_series.index = prot_control_late_vs_early_combined.columns
condition_series
# Out:
# Biostat2L_30_Control_3.5    Early
# Biostat2L_30_Control_4.5    Early
# Biostat2L_30_Control_5.5    Early
# Biostat2L_30_Control_24      Late
# Biostat2L_30_Control_48      Late
# Biostat2L_30_Control_72      Late
# Biostat2L_31_Control_3.5    Early
# Biostat2L_31_Control_4.5    Early
# Biostat2L_31_Control_5.5    Early
# Biostat2L_31_Control_24      Late
# Biostat2L_31_Control_48      Late
# Biostat2L_31_Control_72      Late
# Biostat2L_32_Control_3.5    Early
# Biostat2L_32_Control_4.5    Early
# Biostat2L_32_Control_5.5    Early
# Biostat2L_32_Control_24      Late
# Biostat2L_32_Control_48      Late
# Biostat2L_32_Control_72      Late
# dtype: object

# %%
# calculate p-values. 
prot_control_late_vs_early_combined_stats = global_stats_calc_prot(prot_control_late_vs_early_combined,condition_series)

# %%
prot_control_late_vs_early_combined_stats
# Out:
#                       Protein  Biostat2L_30_Control_3.5  \
# 0      jgi|YarliW29_1|100@GLB                 25.620312
# 1     jgi|YarliW29_1|1000@GLB                 18.042939
# 2     jgi|YarliW29_1|1002@GLB                 24.269189
# 3     jgi|YarliW29_1|1003@GLB                 22.795371
# 4     jgi|YarliW29_1|1004@GLB                 23.298582
# ...                       ...                       ...
# 2754   jgi|YarliW29_1|976@GLB                 24.185245
# 2755   jgi|YarliW29_1|979@GLB                 19.736612
# 2756   jgi|YarliW29_1|982@GLB                 20.883049
# 2757   jgi|YarliW29_1|994@GLB                 23.604555
# 2758   jgi|YarliW29_1|999@GLB                 19.544506
#
#       Biostat2L_30_Control_4.5  Biostat2L_30_Control_5.5  \
# 0                    25.624321                 25.764281
# 1                    18.566494                 18.326494
# 2                    25.312090                 25.154168
# 3                    22.970198                 22.780983
# 4                    23.559677                 23.643344
# ...                        ...                       ...
# 2754                 24.147104                 23.950941
# 2755                 19.916711                 19.875377
# 2756                 20.867039                 20.826988
# 2757                 23.631015                 23.588981
# 2758                 19.845140                 19.817470
#
#       Biostat2L_30_Control_24  Biostat2L_30_Control_48  \
# 0                   25.457543                25.455410
# 1                   17.495514                17.187438
# 2                   22.626837                22.329658
# 3                   21.925310                21.766074
# 4                   25.556813                26.004931
# ...                       ...                      ...
# 2754                23.547418                23.734165
# 2755                20.485113                20.436726
# 2756                21.064355                21.452746
# 2757                23.720030                23.762789
# 2758                20.310288                20.458884
#
#       Biostat2L_30_Control_72  Biostat2L_31_Control_3.5  \
# 0                   25.217178                 25.411074
# 1                   17.406634                 18.109250
# 2                   22.331261                 24.163948
# 3                   21.829104                 22.776268
# 4                   26.278545                 23.545643
# ...                       ...                       ...
# 2754                23.847708                 24.325865
# 2755                20.360083                 19.708205
# 2756                21.679302                 20.844712
# 2757                23.788435                 23.694479
# 2758                20.644705                 19.528336
#
#       Biostat2L_31_Control_4.5  Biostat2L_31_Control_5.5  ...  \
# 0                    25.524545                 25.540872  ...
# 1                    18.146037                 18.268834  ...
# 2                    25.107072                 24.896838  ...
# 3                    22.850626                 22.831415  ...
# 4                    23.635451                 23.680295  ...
# ...                        ...                       ...  ...
# 2754                 24.024101                 23.925307  ...
# 2755                 19.884992                 19.896070  ...
# 2756                 20.807400                 20.841102  ...
# 2757                 23.647181                 23.566868  ...
# 2758                 19.658023                 19.889454  ...
#
#       Biostat2L_31_Control_48  Biostat2L_31_Control_72  \
# 0                   25.201089                25.167410
# 1                   17.158660                17.354388
# 2                   22.197972                22.248940
# 3                   21.767955                21.832119
# 4                   26.082427                26.324661
# ...                       ...                      ...
# 2754                23.655532                23.661952
# 2755                20.408309                20.578521
# 2756                21.335776                21.661598
# 2757                23.766670                23.783017
# 2758                20.536590                20.647440
#
#       Biostat2L_32_Control_3.5  Biostat2L_32_Control_4.5  \
# 0                    25.407241                 25.435482
# 1                    18.158927                 18.378141
# 2                    24.013123                 25.159896
# 3                    22.818493                 22.958359
# 4                    23.541651                 23.739604
# ...                        ...                       ...
# 2754                 24.141060                 24.059585
# 2755                 19.826014                 19.810277
# 2756                 20.907069                 20.739001
# 2757                 23.680782                 23.608196
# 2758                 19.526563                 19.712211
#
#       Biostat2L_32_Control_5.5  Biostat2L_32_Control_24  \
# 0                    25.619442                25.444125
# 1                    18.132837                17.493245
# 2                    24.902267                22.664340
# 3                    22.784787                21.974737
# 4                    23.734051                25.995544
# ...                        ...                      ...
# 2754                 23.923076                23.738355
# 2755                 19.860962                20.505349
# 2756                 20.773919                21.008366
# 2757                 23.604298                23.770805
# 2758                 19.672278                20.324818
#
#       Biostat2L_32_Control_48  Biostat2L_32_Control_72       ANOVA_p  \
# 0                   25.409470                24.962255  8.985946e-03
# 1                   17.306625                17.229185  5.624651e-10
# 2                   22.322748                22.140471  3.144760e-10
# 3                   21.819088                21.820224  5.455562e-15
# 4                   26.272773                26.256044  2.311991e-14
# ...                       ...                      ...           ...
# 2754                23.714951                23.628928  2.074343e-06
# 2755                20.479715                20.507610  1.027066e-12
# 2756                21.373182                21.546767  3.208782e-05
# 2757                23.821185                23.750398  6.920939e-07
# 2758                20.618529                20.714405  1.367773e-08
#
#         ANOVA_padj
# 0     1.143026e-02
# 1     2.255583e-09
# 2     1.347266e-09
# 3     1.881487e-13
# 4     5.824403e-13
# ...            ...
# 2754  4.033201e-06
# 2755  1.166121e-11
# 2756  5.329539e-05
# 2757  1.446581e-06
# 2758  3.801088e-08
#
# [2759 rows x 21 columns]

# %%
# Extract the number between "YarliW29_1|" and "@GLB" using regex
prot_control_late_vs_early_combined_stats["proteinID"] = prot_control_late_vs_early_combined_stats["Protein"].str.extract(r"YarliW29_1\|(\d+)@GLB")

# Convert the extracted number to integer (if needed)
prot_control_late_vs_early_combined_stats["proteinID"] = prot_control_late_vs_early_combined_stats["proteinID"].astype(int)

# %%
prot_control_late_vs_early_combined_stats.head()
# Out:
#                    Protein  Biostat2L_30_Control_3.5  \
# 0   jgi|YarliW29_1|100@GLB                 25.620312
# 1  jgi|YarliW29_1|1000@GLB                 18.042939
# 2  jgi|YarliW29_1|1002@GLB                 24.269189
# 3  jgi|YarliW29_1|1003@GLB                 22.795371
# 4  jgi|YarliW29_1|1004@GLB                 23.298582
#
#    Biostat2L_30_Control_4.5  Biostat2L_30_Control_5.5  \
# 0                 25.624321                 25.764281
# 1                 18.566494                 18.326494
# 2                 25.312090                 25.154168
# 3                 22.970198                 22.780983
# 4                 23.559677                 23.643344
#
#    Biostat2L_30_Control_24  Biostat2L_30_Control_48  Biostat2L_30_Control_72  \
# 0                25.457543                25.455410                25.217178
# 1                17.495514                17.187438                17.406634
# 2                22.626837                22.329658                22.331261
# 3                21.925310                21.766074                21.829104
# 4                25.556813                26.004931                26.278545
#
#    Biostat2L_31_Control_3.5  Biostat2L_31_Control_4.5  \
# 0                 25.411074                 25.524545
# 1                 18.109250                 18.146037
# 2                 24.163948                 25.107072
# 3                 22.776268                 22.850626
# 4                 23.545643                 23.635451
#
#    Biostat2L_31_Control_5.5  ...  Biostat2L_31_Control_72  \
# 0                 25.540872  ...                25.167410
# 1                 18.268834  ...                17.354388
# 2                 24.896838  ...                22.248940
# 3                 22.831415  ...                21.832119
# 4                 23.680295  ...                26.324661
#
#    Biostat2L_32_Control_3.5  Biostat2L_32_Control_4.5  \
# 0                 25.407241                 25.435482
# 1                 18.158927                 18.378141
# 2                 24.013123                 25.159896
# 3                 22.818493                 22.958359
# 4                 23.541651                 23.739604
#
#    Biostat2L_32_Control_5.5  Biostat2L_32_Control_24  Biostat2L_32_Control_48  \
# 0                 25.619442                25.444125                25.409470
# 1                 18.132837                17.493245                17.306625
# 2                 24.902267                22.664340                22.322748
# 3                 22.784787                21.974737                21.819088
# 4                 23.734051                25.995544                26.272773
#
#    Biostat2L_32_Control_72       ANOVA_p    ANOVA_padj  proteinID
# 0                24.962255  8.985946e-03  1.143026e-02        100
# 1                17.229185  5.624651e-10  2.255583e-09       1000
# 2                22.140471  3.144760e-10  1.347266e-09       1002
# 3                21.820224  5.455562e-15  1.881487e-13       1003
# 4                26.256044  2.311991e-14  5.824403e-13       1004
#
# [5 rows x 22 columns]

# %% [markdown]
# ### calculate log2FC

# %%
early = prot_control_late_vs_early_combined_stats.loc[:, prot_control_late_vs_early_combined_stats.columns[prot_control_late_vs_early_combined_stats.columns.str.contains("3.5|4.5|5.5")]]
early.head()

# 24 h
# Out:
#    Biostat2L_30_Control_3.5  Biostat2L_30_Control_4.5  \
# 0                 25.620312                 25.624321
# 1                 18.042939                 18.566494
# 2                 24.269189                 25.312090
# 3                 22.795371                 22.970198
# 4                 23.298582                 23.559677
#
#    Biostat2L_30_Control_5.5  Biostat2L_31_Control_3.5  \
# 0                 25.764281                 25.411074
# 1                 18.326494                 18.109250
# 2                 25.154168                 24.163948
# 3                 22.780983                 22.776268
# 4                 23.643344                 23.545643
#
#    Biostat2L_31_Control_4.5  Biostat2L_31_Control_5.5  \
# 0                 25.524545                 25.540872
# 1                 18.146037                 18.268834
# 2                 25.107072                 24.896838
# 3                 22.850626                 22.831415
# 4                 23.635451                 23.680295
#
#    Biostat2L_32_Control_3.5  Biostat2L_32_Control_4.5  \
# 0                 25.407241                 25.435482
# 1                 18.158927                 18.378141
# 2                 24.013123                 25.159896
# 3                 22.818493                 22.958359
# 4                 23.541651                 23.739604
#
#    Biostat2L_32_Control_5.5
# 0                 25.619442
# 1                 18.132837
# 2                 24.902267
# 3                 22.784787
# 4                 23.734051

# %%
late = prot_control_late_vs_early_combined_stats.loc[:, prot_control_late_vs_early_combined_stats.columns[prot_control_late_vs_early_combined_stats.columns.str.contains("24|48|72")]]
late.head()

# 24 h
# Out:
#    Biostat2L_30_Control_24  Biostat2L_30_Control_48  Biostat2L_30_Control_72  \
# 0                25.457543                25.455410                25.217178
# 1                17.495514                17.187438                17.406634
# 2                22.626837                22.329658                22.331261
# 3                21.925310                21.766074                21.829104
# 4                25.556813                26.004931                26.278545
#
#    Biostat2L_31_Control_24  Biostat2L_31_Control_48  Biostat2L_31_Control_72  \
# 0                25.585560                25.201089                25.167410
# 1                17.383958                17.158660                17.354388
# 2                22.556796                22.197972                22.248940
# 3                21.943296                21.767955                21.832119
# 4                25.796548                26.082427                26.324661
#
#    Biostat2L_32_Control_24  Biostat2L_32_Control_48  Biostat2L_32_Control_72
# 0                25.444125                25.409470                24.962255
# 1                17.493245                17.306625                17.229185
# 2                22.664340                22.322748                22.140471
# 3                21.974737                21.819088                21.820224
# 4                25.995544                26.272773                26.256044

# %%
# gives the increase of the first. 
prot_control_late_vs_early_combined_stats['log2FC']=log2FC_function(early,late)

# %%
df_to_merge = pd.DataFrame()
df_to_merge['early/late'] = prot_control_late_vs_early_combined_stats['log2FC']
df_to_merge['proteinId'] = prot_control_late_vs_early_combined_stats['proteinID']
df_to_merge['early/late_ANOVA_padj'] = prot_control_late_vs_early_combined_stats['ANOVA_padj']
df_to_merge['early/late_ANOVA_p'] = prot_control_late_vs_early_combined_stats['ANOVA_p']

# %%
merged_df = pd.merge(proteomics_data, df_to_merge, left_on='proteinId',right_on='proteinId', how='left')

# %%
merged_df.head(20)
# Out:
#     Biostat2L_29_Oscillation_24  Biostat2L_29_Oscillation_3.5  \
# 0                     25.770213                     25.369272
# 1                     17.293959                     18.245944
# 2                     22.817965                     23.813276
# 3                     21.661173                     22.834460
# 4                     24.612309                     23.180487
# 5                     19.170143                     19.099859
# 6                     19.832808                     19.291079
# 7                     21.191147                     20.473049
# 8                     20.746908                     19.912286
# 9                     24.844245                     23.817512
# 10                    18.626898                     19.098223
# 11                    19.427169                     20.874230
# 12                          NaN                           NaN
# 13                    21.038860                     21.847791
# 14                    23.611131                     23.083143
# 15                    23.502803                     22.454384
# 16                    17.303136                     17.173380
# 17                    25.365749                     25.799364
# 18                    22.419831                     21.742002
# 19                    21.295161                     20.621121
#
#     Biostat2L_29_Oscillation_4.5  Biostat2L_29_Oscillation_48  \
# 0                      25.511412                    25.649494
# 1                      18.186630                    16.996140
# 2                      25.302130                    22.221128
# 3                      22.811937                    21.343351
# 4                      23.514879                    26.057785
# 5                      19.130301                    19.516358
# 6                      19.403216                    19.718643
# 7                      20.521454                    20.670665
# 8                      20.140910                    20.736697
# 9                      23.788359                    25.494086
# 10                     18.709602                    18.635055
# 11                     20.946974                    19.534724
# 12                           NaN                          NaN
# 13                     21.789493                    20.566591
# 14                     22.850264                    23.422226
# 15                     22.482354                    23.557559
# 16                     17.143936                    17.484131
# 17                     26.091535                    24.873230
# 18                     21.729927                    22.455743
# 19                     20.546592                    21.679607
#
#     Biostat2L_29_Oscillation_5.5  Biostat2L_29_Oscillation_72  \
# 0                      25.666597                    25.495693
# 1                      18.011891                    16.940736
# 2                      25.155731                    22.204025
# 3                      22.638917                    21.351494
# 4                      23.618234                    26.347074
# 5                      19.233001                    19.351713
# 6                      19.416530                    19.756749
# 7                      20.493335                    20.465718
# 8                      20.229398                    20.664103
# 9                      23.795971                    25.457786
# 10                     18.987463                    18.275425
# 11                     20.857344                    19.560324
# 12                           NaN                          NaN
# 13                     21.538678                    20.468640
# 14                     23.103606                    23.158692
# 15                     22.569621                    23.496478
# 16                     17.136935                    17.623963
# 17                     26.226551                    24.719508
# 18                     21.997831                    22.435971
# 19                     20.723806                    21.744901
#
#     Biostat2L_30_Control_24  Biostat2L_30_Control_3.5  \
# 0                 25.457543                 25.620312
# 1                 17.495514                 18.042939
# 2                 22.626837                 24.269189
# 3                 21.925310                 22.795371
# 4                 25.556813                 23.298582
# 5                 18.600041                 19.364405
# 6                 19.847332                 19.357177
# 7                 21.188276                 20.309949
# 8                 20.935951                 19.791703
# 9                 25.155977                 23.977720
# 10                18.573947                 18.778430
# 11                20.248282                 20.876796
# 12                17.863364                 18.571953
# 13                20.931999                 21.721825
# 14                23.049919                 23.156217
# 15                23.530914                 22.408786
# 16                17.551380                 17.169403
# 17                25.955489                 26.034642
# 18                22.790453                 21.671254
# 19                21.342802                 20.620416
#
#     Biostat2L_30_Control_4.5  Biostat2L_30_Control_48  ...  \
# 0                  25.624321                25.455410  ...
# 1                  18.566494                17.187438  ...
# 2                  25.312090                22.329658  ...
# 3                  22.970198                21.766074  ...
# 4                  23.559677                26.004931  ...
# 5                  19.315402                18.939302  ...
# 6                  19.469197                19.923761  ...
# 7                  20.325637                21.062829  ...
# 8                  20.213997                20.638092  ...
# 9                  23.981216                25.591142  ...
# 10                 18.786367                18.568092  ...
# 11                 21.119938                20.280289  ...
# 12                 18.713493                17.898284  ...
# 13                 21.665786                20.610626  ...
# 14                 22.482876                23.181027  ...
# 15                 22.437598                23.793859  ...
# 16                 17.390297                17.926589  ...
# 17                 26.003845                25.540278  ...
# 18                 21.704516                22.819898  ...
# 19                 20.623090                21.620287  ...
#
#                                            gotermType  \
# 0              biological_process, molecular_function
# 1                                                 NaN
# 2   biological_process, molecular_function, cellul...
# 3   molecular_function, biological_process, cellul...
# 4              molecular_function, biological_process
# 5   cellular_component, biological_process, molecu...
# 6   molecular_function, cellular_component, biolog...
# 7                                                 NaN
# 8              molecular_function, biological_process
# 9                                  cellular_component
# 10                                 molecular_function
# 11                                 molecular_function
# 12             molecular_function, biological_process
# 13  molecular_function, cellular_component, biolog...
# 14                                                NaN
# 15                                 biological_process
# 16                                                NaN
# 17             molecular_function, biological_process
# 18  biological_process, cellular_component, molecu...
# 19                                                NaN
#
#                                                 goAcc  #transcriptId    kogid  \
# 0                  GO:0008152, GO:0016779, GO:0003983         1078.0  KOG2638
# 1                                                 NaN            NaN      NaN
# 2   GO:0008152, GO:0003861, GO:0009098, GO:0009316...         1980.0  KOG0454
# 3   GO:0004222, GO:0005524, GO:0006508, GO:0000166...         1981.0  KOG0734
# 4      GO:0004185, GO:0006508, GO:0004186, GO:0004258         1982.0  KOG1282
# 5                  GO:0005740, GO:0006122, GO:0008121         1986.0  KOG3494
# 6                  GO:0005097, GO:0005622, GO:0032313         1990.0  KOG4347
# 7                                                 NaN         1993.0  KOG1235
# 8                              GO:0008080, GO:0008152            NaN      NaN
# 9                                          GO:0005783         1995.0  KOG1792
# 10                             GO:0000049, GO:0004831         1996.0  KOG2241
# 11                                         GO:0016804            NaN      NaN
# 12                             GO:0008531, GO:0009231         2000.0  KOG3110
# 13     GO:0003735, GO:0005622, GO:0005840, GO:0006412         2004.0  KOG0398
# 14                                                NaN            NaN      NaN
# 15                                         GO:0008202         1081.0  KOG2210
# 16                                                NaN            NaN      NaN
# 17  GO:0003824, GO:0009058, GO:0030170, GO:0016769...         2014.0  KOG1411
# 18     GO:0006886, GO:0016020, GO:0005515, GO:0016192         2021.0  KOG1666
# 19                                                NaN         2022.0  KOG0527
#
#                                            kogdefline  \
# 0                       UDP-glucose pyrophosphorylase
# 1                                                 NaN
# 2   3-isopropylmalate dehydratase (aconitase super...
# 3   AAA+-type ATPase containing the peptidase M41 ...
# 4    Serine carboxypeptidases (lysosomal cathepsin A)
# 5   Ubiquinol cytochrome c oxidoreductase, subunit...
# 6                       GTPase-activating protein VRP
# 7                    Predicted unusual protein kinase
# 8                                                 NaN
# 9                                           Reticulon
# 10                               tRNA-binding protein
# 11                                                NaN
# 12                                  Riboflavin kinase
# 13  Mitochondrial/chloroplast ribosomal protein L5/L7
# 14                                                NaN
# 15                          Oxysterol-binding protein
# 16                                                NaN
# 17  Aspartate aminotransferase/Glutamic oxaloaceti...
# 18                                            V-SNARE
# 19                       HMG-box transcription factor
#
#                                              kogClass  \
# 0               Carbohydrate transport and metabolism
# 1                                                 NaN
# 2                 Amino acid transport and metabolism
# 3   Posttranslational modification, protein turnov...
# 4   Amino acid transport and metabolism, Posttrans...
# 5                    Energy production and conversion
# 6                    General function prediction only
# 7                    General function prediction only
# 8                                                 NaN
# 9   Intracellular trafficking, secretion, and vesi...
# 10    Translation, ribosomal structure and biogenesis
# 11                                                NaN
# 12                  Coenzyme transport and metabolism
# 13    Translation, ribosomal structure and biogenesis
# 14                                                NaN
# 15                     Signal transduction mechanisms
# 16                                                NaN
# 17                Amino acid transport and metabolism
# 18  Intracellular trafficking, secretion, and vesi...
# 19                                      Transcription
#
#                                         kogGroup  early/late  \
# 0                                     METABOLISM    0.227504
# 1                                            NaN    0.901589
# 2                                     METABOLISM    2.395508
# 3               CELLULAR PROCESSES AND SIGNALING    0.987622
# 4   METABOLISM, CELLULAR PROCESSES AND SIGNALING   -2.465554
# 5                                     METABOLISM    0.504706
# 6                           POORLY CHARACTERIZED   -0.448336
# 7                           POORLY CHARACTERIZED   -0.722948
# 8                                            NaN   -0.632109
# 9               CELLULAR PROCESSES AND SIGNALING   -1.355286
# 10            INFORMATION STORAGE AND PROCESSING    0.166887
# 11                                           NaN    0.534361
# 12                                    METABOLISM    0.831366
# 13            INFORMATION STORAGE AND PROCESSING    0.881654
# 14                                           NaN   -0.336382
# 15              CELLULAR PROCESSES AND SIGNALING   -1.168790
# 16                                           NaN   -0.443570
# 17                                    METABOLISM    0.587828
# 18              CELLULAR PROCESSES AND SIGNALING   -0.925061
# 19            INFORMATION STORAGE AND PROCESSING   -0.918640
#
#     early/late_ANOVA_padj  early/late_ANOVA_p
# 0            1.143026e-02        8.985946e-03
# 1            2.255583e-09        5.624651e-10
# 2            1.347266e-09        3.144760e-10
# 3            1.881487e-13        5.455562e-15
# 4            5.824403e-13        2.311991e-14
# 5            5.329539e-05        3.210472e-05
# 6            1.685166e-10        2.601960e-11
# 7            1.421362e-09        3.343473e-10
# 8            4.720234e-07        2.075261e-07
# 9            5.048688e-12        3.458507e-13
# 10           7.437118e-03        5.749682e-03
# 11           1.145012e-07        4.519458e-08
# 12           1.442485e-09        3.408846e-10
# 13           1.390870e-08        4.406017e-09
# 14           6.030635e-03        4.609200e-03
# 15           2.075344e-12        1.150880e-13
# 16           6.295565e-06        3.365697e-06
# 17           4.552239e-06        2.357792e-06
# 18           4.452584e-10        8.431727e-11
# 19           4.926975e-10        9.607513e-11
#
# [20 rows x 194 columns]

# %%
prot_control_late_vs_early_combined_stats_withAnnote = pd.merge(prot_control_late_vs_early_combined_stats, merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')

# %% [markdown]
# ### optional save.

# %%
# prot_control_late_vs_early_combined_stats_withAnnote.to_csv('early_vs_late.csv')

# %% [markdown]
# ### Volcano plot comparing late vs early.
# all late (increase means increased in low)

# %%
dataset = prot_control_late_vs_early_combined_stats_withAnnote[['log2FC', 'ANOVA_padj']].copy()
dataset.index = prot_control_late_vs_early_combined_stats_withAnnote.proteinID

# %%
log2FC_threshold = np.log2(1.3)

# %%
dataset
# Out:
#              log2FC    ANOVA_padj
# proteinID
# 100        0.227504  1.143026e-02
# 1000       0.901589  2.255583e-09
# 1002       2.395508  1.347266e-09
# 1003       0.987622  1.881487e-13
# 1004      -2.465554  5.824403e-13
# ...             ...           ...
# 976        0.384033  4.033201e-06
# 979       -0.637626  1.166121e-11
# 982       -0.516335  5.329539e-05
# 994       -0.155734  1.446581e-06
# 999       -0.805891  3.801088e-08
#
# [2759 rows x 2 columns]

# %%
# subset the log2FC and the P_value for this dataset. 
dataset.columns = ['log2FC','P_value']

# obtain the -logP_adj for the dataset. 
dataset['-logP_adj'] = -np.log10(dataset['P_value'])

# set a class for up (1) or down (-1) proteins. 
dataset['class'] = 0
dataset.loc[(dataset['log2FC']>log2FC_threshold)&(dataset['-logP_adj']>-np.log10(0.05)),'class'] = 1
dataset.loc[(dataset['log2FC']<-log2FC_threshold)&(dataset['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
volcano_plot(dataset)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_56072/3268818367.py:182: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_min = df.min()[0]-1
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_56072/3268818367.py:183: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_max = df.max()[0]+1
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_56072/3268818367.py:186: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_max = dataset.max()[2]+1

# %% [markdown]
# ## Compare Control vs low. Start with all late (24-72).

# %%
prot = proteomics_data[sample_ids_prot_redox]
proteomics_data['Protein'] = proteomics_data['Site']
prot.index = proteomics_data['Protein']
# drop oscillations.
prot_control_vs_low_late_combined = prot.drop(prot.columns[prot.columns.str.contains("Oscillation")], axis=1)
# prot_control_vs_oscillation_late_combined = prot.drop(prot.columns[prot.columns.str.contains("Low")], axis=1)
prot_control_vs_low_24h = prot.drop(prot.columns[prot.columns.str.contains("Oscillation")], axis=1)


# drop early timepoints. 
prot_control_vs_low_late_combined = prot_control_vs_low_late_combined.drop(prot_control_vs_low_late_combined.columns[
    prot_control_vs_low_late_combined.columns.str.contains("5.5|3.5|4.5")], axis=1)

# prot_control_vs_low_24h = prot_control_vs_low_24h.drop(prot_control_vs_low_24h.columns[
#     prot_control_vs_low_24h.columns.str.contains("5.5|3.5|4.5|48|72")], axis=1)

# %%
prot_control_vs_low_late_combined.columns
# Out:
# Index(['Biostat2L_30_Control_24', 'Biostat2L_30_Control_48',
#        'Biostat2L_30_Control_72', 'Biostat2L_31_Control_24',
#        'Biostat2L_31_Control_48', 'Biostat2L_31_Control_72',
#        'Biostat2L_32_Control_24', 'Biostat2L_32_Control_48',
#        'Biostat2L_32_Control_72', 'Biostat2L_32_Low_24', 'Biostat2L_32_Low_48',
#        'Biostat2L_32_Low_72', 'Biostat2L_33_Low_24', 'Biostat2L_33_Low_48',
#        'Biostat2L_33_Low_72', 'Biostat2L_34_Low_24', 'Biostat2L_34_Low_48',
#        'Biostat2L_34_Low_72'],
#       dtype='object')

# %%
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))

# %% [markdown]
# ### Prep for p-values.

# %%
# group for mapping in nanova. 
condition_series = pd.Series(prot_control_vs_low_late_combined.columns).map(prot_condition_dict)
condition_series.index = prot_control_vs_low_late_combined.columns
condition_series 

condition_series24h = pd.Series(prot_control_vs_low_24h.columns).map(prot_condition_dict)
condition_series24h.index = prot_control_vs_low_24h.columns
condition_series24h
# Out:
# Biostat2L_30_Control_24    Control
# Biostat2L_31_Control_24    Control
# Biostat2L_32_Control_24    Control
# Biostat2L_32_Low_24            Low
# Biostat2L_33_Low_24            Low
# Biostat2L_34_Low_24            Low
# dtype: object

# %%
prot.head()
# Out:
#                          Biostat2L_29_Oscillation_3.5  \
# Protein
# jgi|YarliW29_1|100@GLB                      25.369272
# jgi|YarliW29_1|1000@GLB                     18.245944
# jgi|YarliW29_1|1002@GLB                     23.813276
# jgi|YarliW29_1|1003@GLB                     22.834460
# jgi|YarliW29_1|1004@GLB                     23.180487
#
#                          Biostat2L_29_Oscillation_4.5  \
# Protein
# jgi|YarliW29_1|100@GLB                      25.511412
# jgi|YarliW29_1|1000@GLB                     18.186630
# jgi|YarliW29_1|1002@GLB                     25.302130
# jgi|YarliW29_1|1003@GLB                     22.811937
# jgi|YarliW29_1|1004@GLB                     23.514879
#
#                          Biostat2L_29_Oscillation_5.5  \
# Protein
# jgi|YarliW29_1|100@GLB                      25.666597
# jgi|YarliW29_1|1000@GLB                     18.011891
# jgi|YarliW29_1|1002@GLB                     25.155731
# jgi|YarliW29_1|1003@GLB                     22.638917
# jgi|YarliW29_1|1004@GLB                     23.618234
#
#                          Biostat2L_29_Oscillation_24  \
# Protein
# jgi|YarliW29_1|100@GLB                     25.770213
# jgi|YarliW29_1|1000@GLB                    17.293959
# jgi|YarliW29_1|1002@GLB                    22.817965
# jgi|YarliW29_1|1003@GLB                    21.661173
# jgi|YarliW29_1|1004@GLB                    24.612309
#
#                          Biostat2L_29_Oscillation_48  \
# Protein
# jgi|YarliW29_1|100@GLB                     25.649494
# jgi|YarliW29_1|1000@GLB                    16.996140
# jgi|YarliW29_1|1002@GLB                    22.221128
# jgi|YarliW29_1|1003@GLB                    21.343351
# jgi|YarliW29_1|1004@GLB                    26.057785
#
#                          Biostat2L_29_Oscillation_72  \
# Protein
# jgi|YarliW29_1|100@GLB                     25.495693
# jgi|YarliW29_1|1000@GLB                    16.940736
# jgi|YarliW29_1|1002@GLB                    22.204025
# jgi|YarliW29_1|1003@GLB                    21.351494
# jgi|YarliW29_1|1004@GLB                    26.347074
#
#                          Biostat2L_30_Control_3.5  Biostat2L_30_Control_4.5  \
# Protein
# jgi|YarliW29_1|100@GLB                  25.620312                 25.624321
# jgi|YarliW29_1|1000@GLB                 18.042939                 18.566494
# jgi|YarliW29_1|1002@GLB                 24.269189                 25.312090
# jgi|YarliW29_1|1003@GLB                 22.795371                 22.970198
# jgi|YarliW29_1|1004@GLB                 23.298582                 23.559677
#
#                          Biostat2L_30_Control_5.5  Biostat2L_30_Control_24  \
# Protein
# jgi|YarliW29_1|100@GLB                  25.764281                25.457543
# jgi|YarliW29_1|1000@GLB                 18.326494                17.495514
# jgi|YarliW29_1|1002@GLB                 25.154168                22.626837
# jgi|YarliW29_1|1003@GLB                 22.780983                21.925310
# jgi|YarliW29_1|1004@GLB                 23.643344                25.556813
#
#                          ...  Biostat2L_33_Low_5.5  Biostat2L_33_Low_24  \
# Protein                  ...
# jgi|YarliW29_1|100@GLB   ...             25.752609            26.215771
# jgi|YarliW29_1|1000@GLB  ...             18.012434            17.824969
# jgi|YarliW29_1|1002@GLB  ...             25.186652            23.962114
# jgi|YarliW29_1|1003@GLB  ...             22.740655            21.864980
# jgi|YarliW29_1|1004@GLB  ...             23.352792            23.056913
#
#                          Biostat2L_33_Low_48  Biostat2L_33_Low_72  \
# Protein
# jgi|YarliW29_1|100@GLB             26.254312            26.329296
# jgi|YarliW29_1|1000@GLB            17.550454            17.492877
# jgi|YarliW29_1|1002@GLB            23.148530            22.770328
# jgi|YarliW29_1|1003@GLB            21.646451            21.371498
# jgi|YarliW29_1|1004@GLB            23.387934            24.626466
#
#                          Biostat2L_34_Low_3.5  Biostat2L_34_Low_4.5  \
# Protein
# jgi|YarliW29_1|100@GLB              25.348436             25.474421
# jgi|YarliW29_1|1000@GLB             18.018298             18.046325
# jgi|YarliW29_1|1002@GLB             24.055592             25.125115
# jgi|YarliW29_1|1003@GLB             22.757346             22.752821
# jgi|YarliW29_1|1004@GLB             23.420203             23.752784
#
#                          Biostat2L_34_Low_5.5  Biostat2L_34_Low_24  \
# Protein
# jgi|YarliW29_1|100@GLB              25.636968            26.010065
# jgi|YarliW29_1|1000@GLB             18.003958            17.668527
# jgi|YarliW29_1|1002@GLB             25.069054            23.563942
# jgi|YarliW29_1|1003@GLB             22.521363            21.903156
# jgi|YarliW29_1|1004@GLB             23.876573            23.622010
#
#                          Biostat2L_34_Low_48  Biostat2L_34_Low_72
# Protein
# jgi|YarliW29_1|100@GLB             26.227300            26.059671
# jgi|YarliW29_1|1000@GLB            17.466942            17.402518
# jgi|YarliW29_1|1002@GLB            22.947880            22.543373
# jgi|YarliW29_1|1003@GLB            21.644129            21.391500
# jgi|YarliW29_1|1004@GLB            24.104213            24.727999
#
# [5 rows x 54 columns]

# %%
# calculate p-values. 
prot_control_vs_low_late_combined_stats = global_stats_calc_prot(prot_control_vs_low_late_combined,condition_series)
# prot_control_vs_low_24h_stats = global_stats_calc_prot(prot_control_vs_low_24h,condition_series24h)


# prot_control_vs_oscillation_late_combined_stats = global_stats_calc_prot(prot_control_vs_oscillation_late_combined,condition_series_controlvsOsc )
# prot_control_late_vs_control_early_stats = global_stats_calc_prot(prot_control_late_vs_control_early,condition_series_controlLateVsEarly)
# Out:
# Skipping protein jgi|YarliW29_1|1094@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1150@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1197@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1233@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1461@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1465@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1560@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1594@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1627@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1643@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1902@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|195@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1977@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2204@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2285@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2292@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2306@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2333@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2338@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2452@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2470@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2495@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2532@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2744@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2828@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3167@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3242@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3456@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3487@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3523@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3767@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3773@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3774@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3891@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4014@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4047@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4048@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|405@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4087@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4107@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4114@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4130@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4219@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4256@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4282@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4309@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4364@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4495@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4519@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4610@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4642@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4804@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4875@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4911@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5054@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5279@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5413@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5499@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5640@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5646@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5790@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5855@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5881@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5889@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5928@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5935@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5976@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|598@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|614@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6161@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|620@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6242@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6679@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6822@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6966@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7184@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7206@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7315@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7344@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7366@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7511@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7580@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7630@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7699@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|779@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7838@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7856@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|841@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|891@GLB due to insufficient data in some groups.

# %%
prot_control_vs_low_late_combined_stats.head()
# Out:
#                    Protein  Biostat2L_30_Control_24  Biostat2L_30_Control_48  \
# 0   jgi|YarliW29_1|100@GLB                25.457543                25.455410
# 1  jgi|YarliW29_1|1000@GLB                17.495514                17.187438
# 2  jgi|YarliW29_1|1002@GLB                22.626837                22.329658
# 3  jgi|YarliW29_1|1003@GLB                21.925310                21.766074
# 4  jgi|YarliW29_1|1004@GLB                25.556813                26.004931
#
#    Biostat2L_30_Control_72  Biostat2L_31_Control_24  Biostat2L_31_Control_48  \
# 0                25.217178                25.585560                25.201089
# 1                17.406634                17.383958                17.158660
# 2                22.331261                22.556796                22.197972
# 3                21.829104                21.943296                21.767955
# 4                26.278545                25.796548                26.082427
#
#    Biostat2L_31_Control_72  Biostat2L_32_Control_24  Biostat2L_32_Control_48  \
# 0                25.167410                25.444125                25.409470
# 1                17.354388                17.493245                17.306625
# 2                22.248940                22.664340                22.322748
# 3                21.832119                21.974737                21.819088
# 4                26.324661                25.995544                26.272773
#
#    Biostat2L_32_Control_72  ...  Biostat2L_32_Low_48  Biostat2L_32_Low_72  \
# 0                24.962255  ...            26.238225            26.102031
# 1                17.229185  ...            17.496024            17.353521
# 2                22.140471  ...            22.878133            22.612891
# 3                21.820224  ...            21.527272            21.430709
# 4                26.256044  ...            24.253218            24.949376
#
#    Biostat2L_33_Low_24  Biostat2L_33_Low_48  Biostat2L_33_Low_72  \
# 0            26.215771            26.254312            26.329296
# 1            17.824969            17.550454            17.492877
# 2            23.962114            23.148530            22.770328
# 3            21.864980            21.646451            21.371498
# 4            23.056913            23.387934            24.626466
#
#    Biostat2L_34_Low_24  Biostat2L_34_Low_48  Biostat2L_34_Low_72  \
# 0            26.010065            26.227300            26.059671
# 1            17.668527            17.466942            17.402518
# 2            23.563942            22.947880            22.543373
# 3            21.903156            21.644129            21.391500
# 4            23.622010            24.104213            24.727999
#
#         ANOVA_p    ANOVA_padj
# 0  3.815441e-09  6.021172e-08
# 1  4.862718e-03  8.628655e-03
# 2  6.784525e-04  1.474680e-03
# 3  4.681069e-03  8.330691e-03
# 4  1.977786e-07  1.335381e-06
#
# [5 rows x 21 columns]

# %%
# Extract the number between "YarliW29_1|" and "@GLB" using regex
prot_control_vs_low_late_combined_stats["proteinID"] = prot_control_vs_low_late_combined_stats["Protein"].str.extract(r"YarliW29_1\|(\d+)@GLB")
# prot_control_vs_low_24h_stats["proteinID"] = prot_control_vs_low_24h_stats["Protein"].str.extract(r"YarliW29_1\|(\d+)@GLB")

# Convert the extracted number to integer (if needed)
prot_control_vs_low_late_combined_stats["proteinID"] = prot_control_vs_low_late_combined_stats["proteinID"].astype(int)
# prot_control_vs_low_24h_stats["proteinID"] = prot_control_vs_low_24h_stats["proteinID"].astype(int)

# %%
prot_control_vs_low_late_combined_stats.head()
# Out:
#                    Protein  Biostat2L_30_Control_24  Biostat2L_30_Control_48  \
# 0   jgi|YarliW29_1|100@GLB                25.457543                25.455410
# 1  jgi|YarliW29_1|1000@GLB                17.495514                17.187438
# 2  jgi|YarliW29_1|1002@GLB                22.626837                22.329658
# 3  jgi|YarliW29_1|1003@GLB                21.925310                21.766074
# 4  jgi|YarliW29_1|1004@GLB                25.556813                26.004931
#
#    Biostat2L_30_Control_72  Biostat2L_31_Control_24  Biostat2L_31_Control_48  \
# 0                25.217178                25.585560                25.201089
# 1                17.406634                17.383958                17.158660
# 2                22.331261                22.556796                22.197972
# 3                21.829104                21.943296                21.767955
# 4                26.278545                25.796548                26.082427
#
#    Biostat2L_31_Control_72  Biostat2L_32_Control_24  Biostat2L_32_Control_48  \
# 0                25.167410                25.444125                25.409470
# 1                17.354388                17.493245                17.306625
# 2                22.248940                22.664340                22.322748
# 3                21.832119                21.974737                21.819088
# 4                26.324661                25.995544                26.272773
#
#    Biostat2L_32_Control_72  ...  Biostat2L_32_Low_72  Biostat2L_33_Low_24  \
# 0                24.962255  ...            26.102031            26.215771
# 1                17.229185  ...            17.353521            17.824969
# 2                22.140471  ...            22.612891            23.962114
# 3                21.820224  ...            21.430709            21.864980
# 4                26.256044  ...            24.949376            23.056913
#
#    Biostat2L_33_Low_48  Biostat2L_33_Low_72  Biostat2L_34_Low_24  \
# 0            26.254312            26.329296            26.010065
# 1            17.550454            17.492877            17.668527
# 2            23.148530            22.770328            23.563942
# 3            21.646451            21.371498            21.903156
# 4            23.387934            24.626466            23.622010
#
#    Biostat2L_34_Low_48  Biostat2L_34_Low_72       ANOVA_p    ANOVA_padj  \
# 0            26.227300            26.059671  3.815441e-09  6.021172e-08
# 1            17.466942            17.402518  4.862718e-03  8.628655e-03
# 2            22.947880            22.543373  6.784525e-04  1.474680e-03
# 3            21.644129            21.391500  4.681069e-03  8.330691e-03
# 4            24.104213            24.727999  1.977786e-07  1.335381e-06
#
#    proteinID
# 0        100
# 1       1000
# 2       1002
# 3       1003
# 4       1004
#
# [5 rows x 22 columns]

# %% [markdown]
# ### calculate log2FC

# %%
control = prot_control_vs_low_late_combined_stats.loc[:, prot_control_vs_low_late_combined_stats.columns[prot_control_vs_low_late_combined_stats.columns.str.contains("Control")]]
control.head()

# 24 h
# control24h = prot_control_vs_low_24h_stats.loc[:, prot_control_vs_low_24h_stats.columns[prot_control_vs_low_24h_stats.columns.str.contains("Control")]]
# control24h.head()
# Out:
#    Biostat2L_30_Control_24  Biostat2L_30_Control_48  Biostat2L_30_Control_72  \
# 0                25.457543                25.455410                25.217178
# 1                17.495514                17.187438                17.406634
# 2                22.626837                22.329658                22.331261
# 3                21.925310                21.766074                21.829104
# 4                25.556813                26.004931                26.278545
#
#    Biostat2L_31_Control_24  Biostat2L_31_Control_48  Biostat2L_31_Control_72  \
# 0                25.585560                25.201089                25.167410
# 1                17.383958                17.158660                17.354388
# 2                22.556796                22.197972                22.248940
# 3                21.943296                21.767955                21.832119
# 4                25.796548                26.082427                26.324661
#
#    Biostat2L_32_Control_24  Biostat2L_32_Control_48  Biostat2L_32_Control_72
# 0                25.444125                25.409470                24.962255
# 1                17.493245                17.306625                17.229185
# 2                22.664340                22.322748                22.140471
# 3                21.974737                21.819088                21.820224
# 4                25.995544                26.272773                26.256044

# %%
low = prot_control_vs_low_late_combined_stats.loc[:, prot_control_vs_low_late_combined_stats.columns[
    prot_control_vs_low_late_combined_stats.columns.str.contains("Low")]]
low.head()

# low24h = prot_control_vs_low_24h_stats.loc[:, prot_control_vs_low_24h_stats.columns[
    # prot_control_vs_low_24h_stats.columns.str.contains("Low")]]
# low24h.head()
# Out:
#    Biostat2L_32_Low_24  Biostat2L_32_Low_48  Biostat2L_32_Low_72  \
# 0            26.121008            26.238225            26.102031
# 1            17.637680            17.496024            17.353521
# 2            23.468714            22.878133            22.612891
# 3            21.777503            21.527272            21.430709
# 4            24.002981            24.253218            24.949376
#
#    Biostat2L_33_Low_24  Biostat2L_33_Low_48  Biostat2L_33_Low_72  \
# 0            26.215771            26.254312            26.329296
# 1            17.824969            17.550454            17.492877
# 2            23.962114            23.148530            22.770328
# 3            21.864980            21.646451            21.371498
# 4            23.056913            23.387934            24.626466
#
#    Biostat2L_34_Low_24  Biostat2L_34_Low_48  Biostat2L_34_Low_72
# 0            26.010065            26.227300            26.059671
# 1            17.668527            17.466942            17.402518
# 2            23.563942            22.947880            22.543373
# 3            21.903156            21.644129            21.391500
# 4            23.622010            24.104213            24.727999

# %%
# gives the increase of the first. 
prot_control_vs_low_late_combined_stats['log2FC']=log2FC_function(low,control)
# prot_control_vs_low_24h_stats['log2FC']=log2FC_function(low24h,control24h)

# %%
prot_control_vs_low_late_combined_stats['proteinId'] = prot_control_vs_low_late_combined_stats['proteinID']

# %%
df_to_merge = pd.DataFrame()
df_to_merge['low/control_late_combined'] = prot_control_vs_low_late_combined_stats['log2FC']
df_to_merge['proteinId'] = prot_control_vs_low_late_combined_stats['proteinID']
df_to_merge['low/control_late_combined_ANOVA_padj'] = prot_control_vs_low_late_combined_stats['ANOVA_padj']
df_to_merge['low/control_late_combined_ANOVA_p'] = prot_control_vs_low_late_combined_stats['ANOVA_p']

# %%
df_to_merge
# Out:
#       low/control_late_combined  proteinId  \
# 0                      0.850849        100
# 1                      0.208652       1000
# 2                      0.719654       1002
# 3                     -0.235634       1003
# 4                     -1.981909       1004
# ...                         ...        ...
# 2754                  -0.015719        976
# 2755                   0.033024        979
# 2756                  -0.296854        982
# 2757                  -0.254666        994
# 2758                  -0.099373        999
#
#       low/control_late_combined_ANOVA_padj  low/control_late_combined_ANOVA_p
# 0                             6.021172e-08                       3.815441e-09
# 1                             8.628655e-03                       4.862718e-03
# 2                             1.474680e-03                       6.784525e-04
# 3                             8.330691e-03                       4.681069e-03
# 4                             1.335381e-06                       1.977786e-07
# ...                                    ...                                ...
# 2754                          7.539612e-01                       7.155140e-01
# 2755                          6.212477e-01                       5.702342e-01
# 2756                          3.612704e-02                       2.397633e-02
# 2757                          1.046959e-06                       1.437157e-07
# 2758                          5.964258e-01                       5.434251e-01
#
# [2759 rows x 4 columns]

# %%
merged_df = pd.merge(merged_df, df_to_merge, left_on='proteinId',right_on='proteinId', how='left')

# %%
merged_df.head(20)
# Out:
#     Biostat2L_29_Oscillation_24  Biostat2L_29_Oscillation_3.5  \
# 0                     25.770213                     25.369272
# 1                     17.293959                     18.245944
# 2                     22.817965                     23.813276
# 3                     21.661173                     22.834460
# 4                     24.612309                     23.180487
# 5                     19.170143                     19.099859
# 6                     19.832808                     19.291079
# 7                     21.191147                     20.473049
# 8                     20.746908                     19.912286
# 9                     24.844245                     23.817512
# 10                    18.626898                     19.098223
# 11                    19.427169                     20.874230
# 12                          NaN                           NaN
# 13                    21.038860                     21.847791
# 14                    23.611131                     23.083143
# 15                    23.502803                     22.454384
# 16                    17.303136                     17.173380
# 17                    25.365749                     25.799364
# 18                    22.419831                     21.742002
# 19                    21.295161                     20.621121
#
#     Biostat2L_29_Oscillation_4.5  Biostat2L_29_Oscillation_48  \
# 0                      25.511412                    25.649494
# 1                      18.186630                    16.996140
# 2                      25.302130                    22.221128
# 3                      22.811937                    21.343351
# 4                      23.514879                    26.057785
# 5                      19.130301                    19.516358
# 6                      19.403216                    19.718643
# 7                      20.521454                    20.670665
# 8                      20.140910                    20.736697
# 9                      23.788359                    25.494086
# 10                     18.709602                    18.635055
# 11                     20.946974                    19.534724
# 12                           NaN                          NaN
# 13                     21.789493                    20.566591
# 14                     22.850264                    23.422226
# 15                     22.482354                    23.557559
# 16                     17.143936                    17.484131
# 17                     26.091535                    24.873230
# 18                     21.729927                    22.455743
# 19                     20.546592                    21.679607
#
#     Biostat2L_29_Oscillation_5.5  Biostat2L_29_Oscillation_72  \
# 0                      25.666597                    25.495693
# 1                      18.011891                    16.940736
# 2                      25.155731                    22.204025
# 3                      22.638917                    21.351494
# 4                      23.618234                    26.347074
# 5                      19.233001                    19.351713
# 6                      19.416530                    19.756749
# 7                      20.493335                    20.465718
# 8                      20.229398                    20.664103
# 9                      23.795971                    25.457786
# 10                     18.987463                    18.275425
# 11                     20.857344                    19.560324
# 12                           NaN                          NaN
# 13                     21.538678                    20.468640
# 14                     23.103606                    23.158692
# 15                     22.569621                    23.496478
# 16                     17.136935                    17.623963
# 17                     26.226551                    24.719508
# 18                     21.997831                    22.435971
# 19                     20.723806                    21.744901
#
#     Biostat2L_30_Control_24  Biostat2L_30_Control_3.5  \
# 0                 25.457543                 25.620312
# 1                 17.495514                 18.042939
# 2                 22.626837                 24.269189
# 3                 21.925310                 22.795371
# 4                 25.556813                 23.298582
# 5                 18.600041                 19.364405
# 6                 19.847332                 19.357177
# 7                 21.188276                 20.309949
# 8                 20.935951                 19.791703
# 9                 25.155977                 23.977720
# 10                18.573947                 18.778430
# 11                20.248282                 20.876796
# 12                17.863364                 18.571953
# 13                20.931999                 21.721825
# 14                23.049919                 23.156217
# 15                23.530914                 22.408786
# 16                17.551380                 17.169403
# 17                25.955489                 26.034642
# 18                22.790453                 21.671254
# 19                21.342802                 20.620416
#
#     Biostat2L_30_Control_4.5  Biostat2L_30_Control_48  ...    kogid  \
# 0                  25.624321                25.455410  ...  KOG2638
# 1                  18.566494                17.187438  ...      NaN
# 2                  25.312090                22.329658  ...  KOG0454
# 3                  22.970198                21.766074  ...  KOG0734
# 4                  23.559677                26.004931  ...  KOG1282
# 5                  19.315402                18.939302  ...  KOG3494
# 6                  19.469197                19.923761  ...  KOG4347
# 7                  20.325637                21.062829  ...  KOG1235
# 8                  20.213997                20.638092  ...      NaN
# 9                  23.981216                25.591142  ...  KOG1792
# 10                 18.786367                18.568092  ...  KOG2241
# 11                 21.119938                20.280289  ...      NaN
# 12                 18.713493                17.898284  ...  KOG3110
# 13                 21.665786                20.610626  ...  KOG0398
# 14                 22.482876                23.181027  ...      NaN
# 15                 22.437598                23.793859  ...  KOG2210
# 16                 17.390297                17.926589  ...      NaN
# 17                 26.003845                25.540278  ...  KOG1411
# 18                 21.704516                22.819898  ...  KOG1666
# 19                 20.623090                21.620287  ...  KOG0527
#
#                                            kogdefline  \
# 0                       UDP-glucose pyrophosphorylase
# 1                                                 NaN
# 2   3-isopropylmalate dehydratase (aconitase super...
# 3   AAA+-type ATPase containing the peptidase M41 ...
# 4    Serine carboxypeptidases (lysosomal cathepsin A)
# 5   Ubiquinol cytochrome c oxidoreductase, subunit...
# 6                       GTPase-activating protein VRP
# 7                    Predicted unusual protein kinase
# 8                                                 NaN
# 9                                           Reticulon
# 10                               tRNA-binding protein
# 11                                                NaN
# 12                                  Riboflavin kinase
# 13  Mitochondrial/chloroplast ribosomal protein L5/L7
# 14                                                NaN
# 15                          Oxysterol-binding protein
# 16                                                NaN
# 17  Aspartate aminotransferase/Glutamic oxaloaceti...
# 18                                            V-SNARE
# 19                       HMG-box transcription factor
#
#                                              kogClass  \
# 0               Carbohydrate transport and metabolism
# 1                                                 NaN
# 2                 Amino acid transport and metabolism
# 3   Posttranslational modification, protein turnov...
# 4   Amino acid transport and metabolism, Posttrans...
# 5                    Energy production and conversion
# 6                    General function prediction only
# 7                    General function prediction only
# 8                                                 NaN
# 9   Intracellular trafficking, secretion, and vesi...
# 10    Translation, ribosomal structure and biogenesis
# 11                                                NaN
# 12                  Coenzyme transport and metabolism
# 13    Translation, ribosomal structure and biogenesis
# 14                                                NaN
# 15                     Signal transduction mechanisms
# 16                                                NaN
# 17                Amino acid transport and metabolism
# 18  Intracellular trafficking, secretion, and vesi...
# 19                                      Transcription
#
#                                         kogGroup  early/late  \
# 0                                     METABOLISM    0.227504
# 1                                            NaN    0.901589
# 2                                     METABOLISM    2.395508
# 3               CELLULAR PROCESSES AND SIGNALING    0.987622
# 4   METABOLISM, CELLULAR PROCESSES AND SIGNALING   -2.465554
# 5                                     METABOLISM    0.504706
# 6                           POORLY CHARACTERIZED   -0.448336
# 7                           POORLY CHARACTERIZED   -0.722948
# 8                                            NaN   -0.632109
# 9               CELLULAR PROCESSES AND SIGNALING   -1.355286
# 10            INFORMATION STORAGE AND PROCESSING    0.166887
# 11                                           NaN    0.534361
# 12                                    METABOLISM    0.831366
# 13            INFORMATION STORAGE AND PROCESSING    0.881654
# 14                                           NaN   -0.336382
# 15              CELLULAR PROCESSES AND SIGNALING   -1.168790
# 16                                           NaN   -0.443570
# 17                                    METABOLISM    0.587828
# 18              CELLULAR PROCESSES AND SIGNALING   -0.925061
# 19            INFORMATION STORAGE AND PROCESSING   -0.918640
#
#     early/late_ANOVA_padj  early/late_ANOVA_p  low/control_late_combined  \
# 0            1.143026e-02        8.985946e-03                   0.850849
# 1            2.255583e-09        5.624651e-10                   0.208652
# 2            1.347266e-09        3.144760e-10                   0.719654
# 3            1.881487e-13        5.455562e-15                  -0.235634
# 4            5.824403e-13        2.311991e-14                  -1.981909
# 5            5.329539e-05        3.210472e-05                  -0.084333
# 6            1.685166e-10        2.601960e-11                  -0.046561
# 7            1.421362e-09        3.343473e-10                  -0.544688
# 8            4.720234e-07        2.075261e-07                  -0.339987
# 9            5.048688e-12        3.458507e-13                  -0.254783
# 10           7.437118e-03        5.749682e-03                   0.308619
# 11           1.145012e-07        4.519458e-08                   0.166114
# 12           1.442485e-09        3.408846e-10                   0.212758
# 13           1.390870e-08        4.406017e-09                   0.520509
# 14           6.030635e-03        4.609200e-03                   0.048796
# 15           2.075344e-12        1.150880e-13                  -0.193826
# 16           6.295565e-06        3.365697e-06                   0.357253
# 17           4.552239e-06        2.357792e-06                   0.740677
# 18           4.452584e-10        8.431727e-11                  -0.379443
# 19           4.926975e-10        9.607513e-11                  -0.269547
#
#     low/control_late_combined_ANOVA_padj  low/control_late_combined_ANOVA_p
# 0                           6.021172e-08                       3.815441e-09
# 1                           8.628655e-03                       4.862718e-03
# 2                           1.474680e-03                       6.784525e-04
# 3                           8.330691e-03                       4.681069e-03
# 4                           1.335381e-06                       1.977786e-07
# 5                           6.639069e-01                       6.151158e-01
# 6                           2.948375e-01                       2.433220e-01
# 7                           9.569686e-06                       2.123948e-06
# 8                           4.253729e-04                       1.668317e-04
# 9                           3.045228e-02                       1.968494e-02
# 10                          1.288649e-03                       5.836848e-04
# 11                          2.989102e-01                       2.475788e-01
# 12                          1.165739e-02                       6.842229e-03
# 13                          4.444967e-04                       1.749987e-04
# 14                          5.103005e-01                       4.515595e-01
# 15                          2.610225e-02                       1.664789e-02
# 16                          5.870779e-03                       3.134604e-03
# 17                          1.241516e-05                       2.895474e-06
# 18                          1.124064e-06                       1.588513e-07
# 19                          3.161258e-02                       2.058907e-02
#
# [20 rows x 197 columns]

# %%
prot_control_vs_low_late_combined_stats.head()
# Out:
#                    Protein  Biostat2L_30_Control_24  Biostat2L_30_Control_48  \
# 0   jgi|YarliW29_1|100@GLB                25.457543                25.455410
# 1  jgi|YarliW29_1|1000@GLB                17.495514                17.187438
# 2  jgi|YarliW29_1|1002@GLB                22.626837                22.329658
# 3  jgi|YarliW29_1|1003@GLB                21.925310                21.766074
# 4  jgi|YarliW29_1|1004@GLB                25.556813                26.004931
#
#    Biostat2L_30_Control_72  Biostat2L_31_Control_24  Biostat2L_31_Control_48  \
# 0                25.217178                25.585560                25.201089
# 1                17.406634                17.383958                17.158660
# 2                22.331261                22.556796                22.197972
# 3                21.829104                21.943296                21.767955
# 4                26.278545                25.796548                26.082427
#
#    Biostat2L_31_Control_72  Biostat2L_32_Control_24  Biostat2L_32_Control_48  \
# 0                25.167410                25.444125                25.409470
# 1                17.354388                17.493245                17.306625
# 2                22.248940                22.664340                22.322748
# 3                21.832119                21.974737                21.819088
# 4                26.324661                25.995544                26.272773
#
#    Biostat2L_32_Control_72  ...  Biostat2L_33_Low_48  Biostat2L_33_Low_72  \
# 0                24.962255  ...            26.254312            26.329296
# 1                17.229185  ...            17.550454            17.492877
# 2                22.140471  ...            23.148530            22.770328
# 3                21.820224  ...            21.646451            21.371498
# 4                26.256044  ...            23.387934            24.626466
#
#    Biostat2L_34_Low_24  Biostat2L_34_Low_48  Biostat2L_34_Low_72  \
# 0            26.010065            26.227300            26.059671
# 1            17.668527            17.466942            17.402518
# 2            23.563942            22.947880            22.543373
# 3            21.903156            21.644129            21.391500
# 4            23.622010            24.104213            24.727999
#
#         ANOVA_p    ANOVA_padj  proteinID    log2FC  proteinId
# 0  3.815441e-09  6.021172e-08        100  0.850849        100
# 1  4.862718e-03  8.628655e-03       1000  0.208652       1000
# 2  6.784525e-04  1.474680e-03       1002  0.719654       1002
# 3  4.681069e-03  8.330691e-03       1003 -0.235634       1003
# 4  1.977786e-07  1.335381e-06       1004 -1.981909       1004
#
# [5 rows x 24 columns]

# %%
prot_control_vs_low_late_combined_stats_withAnnote = pd.merge(prot_control_vs_low_late_combined_stats, merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')
# prot_control_vs_low_24h_stats_withAnnote = pd.merge(prot_control_vs_low_24h_stats, merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')

# %%
prot_control_vs_low_late_combined_stats_withAnnote.columns
# Out:
# Index(['Protein', 'Biostat2L_30_Control_24', 'Biostat2L_30_Control_48',
#        'Biostat2L_30_Control_72', 'Biostat2L_31_Control_24',
#        'Biostat2L_31_Control_48', 'Biostat2L_31_Control_72',
#        'Biostat2L_32_Control_24', 'Biostat2L_32_Control_48',
#        'Biostat2L_32_Control_72', 'Biostat2L_32_Low_24', 'Biostat2L_32_Low_48',
#        'Biostat2L_32_Low_72', 'Biostat2L_33_Low_24', 'Biostat2L_33_Low_48',
#        'Biostat2L_33_Low_72', 'Biostat2L_34_Low_24', 'Biostat2L_34_Low_48',
#        'Biostat2L_34_Low_72', 'ANOVA_p', 'ANOVA_padj', 'proteinID', 'log2FC',
#        'proteinId', '#proteinId', 'kogid', 'kogdefline', 'kogClass',
#        'kogGroup', 'definition', 'catalyticActivity', 'pathway',
#        'pathway_class', 'pathway_type', 'ecNum', 'cofactors', 'gotermId',
#        'gotermType', 'goName', 'goAcc'],
#       dtype='object')

# %% [markdown]
# ### optional save.

# %%
prot_control_vs_low_late_combined_stats_withAnnote.to_csv('control_vs_low_late.csv')
# prot_control_vs_low_24h_stats_withAnnote.to_csv('control_vs_low_24h.csv')

# %% [markdown]
# ### Volcano plot comparing low vs high,
# all late (increase means increased in low)

# %%
dataset = prot_control_vs_low_late_combined_stats_withAnnote[['log2FC', 'ANOVA_padj']].copy()
dataset.index = prot_control_vs_low_late_combined_stats_withAnnote.proteinID

# dataset24h = prot_control_vs_low_24h_stats_withAnnote[['log2FC', 'ANOVA_padj']].copy()

# %%
log2FC_threshold = np.log2(1.3)

# %%
dataset
# Out:
#              log2FC    ANOVA_padj
# proteinID
# 100        0.850849  6.021172e-08
# 1000       0.208652  8.628655e-03
# 1002       0.719654  1.474680e-03
# 1003      -0.235634  8.330691e-03
# 1004      -1.981909  1.335381e-06
# ...             ...           ...
# 976       -0.015719  7.539612e-01
# 979        0.033024  6.212477e-01
# 982       -0.296854  3.612704e-02
# 994       -0.254666  1.046959e-06
# 999       -0.099373  5.964258e-01
#
# [2759 rows x 2 columns]

# %%
# subset the log2FC and the P_value for this dataset. 
dataset.columns = ['log2FC','P_value']

# obtain the -logP_adj for the dataset. 
dataset['-logP_adj'] = -np.log10(dataset['P_value'])

# set a class for up (1) or down (-1) proteins. 
dataset['class'] = 0
dataset.loc[(dataset['log2FC']>log2FC_threshold)&(dataset['-logP_adj']>-np.log10(0.05)),'class'] = 1
dataset.loc[(dataset['log2FC']<-log2FC_threshold)&(dataset['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
# # subset the log2FC and the P_value for this dataset. 
# dataset24h.columns = ['log2FC','P_value']

# # obtain the -logP_adj for the dataset. 
# dataset24h['-logP_adj'] = -np.log10(dataset['P_value'])

# # set a class for up (1) or down (-1) proteins. 
# dataset24h['class'] = 0
# dataset24h.loc[(dataset24h['log2FC']>log2FC_threshold)&(dataset24h['-logP_adj']>-np.log10(0.05)),'class'] = 1
# dataset24h.loc[(dataset24h['log2FC']<-log2FC_threshold)&(dataset24h['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
dataset
# Out:
#              log2FC       P_value  -logP_adj  class
# proteinID
# 100        0.850849  6.021172e-08   7.220319      1
# 1000       0.208652  8.628655e-03   2.064057      0
# 1002       0.719654  1.474680e-03   2.831302      1
# 1003      -0.235634  8.330691e-03   2.079319      0
# 1004      -1.981909  1.335381e-06   5.874395     -1
# ...             ...           ...        ...    ...
# 976       -0.015719  7.539612e-01   0.122651      0
# 979        0.033024  6.212477e-01   0.206735      0
# 982       -0.296854  3.612704e-02   1.442168      0
# 994       -0.254666  1.046959e-06   5.980070      0
# 999       -0.099373  5.964258e-01   0.224444      0
#
# [2759 rows x 4 columns]

# %%
volcano_plot(dataset)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_56072/3268818367.py:182: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_min = df.min()[0]-1
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_56072/3268818367.py:183: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_max = df.max()[0]+1
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_56072/3268818367.py:186: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_max = dataset.max()[2]+1

# %%
# volcano_plot_annotate(dataset)

# %%
# volcano_plot(dataset24h)

# %% [markdown]
# ### Significant protein slicing.

# %%
prot_control_vs_low_late_combined_stats_withAnnote.columns
# Out:
# Index(['Protein', 'Biostat2L_30_Control_24', 'Biostat2L_30_Control_48',
#        'Biostat2L_30_Control_72', 'Biostat2L_31_Control_24',
#        'Biostat2L_31_Control_48', 'Biostat2L_31_Control_72',
#        'Biostat2L_32_Control_24', 'Biostat2L_32_Control_48',
#        'Biostat2L_32_Control_72', 'Biostat2L_32_Low_24', 'Biostat2L_32_Low_48',
#        'Biostat2L_32_Low_72', 'Biostat2L_33_Low_24', 'Biostat2L_33_Low_48',
#        'Biostat2L_33_Low_72', 'Biostat2L_34_Low_24', 'Biostat2L_34_Low_48',
#        'Biostat2L_34_Low_72', 'ANOVA_p', 'ANOVA_padj', 'proteinID', 'log2FC',
#        'proteinId', '#proteinId', 'kogid', 'kogdefline', 'kogClass',
#        'kogGroup', 'definition', 'catalyticActivity', 'pathway',
#        'pathway_class', 'pathway_type', 'ecNum', 'cofactors', 'gotermId',
#        'gotermType', 'goName', 'goAcc'],
#       dtype='object')

# %%
sig_control_vs_low_late_combined = prot_control_vs_low_late_combined_stats_withAnnote[prot_control_vs_low_late_combined_stats_withAnnote['ANOVA_padj'] < 0.05]
# sig_control_vs_low_24h = prot_control_vs_low_24h_stats_withAnnote[prot_control_vs_low_24h_stats_withAnnote['ANOVA_padj'] < 0.05]

# %% [markdown]
# ### optional save.

# %%
# sig_control_vs_low_late_combined.to_csv('Sig_control_vs_low_late_combined.csv')
# sig_control_vs_low_24h.to_csv('Sig_control_vs_low_24h.csv')

# %% [markdown]
# ## Compare Control vs Oscillation. Start with all late (24-72). Include 24 hour separately.

# %%
prot = proteomics_data[sample_ids_prot_redox]
proteomics_data['Protein'] = proteomics_data['Site']
prot.index = proteomics_data['Protein']
# drop oscillations.
# prot_control_vs_oscillation_24h = prot.drop(prot.columns[prot.columns.str.contains("Low")], axis=1)
prot_control_vs_oscillation_late_combined = prot.drop(prot.columns[prot.columns.str.contains("Low")], axis=1)


# drop early timepoints. 
# prot_control_vs_oscillation_24h = prot_control_vs_oscillation_24h.drop(prot_control_vs_oscillation_24h.columns[
#     prot_control_vs_oscillation_24h.columns.str.contains("5.5|3.5|4.5|48|72")], axis=1)

prot_control_vs_oscillation_late_combined = prot_control_vs_oscillation_late_combined.drop(prot_control_vs_oscillation_late_combined.columns[
    prot_control_vs_oscillation_late_combined.columns.str.contains("5.5|3.5|4.5")], axis=1)

# %%
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))

# %% [markdown]
# ### Prep for p-values.

# %%
# group for mapping in nanova. 


condition_series_controlvsOscLateCombined = pd.Series(prot_control_vs_oscillation_late_combined.columns).map(prot_condition_dict)
condition_series_controlvsOscLateCombined.index = prot_control_vs_oscillation_late_combined.columns
condition_series_controlvsOscLateCombined 

# condition_series_controlvsOsc24 = pd.Series(prot_control_vs_oscillation_24h.columns).map(prot_condition_dict)
# condition_series_controlvsOsc24.index = prot_control_vs_oscillation_24h.columns
# condition_series_controlvsOsc24
# Out:
# Biostat2L_29_Oscillation_24    Oscillation
# Biostat2L_29_Oscillation_48    Oscillation
# Biostat2L_29_Oscillation_72    Oscillation
# Biostat2L_30_Control_24            Control
# Biostat2L_30_Control_48            Control
# Biostat2L_30_Control_72            Control
# Biostat2L_30_Oscillation_24    Oscillation
# Biostat2L_30_Oscillation_48    Oscillation
# Biostat2L_30_Oscillation_72    Oscillation
# Biostat2L_31_Control_24            Control
# Biostat2L_31_Control_48            Control
# Biostat2L_31_Control_72            Control
# Biostat2L_31_Oscillation_24    Oscillation
# Biostat2L_31_Oscillation_48    Oscillation
# Biostat2L_31_Oscillation_72    Oscillation
# Biostat2L_32_Control_24            Control
# Biostat2L_32_Control_48            Control
# Biostat2L_32_Control_72            Control
# dtype: object

# %%
# late stats.
prot_control_vs_oscillation_late_combined_stats = global_stats_calc_prot(prot_control_vs_oscillation_late_combined,
                                                                         condition_series_controlvsOscLateCombined )

# 24 h stats. 
# prot_control_vs_oscillation_24h_stats = global_stats_calc_prot(prot_control_vs_oscillation_24h,
                                                                  # condition_series_controlvsOsc24)
# Out:
# Skipping protein jgi|YarliW29_1|1022@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1094@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1150@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1233@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1594@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1636@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1765@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1840@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2263@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2532@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2631@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2828@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3148@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3167@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3343@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3464@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3891@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3918@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4014@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4039@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|405@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4106@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4114@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4130@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4219@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4309@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4786@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4863@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4911@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5438@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5642@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5935@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6065@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|614@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6152@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|620@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6242@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6677@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6679@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6741@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6807@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6952@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7184@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7206@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7249@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7437@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7524@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7539@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7699@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|841@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|94@GLB due to insufficient data in some groups.

# %%
# Extract the number between "YarliW29_1|" and "@GLB" using regex.
prot_control_vs_oscillation_late_combined_stats["proteinID"] = prot_control_vs_oscillation_late_combined_stats["Protein"].str.extract(r"YarliW29_1\|(\d+)@GLB")
# prot_control_vs_oscillation_24h_stats["proteinID"] = prot_control_vs_oscillation_24h_stats["Protein"].str.extract(r"YarliW29_1\|(\d+)@GLB")



# Convert the extracted number to integer (if needed).
prot_control_vs_oscillation_late_combined_stats["proteinID"] = prot_control_vs_oscillation_late_combined_stats["proteinID"].astype(int)
# prot_control_vs_oscillation_24h_stats["proteinID"] = prot_control_vs_oscillation_24h_stats["proteinID"].astype(int)

# %% [markdown]
# ### calculate log2FC

# %%
controlLateCombined = prot_control_vs_oscillation_late_combined_stats.loc[:, prot_control_vs_oscillation_late_combined_stats.columns[prot_control_vs_oscillation_late_combined_stats.columns.str.contains("Control")]]
# control24h = prot_control_vs_oscillation_24h_stats.loc[:, prot_control_vs_oscillation_24h_stats.columns[prot_control_vs_oscillation_24h_stats.columns.str.contains("Control")]]
# control24h.head()

# %%
oscLateCombinedLate = prot_control_vs_oscillation_late_combined_stats.loc[:, prot_control_vs_oscillation_late_combined_stats.columns[
    prot_control_vs_oscillation_late_combined_stats.columns.str.contains("Oscillation")]]

# osc24h = prot_control_vs_oscillation_24h_stats.loc[:, prot_control_vs_oscillation_24h_stats.columns[
    # prot_control_vs_oscillation_24h_stats.columns.str.contains("Oscillation")]]
# osc24h.head()

# %%
oscLateCombinedLate.head()
# Out:
#    Biostat2L_29_Oscillation_24  Biostat2L_29_Oscillation_48  \
# 0                    25.770213                    25.649494
# 1                    17.293959                    16.996140
# 2                    22.817965                    22.221128
# 3                    21.661173                    21.343351
# 4                    24.612309                    26.057785
#
#    Biostat2L_29_Oscillation_72  Biostat2L_30_Oscillation_24  \
# 0                    25.495693                    25.715243
# 1                    16.940736                    17.327794
# 2                    22.204025                    22.932771
# 3                    21.351494                    21.707582
# 4                    26.347074                    24.327574
#
#    Biostat2L_30_Oscillation_48  Biostat2L_30_Oscillation_72  \
# 0                    25.566222                    25.374818
# 1                    17.056977                    17.046313
# 2                    22.337595                    22.194845
# 3                    21.402202                    21.308422
# 4                    25.953402                    26.186906
#
#    Biostat2L_31_Oscillation_24  Biostat2L_31_Oscillation_48  \
# 0                    25.570000                    25.482029
# 1                    17.368511                    16.924630
# 2                    22.802610                    22.099818
# 3                    21.931092                    21.302869
# 4                    24.420266                    26.070097
#
#    Biostat2L_31_Oscillation_72
# 0                    25.288831
# 1                    16.850427
# 2                    21.977757
# 3                    21.313301
# 4                    26.439499

# %%
# gives the increase of the first. 
# prot_control_vs_oscillation_24h_stats['log2FC']=log2FC_function(osc24h, control24h)
prot_control_vs_oscillation_late_combined_stats['log2FC']=log2FC_function(oscLateCombinedLate,controlLateCombined)

# %%
df_to_merge = pd.DataFrame()
df_to_merge['osc/control_late_cominbed'] = prot_control_vs_oscillation_late_combined_stats['log2FC']
df_to_merge['proteinId'] = prot_control_vs_oscillation_late_combined_stats['proteinID']
df_to_merge['osc/control_late_cominbedANOVA_padj'] = prot_control_vs_oscillation_late_combined_stats['ANOVA_padj']
df_to_merge['osc/control_late_cominbedANOVA_p'] = prot_control_vs_oscillation_late_combined_stats['ANOVA_p']

# %%
merged_df = pd.merge(merged_df, df_to_merge, left_on='proteinId',right_on='proteinId', how='left')

# %%
merged_df.head(20)
# Out:
#     Biostat2L_29_Oscillation_24  Biostat2L_29_Oscillation_3.5  \
# 0                     25.770213                     25.369272
# 1                     17.293959                     18.245944
# 2                     22.817965                     23.813276
# 3                     21.661173                     22.834460
# 4                     24.612309                     23.180487
# 5                     19.170143                     19.099859
# 6                     19.832808                     19.291079
# 7                     21.191147                     20.473049
# 8                     20.746908                     19.912286
# 9                     24.844245                     23.817512
# 10                    18.626898                     19.098223
# 11                    19.427169                     20.874230
# 12                          NaN                           NaN
# 13                    21.038860                     21.847791
# 14                    23.611131                     23.083143
# 15                    23.502803                     22.454384
# 16                    17.303136                     17.173380
# 17                    25.365749                     25.799364
# 18                    22.419831                     21.742002
# 19                    21.295161                     20.621121
#
#     Biostat2L_29_Oscillation_4.5  Biostat2L_29_Oscillation_48  \
# 0                      25.511412                    25.649494
# 1                      18.186630                    16.996140
# 2                      25.302130                    22.221128
# 3                      22.811937                    21.343351
# 4                      23.514879                    26.057785
# 5                      19.130301                    19.516358
# 6                      19.403216                    19.718643
# 7                      20.521454                    20.670665
# 8                      20.140910                    20.736697
# 9                      23.788359                    25.494086
# 10                     18.709602                    18.635055
# 11                     20.946974                    19.534724
# 12                           NaN                          NaN
# 13                     21.789493                    20.566591
# 14                     22.850264                    23.422226
# 15                     22.482354                    23.557559
# 16                     17.143936                    17.484131
# 17                     26.091535                    24.873230
# 18                     21.729927                    22.455743
# 19                     20.546592                    21.679607
#
#     Biostat2L_29_Oscillation_5.5  Biostat2L_29_Oscillation_72  \
# 0                      25.666597                    25.495693
# 1                      18.011891                    16.940736
# 2                      25.155731                    22.204025
# 3                      22.638917                    21.351494
# 4                      23.618234                    26.347074
# 5                      19.233001                    19.351713
# 6                      19.416530                    19.756749
# 7                      20.493335                    20.465718
# 8                      20.229398                    20.664103
# 9                      23.795971                    25.457786
# 10                     18.987463                    18.275425
# 11                     20.857344                    19.560324
# 12                           NaN                          NaN
# 13                     21.538678                    20.468640
# 14                     23.103606                    23.158692
# 15                     22.569621                    23.496478
# 16                     17.136935                    17.623963
# 17                     26.226551                    24.719508
# 18                     21.997831                    22.435971
# 19                     20.723806                    21.744901
#
#     Biostat2L_30_Control_24  Biostat2L_30_Control_3.5  \
# 0                 25.457543                 25.620312
# 1                 17.495514                 18.042939
# 2                 22.626837                 24.269189
# 3                 21.925310                 22.795371
# 4                 25.556813                 23.298582
# 5                 18.600041                 19.364405
# 6                 19.847332                 19.357177
# 7                 21.188276                 20.309949
# 8                 20.935951                 19.791703
# 9                 25.155977                 23.977720
# 10                18.573947                 18.778430
# 11                20.248282                 20.876796
# 12                17.863364                 18.571953
# 13                20.931999                 21.721825
# 14                23.049919                 23.156217
# 15                23.530914                 22.408786
# 16                17.551380                 17.169403
# 17                25.955489                 26.034642
# 18                22.790453                 21.671254
# 19                21.342802                 20.620416
#
#     Biostat2L_30_Control_4.5  Biostat2L_30_Control_48  ...  \
# 0                  25.624321                25.455410  ...
# 1                  18.566494                17.187438  ...
# 2                  25.312090                22.329658  ...
# 3                  22.970198                21.766074  ...
# 4                  23.559677                26.004931  ...
# 5                  19.315402                18.939302  ...
# 6                  19.469197                19.923761  ...
# 7                  20.325637                21.062829  ...
# 8                  20.213997                20.638092  ...
# 9                  23.981216                25.591142  ...
# 10                 18.786367                18.568092  ...
# 11                 21.119938                20.280289  ...
# 12                 18.713493                17.898284  ...
# 13                 21.665786                20.610626  ...
# 14                 22.482876                23.181027  ...
# 15                 22.437598                23.793859  ...
# 16                 17.390297                17.926589  ...
# 17                 26.003845                25.540278  ...
# 18                 21.704516                22.819898  ...
# 19                 20.623090                21.620287  ...
#
#                                         kogGroup  early/late  \
# 0                                     METABOLISM    0.227504
# 1                                            NaN    0.901589
# 2                                     METABOLISM    2.395508
# 3               CELLULAR PROCESSES AND SIGNALING    0.987622
# 4   METABOLISM, CELLULAR PROCESSES AND SIGNALING   -2.465554
# 5                                     METABOLISM    0.504706
# 6                           POORLY CHARACTERIZED   -0.448336
# 7                           POORLY CHARACTERIZED   -0.722948
# 8                                            NaN   -0.632109
# 9               CELLULAR PROCESSES AND SIGNALING   -1.355286
# 10            INFORMATION STORAGE AND PROCESSING    0.166887
# 11                                           NaN    0.534361
# 12                                    METABOLISM    0.831366
# 13            INFORMATION STORAGE AND PROCESSING    0.881654
# 14                                           NaN   -0.336382
# 15              CELLULAR PROCESSES AND SIGNALING   -1.168790
# 16                                           NaN   -0.443570
# 17                                    METABOLISM    0.587828
# 18              CELLULAR PROCESSES AND SIGNALING   -0.925061
# 19            INFORMATION STORAGE AND PROCESSING   -0.918640
#
#     early/late_ANOVA_padj  early/late_ANOVA_p  low/control_late_combined  \
# 0            1.143026e-02        8.985946e-03                   0.850849
# 1            2.255583e-09        5.624651e-10                   0.208652
# 2            1.347266e-09        3.144760e-10                   0.719654
# 3            1.881487e-13        5.455562e-15                  -0.235634
# 4            5.824403e-13        2.311991e-14                  -1.981909
# 5            5.329539e-05        3.210472e-05                  -0.084333
# 6            1.685166e-10        2.601960e-11                  -0.046561
# 7            1.421362e-09        3.343473e-10                  -0.544688
# 8            4.720234e-07        2.075261e-07                  -0.339987
# 9            5.048688e-12        3.458507e-13                  -0.254783
# 10           7.437118e-03        5.749682e-03                   0.308619
# 11           1.145012e-07        4.519458e-08                   0.166114
# 12           1.442485e-09        3.408846e-10                   0.212758
# 13           1.390870e-08        4.406017e-09                   0.520509
# 14           6.030635e-03        4.609200e-03                   0.048796
# 15           2.075344e-12        1.150880e-13                  -0.193826
# 16           6.295565e-06        3.365697e-06                   0.357253
# 17           4.552239e-06        2.357792e-06                   0.740677
# 18           4.452584e-10        8.431727e-11                  -0.379443
# 19           4.926975e-10        9.607513e-11                  -0.269547
#
#     low/control_late_combined_ANOVA_padj  low/control_late_combined_ANOVA_p  \
# 0                           6.021172e-08                       3.815441e-09
# 1                           8.628655e-03                       4.862718e-03
# 2                           1.474680e-03                       6.784525e-04
# 3                           8.330691e-03                       4.681069e-03
# 4                           1.335381e-06                       1.977786e-07
# 5                           6.639069e-01                       6.151158e-01
# 6                           2.948375e-01                       2.433220e-01
# 7                           9.569686e-06                       2.123948e-06
# 8                           4.253729e-04                       1.668317e-04
# 9                           3.045228e-02                       1.968494e-02
# 10                          1.288649e-03                       5.836848e-04
# 11                          2.989102e-01                       2.475788e-01
# 12                          1.165739e-02                       6.842229e-03
# 13                          4.444967e-04                       1.749987e-04
# 14                          5.103005e-01                       4.515595e-01
# 15                          2.610225e-02                       1.664789e-02
# 16                          5.870779e-03                       3.134604e-03
# 17                          1.241516e-05                       2.895474e-06
# 18                          1.124064e-06                       1.588513e-07
# 19                          3.161258e-02                       2.058907e-02
#
#     osc/control_late_cominbed  osc/control_late_cominbedANOVA_padj  \
# 0                    0.223612                         3.427329e-02
# 1                   -0.245573                         1.308687e-02
# 2                    0.018832                         9.186029e-01
# 3                   -0.372936                         9.931205e-04
# 4                   -0.461486                         2.271951e-01
# 5                    0.477230                         2.036699e-03
# 6                   -0.112413                         4.195529e-03
# 7                   -0.299279                         2.682444e-02
# 8                   -0.062976                         3.402186e-01
# 9                   -0.160971                         2.458775e-01
# 10                   0.062223                         6.637728e-01
# 11                  -0.689683                         2.975989e-08
# 12                        NaN                                  NaN
# 13                  -0.012186                         9.390366e-01
# 14                   0.405093                         1.265500e-03
# 15                  -0.147819                         2.579542e-02
# 16                  -0.241761                         5.852824e-02
# 17                  -0.457891                         8.136506e-03
# 18                  -0.293485                         1.366678e-04
# 19                  -0.024212                         8.461107e-01
#
#     osc/control_late_cominbedANOVA_p
# 0                       1.630071e-02
# 1                       5.319865e-03
# 2                       8.900500e-01
# 3                       2.697500e-04
# 4                       1.492805e-01
# 5                       6.156763e-04
# 6                       1.434170e-03
# 7                       1.223258e-02
# 8                       2.463002e-01
# 9                       1.647361e-01
# 10                      5.770428e-01
# 11                      8.798193e-10
# 12                               NaN
# 13                      9.143982e-01
# 14                      3.586986e-04
# 15                      1.165846e-02
# 16                      3.060512e-02
# 17                      3.085017e-03
# 18                      2.715046e-05
# 19                      7.873269e-01
#
# [20 rows x 200 columns]

# %% [markdown]
# ### optional save. This is final file with proteomic details.

# %%
merged_df['proteinID'] = merged_df['proteinId'].copy()
merged_df['#proteinId'] = merged_df['proteinId'].copy()

# %%
# merged_df.to_csv('../Data/PPI_yarrowia_REDOX_Global/result/PTM/PPI_yarrowia_protein_abundance_wAnnotations_fullLog2FC.csv')

# %%
prot_control_vs_oscillation_late_combined_stats.head()
# Out:
#                    Protein  Biostat2L_29_Oscillation_24  \
# 0   jgi|YarliW29_1|100@GLB                    25.770213
# 1  jgi|YarliW29_1|1000@GLB                    17.293959
# 2  jgi|YarliW29_1|1002@GLB                    22.817965
# 3  jgi|YarliW29_1|1003@GLB                    21.661173
# 4  jgi|YarliW29_1|1004@GLB                    24.612309
#
#    Biostat2L_29_Oscillation_48  Biostat2L_29_Oscillation_72  \
# 0                    25.649494                    25.495693
# 1                    16.996140                    16.940736
# 2                    22.221128                    22.204025
# 3                    21.343351                    21.351494
# 4                    26.057785                    26.347074
#
#    Biostat2L_30_Control_24  Biostat2L_30_Control_48  Biostat2L_30_Control_72  \
# 0                25.457543                25.455410                25.217178
# 1                17.495514                17.187438                17.406634
# 2                22.626837                22.329658                22.331261
# 3                21.925310                21.766074                21.829104
# 4                25.556813                26.004931                26.278545
#
#    Biostat2L_30_Oscillation_24  Biostat2L_30_Oscillation_48  \
# 0                    25.715243                    25.566222
# 1                    17.327794                    17.056977
# 2                    22.932771                    22.337595
# 3                    21.707582                    21.402202
# 4                    24.327574                    25.953402
#
#    Biostat2L_30_Oscillation_72  ...  Biostat2L_31_Oscillation_24  \
# 0                    25.374818  ...                    25.570000
# 1                    17.046313  ...                    17.368511
# 2                    22.194845  ...                    22.802610
# 3                    21.308422  ...                    21.931092
# 4                    26.186906  ...                    24.420266
#
#    Biostat2L_31_Oscillation_48  Biostat2L_31_Oscillation_72  \
# 0                    25.482029                    25.288831
# 1                    16.924630                    16.850427
# 2                    22.099818                    21.977757
# 3                    21.302869                    21.313301
# 4                    26.070097                    26.439499
#
#    Biostat2L_32_Control_24  Biostat2L_32_Control_48  Biostat2L_32_Control_72  \
# 0                25.444125                25.409470                24.962255
# 1                17.493245                17.306625                17.229185
# 2                22.664340                22.322748                22.140471
# 3                21.974737                21.819088                21.820224
# 4                25.995544                26.272773                26.256044
#
#     ANOVA_p  ANOVA_padj  proteinID    log2FC
# 0  0.016301    0.034273        100  0.223612
# 1  0.005320    0.013087       1000 -0.245573
# 2  0.890050    0.918603       1002  0.018832
# 3  0.000270    0.000993       1003 -0.372936
# 4  0.149280    0.227195       1004 -0.461486
#
# [5 rows x 23 columns]

# %%
prot_control_vs_oscillation_late_combined_stats_withAnnote = pd.merge(prot_control_vs_oscillation_late_combined_stats, 
                                                                      merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')
# prot_control_vs_oscillation_24h_stats_withAnnote = pd.merge(prot_control_vs_oscillation_24h_stats, 
                                                                      # merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')

# %%
prot_control_vs_oscillation_late_combined_stats_withAnnote.to_csv('control_vs_oscillation_late.csv')
# prot_control_vs_oscillation_24h_stats_withAnnote.to_csv('control_vs_oscillation_24h.csv')

# %% [markdown]
# ### Volcano plot comparing low vs high,
# all late (increase means increased in low)

# %%
dataset_late_combined = prot_control_vs_oscillation_late_combined_stats_withAnnote[['log2FC', 'ANOVA_padj']].copy()
# dataset_24h = prot_control_vs_oscillation_24h_stats_withAnnote[['log2FC', 'ANOVA_padj']].copy()

# %%
log2FC_threshold = np.log2(1.3)

# %%
# subset the log2FC and the P_value for this dataset. 
dataset_late_combined.columns = ['log2FC','P_value']

# obtain the -logP_adj for the dataset. 
dataset_late_combined['-logP_adj'] = -np.log10(dataset_late_combined['P_value'])

# set a class for up (1) or down (-1) proteins. 
dataset_late_combined['class'] = 0
dataset_late_combined.loc[(dataset_late_combined['log2FC']>log2FC_threshold)&(dataset_late_combined['-logP_adj']>-np.log10(0.05)),'class'] = 1
dataset_late_combined.loc[(dataset_late_combined['log2FC']<-log2FC_threshold)&(dataset_late_combined['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
# # subset the log2FC and the P_value for this dataset. 
# dataset_24h.columns = ['log2FC','P_value']

# # obtain the -logP_adj for the dataset. 
# dataset_24h['-logP_adj'] = -np.log10(dataset_24h['P_value'])

# # set a class for up (1) or down (-1) proteins. 
# dataset_24h['class'] = 0
# dataset_24h.loc[(dataset_24h['log2FC']>log2FC_threshold)&(dataset_24h['-logP_adj']>-np.log10(0.05)),'class'] = 1
# dataset_24h.loc[(dataset_24h['log2FC']<-log2FC_threshold)&(dataset_24h['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
volcano_plot(dataset_late_combined)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_56072/3268818367.py:182: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_min = df.min()[0]-1
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_56072/3268818367.py:183: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_max = df.max()[0]+1
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_56072/3268818367.py:186: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_max = dataset.max()[2]+1

# %%
# volcano_plot(dataset_24h)

# %% [markdown]
# ## Compare Oscillation vs Low. Start with all late (24-72).

# %% [markdown]
# ### prep for p-values.

# %%
prot = proteomics_data[sample_ids_prot_redox]
proteomics_data['Protein'] = proteomics_data['Site']
prot.index = proteomics_data['Protein']
# drop oscillations.
# prot_control_vs_oscillation_24h = prot.drop(prot.columns[prot.columns.str.contains("Low")], axis=1)
prot_oscillation_vs_low_late_combined = prot.drop(prot.columns[prot.columns.str.contains("Control")], axis=1)


# drop early timepoints. 
prot_oscillation_vs_low_late_combined = prot_oscillation_vs_low_late_combined.drop(prot_oscillation_vs_low_late_combined.columns[
    prot_oscillation_vs_low_late_combined.columns.str.contains("5.5|3.5|4.5")], axis=1)

# %%
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))

# %%
# group for mapping in annova. 

condition_series_OscvsLowLateCombined = pd.Series(prot_oscillation_vs_low_late_combined.columns).map(prot_condition_dict)
condition_series_OscvsLowLateCombined.index = prot_oscillation_vs_low_late_combined.columns
condition_series_OscvsLowLateCombined
# Out:
# Biostat2L_29_Oscillation_24    Oscillation
# Biostat2L_29_Oscillation_48    Oscillation
# Biostat2L_29_Oscillation_72    Oscillation
# Biostat2L_30_Oscillation_24    Oscillation
# Biostat2L_30_Oscillation_48    Oscillation
# Biostat2L_30_Oscillation_72    Oscillation
# Biostat2L_31_Oscillation_24    Oscillation
# Biostat2L_31_Oscillation_48    Oscillation
# Biostat2L_31_Oscillation_72    Oscillation
# Biostat2L_32_Low_24                    Low
# Biostat2L_32_Low_48                    Low
# Biostat2L_32_Low_72                    Low
# Biostat2L_33_Low_24                    Low
# Biostat2L_33_Low_48                    Low
# Biostat2L_33_Low_72                    Low
# Biostat2L_34_Low_24                    Low
# Biostat2L_34_Low_48                    Low
# Biostat2L_34_Low_72                    Low
# dtype: object

# %%
# late stats.
prot_OscvsLowLateCombined_stats = global_stats_calc_prot(prot_oscillation_vs_low_late_combined,
                                                                         condition_series_OscvsLowLateCombined)
# Out:
# Skipping protein jgi|YarliW29_1|1022@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1094@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1150@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1197@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1233@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1461@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1465@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1560@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1594@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1627@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1636@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1643@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1765@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1840@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1902@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|195@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|1977@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2204@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2263@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2285@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2292@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2306@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2333@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2338@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2452@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2470@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2495@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2532@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2631@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2744@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2828@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|2980@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3148@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3167@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3242@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3343@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3456@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3464@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3487@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3523@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3767@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3773@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3774@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3891@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|3918@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4014@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4039@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4047@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4048@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|405@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4087@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4106@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4107@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4114@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4130@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4219@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4256@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4282@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4309@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4364@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4495@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4519@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4610@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4642@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4786@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4804@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4863@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4875@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|4911@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5054@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5150@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5279@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5413@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5438@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5499@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5640@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5642@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5646@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5790@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5855@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5881@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5889@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5928@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5935@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|5976@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|598@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6065@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|614@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6152@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6161@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|620@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6242@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6611@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6677@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6679@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6741@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6807@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6822@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6952@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|6966@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7184@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7206@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7249@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7315@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7344@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7366@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7437@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7511@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7524@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7539@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7580@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7607@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7630@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7699@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|779@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7838@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|7856@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|841@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|891@GLB due to insufficient data in some groups.
# Skipping protein jgi|YarliW29_1|94@GLB due to insufficient data in some groups.

# %%
# Extract the number between "YarliW29_1|" and "@GLB" using regex.
prot_OscvsLowLateCombined_stats["proteinID"] = prot_OscvsLowLateCombined_stats["Protein"].str.extract(r"YarliW29_1\|(\d+)@GLB")



# Convert the extracted number to integer (if needed).
prot_OscvsLowLateCombined_stats["proteinID"] = prot_OscvsLowLateCombined_stats["proteinID"].astype(int)

# %% [markdown]
# ### calculate log2FC

# %%
oscLateCombinedLate = prot_OscvsLowLateCombined_stats.loc[:, prot_OscvsLowLateCombined_stats.columns[
    prot_OscvsLowLateCombined_stats.columns.str.contains("Oscillation")]]


oscLateCombinedLate.head()
# Out:
#    Biostat2L_29_Oscillation_24  Biostat2L_29_Oscillation_48  \
# 0                    25.770213                    25.649494
# 1                    17.293959                    16.996140
# 2                    22.817965                    22.221128
# 3                    21.661173                    21.343351
# 4                    24.612309                    26.057785
#
#    Biostat2L_29_Oscillation_72  Biostat2L_30_Oscillation_24  \
# 0                    25.495693                    25.715243
# 1                    16.940736                    17.327794
# 2                    22.204025                    22.932771
# 3                    21.351494                    21.707582
# 4                    26.347074                    24.327574
#
#    Biostat2L_30_Oscillation_48  Biostat2L_30_Oscillation_72  \
# 0                    25.566222                    25.374818
# 1                    17.056977                    17.046313
# 2                    22.337595                    22.194845
# 3                    21.402202                    21.308422
# 4                    25.953402                    26.186906
#
#    Biostat2L_31_Oscillation_24  Biostat2L_31_Oscillation_48  \
# 0                    25.570000                    25.482029
# 1                    17.368511                    16.924630
# 2                    22.802610                    22.099818
# 3                    21.931092                    21.302869
# 4                    24.420266                    26.070097
#
#    Biostat2L_31_Oscillation_72
# 0                    25.288831
# 1                    16.850427
# 2                    21.977757
# 3                    21.313301
# 4                    26.439499

# %%
lowLateCombined = prot_OscvsLowLateCombined_stats.loc[:, prot_OscvsLowLateCombined_stats.columns[prot_OscvsLowLateCombined_stats.columns.str.contains("Low")]]
lowLateCombined.head()
# Out:
#    Biostat2L_32_Low_24  Biostat2L_32_Low_48  Biostat2L_32_Low_72  \
# 0            26.121008            26.238225            26.102031
# 1            17.637680            17.496024            17.353521
# 2            23.468714            22.878133            22.612891
# 3            21.777503            21.527272            21.430709
# 4            24.002981            24.253218            24.949376
#
#    Biostat2L_33_Low_24  Biostat2L_33_Low_48  Biostat2L_33_Low_72  \
# 0            26.215771            26.254312            26.329296
# 1            17.824969            17.550454            17.492877
# 2            23.962114            23.148530            22.770328
# 3            21.864980            21.646451            21.371498
# 4            23.056913            23.387934            24.626466
#
#    Biostat2L_34_Low_24  Biostat2L_34_Low_48  Biostat2L_34_Low_72
# 0            26.010065            26.227300            26.059671
# 1            17.668527            17.466942            17.402518
# 2            23.563942            22.947880            22.543373
# 3            21.903156            21.644129            21.391500
# 4            23.622010            24.104213            24.727999

# %%
# gives the increase of the first. 
prot_OscvsLowLateCombined_stats['log2FC_Osc_vs_low_Late']=log2FC_function(oscLateCombinedLate, lowLateCombined)

# %%
df_to_merge = pd.DataFrame()
df_to_merge['osc/low_late_cominbed'] = prot_OscvsLowLateCombined_stats['log2FC_Osc_vs_low_Late']
df_to_merge['proteinId'] = prot_OscvsLowLateCombined_stats['proteinID']
df_to_merge['osc/low_late_cominbedANOVA_padj'] = prot_OscvsLowLateCombined_stats['ANOVA_padj']
df_to_merge['osc/low_late_cominbedANOVA_p'] = prot_OscvsLowLateCombined_stats['ANOVA_p']

# %% [markdown]
# ## Venn Diagram of overlap.

# %%
low_sig = merged_df[
    (merged_df['low/control_late_combined_ANOVA_padj'] < 0.05) &
    (abs(merged_df['low/control_late_combined']) > log2FC_threshold)
]

osc_sig =  merged_df[
    (merged_df['osc/control_late_cominbedANOVA_padj'] < 0.05) &
    (abs(merged_df['osc/control_late_cominbed']) > log2FC_threshold)
]

# %%
low_sig_sites = low_sig['Site'].values
low_sig_sites
# Out:
# array(['jgi|YarliW29_1|100@GLB', 'jgi|YarliW29_1|1002@GLB',
#        'jgi|YarliW29_1|1004@GLB', ..., 'jgi|YarliW29_1|969@GLB',
#        'jgi|YarliW29_1|971@GLB', 'jgi|YarliW29_1|972@GLB'], dtype=object)

# %%
osc_sig_sites = osc_sig['Site'].values
osc_sig_sites
# Out:
# array(['jgi|YarliW29_1|1008@GLB', 'jgi|YarliW29_1|1020@GLB',
#        'jgi|YarliW29_1|1029@GLB', 'jgi|YarliW29_1|1036@GLB',
#        'jgi|YarliW29_1|1065@GLB', 'jgi|YarliW29_1|1076@GLB',
#        'jgi|YarliW29_1|1080@GLB', 'jgi|YarliW29_1|1084@GLB',
#        'jgi|YarliW29_1|1096@GLB', 'jgi|YarliW29_1|1109@GLB',
#        'jgi|YarliW29_1|111@GLB', 'jgi|YarliW29_1|1121@GLB',
#        'jgi|YarliW29_1|1125@GLB', 'jgi|YarliW29_1|1127@GLB',
#        'jgi|YarliW29_1|1132@GLB', 'jgi|YarliW29_1|1137@GLB',
#        'jgi|YarliW29_1|1143@GLB', 'jgi|YarliW29_1|1172@GLB',
#        'jgi|YarliW29_1|1186@GLB', 'jgi|YarliW29_1|1197@GLB',
#        'jgi|YarliW29_1|120@GLB', 'jgi|YarliW29_1|1206@GLB',
#        'jgi|YarliW29_1|1212@GLB', 'jgi|YarliW29_1|1214@GLB',
#        'jgi|YarliW29_1|1219@GLB', 'jgi|YarliW29_1|1228@GLB',
#        'jgi|YarliW29_1|1245@GLB', 'jgi|YarliW29_1|1256@GLB',
#        'jgi|YarliW29_1|1270@GLB', 'jgi|YarliW29_1|129@GLB',
#        'jgi|YarliW29_1|1319@GLB', 'jgi|YarliW29_1|1340@GLB',
#        'jgi|YarliW29_1|1363@GLB', 'jgi|YarliW29_1|1364@GLB',
#        'jgi|YarliW29_1|1365@GLB', 'jgi|YarliW29_1|1370@GLB',
#        'jgi|YarliW29_1|1386@GLB', 'jgi|YarliW29_1|1406@GLB',
#        'jgi|YarliW29_1|1409@GLB', 'jgi|YarliW29_1|1416@GLB',
#        'jgi|YarliW29_1|1418@GLB', 'jgi|YarliW29_1|1422@GLB',
#        'jgi|YarliW29_1|143@GLB', 'jgi|YarliW29_1|1438@GLB',
#        'jgi|YarliW29_1|1442@GLB', 'jgi|YarliW29_1|1448@GLB',
#        'jgi|YarliW29_1|1450@GLB', 'jgi|YarliW29_1|1460@GLB',
#        'jgi|YarliW29_1|1464@GLB', 'jgi|YarliW29_1|1471@GLB',
#        'jgi|YarliW29_1|1473@GLB', 'jgi|YarliW29_1|1495@GLB',
#        'jgi|YarliW29_1|1513@GLB', 'jgi|YarliW29_1|1515@GLB',
#        'jgi|YarliW29_1|1521@GLB', 'jgi|YarliW29_1|1533@GLB',
#        'jgi|YarliW29_1|1539@GLB', 'jgi|YarliW29_1|1547@GLB',
#        'jgi|YarliW29_1|1548@GLB', 'jgi|YarliW29_1|1552@GLB',
#        'jgi|YarliW29_1|1573@GLB', 'jgi|YarliW29_1|1575@GLB',
#        'jgi|YarliW29_1|158@GLB', 'jgi|YarliW29_1|1585@GLB',
#        'jgi|YarliW29_1|1593@GLB', 'jgi|YarliW29_1|1605@GLB',
#        'jgi|YarliW29_1|1627@GLB', 'jgi|YarliW29_1|1631@GLB',
#        'jgi|YarliW29_1|1632@GLB', 'jgi|YarliW29_1|1637@GLB',
#        'jgi|YarliW29_1|1640@GLB', 'jgi|YarliW29_1|1643@GLB',
#        'jgi|YarliW29_1|1644@GLB', 'jgi|YarliW29_1|1646@GLB',
#        'jgi|YarliW29_1|1650@GLB', 'jgi|YarliW29_1|1657@GLB',
#        'jgi|YarliW29_1|1658@GLB', 'jgi|YarliW29_1|1659@GLB',
#        'jgi|YarliW29_1|1665@GLB', 'jgi|YarliW29_1|1685@GLB',
#        'jgi|YarliW29_1|1690@GLB', 'jgi|YarliW29_1|1703@GLB',
#        'jgi|YarliW29_1|1715@GLB', 'jgi|YarliW29_1|1719@GLB',
#        'jgi|YarliW29_1|1724@GLB', 'jgi|YarliW29_1|1725@GLB',
#        'jgi|YarliW29_1|1731@GLB', 'jgi|YarliW29_1|1733@GLB',
#        'jgi|YarliW29_1|1751@GLB', 'jgi|YarliW29_1|1763@GLB',
#        'jgi|YarliW29_1|1781@GLB', 'jgi|YarliW29_1|1796@GLB',
#        'jgi|YarliW29_1|1808@GLB', 'jgi|YarliW29_1|1811@GLB',
#        'jgi|YarliW29_1|1819@GLB', 'jgi|YarliW29_1|1820@GLB',
#        'jgi|YarliW29_1|1821@GLB', 'jgi|YarliW29_1|1858@GLB',
#        'jgi|YarliW29_1|1871@GLB', 'jgi|YarliW29_1|1878@GLB',
#        'jgi|YarliW29_1|1895@GLB', 'jgi|YarliW29_1|1897@GLB',
#        'jgi|YarliW29_1|19@GLB', 'jgi|YarliW29_1|1902@GLB',
#        'jgi|YarliW29_1|1904@GLB', 'jgi|YarliW29_1|1908@GLB',
#        'jgi|YarliW29_1|1910@GLB', 'jgi|YarliW29_1|1927@GLB',
#        'jgi|YarliW29_1|1929@GLB', 'jgi|YarliW29_1|1930@GLB',
#        'jgi|YarliW29_1|1934@GLB', 'jgi|YarliW29_1|1939@GLB',
#        'jgi|YarliW29_1|1940@GLB', 'jgi|YarliW29_1|1941@GLB',
#        'jgi|YarliW29_1|1955@GLB', 'jgi|YarliW29_1|1967@GLB',
#        'jgi|YarliW29_1|1968@GLB', 'jgi|YarliW29_1|1975@GLB',
#        'jgi|YarliW29_1|1985@GLB', 'jgi|YarliW29_1|2009@GLB',
#        'jgi|YarliW29_1|2011@GLB', 'jgi|YarliW29_1|2014@GLB',
#        'jgi|YarliW29_1|2015@GLB', 'jgi|YarliW29_1|2027@GLB',
#        'jgi|YarliW29_1|2038@GLB', 'jgi|YarliW29_1|2046@GLB',
#        'jgi|YarliW29_1|2061@GLB', 'jgi|YarliW29_1|2067@GLB',
#        'jgi|YarliW29_1|2073@GLB', 'jgi|YarliW29_1|2083@GLB',
#        'jgi|YarliW29_1|211@GLB', 'jgi|YarliW29_1|212@GLB',
#        'jgi|YarliW29_1|2159@GLB', 'jgi|YarliW29_1|2174@GLB',
#        'jgi|YarliW29_1|2202@GLB', 'jgi|YarliW29_1|2212@GLB',
#        'jgi|YarliW29_1|2236@GLB', 'jgi|YarliW29_1|2260@GLB',
#        'jgi|YarliW29_1|2289@GLB', 'jgi|YarliW29_1|2302@GLB',
#        'jgi|YarliW29_1|2331@GLB', 'jgi|YarliW29_1|2338@GLB',
#        'jgi|YarliW29_1|2339@GLB', 'jgi|YarliW29_1|2344@GLB',
#        'jgi|YarliW29_1|2364@GLB', 'jgi|YarliW29_1|2365@GLB',
#        'jgi|YarliW29_1|2374@GLB', 'jgi|YarliW29_1|2384@GLB',
#        'jgi|YarliW29_1|2390@GLB', 'jgi|YarliW29_1|2398@GLB',
#        'jgi|YarliW29_1|2401@GLB', 'jgi|YarliW29_1|2416@GLB',
#        'jgi|YarliW29_1|2426@GLB', 'jgi|YarliW29_1|2470@GLB',
#        'jgi|YarliW29_1|2492@GLB', 'jgi|YarliW29_1|2498@GLB',
#        'jgi|YarliW29_1|25@GLB', 'jgi|YarliW29_1|2504@GLB',
#        'jgi|YarliW29_1|2522@GLB', 'jgi|YarliW29_1|2526@GLB',
#        'jgi|YarliW29_1|2551@GLB', 'jgi|YarliW29_1|2555@GLB',
#        'jgi|YarliW29_1|2558@GLB', 'jgi|YarliW29_1|2567@GLB',
#        'jgi|YarliW29_1|2570@GLB', 'jgi|YarliW29_1|2583@GLB',
#        'jgi|YarliW29_1|2600@GLB', 'jgi|YarliW29_1|2622@GLB',
#        'jgi|YarliW29_1|2638@GLB', 'jgi|YarliW29_1|2645@GLB',
#        'jgi|YarliW29_1|2659@GLB', 'jgi|YarliW29_1|2667@GLB',
#        'jgi|YarliW29_1|2689@GLB', 'jgi|YarliW29_1|2693@GLB',
#        'jgi|YarliW29_1|2705@GLB', 'jgi|YarliW29_1|2716@GLB',
#        'jgi|YarliW29_1|2717@GLB', 'jgi|YarliW29_1|2795@GLB',
#        'jgi|YarliW29_1|2801@GLB', 'jgi|YarliW29_1|2805@GLB',
#        'jgi|YarliW29_1|2845@GLB', 'jgi|YarliW29_1|2868@GLB',
#        'jgi|YarliW29_1|2872@GLB', 'jgi|YarliW29_1|2882@GLB',
#        'jgi|YarliW29_1|2888@GLB', 'jgi|YarliW29_1|2905@GLB',
#        'jgi|YarliW29_1|2911@GLB', 'jgi|YarliW29_1|2912@GLB',
#        'jgi|YarliW29_1|2918@GLB', 'jgi|YarliW29_1|2927@GLB',
#        'jgi|YarliW29_1|2936@GLB', 'jgi|YarliW29_1|2940@GLB',
#        'jgi|YarliW29_1|2941@GLB', 'jgi|YarliW29_1|2946@GLB',
#        'jgi|YarliW29_1|2951@GLB', 'jgi|YarliW29_1|2952@GLB',
#        'jgi|YarliW29_1|2963@GLB', 'jgi|YarliW29_1|2964@GLB',
#        'jgi|YarliW29_1|2975@GLB', 'jgi|YarliW29_1|2994@GLB',
#        'jgi|YarliW29_1|3031@GLB', 'jgi|YarliW29_1|3041@GLB',
#        'jgi|YarliW29_1|3072@GLB', 'jgi|YarliW29_1|3082@GLB',
#        'jgi|YarliW29_1|3089@GLB', 'jgi|YarliW29_1|3109@GLB',
#        'jgi|YarliW29_1|3111@GLB', 'jgi|YarliW29_1|3125@GLB',
#        'jgi|YarliW29_1|3129@GLB', 'jgi|YarliW29_1|3137@GLB',
#        'jgi|YarliW29_1|314@GLB', 'jgi|YarliW29_1|3152@GLB',
#        'jgi|YarliW29_1|318@GLB', 'jgi|YarliW29_1|3182@GLB',
#        'jgi|YarliW29_1|3188@GLB', 'jgi|YarliW29_1|32@GLB',
#        'jgi|YarliW29_1|3205@GLB', 'jgi|YarliW29_1|3219@GLB',
#        'jgi|YarliW29_1|3233@GLB', 'jgi|YarliW29_1|3245@GLB',
#        'jgi|YarliW29_1|3251@GLB', 'jgi|YarliW29_1|3262@GLB',
#        'jgi|YarliW29_1|3264@GLB', 'jgi|YarliW29_1|3267@GLB',
#        'jgi|YarliW29_1|3277@GLB', 'jgi|YarliW29_1|3284@GLB',
#        'jgi|YarliW29_1|3299@GLB', 'jgi|YarliW29_1|3324@GLB',
#        'jgi|YarliW29_1|3339@GLB', 'jgi|YarliW29_1|3375@GLB',
#        'jgi|YarliW29_1|3376@GLB', 'jgi|YarliW29_1|3414@GLB',
#        'jgi|YarliW29_1|3432@GLB', 'jgi|YarliW29_1|3448@GLB',
#        'jgi|YarliW29_1|3449@GLB', 'jgi|YarliW29_1|3455@GLB',
#        'jgi|YarliW29_1|3499@GLB', 'jgi|YarliW29_1|3509@GLB',
#        'jgi|YarliW29_1|3519@GLB', 'jgi|YarliW29_1|3525@GLB',
#        'jgi|YarliW29_1|3534@GLB', 'jgi|YarliW29_1|3544@GLB',
#        'jgi|YarliW29_1|3545@GLB', 'jgi|YarliW29_1|3554@GLB',
#        'jgi|YarliW29_1|3568@GLB', 'jgi|YarliW29_1|3569@GLB',
#        'jgi|YarliW29_1|3580@GLB', 'jgi|YarliW29_1|3605@GLB',
#        'jgi|YarliW29_1|3608@GLB', 'jgi|YarliW29_1|3609@GLB',
#        'jgi|YarliW29_1|3626@GLB', 'jgi|YarliW29_1|3633@GLB',
#        'jgi|YarliW29_1|3636@GLB', 'jgi|YarliW29_1|3650@GLB',
#        'jgi|YarliW29_1|3658@GLB', 'jgi|YarliW29_1|3660@GLB',
#        'jgi|YarliW29_1|3665@GLB', 'jgi|YarliW29_1|3690@GLB',
#        'jgi|YarliW29_1|3695@GLB', 'jgi|YarliW29_1|37@GLB',
#        'jgi|YarliW29_1|3730@GLB', 'jgi|YarliW29_1|3731@GLB',
#        'jgi|YarliW29_1|3748@GLB', 'jgi|YarliW29_1|3749@GLB',
#        'jgi|YarliW29_1|3756@GLB', 'jgi|YarliW29_1|3761@GLB',
#        'jgi|YarliW29_1|3773@GLB', 'jgi|YarliW29_1|3774@GLB',
#        'jgi|YarliW29_1|379@GLB', 'jgi|YarliW29_1|3794@GLB',
#        'jgi|YarliW29_1|380@GLB', 'jgi|YarliW29_1|3800@GLB',
#        'jgi|YarliW29_1|3816@GLB', 'jgi|YarliW29_1|3839@GLB',
#        'jgi|YarliW29_1|3841@GLB', 'jgi|YarliW29_1|3845@GLB',
#        'jgi|YarliW29_1|385@GLB', 'jgi|YarliW29_1|3862@GLB',
#        'jgi|YarliW29_1|3864@GLB', 'jgi|YarliW29_1|3883@GLB',
#        'jgi|YarliW29_1|3908@GLB', 'jgi|YarliW29_1|3911@GLB',
#        'jgi|YarliW29_1|3916@GLB', 'jgi|YarliW29_1|3917@GLB',
#        'jgi|YarliW29_1|3922@GLB', 'jgi|YarliW29_1|3927@GLB',
#        'jgi|YarliW29_1|3930@GLB', 'jgi|YarliW29_1|3931@GLB',
#        'jgi|YarliW29_1|3932@GLB', 'jgi|YarliW29_1|3945@GLB',
#        'jgi|YarliW29_1|3951@GLB', 'jgi|YarliW29_1|3963@GLB',
#        'jgi|YarliW29_1|3970@GLB', 'jgi|YarliW29_1|3976@GLB',
#        'jgi|YarliW29_1|4@GLB', 'jgi|YarliW29_1|4000@GLB',
#        'jgi|YarliW29_1|4001@GLB', 'jgi|YarliW29_1|4012@GLB',
#        'jgi|YarliW29_1|4030@GLB', 'jgi|YarliW29_1|4040@GLB',
#        'jgi|YarliW29_1|4042@GLB', 'jgi|YarliW29_1|4047@GLB',
#        'jgi|YarliW29_1|4066@GLB', 'jgi|YarliW29_1|4075@GLB',
#        'jgi|YarliW29_1|4079@GLB', 'jgi|YarliW29_1|4089@GLB',
#        'jgi|YarliW29_1|4110@GLB', 'jgi|YarliW29_1|413@GLB',
#        'jgi|YarliW29_1|4171@GLB', 'jgi|YarliW29_1|4173@GLB',
#        'jgi|YarliW29_1|4174@GLB', 'jgi|YarliW29_1|4181@GLB',
#        'jgi|YarliW29_1|4188@GLB', 'jgi|YarliW29_1|4195@GLB',
#        'jgi|YarliW29_1|420@GLB', 'jgi|YarliW29_1|4206@GLB',
#        'jgi|YarliW29_1|421@GLB', 'jgi|YarliW29_1|4221@GLB',
#        'jgi|YarliW29_1|4224@GLB', 'jgi|YarliW29_1|423@GLB',
#        'jgi|YarliW29_1|4233@GLB', 'jgi|YarliW29_1|4244@GLB',
#        'jgi|YarliW29_1|4253@GLB', 'jgi|YarliW29_1|4271@GLB',
#        'jgi|YarliW29_1|4280@GLB', 'jgi|YarliW29_1|4282@GLB',
#        'jgi|YarliW29_1|4311@GLB', 'jgi|YarliW29_1|433@GLB',
#        'jgi|YarliW29_1|4340@GLB', 'jgi|YarliW29_1|4351@GLB',
#        'jgi|YarliW29_1|4364@GLB', 'jgi|YarliW29_1|4372@GLB',
#        'jgi|YarliW29_1|4402@GLB', 'jgi|YarliW29_1|4413@GLB',
#        'jgi|YarliW29_1|4417@GLB', 'jgi|YarliW29_1|4433@GLB',
#        'jgi|YarliW29_1|4435@GLB', 'jgi|YarliW29_1|4442@GLB',
#        'jgi|YarliW29_1|4443@GLB', 'jgi|YarliW29_1|4444@GLB',
#        'jgi|YarliW29_1|4445@GLB', 'jgi|YarliW29_1|4466@GLB',
#        'jgi|YarliW29_1|4479@GLB', 'jgi|YarliW29_1|4503@GLB',
#        'jgi|YarliW29_1|4544@GLB', 'jgi|YarliW29_1|4559@GLB',
#        'jgi|YarliW29_1|4587@GLB', 'jgi|YarliW29_1|46@GLB',
#        'jgi|YarliW29_1|4610@GLB', 'jgi|YarliW29_1|4621@GLB',
#        'jgi|YarliW29_1|4629@GLB', 'jgi|YarliW29_1|4631@GLB',
#        'jgi|YarliW29_1|4632@GLB', 'jgi|YarliW29_1|4642@GLB',
#        'jgi|YarliW29_1|4646@GLB', 'jgi|YarliW29_1|4648@GLB',
#        'jgi|YarliW29_1|4671@GLB', 'jgi|YarliW29_1|4678@GLB',
#        'jgi|YarliW29_1|4680@GLB', 'jgi|YarliW29_1|4681@GLB',
#        'jgi|YarliW29_1|4694@GLB', 'jgi|YarliW29_1|4702@GLB',
#        'jgi|YarliW29_1|4704@GLB', 'jgi|YarliW29_1|4721@GLB',
#        'jgi|YarliW29_1|4722@GLB', 'jgi|YarliW29_1|4725@GLB',
#        'jgi|YarliW29_1|4728@GLB', 'jgi|YarliW29_1|4737@GLB',
#        'jgi|YarliW29_1|4741@GLB', 'jgi|YarliW29_1|4743@GLB',
#        'jgi|YarliW29_1|4748@GLB', 'jgi|YarliW29_1|4758@GLB',
#        'jgi|YarliW29_1|4763@GLB', 'jgi|YarliW29_1|4777@GLB',
#        'jgi|YarliW29_1|478@GLB', 'jgi|YarliW29_1|4793@GLB',
#        'jgi|YarliW29_1|4796@GLB', 'jgi|YarliW29_1|48@GLB',
#        'jgi|YarliW29_1|4803@GLB', 'jgi|YarliW29_1|4805@GLB',
#        'jgi|YarliW29_1|4814@GLB', 'jgi|YarliW29_1|4820@GLB',
#        'jgi|YarliW29_1|4843@GLB', 'jgi|YarliW29_1|4855@GLB',
#        'jgi|YarliW29_1|4874@GLB', 'jgi|YarliW29_1|4875@GLB',
#        'jgi|YarliW29_1|488@GLB', 'jgi|YarliW29_1|4892@GLB',
#        'jgi|YarliW29_1|490@GLB', 'jgi|YarliW29_1|4900@GLB',
#        'jgi|YarliW29_1|4933@GLB', 'jgi|YarliW29_1|4961@GLB',
#        'jgi|YarliW29_1|4964@GLB', 'jgi|YarliW29_1|4968@GLB',
#        'jgi|YarliW29_1|4983@GLB', 'jgi|YarliW29_1|4998@GLB',
#        'jgi|YarliW29_1|4999@GLB', 'jgi|YarliW29_1|5012@GLB',
#        'jgi|YarliW29_1|5021@GLB', 'jgi|YarliW29_1|5049@GLB',
#        'jgi|YarliW29_1|5054@GLB', 'jgi|YarliW29_1|5091@GLB',
#        'jgi|YarliW29_1|5102@GLB', 'jgi|YarliW29_1|5118@GLB',
#        'jgi|YarliW29_1|5132@GLB', 'jgi|YarliW29_1|5155@GLB',
#        'jgi|YarliW29_1|5164@GLB', 'jgi|YarliW29_1|5192@GLB',
#        'jgi|YarliW29_1|52@GLB', 'jgi|YarliW29_1|5202@GLB',
#        'jgi|YarliW29_1|5228@GLB', 'jgi|YarliW29_1|5236@GLB',
#        'jgi|YarliW29_1|5256@GLB', 'jgi|YarliW29_1|5261@GLB',
#        'jgi|YarliW29_1|5264@GLB', 'jgi|YarliW29_1|5277@GLB',
#        'jgi|YarliW29_1|5285@GLB', 'jgi|YarliW29_1|5286@GLB',
#        'jgi|YarliW29_1|5300@GLB', 'jgi|YarliW29_1|5303@GLB',
#        'jgi|YarliW29_1|5311@GLB', 'jgi|YarliW29_1|5330@GLB',
#        'jgi|YarliW29_1|5331@GLB', 'jgi|YarliW29_1|5335@GLB',
#        'jgi|YarliW29_1|5350@GLB', 'jgi|YarliW29_1|5351@GLB',
#        'jgi|YarliW29_1|5375@GLB', 'jgi|YarliW29_1|5382@GLB',
#        'jgi|YarliW29_1|5385@GLB', 'jgi|YarliW29_1|5391@GLB',
#        'jgi|YarliW29_1|5395@GLB', 'jgi|YarliW29_1|5400@GLB',
#        'jgi|YarliW29_1|5405@GLB', 'jgi|YarliW29_1|5419@GLB',
#        'jgi|YarliW29_1|5425@GLB', 'jgi|YarliW29_1|5442@GLB',
#        'jgi|YarliW29_1|5449@GLB', 'jgi|YarliW29_1|5474@GLB',
#        'jgi|YarliW29_1|5478@GLB', 'jgi|YarliW29_1|5499@GLB',
#        'jgi|YarliW29_1|5530@GLB', 'jgi|YarliW29_1|5558@GLB',
#        'jgi|YarliW29_1|5564@GLB', 'jgi|YarliW29_1|5624@GLB',
#        'jgi|YarliW29_1|5627@GLB', 'jgi|YarliW29_1|5637@GLB',
#        'jgi|YarliW29_1|5639@GLB', 'jgi|YarliW29_1|5640@GLB',
#        'jgi|YarliW29_1|565@GLB', 'jgi|YarliW29_1|5657@GLB',
#        'jgi|YarliW29_1|5659@GLB', 'jgi|YarliW29_1|5660@GLB',
#        'jgi|YarliW29_1|5661@GLB', 'jgi|YarliW29_1|5672@GLB',
#        'jgi|YarliW29_1|5676@GLB', 'jgi|YarliW29_1|5689@GLB',
#        'jgi|YarliW29_1|5706@GLB', 'jgi|YarliW29_1|5757@GLB',
#        'jgi|YarliW29_1|5759@GLB', 'jgi|YarliW29_1|5761@GLB',
#        'jgi|YarliW29_1|5763@GLB', 'jgi|YarliW29_1|5769@GLB',
#        'jgi|YarliW29_1|577@GLB', 'jgi|YarliW29_1|5774@GLB',
#        'jgi|YarliW29_1|5786@GLB', 'jgi|YarliW29_1|5790@GLB',
#        'jgi|YarliW29_1|5794@GLB', 'jgi|YarliW29_1|5799@GLB',
#        'jgi|YarliW29_1|5828@GLB', 'jgi|YarliW29_1|5835@GLB',
#        'jgi|YarliW29_1|5843@GLB', 'jgi|YarliW29_1|5855@GLB',
#        'jgi|YarliW29_1|5861@GLB', 'jgi|YarliW29_1|5871@GLB',
#        'jgi|YarliW29_1|5872@GLB', 'jgi|YarliW29_1|5881@GLB',
#        'jgi|YarliW29_1|5889@GLB', 'jgi|YarliW29_1|5908@GLB',
#        'jgi|YarliW29_1|5922@GLB', 'jgi|YarliW29_1|5923@GLB',
#        'jgi|YarliW29_1|5928@GLB', 'jgi|YarliW29_1|5946@GLB',
#        'jgi|YarliW29_1|5954@GLB', 'jgi|YarliW29_1|5985@GLB',
#        'jgi|YarliW29_1|6001@GLB', 'jgi|YarliW29_1|6004@GLB',
#        'jgi|YarliW29_1|6018@GLB', 'jgi|YarliW29_1|6038@GLB',
#        'jgi|YarliW29_1|6039@GLB', 'jgi|YarliW29_1|6045@GLB',
#        'jgi|YarliW29_1|6046@GLB', 'jgi|YarliW29_1|6100@GLB',
#        'jgi|YarliW29_1|6102@GLB', 'jgi|YarliW29_1|6125@GLB',
#        'jgi|YarliW29_1|6130@GLB', 'jgi|YarliW29_1|6133@GLB',
#        'jgi|YarliW29_1|6138@GLB', 'jgi|YarliW29_1|6175@GLB',
#        'jgi|YarliW29_1|6178@GLB', 'jgi|YarliW29_1|6181@GLB',
#        'jgi|YarliW29_1|6187@GLB', 'jgi|YarliW29_1|6222@GLB',
#        'jgi|YarliW29_1|6233@GLB', 'jgi|YarliW29_1|6237@GLB',
#        'jgi|YarliW29_1|6256@GLB', 'jgi|YarliW29_1|6269@GLB',
#        'jgi|YarliW29_1|627@GLB', 'jgi|YarliW29_1|6298@GLB',
#        'jgi|YarliW29_1|63@GLB', 'jgi|YarliW29_1|6309@GLB',
#        'jgi|YarliW29_1|6320@GLB', 'jgi|YarliW29_1|6326@GLB',
#        'jgi|YarliW29_1|634@GLB', 'jgi|YarliW29_1|6341@GLB',
#        'jgi|YarliW29_1|6352@GLB', 'jgi|YarliW29_1|6355@GLB',
#        'jgi|YarliW29_1|6367@GLB', 'jgi|YarliW29_1|6379@GLB',
#        'jgi|YarliW29_1|6382@GLB', 'jgi|YarliW29_1|6412@GLB',
#        'jgi|YarliW29_1|642@GLB', 'jgi|YarliW29_1|6424@GLB',
#        'jgi|YarliW29_1|6425@GLB', 'jgi|YarliW29_1|6427@GLB',
#        'jgi|YarliW29_1|6457@GLB', 'jgi|YarliW29_1|6466@GLB',
#        'jgi|YarliW29_1|6468@GLB', 'jgi|YarliW29_1|6469@GLB',
#        'jgi|YarliW29_1|6481@GLB', 'jgi|YarliW29_1|6490@GLB',
#        'jgi|YarliW29_1|6491@GLB', 'jgi|YarliW29_1|650@GLB',
#        'jgi|YarliW29_1|6545@GLB', 'jgi|YarliW29_1|6563@GLB',
#        'jgi|YarliW29_1|6565@GLB', 'jgi|YarliW29_1|6581@GLB',
#        'jgi|YarliW29_1|6602@GLB', 'jgi|YarliW29_1|6608@GLB',
#        'jgi|YarliW29_1|6610@GLB', 'jgi|YarliW29_1|6612@GLB',
#        'jgi|YarliW29_1|6618@GLB', 'jgi|YarliW29_1|6625@GLB',
#        'jgi|YarliW29_1|6628@GLB', 'jgi|YarliW29_1|6636@GLB',
#        'jgi|YarliW29_1|6641@GLB', 'jgi|YarliW29_1|6644@GLB',
#        'jgi|YarliW29_1|6651@GLB', 'jgi|YarliW29_1|6657@GLB',
#        'jgi|YarliW29_1|6662@GLB', 'jgi|YarliW29_1|6672@GLB',
#        'jgi|YarliW29_1|6673@GLB', 'jgi|YarliW29_1|668@GLB',
#        'jgi|YarliW29_1|6682@GLB', 'jgi|YarliW29_1|6683@GLB',
#        'jgi|YarliW29_1|6686@GLB', 'jgi|YarliW29_1|6690@GLB',
#        'jgi|YarliW29_1|6698@GLB', 'jgi|YarliW29_1|6704@GLB',
#        'jgi|YarliW29_1|6727@GLB', 'jgi|YarliW29_1|6758@GLB',
#        'jgi|YarliW29_1|6771@GLB', 'jgi|YarliW29_1|6778@GLB',
#        'jgi|YarliW29_1|6789@GLB', 'jgi|YarliW29_1|6790@GLB',
#        'jgi|YarliW29_1|6804@GLB', 'jgi|YarliW29_1|6816@GLB',
#        'jgi|YarliW29_1|6828@GLB', 'jgi|YarliW29_1|6830@GLB',
#        'jgi|YarliW29_1|6835@GLB', 'jgi|YarliW29_1|6849@GLB',
#        'jgi|YarliW29_1|6862@GLB', 'jgi|YarliW29_1|6864@GLB',
#        'jgi|YarliW29_1|6869@GLB', 'jgi|YarliW29_1|6888@GLB',
#        'jgi|YarliW29_1|6907@GLB', 'jgi|YarliW29_1|6913@GLB',
#        'jgi|YarliW29_1|6917@GLB', 'jgi|YarliW29_1|6942@GLB',
#        'jgi|YarliW29_1|6948@GLB', 'jgi|YarliW29_1|6963@GLB',
#        'jgi|YarliW29_1|6965@GLB', 'jgi|YarliW29_1|697@GLB',
#        'jgi|YarliW29_1|6970@GLB', 'jgi|YarliW29_1|7@GLB',
#        'jgi|YarliW29_1|7006@GLB', 'jgi|YarliW29_1|7032@GLB',
#        'jgi|YarliW29_1|7041@GLB', 'jgi|YarliW29_1|7051@GLB',
#        'jgi|YarliW29_1|7062@GLB', 'jgi|YarliW29_1|7091@GLB',
#        'jgi|YarliW29_1|7094@GLB', 'jgi|YarliW29_1|7095@GLB',
#        'jgi|YarliW29_1|7101@GLB', 'jgi|YarliW29_1|7106@GLB',
#        'jgi|YarliW29_1|7155@GLB', 'jgi|YarliW29_1|7157@GLB',
#        'jgi|YarliW29_1|7163@GLB', 'jgi|YarliW29_1|7173@GLB',
#        'jgi|YarliW29_1|7186@GLB', 'jgi|YarliW29_1|7187@GLB',
#        'jgi|YarliW29_1|7191@GLB', 'jgi|YarliW29_1|7199@GLB',
#        'jgi|YarliW29_1|720@GLB', 'jgi|YarliW29_1|721@GLB',
#        'jgi|YarliW29_1|7210@GLB', 'jgi|YarliW29_1|7221@GLB',
#        'jgi|YarliW29_1|7231@GLB', 'jgi|YarliW29_1|7235@GLB',
#        'jgi|YarliW29_1|7248@GLB', 'jgi|YarliW29_1|726@GLB',
#        'jgi|YarliW29_1|7265@GLB', 'jgi|YarliW29_1|7270@GLB',
#        'jgi|YarliW29_1|7274@GLB', 'jgi|YarliW29_1|7284@GLB',
#        'jgi|YarliW29_1|7309@GLB', 'jgi|YarliW29_1|7311@GLB',
#        'jgi|YarliW29_1|7312@GLB', 'jgi|YarliW29_1|7313@GLB',
#        'jgi|YarliW29_1|7315@GLB', 'jgi|YarliW29_1|7320@GLB',
#        'jgi|YarliW29_1|7329@GLB', 'jgi|YarliW29_1|7338@GLB',
#        'jgi|YarliW29_1|7339@GLB', 'jgi|YarliW29_1|7344@GLB',
#        'jgi|YarliW29_1|7355@GLB', 'jgi|YarliW29_1|7363@GLB',
#        'jgi|YarliW29_1|7366@GLB', 'jgi|YarliW29_1|7367@GLB',
#        'jgi|YarliW29_1|7371@GLB', 'jgi|YarliW29_1|7387@GLB',
#        'jgi|YarliW29_1|7395@GLB', 'jgi|YarliW29_1|7400@GLB',
#        'jgi|YarliW29_1|7401@GLB', 'jgi|YarliW29_1|7404@GLB',
#        'jgi|YarliW29_1|7433@GLB', 'jgi|YarliW29_1|7445@GLB',
#        'jgi|YarliW29_1|747@GLB', 'jgi|YarliW29_1|7484@GLB',
#        'jgi|YarliW29_1|7489@GLB', 'jgi|YarliW29_1|7503@GLB',
#        'jgi|YarliW29_1|7505@GLB', 'jgi|YarliW29_1|7506@GLB',
#        'jgi|YarliW29_1|7507@GLB', 'jgi|YarliW29_1|7511@GLB',
#        'jgi|YarliW29_1|7522@GLB', 'jgi|YarliW29_1|7540@GLB',
#        'jgi|YarliW29_1|7558@GLB', 'jgi|YarliW29_1|7570@GLB',
#        'jgi|YarliW29_1|7573@GLB', 'jgi|YarliW29_1|7575@GLB',
#        'jgi|YarliW29_1|758@GLB', 'jgi|YarliW29_1|7580@GLB',
#        'jgi|YarliW29_1|7589@GLB', 'jgi|YarliW29_1|7595@GLB',
#        'jgi|YarliW29_1|7599@GLB', 'jgi|YarliW29_1|7608@GLB',
#        'jgi|YarliW29_1|7614@GLB', 'jgi|YarliW29_1|7634@GLB',
#        'jgi|YarliW29_1|7667@GLB', 'jgi|YarliW29_1|7673@GLB',
#        'jgi|YarliW29_1|7688@GLB', 'jgi|YarliW29_1|7690@GLB',
#        'jgi|YarliW29_1|7693@GLB', 'jgi|YarliW29_1|7704@GLB',
#        'jgi|YarliW29_1|7716@GLB', 'jgi|YarliW29_1|7740@GLB',
#        'jgi|YarliW29_1|7749@GLB', 'jgi|YarliW29_1|7769@GLB',
#        'jgi|YarliW29_1|779@GLB', 'jgi|YarliW29_1|7803@GLB',
#        'jgi|YarliW29_1|7807@GLB', 'jgi|YarliW29_1|7812@GLB',
#        'jgi|YarliW29_1|7835@GLB', 'jgi|YarliW29_1|7838@GLB',
#        'jgi|YarliW29_1|7844@GLB', 'jgi|YarliW29_1|7847@GLB',
#        'jgi|YarliW29_1|786@GLB', 'jgi|YarliW29_1|7864@GLB',
#        'jgi|YarliW29_1|7871@GLB', 'jgi|YarliW29_1|7879@GLB',
#        'jgi|YarliW29_1|7884@GLB', 'jgi|YarliW29_1|7886@GLB',
#        'jgi|YarliW29_1|7888@GLB', 'jgi|YarliW29_1|7893@GLB',
#        'jgi|YarliW29_1|7905@GLB', 'jgi|YarliW29_1|7911@GLB',
#        'jgi|YarliW29_1|798@GLB', 'jgi|YarliW29_1|803@GLB',
#        'jgi|YarliW29_1|813@GLB', 'jgi|YarliW29_1|818@GLB',
#        'jgi|YarliW29_1|831@GLB', 'jgi|YarliW29_1|833@GLB',
#        'jgi|YarliW29_1|857@GLB', 'jgi|YarliW29_1|862@GLB',
#        'jgi|YarliW29_1|870@GLB', 'jgi|YarliW29_1|880@GLB',
#        'jgi|YarliW29_1|889@GLB', 'jgi|YarliW29_1|891@GLB',
#        'jgi|YarliW29_1|894@GLB', 'jgi|YarliW29_1|92@GLB',
#        'jgi|YarliW29_1|940@GLB', 'jgi|YarliW29_1|941@GLB',
#        'jgi|YarliW29_1|950@GLB', 'jgi|YarliW29_1|963@GLB',
#        'jgi|YarliW29_1|976@GLB', 'jgi|YarliW29_1|999@GLB'], dtype=object)

# %%
len(osc_sig_sites)
# Out:
# 706

# %%
len(low_sig_sites)
# Out:
# 1086

# %%
len(set(osc_sig_sites)-set(low_sig_sites))
# Out:
# 351

# %%
len(set(osc_sig_sites).intersection(set(low_sig_sites)))
# Out:
# 355

# %%
# low_sig_sites = ['gene2', 'gene4', 'gene5']

venn2([set(osc_sig_sites), set(low_sig_sites)],
      set_labels=('Oscillation Significant', 'Low Significant'))

plt.title("Venn Diagram of Significant Genes")
plt.show()

# %%
venn = venn2([set(osc_sig_sites), set(low_sig_sites)],
             set_labels=('Oscillation Significant', 'Low Significant'))

# Set custom colors: light red and light blue
venn.get_patch_by_id('10').set_color('#ff9999')  # Light red
venn.get_patch_by_id('01').set_color('#9999ff')  # Light blue
venn.get_patch_by_id('11').set_color('#d3b3ff')  # Light purple for intersection (optional)

# Set font to Times New Roman
for text in venn.set_labels:
    text.set_fontfamily('Times New Roman')

for text in venn.subset_labels:
    if text:  # Check because some subsets may be empty
        text.set_fontfamily('Times New Roman')

# Title
plt.title("Venn Diagram of Significant Genes", fontname='Times New Roman')
# Out:
# Text(0.5, 1.0, 'Venn Diagram of Significant Genes')

# %% [markdown]
# Saving.

# %%
# # Convert to sets
# osc_set = set(osc_sig_sites)
# low_set = set(low_sig_sites)

# # Compute Venn parts
# only_osc = osc_set - low_set
# only_low = low_set - osc_set
# shared = osc_set & low_set

# # Extract rows from merged_df by gene IDs
# only_osc_df = merged_df[merged_df['Site'].isin(only_osc)]
# only_low_df = merged_df[merged_df['Site'].isin(only_low)]
# shared_df   = merged_df[merged_df['Site'].isin(shared)]

# # Optionally save to CSV
# only_osc_df.to_csv("only_osc_sig.csv", index=False)
# only_low_df.to_csv("only_low_sig.csv", index=False)
# shared_df.to_csv("shared_sig.csv", index=False)

# %% [markdown]
# # multiple Yarrowia gene annotations. mapping/annotations

# %%
def combine_dataframes(dataframes, names):
    """
    Combine multiple dataframes to create a single dataframe tracking provenance 
    of `ANOVA_p`, `ANOVA_padj`, `log2FC` while merging overlapping information.
    
    Args:
        dataframes (list of pd.DataFrame): List of DataFrames to combine.
        names (list of str): Names corresponding to each DataFrame for labeling unique columns.
    
    Returns:
        combined_df (pd.DataFrame): Combined DataFrame.
    """
    # List for renaming and merging
    dataframes_processed = []
    
    for df, name in zip(dataframes, names):
        # Select common and unique columns
        common_cols = ['Protein', 'proteinID', '#proteinId', 'definition',
                       'catalyticActivity', 'pathway', 'pathway_class', 'pathway_type',
                       'ecNum', 'cofactors', 'gotermId', 'gotermType', 'goName', 'goAcc']
        
        unique_cols = ['ANOVA_p', 'ANOVA_padj', 'log2FC']
        
        # Rename unique columns to track source
        df_renamed = df[common_cols + unique_cols].copy()
        df_renamed.rename(columns={
            'ANOVA_p': f'ANOVA_p_{name}',
            'ANOVA_padj': f'ANOVA_padj_{name}',
            'log2FC': f'log2FC_{name}'
        }, inplace=True)
        
        # Append processed DataFrame to the list
        dataframes_processed.append(df_renamed)
    
    # Merge all processed DataFrames on common columns using outer join
    combined_df = dataframes_processed[0]
    for df in dataframes_processed[1:]:
        combined_df = pd.merge(combined_df, df, on=['Protein', 'proteinID', '#proteinId', 'definition',
                                                    'catalyticActivity', 'pathway', 'pathway_class', 'pathway_type',
                                                    'ecNum', 'cofactors', 'gotermId', 'gotermType', 'goName', 'goAcc'],
                               how='outer')
    
    return combined_df

# Example usage

# Create a list of DataFrames (replace these with your actual DataFrames)
dataframes = [
    prot_control_late_vs_early_combined_stats_withAnnote,

    prot_control_vs_low_late_combined_stats_withAnnote,
    prot_control_vs_oscillation_late_combined_stats_withAnnote
]
for df in dataframes:
    for col in ['Protein', 'proteinID', '#proteinId', 'definition', 'catalyticActivity', 'pathway', 
                'pathway_class', 'pathway_type', 'ecNum', 'cofactors', 'gotermId', 'gotermType', 'goName', 'goAcc']:
        df[col] = df[col].astype(str)  # Convert key columns to string

# Create corresponding names for data provenance
names = [
    'late_vs_early_combined',
    'control_vs_low_late',
    'oscillation_late_combined'
]

# Combine all DataFrames into one
combined_df = combine_dataframes(dataframes, names)

# Save the result to a file or inspect it
# combined_df.to_csv("combined_dataframe.csv", index=False)

# %%
df_to_merge['proteinId'] = df_to_merge['proteinId'].astype(str)

# %%
combined_df['proteinId'] = combined_df['proteinID'].copy()

# %%
combined_df = pd.merge(combined_df, df_to_merge, left_on='proteinId',right_on='proteinId', how='left')

# %%
combined_df['#proteinId'] = combined_df['proteinID'].copy()

# %%
gene_dict = {}

# Step Open and Read the FASTA File
with open('../Data/DNA/W29.fasta', 'r') as fasta_file:
    for line in fasta_file:
        # Check for header lines starting with ">"
        if line.startswith(">"):
            # Extract the relevant fields from the header line
            header_parts = line.strip().split('|')  # Split header by '|'
            gene_id = header_parts[2]  # "1000"
            gene_name = header_parts[3]  # "YALI1_B02228p"
            
            # Map "1000" to "YALI1_B02228p" in the dictionary
            gene_dict[gene_id] = gene_name

# %%
gene_dict
# Out:
# {'1000': 'YALI1_B02228p',
#  '1001': 'YALI1_B02283p',
#  '1002': 'YALI1_B02345p',
#  '1003': 'YALI1_B02375p',
#  '1004': 'YALI1_B02415p',
#  '1005': 'YALI1_B02430p',
#  '1006': 'YALI1_B02465p',
#  '1007': 'YALI1_B02472p',
#  '1008': 'YALI1_B02487p',
#  '1009': 'YALI1_B02496p',
#  '100': 'YALI1_A02775p',
#  '1010': 'YALI1_B02506p',
#  '1011': 'YALI1_B02533p',
#  '1012': 'YALI1_B02550p',
#  '1013': 'YALI1_B02604p',
#  '1014': 'YALI1_B02637p',
#  '1015': 'YALI1_B02642p',
#  '1016': 'YALI1_B02672p',
#  '1017': 'YALI1_B02696p',
#  '1018': 'YALI1_B02717p',
#  '1019': 'YALI1_B02733p',
#  '101': 'YALI1_A02813p',
#  '1020': 'YALI1_B02767p',
#  '1021': 'YALI1_B02781p',
#  '1022': 'YALI1_B02806p',
#  '1023': 'YALI1_B02833p',
#  '1024': 'YALI1_B02850p',
#  '1025': 'YALI1_B02874p',
#  '1026': 'YALI1_B02881p',
#  '1027': 'YALI1_B02910p',
#  '1028': 'YALI1_B02931p',
#  '1029': 'YALI1_B02991p',
#  '102': 'YALI1_A02819p',
#  '1030': 'YALI1_B03021p',
#  '1031': 'YALI1_B03041p',
#  '1032': 'YALI1_B03043p',
#  '1033': 'YALI1_B03085p',
#  '1034': 'YALI1_B03120p',
#  '1035': 'YALI1_B03168p',
#  '1036': 'YALI1_B03198p',
#  '1037': 'YALI1_B03225p',
#  '1038': 'YALI1_B03288p',
#  '1039': 'YALI1_B03290p',
#  '103': 'YALI1_A02833p',
#  '1040': 'YALI1_B03299p',
#  '1041': 'YALI1_B03314p',
#  '1042': 'YALI1_B03324p',
#  '1043': 'YALI1_B03335p',
#  '1044': 'YALI1_B03404p',
#  '1045': 'YALI1_B03429p',
#  '1046': 'YALI1_B03516p',
#  '1047': 'YALI1_B03556p',
#  '1048': 'YALI1_B03610p',
#  '1049': 'YALI1_B03644p',
#  '104': 'YALI1_A02875p',
#  '1050': 'YALI1_B03673p',
#  '1051': 'YALI1_B03719p',
#  '1052': 'YALI1_B03761p',
#  '1053': 'YALI1_B03797p',
#  '1054': 'YALI1_B03807p',
#  '1055': 'YALI1_B03832p',
#  '1056': 'YALI1_B03853p',
#  '1057': 'YALI1_B03910p',
#  '1058': 'YALI1_B03963p',
#  '1059': 'YALI1_B03979p',
#  '105': 'YALI1_A02895p',
#  '1060': 'YALI1_B04007p',
#  '1061': 'YALI1_B04032p',
#  '1062': 'YALI1_B04068p',
#  '1063': 'YALI1_B04123p',
#  '1064': 'YALI1_B04138p',
#  '1065': 'YALI1_B04200p',
#  '1066': 'YALI1_B04212p',
#  '1067': 'YALI1_B04228p',
#  '1068': 'YALI1_B04248p',
#  '1069': 'YALI1_B04274p',
#  '106': 'YALI1_A02947p',
#  '1070': 'YALI1_B04309p',
#  '1071': 'YALI1_B04321p',
#  '1072': 'YALI1_B04370p',
#  '1073': 'YALI1_B04391p',
#  '1074': 'YALI1_B04433p',
#  '1075': 'YALI1_B04466p',
#  '1076': 'YALI1_B04470p',
#  '1077': 'YALI1_B04497p',
#  '1078': 'YALI1_B04502p',
#  '1079': 'YALI1_B04523p',
#  '107': 'YALI1_A02974p',
#  '1080': 'YALI1_B04540p',
#  '1081': 'YALI1_B04559p',
#  '1082': 'YALI1_B04577p',
#  '1083': 'YALI1_B04579p',
#  '1084': 'YALI1_B04589p',
#  '1085': 'YALI1_B04637p',
#  '1086': 'YALI1_B04663p',
#  '1087': 'YALI1_B04690p',
#  '1088': 'YALI1_B04703p',
#  '1089': 'YALI1_B04747p',
#  '108': 'YALI1_A02977p',
#  '1090': 'YALI1_B04753p',
#  '1091': 'YALI1_B04759p',
#  '1092': 'YALI1_B04779p',
#  '1093': 'YALI1_B04781p',
#  '1094': 'YALI1_B04803p',
#  '1095': 'YALI1_B04831p',
#  '1096': 'YALI1_B04853p',
#  '1097': 'YALI1_B04873p',
#  '1098': 'YALI1_B04901p',
#  '1099': 'YALI1_B04937p',
#  '109': 'YALI1_A02998p',
#  '10': 'YALI1_A00252p',
#  '1100': 'YALI1_B04947p',
#  '1101': 'YALI1_B04950p',
#  '1102': 'YALI1_B04974p',
#  '1103': 'YALI1_B05005p',
#  '1104': 'YALI1_B05024p',
#  '1105': 'YALI1_B05043p',
#  '1106': 'YALI1_B05072p',
#  '1107': 'YALI1_B05106p',
#  '1108': 'YALI1_B05185p',
#  '1109': 'YALI1_B05226p',
#  '110': 'YALI1_A03017p',
#  '1110': 'YALI1_B05242p',
#  '1111': 'YALI1_B05282p',
#  '1112': 'YALI1_B05295p',
#  '1113': 'YALI1_B05313p',
#  '1114': 'YALI1_B05350p',
#  '1115': 'YALI1_B05364p',
#  '1116': 'YALI1_B05404p',
#  '1117': 'YALI1_B05420p',
#  '1118': 'YALI1_B05438p',
#  '1119': 'YALI1_B05454p',
#  '111': 'YALI1_A03029p',
#  '1120': 'YALI1_B05483p',
#  '1121': 'YALI1_B05497p',
#  '1122': 'YALI1_B05520p',
#  '1123': 'YALI1_B05522p',
#  '1124': 'YALI1_B05571p',
#  '1125': 'YALI1_B05609p',
#  '1126': 'YALI1_B05639p',
#  '1127': 'YALI1_B05646p',
#  '1128': 'YALI1_B05690p',
#  '1129': 'YALI1_B05698p',
#  '112': 'YALI1_A03069p',
#  '1130': 'YALI1_B05711p',
#  '1131': 'YALI1_B05730p',
#  '1132': 'YALI1_B05762p',
#  '1133': 'YALI1_B05782p',
#  '1134': 'YALI1_B05798p',
#  '1135': 'YALI1_B05830p',
#  '1136': 'YALI1_B05832p',
#  '1137': 'YALI1_B05891p',
#  '1138': 'YALI1_B05947p',
#  '1139': 'YALI1_B05954p',
#  '113': 'YALI1_A03081p',
#  '1140': 'YALI1_B05964p',
#  '1141': 'YALI1_B05971p',
#  '1142': 'YALI1_B05984p',
#  '1143': 'YALI1_B05995p',
#  '1144': 'YALI1_B06015p',
#  '1145': 'YALI1_B06028p',
#  '1146': 'YALI1_B06089p',
#  '1147': 'YALI1_B06110p',
#  '1148': 'YALI1_B06134p',
#  '1149': 'YALI1_B06141p',
#  '114': 'YALI1_A03091p',
#  '1150': 'YALI1_B06146p',
#  '1151': 'YALI1_B06207p',
#  '1152': 'YALI1_B06245p',
#  '1153': 'YALI1_B06264p',
#  '1154': 'YALI1_B06315p',
#  '1155': 'YALI1_B06324p',
#  '1156': 'YALI1_B06328p',
#  '1157': 'YALI1_B06340p',
#  '1158': 'YALI1_B06447p',
#  '1159': 'YALI1_B06487p',
#  '115': 'YALI1_A03116p',
#  '1160': 'YALI1_B06489p',
#  '1161': 'YALI1_B06508p',
#  '1162': 'YALI1_B06514p',
#  '1163': 'YALI1_B06537p',
#  '1164': 'YALI1_B06546p',
#  '1165': 'YALI1_B06607p',
#  '1166': 'YALI1_B06613p',
#  '1167': 'YALI1_B06620p',
#  '1168': 'YALI1_B06628p',
#  '1169': 'YALI1_B06635p',
#  '116': 'YALI1_A03137p',
#  '1170': 'YALI1_B06640p',
#  '1171': 'YALI1_B06644p',
#  '1172': 'YALI1_B06704p',
#  '1173': 'YALI1_B06726p',
#  '1174': 'YALI1_B06735p',
#  '1175': 'YALI1_B06745p',
#  '1176': 'YALI1_B06776p',
#  '1177': 'YALI1_B06809p',
#  '1178': 'YALI1_B06839p',
#  '1179': 'YALI1_B06847p',
#  '117': 'YALI1_A03153p',
#  '1180': 'YALI1_B06866p',
#  '1181': 'YALI1_B06885p',
#  '1182': 'YALI1_B06928p',
#  '1183': 'YALI1_B06969p',
#  '1184': 'YALI1_B07043p',
#  '1185': 'YALI1_B07076p',
#  '1186': 'YALI1_B07094p',
#  '1187': 'YALI1_B07134p',
#  '1188': 'YALI1_B07162p',
#  '1189': 'YALI1_B07203p',
#  '118': 'YALI1_A03170p',
#  '1190': 'YALI1_B07210p',
#  '1191': 'YALI1_B07220p',
#  '1192': 'YALI1_B07271p',
#  '1193': 'YALI1_B07284p',
#  '1194': 'YALI1_B07295p',
#  '1195': 'YALI1_B07331p',
#  '1196': 'YALI1_B07366p',
#  '1197': 'YALI1_B07374p',
#  '1198': 'YALI1_B07399p',
#  '1199': 'YALI1_B07413p',
#  '119': 'YALI1_A03183p',
#  '11': 'YALI1_A00309p',
#  '1200': 'YALI1_B07444p',
#  '1201': 'YALI1_B07500p',
#  '1202': 'YALI1_B07538p',
#  '1203': 'YALI1_B07549p',
#  '1204': 'YALI1_B07578p',
#  '1205': 'YALI1_B07598p',
#  '1206': 'YALI1_B07652p',
#  '1207': 'YALI1_B07675p',
#  '1208': 'YALI1_B07696p',
#  '1209': 'YALI1_B07735p',
#  '120': 'YALI1_A03210p',
#  '1210': 'YALI1_B07762p',
#  '1211': 'YALI1_B07769p',
#  '1212': 'YALI1_B07786p',
#  '1213': 'YALI1_B07809p',
#  '1214': 'YALI1_B07843p',
#  '1215': 'YALI1_B07852p',
#  '1216': 'YALI1_B07853p',
#  '1217': 'YALI1_B07864p',
#  '1218': 'YALI1_B07915p',
#  '1219': 'YALI1_B07937p',
#  '121': 'YALI1_A03258p',
#  '1220': 'YALI1_B07957p',
#  '1221': 'YALI1_B07983p',
#  '1222': 'YALI1_B08094p',
#  '1223': 'YALI1_B08102p',
#  '1224': 'YALI1_B08123p',
#  '1225': 'YALI1_B08134p',
#  '1226': 'YALI1_B08156p',
#  '1227': 'YALI1_B08186p',
#  '1228': 'YALI1_B08193p',
#  '1229': 'YALI1_B08207p',
#  '122': 'YALI1_A03278p',
#  '1230': 'YALI1_B08214p',
#  '1231': 'YALI1_B08247p',
#  '1232': 'YALI1_B08263p',
#  '1233': 'YALI1_B08321p',
#  '1234': 'YALI1_B08374p',
#  '1235': 'YALI1_B08401p',
#  '1236': 'YALI1_B08438p',
#  '1237': 'YALI1_B08461p',
#  '1238': 'YALI1_B08493p',
#  '1239': 'YALI1_B08531p',
#  '123': 'YALI1_A03289p',
#  '1240': 'YALI1_B08540p',
#  '1241': 'YALI1_B08575p',
#  '1242': 'YALI1_B08580p',
#  '1243': 'YALI1_B08588p',
#  '1244': 'YALI1_B08616p',
#  '1245': 'YALI1_B08627p',
#  '1246': 'YALI1_B08650p',
#  '1247': 'YALI1_B08699p',
#  '1248': 'YALI1_B08721p',
#  '1249': 'YALI1_B08758p',
#  '124': 'YALI1_A03300p',
#  '1250': 'YALI1_B08783p',
#  '1251': 'YALI1_B08801p',
#  '1252': 'YALI1_B08817p',
#  '1253': 'YALI1_B08831p',
#  '1254': 'YALI1_B08851p',
#  '1255': 'YALI1_B08868p',
#  '1256': 'YALI1_B08885p',
#  '1257': 'YALI1_B08898p',
#  '1258': 'YALI1_B08975p',
#  '1259': 'YALI1_B08978p',
#  '125': 'YALI1_A03322p',
#  '1260': 'YALI1_B09002p',
#  '1261': 'YALI1_B09025p',
#  '1262': 'YALI1_B09044p',
#  '1263': 'YALI1_B09072p',
#  '1264': 'YALI1_B09090p',
#  '1265': 'YALI1_B09117p',
#  '1266': 'YALI1_B09132p',
#  '1267': 'YALI1_B09144p',
#  '1268': 'YALI1_B09161p',
#  '1269': 'YALI1_B09181p',
#  '126': 'YALI1_A03351p',
#  '1270': 'YALI1_B09211p',
#  '1271': 'YALI1_B09258p',
#  '1272': 'YALI1_B09266p',
#  '1273': 'YALI1_B09279p',
#  '1274': 'YALI1_B09299p',
#  '1275': 'YALI1_B09310p',
#  '1276': 'YALI1_B09316p',
#  '1277': 'YALI1_B09320p',
#  '1278': 'YALI1_B09333p',
#  '1279': 'YALI1_B09367p',
#  '127': 'YALI1_A03356p',
#  '1280': 'YALI1_B09426p',
#  '1281': 'YALI1_B09448p',
#  '1282': 'YALI1_B09476p',
#  '1283': 'YALI1_B09497p',
#  '1284': 'YALI1_B09518p',
#  '1285': 'YALI1_B09568p',
#  '1286': 'YALI1_B09580p',
#  '1287': 'YALI1_B09591p',
#  '1288': 'YALI1_B09592p',
#  '1289': 'YALI1_B09708p',
#  '128': 'YALI1_A03396p',
#  '1290': 'YALI1_B09807p',
#  '1291': 'YALI1_B09837p',
#  '1292': 'YALI1_B09871p',
#  '1293': 'YALI1_B09894p',
#  '1294': 'YALI1_B09929p',
#  '1295': 'YALI1_B09931p',
#  '1296': 'YALI1_B09957p',
#  '1297': 'YALI1_B09993p',
#  '1298': 'YALI1_B09994p',
#  '1299': 'YALI1_B10032p',
#  '129': 'YALI1_A03402p',
#  '12': 'YALI1_A00325p',
#  '1300': 'YALI1_B10094p',
#  '1301': 'YALI1_B10119p',
#  '1302': 'YALI1_B10130p',
#  '1303': 'YALI1_B10145p',
#  '1304': 'YALI1_B10170p',
#  '1305': 'YALI1_B10182p',
#  '1306': 'YALI1_B10185p',
#  '1307': 'YALI1_B10231p',
#  '1308': 'YALI1_B10263p',
#  '1309': 'YALI1_B10288p',
#  '130': 'YALI1_A03422p',
#  '1310': 'YALI1_B10359p',
#  '1311': 'YALI1_B10424p',
#  '1312': 'YALI1_B10437p',
#  '1313': 'YALI1_B10449p',
#  '1314': 'YALI1_B10463p',
#  '1315': 'YALI1_B10525p',
#  '1316': 'YALI1_B10552p',
#  '1317': 'YALI1_B10582p',
#  '1318': 'YALI1_B10607p',
#  '1319': 'YALI1_B10635p',
#  '131': 'YALI1_A03442p',
#  '1320': 'YALI1_B10751p',
#  '1321': 'YALI1_B10757p',
#  '1322': 'YALI1_B10762p',
#  '1323': 'YALI1_B10773p',
#  '1324': 'YALI1_B10780p',
#  '1325': 'YALI1_B10782p',
#  '1326': 'YALI1_B10813p',
#  '1327': 'YALI1_B10891p',
#  '1328': 'YALI1_B10933p',
#  '1329': 'YALI1_B10943p',
#  '132': 'YALI1_A03450p',
#  '1330': 'YALI1_B10990p',
#  '1331': 'YALI1_B11034p',
#  '1332': 'YALI1_B11083p',
#  '1333': 'YALI1_B11111p',
#  '1334': 'YALI1_B11120p',
#  '1335': 'YALI1_B11131p',
#  '1336': 'YALI1_B11167p',
#  '1337': 'YALI1_B11183p',
#  '1338': 'YALI1_B11200p',
#  '1339': 'YALI1_B11388p',
#  '133': 'YALI1_A03487p',
#  '1340': 'YALI1_B11398p',
#  '1341': 'YALI1_B11402p',
#  '1342': 'YALI1_B11415p',
#  '1343': 'YALI1_B11448p',
#  '1344': 'YALI1_B11484p',
#  '1345': 'YALI1_B11495p',
#  '1346': 'YALI1_B11519p',
#  '1347': 'YALI1_B11532p',
#  '1348': 'YALI1_B11577p',
#  '1349': 'YALI1_B11588p',
#  '134': 'YALI1_A03507p',
#  '1350': 'YALI1_B11593p',
#  '1351': 'YALI1_B11607p',
#  '1352': 'YALI1_B11625p',
#  '1353': 'YALI1_B11648p',
#  '1354': 'YALI1_B11681p',
#  '1355': 'YALI1_B11715p',
#  '1356': 'YALI1_B11719p',
#  '1357': 'YALI1_B11729p',
#  '1358': 'YALI1_B11759p',
#  '1359': 'YALI1_B11781p',
#  '135': 'YALI1_A03512p',
#  '1360': 'YALI1_B11794p',
#  '1361': 'YALI1_B11853p',
#  '1362': 'YALI1_B11878p',
#  '1363': 'YALI1_B11916p',
#  '1364': 'YALI1_B11934p',
#  '1365': 'YALI1_B11960p',
#  '1366': 'YALI1_B11978p',
#  '1367': 'YALI1_B11983p',
#  '1368': 'YALI1_B12010p',
#  '1369': 'YALI1_B12042p',
#  '136': 'YALI1_A03549p',
#  '1370': 'YALI1_B12057p',
#  '1371': 'YALI1_B12101p',
#  '1372': 'YALI1_B12150p',
#  '1373': 'YALI1_B12154p',
#  '1374': 'YALI1_B12195p',
#  '1375': 'YALI1_B12204p',
#  '1376': 'YALI1_B12243p',
#  '1377': 'YALI1_B12267p',
#  '1378': 'YALI1_B12295p',
#  '1379': 'YALI1_B12313p',
#  '137': 'YALI1_A03567p',
#  '1380': 'YALI1_B12337p',
#  '1381': 'YALI1_B12375p',
#  '1382': 'YALI1_B12384p',
#  '1383': 'YALI1_B12409p',
#  '1384': 'YALI1_B12427p',
#  '1385': 'YALI1_B12443p',
#  '1386': 'YALI1_B12451p',
#  '1387': 'YALI1_B12489p',
#  '1388': 'YALI1_B12529p',
#  '1389': 'YALI1_B12633p',
#  '138': 'YALI1_A03579p',
#  '1390': 'YALI1_B12677p',
#  '1391': 'YALI1_B12691p',
#  '1392': 'YALI1_B12714p',
#  '1393': 'YALI1_B12742p',
#  '1394': 'YALI1_B12781p',
#  '1395': 'YALI1_B12847p',
#  '1396': 'YALI1_B12874p',
#  '1397': 'YALI1_B12917p',
#  '1398': 'YALI1_B12966p',
#  '1399': 'YALI1_B12970p',
#  '139': 'YALI1_A03599p',
#  '13': 'YALI1_A00375p',
#  '1400': 'YALI1_B12993p',
#  '1401': 'YALI1_B13041p',
#  '1402': 'YALI1_B13069p',
#  '1403': 'YALI1_B13112p',
#  '1404': 'YALI1_B13122p',
#  '1405': 'YALI1_B13137p',
#  '1406': 'YALI1_B13150p',
#  '1407': 'YALI1_B13179p',
#  '1408': 'YALI1_B13259p',
#  '1409': 'YALI1_B13290p',
#  '140': 'YALI1_A03624p',
#  '1410': 'YALI1_B13328p',
#  '1411': 'YALI1_B13355p',
#  '1412': 'YALI1_B13401p',
#  '1413': 'YALI1_B13411p',
#  '1414': 'YALI1_B13439p',
#  '1415': 'YALI1_B13483p',
#  '1416': 'YALI1_B13536p',
#  '1417': 'YALI1_B13556p',
#  '1418': 'YALI1_B13586p',
#  '1419': 'YALI1_B13614p',
#  '141': 'YALI1_A03669p',
#  '1420': 'YALI1_B13641p',
#  '1421': 'YALI1_B13662p',
#  '1422': 'YALI1_B13699p',
#  '1423': 'YALI1_B13723p',
#  '1424': 'YALI1_B13737p',
#  '1425': 'YALI1_B13800p',
#  '1426': 'YALI1_B13828p',
#  '1427': 'YALI1_B13886p',
#  '1428': 'YALI1_B13888p',
#  '1429': 'YALI1_B13915p',
#  '142': 'YALI1_A03688p',
#  '1430': 'YALI1_B13917p',
#  '1431': 'YALI1_B13948p',
#  '1432': 'YALI1_B13973p',
#  '1433': 'YALI1_B14013p',
#  '1434': 'YALI1_B14044p',
#  '1435': 'YALI1_B14064p',
#  '1436': 'YALI1_B14121p',
#  '1437': 'YALI1_B14147p',
#  '1438': 'YALI1_B14150p',
#  '1439': 'YALI1_B14187p',
#  '143': 'YALI1_A03721p',
#  '1440': 'YALI1_B14194p',
#  '1441': 'YALI1_B14236p',
#  '1442': 'YALI1_B14238p',
#  '1443': 'YALI1_B14268p',
#  '1444': 'YALI1_B14292p',
#  '1445': 'YALI1_B14308p',
#  '1446': 'YALI1_B14325p',
#  '1447': 'YALI1_B14355p',
#  '1448': 'YALI1_B14382p',
#  '1449': 'YALI1_B14418p',
#  '144': 'YALI1_A03757p',
#  '1450': 'YALI1_B14441p',
#  '1451': 'YALI1_B14492p',
#  '1452': 'YALI1_B14510p',
#  '1453': 'YALI1_B14517p',
#  '1454': 'YALI1_B14544p',
#  '1455': 'YALI1_B14573p',
#  '1456': 'YALI1_B14600p',
#  '1457': 'YALI1_B14615p',
#  '1458': 'YALI1_B14645p',
#  '1459': 'YALI1_B14658p',
#  '145': 'YALI1_A03763p',
#  '1460': 'YALI1_B14680p',
#  '1461': 'YALI1_B14686p',
#  '1462': 'YALI1_B14733p',
#  '1463': 'YALI1_B14752p',
#  '1464': 'YALI1_B14793p',
#  '1465': 'YALI1_B14804p',
#  '1466': 'YALI1_B14826p',
#  '1467': 'YALI1_B14844p',
#  '1468': 'YALI1_B14882p',
#  '1469': 'YALI1_B14924p',
#  '146': 'YALI1_A03803p',
#  '1470': 'YALI1_B14948p',
#  '1471': 'YALI1_B14959p',
#  '1472': 'YALI1_B14978p',
#  '1473': 'YALI1_B14993p',
#  '1474': 'YALI1_B15015p',
#  '1475': 'YALI1_B15036p',
#  '1476': 'YALI1_B15072p',
#  '1477': 'YALI1_B15092p',
#  '1478': 'YALI1_B15109p',
#  '1479': 'YALI1_B15151p',
#  '147': 'YALI1_A03809p',
#  '1480': 'YALI1_B15180p',
#  '1481': 'YALI1_B15192p',
#  '1482': 'YALI1_B15237p',
#  '1483': 'YALI1_B15275p',
#  '1484': 'YALI1_B15301p',
#  '1485': 'YALI1_B15307p',
#  '1486': 'YALI1_B15310p',
#  '1487': 'YALI1_B15346p',
#  '1488': 'YALI1_B15380p',
#  '1489': 'YALI1_B15420p',
#  '148': 'YALI1_A03815p',
#  '1490': 'YALI1_B15440p',
#  '1491': 'YALI1_B15460p',
#  '1492': 'YALI1_B15475p',
#  '1493': 'YALI1_B15482p',
#  '1494': 'YALI1_B15509p',
#  '1495': 'YALI1_B15521p',
#  '1496': 'YALI1_B15560p',
#  '1497': 'YALI1_B15587p',
#  '1498': 'YALI1_B15592p',
#  '1499': 'YALI1_B15624p',
#  '149': 'YALI1_A03837p',
#  '14': 'YALI1_A00406p',
#  '1500': 'YALI1_B15655p',
#  '1501': 'YALI1_B15670p',
#  '1502': 'YALI1_B15692p',
#  '1503': 'YALI1_B15703p',
#  '1504': 'YALI1_B15706p',
#  '1505': 'YALI1_B15733p',
#  '1506': 'YALI1_B15742p',
#  '1507': 'YALI1_B15792p',
#  '1508': 'YALI1_B15852p',
#  '1509': 'YALI1_B15887p',
#  '150': 'YALI1_A03842p',
#  '1510': 'YALI1_B15905p',
#  '1511': 'YALI1_B15928p',
#  '1512': 'YALI1_B15943p',
#  '1513': 'YALI1_B15964p',
#  '1514': 'YALI1_B15988p',
#  '1515': 'YALI1_B15996p',
#  '1516': 'YALI1_B16022p',
#  '1517': 'YALI1_B16068p',
#  '1518': 'YALI1_B16087p',
#  '1519': 'YALI1_B16110p',
#  '151': 'YALI1_A03857p',
#  '1520': 'YALI1_B16158p',
#  '1521': 'YALI1_B16194p',
#  '1522': 'YALI1_B16239p',
#  '1523': 'YALI1_B16255p',
#  '1524': 'YALI1_B16277p',
#  '1525': 'YALI1_B16309p',
#  '1526': 'YALI1_B16318p',
#  '1527': 'YALI1_B16375p',
#  '1528': 'YALI1_B16410p',
#  '1529': 'YALI1_B16419p',
#  '152': 'YALI1_A03883p',
#  '1530': 'YALI1_B16446p',
#  '1531': 'YALI1_B16477p',
#  '1532': 'YALI1_B16504p',
#  '1533': 'YALI1_B16544p',
#  '1534': 'YALI1_B16566p',
#  '1535': 'YALI1_B16572p',
#  '1536': 'YALI1_B16578p',
#  '1537': 'YALI1_B16584p',
#  '1538': 'YALI1_B16645p',
#  '1539': 'YALI1_B16687p',
#  '153': 'YALI1_A03900p',
#  '1540': 'YALI1_B16705p',
#  '1541': 'YALI1_B16735p',
#  '1542': 'YALI1_B16808p',
#  '1543': 'YALI1_B16863p',
#  '1544': 'YALI1_B16922p',
#  '1545': 'YALI1_B16944p',
#  '1546': 'YALI1_B16968p',
#  '1547': 'YALI1_B16996p',
#  '1548': 'YALI1_B17008p',
#  '1549': 'YALI1_B17039p',
#  '154': 'YALI1_A03907p',
#  '1550': 'YALI1_B17050p',
#  '1551': 'YALI1_B17105p',
#  '1552': 'YALI1_B17112p',
#  '1553': 'YALI1_B17132p',
#  '1554': 'YALI1_B17155p',
#  '1555': 'YALI1_B17214p',
#  '1556': 'YALI1_B17261p',
#  '1557': 'YALI1_B17285p',
#  '1558': 'YALI1_B17292p',
#  '1559': 'YALI1_B17299p',
#  '155': 'YALI1_A03937p',
#  '1560': 'YALI1_B17363p',
#  '1561': 'YALI1_B17406p',
#  '1562': 'YALI1_B17441p',
#  '1563': 'YALI1_B17468p',
#  '1564': 'YALI1_B17493p',
#  '1565': 'YALI1_B17518p',
#  '1566': 'YALI1_B17569p',
#  '1567': 'YALI1_B17592p',
#  '1568': 'YALI1_B17660p',
#  '1569': 'YALI1_B17695p',
#  '156': 'YALI1_A03964p',
#  '1570': 'YALI1_B17724p',
#  '1571': 'YALI1_B17773p',
#  '1572': 'YALI1_B17805p',
#  '1573': 'YALI1_B17838p',
#  '1574': 'YALI1_B17853p',
#  '1575': 'YALI1_B17871p',
#  '1576': 'YALI1_B17908p',
#  '1577': 'YALI1_B17927p',
#  '1578': 'YALI1_B17964p',
#  '1579': 'YALI1_B17968p',
#  '157': 'YALI1_A04006p',
#  '1580': 'YALI1_B17990p',
#  '1581': 'YALI1_B17998p',
#  '1582': 'YALI1_B18012p',
#  '1583': 'YALI1_B18069p',
#  '1584': 'YALI1_B18134p',
#  '1585': 'YALI1_B18190p',
#  '1586': 'YALI1_B18205p',
#  '1587': 'YALI1_B18207p',
#  '1588': 'YALI1_B18236p',
#  '1589': 'YALI1_B18260p',
#  '158': 'YALI1_A04022p',
#  '1590': 'YALI1_B18265p',
#  '1591': 'YALI1_B18292p',
#  '1592': 'YALI1_B18311p',
#  '1593': 'YALI1_B18347p',
#  '1594': 'YALI1_B18368p',
#  '1595': 'YALI1_B18375p',
#  '1596': 'YALI1_B18384p',
#  '1597': 'YALI1_B18391p',
#  '1598': 'YALI1_B18451p',
#  '1599': 'YALI1_B18460p',
#  '159': 'YALI1_A04044p',
#  '15': 'YALI1_A00447p',
#  '1600': 'YALI1_B18472p',
#  '1601': 'YALI1_B18499p',
#  '1602': 'YALI1_B18536p',
#  '1603': 'YALI1_B18572p',
#  '1604': 'YALI1_B18607p',
#  '1605': 'YALI1_B18613p',
#  '1606': 'YALI1_B18631p',
#  '1607': 'YALI1_B18645p',
#  '1608': 'YALI1_B18687p',
#  '1609': 'YALI1_B18707p',
#  '160': 'YALI1_A04071p',
#  '1610': 'YALI1_B18727p',
#  '1611': 'YALI1_B18741p',
#  '1612': 'YALI1_B18764p',
#  '1613': 'YALI1_B18798p',
#  '1614': 'YALI1_B18811p',
#  '1615': 'YALI1_B18845p',
#  '1616': 'YALI1_B18854p',
#  '1617': 'YALI1_B18887p',
#  '1618': 'YALI1_B18902p',
#  '1619': 'YALI1_B18921p',
#  '161': 'YALI1_A04109p',
#  '1620': 'YALI1_B18930p',
#  '1621': 'YALI1_B18955p',
#  '1622': 'YALI1_B18971p',
#  '1623': 'YALI1_B18975p',
#  '1624': 'YALI1_B19021p',
#  '1625': 'YALI1_B19044p',
#  '1626': 'YALI1_B19079p',
#  '1627': 'YALI1_B19107p',
#  '1628': 'YALI1_B19120p',
#  '1629': 'YALI1_B19153p',
#  '162': 'YALI1_A04119p',
#  '1630': 'YALI1_B19205p',
#  '1631': 'YALI1_B19217p',
#  '1632': 'YALI1_B19276p',
#  '1633': 'YALI1_B19290p',
#  '1634': 'YALI1_B19323p',
#  '1635': 'YALI1_B19326p',
#  '1636': 'YALI1_B19336p',
#  '1637': 'YALI1_B19348p',
#  '1638': 'YALI1_B19388p',
#  '1639': 'YALI1_B19390p',
#  '163': 'YALI1_A04164p',
#  '1640': 'YALI1_B19429p',
#  '1641': 'YALI1_B19453p',
#  '1642': 'YALI1_B19485p',
#  '1643': 'YALI1_B19490p',
#  '1644': 'YALI1_B19507p',
#  '1645': 'YALI1_B19520p',
#  '1646': 'YALI1_B19567p',
#  '1647': 'YALI1_B19576p',
#  '1648': 'YALI1_B19602p',
#  '1649': 'YALI1_B19668p',
#  '164': 'YALI1_A04178p',
#  '1650': 'YALI1_B19713p',
#  '1651': 'YALI1_B19747p',
#  '1652': 'YALI1_B19774p',
#  '1653': 'YALI1_B19844p',
#  '1654': 'YALI1_B19856p',
#  '1655': 'YALI1_B19877p',
#  '1656': 'YALI1_B19880p',
#  '1657': 'YALI1_B19897p',
#  '1658': 'YALI1_B19932p',
#  '1659': 'YALI1_B19962p',
#  '165': 'YALI1_A04261p',
#  '1660': 'YALI1_B20009p',
#  '1661': 'YALI1_B20043p',
#  '1662': 'YALI1_B20052p',
#  '1663': 'YALI1_B20094p',
#  '1664': 'YALI1_B20108p',
#  '1665': 'YALI1_B20130p',
#  '1666': 'YALI1_B20145p',
#  '1667': 'YALI1_B20153p',
#  '1668': 'YALI1_B20188p',
#  '1669': 'YALI1_B20192p',
#  '166': 'YALI1_A04309p',
#  '1670': 'YALI1_B20205p',
#  '1671': 'YALI1_B20242p',
#  '1672': 'YALI1_B20243p',
#  '1673': 'YALI1_B20276p',
#  '1674': 'YALI1_B20289p',
#  '1675': 'YALI1_B20319p',
#  '1676': 'YALI1_B20337p',
#  '1677': 'YALI1_B20359p',
#  '1678': 'YALI1_B20378p',
#  '1679': 'YALI1_B20399p',
#  '167': 'YALI1_A04332p',
#  '1680': 'YALI1_B20407p',
#  '1681': 'YALI1_B20416p',
#  '1682': 'YALI1_B20462p',
#  '1683': 'YALI1_B20493p',
#  '1684': 'YALI1_B20521p',
#  '1685': 'YALI1_B20527p',
#  '1686': 'YALI1_B20577p',
#  '1687': 'YALI1_B20589p',
#  '1688': 'YALI1_B20634p',
#  '1689': 'YALI1_B20709p',
#  '168': 'YALI1_A04341p',
#  '1690': 'YALI1_B20717p',
#  '1691': 'YALI1_B20730p',
#  '1692': 'YALI1_B20765p',
#  '1693': 'YALI1_B20777p',
#  '1694': 'YALI1_B20802p',
#  '1695': 'YALI1_B20834p',
#  '1696': 'YALI1_B20835p',
#  '1697': 'YALI1_B20870p',
#  '1698': 'YALI1_B20887p',
#  '1699': 'YALI1_B20919p',
#  '169': 'YALI1_A04385p',
#  '16': 'YALI1_A00468p',
#  '1700': 'YALI1_B20935p',
#  '1701': 'YALI1_B20968p',
#  '1702': 'YALI1_B20992p',
#  '1703': 'YALI1_B21004p',
#  '1704': 'YALI1_B21030p',
#  '1705': 'YALI1_B21042p',
#  '1706': 'YALI1_B21043p',
#  '1707': 'YALI1_B21070p',
#  '1708': 'YALI1_B21088p',
#  '1709': 'YALI1_B21104p',
#  '170': 'YALI1_A04415p',
#  '1710': 'YALI1_B21114p',
#  '1711': 'YALI1_B21134p',
#  '1712': 'YALI1_B21155p',
#  '1713': 'YALI1_B21194p',
#  '1714': 'YALI1_B21208p',
#  '1715': 'YALI1_B21250p',
#  '1716': 'YALI1_B21275p',
#  '1717': 'YALI1_B21313p',
#  '1718': 'YALI1_B21323p',
#  '1719': 'YALI1_B21356p',
#  '171': 'YALI1_A04462p',
#  '1720': 'YALI1_B21381p',
#  '1721': 'YALI1_B21423p',
#  '1722': 'YALI1_B21432p',
#  '1723': 'YALI1_B21466p',
#  '1724': 'YALI1_B21493p',
#  '1725': 'YALI1_B21538p',
#  '1726': 'YALI1_B21562p',
#  '1727': 'YALI1_B21594p',
#  '1728': 'YALI1_B21618p',
#  '1729': 'YALI1_B21628p',
#  '172': 'YALI1_A04495p',
#  '1730': 'YALI1_B21675p',
#  '1731': 'YALI1_B21714p',
#  '1732': 'YALI1_B21737p',
#  '1733': 'YALI1_B21774p',
#  '1734': 'YALI1_B21787p',
#  '1735': 'YALI1_B21798p',
#  '1736': 'YALI1_B21816p',
#  '1737': 'YALI1_B21819p',
#  '1738': 'YALI1_B21855p',
#  '1739': 'YALI1_B21885p',
#  '173': 'YALI1_A04533p',
#  '1740': 'YALI1_B21935p',
#  '1741': 'YALI1_B21946p',
#  '1742': 'YALI1_B21966p',
#  '1743': 'YALI1_B22015p',
#  '1744': 'YALI1_B22020p',
#  '1745': 'YALI1_B22055p',
#  '1746': 'YALI1_B22060p',
#  '1747': 'YALI1_B22088p',
#  '1748': 'YALI1_B22109p',
#  '1749': 'YALI1_B22158p',
#  '174': 'YALI1_A04561p',
#  '1750': 'YALI1_B22259p',
#  '1751': 'YALI1_B22266p',
#  '1752': 'YALI1_B22276p',
#  '1753': 'YALI1_B22321p',
#  '1754': 'YALI1_B22351p',
#  '1755': 'YALI1_B22372p',
#  '1756': 'YALI1_B22375p',
#  '1757': 'YALI1_B22391p',
#  '1758': 'YALI1_B22410p',
#  '1759': 'YALI1_B22414p',
#  '175': 'YALI1_A04576p',
#  '1760': 'YALI1_B22452p',
#  '1761': 'YALI1_B22499p',
#  '1762': 'YALI1_B22512p',
#  '1763': 'YALI1_B22533p',
#  '1764': 'YALI1_B22549p',
#  '1765': 'YALI1_B22561p',
#  '1766': 'YALI1_B22598p',
#  '1767': 'YALI1_B22614p',
#  '1768': 'YALI1_B22638p',
#  '1769': 'YALI1_B22645p',
#  '176': 'YALI1_A04620p',
#  '1770': 'YALI1_B22667p',
#  '1771': 'YALI1_B22677p',
#  '1772': 'YALI1_B22697p',
#  '1773': 'YALI1_B22721p',
#  '1774': 'YALI1_B22747p',
#  '1775': 'YALI1_B22793p',
#  '1776': 'YALI1_B22820p',
#  '1777': 'YALI1_B22853p',
#  '1778': 'YALI1_B22883p',
#  '1779': 'YALI1_B22905p',
#  '177': 'YALI1_A04653p',
#  '1780': 'YALI1_B22908p',
#  '1781': 'YALI1_B22938p',
#  '1782': 'YALI1_B23017p',
#  '1783': 'YALI1_B23055p',
#  '1784': 'YALI1_B23061p',
#  '1785': 'YALI1_B23077p',
#  '1786': 'YALI1_B23153p',
#  '1787': 'YALI1_B23176p',
#  '1788': 'YALI1_B23201p',
#  '1789': 'YALI1_B23237p',
#  '178': 'YALI1_A04661p',
#  '1790': 'YALI1_B23300p',
#  '1791': 'YALI1_B23338p',
#  '1792': 'YALI1_B23351p',
#  '1793': 'YALI1_B23373p',
#  '1794': 'YALI1_B23385p',
#  '1795': 'YALI1_B23420p',
#  '1796': 'YALI1_B23440p',
#  '1797': 'YALI1_B23443p',
#  '1798': 'YALI1_B23447p',
#  '1799': 'YALI1_B23467p',
#  '179': 'YALI1_A04676p',
#  '17': 'YALI1_A00504p',
#  '1800': 'YALI1_B23515p',
#  '1801': 'YALI1_B23522p',
#  '1802': 'YALI1_B23554p',
#  '1803': 'YALI1_B23579p',
#  '1804': 'YALI1_B23603p',
#  '1805': 'YALI1_B23609p',
#  '1806': 'YALI1_B23622p',
#  '1807': 'YALI1_B23677p',
#  '1808': 'YALI1_B23708p',
#  '1809': 'YALI1_B23729p',
#  '180': 'YALI1_A04715p',
#  '1810': 'YALI1_B23744p',
#  '1811': 'YALI1_B23771p',
#  '1812': 'YALI1_B23794p',
#  '1813': 'YALI1_B23798p',
#  '1814': 'YALI1_B23834p',
#  '1815': 'YALI1_B23866p',
#  '1816': 'YALI1_B23879p',
#  '1817': 'YALI1_B23933p',
#  '1818': 'YALI1_B23939p',
#  '1819': 'YALI1_B23966p',
#  '181': 'YALI1_A04742p',
#  '1820': 'YALI1_B23981p',
#  '1821': 'YALI1_B24018p',
#  '1822': 'YALI1_B24043p',
#  '1823': 'YALI1_B24051p',
#  '1824': 'YALI1_B24129p',
#  '1825': 'YALI1_B24185p',
#  '1826': 'YALI1_B24214p',
#  '1827': 'YALI1_B24218p',
#  '1828': 'YALI1_B24252p',
#  '1829': 'YALI1_B24264p',
#  '182': 'YALI1_A04781p',
#  '1830': 'YALI1_B24280p',
#  '1831': 'YALI1_B24292p',
#  '1832': 'YALI1_B24335p',
#  '1833': 'YALI1_B24351p',
#  '1834': 'YALI1_B24424p',
#  '1835': 'YALI1_B24446p',
#  '1836': 'YALI1_B24471p',
#  '1837': 'YALI1_B24502p',
#  '1838': 'YALI1_B24564p',
#  '1839': 'YALI1_B24606p',
#  '183': 'YALI1_A04795p',
#  '1840': 'YALI1_B24638p',
#  '1841': 'YALI1_B24654p',
#  '1842': 'YALI1_B24672p',
#  '1843': 'YALI1_B24714p',
#  '1844': 'YALI1_B24758p',
#  '1845': 'YALI1_B24836p',
#  '1846': 'YALI1_B24901p',
#  '1847': 'YALI1_B24936p',
#  '1848': 'YALI1_B24970p',
#  '1849': 'YALI1_B24997p',
#  '184': 'YALI1_A04815p',
#  '1850': 'YALI1_B25004p',
#  '1851': 'YALI1_B25017p',
#  '1852': 'YALI1_B25062p',
#  '1853': 'YALI1_B25077p',
#  '1854': 'YALI1_B25087p',
#  '1855': 'YALI1_B25107p',
#  '1856': 'YALI1_B25136p',
#  '1857': 'YALI1_B25187p',
#  '1858': 'YALI1_B25223p',
#  '1859': 'YALI1_B25258p',
#  '185': 'YALI1_A04817p',
#  '1860': 'YALI1_B25313p',
#  '1861': 'YALI1_B25319p',
#  '1862': 'YALI1_B25322p',
#  '1863': 'YALI1_B25334p',
#  '1864': 'YALI1_B25360p',
#  '1865': 'YALI1_B25387p',
#  '1866': 'YALI1_B25395p',
#  '1867': 'YALI1_B25427p',
#  '1868': 'YALI1_B25484p',
#  '1869': 'YALI1_B25495p',
#  '186': 'YALI1_A04848p',
#  '1870': 'YALI1_B25506p',
#  '1871': 'YALI1_B25553p',
#  '1872': 'YALI1_B25593p',
#  '1873': 'YALI1_B25603p',
#  '1874': 'YALI1_B25676p',
#  '1875': 'YALI1_B25734p',
#  '1876': 'YALI1_B25744p',
#  '1877': 'YALI1_B25762p',
#  '1878': 'YALI1_B25795p',
#  '1879': 'YALI1_B25798p',
#  '187': 'YALI1_A04859p',
#  '1880': 'YALI1_B25833p',
#  '1881': 'YALI1_B25868p',
#  '1882': 'YALI1_B25906p',
#  '1883': 'YALI1_B25952p',
#  '1884': 'YALI1_B25963p',
#  '1885': 'YALI1_B25988p',
#  '1886': 'YALI1_B25997p',
#  '1887': 'YALI1_B26033p',
#  '1888': 'YALI1_B26112p',
#  '1889': 'YALI1_B26153p',
#  '188': 'YALI1_A04864p',
#  '1890': 'YALI1_B26175p',
#  '1891': 'YALI1_B26205p',
#  '1892': 'YALI1_B26235p',
#  '1893': 'YALI1_B26271p',
#  '1894': 'YALI1_B26322p',
#  '1895': 'YALI1_B26350p',
#  '1896': 'YALI1_B26377p',
#  '1897': 'YALI1_B26430p',
#  '1898': 'YALI1_B26451p',
#  '1899': 'YALI1_B26517p',
#  '189': 'YALI1_A04884p',
#  '18': 'YALI1_A00538p',
#  '1900': 'YALI1_B26550p',
#  ...}

# %%
combined_df['YALI1_protID'] = combined_df['proteinID'].map(gene_dict)
combined_df['YALI1_mod'] = combined_df['YALI1_protID'].str.replace('p', 'g', regex=False)

# %%
combined_df.head()
# Out:
#                    Protein proteinID #proteinId  \
# 0  jgi|YarliW29_1|1000@GLB      1000       1000
# 1  jgi|YarliW29_1|1002@GLB      1002       1002
# 2  jgi|YarliW29_1|1003@GLB      1003       1003
# 3  jgi|YarliW29_1|1004@GLB      1004       1004
# 4  jgi|YarliW29_1|1008@GLB      1008       1008
#
#                            definition  \
# 0                                 nan
# 1  ['3-isopropylmalate dehydratase.']
# 2          ['Metalloendopeptidases.']
# 3             ['Carboxypeptidase C.']
# 4                                 nan
#
#                                    catalyticActivity  \
# 0                                                nan
# 1  ['3-isopropylmalate = 2-isopropylmaleate + H(2...
# 2                                            ['\\N']
# 3  ['Release of a C-terminal amino acid with a br...
# 4                                                nan
#
#                                            pathway              pathway_class  \
# 0                                              nan                        nan
# 1  ['Valine, leucine and isoleucine biosynthesis']  ['Amino Acid Metabolism']
# 2                                          ['\\N']                    ['\\N']
# 3                                          ['\\N']                    ['\\N']
# 4                                              nan                        nan
#
#     pathway_type         ecNum cofactors  ... log2FC_control_vs_low_late  \
# 0            nan           nan       nan  ...                   0.208652
# 1  ['METABOLIC']  ['4.2.1.33']   ['\\N']  ...                   0.719654
# 2        ['\\N']  ['3.4.24.-']   ['\\N']  ...                  -0.235634
# 3        ['\\N']  ['3.4.16.5']   ['\\N']  ...                  -1.981909
# 4            nan           nan       nan  ...                  -0.084333
#
#   ANOVA_p_oscillation_late_combined ANOVA_padj_oscillation_late_combined  \
# 0                          0.005320                             0.013087
# 1                          0.890050                             0.918603
# 2                          0.000270                             0.000993
# 3                          0.149280                             0.227195
# 4                          0.000616                             0.002037
#
#   log2FC_oscillation_late_combined  proteinId  osc/low_late_cominbed  \
# 0                        -0.245573       1000              -0.454225
# 1                         0.018832       1002              -0.700821
# 2                        -0.372936       1003              -0.137301
# 3                        -0.461486       1004               1.520422
# 4                         0.477230       1008               0.561563
#
#    osc/low_late_cominbedANOVA_padj  osc/low_late_cominbedANOVA_p  \
# 0                         0.000139                      0.000036
# 1                         0.005904                      0.002754
# 2                         0.247398                      0.195181
# 3                         0.001708                      0.000666
# 4                         0.010054                      0.005037
#
#     YALI1_protID      YALI1_mod
# 0  YALI1_B02228p  YALI1_B02228g
# 1  YALI1_B02345p  YALI1_B02345g
# 2  YALI1_B02375p  YALI1_B02375g
# 3  YALI1_B02415p  YALI1_B02415g
# 4  YALI1_B02487p  YALI1_B02487g
#
# [5 rows x 29 columns]

# %%
# File path to your GFF file
gff_file = "../Data/DNA/genomic_yali1_yali2.gff"

# Initialize mapping dictionary
yali1_to_yali2 = {}

# Regex patterns for locus_tag and old_locus_tag
locus_re = re.compile(r'locus_tag=(YALI1_[A-Z0-9]+g)')
old_locus_re = re.compile(r'old_locus_tag=(YALI2_[A-Z0-9]+g)')

# Parse the GFF
with open(gff_file, 'r') as file:
    for line in file:
        if line.startswith("#"):
            continue
        if "\tgene\t" not in line:
            continue

        locus_match = locus_re.search(line)
        old_locus_match = old_locus_re.search(line)

        if locus_match and old_locus_match:
            yali1 = locus_match.group(1)
            yali2 = old_locus_match.group(1)
            yali1_to_yali2[yali1] = yali2

# Convert to DataFrame for inspection or export
df_map = pd.DataFrame(list(yali1_to_yali2.items()), columns=["YALI1", "YALI2"])

# Optionally save to CSV
df_map.to_csv("yali1_to_yali2_mapping.csv", index=False)

# %%
df_map['YALI1'] = df_map['YALI1'].str.replace('g', 'p', regex=False)
locus_dict_2 = dict(zip(df_map["YALI1"], df_map["YALI2"]))

# %%
df_map
# Out:
#               YALI1          YALI2
# 0     YALI1_A00058p  YALI2_A00002g
# 1     YALI1_A00102p  YALI2_A00003g
# 2     YALI1_A00148p  YALI2_A00004g
# 3     YALI1_A00204p  YALI2_A00005g
# 4     YALI1_A00241p  YALI2_A00692g
# ...             ...            ...
# 6210  YALI1_F39665p  YALI2_E00867g
# 6211  YALI1_F39789p  YALI2_E00868g
# 6212  YALI1_F39844p  YALI2_E00869g
# 6213  YALI1_F39885p  YALI2_E00871g
# 6214  YALI1_F39891p  YALI2_E00870g
#
# [6215 rows x 2 columns]

# %%
combined_df['YALI2'] = combined_df['YALI1_protID'].map(df_map.set_index('YALI1')['YALI2'])

# %%
combined_df.head()
# Out:
#                    Protein proteinID #proteinId  \
# 0  jgi|YarliW29_1|1000@GLB      1000       1000
# 1  jgi|YarliW29_1|1002@GLB      1002       1002
# 2  jgi|YarliW29_1|1003@GLB      1003       1003
# 3  jgi|YarliW29_1|1004@GLB      1004       1004
# 4  jgi|YarliW29_1|1008@GLB      1008       1008
#
#                            definition  \
# 0                                 nan
# 1  ['3-isopropylmalate dehydratase.']
# 2          ['Metalloendopeptidases.']
# 3             ['Carboxypeptidase C.']
# 4                                 nan
#
#                                    catalyticActivity  \
# 0                                                nan
# 1  ['3-isopropylmalate = 2-isopropylmaleate + H(2...
# 2                                            ['\\N']
# 3  ['Release of a C-terminal amino acid with a br...
# 4                                                nan
#
#                                            pathway              pathway_class  \
# 0                                              nan                        nan
# 1  ['Valine, leucine and isoleucine biosynthesis']  ['Amino Acid Metabolism']
# 2                                          ['\\N']                    ['\\N']
# 3                                          ['\\N']                    ['\\N']
# 4                                              nan                        nan
#
#     pathway_type         ecNum cofactors  ...  \
# 0            nan           nan       nan  ...
# 1  ['METABOLIC']  ['4.2.1.33']   ['\\N']  ...
# 2        ['\\N']  ['3.4.24.-']   ['\\N']  ...
# 3        ['\\N']  ['3.4.16.5']   ['\\N']  ...
# 4            nan           nan       nan  ...
#
#   ANOVA_p_oscillation_late_combined ANOVA_padj_oscillation_late_combined  \
# 0                          0.005320                             0.013087
# 1                          0.890050                             0.918603
# 2                          0.000270                             0.000993
# 3                          0.149280                             0.227195
# 4                          0.000616                             0.002037
#
#   log2FC_oscillation_late_combined proteinId  osc/low_late_cominbed  \
# 0                        -0.245573      1000              -0.454225
# 1                         0.018832      1002              -0.700821
# 2                        -0.372936      1003              -0.137301
# 3                        -0.461486      1004               1.520422
# 4                         0.477230      1008               0.561563
#
#    osc/low_late_cominbedANOVA_padj  osc/low_late_cominbedANOVA_p  \
# 0                         0.000139                      0.000036
# 1                         0.005904                      0.002754
# 2                         0.247398                      0.195181
# 3                         0.001708                      0.000666
# 4                         0.010054                      0.005037
#
#     YALI1_protID      YALI1_mod          YALI2
# 0  YALI1_B02228p  YALI1_B02228g  YALI2_B00021g
# 1  YALI1_B02345p  YALI1_B02345g  YALI2_B00628g
# 2  YALI1_B02375p  YALI1_B02375g  YALI2_B00022g
# 3  YALI1_B02415p  YALI1_B02415g  YALI2_B00627g
# 4  YALI1_B02487p  YALI1_B02487g  YALI2_B00625g
#
# [5 rows x 30 columns]

# %%
# JGI_protID_toYali1 = pd.DataFrame(list(gene_dict.items()), columns=['JGI_protID', 'YALI1_protID'])
# # JGI_protID_toYali1.to_csv('JGI_Yali1_protMap.csv')
# JGI_protID_toYali1.head()

# %%
df = pd.read_excel('../Annotations/yali_genes.xlsx')
df.head()
# df = pd.read_excel('../Data/locus_tag_map.xlsx')
# df.head()
# Out:
#   YALI0 locus ID YALI1 Locus ID YALI1 Proteins Gene Type Chromosome  \
# 0            NaN  YALI1_A00014g  YALI1_A00014p      mRNA     YALI1A
# 1            NaN  YALI1_A00019g  YALI1_A00019p      mRNA     YALI1A
# 2            NaN  YALI1_A00032g  YALI1_A00032p      mRNA     YALI1A
# 3   YALI0A00110g  YALI1_A00058g  YALI1_A00058p      mRNA     YALI1A
# 4   YALI0A00132g  YALI1_A00102g  YALI1_A00102p      mRNA     YALI1A
#
#    Start Base  End Base Strand  \
# 0        1230      1648      -
# 1        1806      2173      -
# 2        3285      3920      +
# 3        5913      8531      +
# 4       10299     12134      +
#
#                                           Annotation
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3    weakly similar to uniprot|Q06593 Saccharomyc...
# 4    highly similar to uniprot|P40150 Saccharomyc...

# %%
filtered_df = df.dropna(subset=["YALI0 locus ID"])

locus_dict = dict(zip(filtered_df["YALI1 Proteins"], filtered_df["YALI0 locus ID"]))

# %%
combined_df['YALI0_locus'] = combined_df['YALI1_protID'].map(locus_dict)

# %%
combined_df.head()
# Out:
#                    Protein proteinID #proteinId  \
# 0  jgi|YarliW29_1|1000@GLB      1000       1000
# 1  jgi|YarliW29_1|1002@GLB      1002       1002
# 2  jgi|YarliW29_1|1003@GLB      1003       1003
# 3  jgi|YarliW29_1|1004@GLB      1004       1004
# 4  jgi|YarliW29_1|1008@GLB      1008       1008
#
#                            definition  \
# 0                                 nan
# 1  ['3-isopropylmalate dehydratase.']
# 2          ['Metalloendopeptidases.']
# 3             ['Carboxypeptidase C.']
# 4                                 nan
#
#                                    catalyticActivity  \
# 0                                                nan
# 1  ['3-isopropylmalate = 2-isopropylmaleate + H(2...
# 2                                            ['\\N']
# 3  ['Release of a C-terminal amino acid with a br...
# 4                                                nan
#
#                                            pathway              pathway_class  \
# 0                                              nan                        nan
# 1  ['Valine, leucine and isoleucine biosynthesis']  ['Amino Acid Metabolism']
# 2                                          ['\\N']                    ['\\N']
# 3                                          ['\\N']                    ['\\N']
# 4                                              nan                        nan
#
#     pathway_type         ecNum cofactors  ...  \
# 0            nan           nan       nan  ...
# 1  ['METABOLIC']  ['4.2.1.33']   ['\\N']  ...
# 2        ['\\N']  ['3.4.24.-']   ['\\N']  ...
# 3        ['\\N']  ['3.4.16.5']   ['\\N']  ...
# 4            nan           nan       nan  ...
#
#   ANOVA_padj_oscillation_late_combined log2FC_oscillation_late_combined  \
# 0                             0.013087                        -0.245573
# 1                             0.918603                         0.018832
# 2                             0.000993                        -0.372936
# 3                             0.227195                        -0.461486
# 4                             0.002037                         0.477230
#
#   proteinId osc/low_late_cominbed  osc/low_late_cominbedANOVA_padj  \
# 0      1000             -0.454225                         0.000139
# 1      1002             -0.700821                         0.005904
# 2      1003             -0.137301                         0.247398
# 3      1004              1.520422                         0.001708
# 4      1008              0.561563                         0.010054
#
#    osc/low_late_cominbedANOVA_p   YALI1_protID      YALI1_mod          YALI2  \
# 0                      0.000036  YALI1_B02228p  YALI1_B02228g  YALI2_B00021g
# 1                      0.002754  YALI1_B02345p  YALI1_B02345g  YALI2_B00628g
# 2                      0.195181  YALI1_B02375p  YALI1_B02375g  YALI2_B00022g
# 3                      0.000666  YALI1_B02415p  YALI1_B02415g  YALI2_B00627g
# 4                      0.005037  YALI1_B02487p  YALI1_B02487g  YALI2_B00625g
#
#     YALI0_locus
# 0  YALI0B01320g
# 1  YALI0B01364g
# 2  YALI0B01386g
# 3  YALI0B01408g
# 4  YALI0B01540g
#
# [5 rows x 31 columns]

# %% [markdown]
# # Final Proteomic File for processed.

# %%
# combined_df.save_to_csv('processedProteomic.csv')

# %%
# combined_df['YALI1_protID'] = combined_df['proteinId'].map(JGI_protID_toYali1.set_index('JGI_protID')['YALI1_protID'])
# combined_df['YALI0_locus'] = combined_df['YALI1_protID'].map(Yali1_Yali0.set_index('YALI1_Proteins')['YALI0_locus_ID'])
# combined_df['YALI1_protID_converted'] = combined_df['YALI1_protID'].str.replace('g', 'p', regex=False)
# combined_df['YALI2'] = combined_df['YALI1_protID_converted'].map(Yali1_Yali2.set_index('YALI1')['YALI2'])

# %%
PROT_PATH = '../Data/ProcessedData/Proteomics/PPI_yarrowia_protein_abundance_wAnnotations_fullLog2FC_withOsc.csv'
combined_df.to_csv(PROT_PATH)

# %%
# merged_df.to_csv('../Data/ProcessedData/Proteomics/PPI_yarrowia_protein_abundance_wAnnotations_wOscLow_fullLog2FC.csv')

# %% [markdown]
# # Read metabolomic data

# %%
# metabolomicSampleDataFrame = pd.read_csv('Sample_dict_metabolomics_new.csv')
# metabolomicSampleDataFrame.head()

metabolomics = pd.read_excel('../Data/Metabolomics/YLIP_Metabolomics_ALL_Modes_Pmart_normalized.xlsx',sheet_name = 'Sheet1',index_col=0)

# %%
metabolomics
# Out:
#                                               PPI_Ylip_Ctrl_5hr_35  \
# Metabolite name
# [6]-Gingerol_RP                                          25.304971
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP             20.994103
# 1-Monostearin_RP                                         27.830119
# 1,3-diphenylguanidine_RP                                 18.949790
# 10-HYDROXYDECANOATE_RP                                   23.743140
# ...                                                            ...
# Val-Ser_HN                                               23.699522
# Val-Thr_HN                                               20.870056
# Xanthene-9-carboxylic acid_HN                            28.706756
# Xylulose 5-phosphate_HN                                  25.600585
# 727                                                            NaN
#
#                                               PPI_Ylip_Low_48hr_53  \
# Metabolite name
# [6]-Gingerol_RP                                          25.922555
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP             24.758278
# 1-Monostearin_RP                                         21.642454
# 1,3-diphenylguanidine_RP                                 19.819692
# 10-HYDROXYDECANOATE_RP                                   24.410737
# ...                                                            ...
# Val-Ser_HN                                               17.164227
# Val-Thr_HN                                               19.888300
# Xanthene-9-carboxylic acid_HN                            28.933773
# Xylulose 5-phosphate_HN                                  23.601655
# 727                                                            NaN
#
#                                               PPI_Ylip_Ctrl_5hr_11  \
# Metabolite name
# [6]-Gingerol_RP                                          25.548379
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP             20.993220
# 1-Monostearin_RP                                         21.854335
# 1,3-diphenylguanidine_RP                                 17.945497
# 10-HYDROXYDECANOATE_RP                                   24.345803
# ...                                                            ...
# Val-Ser_HN                                               22.440311
# Val-Thr_HN                                               24.233694
# Xanthene-9-carboxylic acid_HN                            30.406484
# Xylulose 5-phosphate_HN                                  24.091104
# 727                                                            NaN
#
#                                               PPI_Ylip_Ctrl_24hr_37  \
# Metabolite name
# [6]-Gingerol_RP                                           25.298681
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP              20.874734
# 1-Monostearin_RP                                          21.388737
# 1,3-diphenylguanidine_RP                                  18.782512
# 10-HYDROXYDECANOATE_RP                                    24.103620
# ...                                                             ...
# Val-Ser_HN                                                17.950897
# Val-Thr_HN                                                20.282887
# Xanthene-9-carboxylic acid_HN                             26.996939
# Xylulose 5-phosphate_HN                                   24.207352
# 727                                                             NaN
#
#                                               PPI_Ylip_Low_48hr_47  \
# Metabolite name
# [6]-Gingerol_RP                                          25.780203
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP             22.332716
# 1-Monostearin_RP                                         26.363149
# 1,3-diphenylguanidine_RP                                 20.989119
# 10-HYDROXYDECANOATE_RP                                   24.545223
# ...                                                            ...
# Val-Ser_HN                                               21.900764
# Val-Thr_HN                                               20.327822
# Xanthene-9-carboxylic acid_HN                            28.309987
# Xylulose 5-phosphate_HN                                  23.534770
# 727                                                            NaN
#
#                                               PPI_Ylip_Osc_72hr_06  \
# Metabolite name
# [6]-Gingerol_RP                                          23.771397
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP             24.636485
# 1-Monostearin_RP                                         29.145346
# 1,3-diphenylguanidine_RP                                 17.775612
# 10-HYDROXYDECANOATE_RP                                   25.108104
# ...                                                            ...
# Val-Ser_HN                                               19.067961
# Val-Thr_HN                                               17.654231
# Xanthene-9-carboxylic acid_HN                            27.651587
# Xylulose 5-phosphate_HN                                  23.980231
# 727                                                            NaN
#
#                                               PPI_Ylip_Low_72hr_54  \
# Metabolite name
# [6]-Gingerol_RP                                          24.708991
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP             25.891304
# 1-Monostearin_RP                                         23.008059
# 1,3-diphenylguanidine_RP                                 20.088038
# 10-HYDROXYDECANOATE_RP                                   24.367260
# ...                                                            ...
# Val-Ser_HN                                               16.784952
# Val-Thr_HN                                               19.274370
# Xanthene-9-carboxylic acid_HN                            28.917360
# Xylulose 5-phosphate_HN                                  24.095530
# 727                                                            NaN
#
#                                               PPI_Ylip_Low_4hr_34  \
# Metabolite name
# [6]-Gingerol_RP                                         25.304508
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP            21.144469
# 1-Monostearin_RP                                        22.373570
# 1,3-diphenylguanidine_RP                                18.900946
# 10-HYDROXYDECANOATE_RP                                  24.045975
# ...                                                           ...
# Val-Ser_HN                                              22.126459
# Val-Thr_HN                                              23.815441
# Xanthene-9-carboxylic acid_HN                           27.924654
# Xylulose 5-phosphate_HN                                 24.050918
# 727                                                           NaN
#
#                                               PPI_Ylip_Osc_47hr_05  \
# Metabolite name
# [6]-Gingerol_RP                                          25.934016
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP             22.058745
# 1-Monostearin_RP                                         26.187290
# 1,3-diphenylguanidine_RP                                 19.689460
# 10-HYDROXYDECANOATE_RP                                   24.931919
# ...                                                            ...
# Val-Ser_HN                                               17.826344
# Val-Thr_HN                                               14.968629
# Xanthene-9-carboxylic acid_HN                            27.209401
# Xylulose 5-phosphate_HN                                  23.953152
# 727                                                            NaN
#
#                                               PPI_Ylip_Ctrl_4hr_09  ...  \
# Metabolite name                                                     ...
# [6]-Gingerol_RP                                          25.351484  ...
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP             20.675858  ...
# 1-Monostearin_RP                                         27.715287  ...
# 1,3-diphenylguanidine_RP                                 22.292712  ...
# 10-HYDROXYDECANOATE_RP                                   24.123930  ...
# ...                                                            ...  ...
# Val-Ser_HN                                               20.750031  ...
# Val-Thr_HN                                               22.254960  ...
# Xanthene-9-carboxylic acid_HN                            29.131341  ...
# Xylulose 5-phosphate_HN                                  25.286876  ...
# 727                                                            NaN  ...
#
#                                               PPI_Ylip_Low_3hr_49  \
# Metabolite name
# [6]-Gingerol_RP                                         25.604529
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP            21.374189
# 1-Monostearin_RP                                        27.130488
# 1,3-diphenylguanidine_RP                                18.695562
# 10-HYDROXYDECANOATE_RP                                  24.438505
# ...                                                           ...
# Val-Ser_HN                                              20.530180
# Val-Thr_HN                                              22.247302
# Xanthene-9-carboxylic acid_HN                           28.841869
# Xylulose 5-phosphate_HN                                 25.139396
# 727                                                           NaN
#
#                                               PPI_Ylip_Osc_48hr_28  \
# Metabolite name
# [6]-Gingerol_RP                                          25.859027
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP             22.293956
# 1-Monostearin_RP                                         25.472312
# 1,3-diphenylguanidine_RP                                 21.381499
# 10-HYDROXYDECANOATE_RP                                   24.529272
# ...                                                            ...
# Val-Ser_HN                                               18.724222
# Val-Thr_HN                                               18.020312
# Xanthene-9-carboxylic acid_HN                            26.725164
# Xylulose 5-phosphate_HN                                  24.153276
# 727                                                            NaN
#
#                                               PPI_Ylip_Ctrl_24hr_25  \
# Metabolite name
# [6]-Gingerol_RP                                           25.125309
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP              23.950306
# 1-Monostearin_RP                                          20.366222
# 1,3-diphenylguanidine_RP                                  18.484466
# 10-HYDROXYDECANOATE_RP                                    23.915051
# ...                                                             ...
# Val-Ser_HN                                                17.202340
# Val-Thr_HN                                                19.596079
# Xanthene-9-carboxylic acid_HN                             27.716856
# Xylulose 5-phosphate_HN                                   24.803869
# 727                                                             NaN
#
#                                               PPI_Ylip_Osc_24hr_04  \
# Metabolite name
# [6]-Gingerol_RP                                          25.514227
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP             24.495085
# 1-Monostearin_RP                                         25.268657
# 1,3-diphenylguanidine_RP                                 18.746473
# 10-HYDROXYDECANOATE_RP                                   24.350315
# ...                                                            ...
# Val-Ser_HN                                               18.193692
# Val-Thr_HN                                               20.660582
# Xanthene-9-carboxylic acid_HN                            26.523433
# Xylulose 5-phosphate_HN                                  23.689514
# 727                                                            NaN
#
#                                               PPI_Ylip_Ctrl_3hr_19  \
# Metabolite name
# [6]-Gingerol_RP                                          25.261703
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP             21.737653
# 1-Monostearin_RP                                         27.821596
# 1,3-diphenylguanidine_RP                                 18.369038
# 10-HYDROXYDECANOATE_RP                                   24.608141
# ...                                                            ...
# Val-Ser_HN                                               20.590856
# Val-Thr_HN                                               21.800640
# Xanthene-9-carboxylic acid_HN                            29.722747
# Xylulose 5-phosphate_HN                                  24.885772
# 727                                                            NaN
#
#                                               PPI_Ylip_Ctrl_5hr_23  \
# Metabolite name
# [6]-Gingerol_RP                                          25.421335
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP             20.314038
# 1-Monostearin_RP                                         27.801279
# 1,3-diphenylguanidine_RP                                 18.596721
# 10-HYDROXYDECANOATE_RP                                   24.176449
# ...                                                            ...
# Val-Ser_HN                                               20.791481
# Val-Thr_HN                                               23.518958
# Xanthene-9-carboxylic acid_HN                            28.171946
# Xylulose 5-phosphate_HN                                  23.695752
# 727                                                            NaN
#
#                                               PPI_Ylip_Ctrl_72hr_41  \
# Metabolite name
# [6]-Gingerol_RP                                           26.255295
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP              25.083603
# 1-Monostearin_RP                                          21.219226
# 1,3-diphenylguanidine_RP                                  23.473059
# 10-HYDROXYDECANOATE_RP                                    25.230456
# ...                                                             ...
# Val-Ser_HN                                                      NaN
# Val-Thr_HN                                                      NaN
# Xanthene-9-carboxylic acid_HN                             26.263254
# Xylulose 5-phosphate_HN                                   25.143759
# 727                                                             NaN
#
#                                               PPI_Ylip_Ctrl_3hr_31  \
# Metabolite name
# [6]-Gingerol_RP                                          23.357804
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP             26.935488
# 1-Monostearin_RP                                         20.798368
# 1,3-diphenylguanidine_RP                                 21.450317
# 10-HYDROXYDECANOATE_RP                                   23.840167
# ...                                                            ...
# Val-Ser_HN                                               24.377369
# Val-Thr_HN                                               23.357366
# Xanthene-9-carboxylic acid_HN                            27.435653
# Xylulose 5-phosphate_HN                                  24.671759
# 727                                                            NaN
#
#                                               PPI_Ylip_Osc_5hr_03  \
# Metabolite name
# [6]-Gingerol_RP                                         25.796217
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP            19.514575
# 1-Monostearin_RP                                        28.655229
# 1,3-diphenylguanidine_RP                                19.730435
# 10-HYDROXYDECANOATE_RP                                  24.011480
# ...                                                           ...
# Val-Ser_HN                                              22.936662
# Val-Thr_HN                                              24.128312
# Xanthene-9-carboxylic acid_HN                           28.150736
# Xylulose 5-phosphate_HN                                 24.476009
# 727                                                           NaN
#
#                                               PPI_Ylip_Low_4hr_44
# Metabolite name
# [6]-Gingerol_RP                                         25.200045
# 1-(2-hydroxy-4,6-dimethoxyphenyl)ethanone_RP            20.827261
# 1-Monostearin_RP                                        27.910641
# 1,3-diphenylguanidine_RP                                19.283907
# 10-HYDROXYDECANOATE_RP                                  23.716725
# ...                                                           ...
# Val-Ser_HN                                              21.354876
# Val-Thr_HN                                              23.735469
# Xanthene-9-carboxylic acid_HN                           29.431913
# Xylulose 5-phosphate_HN                                 23.887624
# 727                                                           NaN
#
# [728 rows x 54 columns]

# %%
met_timepoint_dict = dict(zip(metabolomics.columns, sample_ids_metabolomics))

# %%
met = metabolomics.dropna(axis=0)
features = met.T
pca_df, explained_variance = pca_preprocess(features)
features['Condition'] = features.index.map(met_condition_dict)


pca_df['Condition'] = features['Condition'].values
pca_df['Timepoint'] = features.index.map(met_timepoint_dict)


pca_df['Batch']=0
# pca_df[pca_df.index<15]['Batch']=1
# pca_df['Reactor'] = df['Reactor'].values
pca_df.loc[pca_df.index <= 17, 'Batch'] = 1
pca_df.loc[pca_df.index > 17, 'Batch'] = 2
plot_pca(pca_df, explained_variance,title='pca_met_condition.png')

# %% [markdown]
# #### PCA functions.

# %% [markdown]
# # Lipidomic data.

# %%
lipidomics = pd.read_excel('../Data/Lipidomics/Processed Expression Data (e_data).xlsx',sheet_name = 'in',index_col=0)

# %%
lipid = lipidomics.dropna(axis=0)
features = lipid.T
pca_df, explained_variance = pca_preprocess(features)
features['Condition'] = features.index.map(lipid_condition_dict)


pca_df['Condition'] = features['Condition'].values
pca_df['Timepoint'] = features.index.map(lipid_timepoint_dict)


pca_df['Batch']=0
# pca_df[pca_df.index<15]['Batch']=1
# pca_df['Reactor'] = df['Reactor'].values
pca_df.loc[pca_df.index <= 17, 'Batch'] = 1
pca_df.loc[pca_df.index > 17, 'Batch'] = 2
plot_pca(pca_df, explained_variance,title='pca_lipid_condition.png')

# %%
lipidomics
# Out:
#                                                     PPI_Ylip_Ctrl_24hr_13  \
# Metabolite name
# 13-Docosenamide_Pos                                             24.158923
# Benzyl butyl phthalate (also known as chemical ...              16.339640
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                                17.143894
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                              18.077867
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                            20.374232
# ...                                                                   ...
# PS 34:2|PS 16:1_18:1_Neg                                        26.151497
# PS 34:3|PS 16:1_18:2_Neg                                        21.922784
# PS 36:3|PS 18:1_18:2_Neg                                        22.611695
# SM 36:1;2O_Neg                                                  13.376558
# ST 27:1;O;S_Neg                                                 23.790849
#
#                                                     PPI_Ylip_Ctrl_24hr_25  \
# Metabolite name
# 13-Docosenamide_Pos                                             24.070855
# Benzyl butyl phthalate (also known as chemical ...                    NaN
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                                16.338256
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                              18.307384
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                            20.018788
# ...                                                                   ...
# PS 34:2|PS 16:1_18:1_Neg                                        26.204853
# PS 34:3|PS 16:1_18:2_Neg                                        21.622256
# PS 36:3|PS 18:1_18:2_Neg                                        22.778382
# SM 36:1;2O_Neg                                                        NaN
# ST 27:1;O;S_Neg                                                 23.988537
#
#                                                     PPI_Ylip_Ctrl_24hr_37  \
# Metabolite name
# 13-Docosenamide_Pos                                             24.846650
# Benzyl butyl phthalate (also known as chemical ...              18.148191
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                                17.968112
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                              17.515529
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                            19.436765
# ...                                                                   ...
# PS 34:2|PS 16:1_18:1_Neg                                        26.668654
# PS 34:3|PS 16:1_18:2_Neg                                        22.249945
# PS 36:3|PS 18:1_18:2_Neg                                        23.066782
# SM 36:1;2O_Neg                                                        NaN
# ST 27:1;O;S_Neg                                                 23.711170
#
#                                                     PPI_Ylip_Ctrl_3hr_07  \
# Metabolite name
# 13-Docosenamide_Pos                                            24.030385
# Benzyl butyl phthalate (also known as chemical ...             22.217064
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                               17.233279
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                             18.088247
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                           21.523350
# ...                                                                  ...
# PS 34:2|PS 16:1_18:1_Neg                                       24.485353
# PS 34:3|PS 16:1_18:2_Neg                                       22.182380
# PS 36:3|PS 18:1_18:2_Neg                                       21.982672
# SM 36:1;2O_Neg                                                       NaN
# ST 27:1;O;S_Neg                                                22.772032
#
#                                                     PPI_Ylip_Ctrl_3hr_19  \
# Metabolite name
# 13-Docosenamide_Pos                                            25.845006
# Benzyl butyl phthalate (also known as chemical ...             18.720416
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                               17.331065
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                             18.154364
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                           20.448098
# ...                                                                  ...
# PS 34:2|PS 16:1_18:1_Neg                                       24.917534
# PS 34:3|PS 16:1_18:2_Neg                                       22.471076
# PS 36:3|PS 18:1_18:2_Neg                                       22.456388
# SM 36:1;2O_Neg                                                       NaN
# ST 27:1;O;S_Neg                                                24.140596
#
#                                                     PPI_Ylip_Ctrl_3hr_31  \
# Metabolite name
# 13-Docosenamide_Pos                                            24.150936
# Benzyl butyl phthalate (also known as chemical ...             17.294258
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                               20.669763
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                             19.394637
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                           23.400762
# ...                                                                  ...
# PS 34:2|PS 16:1_18:1_Neg                                       24.467435
# PS 34:3|PS 16:1_18:2_Neg                                       21.754320
# PS 36:3|PS 18:1_18:2_Neg                                       21.972834
# SM 36:1;2O_Neg                                                 12.572391
# ST 27:1;O;S_Neg                                                23.516403
#
#                                                     PPI_Ylip_Ctrl_48hr_15  \
# Metabolite name
# 13-Docosenamide_Pos                                             22.269583
# Benzyl butyl phthalate (also known as chemical ...              14.666511
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                                15.898285
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                              17.116516
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                            18.875394
# ...                                                                   ...
# PS 34:2|PS 16:1_18:1_Neg                                        26.563338
# PS 34:3|PS 16:1_18:2_Neg                                        22.199900
# PS 36:3|PS 18:1_18:2_Neg                                        22.325820
# SM 36:1;2O_Neg                                                  17.599572
# ST 27:1;O;S_Neg                                                 24.922143
#
#                                                     PPI_Ylip_Ctrl_48hr_27  \
# Metabolite name
# 13-Docosenamide_Pos                                             21.841835
# Benzyl butyl phthalate (also known as chemical ...              20.230303
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                                20.876165
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                              17.624778
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                            18.802658
# ...                                                                   ...
# PS 34:2|PS 16:1_18:1_Neg                                        27.517377
# PS 34:3|PS 16:1_18:2_Neg                                        23.241202
# PS 36:3|PS 18:1_18:2_Neg                                        23.461621
# SM 36:1;2O_Neg                                                  14.130612
# ST 27:1;O;S_Neg                                                 25.450679
#
#                                                     PPI_Ylip_Ctrl_48hr_39  \
# Metabolite name
# 13-Docosenamide_Pos                                             24.773849
# Benzyl butyl phthalate (also known as chemical ...              22.716373
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                                17.343525
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                              18.298178
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                            17.987537
# ...                                                                   ...
# PS 34:2|PS 16:1_18:1_Neg                                        27.427478
# PS 34:3|PS 16:1_18:2_Neg                                        23.180653
# PS 36:3|PS 18:1_18:2_Neg                                        23.095878
# SM 36:1;2O_Neg                                                        NaN
# ST 27:1;O;S_Neg                                                 24.099282
#
#                                                     PPI_Ylip_Ctrl_4hr_09  ...  \
# Metabolite name                                                           ...
# 13-Docosenamide_Pos                                            24.168447  ...
# Benzyl butyl phthalate (also known as chemical ...             19.860221  ...
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                               17.661268  ...
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                             17.768323  ...
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                           21.490306  ...
# ...                                                                  ...  ...
# PS 34:2|PS 16:1_18:1_Neg                                       26.316644  ...
# PS 34:3|PS 16:1_18:2_Neg                                       23.612445  ...
# PS 36:3|PS 18:1_18:2_Neg                                       23.719022  ...
# SM 36:1;2O_Neg                                                       NaN  ...
# ST 27:1;O;S_Neg                                                23.170746  ...
#
#                                                     PPI_Ylip_Osc_48hr_28  \
# Metabolite name
# 13-Docosenamide_Pos                                            23.198611
# Benzyl butyl phthalate (also known as chemical ...             18.316787
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                               17.098120
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                             18.205335
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                           17.635546
# ...                                                                  ...
# PS 34:2|PS 16:1_18:1_Neg                                       26.148316
# PS 34:3|PS 16:1_18:2_Neg                                       21.497560
# PS 36:3|PS 18:1_18:2_Neg                                       22.217822
# SM 36:1;2O_Neg                                                       NaN
# ST 27:1;O;S_Neg                                                24.159170
#
#                                                     PPI_Ylip_Osc_4hr_02  \
# Metabolite name
# 13-Docosenamide_Pos                                           25.708514
# Benzyl butyl phthalate (also known as chemical ...            17.978134
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                              18.986626
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                            18.396952
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                          23.450415
# ...                                                                 ...
# PS 34:2|PS 16:1_18:1_Neg                                      23.853807
# PS 34:3|PS 16:1_18:2_Neg                                      20.899754
# PS 36:3|PS 18:1_18:2_Neg                                      21.308381
# SM 36:1;2O_Neg                                                12.147371
# ST 27:1;O;S_Neg                                               23.209749
#
#                                                     PPI_Ylip_Osc_4hr_10  \
# Metabolite name
# 13-Docosenamide_Pos                                           25.314258
# Benzyl butyl phthalate (also known as chemical ...            17.523400
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                              17.937332
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                            18.594108
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                          23.258153
# ...                                                                 ...
# PS 34:2|PS 16:1_18:1_Neg                                      25.575554
# PS 34:3|PS 16:1_18:2_Neg                                      22.408655
# PS 36:3|PS 18:1_18:2_Neg                                      22.607539
# SM 36:1;2O_Neg                                                13.009637
# ST 27:1;O;S_Neg                                               22.898465
#
#                                                     PPI_Ylip_Osc_4hr_22  \
# Metabolite name
# 13-Docosenamide_Pos                                           25.087312
# Benzyl butyl phthalate (also known as chemical ...            18.456111
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                              18.232838
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                            18.250071
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                          21.760263
# ...                                                                 ...
# PS 34:2|PS 16:1_18:1_Neg                                      24.575755
# PS 34:3|PS 16:1_18:2_Neg                                      21.977006
# PS 36:3|PS 18:1_18:2_Neg                                      21.783180
# SM 36:1;2O_Neg                                                12.463638
# ST 27:1;O;S_Neg                                               23.430768
#
#                                                     PPI_Ylip_Osc_5hr_03  \
# Metabolite name
# 13-Docosenamide_Pos                                           24.467046
# Benzyl butyl phthalate (also known as chemical ...            20.009158
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                              18.824780
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                            18.049123
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                          23.204287
# ...                                                                 ...
# PS 34:2|PS 16:1_18:1_Neg                                      24.378892
# PS 34:3|PS 16:1_18:2_Neg                                      21.167752
# PS 36:3|PS 18:1_18:2_Neg                                      21.684530
# SM 36:1;2O_Neg                                                      NaN
# ST 27:1;O;S_Neg                                               22.601564
#
#                                                     PPI_Ylip_Osc_5hr_12  \
# Metabolite name
# 13-Docosenamide_Pos                                           24.804971
# Benzyl butyl phthalate (also known as chemical ...            18.222837
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                              16.840861
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                            17.395292
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                          21.565203
# ...                                                                 ...
# PS 34:2|PS 16:1_18:1_Neg                                      23.999042
# PS 34:3|PS 16:1_18:2_Neg                                      20.783734
# PS 36:3|PS 18:1_18:2_Neg                                      21.478251
# SM 36:1;2O_Neg                                                      NaN
# ST 27:1;O;S_Neg                                               23.701056
#
#                                                     PPI_Ylip_Osc_5hr_24  \
# Metabolite name
# 13-Docosenamide_Pos                                           23.790713
# Benzyl butyl phthalate (also known as chemical ...            17.431683
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                              17.950651
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                            17.577604
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                          21.974343
# ...                                                                 ...
# PS 34:2|PS 16:1_18:1_Neg                                      23.472622
# PS 34:3|PS 16:1_18:2_Neg                                      20.344045
# PS 36:3|PS 18:1_18:2_Neg                                      20.725867
# SM 36:1;2O_Neg                                                      NaN
# ST 27:1;O;S_Neg                                               23.727102
#
#                                                     PPI_Ylip_Osc_72hr_06  \
# Metabolite name
# 13-Docosenamide_Pos                                            22.310327
# Benzyl butyl phthalate (also known as chemical ...             14.692296
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                               16.432692
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                             16.676311
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                           18.219001
# ...                                                                  ...
# PS 34:2|PS 16:1_18:1_Neg                                       27.082956
# PS 34:3|PS 16:1_18:2_Neg                                       22.224821
# PS 36:3|PS 18:1_18:2_Neg                                       22.554605
# SM 36:1;2O_Neg                                                 13.854972
# ST 27:1;O;S_Neg                                                24.888690
#
#                                                     PPI_Ylip_Osc_72hr_18  \
# Metabolite name
# 13-Docosenamide_Pos                                            22.055169
# Benzyl butyl phthalate (also known as chemical ...             14.805130
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                               15.732836
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                             16.534421
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                           18.263177
# ...                                                                  ...
# PS 34:2|PS 16:1_18:1_Neg                                       26.592536
# PS 34:3|PS 16:1_18:2_Neg                                       22.041227
# PS 36:3|PS 18:1_18:2_Neg                                       22.604825
# SM 36:1;2O_Neg                                                       NaN
# ST 27:1;O;S_Neg                                                24.196137
#
#                                                     PPI_Ylip_Osc_72hr_30
# Metabolite name
# 13-Docosenamide_Pos                                            23.234895
# Benzyl butyl phthalate (also known as chemical ...             19.607589
# Cer 34:0;2O|Cer 18:0;2O/16:0_Pos                               16.462009
# Cer 34:0;3O|Cer 18:0;2O/16:0;O_Pos                             17.113058
# Cer 34:2;3O|Cer 18:2;2O/16:0;O_A_Pos                           18.213140
# ...                                                                  ...
# PS 34:2|PS 16:1_18:1_Neg                                       27.306536
# PS 34:3|PS 16:1_18:2_Neg                                       22.456705
# PS 36:3|PS 18:1_18:2_Neg                                       22.958472
# SM 36:1;2O_Neg                                                       NaN
# ST 27:1;O;S_Neg                                                24.223095
#
# [419 rows x 54 columns]
