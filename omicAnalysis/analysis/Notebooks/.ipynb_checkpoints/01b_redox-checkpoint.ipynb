# %% [markdown]
# # multi-omics analysis of *Yarrowia lipolytica* Reactor samples.
#
# This notebook analysis the omic that was obtained from Yarrowia lipolytica grown under variety of oxygen conditions in 2L bioreactors.

# %% [markdown]
# ## Sample Information
# | Sample Label | 	Media | 	Carbon source  | 	Nitrogen condition | 	comments |
# | --- | --- | --- | --- | --- |
# | Ctrl | 	YNB-100gGlucose-C/N100 | 	Glucose | 	C/N 100 | pO2 set to 25% |
# | Osc | 	YNB-100gGlucose-C/N100 | Glucose | 	C/N 100 | pO2 oscillating between ~5-40%	 |
# | Low | 	YNB-100gGlucose-C/N100 | 	Glucose | 	C/N 100 | pO2 set to 5%	 |

# %% [markdown]
# import libraries.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import zscore
from scipy.stats import ttest_ind
from statsmodels.stats.multitest import multipletests
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn3
from matplotlib.lines import Line2D

import re
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


from Bio.KEGG import REST
from Bio.KEGG.KGML import KGML_parser
import io

from scipy.stats import f_oneway
from statsmodels.stats.multitest import multipletests
sns.set_context("talk")
plt.rcParams['pdf.fonttype'] = 42 # when exporting as PDF, font can be edited as font

# %% [markdown]
# ## Create sample mapping for names to conditions/reactors.

# %%
# Data provided
sample_ids_prot_redox = [
    "Biostat2L_29_Oscillation_3.5", "Biostat2L_29_Oscillation_4.5", "Biostat2L_29_Oscillation_5.5",
    "Biostat2L_29_Oscillation_24", "Biostat2L_29_Oscillation_48", "Biostat2L_29_Oscillation_72",
    "Biostat2L_30_Control_3.5", "Biostat2L_30_Control_4.5", "Biostat2L_30_Control_5.5",
    "Biostat2L_30_Control_24", "Biostat2L_30_Control_48", "Biostat2L_30_Control_72",
    "Biostat2L_30_Oscillation_3.5", "Biostat2L_30_Oscillation_4.5", "Biostat2L_30_Oscillation_5.5",
    "Biostat2L_30_Oscillation_24", "Biostat2L_30_Oscillation_48", "Biostat2L_30_Oscillation_72",
    "Biostat2L_31_Control_3.5", "Biostat2L_31_Control_4.5", "Biostat2L_31_Control_5.5",
    "Biostat2L_31_Control_24", "Biostat2L_31_Control_48", "Biostat2L_31_Control_72",
    "Biostat2L_31_Oscillation_3.5", "Biostat2L_31_Oscillation_4.5", "Biostat2L_31_Oscillation_5.5",
    "Biostat2L_31_Oscillation_24", "Biostat2L_31_Oscillation_48", "Biostat2L_31_Oscillation_72",
    "Biostat2L_32_Control_3.5", "Biostat2L_32_Control_4.5", "Biostat2L_32_Control_5.5",
    "Biostat2L_32_Control_24", "Biostat2L_32_Control_48", "Biostat2L_32_Control_72",
    "Biostat2L_32_Low_3.5", "Biostat2L_32_Low_4.5", "Biostat2L_32_Low_5.5",
    "Biostat2L_32_Low_24", "Biostat2L_32_Low_48", "Biostat2L_32_Low_72",
    "Biostat2L_33_Low_3.5", "Biostat2L_33_Low_4.5", "Biostat2L_33_Low_5.5",
    "Biostat2L_33_Low_24", "Biostat2L_33_Low_48", "Biostat2L_33_Low_72",
    "Biostat2L_34_Low_3.5", "Biostat2L_34_Low_4.5", "Biostat2L_34_Low_5.5",
    "Biostat2L_34_Low_24", "Biostat2L_34_Low_48", "Biostat2L_34_Low_72",
]

sample_ids_metabolomics = [
        'PPI_Ylip_Osc_3hr_01',
        'PPI_Ylip_Osc_3hr_08',
        'PPI_Ylip_Osc_3hr_20',
        'PPI_Ylip_Osc_4hr_02',
        'PPI_Ylip_Osc_4hr_10',
        'PPI_Ylip_Osc_4hr_22',
        'PPI_Ylip_Osc_5hr_03',
        'PPI_Ylip_Osc_5hr_12',
        'PPI_Ylip_Osc_5hr_24',
        'PPI_Ylip_Osc_24hr_04',
        'PPI_Ylip_Osc_24hr_14',
        'PPI_Ylip_Osc_24hr_26',
        'PPI_Ylip_Osc_47hr_05',
        'PPI_Ylip_Osc_48hr_16',
        'PPI_Ylip_Osc_48hr_28',
        'PPI_Ylip_Osc_72hr_06',
        'PPI_Ylip_Osc_72hr_18',
        'PPI_Ylip_Osc_72hr_30',
        'PPI_Ylip_Ctrl_3hr_07',
        'PPI_Ylip_Ctrl_3hr_19',
        'PPI_Ylip_Ctrl_3hr_31',
        'PPI_Ylip_Ctrl_4hr_09',
        'PPI_Ylip_Ctrl_4hr_21',
        'PPI_Ylip_Ctrl_4hr_33',
        'PPI_Ylip_Ctrl_5hr_11',
        'PPI_Ylip_Ctrl_5hr_23',
        'PPI_Ylip_Ctrl_5hr_35',
        'PPI_Ylip_Ctrl_24hr_13',
        'PPI_Ylip_Ctrl_24hr_25',
        'PPI_Ylip_Ctrl_24hr_37',
        'PPI_Ylip_Ctrl_48hr_15',
        'PPI_Ylip_Ctrl_48hr_27',
        'PPI_Ylip_Ctrl_48hr_39',
        'PPI_Ylip_Ctrl_72hr_17',
        'PPI_Ylip_Ctrl_72hr_29',
        'PPI_Ylip_Ctrl_72hr_41',
        'PPI_Ylip_Low_3hr_32',
        'PPI_Ylip_Low_3hr_43',
        'PPI_Ylip_Low_3hr_49',
        'PPI_Ylip_Low_4hr_34',
        'PPI_Ylip_Low_4hr_44',
        'PPI_Ylip_Low_4hr_50',
        'PPI_Ylip_Low_5hr_36',
        'PPI_Ylip_Low_5hr_45',
        'PPI_Ylip_Low_5hr_51',
        'PPI_Ylip_Low_24hr_38',
        'PPI_Ylip_Low_24hr_46',
        'PPI_Ylip_Low_24hr_52',
        'PPI_Ylip_Low_48hr_40',
        'PPI_Ylip_Low_48hr_47',
        'PPI_Ylip_Low_48hr_53',
        'PPI_Ylip_Low_72hr_42',
        'PPI_Ylip_Low_72hr_48',
        'PPI_Ylip_Low_72hr_54',

]
lipid_timepoint = [
  3.5, 3.5, 3.5,
  4.5, 4.5, 4.5,
  5.5, 5.5, 5.5,
  24, 24, 24,
  48, 48, 48,
  72, 72, 72,
  3.5, 3.5, 3.5,
  4.5, 4.5, 4.5,
  5.5, 5.5, 5.5,
  24, 24, 24,
  48, 48, 48,
  72, 72, 72,
  3.5, 3.5, 3.5,
  4.5, 4.5, 4.5,
  5.5, 5.5, 5.5,
  24, 24, 24,
  48, 48, 48,
  72, 72, 72
]

sample_ids_lipidomics = [
        'PPI_Ylip_Osc_3hr_01',
        'PPI_Ylip_Osc_3hr_08',
        'PPI_Ylip_Osc_3hr_20',
        'PPI_Ylip_Osc_4hr_02',
        'PPI_Ylip_Osc_4hr_10',
        'PPI_Ylip_Osc_4hr_22',
        'PPI_Ylip_Osc_5hr_03',
        'PPI_Ylip_Osc_5hr_12',
        'PPI_Ylip_Osc_5hr_24',
        'PPI_Ylip_Osc_24hr_04',
        'PPI_Ylip_Osc_24hr_14',
        'PPI_Ylip_Osc_24hr_26',
        'PPI_Ylip_Osc_47hr_05',
        'PPI_Ylip_Osc_48hr_16',
        'PPI_Ylip_Osc_48hr_28',
        'PPI_Ylip_Osc_72hr_06',
        'PPI_Ylip_Osc_72hr_18',
        'PPI_Ylip_Osc_72hr_30',
        'PPI_Ylip_Ctrl_3hr_07',
        'PPI_Ylip_Ctrl_3hr_19',
        'PPI_Ylip_Ctrl_3hr_31',
        'PPI_Ylip_Ctrl_4hr_09',
        'PPI_Ylip_Ctrl_4hr_21',
        'PPI_Ylip_Ctrl_4hr_33',
        'PPI_Ylip_Ctrl_5hr_11',
        'PPI_Ylip_Ctrl_5hr_23',
        'PPI_Ylip_Ctrl_5hr_35',
        'PPI_Ylip_Ctrl_24hr_13',
        'PPI_Ylip_Ctrl_24hr_25',
        'PPI_Ylip_Ctrl_24hr_37',
        'PPI_Ylip_Ctrl_48hr_15',
        'PPI_Ylip_Ctrl_48hr_27',
        'PPI_Ylip_Ctrl_48hr_39',
        'PPI_Ylip_Ctrl_72hr_17',
        'PPI_Ylip_Ctrl_72hr_29',
        'PPI_Ylip_Ctrl_72hr_41',
        'PPI_Ylip_Low_3hr_32',
        'PPI_Ylip_Low_3hr_43',
        'PPI_Ylip_Low_3hr_49',
        'PPI_Ylip_Low_4hr_34',
        'PPI_Ylip_Low_4hr_44',
        'PPI_Ylip_Low_4hr_50',
        'PPI_Ylip_Low_5hr_36',
        'PPI_Ylip_Low_5hr_45',
        'PPI_Ylip_Low_5hr_51',
        'PPI_Ylip_Low_24hr_38',
        'PPI_Ylip_Low_24hr_46',
        'PPI_Ylip_Low_24hr_52',
        'PPI_Ylip_Low_48hr_40',
        'PPI_Ylip_Low_48hr_47',
        'PPI_Ylip_Low_48hr_53',
        'PPI_Ylip_Low_48hr_40',
        'PPI_Ylip_Low_48hr_47',
        'PPI_Ylip_Low_48hr_53',

]

conditions = [
    "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation",
    "Control", "Control", "Control", "Control", "Control", "Control",
    "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation",
    "Control", "Control", "Control", "Control", "Control", "Control",
    "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation", "Oscillation",
    "Control", "Control", "Control", "Control", "Control", "Control",
    "Low", "Low", "Low", "Low", "Low", "Low",
    "Low", "Low", "Low", "Low", "Low", "Low",
    "Low", "Low", "Low", "Low", "Low", "Low"
]

timepoints = [
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
    3.5, 4.5, 5.5, 24, 48, 72,
]

# Create sample_dict
sample_dict = {
    'prot_redox_ids':sample_ids_prot_redox,
    'lipid_ids':sample_ids_lipidomics,
    'lipid_timepoint': lipid_timepoint,
    'met_ids':sample_ids_metabolomics,
    "sample ID": sample_ids_prot_redox,
    "condition": conditions,
    "timepoint": timepoints,
}

lipid_condition_dict = dict(zip(sample_dict['lipid_ids'], sample_dict['condition']))
lipid_timepoint_dict = dict(zip(sample_dict['lipid_ids'], sample_dict['lipid_timepoint']))
met_condition_dict = dict(zip(sample_dict['met_ids'], sample_dict['condition']))
met_timepoint_dict = dict(zip(sample_dict['met_ids'], sample_dict['lipid_timepoint']))
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict_2 = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))


prot_timepoint_dict = {
    "Biostat2L_29_Oscillation_3.5": "Early",
    "Biostat2L_29_Oscillation_4.5": "Early",
    "Biostat2L_29_Oscillation_5.5": "Early",
    "Biostat2L_29_Oscillation_24": "Late",
    "Biostat2L_29_Oscillation_48": "Late",
    "Biostat2L_29_Oscillation_72": "Late",
    "Biostat2L_30_Control_3.5": "Early",
    "Biostat2L_30_Control_4.5": "Early",
    "Biostat2L_30_Control_5.5": "Early",
    "Biostat2L_30_Control_24": "Late",
    "Biostat2L_30_Control_48": "Late",
    "Biostat2L_30_Control_72": "Late",
    "Biostat2L_30_Oscillation_3.5": "Early",
    "Biostat2L_30_Oscillation_4.5": "Early",
    "Biostat2L_30_Oscillation_5.5": "Early",
    "Biostat2L_30_Oscillation_24": "Late",
    "Biostat2L_30_Oscillation_48": "Late",
    "Biostat2L_30_Oscillation_72": "Late",
    "Biostat2L_31_Control_3.5": "Early",
    "Biostat2L_31_Control_4.5": "Early",
    "Biostat2L_31_Control_5.5": "Early",
    "Biostat2L_31_Control_24": "Late",
    "Biostat2L_31_Control_48": "Late",
    "Biostat2L_31_Control_72": "Late",
    "Biostat2L_31_Oscillation_3.5": "Early",
    "Biostat2L_31_Oscillation_4.5": "Early",
    "Biostat2L_31_Oscillation_5.5": "Early",
    "Biostat2L_31_Oscillation_24": "Late",
    "Biostat2L_31_Oscillation_48": "Late",
    "Biostat2L_31_Oscillation_72": "Late",
    "Biostat2L_32_Control_3.5": "Early",
    "Biostat2L_32_Control_4.5": "Early",
    "Biostat2L_32_Control_5.5": "Early",
    "Biostat2L_32_Control_24": "Late",
    "Biostat2L_32_Control_48": "Late",
    "Biostat2L_32_Control_72": "Late",
    "Biostat2L_32_Low_3.5": "Early",
    "Biostat2L_32_Low_4.5": "Early",
    "Biostat2L_32_Low_5.5": "Early",
    "Biostat2L_32_Low_24": "Late",
    "Biostat2L_32_Low_48": "Late",
    "Biostat2L_32_Low_72": "Late",
    "Biostat2L_33_Low_3.5": "Early",
    "Biostat2L_33_Low_4.5": "Early",
    "Biostat2L_33_Low_5.5": "Early",
    "Biostat2L_33_Low_24": "Late",
    "Biostat2L_33_Low_48": "Late",
    "Biostat2L_33_Low_72": "Late",
    "Biostat2L_34_Low_3.5": "Early",
    "Biostat2L_34_Low_4.5": "Early",
    "Biostat2L_34_Low_5.5": "Early",
    "Biostat2L_34_Low_24": "Late",
    "Biostat2L_34_Low_48": "Late",
    "Biostat2L_34_Low_72": "Late",
}

# %% [markdown]
# ## Definitions.

# %%
def plot_pca(pca_df, explained_variance, hue='Condition', time='Timepoint', title=None):
    # Font style
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']

    # Force condition order and assign colors manually
    condition_order = ['Control', 'Low', 'Oscillation']
    color_palette = {
        'Control': '#9467bd',     # purple
        'Low': '#2ca02c',         # red
        'Oscillation': '#6495ED'  # blue
    }
    pca_df[hue] = pd.Categorical(pca_df[hue], categories=condition_order, ordered=True)

    # Timepoint to marker shape
    marker_styles = {
        24.0: 'v',   # triangle down
        48.0: 's',   # square
        72.0: 'D'    # diamond
    }
    default_marker = 'o'
    pca_df['Marker'] = pca_df[time].map(marker_styles).fillna(default_marker)

    # Create the plot
    plt.figure(figsize=(8, 8))
    ax = sns.scatterplot(
        x='PC1', y='PC2',
        hue=hue,
        hue_order=condition_order,
        style='Marker',
        markers={'o': 'o', 'v': 'v', 's': 's', 'D': 'D'},
        palette=color_palette,
        data=pca_df,
        s=150
    )

    # Label axes
    plt.xlabel(f'PC1 ({explained_variance[0]*100:.2f}% variance)', fontsize=24)
    plt.ylabel(f'PC2 ({explained_variance[1]*100:.2f}% variance)', fontsize=24)

    # Custom shape legend
    shape_legend_elements = [
        Line2D([0], [0], marker='o', color='w', label='< 24 h', markersize=10, markerfacecolor='black'),

        Line2D([0], [0], marker='v', color='w', label='24 h', markersize=10, markerfacecolor='black'),
        Line2D([0], [0], marker='s', color='w', label='48 h', markersize=10, markerfacecolor='black'),
        Line2D([0], [0], marker='D', color='w', label='72 h', markersize=10, markerfacecolor='black'),
    ]

    # Manually control legends to prevent cutoff & missing entries
    handles, labels = ax.get_legend_handles_labels()
    condition_handles = [h for h, l in zip(handles, labels) if l in condition_order]
    condition_labels = condition_order  # preserve order

    # Add condition legend
    first_legend = plt.legend(
        condition_handles, condition_labels,
        title=hue, bbox_to_anchor=(0.95, .75), loc='upper left',
        frameon=False, fontsize=16, title_fontsize=16
    )
    ax.add_artist(first_legend)

    # Add timepoint shape legend
    plt.legend(
        title='Time (h)', 
        handles=shape_legend_elements,
        bbox_to_anchor=(1.0, 0.50), loc='upper left',
        frameon=False, fontsize=16, title_fontsize=16
    )

    # Clean up axes and ticks
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_linewidth(0.5)
    ax.spines['bottom'].set_linewidth(0.5)
    ax.tick_params(axis='both', which='major', width=0.5, labelsize=20)
    plt.xticks(size=16)
    plt.yticks(size=16)

    # Prevent legends from getting cut off
    plt.tight_layout()

    # Save if filename provided
    if title:
        # plt.savefig(title, dpi=600, bbox_inches='tight', facecolor='white')
        plt.savefig(title+".png", dpi=600, bbox_inches="tight", facecolor="white")
        # or
        plt.savefig(title+".tiff", dpi=600, bbox_inches="tight")
        plt.savefig(title+".pdf", bbox_inches="tight" )
        plt.savefig(title+".svg", bbox_inches="tight")
    plt.show()


def global_stats_calc_prot(df, condition_series, id_col='Site'):
    """
    df: rows = proteins/sites, columns = samples + (optionally) id_col
    condition_series: index = sample names matching df sample columns
    id_col: column in df identifying the protein/site (default 'Site')
    """

    # Work on a copy and ensure we have an identifier column to merge on
    df_out = df.copy()

    
    # Avoid: id_col is both index level and column
    if df_out.index.name == id_col and id_col in df_out.columns:
        df_out = df_out.reset_index(drop=True)
    elif df_out.index.name == id_col and id_col not in df_out.columns:
        df_out = df_out.reset_index()    
    # if id_col not in df_out.columns:
    #     # if your df uses the index as the id, promote it to a column
    #     df_out[id_col] = df_out.index

    # Use id as index for analysis
    data = df_out.set_index(id_col)

    # Drop any NaN-valued entries (e.g. accidental 'Protein'/'ProteinID' rows)
    condition_series = condition_series.dropna()

    sample_cols = [c for c in data.columns if c in condition_series.index]
    # Keep only sample columns that exist in condition_series
    sample_cols = [c for c in data.columns if c in condition_series.index]
    t_data = data[sample_cols].T  # rows=samples, cols=proteins/sites

    unique_conditions = pd.unique(condition_series.loc[sample_cols])

    anova_results = {}
    for prot in t_data.columns:
        group_data = []
        for cond in unique_conditions:
            idx = condition_series[(condition_series == cond)].index
            idx = [i for i in idx if i in t_data.index]  # align to available samples
            vals = t_data.loc[idx, prot].dropna().values
            group_data.append(vals)

        # skip if any group has no data
        if any(len(g) == 0 for g in group_data):
            continue

        try:
            _, p = f_oneway(*group_data)
            anova_results[prot] = p
        except Exception:
            continue

    # Build results df and ALWAYS create padj column
    anova_df = pd.DataFrame.from_dict(anova_results, orient='index', columns=['ANOVA_p'])
    anova_df['ANOVA_padj'] = np.nan
    if len(anova_df) > 0:
        anova_df['ANOVA_padj'] = multipletests(anova_df['ANOVA_p'].values, method='fdr_bh')[1]

    # Merge back (even if anova_df is empty, columns will exist in output as NaN)
    anova_df = anova_df.reset_index().rename(columns={'index': id_col})
    merged_df = df_out.merge(anova_df, on=id_col, how='left')

    # Ensure columns exist even if merge produced none (paranoia)
    for col in ['ANOVA_p', 'ANOVA_padj']:
        if col not in merged_df.columns:
            merged_df[col] = np.nan

    return merged_df

def sort_by_significance(df,key_stat='ANOVA_padj'):
    if key_stat not in df.columns:
        raise KeyError("'Key_stat column is missing. Ensure ANOVA has been performed.")
    
    # Sort the DataFrame based on 'ANOVA_p' for significance
    # If you want to use 'ANOVA_padj', you can replace 'ANOVA_p' with 'ANOVA_padj'
    sorted_df = df.sort_values(by=key_stat).copy()

    # Select the top 100 most significant
    top_100_df = sorted_df.head(100)

    return top_100_df

def pca_preprocess(df):
    # Standardize the features
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(df)

    # Perform PCA
    # pca = make_pipeline(StandardScaler(), PCA())

    # pca = PCA()#n_components=2)  # Reduce to 2 components for visualization
    pca = PCA(n_components=2)  # Reduce to 2 components for visualization
    pca_result = pca.fit_transform(df)

    # Capture the explained variance for each component
    explained_variance = pca.explained_variance_ratio_

    # Create a new DataFrame with PCA results
    # pca_df = pd.DataFrame(
    #     pca_result,
    #     columns=[f"PC{i+1}" for i in range(pca_result.shape[1])]
    # )
    pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])
    return pca_df, explained_variance


def get_dynamic_limits(df):
    # Compute the overall minimum and maximum values from the dataset
    x_min = df.min()[0]-1
    x_max = df.max()[0]+1
    
    y_min = 0
    y_max = dataset.max()[2]+1

    return x_min,x_max,y_min,y_max


def volcano_plot(dataset,title=None):
    fig,ax = plt.subplots(1,1,figsize=(7,7))

    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']
    
    x_min,x_max, y_min,y_max = get_dynamic_limits(dataset)

    x_limits = (x_min,x_max)
    y_limits = (0,y_max)
    
    y_cutoff = -np.log10(0.05)
    x_cutoff = 0.37851162325
    sns.scatterplot(data = dataset, 
                    x = 'log2FC', 
                    y = '-logP_adj', 
                    hue='class', 
                    s = 25, alpha = 0.5, palette=['#0571B0','#BABABA','#CA0020'], ax=ax)
    legend_handles, _= ax.get_legend_handles_labels()
    
    legend = ax.legend(legend_handles, ['down-regulated','not significant','up-regulated'], 
              bbox_to_anchor=(1,1), 
              title='')
    
    legend.get_frame().set_edgecolor('none')  # Disable the border

    ax.plot(x_limits,[y_cutoff,y_cutoff],'k--')
    ax.plot([x_cutoff,x_cutoff],y_limits,'k--')
    ax.plot([-x_cutoff,-x_cutoff],y_limits,'k--')
    ax.set_ylabel(r'-Log$_2$(P$_{adj}$)', fontsize=24)
    ax.set_xlabel(r'Log$_2$(FC)', fontsize=24)
    if title:
        fig.savefig(title+'.png')

def log2FC_function(df1,df2):
    # substrates 1 dataframe from the second. 
    mean1 = df1.mean(axis=1)
    mean2 = df2.mean(axis=1)
    return (mean1-mean2)

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# import matplotlib.pyplot as plt
# import seaborn as sns
# import numpy as np
# import pandas as pd

def annotate_top_genes(ax, dataset, num_top=5):
    """
    Annotates the top up-regulated and down-regulated genes on the volcano plot with dynamic text positioning.
    """
    # Sort dataset by log2FC and find top up-regulated and down-regulated genes
    top_up = dataset.nlargest(num_top, 'log2FC')
    top_down = dataset.nsmallest(num_top, 'log2FC')

    # Combine top genes using pd.concat (instead of deprecated append)
    top_genes = pd.concat([top_up, top_down])
    
    for protein_id, row in top_genes.iterrows():
        # Determine text position based on log2FC (right for positive, left for negative)
        if row['log2FC'] > 0:
            xytext = (row['log2FC'] + 0.5, row['-logP_adj'] + 0.5)  # Right-hand side for positive values
        else:
            xytext = (row['log2FC'] - 0.5, row['-logP_adj'] + 0.5)  # Left-hand side for negative values
        
        ax.annotate(
            protein_id, # Annotate with proteinID, which is the index
            xy=(row['log2FC'], row['-logP_adj']), # Point where annotation starts
            xytext=xytext, # Adjust text placement dynamically
            fontsize=10,
            arrowprops=dict(arrowstyle="->", color="black", lw=1.5), # Arrow pointing to the data point
            bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white") # Label background
        )


def volcano_plot_annotate(dataset, title=None):
    """
    Function to plot the volcano plot and annotate the top 5 up-regulated and down-regulated genes with arrows.
    """
    # Extract dynamic plot limits
    x_min, x_max, y_min, y_max = get_dynamic_limits(dataset)
    x_limits = (x_min, x_max)
    y_limits = (0, y_max)

    # Initialize plot
    fig, ax = plt.subplots(1, 1, figsize=(7, 7))
    plt.rcParams['font.family'] = 'serif'
    plt.rcParams['font.serif'] = ['Times New Roman']

    # Add scatter plot
    sns.scatterplot(data=dataset, 
                    x='log2FC', 
                    y='-logP_adj', 
                    hue='class', 
                    s=25, alpha=0.5, palette=['#0571B0','#BABABA','#CA0020'], ax=ax)
    
    # Add legend
    legend_handles, _ = ax.get_legend_handles_labels()
    legend = ax.legend(legend_handles, ['down-regulated', 'not significant', 'up-regulated'], 
                       bbox_to_anchor=(1, 1), title='')
    legend.get_frame().set_edgecolor('none')  # Disable legend border

    # Draw threshold cutoff lines
    y_cutoff = -np.log10(0.05)
    x_cutoff = 0.37851162325
    ax.plot(x_limits, [y_cutoff, y_cutoff], 'k--')
    ax.plot([x_cutoff, x_cutoff], y_limits, 'k--')
    ax.plot([-x_cutoff, -x_cutoff], y_limits, 'k--')

    # Label axes
    ax.set_ylabel(r'-Log$_2$(P$_{adj}$)', fontsize=24)
    ax.set_xlabel(r'Log$_2$(FC)', fontsize=24)

    # Annotate the top genes
    annotate_top_genes(ax, dataset)

    # Save the plot if a title is provided
    if title:
        fig.savefig(f"{title}.png")

    return fig, ax

# %% [markdown]
# # Read in Annotations.

# %% [markdown]
# Annotations downloaded for FKP355 strain from JGI, June 2025.
#
#
# https://mycocosm.jgi.doe.gov/pages/search-for-genes.jsf?organism=Yarlip1

# %% [markdown]
# ### grab KEGG info.

# %%
KEGGannotate = pd.read_table('../Annotations/Filtered Models ("best")/Functional Annotations/EC annotations and KEGG pathway mappings/YarliW29_1_GeneCatalog_proteins_20190319_KEGG.tab')
# annotate.index = annotate.index.map(str)
KEGGannotate.head()
# Kegg_pathwayDict = dict(zip(annotate.index,annotate.pathway))
# Out:
#    #proteinId     ecNum                                definition  \
# 0           5  4.2.1.24                 Porphobilinogen synthase.
# 1          11   6.1.1.5                  Isoleucine--tRNA ligase.
# 2          11   6.1.1.5                  Isoleucine--tRNA ligase.
# 3          32  3.1.4.46  Glycerophosphodiester phosphodiesterase.
# 4          32  3.1.4.46  Glycerophosphodiester phosphodiesterase.
#
#                                    catalyticActivity cofactors  \
# 0   2 5-aminolevulinate = porphobilinogen + 2 H(2)O.     Zinc.
# 1  ATP + L-isoleucine + tRNA(Ile) = AMP + diphosp...        \N
# 2  ATP + L-isoleucine + tRNA(Ile) = AMP + diphosp...        \N
# 3  A glycerophosphodiester + H(2)O = an alcohol +...        \N
# 4  A glycerophosphodiester + H(2)O = an alcohol +...        \N
#
#                                   associatedDiseases  \
# 0  Susceptibility to lead poisoning; MIM:125270. ...
# 1                                                 \N
# 2                                                 \N
# 3                                                 \N
# 4                                                 \N
#
#                                        pathway  \
# 0         Porphyrin and chlorophyll metabolism
# 1  Valine, leucine and isoleucine biosynthesis
# 2                  Aminoacyl-tRNA biosynthesis
# 3                     Phospholipid degradation
# 4                      Glycerolipid metabolism
#
#                           pathway_class pathway_type
# 0  Metabolism of Cofactors and Vitamins    METABOLIC
# 1                 Amino Acid Metabolism    METABOLIC
# 2                           TRANSLATION   REGULATORY
# 3          Metabolism of Complex Lipids    METABOLIC
# 4          Metabolism of Complex Lipids    METABOLIC

# %%
KEGGannotate.shape
# Out:
# (2516, 9)

# %%
# Group by 'proteinId' and aggregate columns into lists for simpler downstream processing. 
KEGGannotate = KEGGannotate.groupby('#proteinId').agg({
    'definition': list,
    'catalyticActivity': list,
    'pathway': list,
    'pathway_class': list,
    'pathway_type': list,
    'ecNum': list,
    'cofactors': list,
}).reset_index()

# %% [markdown]
# ### grab GO info.

# %%
GOannotate  = pd.read_table('../Annotations/Filtered Models ("best")/Functional Annotations/GO/YarliW29_1_GeneCatalog_proteins_20190319_GO.tab')

GOannotate.head()
# Out:
#    #proteinId  gotermId                             goName  \
# 0           5      3028  porphobilinogen synthase activity
# 1          11       162                 nucleotide binding
# 2          11      3172     aminoacyl-tRNA ligase activity
# 3          11      3736                        ATP binding
# 4          11      3930                          cytoplasm
#
#            gotermType       goAcc
# 0  molecular_function  GO:0004655
# 1  molecular_function  GO:0000166
# 2  molecular_function  GO:0004812
# 3  molecular_function  GO:0005524
# 4  cellular_component  GO:0005737

# %%
# Group by 'proteinId' and aggregate columns into lists for simpler downstream processing. 
GOannotate = GOannotate.groupby('#proteinId').agg({
    'gotermId': list,
    'gotermType': list,
    'goName': list,
    'goAcc': list,
}).reset_index()

# %% [markdown]
# ## Merge annotations.

# %%
merged_annotations = pd.merge(KEGGannotate, GOannotate, on='#proteinId', how='outer')

# Merge the result with df3
# merged_annotations = pd.merge(merged_annotations, KEGGannotate, on='proteinId', how='outer')

# %%
merged_annotations.head()
# Out:
#    #proteinId                                         definition  \
# 0           5                        [Porphobilinogen synthase.]
# 1          11  [Isoleucine--tRNA ligase., Isoleucine--tRNA li...
# 2          12                                                NaN
# 3          13                                                NaN
# 4          14                                                NaN
#
#                                    catalyticActivity  \
# 0  [2 5-aminolevulinate = porphobilinogen + 2 H(2...
# 1  [ATP + L-isoleucine + tRNA(Ile) = AMP + diphos...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              pathway  \
# 0             [Porphyrin and chlorophyll metabolism]
# 1  [Valine, leucine and isoleucine biosynthesis, ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                             pathway_class             pathway_type  \
# 0  [Metabolism of Cofactors and Vitamins]              [METABOLIC]
# 1    [Amino Acid Metabolism, TRANSLATION]  [METABOLIC, REGULATORY]
# 2                                     NaN                      NaN
# 3                                     NaN                      NaN
# 4                                     NaN                      NaN
#
#                 ecNum cofactors  \
# 0          [4.2.1.24]   [Zinc.]
# 1  [6.1.1.5, 6.1.1.5]  [\N, \N]
# 2                 NaN       NaN
# 3                 NaN       NaN
# 4                 NaN       NaN
#
#                                           gotermId  \
# 0                                           [3028]
# 1  [162, 3172, 3736, 3930, 4556, 4561, 3182, 4571]
# 2                                           [3737]
# 3                                     [4604, 5817]
# 4                              [3737, 2378, 24058]
#
#                                           gotermType  \
# 0                               [molecular_function]
# 1  [molecular_function, molecular_function, molec...
# 2                               [molecular_function]
# 3           [biological_process, molecular_function]
# 4  [molecular_function, molecular_function, molec...
#
#                                               goName  \
# 0                [porphobilinogen synthase activity]
# 1  [nucleotide binding, aminoacyl-tRNA ligase act...
# 2                                      [GTP binding]
# 3  [protein amino acid dephosphorylation, protein...
# 4  [GTP binding, GTPase activity, hydrolase activ...
#
#                                                goAcc
# 0                                       [GO:0004655]
# 1  [GO:0000166, GO:0004812, GO:0005524, GO:000573...
# 2                                       [GO:0005525]
# 3                           [GO:0006470, GO:0008138]
# 4               [GO:0005525, GO:0003924, GO:0050800]

# %%
# merged_annotations.to_csv('../Annotations/GO_KEGG_EC_annotations.csv')

# %% [markdown]
# ## grab KOG info.

# %%
kog_annotations = pd.read_table('../Annotations/Filtered Models ("best")/Functional Annotations/YarliW29_1_GeneCatalog_proteins_20190319_KOG.tab')
kog_annotations.rename(columns={'proteinId': '#proteinId'}, inplace=True)

# %%
kog_annotations.head()
# Out:
#    #transcriptId  #proteinId    kogid  \
# 0           6541        5563  KOG0001
# 1           6541        5563  KOG0001
# 2           7831        6853  KOG0004
# 3           8270        7292  KOG0005
# 4           8270        7292  KOG0005
#
#                                     kogdefline  \
# 0        Ubiquitin and ubiquitin-like proteins
# 1        Ubiquitin and ubiquitin-like proteins
# 2  Ubiquitin/40S ribosomal protein S27a fusion
# 3                       Ubiquitin-like protein
# 4                       Ubiquitin-like protein
#
#                                             kogClass  \
# 0  Posttranslational modification, protein turnov...
# 1                  General function prediction only
# 2   Translation, ribosomal structure and biogenesis
# 3  Cell cycle control, cell division, chromosome ...
# 4  Posttranslational modification, protein turnov...
#
#                              kogGroup
# 0    CELLULAR PROCESSES AND SIGNALING
# 1                POORLY CHARACTERIZED
# 2  INFORMATION STORAGE AND PROCESSING
# 3                          METABOLISM
# 4    CELLULAR PROCESSES AND SIGNALING

# %%
# Group by 'proteinId' and aggregate columns into lists for simpler downstream processing. 
kog_annotations = kog_annotations.groupby('#proteinId').agg({
    'kogid': list,
    'kogdefline': list,
    'kogClass': list,
    'kogGroup': list,
}).reset_index()

# %% [markdown]
# ## Merge KOG with KEGG / GO annotations.

# %%
merged_annotations = pd.merge(kog_annotations, merged_annotations, on='#proteinId', how='outer')

# Merge the result with df3
# merged_annotations = pd.merge(merged_annotations, KEGGannotate, on='proteinId', how='outer')

# %%
merged_annotations.head()
# Out:
#    #proteinId      kogid                                         kogdefline  \
# 0           4  [KOG2262]      [Sexual differentiation process protein ISP4]
# 1           5  [KOG0101]  [Molecular chaperones HSP70/HSC70, HSP70 super...
# 2          11  [KOG0434]                        [Isoleucyl-tRNA synthetase]
# 3          12  [KOG1487]       [GTP-binding protein DRG1 (ODN superfamily)]
# 4          13  [KOG1716]                     [Dual specificity phosphatase]
#
#                                             kogClass  \
# 0                  [Signal transduction mechanisms ]
# 1  [Posttranslational modification, protein turno...
# 2  [Translation, ribosomal structure and biogenes...
# 3                  [Signal transduction mechanisms ]
# 4                              [Defense mechanisms ]
#
#                                kogGroup  \
# 0    [CELLULAR PROCESSES AND SIGNALING]
# 1    [CELLULAR PROCESSES AND SIGNALING]
# 2  [INFORMATION STORAGE AND PROCESSING]
# 3    [CELLULAR PROCESSES AND SIGNALING]
# 4    [CELLULAR PROCESSES AND SIGNALING]
#
#                                           definition  \
# 0                                                NaN
# 1                        [Porphobilinogen synthase.]
# 2  [Isoleucine--tRNA ligase., Isoleucine--tRNA li...
# 3                                                NaN
# 4                                                NaN
#
#                                    catalyticActivity  \
# 0                                                NaN
# 1  [2 5-aminolevulinate = porphobilinogen + 2 H(2...
# 2  [ATP + L-isoleucine + tRNA(Ile) = AMP + diphos...
# 3                                                NaN
# 4                                                NaN
#
#                                              pathway  \
# 0                                                NaN
# 1             [Porphyrin and chlorophyll metabolism]
# 2  [Valine, leucine and isoleucine biosynthesis, ...
# 3                                                NaN
# 4                                                NaN
#
#                             pathway_class             pathway_type  \
# 0                                     NaN                      NaN
# 1  [Metabolism of Cofactors and Vitamins]              [METABOLIC]
# 2    [Amino Acid Metabolism, TRANSLATION]  [METABOLIC, REGULATORY]
# 3                                     NaN                      NaN
# 4                                     NaN                      NaN
#
#                 ecNum cofactors  \
# 0                 NaN       NaN
# 1          [4.2.1.24]   [Zinc.]
# 2  [6.1.1.5, 6.1.1.5]  [\N, \N]
# 3                 NaN       NaN
# 4                 NaN       NaN
#
#                                           gotermId  \
# 0                                              NaN
# 1                                           [3028]
# 2  [162, 3172, 3736, 3930, 4556, 4561, 3182, 4571]
# 3                                           [3737]
# 4                                     [4604, 5817]
#
#                                           gotermType  \
# 0                                                NaN
# 1                               [molecular_function]
# 2  [molecular_function, molecular_function, molec...
# 3                               [molecular_function]
# 4           [biological_process, molecular_function]
#
#                                               goName  \
# 0                                                NaN
# 1                [porphobilinogen synthase activity]
# 2  [nucleotide binding, aminoacyl-tRNA ligase act...
# 3                                      [GTP binding]
# 4  [protein amino acid dephosphorylation, protein...
#
#                                                goAcc
# 0                                                NaN
# 1                                       [GO:0004655]
# 2  [GO:0000166, GO:0004812, GO:0005524, GO:000573...
# 3                                       [GO:0005525]
# 4                           [GO:0006470, GO:0008138]

# %% [markdown]
# ## save annotation file.

# %%
# merged_annotations.to_csv('../Annotations/KOG_GO_KEGG_EC_annotations.csv')

# %%
annot_plus_kog = merged_annotations.copy()

# %% [markdown]
# # Read in protein and PTM data.

# %%
# proteomics_data = pd.read_csv('../Data/PPI_yarrowia_REDOX_Global/result/PTM/PPI_yarrowia_protein_abundance.csv')
# with annotations
# proteomics_data = pd.read_csv('../Data/Proteomic_PTMs/redox_global/PPI_yarrowia_protein_abundance_wAnnotations.csv')

redox_data = pd.read_csv('../Data/Proteomic_PTMs/redox_global/PPI_yarrowia_all_ptms.csv')
# phospho_data = pd.read_csv('../Data/PPI_yarrowia_REDOX_Global/Phospho/PPI_yarrowia/result/PTM/PPI_yarrowia_all_ptms.csv')
# phospho_data = phospho_data[phospho_data['Type']=='Ph']

redox = redox_data[sample_ids_prot_redox]

# %%
redox_data.head()
# Out:
#                                       Peptide                      Site  \
# 0                              R.IEPIC@AQGR.I  jgi|YarliW29_1|1000@C503
# 1                             K.VFIGSC@TNSR.I  jgi|YarliW29_1|1002@C352
# 2                                R.C@ASTSNR.N  jgi|YarliW29_1|1002@C430
# 3                       K.DC@TLATVDHNIPTTTR.K   jgi|YarliW29_1|1002@C55
# 4  K.ASILVVSGDNFGC@GSSR.E; L.VVSGDNFGC@GSSR.E  jgi|YarliW29_1|1002@C614
#
#                UniProt              Protein Residue                        id  \
# 0  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000    C503  jgi|YarliW29_1|1000@C503
# 1  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C352  jgi|YarliW29_1|1002@C352
# 2  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C430  jgi|YarliW29_1|1002@C430
# 3  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002     C55   jgi|YarliW29_1|1002@C55
# 4  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C614  jgi|YarliW29_1|1002@C614
#
#    Total missingness  Oscillation_24 missingness  Oscillation_3.5 missingness  \
# 0                  0                           0                            0
# 1                  0                           0                            0
# 2                 36                           3                            3
# 3                  0                           0                            0
# 4                  0                           0                            0
#
#    Oscillation_4.5 missingness  ...  Oscillation_24/Oscillation_3.5_adj-p  \
# 0                            0  ...                              0.004273
# 1                            0  ...                              0.074259
# 2                            3  ...                                   NaN
# 3                            0  ...                              0.016003
# 4                            0  ...                              0.009960
#
#    Oscillation_48/Oscillation_3.5  Oscillation_48/Oscillation_3.5_pval  \
# 0                        1.760655                             0.000120
# 1                        0.386963                             0.260477
# 2                             NaN                                  NaN
# 3                        1.571801                             0.008855
# 4                        2.879304                             0.000645
#
#    Oscillation_48/Oscillation_3.5_adj-p  Oscillation_72/Oscillation_3.5  \
# 0                              0.001042                        1.937960
# 1                              0.280174                        0.273868
# 2                                   NaN                             NaN
# 3                              0.015009                        1.852336
# 4                              0.002500                        3.240543
#
#    Oscillation_72/Oscillation_3.5_pval  Oscillation_72/Oscillation_3.5_adj-p  \
# 0                             0.000041                              0.000449
# 1                             0.235540                              0.248877
# 2                                  NaN                                   NaN
# 3                             0.000728                              0.002182
# 4                             0.000032                              0.000423
#
#    Type  Experiment  site_number
# 0    Ox         PTM            1
# 1    Ox         PTM            8
# 2    Ox         PTM            8
# 3    Ox         PTM            8
# 4    Ox         PTM            8
#
# [5 rows x 170 columns]

# %%
redox_data["proteinId"] = redox_data["Protein"].str.rsplit("|", n=1).str[-1]
redox_data["#proteinId"] = redox_data["proteinId"].copy().astype(int)

# %%
redox_data.head()
# Out:
#                                       Peptide                      Site  \
# 0                              R.IEPIC@AQGR.I  jgi|YarliW29_1|1000@C503
# 1                             K.VFIGSC@TNSR.I  jgi|YarliW29_1|1002@C352
# 2                                R.C@ASTSNR.N  jgi|YarliW29_1|1002@C430
# 3                       K.DC@TLATVDHNIPTTTR.K   jgi|YarliW29_1|1002@C55
# 4  K.ASILVVSGDNFGC@GSSR.E; L.VVSGDNFGC@GSSR.E  jgi|YarliW29_1|1002@C614
#
#                UniProt              Protein Residue                        id  \
# 0  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000    C503  jgi|YarliW29_1|1000@C503
# 1  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C352  jgi|YarliW29_1|1002@C352
# 2  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C430  jgi|YarliW29_1|1002@C430
# 3  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002     C55   jgi|YarliW29_1|1002@C55
# 4  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C614  jgi|YarliW29_1|1002@C614
#
#    Total missingness  Oscillation_24 missingness  Oscillation_3.5 missingness  \
# 0                  0                           0                            0
# 1                  0                           0                            0
# 2                 36                           3                            3
# 3                  0                           0                            0
# 4                  0                           0                            0
#
#    Oscillation_4.5 missingness  ...  Oscillation_48/Oscillation_3.5_pval  \
# 0                            0  ...                             0.000120
# 1                            0  ...                             0.260477
# 2                            3  ...                                  NaN
# 3                            0  ...                             0.008855
# 4                            0  ...                             0.000645
#
#    Oscillation_48/Oscillation_3.5_adj-p  Oscillation_72/Oscillation_3.5  \
# 0                              0.001042                        1.937960
# 1                              0.280174                        0.273868
# 2                                   NaN                             NaN
# 3                              0.015009                        1.852336
# 4                              0.002500                        3.240543
#
#    Oscillation_72/Oscillation_3.5_pval  Oscillation_72/Oscillation_3.5_adj-p  \
# 0                             0.000041                              0.000449
# 1                             0.235540                              0.248877
# 2                                  NaN                                   NaN
# 3                             0.000728                              0.002182
# 4                             0.000032                              0.000423
#
#    Type  Experiment  site_number  proteinId  #proteinId
# 0    Ox         PTM            1       1000        1000
# 1    Ox         PTM            8       1002        1002
# 2    Ox         PTM            8       1002        1002
# 3    Ox         PTM            8       1002        1002
# 4    Ox         PTM            8       1002        1002
#
# [5 rows x 172 columns]

# %%
annotated_redox = redox_data.merge(annot_plus_kog, on='#proteinId', how='left')
# annotated_redox.to_csv('../Data/PPI_yarrowia_REDOX_Global/result/PTM/PPI_yarrowia_REDOX_wAnnotations_.csv')

# %% [markdown]
# df['YALI1_protID'] = df['proteinId'].map(JGI_Yali1.set_index('JGI_protID')['YALI1_protID'])
# df['YALI0_locus'] = df['YALI1_protID'].map(Yali1_Yali0.set_index('YALI1_Proteins')['YALI0_locus_ID'])
# df['YALI1_protID_converted'] = df['YALI1_protID'].str.replace('g', 'p', regex=False)
# df['YALI2'] = df['YALI1_protID_converted'].map(Yali1_Yali2.set_index('YALI1')['YALI2'])

# %%
annotated_redox = pd.read_csv( "../Data/Proteomic_PTMs/redox_global/PPI_yarrowia_all_ptms.csv")

# %%
# phospho_data = pd.read_csv('../Data/Proteomic_PTMs/phospho/PPI_yarrowia_all_ptms.csv')

# %%
# phospho_data = phospho_data[phospho_data['Type']=='Ph']

# %%
# phos = phospho_data[sample_ids_prot_redox]
# phos.dropna(axis=0, inplace=True)

# %%
redox = redox_data[sample_ids_prot_redox]

redox.dropna(axis=0, inplace=True)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/981431983.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   redox.dropna(axis=0, inplace=True)

# %%
redox.head()
# Out:
#    Biostat2L_29_Oscillation_3.5  Biostat2L_29_Oscillation_4.5  \
# 0                     16.846811                     16.562889
# 1                     19.436363                     19.469720
# 3                     18.252694                     18.286464
# 4                     15.896053                     15.358501
# 5                     15.450753                     14.430536
#
#    Biostat2L_29_Oscillation_5.5  Biostat2L_29_Oscillation_24  \
# 0                     16.827315                    17.771583
# 1                     19.418304                    19.220965
# 3                     18.422682                    19.363283
# 4                     15.582766                    17.383142
# 5                     14.176803                    17.133909
#
#    Biostat2L_29_Oscillation_48  Biostat2L_29_Oscillation_72  \
# 0                    18.596711                    18.613297
# 1                    19.952574                    19.523283
# 3                    20.099247                    20.247919
# 4                    18.595572                    18.774382
# 5                    18.364913                    18.364627
#
#    Biostat2L_30_Control_3.5  Biostat2L_30_Control_4.5  \
# 0                 16.792441                 16.258855
# 1                 18.877320                 19.745658
# 3                 18.424198                 18.487841
# 4                 15.784976                 15.481521
# 5                 15.162194                 14.713784
#
#    Biostat2L_30_Control_5.5  Biostat2L_30_Control_24  ...  \
# 0                 16.392205                17.457152  ...
# 1                 18.694869                19.717296  ...
# 3                 18.562002                18.874312  ...
# 4                 15.453148                17.278106  ...
# 5                 14.530765                17.177533  ...
#
#    Biostat2L_33_Low_5.5  Biostat2L_33_Low_24  Biostat2L_33_Low_48  \
# 0             16.605363            16.635118            16.142903
# 1             18.014867            18.321864            19.446600
# 3             18.599085            18.679093            18.578693
# 4             15.417675            15.447046            16.150221
# 5             14.516666            15.164010            15.375349
#
#    Biostat2L_33_Low_72  Biostat2L_34_Low_3.5  Biostat2L_34_Low_4.5  \
# 0            16.651285             16.641320             16.532442
# 1            19.953698             19.213165             18.988372
# 3            18.428186             18.354685             18.568332
# 4            16.877026             15.691573             15.082033
# 5            16.649625             15.161328             14.884083
#
#    Biostat2L_34_Low_5.5  Biostat2L_34_Low_24  Biostat2L_34_Low_48  \
# 0             16.538504            16.451691            16.481918
# 1             18.240673            19.104072            19.454477
# 3             18.748328            18.593297            18.424024
# 4             14.969355            15.920855            16.629091
# 5             14.430293            15.278934            15.935781
#
#    Biostat2L_34_Low_72
# 0            16.782876
# 1            20.131243
# 3            18.238569
# 4            17.021753
# 5            16.193239
#
# [5 rows x 54 columns]

# %% [markdown]
# ## PCA plots of REDOX proteome.

# %%
features = redox.T
pca_df, explained_variance = pca_preprocess(features)
features['Condition'] = features.index.map(prot_condition_dict)
# features['Timepoint'] = features.index.map(prot_timepoint_dict)
features['Timepoint'] = features.index.map(prot_timepoint_dict_2)

pca_df['Condition'] = features['Condition'].values
pca_df['Timepoint'] = features['Timepoint'].values


pca_df['Batch']=0
# pca_df[pca_df.index<15]['Batch']=1
# pca_df['Reactor'] = df['Reactor'].values
pca_df.loc[pca_df.index <= 17, 'Batch'] = 1
pca_df.loc[pca_df.index > 17, 'Batch'] = 2
plot_pca(pca_df, explained_variance,title='pca_redox_condition')

# %% [markdown]
# # Differential Expression of Global Prot.

# %% [markdown]
# ## Compare Control late vs early.

# %%
# grab the redox data. 
prot = annotated_redox[sample_ids_prot_redox]
prot['Protein'] = annotated_redox['Protein']
prot['ProteinID'] = annotated_redox['Protein'].copy()
prot.index = annotated_redox['Site']

# drop oscillations, low. 
prot_control_late_vs_early_combined = prot.drop(prot.columns[prot.columns.str.contains("Oscillation|Low")], axis=1)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/3664270755.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prot['Protein'] = annotated_redox['Protein']
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/3664270755.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prot['ProteinID'] = annotated_redox['Protein'].copy()

# %%
prot_control_late_vs_early_combined.columns
# Out:
# Index(['Biostat2L_30_Control_3.5', 'Biostat2L_30_Control_4.5',
#        'Biostat2L_30_Control_5.5', 'Biostat2L_30_Control_24',
#        'Biostat2L_30_Control_48', 'Biostat2L_30_Control_72',
#        'Biostat2L_31_Control_3.5', 'Biostat2L_31_Control_4.5',
#        'Biostat2L_31_Control_5.5', 'Biostat2L_31_Control_24',
#        'Biostat2L_31_Control_48', 'Biostat2L_31_Control_72',
#        'Biostat2L_32_Control_3.5', 'Biostat2L_32_Control_4.5',
#        'Biostat2L_32_Control_5.5', 'Biostat2L_32_Control_24',
#        'Biostat2L_32_Control_48', 'Biostat2L_32_Control_72', 'Protein',
#        'ProteinID'],
#       dtype='object')

# %%
prot_control_late_vs_early_combined.head()
# Out:
#                           Biostat2L_30_Control_3.5  Biostat2L_30_Control_4.5  \
# Site
# jgi|YarliW29_1|1000@C503                 16.792441                 16.258855
# jgi|YarliW29_1|1002@C352                 18.877320                 19.745658
# jgi|YarliW29_1|1002@C430                 14.773199                 14.823748
# jgi|YarliW29_1|1002@C55                  18.424198                 18.487841
# jgi|YarliW29_1|1002@C614                 15.784976                 15.481521
#
#                           Biostat2L_30_Control_5.5  Biostat2L_30_Control_24  \
# Site
# jgi|YarliW29_1|1000@C503                 16.392205                17.457152
# jgi|YarliW29_1|1002@C352                 18.694869                19.717296
# jgi|YarliW29_1|1002@C430                 14.860266                15.879484
# jgi|YarliW29_1|1002@C55                  18.562002                18.874312
# jgi|YarliW29_1|1002@C614                 15.453148                17.278106
#
#                           Biostat2L_30_Control_48  Biostat2L_30_Control_72  \
# Site
# jgi|YarliW29_1|1000@C503                17.893231                18.139734
# jgi|YarliW29_1|1002@C352                18.925732                19.799532
# jgi|YarliW29_1|1002@C430                15.917200                16.575859
# jgi|YarliW29_1|1002@C55                 19.007607                19.145622
# jgi|YarliW29_1|1002@C614                17.453021                17.570320
#
#                           Biostat2L_31_Control_3.5  Biostat2L_31_Control_4.5  \
# Site
# jgi|YarliW29_1|1000@C503                 16.713413                 16.506901
# jgi|YarliW29_1|1002@C352                 19.781442                 18.765620
# jgi|YarliW29_1|1002@C430                 14.684933                 14.533579
# jgi|YarliW29_1|1002@C55                  18.401798                 18.542063
# jgi|YarliW29_1|1002@C614                 15.389383                 15.218174
#
#                           Biostat2L_31_Control_5.5  Biostat2L_31_Control_24  \
# Site
# jgi|YarliW29_1|1000@C503                 16.430372                17.551684
# jgi|YarliW29_1|1002@C352                 19.711690                18.844664
# jgi|YarliW29_1|1002@C430                 14.384753                15.988922
# jgi|YarliW29_1|1002@C55                  18.412196                19.174561
# jgi|YarliW29_1|1002@C614                 15.477929                17.479830
#
#                           Biostat2L_31_Control_48  Biostat2L_31_Control_72  \
# Site
# jgi|YarliW29_1|1000@C503                17.772679                18.088275
# jgi|YarliW29_1|1002@C352                19.605383                18.915459
# jgi|YarliW29_1|1002@C430                15.670962                16.244652
# jgi|YarliW29_1|1002@C55                 19.139245                19.094474
# jgi|YarliW29_1|1002@C614                17.775941                17.858263
#
#                           Biostat2L_32_Control_3.5  Biostat2L_32_Control_4.5  \
# Site
# jgi|YarliW29_1|1000@C503                 16.788640                 16.385374
# jgi|YarliW29_1|1002@C352                 18.242943                 19.747221
# jgi|YarliW29_1|1002@C430                 14.894322                 14.801967
# jgi|YarliW29_1|1002@C55                  18.550655                 18.647581
# jgi|YarliW29_1|1002@C614                 15.620329                 15.376883
#
#                           Biostat2L_32_Control_5.5  Biostat2L_32_Control_24  \
# Site
# jgi|YarliW29_1|1000@C503                 16.694972                17.514607
# jgi|YarliW29_1|1002@C352                 18.412562                19.727180
# jgi|YarliW29_1|1002@C430                 14.884362                15.976270
# jgi|YarliW29_1|1002@C55                  18.640002                18.658341
# jgi|YarliW29_1|1002@C614                 15.459093                17.354568
#
#                           Biostat2L_32_Control_48  Biostat2L_32_Control_72  \
# Site
# jgi|YarliW29_1|1000@C503                17.751886                18.596925
# jgi|YarliW29_1|1002@C352                18.980346                19.595083
# jgi|YarliW29_1|1002@C430                15.809801                16.888492
# jgi|YarliW29_1|1002@C55                 18.861431                19.566815
# jgi|YarliW29_1|1002@C614                17.347667                17.954387
#
#                                       Protein            ProteinID
# Site
# jgi|YarliW29_1|1000@C503  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000
# jgi|YarliW29_1|1002@C352  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# jgi|YarliW29_1|1002@C430  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# jgi|YarliW29_1|1002@C55   jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# jgi|YarliW29_1|1002@C614  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002

# %%
# prot_timepoint_dict initialized in annotation section. 
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))

# %% [markdown]
# ### Prep for p-values.

# %%
# group for mapping in nanova. 
condition_series = pd.Series(prot_control_late_vs_early_combined.columns).map(prot_timepoint_dict)
condition_series.index = prot_control_late_vs_early_combined.columns
condition_series
# Out:
# Biostat2L_30_Control_3.5    Early
# Biostat2L_30_Control_4.5    Early
# Biostat2L_30_Control_5.5    Early
# Biostat2L_30_Control_24      Late
# Biostat2L_30_Control_48      Late
# Biostat2L_30_Control_72      Late
# Biostat2L_31_Control_3.5    Early
# Biostat2L_31_Control_4.5    Early
# Biostat2L_31_Control_5.5    Early
# Biostat2L_31_Control_24      Late
# Biostat2L_31_Control_48      Late
# Biostat2L_31_Control_72      Late
# Biostat2L_32_Control_3.5    Early
# Biostat2L_32_Control_4.5    Early
# Biostat2L_32_Control_5.5    Early
# Biostat2L_32_Control_24      Late
# Biostat2L_32_Control_48      Late
# Biostat2L_32_Control_72      Late
# Protein                       NaN
# ProteinID                     NaN
# dtype: object

# %%
# calculate p-values. 
prot_control_late_vs_early_combined_stats = global_stats_calc_prot(prot_control_late_vs_early_combined,condition_series)

# %%
prot_control_late_vs_early_combined_stats
# Out:
#                           Site  Biostat2L_30_Control_3.5  \
# 0     jgi|YarliW29_1|1000@C503                 16.792441
# 1     jgi|YarliW29_1|1002@C352                 18.877320
# 2     jgi|YarliW29_1|1002@C430                 14.773199
# 3      jgi|YarliW29_1|1002@C55                 18.424198
# 4     jgi|YarliW29_1|1002@C614                 15.784976
# ...                        ...                       ...
# 5223   jgi|YarliW29_1|994@C695                 14.443583
# 5224   jgi|YarliW29_1|994@C850                 17.878485
# 5225    jgi|YarliW29_1|99@C106                 17.172607
# 5226     jgi|YarliW29_1|99@C21                 12.721381
# 5227     jgi|YarliW29_1|99@C94                 17.227978
#
#       Biostat2L_30_Control_4.5  Biostat2L_30_Control_5.5  \
# 0                    16.258855                 16.392205
# 1                    19.745658                 18.694869
# 2                    14.823748                 14.860266
# 3                    18.487841                 18.562002
# 4                    15.481521                 15.453148
# ...                        ...                       ...
# 5223                 14.875364                 14.918543
# 5224                 17.990065                 17.893468
# 5225                 17.055208                 17.161644
# 5226                 13.151161                 12.944366
# 5227                 16.204791                 16.979734
#
#       Biostat2L_30_Control_24  Biostat2L_30_Control_48  \
# 0                   17.457152                17.893231
# 1                   19.717296                18.925732
# 2                   15.879484                15.917200
# 3                   18.874312                19.007607
# 4                   17.278106                17.453021
# ...                       ...                      ...
# 5223                16.117669                16.659739
# 5224                17.696625                18.457670
# 5225                18.368031                18.053318
# 5226                14.683138                15.053006
# 5227                18.005775                18.445894
#
#       Biostat2L_30_Control_72  Biostat2L_31_Control_3.5  \
# 0                   18.139734                 16.713413
# 1                   19.799532                 19.781442
# 2                   16.575859                 14.684933
# 3                   19.145622                 18.401798
# 4                   17.570320                 15.389383
# ...                       ...                       ...
# 5223                17.354592                 14.657209
# 5224                19.254938                 17.754294
# 5225                18.075467                 17.082192
# 5226                15.311879                 12.714920
# 5227                17.872800                 16.459313
#
#       Biostat2L_31_Control_4.5  Biostat2L_31_Control_5.5  ...  \
# 0                    16.506901                 16.430372  ...
# 1                    18.765620                 19.711690  ...
# 2                    14.533579                 14.384753  ...
# 3                    18.542063                 18.412196  ...
# 4                    15.218174                 15.477929  ...
# ...                        ...                       ...  ...
# 5223                 14.196521                 14.984696  ...
# 5224                 17.793360                 17.787611  ...
# 5225                 17.124442                 17.226790  ...
# 5226                 12.922347                 12.667190  ...
# 5227                 17.050352                 15.976667  ...
#
#       Biostat2L_32_Control_3.5  Biostat2L_32_Control_4.5  \
# 0                    16.788640                 16.385374
# 1                    18.242943                 19.747221
# 2                    14.894322                 14.801967
# 3                    18.550655                 18.647581
# 4                    15.620329                 15.376883
# ...                        ...                       ...
# 5223                 14.986476                 14.999868
# 5224                 17.847158                 17.920440
# 5225                 17.140785                 17.249458
# 5226                 13.352763                 13.339111
# 5227                 17.131286                 16.357242
#
#       Biostat2L_32_Control_5.5  Biostat2L_32_Control_24  \
# 0                    16.694972                17.514607
# 1                    18.412562                19.727180
# 2                    14.884362                15.976270
# 3                    18.640002                18.658341
# 4                    15.459093                17.354568
# ...                        ...                      ...
# 5223                 15.484344                16.412921
# 5224                 17.891766                17.847518
# 5225                 17.289880                18.573609
# 5226                 13.124356                14.923493
# 5227                 17.178532                18.459408
#
#       Biostat2L_32_Control_48  Biostat2L_32_Control_72              Protein  \
# 0                   17.751886                18.596925  jgi|YarliW29_1|1000
# 1                   18.980346                19.595083  jgi|YarliW29_1|1002
# 2                   15.809801                16.888492  jgi|YarliW29_1|1002
# 3                   18.861431                19.566815  jgi|YarliW29_1|1002
# 4                   17.347667                17.954387  jgi|YarliW29_1|1002
# ...                       ...                      ...                  ...
# 5223                16.519977                17.604168   jgi|YarliW29_1|994
# 5224                18.499076                19.673688   jgi|YarliW29_1|994
# 5225                18.255087                18.298690    jgi|YarliW29_1|99
# 5226                14.749682                15.285843    jgi|YarliW29_1|99
# 5227                18.516324                18.101758    jgi|YarliW29_1|99
#
#                 ProteinID       ANOVA_p    ANOVA_padj
# 0     jgi|YarliW29_1|1000  6.002670e-08  1.718573e-07
# 1     jgi|YarliW29_1|1002  3.612753e-01  3.685403e-01
# 2     jgi|YarliW29_1|1002  5.504471e-08  1.603170e-07
# 3     jgi|YarliW29_1|1002  2.051635e-05  2.940152e-05
# 4     jgi|YarliW29_1|1002  2.996224e-13  7.454891e-12
# ...                   ...           ...           ...
# 5223   jgi|YarliW29_1|994  1.483949e-07  3.754786e-07
# 5224   jgi|YarliW29_1|994  1.751333e-02  1.871312e-02
# 5225    jgi|YarliW29_1|99  1.304693e-10  9.697040e-10
# 5226    jgi|YarliW29_1|99  5.474094e-12  7.586774e-11
# 5227    jgi|YarliW29_1|99  1.870225e-06  3.442031e-06
#
# [5228 rows x 23 columns]

# %%
# Extract the number between "YarliW29_1|" and "@GLB" using regex
prot_control_late_vs_early_combined_stats["proteinID"] = prot_control_late_vs_early_combined_stats["Site"].str.extract(r"YarliW29_1\|(\d+)@")

# Convert the extracted number to integer (if needed)
prot_control_late_vs_early_combined_stats["proteinID"] = prot_control_late_vs_early_combined_stats["proteinID"].astype(int)

# %%
prot_control_late_vs_early_combined_stats
# Out:
#                           Site  Biostat2L_30_Control_3.5  \
# 0     jgi|YarliW29_1|1000@C503                 16.792441
# 1     jgi|YarliW29_1|1002@C352                 18.877320
# 2     jgi|YarliW29_1|1002@C430                 14.773199
# 3      jgi|YarliW29_1|1002@C55                 18.424198
# 4     jgi|YarliW29_1|1002@C614                 15.784976
# ...                        ...                       ...
# 5223   jgi|YarliW29_1|994@C695                 14.443583
# 5224   jgi|YarliW29_1|994@C850                 17.878485
# 5225    jgi|YarliW29_1|99@C106                 17.172607
# 5226     jgi|YarliW29_1|99@C21                 12.721381
# 5227     jgi|YarliW29_1|99@C94                 17.227978
#
#       Biostat2L_30_Control_4.5  Biostat2L_30_Control_5.5  \
# 0                    16.258855                 16.392205
# 1                    19.745658                 18.694869
# 2                    14.823748                 14.860266
# 3                    18.487841                 18.562002
# 4                    15.481521                 15.453148
# ...                        ...                       ...
# 5223                 14.875364                 14.918543
# 5224                 17.990065                 17.893468
# 5225                 17.055208                 17.161644
# 5226                 13.151161                 12.944366
# 5227                 16.204791                 16.979734
#
#       Biostat2L_30_Control_24  Biostat2L_30_Control_48  \
# 0                   17.457152                17.893231
# 1                   19.717296                18.925732
# 2                   15.879484                15.917200
# 3                   18.874312                19.007607
# 4                   17.278106                17.453021
# ...                       ...                      ...
# 5223                16.117669                16.659739
# 5224                17.696625                18.457670
# 5225                18.368031                18.053318
# 5226                14.683138                15.053006
# 5227                18.005775                18.445894
#
#       Biostat2L_30_Control_72  Biostat2L_31_Control_3.5  \
# 0                   18.139734                 16.713413
# 1                   19.799532                 19.781442
# 2                   16.575859                 14.684933
# 3                   19.145622                 18.401798
# 4                   17.570320                 15.389383
# ...                       ...                       ...
# 5223                17.354592                 14.657209
# 5224                19.254938                 17.754294
# 5225                18.075467                 17.082192
# 5226                15.311879                 12.714920
# 5227                17.872800                 16.459313
#
#       Biostat2L_31_Control_4.5  Biostat2L_31_Control_5.5  ...  \
# 0                    16.506901                 16.430372  ...
# 1                    18.765620                 19.711690  ...
# 2                    14.533579                 14.384753  ...
# 3                    18.542063                 18.412196  ...
# 4                    15.218174                 15.477929  ...
# ...                        ...                       ...  ...
# 5223                 14.196521                 14.984696  ...
# 5224                 17.793360                 17.787611  ...
# 5225                 17.124442                 17.226790  ...
# 5226                 12.922347                 12.667190  ...
# 5227                 17.050352                 15.976667  ...
#
#       Biostat2L_32_Control_4.5  Biostat2L_32_Control_5.5  \
# 0                    16.385374                 16.694972
# 1                    19.747221                 18.412562
# 2                    14.801967                 14.884362
# 3                    18.647581                 18.640002
# 4                    15.376883                 15.459093
# ...                        ...                       ...
# 5223                 14.999868                 15.484344
# 5224                 17.920440                 17.891766
# 5225                 17.249458                 17.289880
# 5226                 13.339111                 13.124356
# 5227                 16.357242                 17.178532
#
#       Biostat2L_32_Control_24  Biostat2L_32_Control_48  \
# 0                   17.514607                17.751886
# 1                   19.727180                18.980346
# 2                   15.976270                15.809801
# 3                   18.658341                18.861431
# 4                   17.354568                17.347667
# ...                       ...                      ...
# 5223                16.412921                16.519977
# 5224                17.847518                18.499076
# 5225                18.573609                18.255087
# 5226                14.923493                14.749682
# 5227                18.459408                18.516324
#
#       Biostat2L_32_Control_72              Protein            ProteinID  \
# 0                   18.596925  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000
# 1                   19.595083  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 2                   16.888492  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 3                   19.566815  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 4                   17.954387  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# ...                       ...                  ...                  ...
# 5223                17.604168   jgi|YarliW29_1|994   jgi|YarliW29_1|994
# 5224                19.673688   jgi|YarliW29_1|994   jgi|YarliW29_1|994
# 5225                18.298690    jgi|YarliW29_1|99    jgi|YarliW29_1|99
# 5226                15.285843    jgi|YarliW29_1|99    jgi|YarliW29_1|99
# 5227                18.101758    jgi|YarliW29_1|99    jgi|YarliW29_1|99
#
#            ANOVA_p    ANOVA_padj proteinID
# 0     6.002670e-08  1.718573e-07      1000
# 1     3.612753e-01  3.685403e-01      1002
# 2     5.504471e-08  1.603170e-07      1002
# 3     2.051635e-05  2.940152e-05      1002
# 4     2.996224e-13  7.454891e-12      1002
# ...            ...           ...       ...
# 5223  1.483949e-07  3.754786e-07       994
# 5224  1.751333e-02  1.871312e-02       994
# 5225  1.304693e-10  9.697040e-10        99
# 5226  5.474094e-12  7.586774e-11        99
# 5227  1.870225e-06  3.442031e-06        99
#
# [5228 rows x 24 columns]

# %%
prot_control_late_vs_early_combined_stats.head()
# Out:
#                        Site  Biostat2L_30_Control_3.5  \
# 0  jgi|YarliW29_1|1000@C503                 16.792441
# 1  jgi|YarliW29_1|1002@C352                 18.877320
# 2  jgi|YarliW29_1|1002@C430                 14.773199
# 3   jgi|YarliW29_1|1002@C55                 18.424198
# 4  jgi|YarliW29_1|1002@C614                 15.784976
#
#    Biostat2L_30_Control_4.5  Biostat2L_30_Control_5.5  \
# 0                 16.258855                 16.392205
# 1                 19.745658                 18.694869
# 2                 14.823748                 14.860266
# 3                 18.487841                 18.562002
# 4                 15.481521                 15.453148
#
#    Biostat2L_30_Control_24  Biostat2L_30_Control_48  Biostat2L_30_Control_72  \
# 0                17.457152                17.893231                18.139734
# 1                19.717296                18.925732                19.799532
# 2                15.879484                15.917200                16.575859
# 3                18.874312                19.007607                19.145622
# 4                17.278106                17.453021                17.570320
#
#    Biostat2L_31_Control_3.5  Biostat2L_31_Control_4.5  \
# 0                 16.713413                 16.506901
# 1                 19.781442                 18.765620
# 2                 14.684933                 14.533579
# 3                 18.401798                 18.542063
# 4                 15.389383                 15.218174
#
#    Biostat2L_31_Control_5.5  ...  Biostat2L_32_Control_4.5  \
# 0                 16.430372  ...                 16.385374
# 1                 19.711690  ...                 19.747221
# 2                 14.384753  ...                 14.801967
# 3                 18.412196  ...                 18.647581
# 4                 15.477929  ...                 15.376883
#
#    Biostat2L_32_Control_5.5  Biostat2L_32_Control_24  Biostat2L_32_Control_48  \
# 0                 16.694972                17.514607                17.751886
# 1                 18.412562                19.727180                18.980346
# 2                 14.884362                15.976270                15.809801
# 3                 18.640002                18.658341                18.861431
# 4                 15.459093                17.354568                17.347667
#
#    Biostat2L_32_Control_72              Protein            ProteinID  \
# 0                18.596925  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000
# 1                19.595083  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 2                16.888492  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 3                19.566815  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 4                17.954387  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
#
#         ANOVA_p    ANOVA_padj proteinID
# 0  6.002670e-08  1.718573e-07      1000
# 1  3.612753e-01  3.685403e-01      1002
# 2  5.504471e-08  1.603170e-07      1002
# 3  2.051635e-05  2.940152e-05      1002
# 4  2.996224e-13  7.454891e-12      1002
#
# [5 rows x 24 columns]

# %% [markdown]
# ### calculate log2FC

# %%
early = prot_control_late_vs_early_combined_stats.loc[:, prot_control_late_vs_early_combined_stats.columns[prot_control_late_vs_early_combined_stats.columns.str.contains("3.5|4.5|5.5")]]
early.head()

# 24 h
# Out:
#    Biostat2L_30_Control_3.5  Biostat2L_30_Control_4.5  \
# 0                 16.792441                 16.258855
# 1                 18.877320                 19.745658
# 2                 14.773199                 14.823748
# 3                 18.424198                 18.487841
# 4                 15.784976                 15.481521
#
#    Biostat2L_30_Control_5.5  Biostat2L_31_Control_3.5  \
# 0                 16.392205                 16.713413
# 1                 18.694869                 19.781442
# 2                 14.860266                 14.684933
# 3                 18.562002                 18.401798
# 4                 15.453148                 15.389383
#
#    Biostat2L_31_Control_4.5  Biostat2L_31_Control_5.5  \
# 0                 16.506901                 16.430372
# 1                 18.765620                 19.711690
# 2                 14.533579                 14.384753
# 3                 18.542063                 18.412196
# 4                 15.218174                 15.477929
#
#    Biostat2L_32_Control_3.5  Biostat2L_32_Control_4.5  \
# 0                 16.788640                 16.385374
# 1                 18.242943                 19.747221
# 2                 14.894322                 14.801967
# 3                 18.550655                 18.647581
# 4                 15.620329                 15.376883
#
#    Biostat2L_32_Control_5.5
# 0                 16.694972
# 1                 18.412562
# 2                 14.884362
# 3                 18.640002
# 4                 15.459093

# %%
late = prot_control_late_vs_early_combined_stats.loc[:, prot_control_late_vs_early_combined_stats.columns[prot_control_late_vs_early_combined_stats.columns.str.contains("24|48|72")]]
late.head()

# 24 h
# Out:
#    Biostat2L_30_Control_24  Biostat2L_30_Control_48  Biostat2L_30_Control_72  \
# 0                17.457152                17.893231                18.139734
# 1                19.717296                18.925732                19.799532
# 2                15.879484                15.917200                16.575859
# 3                18.874312                19.007607                19.145622
# 4                17.278106                17.453021                17.570320
#
#    Biostat2L_31_Control_24  Biostat2L_31_Control_48  Biostat2L_31_Control_72  \
# 0                17.551684                17.772679                18.088275
# 1                18.844664                19.605383                18.915459
# 2                15.988922                15.670962                16.244652
# 3                19.174561                19.139245                19.094474
# 4                17.479830                17.775941                17.858263
#
#    Biostat2L_32_Control_24  Biostat2L_32_Control_48  Biostat2L_32_Control_72
# 0                17.514607                17.751886                18.596925
# 1                19.727180                18.980346                19.595083
# 2                15.976270                15.809801                16.888492
# 3                18.658341                18.861431                19.566815
# 4                17.354568                17.347667                17.954387

# %%
# gives the increase of the first. 
prot_control_late_vs_early_combined_stats['log2FC']=log2FC_function(early,late)

# %%
df_to_merge = pd.DataFrame()
df_to_merge['early/late'] = prot_control_late_vs_early_combined_stats['log2FC']
df_to_merge['Site'] = prot_control_late_vs_early_combined_stats['Site']
df_to_merge['early/late_ANOVA_padj'] = prot_control_late_vs_early_combined_stats['ANOVA_padj']
df_to_merge['early/late_ANOVA_p'] = prot_control_late_vs_early_combined_stats['ANOVA_p']

# %%
df_to_merge.columns
# Out:
# Index(['early/late', 'Site', 'early/late_ANOVA_padj', 'early/late_ANOVA_p'], dtype='object')

# %%
merged_df = pd.merge(annotated_redox, df_to_merge, left_on='Site',right_on='Site', how='left')

# %%
merged_df.head(20)
# Out:
#                                               Peptide  \
# 0                                      R.IEPIC@AQGR.I
# 1                                     K.VFIGSC@TNSR.I
# 2                                        R.C@ASTSNR.N
# 3                               K.DC@TLATVDHNIPTTTR.K
# 4          K.ASILVVSGDNFGC@GSSR.E; L.VVSGDNFGC@GSSR.E
# 5       K.HC@LVNGLDDIGLTM*QK.E; K.HC@LVNGLDDIGLTMQK.E
# 6                                    R.LQC@TTLEQNVK.D
# 7                                         R.NADC@DK.L
# 8           K.KVEASPLVDC@SVLAR.G; K.VEASPLVDC@SVLAR.G
# 9                                      R.VDVC@M*GGK.I
# 10  E.YYRPM*AC@GEGGYPAVITPEEC@DK.M; M.AC@GEGGYPAVI...
# 11  E.YYRPM*AC@GEGGYPAVITPEEC@DK.M; M.AC@GEGGYPAVI...
# 12                                       R.DVPKC@QR.L
# 13  L.VDLC@YSTNNR.I; R.LVDLC@YST.N; R.LVDLC@YSTN.N...
# 14  R.IAC@VAPN.F; R.IAC@VAPNF.Y; R.IAC@VAPNFY.C; R...
# 15  N.FYC@NAVTM*GAYQQTGR.N; N.FYC@NAVTMGAYQQTGR.N;...
# 16  R.EQC@GDSDLC@YE.Q; R.EQC@GDSDLC@YEQED.W; R.EQC...
# 17  R.EQC@GDSDLC@YE.Q; R.EQC@GDSDLC@YEQED.W; R.EQC...
# 18  A.IGAEVEVFEGC@K.N; E.VEVFEGC@K.N; E.VFEGC@K.N;...
# 19        K.LNGGLGTSM*GC@VGPK.S; K.LNGGLGTSMGC@VGPK.S
#
#                         Site              UniProt              Protein  \
# 0   jgi|YarliW29_1|1000@C503  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000
# 1   jgi|YarliW29_1|1002@C352  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 2   jgi|YarliW29_1|1002@C430  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 3    jgi|YarliW29_1|1002@C55  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 4   jgi|YarliW29_1|1002@C614  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 5   jgi|YarliW29_1|1002@C704  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 6    jgi|YarliW29_1|1002@C88  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 7   jgi|YarliW29_1|1003@C116  jgi|YarliW29_1|1003  jgi|YarliW29_1|1003
# 8   jgi|YarliW29_1|1003@C417  jgi|YarliW29_1|1003  jgi|YarliW29_1|1003
# 9   jgi|YarliW29_1|1003@C540  jgi|YarliW29_1|1003  jgi|YarliW29_1|1003
# 10  jgi|YarliW29_1|1004@C317  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 11  jgi|YarliW29_1|1004@C331  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 12  jgi|YarliW29_1|1004@C341  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 13  jgi|YarliW29_1|1004@C348  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 14  jgi|YarliW29_1|1004@C357  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 15  jgi|YarliW29_1|1004@C364  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 16  jgi|YarliW29_1|1004@C386  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 17  jgi|YarliW29_1|1004@C392  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 18  jgi|YarliW29_1|1004@C422  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 19   jgi|YarliW29_1|100@C116   jgi|YarliW29_1|100   jgi|YarliW29_1|100
#
#    Residue                        id  Total missingness  \
# 0     C503  jgi|YarliW29_1|1000@C503                  0
# 1     C352  jgi|YarliW29_1|1002@C352                  0
# 2     C430  jgi|YarliW29_1|1002@C430                 36
# 3      C55   jgi|YarliW29_1|1002@C55                  0
# 4     C614  jgi|YarliW29_1|1002@C614                  0
# 5     C704  jgi|YarliW29_1|1002@C704                  0
# 6      C88   jgi|YarliW29_1|1002@C88                  0
# 7     C116  jgi|YarliW29_1|1003@C116                 18
# 8     C417  jgi|YarliW29_1|1003@C417                  0
# 9     C540  jgi|YarliW29_1|1003@C540                 36
# 10    C317  jgi|YarliW29_1|1004@C317                  0
# 11    C331  jgi|YarliW29_1|1004@C331                  0
# 12    C341  jgi|YarliW29_1|1004@C341                  0
# 13    C348  jgi|YarliW29_1|1004@C348                  0
# 14    C357  jgi|YarliW29_1|1004@C357                  0
# 15    C364  jgi|YarliW29_1|1004@C364                  0
# 16    C386  jgi|YarliW29_1|1004@C386                 18
# 17    C392  jgi|YarliW29_1|1004@C392                 18
# 18    C422  jgi|YarliW29_1|1004@C422                  0
# 19    C116   jgi|YarliW29_1|100@C116                  0
#
#     Oscillation_24 missingness  Oscillation_3.5 missingness  \
# 0                            0                            0
# 1                            0                            0
# 2                            3                            3
# 3                            0                            0
# 4                            0                            0
# 5                            0                            0
# 6                            0                            0
# 7                            3                            3
# 8                            0                            0
# 9                            3                            3
# 10                           0                            0
# 11                           0                            0
# 12                           0                            0
# 13                           0                            0
# 14                           0                            0
# 15                           0                            0
# 16                           0                            0
# 17                           0                            0
# 18                           0                            0
# 19                           0                            0
#
#     Oscillation_4.5 missingness  ...  Oscillation_48/Oscillation_3.5_adj-p  \
# 0                             0  ...                              0.001042
# 1                             0  ...                              0.280174
# 2                             3  ...                                   NaN
# 3                             0  ...                              0.015009
# 4                             0  ...                              0.002500
# 5                             0  ...                              0.002118
# 6                             0  ...                              0.008951
# 7                             3  ...                                   NaN
# 8                             0  ...                              0.019341
# 9                             3  ...                                   NaN
# 10                            0  ...                              0.002431
# 11                            0  ...                              0.003414
# 12                            0  ...                              0.093202
# 13                            0  ...                              0.368484
# 14                            0  ...                              0.725610
# 15                            0  ...                              0.093079
# 16                            0  ...                              0.010450
# 17                            0  ...                              0.010450
# 18                            0  ...                              0.002311
# 19                            0  ...                              0.011983
#
#     Oscillation_72/Oscillation_3.5  Oscillation_72/Oscillation_3.5_pval  \
# 0                         1.937960                             0.000041
# 1                         0.273868                             0.235540
# 2                              NaN                                  NaN
# 3                         1.852336                             0.000728
# 4                         3.240543                             0.000032
# 5                         3.215732                             0.000437
# 6                         1.970878                             0.001284
# 7                              NaN                                  NaN
# 8                         1.945102                             0.024278
# 9                              NaN                                  NaN
# 10                        0.594436                             0.001426
# 11                        0.643914                             0.002154
# 12                        0.961789                             0.026705
# 13                        0.279743                             0.378353
# 14                        0.021689                             0.829465
# 15                       -0.122319                             0.210728
# 16                       -1.293868                             0.003419
# 17                       -1.293868                             0.003419
# 18                        1.670029                             0.000277
# 19                        1.636002                             0.006229
#
#     Oscillation_72/Oscillation_3.5_adj-p  Type  Experiment  site_number  \
# 0                               0.000449    Ox         PTM            1
# 1                               0.248877    Ox         PTM            8
# 2                                    NaN    Ox         PTM            8
# 3                               0.002182    Ox         PTM            8
# 4                               0.000423    Ox         PTM            8
# 5                               0.001563    Ox         PTM            8
# 6                               0.003183    Ox         PTM            8
# 7                                    NaN    Ox         PTM            3
# 8                               0.030882    Ox         PTM            3
# 9                                    NaN    Ox         PTM            3
# 10                              0.003411    Ox         PTM            9
# 11                              0.004593    Ox         PTM            9
# 12                              0.033571    Ox         PTM            9
# 13                              0.391639    Ox         PTM            9
# 14                              0.836249    Ox         PTM            9
# 15                              0.223706    Ox         PTM            9
# 16                              0.006369    Ox         PTM            9
# 17                              0.006369    Ox         PTM            9
# 18                              0.001177    Ox         PTM            9
# 19                              0.010161    Ox         PTM            5
#
#     early/late  early/late_ANOVA_padj  early/late_ANOVA_p
# 0    -1.311444           1.718573e-07        6.002670e-08
# 1    -0.236817           3.685403e-01        3.612753e-01
# 2    -1.367835           1.603170e-07        5.504471e-08
# 3    -0.539341           2.940152e-05        2.051635e-05
# 4    -2.090074           7.454891e-12        2.996224e-13
# 5    -2.704643           1.950483e-12        4.456987e-14
# 6    -2.275029           2.310453e-12        5.969592e-14
# 7    -1.864124           2.935036e-05        2.045819e-05
# 8    -1.492496           7.851495e-07        3.498739e-07
# 9    -2.270989           2.889671e-10        2.886906e-11
# 10   -0.481519           5.548168e-07        2.335009e-07
# 11   -0.620590           9.848723e-08        3.096324e-08
# 12   -0.882754           6.201625e-06        3.629582e-06
# 13   -0.265251           2.889434e-06        1.541769e-06
# 14   -0.065797           6.168141e-02        5.883639e-02
# 15   -0.126694           8.534924e-03        7.863564e-03
# 16    0.883627           1.464589e-07        4.963743e-08
# 17    0.883627           1.464589e-07        4.963743e-08
# 18   -2.235629           1.142856e-10        9.099103e-12
# 19   -2.140330           2.728947e-09        4.455104e-10
#
# [20 rows x 173 columns]

# %%
prot_control_late_vs_early_combined_stats_withAnnote = pd.merge(prot_control_late_vs_early_combined_stats, merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')

# %% [markdown]
# ### optional save.

# %%
# prot_control_late_vs_early_combined_stats_withAnnote.to_csv('early_vs_late.csv')

# %% [markdown]
# ### Volcano plot comparing late vs early.
# all late (increase means increased in low)

# %%
dataset = prot_control_late_vs_early_combined_stats_withAnnote[['log2FC', 'ANOVA_padj']].copy()
dataset.index = prot_control_late_vs_early_combined_stats_withAnnote.Site

# %%
log2FC_threshold = np.log2(1.3)

# %%
dataset
# Out:
#                             log2FC    ANOVA_padj
# Site
# jgi|YarliW29_1|1000@C503 -1.311444  1.718573e-07
# jgi|YarliW29_1|1002@C352 -0.236817  3.685403e-01
# jgi|YarliW29_1|1002@C430 -1.367835  1.603170e-07
# jgi|YarliW29_1|1002@C55  -0.539341  2.940152e-05
# jgi|YarliW29_1|1002@C614 -2.090074  7.454891e-12
# ...                            ...           ...
# jgi|YarliW29_1|994@C695  -1.884119  3.754786e-07
# jgi|YarliW29_1|994@C850  -0.654562  1.871312e-02
# jgi|YarliW29_1|99@C106   -1.147937  9.697040e-10
# jgi|YarliW29_1|99@C21    -2.022789  7.586774e-11
# jgi|YarliW29_1|99@C94    -1.612527  3.442031e-06
#
# [5228 rows x 2 columns]

# %%
# subset the log2FC and the P_value for this dataset. 
dataset.columns = ['log2FC','P_value']

# obtain the -logP_adj for the dataset. 
dataset['-logP_adj'] = -np.log10(dataset['P_value'])

# set a class for up (1) or down (-1) proteins. 
dataset['class'] = 0
dataset.loc[(dataset['log2FC']>log2FC_threshold)&(dataset['-logP_adj']>-np.log10(0.05)),'class'] = 1
dataset.loc[(dataset['log2FC']<-log2FC_threshold)&(dataset['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
volcano_plot(dataset)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/1246007795.py:202: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_min = df.min()[0]-1
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/1246007795.py:203: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_max = df.max()[0]+1
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/1246007795.py:206: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_max = dataset.max()[2]+1

# %% [markdown]
# ## Compare Control vs low.

# %%
prot = annotated_redox[sample_ids_prot_redox]
prot['Protein'] = annotated_redox['Site']
prot.index = annotated_redox['Site']
# drop oscillations.
prot_control_vs_low_late_combined = prot.drop(prot.columns[prot.columns.str.contains("Oscillation")], axis=1)
# prot_control_vs_oscillation_late_combined = prot.drop(prot.columns[prot.columns.str.contains("Low")], axis=1)
prot_control_vs_low_24h = prot.drop(prot.columns[prot.columns.str.contains("Oscillation")], axis=1)


# drop early timepoints. 
prot_control_vs_low_late_combined = prot_control_vs_low_late_combined.drop(prot_control_vs_low_late_combined.columns[
    prot_control_vs_low_late_combined.columns.str.contains("5.5|3.5|4.5")], axis=1)

# prot_control_vs_low_24h = prot_control_vs_low_24h.drop(prot_control_vs_low_24h.columns[
#     prot_control_vs_low_24h.columns.str.contains("5.5|3.5|4.5|48|72")], axis=1)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/696267827.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prot['Protein'] = annotated_redox['Site']

# %%
prot_control_vs_low_late_combined.columns
# Out:
# Index(['Biostat2L_30_Control_24', 'Biostat2L_30_Control_48',
#        'Biostat2L_30_Control_72', 'Biostat2L_31_Control_24',
#        'Biostat2L_31_Control_48', 'Biostat2L_31_Control_72',
#        'Biostat2L_32_Control_24', 'Biostat2L_32_Control_48',
#        'Biostat2L_32_Control_72', 'Biostat2L_32_Low_24', 'Biostat2L_32_Low_48',
#        'Biostat2L_32_Low_72', 'Biostat2L_33_Low_24', 'Biostat2L_33_Low_48',
#        'Biostat2L_33_Low_72', 'Biostat2L_34_Low_24', 'Biostat2L_34_Low_48',
#        'Biostat2L_34_Low_72', 'Protein'],
#       dtype='object')

# %%
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))

# %% [markdown]
# ### Prep for p-values.

# %%
# group for mapping in nanova. 
condition_series = pd.Series(prot_control_vs_low_late_combined.columns).map(prot_condition_dict)
condition_series.index = prot_control_vs_low_late_combined.columns
condition_series 

condition_series24h = pd.Series(prot_control_vs_low_24h.columns).map(prot_condition_dict)
condition_series24h.index = prot_control_vs_low_24h.columns
condition_series24h
# Out:
# Biostat2L_30_Control_3.5    Control
# Biostat2L_30_Control_4.5    Control
# Biostat2L_30_Control_5.5    Control
# Biostat2L_30_Control_24     Control
# Biostat2L_30_Control_48     Control
# Biostat2L_30_Control_72     Control
# Biostat2L_31_Control_3.5    Control
# Biostat2L_31_Control_4.5    Control
# Biostat2L_31_Control_5.5    Control
# Biostat2L_31_Control_24     Control
# Biostat2L_31_Control_48     Control
# Biostat2L_31_Control_72     Control
# Biostat2L_32_Control_3.5    Control
# Biostat2L_32_Control_4.5    Control
# Biostat2L_32_Control_5.5    Control
# Biostat2L_32_Control_24     Control
# Biostat2L_32_Control_48     Control
# Biostat2L_32_Control_72     Control
# Biostat2L_32_Low_3.5            Low
# Biostat2L_32_Low_4.5            Low
# Biostat2L_32_Low_5.5            Low
# Biostat2L_32_Low_24             Low
# Biostat2L_32_Low_48             Low
# Biostat2L_32_Low_72             Low
# Biostat2L_33_Low_3.5            Low
# Biostat2L_33_Low_4.5            Low
# Biostat2L_33_Low_5.5            Low
# Biostat2L_33_Low_24             Low
# Biostat2L_33_Low_48             Low
# Biostat2L_33_Low_72             Low
# Biostat2L_34_Low_3.5            Low
# Biostat2L_34_Low_4.5            Low
# Biostat2L_34_Low_5.5            Low
# Biostat2L_34_Low_24             Low
# Biostat2L_34_Low_48             Low
# Biostat2L_34_Low_72             Low
# Protein                         NaN
# dtype: object

# %%
prot.head()
# Out:
#                           Biostat2L_29_Oscillation_3.5  \
# Site
# jgi|YarliW29_1|1000@C503                     16.846811
# jgi|YarliW29_1|1002@C352                     19.436363
# jgi|YarliW29_1|1002@C430                           NaN
# jgi|YarliW29_1|1002@C55                      18.252694
# jgi|YarliW29_1|1002@C614                     15.896053
#
#                           Biostat2L_29_Oscillation_4.5  \
# Site
# jgi|YarliW29_1|1000@C503                     16.562889
# jgi|YarliW29_1|1002@C352                     19.469720
# jgi|YarliW29_1|1002@C430                           NaN
# jgi|YarliW29_1|1002@C55                      18.286464
# jgi|YarliW29_1|1002@C614                     15.358501
#
#                           Biostat2L_29_Oscillation_5.5  \
# Site
# jgi|YarliW29_1|1000@C503                     16.827315
# jgi|YarliW29_1|1002@C352                     19.418304
# jgi|YarliW29_1|1002@C430                           NaN
# jgi|YarliW29_1|1002@C55                      18.422682
# jgi|YarliW29_1|1002@C614                     15.582766
#
#                           Biostat2L_29_Oscillation_24  \
# Site
# jgi|YarliW29_1|1000@C503                    17.771583
# jgi|YarliW29_1|1002@C352                    19.220965
# jgi|YarliW29_1|1002@C430                          NaN
# jgi|YarliW29_1|1002@C55                     19.363283
# jgi|YarliW29_1|1002@C614                    17.383142
#
#                           Biostat2L_29_Oscillation_48  \
# Site
# jgi|YarliW29_1|1000@C503                    18.596711
# jgi|YarliW29_1|1002@C352                    19.952574
# jgi|YarliW29_1|1002@C430                          NaN
# jgi|YarliW29_1|1002@C55                     20.099247
# jgi|YarliW29_1|1002@C614                    18.595572
#
#                           Biostat2L_29_Oscillation_72  \
# Site
# jgi|YarliW29_1|1000@C503                    18.613297
# jgi|YarliW29_1|1002@C352                    19.523283
# jgi|YarliW29_1|1002@C430                          NaN
# jgi|YarliW29_1|1002@C55                     20.247919
# jgi|YarliW29_1|1002@C614                    18.774382
#
#                           Biostat2L_30_Control_3.5  Biostat2L_30_Control_4.5  \
# Site
# jgi|YarliW29_1|1000@C503                 16.792441                 16.258855
# jgi|YarliW29_1|1002@C352                 18.877320                 19.745658
# jgi|YarliW29_1|1002@C430                 14.773199                 14.823748
# jgi|YarliW29_1|1002@C55                  18.424198                 18.487841
# jgi|YarliW29_1|1002@C614                 15.784976                 15.481521
#
#                           Biostat2L_30_Control_5.5  Biostat2L_30_Control_24  \
# Site
# jgi|YarliW29_1|1000@C503                 16.392205                17.457152
# jgi|YarliW29_1|1002@C352                 18.694869                19.717296
# jgi|YarliW29_1|1002@C430                 14.860266                15.879484
# jgi|YarliW29_1|1002@C55                  18.562002                18.874312
# jgi|YarliW29_1|1002@C614                 15.453148                17.278106
#
#                           ...  Biostat2L_33_Low_24  Biostat2L_33_Low_48  \
# Site                      ...
# jgi|YarliW29_1|1000@C503  ...            16.635118            16.142903
# jgi|YarliW29_1|1002@C352  ...            18.321864            19.446600
# jgi|YarliW29_1|1002@C430  ...                  NaN                  NaN
# jgi|YarliW29_1|1002@C55   ...            18.679093            18.578693
# jgi|YarliW29_1|1002@C614  ...            15.447046            16.150221
#
#                           Biostat2L_33_Low_72  Biostat2L_34_Low_3.5  \
# Site
# jgi|YarliW29_1|1000@C503            16.651285             16.641320
# jgi|YarliW29_1|1002@C352            19.953698             19.213165
# jgi|YarliW29_1|1002@C430                  NaN                   NaN
# jgi|YarliW29_1|1002@C55             18.428186             18.354685
# jgi|YarliW29_1|1002@C614            16.877026             15.691573
#
#                           Biostat2L_34_Low_4.5  Biostat2L_34_Low_5.5  \
# Site
# jgi|YarliW29_1|1000@C503             16.532442             16.538504
# jgi|YarliW29_1|1002@C352             18.988372             18.240673
# jgi|YarliW29_1|1002@C430                   NaN                   NaN
# jgi|YarliW29_1|1002@C55              18.568332             18.748328
# jgi|YarliW29_1|1002@C614             15.082033             14.969355
#
#                           Biostat2L_34_Low_24  Biostat2L_34_Low_48  \
# Site
# jgi|YarliW29_1|1000@C503            16.451691            16.481918
# jgi|YarliW29_1|1002@C352            19.104072            19.454477
# jgi|YarliW29_1|1002@C430                  NaN                  NaN
# jgi|YarliW29_1|1002@C55             18.593297            18.424024
# jgi|YarliW29_1|1002@C614            15.920855            16.629091
#
#                           Biostat2L_34_Low_72                   Protein
# Site
# jgi|YarliW29_1|1000@C503            16.782876  jgi|YarliW29_1|1000@C503
# jgi|YarliW29_1|1002@C352            20.131243  jgi|YarliW29_1|1002@C352
# jgi|YarliW29_1|1002@C430                  NaN  jgi|YarliW29_1|1002@C430
# jgi|YarliW29_1|1002@C55             18.238569   jgi|YarliW29_1|1002@C55
# jgi|YarliW29_1|1002@C614            17.021753  jgi|YarliW29_1|1002@C614
#
# [5 rows x 55 columns]

# %%
# calculate p-values. 
prot_control_vs_low_late_combined_stats = global_stats_calc_prot(prot_control_vs_low_late_combined,condition_series)
# prot_control_vs_low_24h_stats = global_stats_calc_prot(prot_control_vs_low_24h,condition_series24h)


# prot_control_vs_oscillation_late_combined_stats = global_stats_calc_prot(prot_control_vs_oscillation_late_combined,condition_series_controlvsOsc )
# prot_control_late_vs_control_early_stats = global_stats_calc_prot(prot_control_late_vs_control_early,condition_series_controlLateVsEarly)

# %%
prot_control_vs_low_late_combined_stats.head()
# Out:
#                        Site  Biostat2L_30_Control_24  Biostat2L_30_Control_48  \
# 0  jgi|YarliW29_1|1000@C503                17.457152                17.893231
# 1  jgi|YarliW29_1|1002@C352                19.717296                18.925732
# 2  jgi|YarliW29_1|1002@C430                15.879484                15.917200
# 3   jgi|YarliW29_1|1002@C55                18.874312                19.007607
# 4  jgi|YarliW29_1|1002@C614                17.278106                17.453021
#
#    Biostat2L_30_Control_72  Biostat2L_31_Control_24  Biostat2L_31_Control_48  \
# 0                18.139734                17.551684                17.772679
# 1                19.799532                18.844664                19.605383
# 2                16.575859                15.988922                15.670962
# 3                19.145622                19.174561                19.139245
# 4                17.570320                17.479830                17.775941
#
#    Biostat2L_31_Control_72  Biostat2L_32_Control_24  Biostat2L_32_Control_48  \
# 0                18.088275                17.514607                17.751886
# 1                18.915459                19.727180                18.980346
# 2                16.244652                15.976270                15.809801
# 3                19.094474                18.658341                18.861431
# 4                17.858263                17.354568                17.347667
#
#    Biostat2L_32_Control_72  ...  Biostat2L_32_Low_72  Biostat2L_33_Low_24  \
# 0                18.596925  ...            16.618327            16.635118
# 1                19.595083  ...            19.958991            18.321864
# 2                16.888492  ...                  NaN                  NaN
# 3                19.566815  ...            18.423242            18.679093
# 4                17.954387  ...            17.253550            15.447046
#
#    Biostat2L_33_Low_48  Biostat2L_33_Low_72  Biostat2L_34_Low_24  \
# 0            16.142903            16.651285            16.451691
# 1            19.446600            19.953698            19.104072
# 2                  NaN                  NaN                  NaN
# 3            18.578693            18.428186            18.593297
# 4            16.150221            16.877026            15.920855
#
#    Biostat2L_34_Low_48  Biostat2L_34_Low_72                   Protein  \
# 0            16.481918            16.782876  jgi|YarliW29_1|1000@C503
# 1            19.454477            20.131243  jgi|YarliW29_1|1002@C352
# 2                  NaN                  NaN  jgi|YarliW29_1|1002@C430
# 3            18.424024            18.238569   jgi|YarliW29_1|1002@C55
# 4            16.629091            17.021753  jgi|YarliW29_1|1002@C614
#
#         ANOVA_p    ANOVA_padj
# 0  3.357202e-08  4.004436e-07
# 1  4.746497e-01  4.965747e-01
# 2           NaN           NaN
# 3  2.505666e-05  6.463768e-05
# 4  6.094821e-05  1.310214e-04
#
# [5 rows x 22 columns]

# %%
# Extract the number between "YarliW29_1|" and "@GLB" using regex
prot_control_vs_low_late_combined_stats["proteinID"] = prot_control_vs_low_late_combined_stats["Site"].str.extract(r"YarliW29_1\|(\d+)@")
# prot_control_vs_low_24h_stats["proteinID"] = prot_control_vs_low_24h_stats["Protein"].str.extract(r"YarliW29_1\|(\d+)@GLB")

# Convert the extracted number to integer (if needed)
prot_control_vs_low_late_combined_stats["proteinID"] = prot_control_vs_low_late_combined_stats["proteinID"].astype(int)
# prot_control_vs_low_24h_stats["proteinID"] = prot_control_vs_low_24h_stats["proteinID"].astype(int)

# %%
prot_control_vs_low_late_combined_stats.head()
# Out:
#                        Site  Biostat2L_30_Control_24  Biostat2L_30_Control_48  \
# 0  jgi|YarliW29_1|1000@C503                17.457152                17.893231
# 1  jgi|YarliW29_1|1002@C352                19.717296                18.925732
# 2  jgi|YarliW29_1|1002@C430                15.879484                15.917200
# 3   jgi|YarliW29_1|1002@C55                18.874312                19.007607
# 4  jgi|YarliW29_1|1002@C614                17.278106                17.453021
#
#    Biostat2L_30_Control_72  Biostat2L_31_Control_24  Biostat2L_31_Control_48  \
# 0                18.139734                17.551684                17.772679
# 1                19.799532                18.844664                19.605383
# 2                16.575859                15.988922                15.670962
# 3                19.145622                19.174561                19.139245
# 4                17.570320                17.479830                17.775941
#
#    Biostat2L_31_Control_72  Biostat2L_32_Control_24  Biostat2L_32_Control_48  \
# 0                18.088275                17.514607                17.751886
# 1                18.915459                19.727180                18.980346
# 2                16.244652                15.976270                15.809801
# 3                19.094474                18.658341                18.861431
# 4                17.858263                17.354568                17.347667
#
#    Biostat2L_32_Control_72  ...  Biostat2L_33_Low_24  Biostat2L_33_Low_48  \
# 0                18.596925  ...            16.635118            16.142903
# 1                19.595083  ...            18.321864            19.446600
# 2                16.888492  ...                  NaN                  NaN
# 3                19.566815  ...            18.679093            18.578693
# 4                17.954387  ...            15.447046            16.150221
#
#    Biostat2L_33_Low_72  Biostat2L_34_Low_24  Biostat2L_34_Low_48  \
# 0            16.651285            16.451691            16.481918
# 1            19.953698            19.104072            19.454477
# 2                  NaN                  NaN                  NaN
# 3            18.428186            18.593297            18.424024
# 4            16.877026            15.920855            16.629091
#
#    Biostat2L_34_Low_72                   Protein       ANOVA_p    ANOVA_padj  \
# 0            16.782876  jgi|YarliW29_1|1000@C503  3.357202e-08  4.004436e-07
# 1            20.131243  jgi|YarliW29_1|1002@C352  4.746497e-01  4.965747e-01
# 2                  NaN  jgi|YarliW29_1|1002@C430           NaN           NaN
# 3            18.238569   jgi|YarliW29_1|1002@C55  2.505666e-05  6.463768e-05
# 4            17.021753  jgi|YarliW29_1|1002@C614  6.094821e-05  1.310214e-04
#
#   proteinID
# 0      1000
# 1      1002
# 2      1002
# 3      1002
# 4      1002
#
# [5 rows x 23 columns]

# %% [markdown]
# ### calculate log2FC

# %%
control = prot_control_vs_low_late_combined_stats.loc[:, prot_control_vs_low_late_combined_stats.columns[prot_control_vs_low_late_combined_stats.columns.str.contains("Control")]]
control.head()

# 24 h
# control24h = prot_control_vs_low_24h_stats.loc[:, prot_control_vs_low_24h_stats.columns[prot_control_vs_low_24h_stats.columns.str.contains("Control")]]
# control24h.head()
# Out:
#    Biostat2L_30_Control_24  Biostat2L_30_Control_48  Biostat2L_30_Control_72  \
# 0                17.457152                17.893231                18.139734
# 1                19.717296                18.925732                19.799532
# 2                15.879484                15.917200                16.575859
# 3                18.874312                19.007607                19.145622
# 4                17.278106                17.453021                17.570320
#
#    Biostat2L_31_Control_24  Biostat2L_31_Control_48  Biostat2L_31_Control_72  \
# 0                17.551684                17.772679                18.088275
# 1                18.844664                19.605383                18.915459
# 2                15.988922                15.670962                16.244652
# 3                19.174561                19.139245                19.094474
# 4                17.479830                17.775941                17.858263
#
#    Biostat2L_32_Control_24  Biostat2L_32_Control_48  Biostat2L_32_Control_72
# 0                17.514607                17.751886                18.596925
# 1                19.727180                18.980346                19.595083
# 2                15.976270                15.809801                16.888492
# 3                18.658341                18.861431                19.566815
# 4                17.354568                17.347667                17.954387

# %%
low = prot_control_vs_low_late_combined_stats.loc[:, prot_control_vs_low_late_combined_stats.columns[
    prot_control_vs_low_late_combined_stats.columns.str.contains("Low")]]
low.head()

# low24h = prot_control_vs_low_24h_stats.loc[:, prot_control_vs_low_24h_stats.columns[
    # prot_control_vs_low_24h_stats.columns.str.contains("Low")]]
# low24h.head()
# Out:
#    Biostat2L_32_Low_24  Biostat2L_32_Low_48  Biostat2L_32_Low_72  \
# 0            16.478083            16.438153            16.618327
# 1            19.358798            19.919088            19.958991
# 2                  NaN                  NaN                  NaN
# 3            18.641459            18.363472            18.423242
# 4            16.104204            16.517260            17.253550
#
#    Biostat2L_33_Low_24  Biostat2L_33_Low_48  Biostat2L_33_Low_72  \
# 0            16.635118            16.142903            16.651285
# 1            18.321864            19.446600            19.953698
# 2                  NaN                  NaN                  NaN
# 3            18.679093            18.578693            18.428186
# 4            15.447046            16.150221            16.877026
#
#    Biostat2L_34_Low_24  Biostat2L_34_Low_48  Biostat2L_34_Low_72
# 0            16.451691            16.481918            16.782876
# 1            19.104072            19.454477            20.131243
# 2                  NaN                  NaN                  NaN
# 3            18.593297            18.424024            18.238569
# 4            15.920855            16.629091            17.021753

# %%
# gives the increase of the first. 
prot_control_vs_low_late_combined_stats['log2FC']=log2FC_function(low,control)
# prot_control_vs_low_24h_stats['log2FC']=log2FC_function(low24h,control24h)

# %%
prot_control_vs_low_late_combined_stats['proteinId'] = prot_control_vs_low_late_combined_stats['proteinID']

# %%
df_to_merge = pd.DataFrame()
df_to_merge['low/control_late_combined'] = prot_control_vs_low_late_combined_stats['log2FC']
df_to_merge['Site'] = prot_control_vs_low_late_combined_stats['Site']
df_to_merge['low/control_late_combined_ANOVA_padj'] = prot_control_vs_low_late_combined_stats['ANOVA_padj']
df_to_merge['low/control_late_combined_ANOVA_p'] = prot_control_vs_low_late_combined_stats['ANOVA_p']

# %%
df_to_merge
# Out:
#       low/control_late_combined                      Site  \
# 0                     -1.342868  jgi|YarliW29_1|1000@C503
# 1                      0.170906  jgi|YarliW29_1|1002@C352
# 2                           NaN  jgi|YarliW29_1|1002@C430
# 3                     -0.572486   jgi|YarliW29_1|1002@C55
# 4                     -1.127900  jgi|YarliW29_1|1002@C614
# ...                         ...                       ...
# 5223                  -0.821914   jgi|YarliW29_1|994@C695
# 5224                  -0.870977   jgi|YarliW29_1|994@C850
# 5225                   0.096414    jgi|YarliW29_1|99@C106
# 5226                  -0.909302     jgi|YarliW29_1|99@C21
# 5227                   0.533244     jgi|YarliW29_1|99@C94
#
#       low/control_late_combined_ANOVA_padj  low/control_late_combined_ANOVA_p
# 0                             4.004436e-07                       3.357202e-08
# 1                             4.965747e-01                       4.746497e-01
# 2                                      NaN                                NaN
# 3                             6.463768e-05                       2.505666e-05
# 4                             1.310214e-04                       6.094821e-05
# ...                                    ...                                ...
# 5223                          3.474731e-03                       2.505825e-03
# 5224                          4.020606e-03                       2.942809e-03
# 5225                          5.861351e-01                       5.656473e-01
# 5226                          9.794836e-04                       6.260458e-04
# 5227                          4.078315e-02                       3.436288e-02
#
# [5228 rows x 4 columns]

# %%
merged_df = pd.merge(merged_df, df_to_merge, left_on='Site',right_on='Site', how='left')

# %%
merged_df.head(20)
# Out:
#                                               Peptide  \
# 0                                      R.IEPIC@AQGR.I
# 1                                     K.VFIGSC@TNSR.I
# 2                                        R.C@ASTSNR.N
# 3                               K.DC@TLATVDHNIPTTTR.K
# 4          K.ASILVVSGDNFGC@GSSR.E; L.VVSGDNFGC@GSSR.E
# 5       K.HC@LVNGLDDIGLTM*QK.E; K.HC@LVNGLDDIGLTMQK.E
# 6                                    R.LQC@TTLEQNVK.D
# 7                                         R.NADC@DK.L
# 8           K.KVEASPLVDC@SVLAR.G; K.VEASPLVDC@SVLAR.G
# 9                                      R.VDVC@M*GGK.I
# 10  E.YYRPM*AC@GEGGYPAVITPEEC@DK.M; M.AC@GEGGYPAVI...
# 11  E.YYRPM*AC@GEGGYPAVITPEEC@DK.M; M.AC@GEGGYPAVI...
# 12                                       R.DVPKC@QR.L
# 13  L.VDLC@YSTNNR.I; R.LVDLC@YST.N; R.LVDLC@YSTN.N...
# 14  R.IAC@VAPN.F; R.IAC@VAPNF.Y; R.IAC@VAPNFY.C; R...
# 15  N.FYC@NAVTM*GAYQQTGR.N; N.FYC@NAVTMGAYQQTGR.N;...
# 16  R.EQC@GDSDLC@YE.Q; R.EQC@GDSDLC@YEQED.W; R.EQC...
# 17  R.EQC@GDSDLC@YE.Q; R.EQC@GDSDLC@YEQED.W; R.EQC...
# 18  A.IGAEVEVFEGC@K.N; E.VEVFEGC@K.N; E.VFEGC@K.N;...
# 19        K.LNGGLGTSM*GC@VGPK.S; K.LNGGLGTSMGC@VGPK.S
#
#                         Site              UniProt              Protein  \
# 0   jgi|YarliW29_1|1000@C503  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000
# 1   jgi|YarliW29_1|1002@C352  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 2   jgi|YarliW29_1|1002@C430  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 3    jgi|YarliW29_1|1002@C55  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 4   jgi|YarliW29_1|1002@C614  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 5   jgi|YarliW29_1|1002@C704  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 6    jgi|YarliW29_1|1002@C88  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 7   jgi|YarliW29_1|1003@C116  jgi|YarliW29_1|1003  jgi|YarliW29_1|1003
# 8   jgi|YarliW29_1|1003@C417  jgi|YarliW29_1|1003  jgi|YarliW29_1|1003
# 9   jgi|YarliW29_1|1003@C540  jgi|YarliW29_1|1003  jgi|YarliW29_1|1003
# 10  jgi|YarliW29_1|1004@C317  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 11  jgi|YarliW29_1|1004@C331  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 12  jgi|YarliW29_1|1004@C341  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 13  jgi|YarliW29_1|1004@C348  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 14  jgi|YarliW29_1|1004@C357  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 15  jgi|YarliW29_1|1004@C364  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 16  jgi|YarliW29_1|1004@C386  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 17  jgi|YarliW29_1|1004@C392  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 18  jgi|YarliW29_1|1004@C422  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 19   jgi|YarliW29_1|100@C116   jgi|YarliW29_1|100   jgi|YarliW29_1|100
#
#    Residue                        id  Total missingness  \
# 0     C503  jgi|YarliW29_1|1000@C503                  0
# 1     C352  jgi|YarliW29_1|1002@C352                  0
# 2     C430  jgi|YarliW29_1|1002@C430                 36
# 3      C55   jgi|YarliW29_1|1002@C55                  0
# 4     C614  jgi|YarliW29_1|1002@C614                  0
# 5     C704  jgi|YarliW29_1|1002@C704                  0
# 6      C88   jgi|YarliW29_1|1002@C88                  0
# 7     C116  jgi|YarliW29_1|1003@C116                 18
# 8     C417  jgi|YarliW29_1|1003@C417                  0
# 9     C540  jgi|YarliW29_1|1003@C540                 36
# 10    C317  jgi|YarliW29_1|1004@C317                  0
# 11    C331  jgi|YarliW29_1|1004@C331                  0
# 12    C341  jgi|YarliW29_1|1004@C341                  0
# 13    C348  jgi|YarliW29_1|1004@C348                  0
# 14    C357  jgi|YarliW29_1|1004@C357                  0
# 15    C364  jgi|YarliW29_1|1004@C364                  0
# 16    C386  jgi|YarliW29_1|1004@C386                 18
# 17    C392  jgi|YarliW29_1|1004@C392                 18
# 18    C422  jgi|YarliW29_1|1004@C422                  0
# 19    C116   jgi|YarliW29_1|100@C116                  0
#
#     Oscillation_24 missingness  Oscillation_3.5 missingness  \
# 0                            0                            0
# 1                            0                            0
# 2                            3                            3
# 3                            0                            0
# 4                            0                            0
# 5                            0                            0
# 6                            0                            0
# 7                            3                            3
# 8                            0                            0
# 9                            3                            3
# 10                           0                            0
# 11                           0                            0
# 12                           0                            0
# 13                           0                            0
# 14                           0                            0
# 15                           0                            0
# 16                           0                            0
# 17                           0                            0
# 18                           0                            0
# 19                           0                            0
#
#     Oscillation_4.5 missingness  ...  Oscillation_72/Oscillation_3.5_adj-p  \
# 0                             0  ...                              0.000449
# 1                             0  ...                              0.248877
# 2                             3  ...                                   NaN
# 3                             0  ...                              0.002182
# 4                             0  ...                              0.000423
# 5                             0  ...                              0.001563
# 6                             0  ...                              0.003183
# 7                             3  ...                                   NaN
# 8                             0  ...                              0.030882
# 9                             3  ...                                   NaN
# 10                            0  ...                              0.003411
# 11                            0  ...                              0.004593
# 12                            0  ...                              0.033571
# 13                            0  ...                              0.391639
# 14                            0  ...                              0.836249
# 15                            0  ...                              0.223706
# 16                            0  ...                              0.006369
# 17                            0  ...                              0.006369
# 18                            0  ...                              0.001177
# 19                            0  ...                              0.010161
#
#     Type  Experiment  site_number  early/late  early/late_ANOVA_padj  \
# 0     Ox         PTM            1   -1.311444           1.718573e-07
# 1     Ox         PTM            8   -0.236817           3.685403e-01
# 2     Ox         PTM            8   -1.367835           1.603170e-07
# 3     Ox         PTM            8   -0.539341           2.940152e-05
# 4     Ox         PTM            8   -2.090074           7.454891e-12
# 5     Ox         PTM            8   -2.704643           1.950483e-12
# 6     Ox         PTM            8   -2.275029           2.310453e-12
# 7     Ox         PTM            3   -1.864124           2.935036e-05
# 8     Ox         PTM            3   -1.492496           7.851495e-07
# 9     Ox         PTM            3   -2.270989           2.889671e-10
# 10    Ox         PTM            9   -0.481519           5.548168e-07
# 11    Ox         PTM            9   -0.620590           9.848723e-08
# 12    Ox         PTM            9   -0.882754           6.201625e-06
# 13    Ox         PTM            9   -0.265251           2.889434e-06
# 14    Ox         PTM            9   -0.065797           6.168141e-02
# 15    Ox         PTM            9   -0.126694           8.534924e-03
# 16    Ox         PTM            9    0.883627           1.464589e-07
# 17    Ox         PTM            9    0.883627           1.464589e-07
# 18    Ox         PTM            9   -2.235629           1.142856e-10
# 19    Ox         PTM            5   -2.140330           2.728947e-09
#
#     early/late_ANOVA_p  low/control_late_combined  \
# 0         6.002670e-08                  -1.342868
# 1         3.612753e-01                   0.170906
# 2         5.504471e-08                        NaN
# 3         2.051635e-05                  -0.572486
# 4         2.996224e-13                  -1.127900
# 5         4.456987e-14                  -1.642798
# 6         5.969592e-14                  -1.272995
# 7         2.045819e-05                  -2.116169
# 8         3.498739e-07                   0.459669
# 9         2.886906e-11                        NaN
# 10        2.335009e-07                  -0.290508
# 11        3.096324e-08                  -0.430594
# 12        3.629582e-06                  -0.082242
# 13        1.541769e-06                  -0.292714
# 14        5.883639e-02                   0.076199
# 15        7.863564e-03                  -0.005588
# 16        4.963743e-08                        NaN
# 17        4.963743e-08                        NaN
# 18        9.099103e-12                  -2.017871
# 19        4.455104e-10                  -2.630871
#
#     low/control_late_combined_ANOVA_padj  low/control_late_combined_ANOVA_p
# 0                           4.004436e-07                       3.357202e-08
# 1                           4.965747e-01                       4.746497e-01
# 2                                    NaN                                NaN
# 3                           6.463768e-05                       2.505666e-05
# 4                           1.310214e-04                       6.094821e-05
# 5                           4.206601e-06                       7.472974e-07
# 6                           2.398887e-06                       3.505338e-07
# 7                           2.745341e-05                       8.456083e-06
# 8                           1.386652e-01                       1.238694e-01
# 9                                    NaN                                NaN
# 10                          1.463211e-03                       9.775249e-04
# 11                          9.326326e-05                       4.012404e-05
# 12                          4.438961e-01                       4.207972e-01
# 13                          6.454954e-05                       2.497159e-05
# 14                          1.315642e-01                       1.172149e-01
# 15                          9.248704e-01                       9.190368e-01
# 16                                   NaN                                NaN
# 17                                   NaN                                NaN
# 18                          2.789084e-09                       4.401394e-11
# 19                          2.500536e-09                       3.614441e-11
#
# [20 rows x 176 columns]

# %%
prot_control_vs_low_late_combined_stats.head()
# Out:
#                        Site  Biostat2L_30_Control_24  Biostat2L_30_Control_48  \
# 0  jgi|YarliW29_1|1000@C503                17.457152                17.893231
# 1  jgi|YarliW29_1|1002@C352                19.717296                18.925732
# 2  jgi|YarliW29_1|1002@C430                15.879484                15.917200
# 3   jgi|YarliW29_1|1002@C55                18.874312                19.007607
# 4  jgi|YarliW29_1|1002@C614                17.278106                17.453021
#
#    Biostat2L_30_Control_72  Biostat2L_31_Control_24  Biostat2L_31_Control_48  \
# 0                18.139734                17.551684                17.772679
# 1                19.799532                18.844664                19.605383
# 2                16.575859                15.988922                15.670962
# 3                19.145622                19.174561                19.139245
# 4                17.570320                17.479830                17.775941
#
#    Biostat2L_31_Control_72  Biostat2L_32_Control_24  Biostat2L_32_Control_48  \
# 0                18.088275                17.514607                17.751886
# 1                18.915459                19.727180                18.980346
# 2                16.244652                15.976270                15.809801
# 3                19.094474                18.658341                18.861431
# 4                17.858263                17.354568                17.347667
#
#    Biostat2L_32_Control_72  ...  Biostat2L_33_Low_72  Biostat2L_34_Low_24  \
# 0                18.596925  ...            16.651285            16.451691
# 1                19.595083  ...            19.953698            19.104072
# 2                16.888492  ...                  NaN                  NaN
# 3                19.566815  ...            18.428186            18.593297
# 4                17.954387  ...            16.877026            15.920855
#
#    Biostat2L_34_Low_48  Biostat2L_34_Low_72                   Protein  \
# 0            16.481918            16.782876  jgi|YarliW29_1|1000@C503
# 1            19.454477            20.131243  jgi|YarliW29_1|1002@C352
# 2                  NaN                  NaN  jgi|YarliW29_1|1002@C430
# 3            18.424024            18.238569   jgi|YarliW29_1|1002@C55
# 4            16.629091            17.021753  jgi|YarliW29_1|1002@C614
#
#         ANOVA_p    ANOVA_padj  proteinID    log2FC proteinId
# 0  3.357202e-08  4.004436e-07       1000 -1.342868      1000
# 1  4.746497e-01  4.965747e-01       1002  0.170906      1002
# 2           NaN           NaN       1002       NaN      1002
# 3  2.505666e-05  6.463768e-05       1002 -0.572486      1002
# 4  6.094821e-05  1.310214e-04       1002 -1.127900      1002
#
# [5 rows x 25 columns]

# %%
prot_control_vs_low_late_combined_stats_withAnnote = pd.merge(prot_control_vs_low_late_combined_stats, merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')
# prot_control_vs_low_24h_stats_withAnnote = pd.merge(prot_control_vs_low_24h_stats, merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')

# %%
prot_control_vs_low_late_combined_stats_withAnnote.columns
# Out:
# Index(['Site', 'Biostat2L_30_Control_24', 'Biostat2L_30_Control_48',
#        'Biostat2L_30_Control_72', 'Biostat2L_31_Control_24',
#        'Biostat2L_31_Control_48', 'Biostat2L_31_Control_72',
#        'Biostat2L_32_Control_24', 'Biostat2L_32_Control_48',
#        'Biostat2L_32_Control_72', 'Biostat2L_32_Low_24', 'Biostat2L_32_Low_48',
#        'Biostat2L_32_Low_72', 'Biostat2L_33_Low_24', 'Biostat2L_33_Low_48',
#        'Biostat2L_33_Low_72', 'Biostat2L_34_Low_24', 'Biostat2L_34_Low_48',
#        'Biostat2L_34_Low_72', 'Protein', 'ANOVA_p', 'ANOVA_padj', 'proteinID',
#        'log2FC', 'proteinId', '#proteinId', 'kogid', 'kogdefline', 'kogClass',
#        'kogGroup', 'definition', 'catalyticActivity', 'pathway',
#        'pathway_class', 'pathway_type', 'ecNum', 'cofactors', 'gotermId',
#        'gotermType', 'goName', 'goAcc'],
#       dtype='object')

# %% [markdown]
# ### optional save.

# %%
# prot_control_vs_low_late_combined_stats_withAnnote.to_csv('control_vs_low_late.csv')
# prot_control_vs_low_24h_stats_withAnnote.to_csv('control_vs_low_24h.csv')

# %% [markdown]
# ### Volcano plot comparing low vs high,
# all late (increase means increased in low)

# %%
dataset = prot_control_vs_low_late_combined_stats_withAnnote[['log2FC', 'ANOVA_padj']].copy()
dataset.index = prot_control_vs_low_late_combined_stats_withAnnote.Site

# dataset24h = prot_control_vs_low_24h_stats_withAnnote[['log2FC', 'ANOVA_padj']].copy()

# %%
log2FC_threshold = np.log2(1.3)

# %%
# dataset

# %%
# subset the log2FC and the P_value for this dataset. 
dataset.columns = ['log2FC','P_value']

# obtain the -logP_adj for the dataset. 
dataset['-logP_adj'] = -np.log10(dataset['P_value'])

# set a class for up (1) or down (-1) proteins. 
dataset['class'] = 0
dataset.loc[(dataset['log2FC']>log2FC_threshold)&(dataset['-logP_adj']>-np.log10(0.05)),'class'] = 1
dataset.loc[(dataset['log2FC']<-log2FC_threshold)&(dataset['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
# # subset the log2FC and the P_value for this dataset. 
# dataset24h.columns = ['log2FC','P_value']

# # obtain the -logP_adj for the dataset. 
# dataset24h['-logP_adj'] = -np.log10(dataset['P_value'])

# # set a class for up (1) or down (-1) proteins. 
# dataset24h['class'] = 0
# dataset24h.loc[(dataset24h['log2FC']>log2FC_threshold)&(dataset24h['-logP_adj']>-np.log10(0.05)),'class'] = 1
# dataset24h.loc[(dataset24h['log2FC']<-log2FC_threshold)&(dataset24h['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
# dataset

# %%
volcano_plot(dataset)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/1246007795.py:202: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_min = df.min()[0]-1
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/1246007795.py:203: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_max = df.max()[0]+1
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/1246007795.py:206: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_max = dataset.max()[2]+1

# %%
# volcano_plot_annotate(dataset)

# %%
# volcano_plot(dataset24h)

# %% [markdown]
# ### Significant protein slicing.

# %%
# prot_control_vxs_low_late_combined_stats_withAnnote.columns

# %%
# sig_control_vs_low_late_combined = prot_control_vs_low_late_combined_stats_withAnnote[prot_control_vs_low_late_combined_stats_withAnnote['ANOVA_padj'] < 0.05]
# # sig_control_vs_low_24h = prot_control_vs_low_24h_stats_withAnnote[prot_control_vs_low_24h_stats_withAnnote['ANOVA_padj'] < 0.05]

# %% [markdown]
# ### optional save.

# %%
# sig_control_vs_low_late_combined.to_csv('Sig_control_vs_low_late_combined.csv')
# sig_control_vs_low_24h.to_csv('Sig_control_vs_low_24h.csv')

# %% [markdown]
# ## Compare Control vs Oscillation.

# %%
prot = annotated_redox[sample_ids_prot_redox]
annotated_redox['Protein'] = annotated_redox['Site']
prot.index = annotated_redox['Site']
# drop oscillations.
# prot_control_vs_oscillation_24h = prot.drop(prot.columns[prot.columns.str.contains("Low")], axis=1)
prot_control_vs_oscillation_late_combined = prot.drop(prot.columns[prot.columns.str.contains("Low")], axis=1)


# drop early timepoints. 
# prot_control_vs_oscillation_24h = prot_control_vs_oscillation_24h.drop(prot_control_vs_oscillation_24h.columns[
#     prot_control_vs_oscillation_24h.columns.str.contains("5.5|3.5|4.5|48|72")], axis=1)

prot_control_vs_oscillation_late_combined = prot_control_vs_oscillation_late_combined.drop(prot_control_vs_oscillation_late_combined.columns[
    prot_control_vs_oscillation_late_combined.columns.str.contains("5.5|3.5|4.5")], axis=1)

# %%
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))

# %% [markdown]
# ### Prep for p-values.

# %%
# group for mapping in nanova. 


condition_series_controlvsOscLateCombined = pd.Series(prot_control_vs_oscillation_late_combined.columns).map(prot_condition_dict)
condition_series_controlvsOscLateCombined.index = prot_control_vs_oscillation_late_combined.columns
condition_series_controlvsOscLateCombined 

# condition_series_controlvsOsc24 = pd.Series(prot_control_vs_oscillation_24h.columns).map(prot_condition_dict)
# condition_series_controlvsOsc24.index = prot_control_vs_oscillation_24h.columns
# condition_series_controlvsOsc24
# Out:
# Biostat2L_29_Oscillation_24    Oscillation
# Biostat2L_29_Oscillation_48    Oscillation
# Biostat2L_29_Oscillation_72    Oscillation
# Biostat2L_30_Control_24            Control
# Biostat2L_30_Control_48            Control
# Biostat2L_30_Control_72            Control
# Biostat2L_30_Oscillation_24    Oscillation
# Biostat2L_30_Oscillation_48    Oscillation
# Biostat2L_30_Oscillation_72    Oscillation
# Biostat2L_31_Control_24            Control
# Biostat2L_31_Control_48            Control
# Biostat2L_31_Control_72            Control
# Biostat2L_31_Oscillation_24    Oscillation
# Biostat2L_31_Oscillation_48    Oscillation
# Biostat2L_31_Oscillation_72    Oscillation
# Biostat2L_32_Control_24            Control
# Biostat2L_32_Control_48            Control
# Biostat2L_32_Control_72            Control
# dtype: object

# %%
# late stats.
prot_control_vs_oscillation_late_combined_stats = global_stats_calc_prot(prot_control_vs_oscillation_late_combined,
                                                                         condition_series_controlvsOscLateCombined )

# 24 h stats. 
# prot_control_vs_oscillation_24h_stats = global_stats_calc_prot(prot_control_vs_oscillation_24h,
                                                                  # condition_series_controlvsOsc24)

# %%
# Extract the number between "YarliW29_1|" and "@GLB" using regex.
prot_control_vs_oscillation_late_combined_stats["proteinID"] = prot_control_vs_oscillation_late_combined_stats["Site"].str.extract(r"YarliW29_1\|(\d+)@")
# prot_control_vs_oscillation_24h_stats["proteinID"] = prot_control_vs_oscillation_24h_stats["Protein"].str.extract(r"YarliW29_1\|(\d+)@GLB")



# Convert the extracted number to integer (if needed).
prot_control_vs_oscillation_late_combined_stats["proteinID"] = prot_control_vs_oscillation_late_combined_stats["proteinID"].astype(int)
# prot_control_vs_oscillation_24h_stats["proteinID"] = prot_control_vs_oscillation_24h_stats["proteinID"].astype(int)

# %% [markdown]
# ### calculate log2FC

# %%
controlLateCombined = prot_control_vs_oscillation_late_combined_stats.loc[:, prot_control_vs_oscillation_late_combined_stats.columns[prot_control_vs_oscillation_late_combined_stats.columns.str.contains("Control")]]
# control24h = prot_control_vs_oscillation_24h_stats.loc[:, prot_control_vs_oscillation_24h_stats.columns[prot_control_vs_oscillation_24h_stats.columns.str.contains("Control")]]
# control24h.head()

# %%
oscLateCombinedLate = prot_control_vs_oscillation_late_combined_stats.loc[:, prot_control_vs_oscillation_late_combined_stats.columns[
    prot_control_vs_oscillation_late_combined_stats.columns.str.contains("Oscillation")]]

# osc24h = prot_control_vs_oscillation_24h_stats.loc[:, prot_control_vs_oscillation_24h_stats.columns[
    # prot_control_vs_oscillation_24h_stats.columns.str.contains("Oscillation")]]
# osc24h.head()

# %%
oscLateCombinedLate.head()
# Out:
#    Biostat2L_29_Oscillation_24  Biostat2L_29_Oscillation_48  \
# 0                    17.771583                    18.596711
# 1                    19.220965                    19.952574
# 2                          NaN                          NaN
# 3                    19.363283                    20.099247
# 4                    17.383142                    18.595572
#
#    Biostat2L_29_Oscillation_72  Biostat2L_30_Oscillation_24  \
# 0                    18.613297                    17.960813
# 1                    19.523283                    19.134185
# 2                          NaN                          NaN
# 3                    20.247919                    19.283361
# 4                    18.774382                    17.304078
#
#    Biostat2L_30_Oscillation_48  Biostat2L_30_Oscillation_72  \
# 0                    18.709230                    18.905539
# 1                    20.119849                    20.001728
# 2                          NaN                          NaN
# 3                    20.387765                    20.516008
# 4                    19.040781                    19.159442
#
#    Biostat2L_31_Oscillation_24  Biostat2L_31_Oscillation_48  \
# 0                    17.714967                    18.328691
# 1                    19.114733                    19.183590
# 2                          NaN                          NaN
# 3                    18.941259                    19.307079
# 4                    16.828341                    18.071971
#
#    Biostat2L_31_Oscillation_72
# 0                    18.647709
# 1                    19.391718
# 2                          NaN
# 3                    19.871772
# 4                    18.858217

# %%
# gives the increase of the first. 
# prot_control_vs_oscillation_24h_stats['log2FC']=log2FC_function(osc24h, control24h)
prot_control_vs_oscillation_late_combined_stats['log2FC']=log2FC_function(oscLateCombinedLate,controlLateCombined)

# %%
df_to_merge = pd.DataFrame()
df_to_merge['osc/control_late_cominbed'] = prot_control_vs_oscillation_late_combined_stats['log2FC']
df_to_merge['Site'] = prot_control_vs_oscillation_late_combined_stats['Site']
df_to_merge['osc/control_late_cominbedANOVA_padj'] = prot_control_vs_oscillation_late_combined_stats['ANOVA_padj']
df_to_merge['osc/control_late_cominbedANOVA_p'] = prot_control_vs_oscillation_late_combined_stats['ANOVA_p']

# %%
merged_df = pd.merge(merged_df, df_to_merge, left_on='Site',right_on='Site', how='left')

# %%
merged_df.head(20)
# Out:
#                                               Peptide  \
# 0                                      R.IEPIC@AQGR.I
# 1                                     K.VFIGSC@TNSR.I
# 2                                        R.C@ASTSNR.N
# 3                               K.DC@TLATVDHNIPTTTR.K
# 4          K.ASILVVSGDNFGC@GSSR.E; L.VVSGDNFGC@GSSR.E
# 5       K.HC@LVNGLDDIGLTM*QK.E; K.HC@LVNGLDDIGLTMQK.E
# 6                                    R.LQC@TTLEQNVK.D
# 7                                         R.NADC@DK.L
# 8           K.KVEASPLVDC@SVLAR.G; K.VEASPLVDC@SVLAR.G
# 9                                      R.VDVC@M*GGK.I
# 10  E.YYRPM*AC@GEGGYPAVITPEEC@DK.M; M.AC@GEGGYPAVI...
# 11  E.YYRPM*AC@GEGGYPAVITPEEC@DK.M; M.AC@GEGGYPAVI...
# 12                                       R.DVPKC@QR.L
# 13  L.VDLC@YSTNNR.I; R.LVDLC@YST.N; R.LVDLC@YSTN.N...
# 14  R.IAC@VAPN.F; R.IAC@VAPNF.Y; R.IAC@VAPNFY.C; R...
# 15  N.FYC@NAVTM*GAYQQTGR.N; N.FYC@NAVTMGAYQQTGR.N;...
# 16  R.EQC@GDSDLC@YE.Q; R.EQC@GDSDLC@YEQED.W; R.EQC...
# 17  R.EQC@GDSDLC@YE.Q; R.EQC@GDSDLC@YEQED.W; R.EQC...
# 18  A.IGAEVEVFEGC@K.N; E.VEVFEGC@K.N; E.VFEGC@K.N;...
# 19        K.LNGGLGTSM*GC@VGPK.S; K.LNGGLGTSMGC@VGPK.S
#
#                         Site              UniProt              Protein  \
# 0   jgi|YarliW29_1|1000@C503  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000
# 1   jgi|YarliW29_1|1002@C352  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 2   jgi|YarliW29_1|1002@C430  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 3    jgi|YarliW29_1|1002@C55  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 4   jgi|YarliW29_1|1002@C614  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 5   jgi|YarliW29_1|1002@C704  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 6    jgi|YarliW29_1|1002@C88  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 7   jgi|YarliW29_1|1003@C116  jgi|YarliW29_1|1003  jgi|YarliW29_1|1003
# 8   jgi|YarliW29_1|1003@C417  jgi|YarliW29_1|1003  jgi|YarliW29_1|1003
# 9   jgi|YarliW29_1|1003@C540  jgi|YarliW29_1|1003  jgi|YarliW29_1|1003
# 10  jgi|YarliW29_1|1004@C317  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 11  jgi|YarliW29_1|1004@C331  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 12  jgi|YarliW29_1|1004@C341  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 13  jgi|YarliW29_1|1004@C348  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 14  jgi|YarliW29_1|1004@C357  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 15  jgi|YarliW29_1|1004@C364  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 16  jgi|YarliW29_1|1004@C386  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 17  jgi|YarliW29_1|1004@C392  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 18  jgi|YarliW29_1|1004@C422  jgi|YarliW29_1|1004  jgi|YarliW29_1|1004
# 19   jgi|YarliW29_1|100@C116   jgi|YarliW29_1|100   jgi|YarliW29_1|100
#
#    Residue                        id  Total missingness  \
# 0     C503  jgi|YarliW29_1|1000@C503                  0
# 1     C352  jgi|YarliW29_1|1002@C352                  0
# 2     C430  jgi|YarliW29_1|1002@C430                 36
# 3      C55   jgi|YarliW29_1|1002@C55                  0
# 4     C614  jgi|YarliW29_1|1002@C614                  0
# 5     C704  jgi|YarliW29_1|1002@C704                  0
# 6      C88   jgi|YarliW29_1|1002@C88                  0
# 7     C116  jgi|YarliW29_1|1003@C116                 18
# 8     C417  jgi|YarliW29_1|1003@C417                  0
# 9     C540  jgi|YarliW29_1|1003@C540                 36
# 10    C317  jgi|YarliW29_1|1004@C317                  0
# 11    C331  jgi|YarliW29_1|1004@C331                  0
# 12    C341  jgi|YarliW29_1|1004@C341                  0
# 13    C348  jgi|YarliW29_1|1004@C348                  0
# 14    C357  jgi|YarliW29_1|1004@C357                  0
# 15    C364  jgi|YarliW29_1|1004@C364                  0
# 16    C386  jgi|YarliW29_1|1004@C386                 18
# 17    C392  jgi|YarliW29_1|1004@C392                 18
# 18    C422  jgi|YarliW29_1|1004@C422                  0
# 19    C116   jgi|YarliW29_1|100@C116                  0
#
#     Oscillation_24 missingness  Oscillation_3.5 missingness  \
# 0                            0                            0
# 1                            0                            0
# 2                            3                            3
# 3                            0                            0
# 4                            0                            0
# 5                            0                            0
# 6                            0                            0
# 7                            3                            3
# 8                            0                            0
# 9                            3                            3
# 10                           0                            0
# 11                           0                            0
# 12                           0                            0
# 13                           0                            0
# 14                           0                            0
# 15                           0                            0
# 16                           0                            0
# 17                           0                            0
# 18                           0                            0
# 19                           0                            0
#
#     Oscillation_4.5 missingness  ...  site_number  early/late  \
# 0                             0  ...            1   -1.311444
# 1                             0  ...            8   -0.236817
# 2                             3  ...            8   -1.367835
# 3                             0  ...            8   -0.539341
# 4                             0  ...            8   -2.090074
# 5                             0  ...            8   -2.704643
# 6                             0  ...            8   -2.275029
# 7                             3  ...            3   -1.864124
# 8                             0  ...            3   -1.492496
# 9                             3  ...            3   -2.270989
# 10                            0  ...            9   -0.481519
# 11                            0  ...            9   -0.620590
# 12                            0  ...            9   -0.882754
# 13                            0  ...            9   -0.265251
# 14                            0  ...            9   -0.065797
# 15                            0  ...            9   -0.126694
# 16                            0  ...            9    0.883627
# 17                            0  ...            9    0.883627
# 18                            0  ...            9   -2.235629
# 19                            0  ...            5   -2.140330
#
#     early/late_ANOVA_padj  early/late_ANOVA_p  low/control_late_combined  \
# 0            1.718573e-07        6.002670e-08                  -1.342868
# 1            3.685403e-01        3.612753e-01                   0.170906
# 2            1.603170e-07        5.504471e-08                        NaN
# 3            2.940152e-05        2.051635e-05                  -0.572486
# 4            7.454891e-12        2.996224e-13                  -1.127900
# 5            1.950483e-12        4.456987e-14                  -1.642798
# 6            2.310453e-12        5.969592e-14                  -1.272995
# 7            2.935036e-05        2.045819e-05                  -2.116169
# 8            7.851495e-07        3.498739e-07                   0.459669
# 9            2.889671e-10        2.886906e-11                        NaN
# 10           5.548168e-07        2.335009e-07                  -0.290508
# 11           9.848723e-08        3.096324e-08                  -0.430594
# 12           6.201625e-06        3.629582e-06                  -0.082242
# 13           2.889434e-06        1.541769e-06                  -0.292714
# 14           6.168141e-02        5.883639e-02                   0.076199
# 15           8.534924e-03        7.863564e-03                  -0.005588
# 16           1.464589e-07        4.963743e-08                        NaN
# 17           1.464589e-07        4.963743e-08                        NaN
# 18           1.142856e-10        9.099103e-12                  -2.017871
# 19           2.728947e-09        4.455104e-10                  -2.630871
#
#     low/control_late_combined_ANOVA_padj  low/control_late_combined_ANOVA_p  \
# 0                           4.004436e-07                       3.357202e-08
# 1                           4.965747e-01                       4.746497e-01
# 2                                    NaN                                NaN
# 3                           6.463768e-05                       2.505666e-05
# 4                           1.310214e-04                       6.094821e-05
# 5                           4.206601e-06                       7.472974e-07
# 6                           2.398887e-06                       3.505338e-07
# 7                           2.745341e-05                       8.456083e-06
# 8                           1.386652e-01                       1.238694e-01
# 9                                    NaN                                NaN
# 10                          1.463211e-03                       9.775249e-04
# 11                          9.326326e-05                       4.012404e-05
# 12                          4.438961e-01                       4.207972e-01
# 13                          6.454954e-05                       2.497159e-05
# 14                          1.315642e-01                       1.172149e-01
# 15                          9.248704e-01                       9.190368e-01
# 16                                   NaN                                NaN
# 17                                   NaN                                NaN
# 18                          2.789084e-09                       4.401394e-11
# 19                          2.500536e-09                       3.614441e-11
#
#     osc/control_late_cominbed  osc/control_late_cominbedANOVA_padj  \
# 0                    0.498041                             0.068902
# 1                    0.170217                             0.534709
# 2                         NaN                                  NaN
# 3                    0.721698                             0.018774
# 4                    0.660425                             0.116799
# 5                    0.344931                             0.304527
# 6                   -0.753507                             0.023794
# 7                         NaN                                  NaN
# 8                   -0.046042                             0.928795
# 9                         NaN                                  NaN
# 10                  -0.082930                             0.450894
# 11                  -0.230885                             0.067841
# 12                  -0.238063                             0.258534
# 13                  -0.018084                             0.914813
# 14                   0.026146                             0.596108
# 15                  -0.110065                             0.095380
# 16                   0.183979                             0.355350
# 17                   0.183979                             0.355350
# 18                  -0.878306                             0.000370
# 19                  -1.109743                             0.007354
#
#     osc/control_late_cominbedANOVA_p
# 0                           0.018835
# 1                           0.390366
# 2                                NaN
# 3                           0.003143
# 4                           0.041402
# 5                           0.171625
# 6                           0.004370
# 7                                NaN
# 8                           0.894753
# 9                                NaN
# 10                          0.306415
# 11                          0.018395
# 12                          0.134712
# 13                          0.869388
# 14                          0.456167
# 15                          0.030527
# 16                          0.216427
# 17                          0.216427
# 18                          0.000019
# 19                          0.000869
#
# [20 rows x 179 columns]

# %%
merged_df
# Out:
#                                                 Peptide  \
# 0                                        R.IEPIC@AQGR.I
# 1                                       K.VFIGSC@TNSR.I
# 2                                          R.C@ASTSNR.N
# 3                                 K.DC@TLATVDHNIPTTTR.K
# 4            K.ASILVVSGDNFGC@GSSR.E; L.VVSGDNFGC@GSSR.E
# ...                                                 ...
# 5223                                     K.EELRNDC@ER.Q
# 5224                                       R.YC@VALAR.Y
# 5225  K.DTKPETC@PIQPGQE.A; K.DTKPETC@PIQPGQEASFAYTVE...
# 5226                                    A.IYFSDC@FHQR.N
# 5227                                       R.FC@DEVSK.D
#
#                           Site              UniProt              Protein  \
# 0     jgi|YarliW29_1|1000@C503  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000
# 1     jgi|YarliW29_1|1002@C352  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 2     jgi|YarliW29_1|1002@C430  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 3      jgi|YarliW29_1|1002@C55  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# 4     jgi|YarliW29_1|1002@C614  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002
# ...                        ...                  ...                  ...
# 5223   jgi|YarliW29_1|994@C695   jgi|YarliW29_1|994   jgi|YarliW29_1|994
# 5224   jgi|YarliW29_1|994@C850   jgi|YarliW29_1|994   jgi|YarliW29_1|994
# 5225    jgi|YarliW29_1|99@C106    jgi|YarliW29_1|99    jgi|YarliW29_1|99
# 5226     jgi|YarliW29_1|99@C21    jgi|YarliW29_1|99    jgi|YarliW29_1|99
# 5227     jgi|YarliW29_1|99@C94    jgi|YarliW29_1|99    jgi|YarliW29_1|99
#
#      Residue                        id  Total missingness  \
# 0       C503  jgi|YarliW29_1|1000@C503                  0
# 1       C352  jgi|YarliW29_1|1002@C352                  0
# 2       C430  jgi|YarliW29_1|1002@C430                 36
# 3        C55   jgi|YarliW29_1|1002@C55                  0
# 4       C614  jgi|YarliW29_1|1002@C614                  0
# ...      ...                       ...                ...
# 5223    C695   jgi|YarliW29_1|994@C695                  0
# 5224    C850   jgi|YarliW29_1|994@C850                  0
# 5225    C106    jgi|YarliW29_1|99@C106                  0
# 5226     C21     jgi|YarliW29_1|99@C21                 18
# 5227     C94     jgi|YarliW29_1|99@C94                 18
#
#       Oscillation_24 missingness  Oscillation_3.5 missingness  \
# 0                              0                            0
# 1                              0                            0
# 2                              3                            3
# 3                              0                            0
# 4                              0                            0
# ...                          ...                          ...
# 5223                           0                            0
# 5224                           0                            0
# 5225                           0                            0
# 5226                           3                            3
# 5227                           3                            3
#
#       Oscillation_4.5 missingness  ...  site_number  early/late  \
# 0                               0  ...            1   -1.311444
# 1                               0  ...            8   -0.236817
# 2                               3  ...            8   -1.367835
# 3                               0  ...            8   -0.539341
# 4                               0  ...            8   -2.090074
# ...                           ...  ...          ...         ...
# 5223                            0  ...            6   -1.884119
# 5224                            0  ...            6   -0.654562
# 5225                            0  ...            3   -1.147937
# 5226                            3  ...            3   -2.022789
# 5227                            3  ...            3   -1.612527
#
#       early/late_ANOVA_padj  early/late_ANOVA_p  low/control_late_combined  \
# 0              1.718573e-07        6.002670e-08                  -1.342868
# 1              3.685403e-01        3.612753e-01                   0.170906
# 2              1.603170e-07        5.504471e-08                        NaN
# 3              2.940152e-05        2.051635e-05                  -0.572486
# 4              7.454891e-12        2.996224e-13                  -1.127900
# ...                     ...                 ...                        ...
# 5223           3.754786e-07        1.483949e-07                  -0.821914
# 5224           1.871312e-02        1.751333e-02                  -0.870977
# 5225           9.697040e-10        1.304693e-10                   0.096414
# 5226           7.586774e-11        5.474094e-12                  -0.909302
# 5227           3.442031e-06        1.870225e-06                   0.533244
#
#       low/control_late_combined_ANOVA_padj  low/control_late_combined_ANOVA_p  \
# 0                             4.004436e-07                       3.357202e-08
# 1                             4.965747e-01                       4.746497e-01
# 2                                      NaN                                NaN
# 3                             6.463768e-05                       2.505666e-05
# 4                             1.310214e-04                       6.094821e-05
# ...                                    ...                                ...
# 5223                          3.474731e-03                       2.505825e-03
# 5224                          4.020606e-03                       2.942809e-03
# 5225                          5.861351e-01                       5.656473e-01
# 5226                          9.794836e-04                       6.260458e-04
# 5227                          4.078315e-02                       3.436288e-02
#
#       osc/control_late_cominbed  osc/control_late_cominbedANOVA_padj  \
# 0                      0.498041                             0.068902
# 1                      0.170217                             0.534709
# 2                           NaN                                  NaN
# 3                      0.721698                             0.018774
# 4                      0.660425                             0.116799
# ...                         ...                                  ...
# 5223                  -0.589082                             0.118214
# 5224                  -0.748239                             0.145794
# 5225                  -0.220181                             0.113304
# 5226                        NaN                                  NaN
# 5227                        NaN                                  NaN
#
#       osc/control_late_cominbedANOVA_p
# 0                             0.018835
# 1                             0.390366
# 2                                  NaN
# 3                             0.003143
# 4                             0.041402
# ...                                ...
# 5223                          0.042098
# 5224                          0.057020
# 5225                          0.039551
# 5226                               NaN
# 5227                               NaN
#
# [5228 rows x 179 columns]

# %% [markdown]
# ### optional save. This is final file with proteomic details.

# %%
merged_df["proteinId"] = merged_df["Site"].str.extract(r"YarliW29_1\|(\d+)@")
merged_df['proteinID'] = merged_df['proteinId'].copy()
merged_df['#proteinId'] = merged_df['proteinId'].copy()

# %%
# merged_df.to_csv('../Data/PPI_yarrowia_REDOX_Global/result/PPI_yarrowia_redox_wAnnotations_fullLog2FC.csv')

# %%
prot_control_vs_oscillation_late_combined_stats.head()
# Out:
#                        Site  Biostat2L_29_Oscillation_24  \
# 0  jgi|YarliW29_1|1000@C503                    17.771583
# 1  jgi|YarliW29_1|1002@C352                    19.220965
# 2  jgi|YarliW29_1|1002@C430                          NaN
# 3   jgi|YarliW29_1|1002@C55                    19.363283
# 4  jgi|YarliW29_1|1002@C614                    17.383142
#
#    Biostat2L_29_Oscillation_48  Biostat2L_29_Oscillation_72  \
# 0                    18.596711                    18.613297
# 1                    19.952574                    19.523283
# 2                          NaN                          NaN
# 3                    20.099247                    20.247919
# 4                    18.595572                    18.774382
#
#    Biostat2L_30_Control_24  Biostat2L_30_Control_48  Biostat2L_30_Control_72  \
# 0                17.457152                17.893231                18.139734
# 1                19.717296                18.925732                19.799532
# 2                15.879484                15.917200                16.575859
# 3                18.874312                19.007607                19.145622
# 4                17.278106                17.453021                17.570320
#
#    Biostat2L_30_Oscillation_24  Biostat2L_30_Oscillation_48  \
# 0                    17.960813                    18.709230
# 1                    19.134185                    20.119849
# 2                          NaN                          NaN
# 3                    19.283361                    20.387765
# 4                    17.304078                    19.040781
#
#    Biostat2L_30_Oscillation_72  ...  Biostat2L_31_Oscillation_24  \
# 0                    18.905539  ...                    17.714967
# 1                    20.001728  ...                    19.114733
# 2                          NaN  ...                          NaN
# 3                    20.516008  ...                    18.941259
# 4                    19.159442  ...                    16.828341
#
#    Biostat2L_31_Oscillation_48  Biostat2L_31_Oscillation_72  \
# 0                    18.328691                    18.647709
# 1                    19.183590                    19.391718
# 2                          NaN                          NaN
# 3                    19.307079                    19.871772
# 4                    18.071971                    18.858217
#
#    Biostat2L_32_Control_24  Biostat2L_32_Control_48  Biostat2L_32_Control_72  \
# 0                17.514607                17.751886                18.596925
# 1                19.727180                18.980346                19.595083
# 2                15.976270                15.809801                16.888492
# 3                18.658341                18.861431                19.566815
# 4                17.354568                17.347667                17.954387
#
#     ANOVA_p  ANOVA_padj  proteinID    log2FC
# 0  0.018835    0.068902       1000  0.498041
# 1  0.390366    0.534709       1002  0.170217
# 2       NaN         NaN       1002       NaN
# 3  0.003143    0.018774       1002  0.721698
# 4  0.041402    0.116799       1002  0.660425
#
# [5 rows x 23 columns]

# %%
prot_control_vs_oscillation_late_combined_stats_withAnnote = pd.merge(prot_control_vs_oscillation_late_combined_stats, 
                                                                      merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')
# prot_control_vs_oscillation_24h_stats_withAnnote = pd.merge(prot_control_vs_oscillation_24h_stats, 
                                                                      # merged_annotations, left_on='proteinID', right_on='#proteinId', how='left')

# %%
# prot_control_vs_oscillation_late_combined_stats_withAnnote.to_csv('control_vs_oscillation_late.csv')
# prot_control_vs_oscillation_24h_stats_withAnnote.to_csv('control_vs_oscillation_24h.csv')

# %% [markdown]
# ### Volcano plot comparing low vs high,
# all late (increase means increased in low)

# %%
dataset_late_combined = prot_control_vs_oscillation_late_combined_stats_withAnnote[['log2FC', 'ANOVA_padj']].copy()
# dataset_24h = prot_control_vs_oscillation_24h_stats_withAnnote[['log2FC', 'ANOVA_padj']].copy()

# %%
log2FC_threshold = np.log2(1.3)

# %%
# subset the log2FC and the P_value for this dataset. 
dataset_late_combined.columns = ['log2FC','P_value']

# obtain the -logP_adj for the dataset. 
dataset_late_combined['-logP_adj'] = -np.log10(dataset_late_combined['P_value'])

# set a class for up (1) or down (-1) proteins. 
dataset_late_combined['class'] = 0
dataset_late_combined.loc[(dataset_late_combined['log2FC']>log2FC_threshold)&(dataset_late_combined['-logP_adj']>-np.log10(0.05)),'class'] = 1
dataset_late_combined.loc[(dataset_late_combined['log2FC']<-log2FC_threshold)&(dataset_late_combined['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
# # subset the log2FC and the P_value for this dataset. 
# dataset_24h.columns = ['log2FC','P_value']

# # obtain the -logP_adj for the dataset. 
# dataset_24h['-logP_adj'] = -np.log10(dataset_24h['P_value'])

# # set a class for up (1) or down (-1) proteins. 
# dataset_24h['class'] = 0
# dataset_24h.loc[(dataset_24h['log2FC']>log2FC_threshold)&(dataset_24h['-logP_adj']>-np.log10(0.05)),'class'] = 1
# dataset_24h.loc[(dataset_24h['log2FC']<-log2FC_threshold)&(dataset_24h['-logP_adj']>-np.log10(0.05)),'class'] = -1

# %%
volcano_plot(dataset_late_combined)
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/1246007795.py:202: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_min = df.min()[0]-1
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/1246007795.py:203: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_max = df.max()[0]+1
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/1246007795.py:206: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_max = dataset.max()[2]+1

# %%
# volcano_plot(dataset_24h)

# %% [markdown]
# ## Compare Oscillation vs Low.

# %% [markdown]
# ### prep for p-values.

# %%
prot = annotated_redox[sample_ids_prot_redox]
annotated_redox['Protein'] = annotated_redox['Site']
prot.index = annotated_redox['Site']
# drop oscillations.
# prot_control_vs_oscillation_24h = prot.drop(prot.columns[prot.columns.str.contains("Low")], axis=1)
prot_oscillation_vs_low_late_combined = prot.drop(prot.columns[prot.columns.str.contains("Control")], axis=1)


# drop early timepoints. 
prot_oscillation_vs_low_late_combined = prot_oscillation_vs_low_late_combined.drop(prot_oscillation_vs_low_late_combined.columns[
    prot_oscillation_vs_low_late_combined.columns.str.contains("5.5|3.5|4.5")], axis=1)

# %%
prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))

# %%
# group for mapping in annova. 

condition_series_OscvsLowLateCombined = pd.Series(prot_oscillation_vs_low_late_combined.columns).map(prot_condition_dict)
condition_series_OscvsLowLateCombined.index = prot_oscillation_vs_low_late_combined.columns
condition_series_OscvsLowLateCombined
# Out:
# Biostat2L_29_Oscillation_24    Oscillation
# Biostat2L_29_Oscillation_48    Oscillation
# Biostat2L_29_Oscillation_72    Oscillation
# Biostat2L_30_Oscillation_24    Oscillation
# Biostat2L_30_Oscillation_48    Oscillation
# Biostat2L_30_Oscillation_72    Oscillation
# Biostat2L_31_Oscillation_24    Oscillation
# Biostat2L_31_Oscillation_48    Oscillation
# Biostat2L_31_Oscillation_72    Oscillation
# Biostat2L_32_Low_24                    Low
# Biostat2L_32_Low_48                    Low
# Biostat2L_32_Low_72                    Low
# Biostat2L_33_Low_24                    Low
# Biostat2L_33_Low_48                    Low
# Biostat2L_33_Low_72                    Low
# Biostat2L_34_Low_24                    Low
# Biostat2L_34_Low_48                    Low
# Biostat2L_34_Low_72                    Low
# dtype: object

# %%
# late stats.
prot_OscvsLowLateCombined_stats = global_stats_calc_prot(prot_oscillation_vs_low_late_combined,
                                                                         condition_series_OscvsLowLateCombined)

# %%
# Extract the number between "YarliW29_1|" and "@GLB" using regex.
prot_OscvsLowLateCombined_stats["proteinID"] = prot_OscvsLowLateCombined_stats["Site"].str.extract(r"YarliW29_1\|(\d+)@")



# Convert the extracted number to integer (if needed).
prot_OscvsLowLateCombined_stats["proteinID"] = prot_OscvsLowLateCombined_stats["proteinID"].astype(int)

# %% [markdown]
# ### calculate log2FC

# %%
oscLateCombinedLate = prot_OscvsLowLateCombined_stats.loc[:, prot_OscvsLowLateCombined_stats.columns[
    prot_OscvsLowLateCombined_stats.columns.str.contains("Oscillation")]]


oscLateCombinedLate.head()
# Out:
#    Biostat2L_29_Oscillation_24  Biostat2L_29_Oscillation_48  \
# 0                    17.771583                    18.596711
# 1                    19.220965                    19.952574
# 2                          NaN                          NaN
# 3                    19.363283                    20.099247
# 4                    17.383142                    18.595572
#
#    Biostat2L_29_Oscillation_72  Biostat2L_30_Oscillation_24  \
# 0                    18.613297                    17.960813
# 1                    19.523283                    19.134185
# 2                          NaN                          NaN
# 3                    20.247919                    19.283361
# 4                    18.774382                    17.304078
#
#    Biostat2L_30_Oscillation_48  Biostat2L_30_Oscillation_72  \
# 0                    18.709230                    18.905539
# 1                    20.119849                    20.001728
# 2                          NaN                          NaN
# 3                    20.387765                    20.516008
# 4                    19.040781                    19.159442
#
#    Biostat2L_31_Oscillation_24  Biostat2L_31_Oscillation_48  \
# 0                    17.714967                    18.328691
# 1                    19.114733                    19.183590
# 2                          NaN                          NaN
# 3                    18.941259                    19.307079
# 4                    16.828341                    18.071971
#
#    Biostat2L_31_Oscillation_72
# 0                    18.647709
# 1                    19.391718
# 2                          NaN
# 3                    19.871772
# 4                    18.858217

# %%
lowLateCombined = prot_OscvsLowLateCombined_stats.loc[:, prot_OscvsLowLateCombined_stats.columns[prot_OscvsLowLateCombined_stats.columns.str.contains("Low")]]
lowLateCombined.head()
# Out:
#    Biostat2L_32_Low_24  Biostat2L_32_Low_48  Biostat2L_32_Low_72  \
# 0            16.478083            16.438153            16.618327
# 1            19.358798            19.919088            19.958991
# 2                  NaN                  NaN                  NaN
# 3            18.641459            18.363472            18.423242
# 4            16.104204            16.517260            17.253550
#
#    Biostat2L_33_Low_24  Biostat2L_33_Low_48  Biostat2L_33_Low_72  \
# 0            16.635118            16.142903            16.651285
# 1            18.321864            19.446600            19.953698
# 2                  NaN                  NaN                  NaN
# 3            18.679093            18.578693            18.428186
# 4            15.447046            16.150221            16.877026
#
#    Biostat2L_34_Low_24  Biostat2L_34_Low_48  Biostat2L_34_Low_72
# 0            16.451691            16.481918            16.782876
# 1            19.104072            19.454477            20.131243
# 2                  NaN                  NaN                  NaN
# 3            18.593297            18.424024            18.238569
# 4            15.920855            16.629091            17.021753

# %%
# gives the increase of the first. 
prot_OscvsLowLateCombined_stats['log2FC_Osc_vs_low_Late']=log2FC_function(oscLateCombinedLate, lowLateCombined)

# %%
df_to_merge = pd.DataFrame()
df_to_merge['osc/low_late_cominbed'] = prot_OscvsLowLateCombined_stats['log2FC_Osc_vs_low_Late']
df_to_merge['Site'] = prot_OscvsLowLateCombined_stats['Site']
df_to_merge['osc/low_late_cominbedANOVA_padj'] = prot_OscvsLowLateCombined_stats['ANOVA_padj']
df_to_merge['osc/low_late_cominbedANOVA_p'] = prot_OscvsLowLateCombined_stats['ANOVA_p']

# %%
merged_df = pd.merge(merged_df, df_to_merge, left_on='Site',right_on='Site', how='left')

# %% [markdown]
# ## Venn Diagram of overlap.

# %% [markdown]
# Saving.

# %%
low_sig = merged_df[
    (merged_df['low/control_late_combined_ANOVA_padj'] < 0.05) &
    (abs(merged_df['low/control_late_combined']) > log2FC_threshold)
]

osc_sig =  merged_df[
    (merged_df['osc/control_late_cominbedANOVA_padj'] < 0.05) &
    (abs(merged_df['osc/control_late_cominbed']) > log2FC_threshold)
]

# %%
low_sig_sites = low_sig['Site'].values
low_sig_sites
osc_sig_sites = osc_sig['Site'].values
osc_sig_sites
# Out:
# array(['jgi|YarliW29_1|1002@C55', 'jgi|YarliW29_1|1002@C88',
#        'jgi|YarliW29_1|1004@C422', 'jgi|YarliW29_1|100@C116',
#        'jgi|YarliW29_1|1014@C389', 'jgi|YarliW29_1|1014@C391',
#        'jgi|YarliW29_1|103@C243', 'jgi|YarliW29_1|1054@C58',
#        'jgi|YarliW29_1|1056@C118', 'jgi|YarliW29_1|1056@C170',
#        'jgi|YarliW29_1|1056@C178', 'jgi|YarliW29_1|1056@C188',
#        'jgi|YarliW29_1|1056@C212', 'jgi|YarliW29_1|1069@C754',
#        'jgi|YarliW29_1|1070@C27', 'jgi|YarliW29_1|1084@C251',
#        'jgi|YarliW29_1|1096@C142', 'jgi|YarliW29_1|1104@C257',
#        'jgi|YarliW29_1|1109@C657', 'jgi|YarliW29_1|1119@C225',
#        'jgi|YarliW29_1|1125@C701', 'jgi|YarliW29_1|1127@C12',
#        'jgi|YarliW29_1|1127@C17', 'jgi|YarliW29_1|1127@C74',
#        'jgi|YarliW29_1|1127@C77', 'jgi|YarliW29_1|1136@C180',
#        'jgi|YarliW29_1|1141@C316', 'jgi|YarliW29_1|1175@C442',
#        'jgi|YarliW29_1|1188@C244', 'jgi|YarliW29_1|1188@C290',
#        'jgi|YarliW29_1|1188@C342', 'jgi|YarliW29_1|1196@C216',
#        'jgi|YarliW29_1|1199@C158', 'jgi|YarliW29_1|1199@C195',
#        'jgi|YarliW29_1|119@C241', 'jgi|YarliW29_1|1215@C97',
#        'jgi|YarliW29_1|121@C166', 'jgi|YarliW29_1|1235@C101',
#        'jgi|YarliW29_1|1275@C110', 'jgi|YarliW29_1|1275@C76',
#        'jgi|YarliW29_1|1288@C284', 'jgi|YarliW29_1|1291@C472',
#        'jgi|YarliW29_1|1319@C236', 'jgi|YarliW29_1|1347@C352',
#        'jgi|YarliW29_1|1368@C195', 'jgi|YarliW29_1|1380@C216',
#        'jgi|YarliW29_1|1387@C150', 'jgi|YarliW29_1|1387@C153',
#        'jgi|YarliW29_1|1387@C301', 'jgi|YarliW29_1|1416@C306',
#        'jgi|YarliW29_1|1416@C82', 'jgi|YarliW29_1|1422@C390',
#        'jgi|YarliW29_1|1422@C59', 'jgi|YarliW29_1|1435@C1158',
#        'jgi|YarliW29_1|1451@C179', 'jgi|YarliW29_1|1466@C139',
#        'jgi|YarliW29_1|1466@C292', 'jgi|YarliW29_1|1469@C227',
#        'jgi|YarliW29_1|146@C425', 'jgi|YarliW29_1|146@C520',
#        'jgi|YarliW29_1|1488@C576', 'jgi|YarliW29_1|1514@C598',
#        'jgi|YarliW29_1|1533@C201', 'jgi|YarliW29_1|1533@C77',
#        'jgi|YarliW29_1|1554@C691', 'jgi|YarliW29_1|1560@C29',
#        'jgi|YarliW29_1|1560@C32', 'jgi|YarliW29_1|1562@C676',
#        'jgi|YarliW29_1|1573@C176', 'jgi|YarliW29_1|1576@C623',
#        'jgi|YarliW29_1|1576@C920', 'jgi|YarliW29_1|1582@C20',
#        'jgi|YarliW29_1|1582@C30', 'jgi|YarliW29_1|1609@C240',
#        'jgi|YarliW29_1|1615@C96', 'jgi|YarliW29_1|1627@C144',
#        'jgi|YarliW29_1|1631@C100', 'jgi|YarliW29_1|1631@C254',
#        'jgi|YarliW29_1|1631@C279', 'jgi|YarliW29_1|1631@C288',
#        'jgi|YarliW29_1|1631@C377', 'jgi|YarliW29_1|1631@C45',
#        'jgi|YarliW29_1|1633@C135', 'jgi|YarliW29_1|1659@C436',
#        'jgi|YarliW29_1|1659@C446', 'jgi|YarliW29_1|1665@C346',
#        'jgi|YarliW29_1|1674@C97', 'jgi|YarliW29_1|1678@C295',
#        'jgi|YarliW29_1|1678@C31', 'jgi|YarliW29_1|1678@C37',
#        'jgi|YarliW29_1|1678@C65', 'jgi|YarliW29_1|1678@C71',
#        'jgi|YarliW29_1|1684@C195', 'jgi|YarliW29_1|1693@C114',
#        'jgi|YarliW29_1|1700@C713', 'jgi|YarliW29_1|1713@C73',
#        'jgi|YarliW29_1|1714@C1000', 'jgi|YarliW29_1|1714@C168',
#        'jgi|YarliW29_1|1714@C868', 'jgi|YarliW29_1|1719@C597',
#        'jgi|YarliW29_1|1724@C351', 'jgi|YarliW29_1|1729@C235',
#        'jgi|YarliW29_1|1731@C300', 'jgi|YarliW29_1|1752@C433',
#        'jgi|YarliW29_1|1752@C436', 'jgi|YarliW29_1|1758@C53',
#        'jgi|YarliW29_1|1759@C400', 'jgi|YarliW29_1|1766@C72',
#        'jgi|YarliW29_1|17@C315', 'jgi|YarliW29_1|1811@C13',
#        'jgi|YarliW29_1|1811@C16', 'jgi|YarliW29_1|1814@C285',
#        'jgi|YarliW29_1|181@C286', 'jgi|YarliW29_1|181@C356',
#        'jgi|YarliW29_1|181@C360', 'jgi|YarliW29_1|181@C419',
#        'jgi|YarliW29_1|181@C478', 'jgi|YarliW29_1|181@C484',
#        'jgi|YarliW29_1|1867@C985', 'jgi|YarliW29_1|1887@C23',
#        'jgi|YarliW29_1|1888@C1738', 'jgi|YarliW29_1|1888@C1742',
#        'jgi|YarliW29_1|1888@C565', 'jgi|YarliW29_1|1889@C56',
#        'jgi|YarliW29_1|1901@C273', 'jgi|YarliW29_1|1906@C126',
#        'jgi|YarliW29_1|1906@C84', 'jgi|YarliW29_1|1922@C177',
#        'jgi|YarliW29_1|1922@C221', 'jgi|YarliW29_1|1922@C227',
#        'jgi|YarliW29_1|1934@C63', 'jgi|YarliW29_1|1944@C173',
#        'jgi|YarliW29_1|1947@C62', 'jgi|YarliW29_1|1952@C226',
#        'jgi|YarliW29_1|1971@C274', 'jgi|YarliW29_1|1974@C482',
#        'jgi|YarliW29_1|197@C546', 'jgi|YarliW29_1|197@C826',
#        'jgi|YarliW29_1|1996@C484', 'jgi|YarliW29_1|2015@C520',
#        'jgi|YarliW29_1|2027@C45', 'jgi|YarliW29_1|202@C256',
#        'jgi|YarliW29_1|2036@C10', 'jgi|YarliW29_1|2056@C228',
#        'jgi|YarliW29_1|2056@C52', 'jgi|YarliW29_1|2061@C293',
#        'jgi|YarliW29_1|2061@C316', 'jgi|YarliW29_1|2061@C317',
#        'jgi|YarliW29_1|2064@C582', 'jgi|YarliW29_1|2075@C975',
#        'jgi|YarliW29_1|2095@C369', 'jgi|YarliW29_1|2097@C121',
#        'jgi|YarliW29_1|2097@C762', 'jgi|YarliW29_1|2107@C933',
#        'jgi|YarliW29_1|212@C431', 'jgi|YarliW29_1|212@C690',
#        'jgi|YarliW29_1|2149@C3467', 'jgi|YarliW29_1|214@C70',
#        'jgi|YarliW29_1|2184@C58', 'jgi|YarliW29_1|2184@C62',
#        'jgi|YarliW29_1|2194@C200', 'jgi|YarliW29_1|2204@C121',
#        'jgi|YarliW29_1|2204@C332', 'jgi|YarliW29_1|2216@C449',
#        'jgi|YarliW29_1|2223@C450', 'jgi|YarliW29_1|2225@C679',
#        'jgi|YarliW29_1|2243@C4', 'jgi|YarliW29_1|2260@C172',
#        'jgi|YarliW29_1|2260@C207', 'jgi|YarliW29_1|2260@C234',
#        'jgi|YarliW29_1|2263@C105', 'jgi|YarliW29_1|2263@C122',
#        'jgi|YarliW29_1|2286@C44', 'jgi|YarliW29_1|2286@C47',
#        'jgi|YarliW29_1|2298@C421', 'jgi|YarliW29_1|2302@C387',
#        'jgi|YarliW29_1|2313@C80', 'jgi|YarliW29_1|2313@C90',
#        'jgi|YarliW29_1|2338@C304', 'jgi|YarliW29_1|2339@C76',
#        'jgi|YarliW29_1|2346@C51', 'jgi|YarliW29_1|2350@C275',
#        'jgi|YarliW29_1|2351@C277', 'jgi|YarliW29_1|2351@C32',
#        'jgi|YarliW29_1|2358@C409', 'jgi|YarliW29_1|2363@C414',
#        'jgi|YarliW29_1|2374@C549', 'jgi|YarliW29_1|2374@C669',
#        'jgi|YarliW29_1|2384@C521', 'jgi|YarliW29_1|2384@C580',
#        'jgi|YarliW29_1|238@C226', 'jgi|YarliW29_1|238@C356',
#        'jgi|YarliW29_1|2391@C428', 'jgi|YarliW29_1|2401@C210',
#        'jgi|YarliW29_1|2407@C245', 'jgi|YarliW29_1|2407@C974',
#        'jgi|YarliW29_1|2416@C24', 'jgi|YarliW29_1|2416@C247',
#        'jgi|YarliW29_1|2453@C101', 'jgi|YarliW29_1|2453@C146',
#        'jgi|YarliW29_1|2459@C272', 'jgi|YarliW29_1|2484@C478',
#        'jgi|YarliW29_1|2492@C336', 'jgi|YarliW29_1|2492@C369',
#        'jgi|YarliW29_1|2495@C102', 'jgi|YarliW29_1|2558@C361',
#        'jgi|YarliW29_1|2569@C201', 'jgi|YarliW29_1|2569@C347',
#        'jgi|YarliW29_1|2571@C29', 'jgi|YarliW29_1|2571@C36',
#        'jgi|YarliW29_1|2600@C98', 'jgi|YarliW29_1|2623@C591',
#        'jgi|YarliW29_1|2623@C813', 'jgi|YarliW29_1|2631@C76',
#        'jgi|YarliW29_1|2649@C69', 'jgi|YarliW29_1|2658@C100',
#        'jgi|YarliW29_1|2658@C97', 'jgi|YarliW29_1|2701@C129',
#        'jgi|YarliW29_1|2717@C198', 'jgi|YarliW29_1|2748@C86',
#        'jgi|YarliW29_1|2819@C615', 'jgi|YarliW29_1|2819@C618',
#        'jgi|YarliW29_1|2823@C140', 'jgi|YarliW29_1|2839@C100',
#        'jgi|YarliW29_1|2839@C106', 'jgi|YarliW29_1|2839@C108',
#        'jgi|YarliW29_1|2839@C111', 'jgi|YarliW29_1|2839@C119',
#        'jgi|YarliW29_1|2839@C63', 'jgi|YarliW29_1|2839@C98',
#        'jgi|YarliW29_1|2872@C271', 'jgi|YarliW29_1|2913@C325',
#        'jgi|YarliW29_1|2913@C330', 'jgi|YarliW29_1|2927@C345',
#        'jgi|YarliW29_1|2936@C324', 'jgi|YarliW29_1|2936@C626',
#        'jgi|YarliW29_1|2956@C130', 'jgi|YarliW29_1|2956@C385',
#        'jgi|YarliW29_1|2975@C29', 'jgi|YarliW29_1|3000@C386',
#        'jgi|YarliW29_1|3022@C108', 'jgi|YarliW29_1|3027@C239',
#        'jgi|YarliW29_1|3034@C333', 'jgi|YarliW29_1|3034@C338',
#        'jgi|YarliW29_1|3037@C144', 'jgi|YarliW29_1|3041@C291',
#        'jgi|YarliW29_1|3041@C296', 'jgi|YarliW29_1|306@C1087',
#        'jgi|YarliW29_1|3071@C625', 'jgi|YarliW29_1|3072@C48',
#        'jgi|YarliW29_1|3072@C51', 'jgi|YarliW29_1|3072@C65',
#        'jgi|YarliW29_1|3072@C68', 'jgi|YarliW29_1|3080@C1369',
#        'jgi|YarliW29_1|3080@C350', 'jgi|YarliW29_1|3080@C688',
#        'jgi|YarliW29_1|3080@C708', 'jgi|YarliW29_1|3082@C230',
#        'jgi|YarliW29_1|3082@C244', 'jgi|YarliW29_1|3098@C233',
#        'jgi|YarliW29_1|3098@C27', 'jgi|YarliW29_1|3098@C33',
#        'jgi|YarliW29_1|3098@C45', 'jgi|YarliW29_1|3098@C80',
#        'jgi|YarliW29_1|3098@C81', 'jgi|YarliW29_1|3098@C915',
#        'jgi|YarliW29_1|3098@C924', 'jgi|YarliW29_1|3098@C927',
#        'jgi|YarliW29_1|3098@C963', 'jgi|YarliW29_1|3107@C315',
#        'jgi|YarliW29_1|3111@C109', 'jgi|YarliW29_1|3111@C78',
#        'jgi|YarliW29_1|3129@C208', 'jgi|YarliW29_1|3129@C264',
#        'jgi|YarliW29_1|3131@C203', 'jgi|YarliW29_1|3135@C382',
#        'jgi|YarliW29_1|3135@C390', 'jgi|YarliW29_1|3135@C53',
#        'jgi|YarliW29_1|3135@C62', 'jgi|YarliW29_1|3139@C281',
#        'jgi|YarliW29_1|3140@C362', 'jgi|YarliW29_1|3140@C376',
#        'jgi|YarliW29_1|3140@C386', 'jgi|YarliW29_1|3140@C393',
#        'jgi|YarliW29_1|3140@C402', 'jgi|YarliW29_1|3140@C409',
#        'jgi|YarliW29_1|3140@C431', 'jgi|YarliW29_1|3140@C437',
#        'jgi|YarliW29_1|3140@C510', 'jgi|YarliW29_1|3162@C117',
#        'jgi|YarliW29_1|3172@C1226', 'jgi|YarliW29_1|3189@C115',
#        'jgi|YarliW29_1|3189@C118', 'jgi|YarliW29_1|3189@C746',
#        'jgi|YarliW29_1|3207@C587', 'jgi|YarliW29_1|3207@C604',
#        'jgi|YarliW29_1|3214@C61', 'jgi|YarliW29_1|3218@C141',
#        'jgi|YarliW29_1|3218@C144', 'jgi|YarliW29_1|3218@C170',
#        'jgi|YarliW29_1|3224@C209', 'jgi|YarliW29_1|3226@C637',
#        'jgi|YarliW29_1|3232@C486', 'jgi|YarliW29_1|3243@C234',
#        'jgi|YarliW29_1|3243@C236', 'jgi|YarliW29_1|3243@C243',
#        'jgi|YarliW29_1|3264@C165', 'jgi|YarliW29_1|3264@C231',
#        'jgi|YarliW29_1|3264@C350', 'jgi|YarliW29_1|3271@C269',
#        'jgi|YarliW29_1|3275@C373', 'jgi|YarliW29_1|3284@C12',
#        'jgi|YarliW29_1|3300@C687', 'jgi|YarliW29_1|3300@C692',
#        'jgi|YarliW29_1|3319@C48', 'jgi|YarliW29_1|3319@C51',
#        'jgi|YarliW29_1|332@C1026', 'jgi|YarliW29_1|3336@C162',
#        'jgi|YarliW29_1|3336@C19', 'jgi|YarliW29_1|3340@C411',
#        'jgi|YarliW29_1|3340@C412', 'jgi|YarliW29_1|3367@C192',
#        'jgi|YarliW29_1|3376@C314', 'jgi|YarliW29_1|3386@C188',
#        'jgi|YarliW29_1|3389@C287', 'jgi|YarliW29_1|3393@C109',
#        'jgi|YarliW29_1|3393@C516', 'jgi|YarliW29_1|3410@C68',
#        'jgi|YarliW29_1|3412@C209', 'jgi|YarliW29_1|3414@C294',
#        'jgi|YarliW29_1|3414@C345', 'jgi|YarliW29_1|3414@C354',
#        'jgi|YarliW29_1|3436@C169', 'jgi|YarliW29_1|3455@C56',
#        'jgi|YarliW29_1|3486@C358', 'jgi|YarliW29_1|3519@C206',
#        'jgi|YarliW29_1|3519@C91', 'jgi|YarliW29_1|351@C1279',
#        'jgi|YarliW29_1|3534@C1331', 'jgi|YarliW29_1|3534@C66',
#        'jgi|YarliW29_1|3535@C290', 'jgi|YarliW29_1|3538@C221',
#        'jgi|YarliW29_1|354@C86', 'jgi|YarliW29_1|3574@C27',
#        'jgi|YarliW29_1|3580@C396', 'jgi|YarliW29_1|3580@C403',
#        'jgi|YarliW29_1|3590@C426', 'jgi|YarliW29_1|3592@C240',
#        'jgi|YarliW29_1|3617@C611', 'jgi|YarliW29_1|3625@C52',
#        'jgi|YarliW29_1|3625@C56', 'jgi|YarliW29_1|3654@C230',
#        'jgi|YarliW29_1|365@C41', 'jgi|YarliW29_1|3660@C33',
#        'jgi|YarliW29_1|3686@C352', 'jgi|YarliW29_1|3686@C360',
#        'jgi|YarliW29_1|3686@C394', 'jgi|YarliW29_1|3690@C312',
#        'jgi|YarliW29_1|3692@C223', 'jgi|YarliW29_1|3692@C284',
#        'jgi|YarliW29_1|3692@C289', 'jgi|YarliW29_1|3692@C298',
#        'jgi|YarliW29_1|3695@C26', 'jgi|YarliW29_1|3700@C638',
#        'jgi|YarliW29_1|3727@C274', 'jgi|YarliW29_1|3746@C43',
#        'jgi|YarliW29_1|3748@C132', 'jgi|YarliW29_1|3759@C125',
#        'jgi|YarliW29_1|3759@C331', 'jgi|YarliW29_1|3766@C199',
#        'jgi|YarliW29_1|3766@C244', 'jgi|YarliW29_1|3770@C202',
#        'jgi|YarliW29_1|3771@C290', 'jgi|YarliW29_1|3772@C216',
#        'jgi|YarliW29_1|3772@C236', 'jgi|YarliW29_1|3792@C146',
#        'jgi|YarliW29_1|3794@C255', 'jgi|YarliW29_1|3812@C764',
#        'jgi|YarliW29_1|3813@C81', 'jgi|YarliW29_1|3825@C262',
#        'jgi|YarliW29_1|3825@C269', 'jgi|YarliW29_1|382@C476',
#        'jgi|YarliW29_1|3834@C250', 'jgi|YarliW29_1|3839@C95',
#        'jgi|YarliW29_1|3840@C22', 'jgi|YarliW29_1|3840@C31',
#        'jgi|YarliW29_1|3841@C1287', 'jgi|YarliW29_1|3841@C1293',
#        'jgi|YarliW29_1|3850@C127', 'jgi|YarliW29_1|3850@C329',
#        'jgi|YarliW29_1|3859@C79', 'jgi|YarliW29_1|385@C78',
#        'jgi|YarliW29_1|3880@C141', 'jgi|YarliW29_1|3880@C15',
#        'jgi|YarliW29_1|3880@C178', 'jgi|YarliW29_1|3880@C18',
#        'jgi|YarliW29_1|3884@C161', 'jgi|YarliW29_1|3891@C199',
#        'jgi|YarliW29_1|3891@C50', 'jgi|YarliW29_1|3891@C79',
#        'jgi|YarliW29_1|3909@C360', 'jgi|YarliW29_1|3916@C181',
#        'jgi|YarliW29_1|3926@C192', 'jgi|YarliW29_1|3929@C121',
#        'jgi|YarliW29_1|3932@C173', 'jgi|YarliW29_1|3932@C195',
#        'jgi|YarliW29_1|3953@C571', 'jgi|YarliW29_1|3984@C471',
#        'jgi|YarliW29_1|4003@C270', 'jgi|YarliW29_1|402@C49',
#        'jgi|YarliW29_1|4032@C655', 'jgi|YarliW29_1|4071@C199',
#        'jgi|YarliW29_1|4075@C205', 'jgi|YarliW29_1|40@C366',
#        'jgi|YarliW29_1|4113@C363', 'jgi|YarliW29_1|4114@C47',
#        'jgi|YarliW29_1|4114@C50', 'jgi|YarliW29_1|4171@C181',
#        'jgi|YarliW29_1|4221@C197', 'jgi|YarliW29_1|4221@C297',
#        'jgi|YarliW29_1|4251@C860', 'jgi|YarliW29_1|4282@C475',
#        'jgi|YarliW29_1|4311@C182', 'jgi|YarliW29_1|4311@C208',
#        'jgi|YarliW29_1|4311@C348', 'jgi|YarliW29_1|4351@C111',
#        'jgi|YarliW29_1|4351@C118', 'jgi|YarliW29_1|4351@C151',
#        'jgi|YarliW29_1|4351@C161', 'jgi|YarliW29_1|4362@C1042',
#        'jgi|YarliW29_1|4388@C938', 'jgi|YarliW29_1|4397@C732',
#        'jgi|YarliW29_1|4400@C575', 'jgi|YarliW29_1|4417@C266',
#        'jgi|YarliW29_1|4418@C110', 'jgi|YarliW29_1|4442@C830',
#        'jgi|YarliW29_1|4445@C468', 'jgi|YarliW29_1|4450@C109',
#        'jgi|YarliW29_1|4450@C94', 'jgi|YarliW29_1|4450@C97',
#        'jgi|YarliW29_1|446@C173', 'jgi|YarliW29_1|446@C179',
#        'jgi|YarliW29_1|4487@C603', 'jgi|YarliW29_1|4496@C764',
#        'jgi|YarliW29_1|4496@C768', 'jgi|YarliW29_1|4496@C805',
#        'jgi|YarliW29_1|4538@C260', 'jgi|YarliW29_1|4563@C55',
#        'jgi|YarliW29_1|4563@C59', 'jgi|YarliW29_1|4590@C535',
#        'jgi|YarliW29_1|4594@C595', 'jgi|YarliW29_1|4594@C596',
#        'jgi|YarliW29_1|4643@C260', 'jgi|YarliW29_1|4643@C420',
#        'jgi|YarliW29_1|4672@C59', 'jgi|YarliW29_1|4743@C266',
#        'jgi|YarliW29_1|4743@C312', 'jgi|YarliW29_1|4752@C387',
#        'jgi|YarliW29_1|4762@C64', 'jgi|YarliW29_1|4767@C480',
#        'jgi|YarliW29_1|4775@C185', 'jgi|YarliW29_1|4780@C29',
#        'jgi|YarliW29_1|4780@C43', 'jgi|YarliW29_1|4780@C46',
#        'jgi|YarliW29_1|4783@C228', 'jgi|YarliW29_1|4783@C59',
#        'jgi|YarliW29_1|4783@C62', 'jgi|YarliW29_1|478@C984',
#        'jgi|YarliW29_1|4793@C920', 'jgi|YarliW29_1|4797@C76',
#        'jgi|YarliW29_1|4805@C47', 'jgi|YarliW29_1|4805@C50',
#        'jgi|YarliW29_1|4821@C93', 'jgi|YarliW29_1|4827@C403',
#        'jgi|YarliW29_1|4835@C171', 'jgi|YarliW29_1|4837@C168',
#        'jgi|YarliW29_1|4838@C121', 'jgi|YarliW29_1|4838@C66',
#        'jgi|YarliW29_1|4838@C70', 'jgi|YarliW29_1|484@C126',
#        'jgi|YarliW29_1|4851@C840', 'jgi|YarliW29_1|4862@C236',
#        'jgi|YarliW29_1|4869@C242', 'jgi|YarliW29_1|4880@C486',
#        'jgi|YarliW29_1|4880@C931', 'jgi|YarliW29_1|4900@C22',
#        'jgi|YarliW29_1|4903@C35', 'jgi|YarliW29_1|4903@C39',
#        'jgi|YarliW29_1|4910@C204', 'jgi|YarliW29_1|4918@C313',
#        'jgi|YarliW29_1|4918@C704', 'jgi|YarliW29_1|4918@C708',
#        'jgi|YarliW29_1|4918@C717', 'jgi|YarliW29_1|4927@C185',
#        'jgi|YarliW29_1|4929@C224', 'jgi|YarliW29_1|4933@C128',
#        'jgi|YarliW29_1|4933@C131', 'jgi|YarliW29_1|4936@C100',
#        'jgi|YarliW29_1|4951@C830', 'jgi|YarliW29_1|4960@C27',
#        'jgi|YarliW29_1|4969@C125', 'jgi|YarliW29_1|4969@C311',
#        'jgi|YarliW29_1|4974@C416', 'jgi|YarliW29_1|4974@C420',
#        'jgi|YarliW29_1|4977@C216', 'jgi|YarliW29_1|4993@C193',
#        'jgi|YarliW29_1|4994@C1392', 'jgi|YarliW29_1|5001@C1584',
#        'jgi|YarliW29_1|5001@C239', 'jgi|YarliW29_1|5021@C116',
#        'jgi|YarliW29_1|5032@C78', 'jgi|YarliW29_1|5037@C592',
#        'jgi|YarliW29_1|5044@C423', 'jgi|YarliW29_1|5044@C467',
#        'jgi|YarliW29_1|5046@C419', 'jgi|YarliW29_1|5046@C546',
#        'jgi|YarliW29_1|5065@C386', 'jgi|YarliW29_1|5077@C1015',
#        'jgi|YarliW29_1|5077@C993', 'jgi|YarliW29_1|5093@C82',
#        'jgi|YarliW29_1|5106@C2140', 'jgi|YarliW29_1|5134@C325',
#        'jgi|YarliW29_1|5134@C328', 'jgi|YarliW29_1|5147@C130',
#        'jgi|YarliW29_1|5147@C345', 'jgi|YarliW29_1|5147@C347',
#        'jgi|YarliW29_1|5147@C396', 'jgi|YarliW29_1|5150@C290',
#        'jgi|YarliW29_1|5162@C779', 'jgi|YarliW29_1|5185@C373',
#        'jgi|YarliW29_1|5214@C72', 'jgi|YarliW29_1|5214@C76',
#        'jgi|YarliW29_1|5227@C50', 'jgi|YarliW29_1|5239@C58',
#        'jgi|YarliW29_1|5245@C947', 'jgi|YarliW29_1|5245@C952',
#        'jgi|YarliW29_1|5253@C222', 'jgi|YarliW29_1|5253@C445',
#        'jgi|YarliW29_1|5256@C126', 'jgi|YarliW29_1|5256@C136',
#        'jgi|YarliW29_1|5256@C303', 'jgi|YarliW29_1|5261@C230',
#        'jgi|YarliW29_1|5272@C355', 'jgi|YarliW29_1|5277@C135',
#        'jgi|YarliW29_1|5277@C145', 'jgi|YarliW29_1|5277@C180',
#        'jgi|YarliW29_1|5277@C278', 'jgi|YarliW29_1|5277@C394',
#        'jgi|YarliW29_1|528@C339', 'jgi|YarliW29_1|528@C342',
#        'jgi|YarliW29_1|5291@C442', 'jgi|YarliW29_1|5291@C921',
#        'jgi|YarliW29_1|5298@C51', 'jgi|YarliW29_1|5336@C808',
#        'jgi|YarliW29_1|5337@C23', 'jgi|YarliW29_1|5345@C224',
#        'jgi|YarliW29_1|5351@C205', 'jgi|YarliW29_1|5351@C209',
#        'jgi|YarliW29_1|5351@C67', 'jgi|YarliW29_1|5375@C157',
#        'jgi|YarliW29_1|5375@C189', 'jgi|YarliW29_1|5375@C202',
#        'jgi|YarliW29_1|5375@C213', 'jgi|YarliW29_1|5383@C829',
#        'jgi|YarliW29_1|5397@C476', 'jgi|YarliW29_1|5409@C270',
#        'jgi|YarliW29_1|5410@C565', 'jgi|YarliW29_1|5410@C568',
#        'jgi|YarliW29_1|5444@C61', 'jgi|YarliW29_1|5447@C159',
#        'jgi|YarliW29_1|5458@C373', 'jgi|YarliW29_1|5462@C866',
#        'jgi|YarliW29_1|5484@C46', 'jgi|YarliW29_1|5489@C326',
#        'jgi|YarliW29_1|5495@C47', 'jgi|YarliW29_1|5497@C557',
#        'jgi|YarliW29_1|5530@C434', 'jgi|YarliW29_1|5531@C74',
#        'jgi|YarliW29_1|5543@C400', 'jgi|YarliW29_1|5543@C97',
#        'jgi|YarliW29_1|5564@C223', 'jgi|YarliW29_1|5581@C173',
#        'jgi|YarliW29_1|5581@C51', 'jgi|YarliW29_1|5610@C140',
#        'jgi|YarliW29_1|5612@C259', 'jgi|YarliW29_1|5624@C265',
#        'jgi|YarliW29_1|5639@C48', 'jgi|YarliW29_1|5646@C36',
#        'jgi|YarliW29_1|5646@C44', 'jgi|YarliW29_1|5646@C46',
#        'jgi|YarliW29_1|5646@C61', 'jgi|YarliW29_1|5646@C77',
#        'jgi|YarliW29_1|5652@C117', 'jgi|YarliW29_1|5657@C132',
#        'jgi|YarliW29_1|5657@C192', 'jgi|YarliW29_1|5657@C195',
#        'jgi|YarliW29_1|5657@C42', 'jgi|YarliW29_1|5663@C1068',
#        'jgi|YarliW29_1|5664@C148', 'jgi|YarliW29_1|5664@C87',
#        'jgi|YarliW29_1|5664@C96', 'jgi|YarliW29_1|5668@C71',
#        'jgi|YarliW29_1|5678@C132', 'jgi|YarliW29_1|568@C363',
#        'jgi|YarliW29_1|5698@C218', 'jgi|YarliW29_1|5711@C715',
#        'jgi|YarliW29_1|5712@C35', 'jgi|YarliW29_1|5718@C351',
#        'jgi|YarliW29_1|5741@C54', 'jgi|YarliW29_1|5751@C126',
#        'jgi|YarliW29_1|5751@C164', 'jgi|YarliW29_1|5759@C97',
#        'jgi|YarliW29_1|5762@C220', 'jgi|YarliW29_1|5762@C312',
#        'jgi|YarliW29_1|5766@C105', 'jgi|YarliW29_1|5769@C156',
#        'jgi|YarliW29_1|5775@C97', 'jgi|YarliW29_1|5828@C59',
#        'jgi|YarliW29_1|5828@C63', 'jgi|YarliW29_1|5843@C287',
#        'jgi|YarliW29_1|5863@C388', 'jgi|YarliW29_1|5864@C261',
#        'jgi|YarliW29_1|5875@C53', 'jgi|YarliW29_1|5875@C83',
#        'jgi|YarliW29_1|5877@C153', 'jgi|YarliW29_1|5877@C242',
#        'jgi|YarliW29_1|5887@C292', 'jgi|YarliW29_1|5919@C635',
#        'jgi|YarliW29_1|5919@C638', 'jgi|YarliW29_1|5944@C141',
#        'jgi|YarliW29_1|5945@C94', 'jgi|YarliW29_1|5950@C1278',
#        'jgi|YarliW29_1|5952@C246', 'jgi|YarliW29_1|5952@C454',
#        'jgi|YarliW29_1|5952@C65', 'jgi|YarliW29_1|5953@C245',
#        'jgi|YarliW29_1|5954@C61', 'jgi|YarliW29_1|5975@C430',
#        'jgi|YarliW29_1|5979@C348', 'jgi|YarliW29_1|6001@C8',
#        'jgi|YarliW29_1|6015@C353', 'jgi|YarliW29_1|6045@C143',
#        'jgi|YarliW29_1|6049@C1074', 'jgi|YarliW29_1|6066@C71',
#        'jgi|YarliW29_1|6085@C204', 'jgi|YarliW29_1|6094@C264',
#        'jgi|YarliW29_1|6098@C1450', 'jgi|YarliW29_1|6118@C261',
#        'jgi|YarliW29_1|6118@C264', 'jgi|YarliW29_1|6127@C1743',
#        'jgi|YarliW29_1|6131@C314', 'jgi|YarliW29_1|6131@C327',
#        'jgi|YarliW29_1|6146@C1240', 'jgi|YarliW29_1|6168@C529',
#        'jgi|YarliW29_1|6175@C23', 'jgi|YarliW29_1|6178@C524',
#        'jgi|YarliW29_1|6181@C26', 'jgi|YarliW29_1|6181@C36',
#        'jgi|YarliW29_1|6181@C47', 'jgi|YarliW29_1|6181@C57',
#        'jgi|YarliW29_1|6185@C210', 'jgi|YarliW29_1|6187@C45',
#        'jgi|YarliW29_1|6187@C64', 'jgi|YarliW29_1|6217@C272',
#        'jgi|YarliW29_1|6230@C198', 'jgi|YarliW29_1|6230@C208',
#        'jgi|YarliW29_1|6242@C419', 'jgi|YarliW29_1|6244@C415',
#        'jgi|YarliW29_1|626@C667', 'jgi|YarliW29_1|6270@C756',
#        'jgi|YarliW29_1|6273@C269', 'jgi|YarliW29_1|6277@C51',
#        'jgi|YarliW29_1|6277@C58', 'jgi|YarliW29_1|6278@C305',
#        'jgi|YarliW29_1|6302@C232', 'jgi|YarliW29_1|6307@C427',
#        'jgi|YarliW29_1|6313@C210', 'jgi|YarliW29_1|6323@C58',
#        'jgi|YarliW29_1|6325@C158', 'jgi|YarliW29_1|6341@C143',
#        'jgi|YarliW29_1|6341@C206', 'jgi|YarliW29_1|6341@C309',
#        'jgi|YarliW29_1|6352@C30', 'jgi|YarliW29_1|6355@C142',
#        'jgi|YarliW29_1|6370@C99', 'jgi|YarliW29_1|6384@C133',
#        'jgi|YarliW29_1|6392@C136', 'jgi|YarliW29_1|6392@C140',
#        'jgi|YarliW29_1|63@C99', 'jgi|YarliW29_1|6406@C119',
#        'jgi|YarliW29_1|6410@C455', 'jgi|YarliW29_1|6412@C118',
#        'jgi|YarliW29_1|6412@C151', 'jgi|YarliW29_1|6412@C161',
#        'jgi|YarliW29_1|6419@C56', 'jgi|YarliW29_1|6419@C59',
#        'jgi|YarliW29_1|6419@C81', 'jgi|YarliW29_1|6427@C215',
#        'jgi|YarliW29_1|6434@C498', 'jgi|YarliW29_1|6434@C511',
#        'jgi|YarliW29_1|6434@C687', 'jgi|YarliW29_1|6438@C467',
#        'jgi|YarliW29_1|643@C65', 'jgi|YarliW29_1|643@C67',
#        'jgi|YarliW29_1|6440@C420', 'jgi|YarliW29_1|6440@C470',
#        'jgi|YarliW29_1|6472@C185', 'jgi|YarliW29_1|6478@C398',
#        'jgi|YarliW29_1|6502@C227', 'jgi|YarliW29_1|6504@C337',
#        'jgi|YarliW29_1|650@C347', 'jgi|YarliW29_1|650@C45',
#        'jgi|YarliW29_1|6512@C775', 'jgi|YarliW29_1|6545@C173',
#        'jgi|YarliW29_1|6549@C705', 'jgi|YarliW29_1|6571@C102',
#        'jgi|YarliW29_1|6578@C57', 'jgi|YarliW29_1|6581@C471',
#        'jgi|YarliW29_1|6610@C112', 'jgi|YarliW29_1|6610@C331',
#        'jgi|YarliW29_1|6610@C355', 'jgi|YarliW29_1|6625@C200',
#        'jgi|YarliW29_1|6625@C514', 'jgi|YarliW29_1|6625@C607',
#        'jgi|YarliW29_1|6625@C709', 'jgi|YarliW29_1|6625@C728',
#        'jgi|YarliW29_1|6628@C144', 'jgi|YarliW29_1|6628@C296',
#        'jgi|YarliW29_1|6628@C321', 'jgi|YarliW29_1|6628@C419',
#        'jgi|YarliW29_1|6672@C119', 'jgi|YarliW29_1|6679@C18',
#        'jgi|YarliW29_1|6686@C370', 'jgi|YarliW29_1|6746@C120',
#        'jgi|YarliW29_1|6754@C10', 'jgi|YarliW29_1|6759@C74',
#        'jgi|YarliW29_1|6759@C78', 'jgi|YarliW29_1|6773@C200',
#        'jgi|YarliW29_1|6773@C214', 'jgi|YarliW29_1|6777@C199',
#        'jgi|YarliW29_1|6797@C320', 'jgi|YarliW29_1|6802@C374',
#        'jgi|YarliW29_1|6822@C133', 'jgi|YarliW29_1|6822@C332',
#        'jgi|YarliW29_1|6822@C82', 'jgi|YarliW29_1|6822@C90',
#        'jgi|YarliW29_1|6823@C298', 'jgi|YarliW29_1|6830@C312',
#        'jgi|YarliW29_1|6860@C242', 'jgi|YarliW29_1|6865@C256',
#        'jgi|YarliW29_1|6877@C702', 'jgi|YarliW29_1|688@C1556',
#        'jgi|YarliW29_1|688@C1564', 'jgi|YarliW29_1|6893@C114',
#        'jgi|YarliW29_1|6893@C117', 'jgi|YarliW29_1|6893@C134',
#        'jgi|YarliW29_1|6896@C418', 'jgi|YarliW29_1|6896@C429',
#        'jgi|YarliW29_1|6896@C695', 'jgi|YarliW29_1|6911@C190',
#        'jgi|YarliW29_1|6913@C31', 'jgi|YarliW29_1|6913@C33',
#        'jgi|YarliW29_1|6913@C47', 'jgi|YarliW29_1|6926@C255',
#        'jgi|YarliW29_1|6942@C153', 'jgi|YarliW29_1|6942@C352',
#        'jgi|YarliW29_1|6944@C326', 'jgi|YarliW29_1|6944@C334',
#        'jgi|YarliW29_1|6944@C363', 'jgi|YarliW29_1|6945@C40',
#        'jgi|YarliW29_1|6945@C45', 'jgi|YarliW29_1|6945@C47',
#        'jgi|YarliW29_1|6948@C629', 'jgi|YarliW29_1|6961@C114',
#        'jgi|YarliW29_1|6963@C240', 'jgi|YarliW29_1|6963@C242',
#        'jgi|YarliW29_1|697@C90', 'jgi|YarliW29_1|6982@C333',
#        'jgi|YarliW29_1|6994@C165', 'jgi|YarliW29_1|6994@C64',
#        'jgi|YarliW29_1|6994@C75', 'jgi|YarliW29_1|7001@C90',
#        'jgi|YarliW29_1|7014@C923', 'jgi|YarliW29_1|7047@C520',
#        'jgi|YarliW29_1|7063@C375', 'jgi|YarliW29_1|706@C154',
#        'jgi|YarliW29_1|7073@C896', 'jgi|YarliW29_1|7076@C663',
#        'jgi|YarliW29_1|7076@C910', 'jgi|YarliW29_1|7087@C215',
#        'jgi|YarliW29_1|7087@C343', 'jgi|YarliW29_1|7095@C287',
#        'jgi|YarliW29_1|7103@C67', 'jgi|YarliW29_1|7111@C889',
#        'jgi|YarliW29_1|7117@C49', 'jgi|YarliW29_1|7124@C159',
#        'jgi|YarliW29_1|7144@C581', 'jgi|YarliW29_1|7144@C588',
#        'jgi|YarliW29_1|7145@C204', 'jgi|YarliW29_1|7155@C238',
#        'jgi|YarliW29_1|7155@C52', 'jgi|YarliW29_1|7155@C63',
#        'jgi|YarliW29_1|7160@C241', 'jgi|YarliW29_1|7173@C328',
#        'jgi|YarliW29_1|7191@C36', 'jgi|YarliW29_1|7199@C118',
#        'jgi|YarliW29_1|7210@C550', 'jgi|YarliW29_1|721@C507',
#        'jgi|YarliW29_1|721@C57', 'jgi|YarliW29_1|7241@C400',
#        'jgi|YarliW29_1|7241@C406', 'jgi|YarliW29_1|7245@C826',
#        'jgi|YarliW29_1|724@C69', 'jgi|YarliW29_1|724@C71',
#        'jgi|YarliW29_1|7263@C132', 'jgi|YarliW29_1|7263@C413',
#        'jgi|YarliW29_1|7270@C1391', 'jgi|YarliW29_1|7273@C64',
#        'jgi|YarliW29_1|7285@C106', 'jgi|YarliW29_1|7285@C123',
#        'jgi|YarliW29_1|7302@C94', 'jgi|YarliW29_1|7314@C241',
#        'jgi|YarliW29_1|7317@C316', 'jgi|YarliW29_1|7317@C360',
#        'jgi|YarliW29_1|7367@C290', 'jgi|YarliW29_1|7371@C410',
#        'jgi|YarliW29_1|7397@C513', 'jgi|YarliW29_1|7398@C140',
#        'jgi|YarliW29_1|7400@C127', 'jgi|YarliW29_1|744@C161',
#        'jgi|YarliW29_1|744@C92', 'jgi|YarliW29_1|7457@C1338',
#        'jgi|YarliW29_1|7462@C88', 'jgi|YarliW29_1|7463@C63',
#        'jgi|YarliW29_1|7466@C307', 'jgi|YarliW29_1|7466@C314',
#        'jgi|YarliW29_1|7482@C238', 'jgi|YarliW29_1|7489@C20',
#        'jgi|YarliW29_1|7508@C100', 'jgi|YarliW29_1|7516@C749',
#        'jgi|YarliW29_1|7534@C115', 'jgi|YarliW29_1|7559@C387',
#        'jgi|YarliW29_1|7559@C393', 'jgi|YarliW29_1|7567@C39',
#        'jgi|YarliW29_1|7567@C74', 'jgi|YarliW29_1|7567@C79',
#        'jgi|YarliW29_1|7577@C29', 'jgi|YarliW29_1|7584@C91',
#        'jgi|YarliW29_1|7594@C84', 'jgi|YarliW29_1|7605@C242',
#        'jgi|YarliW29_1|7605@C260', 'jgi|YarliW29_1|7608@C121',
#        'jgi|YarliW29_1|7614@C72', 'jgi|YarliW29_1|7634@C93',
#        'jgi|YarliW29_1|7640@C270', 'jgi|YarliW29_1|7644@C116',
#        'jgi|YarliW29_1|7663@C250', 'jgi|YarliW29_1|7677@C265',
#        'jgi|YarliW29_1|7691@C310', 'jgi|YarliW29_1|7691@C474',
#        'jgi|YarliW29_1|7694@C319', 'jgi|YarliW29_1|7749@C117',
#        'jgi|YarliW29_1|7765@C347', 'jgi|YarliW29_1|7795@C50',
#        'jgi|YarliW29_1|7795@C53', 'jgi|YarliW29_1|7795@C78',
#        'jgi|YarliW29_1|7795@C87', 'jgi|YarliW29_1|7802@C174',
#        'jgi|YarliW29_1|7808@C319', 'jgi|YarliW29_1|7812@C157',
#        'jgi|YarliW29_1|7813@C193', 'jgi|YarliW29_1|7850@C168',
#        'jgi|YarliW29_1|7864@C104', 'jgi|YarliW29_1|7864@C197',
#        'jgi|YarliW29_1|7869@C2', 'jgi|YarliW29_1|786@C263',
#        'jgi|YarliW29_1|786@C287', 'jgi|YarliW29_1|786@C294',
#        'jgi|YarliW29_1|786@C412', 'jgi|YarliW29_1|7879@C80',
#        'jgi|YarliW29_1|7892@C37', 'jgi|YarliW29_1|7892@C47',
#        'jgi|YarliW29_1|7899@C225', 'jgi|YarliW29_1|7903@C22',
#        'jgi|YarliW29_1|7905@C329', 'jgi|YarliW29_1|7910@C401',
#        'jgi|YarliW29_1|813@C50', 'jgi|YarliW29_1|818@C137',
#        'jgi|YarliW29_1|818@C260', 'jgi|YarliW29_1|846@C536',
#        'jgi|YarliW29_1|854@C332', 'jgi|YarliW29_1|854@C63',
#        'jgi|YarliW29_1|857@C516', 'jgi|YarliW29_1|857@C586',
#        'jgi|YarliW29_1|857@C605', 'jgi|YarliW29_1|858@C240',
#        'jgi|YarliW29_1|867@C258', 'jgi|YarliW29_1|880@C106',
#        'jgi|YarliW29_1|894@C447', 'jgi|YarliW29_1|897@C228',
#        'jgi|YarliW29_1|897@C232', 'jgi|YarliW29_1|897@C501',
#        'jgi|YarliW29_1|897@C510', 'jgi|YarliW29_1|900@C132',
#        'jgi|YarliW29_1|902@C142', 'jgi|YarliW29_1|903@C335',
#        'jgi|YarliW29_1|916@C201', 'jgi|YarliW29_1|941@C28',
#        'jgi|YarliW29_1|941@C31', 'jgi|YarliW29_1|948@C163',
#        'jgi|YarliW29_1|950@C61', 'jgi|YarliW29_1|972@C173',
#        'jgi|YarliW29_1|994@C302'], dtype=object)

# %%
# low_sig_sites = ['gene2', 'gene4', 'gene5']

venn2([set(osc_sig_sites), set(low_sig_sites)],
      set_labels=('Oscillation Significant', 'Low Significant'))

plt.title("Venn Diagram of Significant Genes")
plt.show()

# %%
# Convert to sets
osc_set = set(osc_sig_sites)
low_set = set(low_sig_sites)

# Compute Venn parts
only_osc = osc_set - low_set
only_low = low_set - osc_set
shared = osc_set & low_set

# Extract rows from merged_df by gene IDs
only_osc_df = merged_df[merged_df['Site'].isin(only_osc)]
only_low_df = merged_df[merged_df['Site'].isin(only_low)]
shared_df   = merged_df[merged_df['Site'].isin(shared)]

# Optionally save to CSV
# only_osc_df.to_csv("only_osc_sig.csv", index=False)
# only_low_df.to_csv("only_low_sig.csv", index=False)
# shared_df.to_csv("shared_sig.csv", index=False)

# %%
prot_control_vs_oscillation_late_combined_stats_withAnnote.columns
# Out:
# Index(['Site', 'Biostat2L_29_Oscillation_24', 'Biostat2L_29_Oscillation_48',
#        'Biostat2L_29_Oscillation_72', 'Biostat2L_30_Control_24',
#        'Biostat2L_30_Control_48', 'Biostat2L_30_Control_72',
#        'Biostat2L_30_Oscillation_24', 'Biostat2L_30_Oscillation_48',
#        'Biostat2L_30_Oscillation_72', 'Biostat2L_31_Control_24',
#        'Biostat2L_31_Control_48', 'Biostat2L_31_Control_72',
#        'Biostat2L_31_Oscillation_24', 'Biostat2L_31_Oscillation_48',
#        'Biostat2L_31_Oscillation_72', 'Biostat2L_32_Control_24',
#        'Biostat2L_32_Control_48', 'Biostat2L_32_Control_72', 'ANOVA_p',
#        'ANOVA_padj', 'proteinID', 'log2FC', '#proteinId', 'kogid',
#        'kogdefline', 'kogClass', 'kogGroup', 'definition', 'catalyticActivity',
#        'pathway', 'pathway_class', 'pathway_type', 'ecNum', 'cofactors',
#        'gotermId', 'gotermType', 'goName', 'goAcc'],
#       dtype='object')

# %% [markdown]
# # multiple Yarrowia gene annotations. mapping/annotations

# %%
combined_df = merged_df.copy()

# %%
combined_df['proteinId'] = combined_df['proteinID'].copy()

# %%
combined_df['#proteinId'] = combined_df['proteinID'].copy()

# %%
gene_dict = {}

# Step Open and Read the FASTA File
with open('../Data/DNA/W29.fasta', 'r') as fasta_file:
    for line in fasta_file:
        # Check for header lines starting with ">"
        if line.startswith(">"):
            # Extract the relevant fields from the header line
            header_parts = line.strip().split('|')  # Split header by '|'
            gene_id = header_parts[2]  # "1000"
            gene_name = header_parts[3]  # "YALI1_B02228p"
            
            # Map "1000" to "YALI1_B02228p" in the dictionary
            gene_dict[gene_id] = gene_name

# %%
gene_dict
# Out:
# {'1000': 'YALI1_B02228p',
#  '1001': 'YALI1_B02283p',
#  '1002': 'YALI1_B02345p',
#  '1003': 'YALI1_B02375p',
#  '1004': 'YALI1_B02415p',
#  '1005': 'YALI1_B02430p',
#  '1006': 'YALI1_B02465p',
#  '1007': 'YALI1_B02472p',
#  '1008': 'YALI1_B02487p',
#  '1009': 'YALI1_B02496p',
#  '100': 'YALI1_A02775p',
#  '1010': 'YALI1_B02506p',
#  '1011': 'YALI1_B02533p',
#  '1012': 'YALI1_B02550p',
#  '1013': 'YALI1_B02604p',
#  '1014': 'YALI1_B02637p',
#  '1015': 'YALI1_B02642p',
#  '1016': 'YALI1_B02672p',
#  '1017': 'YALI1_B02696p',
#  '1018': 'YALI1_B02717p',
#  '1019': 'YALI1_B02733p',
#  '101': 'YALI1_A02813p',
#  '1020': 'YALI1_B02767p',
#  '1021': 'YALI1_B02781p',
#  '1022': 'YALI1_B02806p',
#  '1023': 'YALI1_B02833p',
#  '1024': 'YALI1_B02850p',
#  '1025': 'YALI1_B02874p',
#  '1026': 'YALI1_B02881p',
#  '1027': 'YALI1_B02910p',
#  '1028': 'YALI1_B02931p',
#  '1029': 'YALI1_B02991p',
#  '102': 'YALI1_A02819p',
#  '1030': 'YALI1_B03021p',
#  '1031': 'YALI1_B03041p',
#  '1032': 'YALI1_B03043p',
#  '1033': 'YALI1_B03085p',
#  '1034': 'YALI1_B03120p',
#  '1035': 'YALI1_B03168p',
#  '1036': 'YALI1_B03198p',
#  '1037': 'YALI1_B03225p',
#  '1038': 'YALI1_B03288p',
#  '1039': 'YALI1_B03290p',
#  '103': 'YALI1_A02833p',
#  '1040': 'YALI1_B03299p',
#  '1041': 'YALI1_B03314p',
#  '1042': 'YALI1_B03324p',
#  '1043': 'YALI1_B03335p',
#  '1044': 'YALI1_B03404p',
#  '1045': 'YALI1_B03429p',
#  '1046': 'YALI1_B03516p',
#  '1047': 'YALI1_B03556p',
#  '1048': 'YALI1_B03610p',
#  '1049': 'YALI1_B03644p',
#  '104': 'YALI1_A02875p',
#  '1050': 'YALI1_B03673p',
#  '1051': 'YALI1_B03719p',
#  '1052': 'YALI1_B03761p',
#  '1053': 'YALI1_B03797p',
#  '1054': 'YALI1_B03807p',
#  '1055': 'YALI1_B03832p',
#  '1056': 'YALI1_B03853p',
#  '1057': 'YALI1_B03910p',
#  '1058': 'YALI1_B03963p',
#  '1059': 'YALI1_B03979p',
#  '105': 'YALI1_A02895p',
#  '1060': 'YALI1_B04007p',
#  '1061': 'YALI1_B04032p',
#  '1062': 'YALI1_B04068p',
#  '1063': 'YALI1_B04123p',
#  '1064': 'YALI1_B04138p',
#  '1065': 'YALI1_B04200p',
#  '1066': 'YALI1_B04212p',
#  '1067': 'YALI1_B04228p',
#  '1068': 'YALI1_B04248p',
#  '1069': 'YALI1_B04274p',
#  '106': 'YALI1_A02947p',
#  '1070': 'YALI1_B04309p',
#  '1071': 'YALI1_B04321p',
#  '1072': 'YALI1_B04370p',
#  '1073': 'YALI1_B04391p',
#  '1074': 'YALI1_B04433p',
#  '1075': 'YALI1_B04466p',
#  '1076': 'YALI1_B04470p',
#  '1077': 'YALI1_B04497p',
#  '1078': 'YALI1_B04502p',
#  '1079': 'YALI1_B04523p',
#  '107': 'YALI1_A02974p',
#  '1080': 'YALI1_B04540p',
#  '1081': 'YALI1_B04559p',
#  '1082': 'YALI1_B04577p',
#  '1083': 'YALI1_B04579p',
#  '1084': 'YALI1_B04589p',
#  '1085': 'YALI1_B04637p',
#  '1086': 'YALI1_B04663p',
#  '1087': 'YALI1_B04690p',
#  '1088': 'YALI1_B04703p',
#  '1089': 'YALI1_B04747p',
#  '108': 'YALI1_A02977p',
#  '1090': 'YALI1_B04753p',
#  '1091': 'YALI1_B04759p',
#  '1092': 'YALI1_B04779p',
#  '1093': 'YALI1_B04781p',
#  '1094': 'YALI1_B04803p',
#  '1095': 'YALI1_B04831p',
#  '1096': 'YALI1_B04853p',
#  '1097': 'YALI1_B04873p',
#  '1098': 'YALI1_B04901p',
#  '1099': 'YALI1_B04937p',
#  '109': 'YALI1_A02998p',
#  '10': 'YALI1_A00252p',
#  '1100': 'YALI1_B04947p',
#  '1101': 'YALI1_B04950p',
#  '1102': 'YALI1_B04974p',
#  '1103': 'YALI1_B05005p',
#  '1104': 'YALI1_B05024p',
#  '1105': 'YALI1_B05043p',
#  '1106': 'YALI1_B05072p',
#  '1107': 'YALI1_B05106p',
#  '1108': 'YALI1_B05185p',
#  '1109': 'YALI1_B05226p',
#  '110': 'YALI1_A03017p',
#  '1110': 'YALI1_B05242p',
#  '1111': 'YALI1_B05282p',
#  '1112': 'YALI1_B05295p',
#  '1113': 'YALI1_B05313p',
#  '1114': 'YALI1_B05350p',
#  '1115': 'YALI1_B05364p',
#  '1116': 'YALI1_B05404p',
#  '1117': 'YALI1_B05420p',
#  '1118': 'YALI1_B05438p',
#  '1119': 'YALI1_B05454p',
#  '111': 'YALI1_A03029p',
#  '1120': 'YALI1_B05483p',
#  '1121': 'YALI1_B05497p',
#  '1122': 'YALI1_B05520p',
#  '1123': 'YALI1_B05522p',
#  '1124': 'YALI1_B05571p',
#  '1125': 'YALI1_B05609p',
#  '1126': 'YALI1_B05639p',
#  '1127': 'YALI1_B05646p',
#  '1128': 'YALI1_B05690p',
#  '1129': 'YALI1_B05698p',
#  '112': 'YALI1_A03069p',
#  '1130': 'YALI1_B05711p',
#  '1131': 'YALI1_B05730p',
#  '1132': 'YALI1_B05762p',
#  '1133': 'YALI1_B05782p',
#  '1134': 'YALI1_B05798p',
#  '1135': 'YALI1_B05830p',
#  '1136': 'YALI1_B05832p',
#  '1137': 'YALI1_B05891p',
#  '1138': 'YALI1_B05947p',
#  '1139': 'YALI1_B05954p',
#  '113': 'YALI1_A03081p',
#  '1140': 'YALI1_B05964p',
#  '1141': 'YALI1_B05971p',
#  '1142': 'YALI1_B05984p',
#  '1143': 'YALI1_B05995p',
#  '1144': 'YALI1_B06015p',
#  '1145': 'YALI1_B06028p',
#  '1146': 'YALI1_B06089p',
#  '1147': 'YALI1_B06110p',
#  '1148': 'YALI1_B06134p',
#  '1149': 'YALI1_B06141p',
#  '114': 'YALI1_A03091p',
#  '1150': 'YALI1_B06146p',
#  '1151': 'YALI1_B06207p',
#  '1152': 'YALI1_B06245p',
#  '1153': 'YALI1_B06264p',
#  '1154': 'YALI1_B06315p',
#  '1155': 'YALI1_B06324p',
#  '1156': 'YALI1_B06328p',
#  '1157': 'YALI1_B06340p',
#  '1158': 'YALI1_B06447p',
#  '1159': 'YALI1_B06487p',
#  '115': 'YALI1_A03116p',
#  '1160': 'YALI1_B06489p',
#  '1161': 'YALI1_B06508p',
#  '1162': 'YALI1_B06514p',
#  '1163': 'YALI1_B06537p',
#  '1164': 'YALI1_B06546p',
#  '1165': 'YALI1_B06607p',
#  '1166': 'YALI1_B06613p',
#  '1167': 'YALI1_B06620p',
#  '1168': 'YALI1_B06628p',
#  '1169': 'YALI1_B06635p',
#  '116': 'YALI1_A03137p',
#  '1170': 'YALI1_B06640p',
#  '1171': 'YALI1_B06644p',
#  '1172': 'YALI1_B06704p',
#  '1173': 'YALI1_B06726p',
#  '1174': 'YALI1_B06735p',
#  '1175': 'YALI1_B06745p',
#  '1176': 'YALI1_B06776p',
#  '1177': 'YALI1_B06809p',
#  '1178': 'YALI1_B06839p',
#  '1179': 'YALI1_B06847p',
#  '117': 'YALI1_A03153p',
#  '1180': 'YALI1_B06866p',
#  '1181': 'YALI1_B06885p',
#  '1182': 'YALI1_B06928p',
#  '1183': 'YALI1_B06969p',
#  '1184': 'YALI1_B07043p',
#  '1185': 'YALI1_B07076p',
#  '1186': 'YALI1_B07094p',
#  '1187': 'YALI1_B07134p',
#  '1188': 'YALI1_B07162p',
#  '1189': 'YALI1_B07203p',
#  '118': 'YALI1_A03170p',
#  '1190': 'YALI1_B07210p',
#  '1191': 'YALI1_B07220p',
#  '1192': 'YALI1_B07271p',
#  '1193': 'YALI1_B07284p',
#  '1194': 'YALI1_B07295p',
#  '1195': 'YALI1_B07331p',
#  '1196': 'YALI1_B07366p',
#  '1197': 'YALI1_B07374p',
#  '1198': 'YALI1_B07399p',
#  '1199': 'YALI1_B07413p',
#  '119': 'YALI1_A03183p',
#  '11': 'YALI1_A00309p',
#  '1200': 'YALI1_B07444p',
#  '1201': 'YALI1_B07500p',
#  '1202': 'YALI1_B07538p',
#  '1203': 'YALI1_B07549p',
#  '1204': 'YALI1_B07578p',
#  '1205': 'YALI1_B07598p',
#  '1206': 'YALI1_B07652p',
#  '1207': 'YALI1_B07675p',
#  '1208': 'YALI1_B07696p',
#  '1209': 'YALI1_B07735p',
#  '120': 'YALI1_A03210p',
#  '1210': 'YALI1_B07762p',
#  '1211': 'YALI1_B07769p',
#  '1212': 'YALI1_B07786p',
#  '1213': 'YALI1_B07809p',
#  '1214': 'YALI1_B07843p',
#  '1215': 'YALI1_B07852p',
#  '1216': 'YALI1_B07853p',
#  '1217': 'YALI1_B07864p',
#  '1218': 'YALI1_B07915p',
#  '1219': 'YALI1_B07937p',
#  '121': 'YALI1_A03258p',
#  '1220': 'YALI1_B07957p',
#  '1221': 'YALI1_B07983p',
#  '1222': 'YALI1_B08094p',
#  '1223': 'YALI1_B08102p',
#  '1224': 'YALI1_B08123p',
#  '1225': 'YALI1_B08134p',
#  '1226': 'YALI1_B08156p',
#  '1227': 'YALI1_B08186p',
#  '1228': 'YALI1_B08193p',
#  '1229': 'YALI1_B08207p',
#  '122': 'YALI1_A03278p',
#  '1230': 'YALI1_B08214p',
#  '1231': 'YALI1_B08247p',
#  '1232': 'YALI1_B08263p',
#  '1233': 'YALI1_B08321p',
#  '1234': 'YALI1_B08374p',
#  '1235': 'YALI1_B08401p',
#  '1236': 'YALI1_B08438p',
#  '1237': 'YALI1_B08461p',
#  '1238': 'YALI1_B08493p',
#  '1239': 'YALI1_B08531p',
#  '123': 'YALI1_A03289p',
#  '1240': 'YALI1_B08540p',
#  '1241': 'YALI1_B08575p',
#  '1242': 'YALI1_B08580p',
#  '1243': 'YALI1_B08588p',
#  '1244': 'YALI1_B08616p',
#  '1245': 'YALI1_B08627p',
#  '1246': 'YALI1_B08650p',
#  '1247': 'YALI1_B08699p',
#  '1248': 'YALI1_B08721p',
#  '1249': 'YALI1_B08758p',
#  '124': 'YALI1_A03300p',
#  '1250': 'YALI1_B08783p',
#  '1251': 'YALI1_B08801p',
#  '1252': 'YALI1_B08817p',
#  '1253': 'YALI1_B08831p',
#  '1254': 'YALI1_B08851p',
#  '1255': 'YALI1_B08868p',
#  '1256': 'YALI1_B08885p',
#  '1257': 'YALI1_B08898p',
#  '1258': 'YALI1_B08975p',
#  '1259': 'YALI1_B08978p',
#  '125': 'YALI1_A03322p',
#  '1260': 'YALI1_B09002p',
#  '1261': 'YALI1_B09025p',
#  '1262': 'YALI1_B09044p',
#  '1263': 'YALI1_B09072p',
#  '1264': 'YALI1_B09090p',
#  '1265': 'YALI1_B09117p',
#  '1266': 'YALI1_B09132p',
#  '1267': 'YALI1_B09144p',
#  '1268': 'YALI1_B09161p',
#  '1269': 'YALI1_B09181p',
#  '126': 'YALI1_A03351p',
#  '1270': 'YALI1_B09211p',
#  '1271': 'YALI1_B09258p',
#  '1272': 'YALI1_B09266p',
#  '1273': 'YALI1_B09279p',
#  '1274': 'YALI1_B09299p',
#  '1275': 'YALI1_B09310p',
#  '1276': 'YALI1_B09316p',
#  '1277': 'YALI1_B09320p',
#  '1278': 'YALI1_B09333p',
#  '1279': 'YALI1_B09367p',
#  '127': 'YALI1_A03356p',
#  '1280': 'YALI1_B09426p',
#  '1281': 'YALI1_B09448p',
#  '1282': 'YALI1_B09476p',
#  '1283': 'YALI1_B09497p',
#  '1284': 'YALI1_B09518p',
#  '1285': 'YALI1_B09568p',
#  '1286': 'YALI1_B09580p',
#  '1287': 'YALI1_B09591p',
#  '1288': 'YALI1_B09592p',
#  '1289': 'YALI1_B09708p',
#  '128': 'YALI1_A03396p',
#  '1290': 'YALI1_B09807p',
#  '1291': 'YALI1_B09837p',
#  '1292': 'YALI1_B09871p',
#  '1293': 'YALI1_B09894p',
#  '1294': 'YALI1_B09929p',
#  '1295': 'YALI1_B09931p',
#  '1296': 'YALI1_B09957p',
#  '1297': 'YALI1_B09993p',
#  '1298': 'YALI1_B09994p',
#  '1299': 'YALI1_B10032p',
#  '129': 'YALI1_A03402p',
#  '12': 'YALI1_A00325p',
#  '1300': 'YALI1_B10094p',
#  '1301': 'YALI1_B10119p',
#  '1302': 'YALI1_B10130p',
#  '1303': 'YALI1_B10145p',
#  '1304': 'YALI1_B10170p',
#  '1305': 'YALI1_B10182p',
#  '1306': 'YALI1_B10185p',
#  '1307': 'YALI1_B10231p',
#  '1308': 'YALI1_B10263p',
#  '1309': 'YALI1_B10288p',
#  '130': 'YALI1_A03422p',
#  '1310': 'YALI1_B10359p',
#  '1311': 'YALI1_B10424p',
#  '1312': 'YALI1_B10437p',
#  '1313': 'YALI1_B10449p',
#  '1314': 'YALI1_B10463p',
#  '1315': 'YALI1_B10525p',
#  '1316': 'YALI1_B10552p',
#  '1317': 'YALI1_B10582p',
#  '1318': 'YALI1_B10607p',
#  '1319': 'YALI1_B10635p',
#  '131': 'YALI1_A03442p',
#  '1320': 'YALI1_B10751p',
#  '1321': 'YALI1_B10757p',
#  '1322': 'YALI1_B10762p',
#  '1323': 'YALI1_B10773p',
#  '1324': 'YALI1_B10780p',
#  '1325': 'YALI1_B10782p',
#  '1326': 'YALI1_B10813p',
#  '1327': 'YALI1_B10891p',
#  '1328': 'YALI1_B10933p',
#  '1329': 'YALI1_B10943p',
#  '132': 'YALI1_A03450p',
#  '1330': 'YALI1_B10990p',
#  '1331': 'YALI1_B11034p',
#  '1332': 'YALI1_B11083p',
#  '1333': 'YALI1_B11111p',
#  '1334': 'YALI1_B11120p',
#  '1335': 'YALI1_B11131p',
#  '1336': 'YALI1_B11167p',
#  '1337': 'YALI1_B11183p',
#  '1338': 'YALI1_B11200p',
#  '1339': 'YALI1_B11388p',
#  '133': 'YALI1_A03487p',
#  '1340': 'YALI1_B11398p',
#  '1341': 'YALI1_B11402p',
#  '1342': 'YALI1_B11415p',
#  '1343': 'YALI1_B11448p',
#  '1344': 'YALI1_B11484p',
#  '1345': 'YALI1_B11495p',
#  '1346': 'YALI1_B11519p',
#  '1347': 'YALI1_B11532p',
#  '1348': 'YALI1_B11577p',
#  '1349': 'YALI1_B11588p',
#  '134': 'YALI1_A03507p',
#  '1350': 'YALI1_B11593p',
#  '1351': 'YALI1_B11607p',
#  '1352': 'YALI1_B11625p',
#  '1353': 'YALI1_B11648p',
#  '1354': 'YALI1_B11681p',
#  '1355': 'YALI1_B11715p',
#  '1356': 'YALI1_B11719p',
#  '1357': 'YALI1_B11729p',
#  '1358': 'YALI1_B11759p',
#  '1359': 'YALI1_B11781p',
#  '135': 'YALI1_A03512p',
#  '1360': 'YALI1_B11794p',
#  '1361': 'YALI1_B11853p',
#  '1362': 'YALI1_B11878p',
#  '1363': 'YALI1_B11916p',
#  '1364': 'YALI1_B11934p',
#  '1365': 'YALI1_B11960p',
#  '1366': 'YALI1_B11978p',
#  '1367': 'YALI1_B11983p',
#  '1368': 'YALI1_B12010p',
#  '1369': 'YALI1_B12042p',
#  '136': 'YALI1_A03549p',
#  '1370': 'YALI1_B12057p',
#  '1371': 'YALI1_B12101p',
#  '1372': 'YALI1_B12150p',
#  '1373': 'YALI1_B12154p',
#  '1374': 'YALI1_B12195p',
#  '1375': 'YALI1_B12204p',
#  '1376': 'YALI1_B12243p',
#  '1377': 'YALI1_B12267p',
#  '1378': 'YALI1_B12295p',
#  '1379': 'YALI1_B12313p',
#  '137': 'YALI1_A03567p',
#  '1380': 'YALI1_B12337p',
#  '1381': 'YALI1_B12375p',
#  '1382': 'YALI1_B12384p',
#  '1383': 'YALI1_B12409p',
#  '1384': 'YALI1_B12427p',
#  '1385': 'YALI1_B12443p',
#  '1386': 'YALI1_B12451p',
#  '1387': 'YALI1_B12489p',
#  '1388': 'YALI1_B12529p',
#  '1389': 'YALI1_B12633p',
#  '138': 'YALI1_A03579p',
#  '1390': 'YALI1_B12677p',
#  '1391': 'YALI1_B12691p',
#  '1392': 'YALI1_B12714p',
#  '1393': 'YALI1_B12742p',
#  '1394': 'YALI1_B12781p',
#  '1395': 'YALI1_B12847p',
#  '1396': 'YALI1_B12874p',
#  '1397': 'YALI1_B12917p',
#  '1398': 'YALI1_B12966p',
#  '1399': 'YALI1_B12970p',
#  '139': 'YALI1_A03599p',
#  '13': 'YALI1_A00375p',
#  '1400': 'YALI1_B12993p',
#  '1401': 'YALI1_B13041p',
#  '1402': 'YALI1_B13069p',
#  '1403': 'YALI1_B13112p',
#  '1404': 'YALI1_B13122p',
#  '1405': 'YALI1_B13137p',
#  '1406': 'YALI1_B13150p',
#  '1407': 'YALI1_B13179p',
#  '1408': 'YALI1_B13259p',
#  '1409': 'YALI1_B13290p',
#  '140': 'YALI1_A03624p',
#  '1410': 'YALI1_B13328p',
#  '1411': 'YALI1_B13355p',
#  '1412': 'YALI1_B13401p',
#  '1413': 'YALI1_B13411p',
#  '1414': 'YALI1_B13439p',
#  '1415': 'YALI1_B13483p',
#  '1416': 'YALI1_B13536p',
#  '1417': 'YALI1_B13556p',
#  '1418': 'YALI1_B13586p',
#  '1419': 'YALI1_B13614p',
#  '141': 'YALI1_A03669p',
#  '1420': 'YALI1_B13641p',
#  '1421': 'YALI1_B13662p',
#  '1422': 'YALI1_B13699p',
#  '1423': 'YALI1_B13723p',
#  '1424': 'YALI1_B13737p',
#  '1425': 'YALI1_B13800p',
#  '1426': 'YALI1_B13828p',
#  '1427': 'YALI1_B13886p',
#  '1428': 'YALI1_B13888p',
#  '1429': 'YALI1_B13915p',
#  '142': 'YALI1_A03688p',
#  '1430': 'YALI1_B13917p',
#  '1431': 'YALI1_B13948p',
#  '1432': 'YALI1_B13973p',
#  '1433': 'YALI1_B14013p',
#  '1434': 'YALI1_B14044p',
#  '1435': 'YALI1_B14064p',
#  '1436': 'YALI1_B14121p',
#  '1437': 'YALI1_B14147p',
#  '1438': 'YALI1_B14150p',
#  '1439': 'YALI1_B14187p',
#  '143': 'YALI1_A03721p',
#  '1440': 'YALI1_B14194p',
#  '1441': 'YALI1_B14236p',
#  '1442': 'YALI1_B14238p',
#  '1443': 'YALI1_B14268p',
#  '1444': 'YALI1_B14292p',
#  '1445': 'YALI1_B14308p',
#  '1446': 'YALI1_B14325p',
#  '1447': 'YALI1_B14355p',
#  '1448': 'YALI1_B14382p',
#  '1449': 'YALI1_B14418p',
#  '144': 'YALI1_A03757p',
#  '1450': 'YALI1_B14441p',
#  '1451': 'YALI1_B14492p',
#  '1452': 'YALI1_B14510p',
#  '1453': 'YALI1_B14517p',
#  '1454': 'YALI1_B14544p',
#  '1455': 'YALI1_B14573p',
#  '1456': 'YALI1_B14600p',
#  '1457': 'YALI1_B14615p',
#  '1458': 'YALI1_B14645p',
#  '1459': 'YALI1_B14658p',
#  '145': 'YALI1_A03763p',
#  '1460': 'YALI1_B14680p',
#  '1461': 'YALI1_B14686p',
#  '1462': 'YALI1_B14733p',
#  '1463': 'YALI1_B14752p',
#  '1464': 'YALI1_B14793p',
#  '1465': 'YALI1_B14804p',
#  '1466': 'YALI1_B14826p',
#  '1467': 'YALI1_B14844p',
#  '1468': 'YALI1_B14882p',
#  '1469': 'YALI1_B14924p',
#  '146': 'YALI1_A03803p',
#  '1470': 'YALI1_B14948p',
#  '1471': 'YALI1_B14959p',
#  '1472': 'YALI1_B14978p',
#  '1473': 'YALI1_B14993p',
#  '1474': 'YALI1_B15015p',
#  '1475': 'YALI1_B15036p',
#  '1476': 'YALI1_B15072p',
#  '1477': 'YALI1_B15092p',
#  '1478': 'YALI1_B15109p',
#  '1479': 'YALI1_B15151p',
#  '147': 'YALI1_A03809p',
#  '1480': 'YALI1_B15180p',
#  '1481': 'YALI1_B15192p',
#  '1482': 'YALI1_B15237p',
#  '1483': 'YALI1_B15275p',
#  '1484': 'YALI1_B15301p',
#  '1485': 'YALI1_B15307p',
#  '1486': 'YALI1_B15310p',
#  '1487': 'YALI1_B15346p',
#  '1488': 'YALI1_B15380p',
#  '1489': 'YALI1_B15420p',
#  '148': 'YALI1_A03815p',
#  '1490': 'YALI1_B15440p',
#  '1491': 'YALI1_B15460p',
#  '1492': 'YALI1_B15475p',
#  '1493': 'YALI1_B15482p',
#  '1494': 'YALI1_B15509p',
#  '1495': 'YALI1_B15521p',
#  '1496': 'YALI1_B15560p',
#  '1497': 'YALI1_B15587p',
#  '1498': 'YALI1_B15592p',
#  '1499': 'YALI1_B15624p',
#  '149': 'YALI1_A03837p',
#  '14': 'YALI1_A00406p',
#  '1500': 'YALI1_B15655p',
#  '1501': 'YALI1_B15670p',
#  '1502': 'YALI1_B15692p',
#  '1503': 'YALI1_B15703p',
#  '1504': 'YALI1_B15706p',
#  '1505': 'YALI1_B15733p',
#  '1506': 'YALI1_B15742p',
#  '1507': 'YALI1_B15792p',
#  '1508': 'YALI1_B15852p',
#  '1509': 'YALI1_B15887p',
#  '150': 'YALI1_A03842p',
#  '1510': 'YALI1_B15905p',
#  '1511': 'YALI1_B15928p',
#  '1512': 'YALI1_B15943p',
#  '1513': 'YALI1_B15964p',
#  '1514': 'YALI1_B15988p',
#  '1515': 'YALI1_B15996p',
#  '1516': 'YALI1_B16022p',
#  '1517': 'YALI1_B16068p',
#  '1518': 'YALI1_B16087p',
#  '1519': 'YALI1_B16110p',
#  '151': 'YALI1_A03857p',
#  '1520': 'YALI1_B16158p',
#  '1521': 'YALI1_B16194p',
#  '1522': 'YALI1_B16239p',
#  '1523': 'YALI1_B16255p',
#  '1524': 'YALI1_B16277p',
#  '1525': 'YALI1_B16309p',
#  '1526': 'YALI1_B16318p',
#  '1527': 'YALI1_B16375p',
#  '1528': 'YALI1_B16410p',
#  '1529': 'YALI1_B16419p',
#  '152': 'YALI1_A03883p',
#  '1530': 'YALI1_B16446p',
#  '1531': 'YALI1_B16477p',
#  '1532': 'YALI1_B16504p',
#  '1533': 'YALI1_B16544p',
#  '1534': 'YALI1_B16566p',
#  '1535': 'YALI1_B16572p',
#  '1536': 'YALI1_B16578p',
#  '1537': 'YALI1_B16584p',
#  '1538': 'YALI1_B16645p',
#  '1539': 'YALI1_B16687p',
#  '153': 'YALI1_A03900p',
#  '1540': 'YALI1_B16705p',
#  '1541': 'YALI1_B16735p',
#  '1542': 'YALI1_B16808p',
#  '1543': 'YALI1_B16863p',
#  '1544': 'YALI1_B16922p',
#  '1545': 'YALI1_B16944p',
#  '1546': 'YALI1_B16968p',
#  '1547': 'YALI1_B16996p',
#  '1548': 'YALI1_B17008p',
#  '1549': 'YALI1_B17039p',
#  '154': 'YALI1_A03907p',
#  '1550': 'YALI1_B17050p',
#  '1551': 'YALI1_B17105p',
#  '1552': 'YALI1_B17112p',
#  '1553': 'YALI1_B17132p',
#  '1554': 'YALI1_B17155p',
#  '1555': 'YALI1_B17214p',
#  '1556': 'YALI1_B17261p',
#  '1557': 'YALI1_B17285p',
#  '1558': 'YALI1_B17292p',
#  '1559': 'YALI1_B17299p',
#  '155': 'YALI1_A03937p',
#  '1560': 'YALI1_B17363p',
#  '1561': 'YALI1_B17406p',
#  '1562': 'YALI1_B17441p',
#  '1563': 'YALI1_B17468p',
#  '1564': 'YALI1_B17493p',
#  '1565': 'YALI1_B17518p',
#  '1566': 'YALI1_B17569p',
#  '1567': 'YALI1_B17592p',
#  '1568': 'YALI1_B17660p',
#  '1569': 'YALI1_B17695p',
#  '156': 'YALI1_A03964p',
#  '1570': 'YALI1_B17724p',
#  '1571': 'YALI1_B17773p',
#  '1572': 'YALI1_B17805p',
#  '1573': 'YALI1_B17838p',
#  '1574': 'YALI1_B17853p',
#  '1575': 'YALI1_B17871p',
#  '1576': 'YALI1_B17908p',
#  '1577': 'YALI1_B17927p',
#  '1578': 'YALI1_B17964p',
#  '1579': 'YALI1_B17968p',
#  '157': 'YALI1_A04006p',
#  '1580': 'YALI1_B17990p',
#  '1581': 'YALI1_B17998p',
#  '1582': 'YALI1_B18012p',
#  '1583': 'YALI1_B18069p',
#  '1584': 'YALI1_B18134p',
#  '1585': 'YALI1_B18190p',
#  '1586': 'YALI1_B18205p',
#  '1587': 'YALI1_B18207p',
#  '1588': 'YALI1_B18236p',
#  '1589': 'YALI1_B18260p',
#  '158': 'YALI1_A04022p',
#  '1590': 'YALI1_B18265p',
#  '1591': 'YALI1_B18292p',
#  '1592': 'YALI1_B18311p',
#  '1593': 'YALI1_B18347p',
#  '1594': 'YALI1_B18368p',
#  '1595': 'YALI1_B18375p',
#  '1596': 'YALI1_B18384p',
#  '1597': 'YALI1_B18391p',
#  '1598': 'YALI1_B18451p',
#  '1599': 'YALI1_B18460p',
#  '159': 'YALI1_A04044p',
#  '15': 'YALI1_A00447p',
#  '1600': 'YALI1_B18472p',
#  '1601': 'YALI1_B18499p',
#  '1602': 'YALI1_B18536p',
#  '1603': 'YALI1_B18572p',
#  '1604': 'YALI1_B18607p',
#  '1605': 'YALI1_B18613p',
#  '1606': 'YALI1_B18631p',
#  '1607': 'YALI1_B18645p',
#  '1608': 'YALI1_B18687p',
#  '1609': 'YALI1_B18707p',
#  '160': 'YALI1_A04071p',
#  '1610': 'YALI1_B18727p',
#  '1611': 'YALI1_B18741p',
#  '1612': 'YALI1_B18764p',
#  '1613': 'YALI1_B18798p',
#  '1614': 'YALI1_B18811p',
#  '1615': 'YALI1_B18845p',
#  '1616': 'YALI1_B18854p',
#  '1617': 'YALI1_B18887p',
#  '1618': 'YALI1_B18902p',
#  '1619': 'YALI1_B18921p',
#  '161': 'YALI1_A04109p',
#  '1620': 'YALI1_B18930p',
#  '1621': 'YALI1_B18955p',
#  '1622': 'YALI1_B18971p',
#  '1623': 'YALI1_B18975p',
#  '1624': 'YALI1_B19021p',
#  '1625': 'YALI1_B19044p',
#  '1626': 'YALI1_B19079p',
#  '1627': 'YALI1_B19107p',
#  '1628': 'YALI1_B19120p',
#  '1629': 'YALI1_B19153p',
#  '162': 'YALI1_A04119p',
#  '1630': 'YALI1_B19205p',
#  '1631': 'YALI1_B19217p',
#  '1632': 'YALI1_B19276p',
#  '1633': 'YALI1_B19290p',
#  '1634': 'YALI1_B19323p',
#  '1635': 'YALI1_B19326p',
#  '1636': 'YALI1_B19336p',
#  '1637': 'YALI1_B19348p',
#  '1638': 'YALI1_B19388p',
#  '1639': 'YALI1_B19390p',
#  '163': 'YALI1_A04164p',
#  '1640': 'YALI1_B19429p',
#  '1641': 'YALI1_B19453p',
#  '1642': 'YALI1_B19485p',
#  '1643': 'YALI1_B19490p',
#  '1644': 'YALI1_B19507p',
#  '1645': 'YALI1_B19520p',
#  '1646': 'YALI1_B19567p',
#  '1647': 'YALI1_B19576p',
#  '1648': 'YALI1_B19602p',
#  '1649': 'YALI1_B19668p',
#  '164': 'YALI1_A04178p',
#  '1650': 'YALI1_B19713p',
#  '1651': 'YALI1_B19747p',
#  '1652': 'YALI1_B19774p',
#  '1653': 'YALI1_B19844p',
#  '1654': 'YALI1_B19856p',
#  '1655': 'YALI1_B19877p',
#  '1656': 'YALI1_B19880p',
#  '1657': 'YALI1_B19897p',
#  '1658': 'YALI1_B19932p',
#  '1659': 'YALI1_B19962p',
#  '165': 'YALI1_A04261p',
#  '1660': 'YALI1_B20009p',
#  '1661': 'YALI1_B20043p',
#  '1662': 'YALI1_B20052p',
#  '1663': 'YALI1_B20094p',
#  '1664': 'YALI1_B20108p',
#  '1665': 'YALI1_B20130p',
#  '1666': 'YALI1_B20145p',
#  '1667': 'YALI1_B20153p',
#  '1668': 'YALI1_B20188p',
#  '1669': 'YALI1_B20192p',
#  '166': 'YALI1_A04309p',
#  '1670': 'YALI1_B20205p',
#  '1671': 'YALI1_B20242p',
#  '1672': 'YALI1_B20243p',
#  '1673': 'YALI1_B20276p',
#  '1674': 'YALI1_B20289p',
#  '1675': 'YALI1_B20319p',
#  '1676': 'YALI1_B20337p',
#  '1677': 'YALI1_B20359p',
#  '1678': 'YALI1_B20378p',
#  '1679': 'YALI1_B20399p',
#  '167': 'YALI1_A04332p',
#  '1680': 'YALI1_B20407p',
#  '1681': 'YALI1_B20416p',
#  '1682': 'YALI1_B20462p',
#  '1683': 'YALI1_B20493p',
#  '1684': 'YALI1_B20521p',
#  '1685': 'YALI1_B20527p',
#  '1686': 'YALI1_B20577p',
#  '1687': 'YALI1_B20589p',
#  '1688': 'YALI1_B20634p',
#  '1689': 'YALI1_B20709p',
#  '168': 'YALI1_A04341p',
#  '1690': 'YALI1_B20717p',
#  '1691': 'YALI1_B20730p',
#  '1692': 'YALI1_B20765p',
#  '1693': 'YALI1_B20777p',
#  '1694': 'YALI1_B20802p',
#  '1695': 'YALI1_B20834p',
#  '1696': 'YALI1_B20835p',
#  '1697': 'YALI1_B20870p',
#  '1698': 'YALI1_B20887p',
#  '1699': 'YALI1_B20919p',
#  '169': 'YALI1_A04385p',
#  '16': 'YALI1_A00468p',
#  '1700': 'YALI1_B20935p',
#  '1701': 'YALI1_B20968p',
#  '1702': 'YALI1_B20992p',
#  '1703': 'YALI1_B21004p',
#  '1704': 'YALI1_B21030p',
#  '1705': 'YALI1_B21042p',
#  '1706': 'YALI1_B21043p',
#  '1707': 'YALI1_B21070p',
#  '1708': 'YALI1_B21088p',
#  '1709': 'YALI1_B21104p',
#  '170': 'YALI1_A04415p',
#  '1710': 'YALI1_B21114p',
#  '1711': 'YALI1_B21134p',
#  '1712': 'YALI1_B21155p',
#  '1713': 'YALI1_B21194p',
#  '1714': 'YALI1_B21208p',
#  '1715': 'YALI1_B21250p',
#  '1716': 'YALI1_B21275p',
#  '1717': 'YALI1_B21313p',
#  '1718': 'YALI1_B21323p',
#  '1719': 'YALI1_B21356p',
#  '171': 'YALI1_A04462p',
#  '1720': 'YALI1_B21381p',
#  '1721': 'YALI1_B21423p',
#  '1722': 'YALI1_B21432p',
#  '1723': 'YALI1_B21466p',
#  '1724': 'YALI1_B21493p',
#  '1725': 'YALI1_B21538p',
#  '1726': 'YALI1_B21562p',
#  '1727': 'YALI1_B21594p',
#  '1728': 'YALI1_B21618p',
#  '1729': 'YALI1_B21628p',
#  '172': 'YALI1_A04495p',
#  '1730': 'YALI1_B21675p',
#  '1731': 'YALI1_B21714p',
#  '1732': 'YALI1_B21737p',
#  '1733': 'YALI1_B21774p',
#  '1734': 'YALI1_B21787p',
#  '1735': 'YALI1_B21798p',
#  '1736': 'YALI1_B21816p',
#  '1737': 'YALI1_B21819p',
#  '1738': 'YALI1_B21855p',
#  '1739': 'YALI1_B21885p',
#  '173': 'YALI1_A04533p',
#  '1740': 'YALI1_B21935p',
#  '1741': 'YALI1_B21946p',
#  '1742': 'YALI1_B21966p',
#  '1743': 'YALI1_B22015p',
#  '1744': 'YALI1_B22020p',
#  '1745': 'YALI1_B22055p',
#  '1746': 'YALI1_B22060p',
#  '1747': 'YALI1_B22088p',
#  '1748': 'YALI1_B22109p',
#  '1749': 'YALI1_B22158p',
#  '174': 'YALI1_A04561p',
#  '1750': 'YALI1_B22259p',
#  '1751': 'YALI1_B22266p',
#  '1752': 'YALI1_B22276p',
#  '1753': 'YALI1_B22321p',
#  '1754': 'YALI1_B22351p',
#  '1755': 'YALI1_B22372p',
#  '1756': 'YALI1_B22375p',
#  '1757': 'YALI1_B22391p',
#  '1758': 'YALI1_B22410p',
#  '1759': 'YALI1_B22414p',
#  '175': 'YALI1_A04576p',
#  '1760': 'YALI1_B22452p',
#  '1761': 'YALI1_B22499p',
#  '1762': 'YALI1_B22512p',
#  '1763': 'YALI1_B22533p',
#  '1764': 'YALI1_B22549p',
#  '1765': 'YALI1_B22561p',
#  '1766': 'YALI1_B22598p',
#  '1767': 'YALI1_B22614p',
#  '1768': 'YALI1_B22638p',
#  '1769': 'YALI1_B22645p',
#  '176': 'YALI1_A04620p',
#  '1770': 'YALI1_B22667p',
#  '1771': 'YALI1_B22677p',
#  '1772': 'YALI1_B22697p',
#  '1773': 'YALI1_B22721p',
#  '1774': 'YALI1_B22747p',
#  '1775': 'YALI1_B22793p',
#  '1776': 'YALI1_B22820p',
#  '1777': 'YALI1_B22853p',
#  '1778': 'YALI1_B22883p',
#  '1779': 'YALI1_B22905p',
#  '177': 'YALI1_A04653p',
#  '1780': 'YALI1_B22908p',
#  '1781': 'YALI1_B22938p',
#  '1782': 'YALI1_B23017p',
#  '1783': 'YALI1_B23055p',
#  '1784': 'YALI1_B23061p',
#  '1785': 'YALI1_B23077p',
#  '1786': 'YALI1_B23153p',
#  '1787': 'YALI1_B23176p',
#  '1788': 'YALI1_B23201p',
#  '1789': 'YALI1_B23237p',
#  '178': 'YALI1_A04661p',
#  '1790': 'YALI1_B23300p',
#  '1791': 'YALI1_B23338p',
#  '1792': 'YALI1_B23351p',
#  '1793': 'YALI1_B23373p',
#  '1794': 'YALI1_B23385p',
#  '1795': 'YALI1_B23420p',
#  '1796': 'YALI1_B23440p',
#  '1797': 'YALI1_B23443p',
#  '1798': 'YALI1_B23447p',
#  '1799': 'YALI1_B23467p',
#  '179': 'YALI1_A04676p',
#  '17': 'YALI1_A00504p',
#  '1800': 'YALI1_B23515p',
#  '1801': 'YALI1_B23522p',
#  '1802': 'YALI1_B23554p',
#  '1803': 'YALI1_B23579p',
#  '1804': 'YALI1_B23603p',
#  '1805': 'YALI1_B23609p',
#  '1806': 'YALI1_B23622p',
#  '1807': 'YALI1_B23677p',
#  '1808': 'YALI1_B23708p',
#  '1809': 'YALI1_B23729p',
#  '180': 'YALI1_A04715p',
#  '1810': 'YALI1_B23744p',
#  '1811': 'YALI1_B23771p',
#  '1812': 'YALI1_B23794p',
#  '1813': 'YALI1_B23798p',
#  '1814': 'YALI1_B23834p',
#  '1815': 'YALI1_B23866p',
#  '1816': 'YALI1_B23879p',
#  '1817': 'YALI1_B23933p',
#  '1818': 'YALI1_B23939p',
#  '1819': 'YALI1_B23966p',
#  '181': 'YALI1_A04742p',
#  '1820': 'YALI1_B23981p',
#  '1821': 'YALI1_B24018p',
#  '1822': 'YALI1_B24043p',
#  '1823': 'YALI1_B24051p',
#  '1824': 'YALI1_B24129p',
#  '1825': 'YALI1_B24185p',
#  '1826': 'YALI1_B24214p',
#  '1827': 'YALI1_B24218p',
#  '1828': 'YALI1_B24252p',
#  '1829': 'YALI1_B24264p',
#  '182': 'YALI1_A04781p',
#  '1830': 'YALI1_B24280p',
#  '1831': 'YALI1_B24292p',
#  '1832': 'YALI1_B24335p',
#  '1833': 'YALI1_B24351p',
#  '1834': 'YALI1_B24424p',
#  '1835': 'YALI1_B24446p',
#  '1836': 'YALI1_B24471p',
#  '1837': 'YALI1_B24502p',
#  '1838': 'YALI1_B24564p',
#  '1839': 'YALI1_B24606p',
#  '183': 'YALI1_A04795p',
#  '1840': 'YALI1_B24638p',
#  '1841': 'YALI1_B24654p',
#  '1842': 'YALI1_B24672p',
#  '1843': 'YALI1_B24714p',
#  '1844': 'YALI1_B24758p',
#  '1845': 'YALI1_B24836p',
#  '1846': 'YALI1_B24901p',
#  '1847': 'YALI1_B24936p',
#  '1848': 'YALI1_B24970p',
#  '1849': 'YALI1_B24997p',
#  '184': 'YALI1_A04815p',
#  '1850': 'YALI1_B25004p',
#  '1851': 'YALI1_B25017p',
#  '1852': 'YALI1_B25062p',
#  '1853': 'YALI1_B25077p',
#  '1854': 'YALI1_B25087p',
#  '1855': 'YALI1_B25107p',
#  '1856': 'YALI1_B25136p',
#  '1857': 'YALI1_B25187p',
#  '1858': 'YALI1_B25223p',
#  '1859': 'YALI1_B25258p',
#  '185': 'YALI1_A04817p',
#  '1860': 'YALI1_B25313p',
#  '1861': 'YALI1_B25319p',
#  '1862': 'YALI1_B25322p',
#  '1863': 'YALI1_B25334p',
#  '1864': 'YALI1_B25360p',
#  '1865': 'YALI1_B25387p',
#  '1866': 'YALI1_B25395p',
#  '1867': 'YALI1_B25427p',
#  '1868': 'YALI1_B25484p',
#  '1869': 'YALI1_B25495p',
#  '186': 'YALI1_A04848p',
#  '1870': 'YALI1_B25506p',
#  '1871': 'YALI1_B25553p',
#  '1872': 'YALI1_B25593p',
#  '1873': 'YALI1_B25603p',
#  '1874': 'YALI1_B25676p',
#  '1875': 'YALI1_B25734p',
#  '1876': 'YALI1_B25744p',
#  '1877': 'YALI1_B25762p',
#  '1878': 'YALI1_B25795p',
#  '1879': 'YALI1_B25798p',
#  '187': 'YALI1_A04859p',
#  '1880': 'YALI1_B25833p',
#  '1881': 'YALI1_B25868p',
#  '1882': 'YALI1_B25906p',
#  '1883': 'YALI1_B25952p',
#  '1884': 'YALI1_B25963p',
#  '1885': 'YALI1_B25988p',
#  '1886': 'YALI1_B25997p',
#  '1887': 'YALI1_B26033p',
#  '1888': 'YALI1_B26112p',
#  '1889': 'YALI1_B26153p',
#  '188': 'YALI1_A04864p',
#  '1890': 'YALI1_B26175p',
#  '1891': 'YALI1_B26205p',
#  '1892': 'YALI1_B26235p',
#  '1893': 'YALI1_B26271p',
#  '1894': 'YALI1_B26322p',
#  '1895': 'YALI1_B26350p',
#  '1896': 'YALI1_B26377p',
#  '1897': 'YALI1_B26430p',
#  '1898': 'YALI1_B26451p',
#  '1899': 'YALI1_B26517p',
#  '189': 'YALI1_A04884p',
#  '18': 'YALI1_A00538p',
#  '1900': 'YALI1_B26550p',
#  ...}

# %%
combined_df['YALI1_protID'] = combined_df['proteinID'].map(gene_dict)
combined_df['YALI1_mod'] = combined_df['YALI1_protID'].str.replace('p', 'g', regex=False)

# %%
combined_df.head()
# Out:
#                                       Peptide                      Site  \
# 0                              R.IEPIC@AQGR.I  jgi|YarliW29_1|1000@C503
# 1                             K.VFIGSC@TNSR.I  jgi|YarliW29_1|1002@C352
# 2                                R.C@ASTSNR.N  jgi|YarliW29_1|1002@C430
# 3                       K.DC@TLATVDHNIPTTTR.K   jgi|YarliW29_1|1002@C55
# 4  K.ASILVVSGDNFGC@GSSR.E; L.VVSGDNFGC@GSSR.E  jgi|YarliW29_1|1002@C614
#
#                UniProt              Protein Residue                        id  \
# 0  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000    C503  jgi|YarliW29_1|1000@C503
# 1  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C352  jgi|YarliW29_1|1002@C352
# 2  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C430  jgi|YarliW29_1|1002@C430
# 3  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002     C55   jgi|YarliW29_1|1002@C55
# 4  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C614  jgi|YarliW29_1|1002@C614
#
#    Total missingness  Oscillation_24 missingness  Oscillation_3.5 missingness  \
# 0                  0                           0                            0
# 1                  0                           0                            0
# 2                 36                           3                            3
# 3                  0                           0                            0
# 4                  0                           0                            0
#
#    Oscillation_4.5 missingness  ...  osc/control_late_cominbedANOVA_padj  \
# 0                            0  ...                             0.068902
# 1                            0  ...                             0.534709
# 2                            3  ...                                  NaN
# 3                            0  ...                             0.018774
# 4                            0  ...                             0.116799
#
#    osc/control_late_cominbedANOVA_p  proteinId  proteinID  #proteinId  \
# 0                          0.018835       1000       1000        1000
# 1                          0.390366       1002       1002        1002
# 2                               NaN       1002       1002        1002
# 3                          0.003143       1002       1002        1002
# 4                          0.041402       1002       1002        1002
#
#    osc/low_late_cominbed  osc/low_late_cominbedANOVA_padj  \
# 0               1.840909                     3.498930e-07
# 1              -0.000690                     9.976631e-01
# 2                    NaN                              NaN
# 3               1.294184                     5.868462e-05
# 4               1.788325                     3.966176e-04
#
#    osc/low_late_cominbedANOVA_p   YALI1_protID      YALI1_mod
# 0                  3.328472e-09  YALI1_B02228p  YALI1_B02228g
# 1                  9.976631e-01  YALI1_B02345p  YALI1_B02345g
# 2                           NaN  YALI1_B02345p  YALI1_B02345g
# 3                  5.954738e-06  YALI1_B02345p  YALI1_B02345g
# 4                  9.192291e-05  YALI1_B02345p  YALI1_B02345g
#
# [5 rows x 187 columns]

# %%
# File path to your GFF file
gff_file = "../Data/DNA/genomic_yali1_yali2.gff"

# Initialize mapping dictionary
yali1_to_yali2 = {}

# Regex patterns for locus_tag and old_locus_tag
locus_re = re.compile(r'locus_tag=(YALI1_[A-Z0-9]+g)')
old_locus_re = re.compile(r'old_locus_tag=(YALI2_[A-Z0-9]+g)')

# Parse the GFF
with open(gff_file, 'r') as file:
    for line in file:
        if line.startswith("#"):
            continue
        if "\tgene\t" not in line:
            continue

        locus_match = locus_re.search(line)
        old_locus_match = old_locus_re.search(line)

        if locus_match and old_locus_match:
            yali1 = locus_match.group(1)
            yali2 = old_locus_match.group(1)
            yali1_to_yali2[yali1] = yali2

# Convert to DataFrame for inspection or export
df_map = pd.DataFrame(list(yali1_to_yali2.items()), columns=["YALI1", "YALI2"])

# Optionally save to CSV
df_map.to_csv("yali1_to_yali2_mapping.csv", index=False)

# %%
df_map['YALI1'] = df_map['YALI1'].str.replace('g', 'p', regex=False)
locus_dict_2 = dict(zip(df_map["YALI1"], df_map["YALI2"]))

# %%
df_map
# Out:
#               YALI1          YALI2
# 0     YALI1_A00058p  YALI2_A00002g
# 1     YALI1_A00102p  YALI2_A00003g
# 2     YALI1_A00148p  YALI2_A00004g
# 3     YALI1_A00204p  YALI2_A00005g
# 4     YALI1_A00241p  YALI2_A00692g
# ...             ...            ...
# 6210  YALI1_F39665p  YALI2_E00867g
# 6211  YALI1_F39789p  YALI2_E00868g
# 6212  YALI1_F39844p  YALI2_E00869g
# 6213  YALI1_F39885p  YALI2_E00871g
# 6214  YALI1_F39891p  YALI2_E00870g
#
# [6215 rows x 2 columns]

# %%
combined_df['YALI2'] = combined_df['YALI1_protID'].map(df_map.set_index('YALI1')['YALI2'])

# %%
combined_df.head()
# Out:
#                                       Peptide                      Site  \
# 0                              R.IEPIC@AQGR.I  jgi|YarliW29_1|1000@C503
# 1                             K.VFIGSC@TNSR.I  jgi|YarliW29_1|1002@C352
# 2                                R.C@ASTSNR.N  jgi|YarliW29_1|1002@C430
# 3                       K.DC@TLATVDHNIPTTTR.K   jgi|YarliW29_1|1002@C55
# 4  K.ASILVVSGDNFGC@GSSR.E; L.VVSGDNFGC@GSSR.E  jgi|YarliW29_1|1002@C614
#
#                UniProt              Protein Residue                        id  \
# 0  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000    C503  jgi|YarliW29_1|1000@C503
# 1  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C352  jgi|YarliW29_1|1002@C352
# 2  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C430  jgi|YarliW29_1|1002@C430
# 3  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002     C55   jgi|YarliW29_1|1002@C55
# 4  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C614  jgi|YarliW29_1|1002@C614
#
#    Total missingness  Oscillation_24 missingness  Oscillation_3.5 missingness  \
# 0                  0                           0                            0
# 1                  0                           0                            0
# 2                 36                           3                            3
# 3                  0                           0                            0
# 4                  0                           0                            0
#
#    Oscillation_4.5 missingness  ...  osc/control_late_cominbedANOVA_p  \
# 0                            0  ...                          0.018835
# 1                            0  ...                          0.390366
# 2                            3  ...                               NaN
# 3                            0  ...                          0.003143
# 4                            0  ...                          0.041402
#
#    proteinId  proteinID  #proteinId  osc/low_late_cominbed  \
# 0       1000       1000        1000               1.840909
# 1       1002       1002        1002              -0.000690
# 2       1002       1002        1002                    NaN
# 3       1002       1002        1002               1.294184
# 4       1002       1002        1002               1.788325
#
#    osc/low_late_cominbedANOVA_padj  osc/low_late_cominbedANOVA_p  \
# 0                     3.498930e-07                  3.328472e-09
# 1                     9.976631e-01                  9.976631e-01
# 2                              NaN                           NaN
# 3                     5.868462e-05                  5.954738e-06
# 4                     3.966176e-04                  9.192291e-05
#
#     YALI1_protID      YALI1_mod          YALI2
# 0  YALI1_B02228p  YALI1_B02228g  YALI2_B00021g
# 1  YALI1_B02345p  YALI1_B02345g  YALI2_B00628g
# 2  YALI1_B02345p  YALI1_B02345g  YALI2_B00628g
# 3  YALI1_B02345p  YALI1_B02345g  YALI2_B00628g
# 4  YALI1_B02345p  YALI1_B02345g  YALI2_B00628g
#
# [5 rows x 188 columns]

# %%
# JGI_protID_toYali1 = pd.DataFrame(list(gene_dict.items()), columns=['JGI_protID', 'YALI1_protID'])
# # JGI_protID_toYali1.to_csv('JGI_Yali1_protMap.csv')
# JGI_protID_toYali1.head()

# %%
df = pd.read_excel('../Annotations/yali_genes.xlsx')
df.head()
# df = pd.read_excel('../Data/locus_tag_map.xlsx')
# df.head()
# Out:
#   YALI0 locus ID YALI1 Locus ID YALI1 Proteins Gene Type Chromosome  \
# 0            NaN  YALI1_A00014g  YALI1_A00014p      mRNA     YALI1A
# 1            NaN  YALI1_A00019g  YALI1_A00019p      mRNA     YALI1A
# 2            NaN  YALI1_A00032g  YALI1_A00032p      mRNA     YALI1A
# 3   YALI0A00110g  YALI1_A00058g  YALI1_A00058p      mRNA     YALI1A
# 4   YALI0A00132g  YALI1_A00102g  YALI1_A00102p      mRNA     YALI1A
#
#    Start Base  End Base Strand  \
# 0        1230      1648      -
# 1        1806      2173      -
# 2        3285      3920      +
# 3        5913      8531      +
# 4       10299     12134      +
#
#                                           Annotation
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3    weakly similar to uniprot|Q06593 Saccharomyc...
# 4    highly similar to uniprot|P40150 Saccharomyc...

# %%
filtered_df = df.dropna(subset=["YALI0 locus ID"])

locus_dict = dict(zip(filtered_df["YALI1 Proteins"], filtered_df["YALI0 locus ID"]))

# %%
combined_df['YALI0_locus'] = combined_df['YALI1_protID'].map(locus_dict)

# %%
combined_df.head()
# Out:
#                                       Peptide                      Site  \
# 0                              R.IEPIC@AQGR.I  jgi|YarliW29_1|1000@C503
# 1                             K.VFIGSC@TNSR.I  jgi|YarliW29_1|1002@C352
# 2                                R.C@ASTSNR.N  jgi|YarliW29_1|1002@C430
# 3                       K.DC@TLATVDHNIPTTTR.K   jgi|YarliW29_1|1002@C55
# 4  K.ASILVVSGDNFGC@GSSR.E; L.VVSGDNFGC@GSSR.E  jgi|YarliW29_1|1002@C614
#
#                UniProt              Protein Residue                        id  \
# 0  jgi|YarliW29_1|1000  jgi|YarliW29_1|1000    C503  jgi|YarliW29_1|1000@C503
# 1  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C352  jgi|YarliW29_1|1002@C352
# 2  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C430  jgi|YarliW29_1|1002@C430
# 3  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002     C55   jgi|YarliW29_1|1002@C55
# 4  jgi|YarliW29_1|1002  jgi|YarliW29_1|1002    C614  jgi|YarliW29_1|1002@C614
#
#    Total missingness  Oscillation_24 missingness  Oscillation_3.5 missingness  \
# 0                  0                           0                            0
# 1                  0                           0                            0
# 2                 36                           3                            3
# 3                  0                           0                            0
# 4                  0                           0                            0
#
#    Oscillation_4.5 missingness  ...  proteinId  proteinID  #proteinId  \
# 0                            0  ...       1000       1000        1000
# 1                            0  ...       1002       1002        1002
# 2                            3  ...       1002       1002        1002
# 3                            0  ...       1002       1002        1002
# 4                            0  ...       1002       1002        1002
#
#    osc/low_late_cominbed  osc/low_late_cominbedANOVA_padj  \
# 0               1.840909                     3.498930e-07
# 1              -0.000690                     9.976631e-01
# 2                    NaN                              NaN
# 3               1.294184                     5.868462e-05
# 4               1.788325                     3.966176e-04
#
#    osc/low_late_cominbedANOVA_p   YALI1_protID      YALI1_mod          YALI2  \
# 0                  3.328472e-09  YALI1_B02228p  YALI1_B02228g  YALI2_B00021g
# 1                  9.976631e-01  YALI1_B02345p  YALI1_B02345g  YALI2_B00628g
# 2                           NaN  YALI1_B02345p  YALI1_B02345g  YALI2_B00628g
# 3                  5.954738e-06  YALI1_B02345p  YALI1_B02345g  YALI2_B00628g
# 4                  9.192291e-05  YALI1_B02345p  YALI1_B02345g  YALI2_B00628g
#
#     YALI0_locus
# 0  YALI0B01320g
# 1  YALI0B01364g
# 2  YALI0B01364g
# 3  YALI0B01364g
# 4  YALI0B01364g
#
# [5 rows x 189 columns]

# %%
for col in combined_df:
    print(col)
# Out:
# Peptide
# Site
# UniProt
# Protein
# Residue
# id
# Total missingness
# Oscillation_24 missingness
# Oscillation_3.5 missingness
# Oscillation_4.5 missingness
# Oscillation_48 missingness
# Oscillation_5.5 missingness
# Oscillation_72 missingness
# Control_24 missingness
# Control_3.5 missingness
# Control_4.5 missingness
# Control_48 missingness
# Control_5.5 missingness
# Control_72 missingness
# Low_24 missingness
# Low_3.5 missingness
# Low_4.5 missingness
# Low_48 missingness
# Low_5.5 missingness
# Low_72 missingness
# missing_check
# Biostat2L_29_Oscillation_24
# Biostat2L_29_Oscillation_3.5
# Biostat2L_29_Oscillation_4.5
# Biostat2L_29_Oscillation_48
# Biostat2L_29_Oscillation_5.5
# Biostat2L_29_Oscillation_72
# Biostat2L_30_Control_24
# Biostat2L_30_Control_3.5
# Biostat2L_30_Control_4.5
# Biostat2L_30_Control_48
# Biostat2L_30_Control_5.5
# Biostat2L_30_Control_72
# Biostat2L_30_Oscillation_24
# Biostat2L_30_Oscillation_3.5
# Biostat2L_30_Oscillation_4.5
# Biostat2L_30_Oscillation_48
# Biostat2L_30_Oscillation_5.5
# Biostat2L_30_Oscillation_72
# Biostat2L_31_Control_24
# Biostat2L_31_Control_3.5
# Biostat2L_31_Control_4.5
# Biostat2L_31_Control_48
# Biostat2L_31_Control_5.5
# Biostat2L_31_Control_72
# Biostat2L_31_Oscillation_24
# Biostat2L_31_Oscillation_3.5
# Biostat2L_31_Oscillation_4.5
# Biostat2L_31_Oscillation_48
# Biostat2L_31_Oscillation_5.5
# Biostat2L_31_Oscillation_72
# Biostat2L_32_Control_24
# Biostat2L_32_Control_3.5
# Biostat2L_32_Control_4.5
# Biostat2L_32_Control_48
# Biostat2L_32_Control_5.5
# Biostat2L_32_Control_72
# Biostat2L_32_Low_24
# Biostat2L_32_Low_3.5
# Biostat2L_32_Low_4.5
# Biostat2L_32_Low_48
# Biostat2L_32_Low_5.5
# Biostat2L_32_Low_72
# Biostat2L_33_Low_24
# Biostat2L_33_Low_3.5
# Biostat2L_33_Low_4.5
# Biostat2L_33_Low_48
# Biostat2L_33_Low_5.5
# Biostat2L_33_Low_72
# Biostat2L_34_Low_24
# Biostat2L_34_Low_3.5
# Biostat2L_34_Low_4.5
# Biostat2L_34_Low_48
# Biostat2L_34_Low_5.5
# Biostat2L_34_Low_72
# ANOVA_[Treatment]_pval
# ANOVA_[Treatment * Time]_pval
# ANOVA_[Time]_pval
# ANOVA_[Treatment]_adj-p
# ANOVA_[Treatment * Time]_adj-p
# ANOVA_[Time]_adj-p
# Low_3.5/Control_3.5
# Low_3.5/Control_3.5_pval
# Low_3.5/Control_3.5_adj-p
# Low_4.5/Control_4.5
# Low_4.5/Control_4.5_pval
# Low_4.5/Control_4.5_adj-p
# Low_5.5/Control_5.5
# Low_5.5/Control_5.5_pval
# Low_5.5/Control_5.5_adj-p
# Low_24/Control_24
# Low_24/Control_24_pval
# Low_24/Control_24_adj-p
# Low_48/Control_48
# Low_48/Control_48_pval
# Low_48/Control_48_adj-p
# Low_72/Control_72
# Low_72/Control_72_pval
# Low_72/Control_72_adj-p
# Oscillation_3.5/Control_3.5
# Oscillation_3.5/Control_3.5_pval
# Oscillation_3.5/Control_3.5_adj-p
# Oscillation_4.5/Control_4.5
# Oscillation_4.5/Control_4.5_pval
# Oscillation_4.5/Control_4.5_adj-p
# Oscillation_5.5/Control_5.5
# Oscillation_5.5/Control_5.5_pval
# Oscillation_5.5/Control_5.5_adj-p
# Oscillation_24/Control_24
# Oscillation_24/Control_24_pval
# Oscillation_24/Control_24_adj-p
# Oscillation_48/Control_48
# Oscillation_48/Control_48_pval
# Oscillation_48/Control_48_adj-p
# Oscillation_72/Control_72
# Oscillation_72/Control_72_pval
# Oscillation_72/Control_72_adj-p
# Control_4.5/Control_3.5
# Control_4.5/Control_3.5_pval
# Control_4.5/Control_3.5_adj-p
# Control_5.5/Control_3.5
# Control_5.5/Control_3.5_pval
# Control_5.5/Control_3.5_adj-p
# Control_24/Control_3.5
# Control_24/Control_3.5_pval
# Control_24/Control_3.5_adj-p
# Control_48/Control_3.5
# Control_48/Control_3.5_pval
# Control_48/Control_3.5_adj-p
# Control_72/Control_3.5
# Control_72/Control_3.5_pval
# Control_72/Control_3.5_adj-p
# Low_4.5/Low_3.5
# Low_4.5/Low_3.5_pval
# Low_4.5/Low_3.5_adj-p
# Low_5.5/Low_3.5
# Low_5.5/Low_3.5_pval
# Low_5.5/Low_3.5_adj-p
# Low_24/Low_3.5
# Low_24/Low_3.5_pval
# Low_24/Low_3.5_adj-p
# Low_48/Low_3.5
# Low_48/Low_3.5_pval
# Low_48/Low_3.5_adj-p
# Low_72/Low_3.5
# Low_72/Low_3.5_pval
# Low_72/Low_3.5_adj-p
# Oscillation_4.5/Oscillation_3.5
# Oscillation_4.5/Oscillation_3.5_pval
# Oscillation_4.5/Oscillation_3.5_adj-p
# Oscillation_5.5/Oscillation_3.5
# Oscillation_5.5/Oscillation_3.5_pval
# Oscillation_5.5/Oscillation_3.5_adj-p
# Oscillation_24/Oscillation_3.5
# Oscillation_24/Oscillation_3.5_pval
# Oscillation_24/Oscillation_3.5_adj-p
# Oscillation_48/Oscillation_3.5
# Oscillation_48/Oscillation_3.5_pval
# Oscillation_48/Oscillation_3.5_adj-p
# Oscillation_72/Oscillation_3.5
# Oscillation_72/Oscillation_3.5_pval
# Oscillation_72/Oscillation_3.5_adj-p
# Type
# Experiment
# site_number
# early/late
# early/late_ANOVA_padj
# early/late_ANOVA_p
# low/control_late_combined
# low/control_late_combined_ANOVA_padj
# low/control_late_combined_ANOVA_p
# osc/control_late_cominbed
# osc/control_late_cominbedANOVA_padj
# osc/control_late_cominbedANOVA_p
# proteinId
# proteinID
# #proteinId
# osc/low_late_cominbed
# osc/low_late_cominbedANOVA_padj
# osc/low_late_cominbedANOVA_p
# YALI1_protID
# YALI1_mod
# YALI2
# YALI0_locus

# %% [markdown]
# ## add rest of proteomic comparisions to timepoint.

# %%
# ============================================================
# CONDITION-TO-CONDITION COMPARISONS AT EACH TIMEPOINT
# Adds log2FC, ANOVA_p, and ANOVA_padj directly to combined_df
# ============================================================

# Build protein dataframe exactly as elsewhere in notebook
prot = annotated_redox[sample_ids_prot_redox]
prot['Protein'] = annotated_redox['Site']
prot.index = annotated_redox['Site']

prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))


STRESS_VS_CTRL_COLS = [
    "Low_3.5/Control_3.5",
    "Low_4.5/Control_4.5",
    "Low_5.5/Control_5.5",
    "Low_24/Control_24",
    "Low_48/Control_48",
    "Low_72/Control_72",

    "Oscillation_3.5/Control_3.5",
    "Oscillation_4.5/Control_4.5",
    "Oscillation_5.5/Control_5.5",
    "Oscillation_24/Control_24",
    "Oscillation_48/Control_48",
    "Oscillation_72/Control_72",
]


for comparison in STRESS_VS_CTRL_COLS:

    first, second = comparison.split("/")

    first_condition, first_timepoint = first.rsplit("_", 1)
    second_condition, second_timepoint = second.rsplit("_", 1)

    # -------------------------------------------------------
    # Keep only the two conditions being compared
    # -------------------------------------------------------
    prot_compare = prot.drop(
        prot.columns[
            ~(prot.columns.str.contains(first_condition) |
              prot.columns.str.contains(second_condition))
        ],
        axis=1
    )

    # -------------------------------------------------------
    # Keep only the requested timepoint
    # -------------------------------------------------------
    prot_compare = prot_compare.drop(
        prot_compare.columns[
            ~prot_compare.columns.str.contains(f"_{first_timepoint}$")
        ],
        axis=1
    )

    # -------------------------------------------------------
    # Group samples by CONDITION for ANOVA
    # -------------------------------------------------------
    condition_series = pd.Series(
        prot_compare.columns
    ).map(prot_condition_dict)

    condition_series.index = prot_compare.columns

    # -------------------------------------------------------
    # Calculate p-values
    # -------------------------------------------------------
    prot_compare_stats = global_stats_calc_prot(
        prot_compare,
        condition_series
    )

    # -------------------------------------------------------
    # Extract protein ID exactly as elsewhere in notebook
    # -------------------------------------------------------
    prot_compare_stats["proteinID"] = (
        prot_compare_stats["Site"]
        .str.extract(r"YarliW29_1\|(\d+)@")
    )

    prot_compare_stats["proteinID"] = (
        prot_compare_stats["proteinID"].astype(int)
    )

    # -------------------------------------------------------
    # Separate first and second condition
    # -------------------------------------------------------
    first_group = prot_compare_stats[
        prot_compare_stats.columns[
            prot_compare_stats.columns.str.contains(
                f"_{first_condition}_{first_timepoint}$"
            )
        ]
    ]

    second_group = prot_compare_stats[
        prot_compare_stats.columns[
            prot_compare_stats.columns.str.contains(
                f"_{second_condition}_{second_timepoint}$"
            )
        ]
    ]

    # gives the increase of the first
    prot_compare_stats['log2FC'] = log2FC_function(
        first_group,
        second_group
    )

    # -------------------------------------------------------
    # Merge exactly like existing notebook
    # -------------------------------------------------------
    df_to_merge2 = pd.DataFrame()

    df_to_merge2[comparison] = prot_compare_stats['log2FC']
    df_to_merge2['Site'] = prot_compare_stats['Site']
    df_to_merge2[f'{comparison}_ANOVA_padj'] = prot_compare_stats['ANOVA_padj']
    df_to_merge2[f'{comparison}_ANOVA_p'] = prot_compare_stats['ANOVA_p']

    # match proteinId dtype before merge
    # df_to_merge2['proteinID'] = df_to_merge['proteinID'].astype(str)
    # combined_df['proteinId'] = combined_df['proteinId'].astype(str)

    combined_df = pd.merge(
        combined_df,
        df_to_merge2,
        left_on='Site',
        right_on='Site',
        how='left'
    )
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_85794/4066024486.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prot['Protein'] = annotated_redox['Site']

# %%
# Build protein dataframe exactly as elsewhere in notebook
prot = annotated_redox[sample_ids_prot_redox]
prot['Protein'] = annotated_redox['Site']
prot.index = annotated_redox['Site']

prot_condition_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['condition']))
prot_timepoint_dict = dict(zip(sample_dict['prot_redox_ids'], sample_dict['timepoint']))


WITHIN_COND_COLS = [
    "Control_4.5/Control_3.5",
    "Control_5.5/Control_3.5",
    "Control_24/Control_3.5",
    "Control_48/Control_3.5",
    "Control_72/Control_3.5",
    
    "Low_4.5/Low_3.5",
    "Low_5.5/Low_3.5",
    "Low_24/Low_3.5",
    "Low_48/Low_3.5",
    "Low_72/Low_3.5",
    
    "Oscillation_4.5/Oscillation_3.5",
    "Oscillation_5.5/Oscillation_3.5",
    "Oscillation_24/Oscillation_3.5",
    "Oscillation_48/Oscillation_3.5",
    "Oscillation_72/Oscillation_3.5",
]


for comparison in WITHIN_COND_COLS:

    first, second = comparison.split("/")
    
    condition = first.rsplit("_", 1)[0]
    timepoint = first.rsplit("_", 1)[1]

    # -------------------------------------------------------
    # Keep only the condition being tested
    # -------------------------------------------------------
    prot_compare = prot.drop(
        prot.columns[~prot.columns.str.contains(condition)],
        axis=1
    )

    # -------------------------------------------------------
    # Keep only current timepoint and 3.5 h
    # -------------------------------------------------------
    keep_pattern = f"_{timepoint}$|_3.5$"

    prot_compare = prot_compare.drop(
        prot_compare.columns[
            ~prot_compare.columns.str.contains(keep_pattern)
        ],
        axis=1
    )

    # -------------------------------------------------------
    # Group samples by TIMEPOINT for ANOVA
    # -------------------------------------------------------
    timepoint_series = pd.Series(
        prot_compare.columns
    ).map(prot_timepoint_dict)

    timepoint_series.index = prot_compare.columns

    # -------------------------------------------------------
    # Calculate p-values
    # -------------------------------------------------------
    prot_compare_stats = global_stats_calc_prot(
        prot_compare,
        timepoint_series
    )

    # -------------------------------------------------------
    # Extract protein ID exactly as elsewhere in notebook
    # -------------------------------------------------------
    prot_compare_stats["proteinID"] = (
        prot_compare_stats["Site"]
        .str.extract(r"YarliW29_1\|(\d+)@")
    )

    prot_compare_stats["proteinID"] = (
        prot_compare_stats["proteinID"].astype(int)
    )

    # -------------------------------------------------------
    # Separate later timepoint and 3.5 h
    # -------------------------------------------------------
    later = prot_compare_stats[
        prot_compare_stats.columns[
            prot_compare_stats.columns.str.contains(
                f"_{condition}_{timepoint}$"
            )
        ]
    ]

    baseline = prot_compare_stats[
        prot_compare_stats.columns[
            prot_compare_stats.columns.str.contains(
                f"_{condition}_3.5$"
            )
        ]
    ]

    # gives the increase of the first
    prot_compare_stats['log2FC'] = log2FC_function(
        later,
        baseline
    )

    # -------------------------------------------------------
    # Merge exactly like existing notebook
    # -------------------------------------------------------
    df_to_merge2 = pd.DataFrame()

    df_to_merge2[comparison] = prot_compare_stats['log2FC']
    df_to_merge2['Site'] = prot_compare_stats['Site']
    df_to_merge2[f'{comparison}_ANOVA_padj'] = prot_compare_stats['ANOVA_padj']
    df_to_merge2[f'{comparison}_ANOVA_p'] = prot_compare_stats['ANOVA_p']

    # df_to_merge2['Site'] = df_to_merge2['Site'].astype(str)

    combined_df = pd.merge(
        combined_df,
        df_to_merge2,
        left_on='Site',
        right_on='Site',
        how='left'
    )
# Out:
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/1698501097.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prot['Protein'] = annotated_redox['Site']
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)
# /Users/czaj603/miniconda3/envs/bio/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:580: SmallSampleWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   if is_too_small(samples, kwds):
# /var/folders/kn/zzns_smn1q79xdnf1tgqk__r0000gn/T/ipykernel_75804/344067234.py:138: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   _, p = f_oneway(*group_data)

# %%
for col in combined_df.columns:
    print(col)
# Out:
# Peptide
# Site
# UniProt
# Protein
# Residue
# id
# Total missingness
# Oscillation_24 missingness
# Oscillation_3.5 missingness
# Oscillation_4.5 missingness
# Oscillation_48 missingness
# Oscillation_5.5 missingness
# Oscillation_72 missingness
# Control_24 missingness
# Control_3.5 missingness
# Control_4.5 missingness
# Control_48 missingness
# Control_5.5 missingness
# Control_72 missingness
# Low_24 missingness
# Low_3.5 missingness
# Low_4.5 missingness
# Low_48 missingness
# Low_5.5 missingness
# Low_72 missingness
# missing_check
# Biostat2L_29_Oscillation_24
# Biostat2L_29_Oscillation_3.5
# Biostat2L_29_Oscillation_4.5
# Biostat2L_29_Oscillation_48
# Biostat2L_29_Oscillation_5.5
# Biostat2L_29_Oscillation_72
# Biostat2L_30_Control_24
# Biostat2L_30_Control_3.5
# Biostat2L_30_Control_4.5
# Biostat2L_30_Control_48
# Biostat2L_30_Control_5.5
# Biostat2L_30_Control_72
# Biostat2L_30_Oscillation_24
# Biostat2L_30_Oscillation_3.5
# Biostat2L_30_Oscillation_4.5
# Biostat2L_30_Oscillation_48
# Biostat2L_30_Oscillation_5.5
# Biostat2L_30_Oscillation_72
# Biostat2L_31_Control_24
# Biostat2L_31_Control_3.5
# Biostat2L_31_Control_4.5
# Biostat2L_31_Control_48
# Biostat2L_31_Control_5.5
# Biostat2L_31_Control_72
# Biostat2L_31_Oscillation_24
# Biostat2L_31_Oscillation_3.5
# Biostat2L_31_Oscillation_4.5
# Biostat2L_31_Oscillation_48
# Biostat2L_31_Oscillation_5.5
# Biostat2L_31_Oscillation_72
# Biostat2L_32_Control_24
# Biostat2L_32_Control_3.5
# Biostat2L_32_Control_4.5
# Biostat2L_32_Control_48
# Biostat2L_32_Control_5.5
# Biostat2L_32_Control_72
# Biostat2L_32_Low_24
# Biostat2L_32_Low_3.5
# Biostat2L_32_Low_4.5
# Biostat2L_32_Low_48
# Biostat2L_32_Low_5.5
# Biostat2L_32_Low_72
# Biostat2L_33_Low_24
# Biostat2L_33_Low_3.5
# Biostat2L_33_Low_4.5
# Biostat2L_33_Low_48
# Biostat2L_33_Low_5.5
# Biostat2L_33_Low_72
# Biostat2L_34_Low_24
# Biostat2L_34_Low_3.5
# Biostat2L_34_Low_4.5
# Biostat2L_34_Low_48
# Biostat2L_34_Low_5.5
# Biostat2L_34_Low_72
# ANOVA_[Treatment]_pval
# ANOVA_[Treatment * Time]_pval
# ANOVA_[Time]_pval
# ANOVA_[Treatment]_adj-p
# ANOVA_[Treatment * Time]_adj-p
# ANOVA_[Time]_adj-p
# Low_3.5/Control_3.5_x
# Low_3.5/Control_3.5_pval
# Low_3.5/Control_3.5_adj-p
# Low_4.5/Control_4.5_x
# Low_4.5/Control_4.5_pval
# Low_4.5/Control_4.5_adj-p
# Low_5.5/Control_5.5_x
# Low_5.5/Control_5.5_pval
# Low_5.5/Control_5.5_adj-p
# Low_24/Control_24_x
# Low_24/Control_24_pval
# Low_24/Control_24_adj-p
# Low_48/Control_48_x
# Low_48/Control_48_pval
# Low_48/Control_48_adj-p
# Low_72/Control_72_x
# Low_72/Control_72_pval
# Low_72/Control_72_adj-p
# Oscillation_3.5/Control_3.5_x
# Oscillation_3.5/Control_3.5_pval
# Oscillation_3.5/Control_3.5_adj-p
# Oscillation_4.5/Control_4.5_x
# Oscillation_4.5/Control_4.5_pval
# Oscillation_4.5/Control_4.5_adj-p
# Oscillation_5.5/Control_5.5_x
# Oscillation_5.5/Control_5.5_pval
# Oscillation_5.5/Control_5.5_adj-p
# Oscillation_24/Control_24_x
# Oscillation_24/Control_24_pval
# Oscillation_24/Control_24_adj-p
# Oscillation_48/Control_48_x
# Oscillation_48/Control_48_pval
# Oscillation_48/Control_48_adj-p
# Oscillation_72/Control_72_x
# Oscillation_72/Control_72_pval
# Oscillation_72/Control_72_adj-p
# Control_4.5/Control_3.5_x
# Control_4.5/Control_3.5_pval
# Control_4.5/Control_3.5_adj-p
# Control_5.5/Control_3.5_x
# Control_5.5/Control_3.5_pval
# Control_5.5/Control_3.5_adj-p
# Control_24/Control_3.5_x
# Control_24/Control_3.5_pval
# Control_24/Control_3.5_adj-p
# Control_48/Control_3.5_x
# Control_48/Control_3.5_pval
# Control_48/Control_3.5_adj-p
# Control_72/Control_3.5_x
# Control_72/Control_3.5_pval
# Control_72/Control_3.5_adj-p
# Low_4.5/Low_3.5_x
# Low_4.5/Low_3.5_pval
# Low_4.5/Low_3.5_adj-p
# Low_5.5/Low_3.5_x
# Low_5.5/Low_3.5_pval
# Low_5.5/Low_3.5_adj-p
# Low_24/Low_3.5_x
# Low_24/Low_3.5_pval
# Low_24/Low_3.5_adj-p
# Low_48/Low_3.5_x
# Low_48/Low_3.5_pval
# Low_48/Low_3.5_adj-p
# Low_72/Low_3.5_x
# Low_72/Low_3.5_pval
# Low_72/Low_3.5_adj-p
# Oscillation_4.5/Oscillation_3.5_x
# Oscillation_4.5/Oscillation_3.5_pval
# Oscillation_4.5/Oscillation_3.5_adj-p
# Oscillation_5.5/Oscillation_3.5_x
# Oscillation_5.5/Oscillation_3.5_pval
# Oscillation_5.5/Oscillation_3.5_adj-p
# Oscillation_24/Oscillation_3.5_x
# Oscillation_24/Oscillation_3.5_pval
# Oscillation_24/Oscillation_3.5_adj-p
# Oscillation_48/Oscillation_3.5_x
# Oscillation_48/Oscillation_3.5_pval
# Oscillation_48/Oscillation_3.5_adj-p
# Oscillation_72/Oscillation_3.5_x
# Oscillation_72/Oscillation_3.5_pval
# Oscillation_72/Oscillation_3.5_adj-p
# Type
# Experiment
# site_number
# early/late
# early/late_ANOVA_padj
# early/late_ANOVA_p
# low/control_late_combined
# low/control_late_combined_ANOVA_padj
# low/control_late_combined_ANOVA_p
# osc/control_late_cominbed
# osc/control_late_cominbedANOVA_padj
# osc/control_late_cominbedANOVA_p
# proteinId
# proteinID
# #proteinId
# osc/low_late_cominbed
# osc/low_late_cominbedANOVA_padj
# osc/low_late_cominbedANOVA_p
# YALI1_protID
# YALI1_mod
# YALI2
# YALI0_locus
# Low_3.5/Control_3.5_y
# Low_3.5/Control_3.5_ANOVA_padj
# Low_3.5/Control_3.5_ANOVA_p
# Low_4.5/Control_4.5_y
# Low_4.5/Control_4.5_ANOVA_padj
# Low_4.5/Control_4.5_ANOVA_p
# Low_5.5/Control_5.5_y
# Low_5.5/Control_5.5_ANOVA_padj
# Low_5.5/Control_5.5_ANOVA_p
# Low_24/Control_24_y
# Low_24/Control_24_ANOVA_padj
# Low_24/Control_24_ANOVA_p
# Low_48/Control_48_y
# Low_48/Control_48_ANOVA_padj
# Low_48/Control_48_ANOVA_p
# Low_72/Control_72_y
# Low_72/Control_72_ANOVA_padj
# Low_72/Control_72_ANOVA_p
# Oscillation_3.5/Control_3.5_y
# Oscillation_3.5/Control_3.5_ANOVA_padj
# Oscillation_3.5/Control_3.5_ANOVA_p
# Oscillation_4.5/Control_4.5_y
# Oscillation_4.5/Control_4.5_ANOVA_padj
# Oscillation_4.5/Control_4.5_ANOVA_p
# Oscillation_5.5/Control_5.5_y
# Oscillation_5.5/Control_5.5_ANOVA_padj
# Oscillation_5.5/Control_5.5_ANOVA_p
# Oscillation_24/Control_24_y
# Oscillation_24/Control_24_ANOVA_padj
# Oscillation_24/Control_24_ANOVA_p
# Oscillation_48/Control_48_y
# Oscillation_48/Control_48_ANOVA_padj
# Oscillation_48/Control_48_ANOVA_p
# Oscillation_72/Control_72_y
# Oscillation_72/Control_72_ANOVA_padj
# Oscillation_72/Control_72_ANOVA_p
# Control_4.5/Control_3.5_y
# Control_4.5/Control_3.5_ANOVA_padj
# Control_4.5/Control_3.5_ANOVA_p
# Control_5.5/Control_3.5_y
# Control_5.5/Control_3.5_ANOVA_padj
# Control_5.5/Control_3.5_ANOVA_p
# Control_24/Control_3.5_y
# Control_24/Control_3.5_ANOVA_padj
# Control_24/Control_3.5_ANOVA_p
# Control_48/Control_3.5_y
# Control_48/Control_3.5_ANOVA_padj
# Control_48/Control_3.5_ANOVA_p
# Control_72/Control_3.5_y
# Control_72/Control_3.5_ANOVA_padj
# Control_72/Control_3.5_ANOVA_p
# Low_4.5/Low_3.5_y
# Low_4.5/Low_3.5_ANOVA_padj
# Low_4.5/Low_3.5_ANOVA_p
# Low_5.5/Low_3.5_y
# Low_5.5/Low_3.5_ANOVA_padj
# Low_5.5/Low_3.5_ANOVA_p
# Low_24/Low_3.5_y
# Low_24/Low_3.5_ANOVA_padj
# Low_24/Low_3.5_ANOVA_p
# Low_48/Low_3.5_y
# Low_48/Low_3.5_ANOVA_padj
# Low_48/Low_3.5_ANOVA_p
# Low_72/Low_3.5_y
# Low_72/Low_3.5_ANOVA_padj
# Low_72/Low_3.5_ANOVA_p
# Oscillation_4.5/Oscillation_3.5_y
# Oscillation_4.5/Oscillation_3.5_ANOVA_padj
# Oscillation_4.5/Oscillation_3.5_ANOVA_p
# Oscillation_5.5/Oscillation_3.5_y
# Oscillation_5.5/Oscillation_3.5_ANOVA_padj
# Oscillation_5.5/Oscillation_3.5_ANOVA_p
# Oscillation_24/Oscillation_3.5_y
# Oscillation_24/Oscillation_3.5_ANOVA_padj
# Oscillation_24/Oscillation_3.5_ANOVA_p
# Oscillation_48/Oscillation_3.5_y
# Oscillation_48/Oscillation_3.5_ANOVA_padj
# Oscillation_48/Oscillation_3.5_ANOVA_p
# Oscillation_72/Oscillation_3.5_y
# Oscillation_72/Oscillation_3.5_ANOVA_padj
# Oscillation_72/Oscillation_3.5_ANOVA_p

# %% [markdown]
# # Final REDOX File for processed.

# %%
# combined_df.save_to_csv('processedProteomic.csv')

# %%
# combined_df['YALI1_protID'] = combined_df['proteinId'].map(JGI_protID_toYali1.set_index('JGI_protID')['YALI1_protID'])
# combined_df['YALI0_locus'] = combined_df['YALI1_protID'].map(Yali1_Yali0.set_index('YALI1_Proteins')['YALI0_locus_ID'])
# combined_df['YALI1_protID_converted'] = combined_df['YALI1_protID'].str.replace('g', 'p', regex=False)
# combined_df['YALI2'] = combined_df['YALI1_protID_converted'].map(Yali1_Yali2.set_index('YALI1')['YALI2'])

# %%
Redox_PATH = '../Data/ProcessedData/Proteomics/PPI_yarrowia_redox_wAnnotations_fullLog2FC_withOsc.csv'
combined_df.to_csv(Redox_PATH)

# %%
# merged_df.to_csv('../Data/ProcessedData/Proteomics/PPI_yarrowia_protein_abundance_wAnnotations_wOscLow_fullLog2FC.csv')
